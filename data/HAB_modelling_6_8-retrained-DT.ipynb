# %%
from datetime import datetime
import pandas as pd
import numpy as np
import os
import pickle
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.svm import SVC 
from sklearn.tree import export_text
import dtreeviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold
import umap

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import warnings

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

import ipynbname
notebook_name = ipynbname.name()

import seaborn as sns

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 35)
# Out:
# 2023-06-05 13:51:46.776788: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Define directory path name and timestamp

# Get the current date and time as a string
timestamp = datetime.datetime.now().strftime('%d%m%Y_%H%M')

# Construct the directory path with the models folder and timestamp
dir_path = f"models/{timestamp}"
    
# Create the directory if it doesn't exist
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

# %%
import random
# Generate a random number between 0 and 100
# rand_num = random.randint(0, 10000)
rand_num = None

#save random state number
with open(f"{dir_path}/random_state_number-{notebook_name}-{timestamp}.txt", 'w') as f:
    f.write(str(rand_num))
print(rand_num)
# Out:
# None

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")
# data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# SECCHI                   450
# DIN                      352
# PO4-P                    349
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
# move month to first place
cols = data.columns.tolist()  # Get a list of column names
cols = [cols[-2]] + cols[:-2] + [cols[-1]]  # Move the one before the last column to the first position
data = data[cols]

# %%
data.drop(columns=["Chl-a","PO4-P","DIN","SECCHI"], inplace=True)
# data.drop(columns=["SECCHI"], inplace=True)
data.isnull().sum()
# Out:
# month                      0
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# salinity                  21
# T                         59
# Soca                       0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Descriptive analysis

# %%
# describe
description = data.describe(include='all').round(0)

# Calculate the number of missing values for each column
missing_values = data.isna().sum()
missing_values.name = 'missing_values'

# Append the missing_values row to the description DataFrame
description_with_missing = description.append(missing_values)
description_with_missing = description_with_missing.drop(['unique', 'top', 'freq'])

description_with_missing

# # Descriptive statistics without decimals.
# # Generate summary statistics for the dataset and format all numbers as integers
# description = data.describe(include='all').apply(lambda x: x.apply(lambda y: "{:.0f}".format(y) if isinstance(y, (int, float)) else y))

# # Calculate the number of missing values for each column
# missing_values = data.isna().sum()
# missing_values.name = 'missing_values'

# # Append the missing_values row to the description DataFrame
# description_with_missing = description.append(missing_values)
# description_with_missing = description_with_missing.drop(['unique', 'top', 'freq'])

# # Output the modified DataFrame
# description_with_missing
# Out:
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                  month     DSP  Dinophysis caudata  Dinophysis fortii  \
# count           1452.0  1451.0              1451.0             1451.0
# mean               7.0   106.0                25.0               26.0
# std                3.0   340.0                88.0              160.0
# min                1.0     0.0                 0.0                0.0
# 25%                5.0    10.0                 0.0                0.0
# 50%                8.0    37.0                 0.0                0.0
# 75%               10.0    90.0                13.0               10.0
# max               12.0  7630.0              1309.0             4624.0
# missing_values     0.0     1.0                 1.0                1.0
#
#                 Phalacroma rotundatum  Dinophysis sacculus  Dinophysis tripos  \
# count                          1451.0               1451.0             1451.0
# mean                             14.0                 29.0                5.0
# std                              30.0                178.0               41.0
# min                               0.0                  0.0                0.0
# 25%                               0.0                  0.0                0.0
# 50%                              10.0                  0.0                0.0
# 75%                              20.0                 10.0                0.0
# max                             393.0               4639.0             1139.0
# missing_values                    1.0                  1.0                1.0
#
#                 sun [h]  air temp  wind strength  precipitation  salinity  \
# count            1452.0    1452.0         1452.0         1452.0    1431.0
# mean              159.0      17.0            3.0           58.0      37.0
# std                61.0       6.0            0.0           51.0      26.0
# min                23.0      -1.0            1.0            0.0      24.0
# 25%               113.0      12.0            3.0           20.0      36.0
# 50%               161.0      17.0            3.0           45.0      37.0
# 75%               207.0      22.0            3.0           79.0      37.0
# max               278.0      27.0            5.0          268.0     999.0
# missing_values      0.0       0.0            0.0            0.0      21.0
#
#                      T     Soca lipophylic_toxins
# count           1393.0   1452.0              1132
# mean              19.0   3295.0               NaN
# std                5.0   2330.0               NaN
# min                6.0    594.0               NaN
# 25%               16.0   1636.0               NaN
# 50%               20.0   2581.0               NaN
# 75%               24.0   4237.0               NaN
# max               28.0  16040.0               NaN
# missing_values    59.0      0.0               320

# %%
# Visualize the distribution of each variable with boxplot
num_columns = len(data.columns)
subplots_per_row = 4
num_rows = math.ceil(num_columns / subplots_per_row)

fig, axes = plt.subplots(num_rows, subplots_per_row, figsize=(20, num_rows * 4))

for i, column in enumerate(data.columns):
    row = i // subplots_per_row
    col = i % subplots_per_row
    
    if data[column].dtype == 'float64' or data[column].dtype == 'int64':
        sns.boxplot(data=data, y=column, ax=axes[row, col], palette="pastel", showmeans=True)
        axes[row, col].set_title(f'Box plot of {column}')
    else:
        # Skip categorical columns for box plots
        axes[row, col].set_visible(False)

# Hide unused subplots
for i in range(num_columns, num_rows * subplots_per_row):
    row = i // subplots_per_row
    col = i % subplots_per_row
    axes[row, col].set_visible(False)

plt.tight_layout()
plt.savefig(f"{dir_path}/feature_distribution_boxplots-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Create a figure with a more narrow width
fig, ax = plt.subplots(figsize=(4, 5))

# Create a custom  pastel color palette
custom_pastel = sns.color_palette("bright")

# Set the color for class 1 to orange
custom_pastel[1] = sns.color_palette("bright")[2]
custom_pastel[0] = sns.color_palette("bright")[3]


# Create a count plot
sns.countplot(data=data, x="lipophylic_toxins", ax=ax, palette=custom_pastel, alpha=0.6)
ax.set_title('Distribution of lipophylic toxins test counts')

# Add numbers on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height() + 0.5,
            p.get_height(), ha='center', fontsize=10)

# Show the plot
plt.savefig(f"{dir_path}/lipophylic_toxins_test_counts-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# ## Descriptive analysis by month

# %%
# table of mean values for each feature by month 
import calendar

grouped_means = data.groupby('month').mean()

# Count binary values for the categorical feature grouped by month
binary_counts = data.groupby('month')['lipophylic_toxins'].value_counts().unstack()

# Calculate the ratio of positive values for each month
sum_positive = binary_counts["poz"].sum()
positive_ratios = [i for i in (binary_counts["poz"] / sum_positive)] 
positive_ratios = [round(v * 100, 1) for v in positive_ratios]

# Change month names
month_names = {i: calendar.month_name[i] for i in range(1, 13)}

# Update the index using the month_names dictionary
grouped_means.index = grouped_means.index.map(month_names)
binary_counts.index = binary_counts.index.map(month_names)

# Concatenate the grouped_means and binary_counts DataFrames
result = pd.concat([grouped_means, binary_counts], axis=1).round(2)

# Add the positive_ratios Series as a new column to the result DataFrame
result["poz %"] = positive_ratios
result.to_csv(f"{dir_path}/features_by_month_A-{notebook_name}-{timestamp}.csv", index=True)

result
# Out:
#               DSP  Dinophysis caudata  Dinophysis fortii  \
# month
# January      9.00                1.16               2.96
# February    12.86                1.02               4.08
# March       12.38                0.21               0.68
# April       15.49                0.97               0.48
# May         59.00                6.00               0.97
# June       146.89               29.23               1.49
# July       237.04               67.07              44.50
# August     129.67               55.46              24.23
# September  116.79               28.04              58.58
# October     97.76               13.21              35.56
# November    80.54               13.81              29.33
# December    81.96                2.33              51.95
#
#            Phalacroma rotundatum  Dinophysis sacculus  Dinophysis tripos  \
# month
# January                     3.66                 0.09               0.20
# February                    3.38                 0.20               0.69
# March                       3.79                 0.43               0.64
# April                       5.24                 4.51               0.00
# May                         9.67                34.25               0.15
# June                       12.87                93.28               0.09
# July                       19.57                97.25               0.04
# August                     19.01                22.96               0.08
# September                  12.81                 3.57               6.04
# October                    19.39                 2.17              19.76
# November                   19.09                 1.11               8.90
# December                   16.06                 1.18               4.77
#
#            sun [h]  air temp  wind strength  precipitation  salinity      T  \
# month
# January      72.62      4.95           2.71          46.53     36.95  11.07
# February     80.19      5.52           3.06          60.66     37.02  10.22
# March       118.56      7.55           3.30          30.01     37.17   9.49
# April       144.63     11.69           3.17          54.90     36.93  11.68
# May         171.96     16.22           2.89          48.55     36.57  14.87
# June        202.85     20.51           2.83          45.16     35.60  20.28
# July        227.47     23.31           2.88          38.27     35.40  23.48
# August      220.46     23.46           3.03          54.38     41.92  24.93
# September   174.65     20.06           3.11          69.73     36.59  24.38
# October     127.60     15.56           3.08          72.07     36.91  21.70
# November     82.48     11.35           3.01          74.21     36.72  17.61
# December     65.97      7.51           2.83          81.32     36.81  15.56
#
#               Soca  neg  poz  poz %
# month
# January    4652.16   15    3    2.2
# February   4378.79   21    3    2.2
# March      3257.07   28    2    1.5
# April      3826.10   66    2    1.5
# May        3864.97   89   14   10.3
# June       3436.93  115   12    8.8
# July       2473.18  125   18   13.2
# August     1637.28  126   11    8.1
# September  2102.01  143   31   22.8
# October    2988.28  138   24   17.6
# November   5263.97   91   13    9.6
# December   5868.74   39    3    2.2

# %%
# table of mean values for each feature by month
import calendar

grouped_means = data.groupby('month').mean()

# Count binary values for the categorical feature grouped by month
binary_counts = data.groupby('month')['lipophylic_toxins'].value_counts().unstack()

# Calculate the ratio of positive values for each month
sum_positive = binary_counts["poz"].sum()
positive_ratios = [i for i in (binary_counts["poz"] / sum_positive)] 
positive_ratios = [round(v * 100, 1) for v in positive_ratios]

# Calculate the ratio of negative values for each month
sum_negative = binary_counts["neg"].sum()
negative_ratios = [i for i in (binary_counts["neg"] / sum_negative)]
negative_ratios = [round(v * 100, 1) for v in negative_ratios]

# Change month names
month_names = {i: calendar.month_name[i] for i in range(1, 13)}

# Update the index using the month_names dictionary
grouped_means.index = grouped_means.index.map(month_names)
binary_counts.index = binary_counts.index.map(month_names)

# Concatenate the grouped_means and binary_counts DataFrames
result = pd.concat([grouped_means, binary_counts], axis=1).round(2)

# Drop the 'neg' and 'poz' columns
result = result.drop(columns=['neg', 'poz'])

# Add the positive_ratios and negative_ratios Series as new columns to the result DataFrame
result["poz %"] = positive_ratios
result["neg %"] = negative_ratios

result.to_csv(f"{dir_path}/features_by_month_B-{notebook_name}-{timestamp}.csv", index=True)
result
# Out:
#               DSP  Dinophysis caudata  Dinophysis fortii  \
# month
# January      9.00                1.16               2.96
# February    12.86                1.02               4.08
# March       12.38                0.21               0.68
# April       15.49                0.97               0.48
# May         59.00                6.00               0.97
# June       146.89               29.23               1.49
# July       237.04               67.07              44.50
# August     129.67               55.46              24.23
# September  116.79               28.04              58.58
# October     97.76               13.21              35.56
# November    80.54               13.81              29.33
# December    81.96                2.33              51.95
#
#            Phalacroma rotundatum  Dinophysis sacculus  Dinophysis tripos  \
# month
# January                     3.66                 0.09               0.20
# February                    3.38                 0.20               0.69
# March                       3.79                 0.43               0.64
# April                       5.24                 4.51               0.00
# May                         9.67                34.25               0.15
# June                       12.87                93.28               0.09
# July                       19.57                97.25               0.04
# August                     19.01                22.96               0.08
# September                  12.81                 3.57               6.04
# October                    19.39                 2.17              19.76
# November                   19.09                 1.11               8.90
# December                   16.06                 1.18               4.77
#
#            sun [h]  air temp  wind strength  precipitation  salinity      T  \
# month
# January      72.62      4.95           2.71          46.53     36.95  11.07
# February     80.19      5.52           3.06          60.66     37.02  10.22
# March       118.56      7.55           3.30          30.01     37.17   9.49
# April       144.63     11.69           3.17          54.90     36.93  11.68
# May         171.96     16.22           2.89          48.55     36.57  14.87
# June        202.85     20.51           2.83          45.16     35.60  20.28
# July        227.47     23.31           2.88          38.27     35.40  23.48
# August      220.46     23.46           3.03          54.38     41.92  24.93
# September   174.65     20.06           3.11          69.73     36.59  24.38
# October     127.60     15.56           3.08          72.07     36.91  21.70
# November     82.48     11.35           3.01          74.21     36.72  17.61
# December     65.97      7.51           2.83          81.32     36.81  15.56
#
#               Soca  poz %  neg %
# month
# January    4652.16    2.2    1.5
# February   4378.79    2.2    2.1
# March      3257.07    1.5    2.8
# April      3826.10    1.5    6.6
# May        3864.97   10.3    8.9
# June       3436.93    8.8   11.5
# July       2473.18   13.2   12.6
# August     1637.28    8.1   12.7
# September  2102.01   22.8   14.4
# October    2988.28   17.6   13.9
# November   5263.97    9.6    9.1
# December   5868.74    2.2    3.9

# %%
# Plot phytoplantkon distribution by month
# Get the phytoplankton columns
phytoplankton = data.iloc[:, 1:7].columns

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the distribution of each of the first 6 numerical variables by month on the same plot
for column in phytoplankton:
    sns.lineplot(data=data, x='month', y=column, ax=ax, label=column, palette="pastel")

# Customize the plot
ax.set_title('Distribution of phytoplankton by Month')
ax.set_ylabel('Abundance')  # Set the y-axis label to "Abundance"
ax.legend()

# Customize the x-axis ticks and labels to show only month names
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(range(1, 13), month_names)

# Save and show the plot
plt.tight_layout()
plt.savefig(f"{dir_path}/phytoplankton_abundance_distribution_by_month-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Visualise target variable distribution by month
# Create a displot with hue
custom_palette = {'neg': '#3eb489', 'poz': '#ff5349'}

sns.displot(data=data, x="month", hue="lipophylic_toxins", kde=True, height=6, palette=custom_palette, legend=False)

# Customize the x-axis ticks and labels
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                         'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Customize the plot if desired
sns.set_style("whitegrid")
sns.set_palette("Set2")
plt.title('Distribution of Lipophilic Toxins test results by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title="Lipophylic Toxins", loc='upper left', labels=['neg', 'poz'], bbox_to_anchor=(0.05, 0.7))


# Show the plot
plt.savefig(f"{dir_path}/target_distribution_month-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Data preprocessing for modelling

# %% [markdown]
# ## Removing instances with unlabeled target, label encoding

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    956
# poz    132
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# ## Dimensionality reduction

# %%
# Using UMAP for dimensionality reduction and visualisation before removing similar instances 
# Initialize UMAP

reducer = umap.UMAP(n_components=2, metric="correlation", random_state=rand_num)

# Fit and transform the data
embedding = reducer.fit_transform(X)

# Create a DataFrame for seaborn
df = pd.DataFrame(embedding, columns=['UMAP1', 'UMAP2'])
df['y'] = pd.Series(y).map({0: 'neg', 1: 'poz'})

# Create a color palette dictionary with pastel colors
color_mapping = {'neg': '#3eb489', 'poz': '#ff5349'}

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(x='UMAP1', y='UMAP2', hue='y', data=df, palette=color_mapping, alpha=0.9)

# Remove x and y axis names
plt.gca().axes.get_xaxis().set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)

plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection', fontsize=18)
plt.savefig(f"{dir_path}/umap_before_removal-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Clean instances close to the decision boundary

# %% [markdown]
# Clean the dataset by removing samples close to the decision boundary. Because the dataset is heavily imbalanced in favor of clas 0 (neg) we will remove instances from this class whenever finding samples which do not agree “enough” with their neighboorhood. The EditedNearestNeighbours will be used. One other option is to use Tomek links but it is more conservative and was found to perform slightly worse.

# %%
from collections import Counter
from imblearn.under_sampling import TomekLinks, RepeatedEditedNearestNeighbours

print(f'Original dataset shape: {Counter(y)}')
usmp = RepeatedEditedNearestNeighbours()
lastMajorityCount = Counter(y)[0]
X_res, y_res = usmp.fit_resample(X, y)
print(f'Resampled dataset shape {Counter(y_res)}')
X = X_res
y = y_res
# Out:
# Original dataset shape: Counter({0: 956, 1: 132})
# Resampled dataset shape Counter({0: 745, 1: 132})

# %%
# Using UMAP for dimensionality reduction and visualisation after removing similar instances 
# Initialize UMAP

reducer = umap.UMAP(n_components=2, metric="correlation", random_state=rand_num)

# Fit and transform the data
embedding = reducer.fit_transform(X)

# Create a DataFrame for seaborn
df = pd.DataFrame(embedding, columns=['UMAP1', 'UMAP2'])
df['y'] = pd.Series(y).map({0: 'neg', 1: 'poz'})

# Create a color palette dictionary with pastel colors
color_mapping = {'neg': '#3eb489', 'poz': '#ff5349'}

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(x='UMAP1', y='UMAP2', hue='y', data=df, palette=color_mapping, alpha=0.9)

# Remove x and y axis names
plt.gca().axes.get_xaxis().set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)

plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection', fontsize=18)
plt.savefig(f"{dir_path}/umap_after_removal-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Train-test split

# %%
# All data
import copy

X_all = copy.copy(X)
y_all = copy.copy(y)

X_all.to_csv(f"{dir_path}/X_all.csv", index=False)
pd.Series(y_all).to_csv(f"{dir_path}/y_all.csv", index=False)

# train test split
X, X_eval, y, y_eval = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.30, random_state=rand_num) 

# Save X, X_eval, y, y_eval 
X.to_csv(f"{dir_path}/X_train.csv", index=False)
X_eval.to_csv(f"{dir_path}/X_test.csv", index=False)
pd.Series(y).to_csv(f"{dir_path}/y_train.csv", index=False)
pd.Series(y_eval).to_csv(f"{dir_path}/y_test.csv", index=False)

# # # Load 
# # X = pd.read_csv('X_train.csv')
# # X_eval = pd.read_csv('X_test.csv')
# y = pd.read_csv(f"{dir_path}/y_train.csv", squeeze=True).values
# y_eval = pd.read_csv(f"{dir_path}/y_test.csv", squeeze=True).values

# %% [markdown]
# # Correlation analysis on training data

# %%
# Calculate Pearson correlation between numeric features and binary target variable
pearson_correlations = X_all.corrwith(pd.Series(y_all), method='pearson')
pearson_correlations.name = 'Pearson'


# Combine the correlation values into a single dataframe
corr_df = pd.concat([pearson_correlations], axis=1)

# Create a new column for absolute Spearman correlation values
corr_df['Pearson_abs'] = corr_df['Pearson'].abs()

# Sort the dataframe by absolute Spearman correlation values
corr_df_sorted = corr_df.sort_values(by=['Pearson_abs'], ascending=False)

# Drop the absolute Spearman correlation column and return the sorted dataframe
corr_df_ranked = corr_df_sorted.drop(columns=['Pearson_abs']).round(2)

corr_df_ranked.to_csv(f"{dir_path}/Pearson_cor_coef-{notebook_name}-{timestamp}.csv", index=True)

corr_df_ranked
# Out:
#                        Pearson
# Dinophysis tripos         0.24
# salinity                 -0.21
# Dinophysis fortii         0.19
# DSP                       0.16
# precipitation             0.13
# Dinophysis caudata        0.10
# sun [h]                  -0.08
# wind strength            -0.07
# Soca                      0.07
# Dinophysis sacculus       0.07
# month                     0.05
# air temp                 -0.02
# T                         0.02
# Phalacroma rotundatum    -0.01

# %% [markdown]
# # Model Training and Evaluation

# %%
# Saving models

# Function to save best estimator
def save_best_estimator(grid_search_cv, classifier_name, notebook_name):
    # Get the best estimator from the GridSearchCV object
    best_estimator = grid_search_cv.best_estimator_

    # Construct the file name with the classifier name and notebook name
    pickle_file_name = f"{dir_path}/{classifier_name}-{notebook_name}-{timestamp}.pkl"
    
    # Save the best estimator to the file
    with open(pickle_file_name, 'wb') as f:
        pickle.dump(best_estimator, f)

    print(f"Best estimator saved as: {pickle_file_name}")

# %%
# Function for loading saved models

def load_best_estimator(pickle_file_name):
    with open(pickle_file_name, 'rb') as f:
        best_estimator = pickle.load(f)
    return best_estimator

# %% [markdown]
# ## SVM

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE(random_state=rand_num)), 
    ('under', RandomUnderSampler(random_state=rand_num)), 
    ('clf', SVC(random_state=rand_num))
])

parameters = {
            'clf__C': [0.1, 0.5, 1, 3, 10, 100],
            # 'clf__gamma': ['scale', 'auto'],
            # 'clf__kernel': ['linear', 'rbf', 'poly'],
            'clf__class_weight': ['balanced', None],
            'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
            'under__sampling_strategy': [0.5, 0.6, 0.7],
            'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv_svm = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True, random_state=rand_num),
                    return_train_score=False, 
                    verbose=1, 
                    refit="f1",
                    n_jobs=-1)
resultsGSCV = gscv_svm.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_svm, classifier_name, notebook_name)

# Save best parameters 
SVM_best_params = gscv_svm.best_params_
df = pd.DataFrame([SVM_best_params])
df.to_csv(f"{dir_path}/SVM_best_params-{notebook_name}-{timestamp}.csv", index=False)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best estimator saved as: models/02062023_1415/SVC-HAB_modelling_6_8-retrained-DT-02062023_1415.pkl
#                                                                               285  \
# mean_fit_time                                                            0.055361
# std_fit_time                                                             0.005319
# mean_score_time                                                          0.037445
# std_score_time                                                           0.001765
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.526316
# split3_test_recall                                                       0.611111
# split4_test_recall                                                       0.333333
# mean_test_recall                                                         0.509942
# std_test_recall                                                          0.096493
# rank_test_recall                                                               74
# split0_test_precision                                                         0.6
# split1_test_precision                                                     0.37931
# split2_test_precision                                                    0.909091
# split3_test_precision                                                        0.44
# split4_test_precision                                                    0.428571
# mean_test_precision                                                      0.551395
# std_test_precision                                                       0.193606
# rank_test_precision                                                            38
# split0_test_f1                                                           0.545455
# split1_test_f1                                                           0.458333
# split2_test_f1                                                           0.666667
# split3_test_f1                                                           0.511628
# split4_test_f1                                                              0.375
# mean_test_f1                                                             0.511416
# std_test_f1                                                              0.096632
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.694709
# split1_test_roc_auc                                                        0.7667
# split2_test_roc_auc                                                      0.882085
# split3_test_roc_auc                                                      0.822115
# split4_test_roc_auc                                                      0.714209
# mean_test_roc_auc                                                        0.775964
# std_test_roc_auc                                                         0.069128
# rank_test_roc_auc                                                               2
# split0_test_recall_weighted                                              0.878049
# split1_test_recall_weighted                                              0.788618
# split2_test_recall_weighted                                              0.918699
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.836066
# mean_test_recall_weighted                                                 0.84986
# std_test_recall_weighted                                                 0.044627
# rank_test_recall_weighted                                                      61
#
#                                                                               302  \
# mean_fit_time                                                            0.033068
# std_fit_time                                                             0.002624
# mean_score_time                                                          0.029054
# std_score_time                                                           0.002602
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.315789
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.222222
# mean_test_recall                                                         0.412865
# std_test_recall                                                          0.121511
# rank_test_recall                                                              165
# split0_test_precision                                                    0.818182
# split1_test_precision                                                    0.588235
# split2_test_precision                                                         1.0
# split3_test_precision                                                    0.529412
# split4_test_precision                                                         1.0
# mean_test_precision                                                      0.787166
# std_test_precision                                                       0.198781
# rank_test_precision                                                             7
# split0_test_f1                                                            0.62069
# split1_test_f1                                                           0.555556
# split2_test_f1                                                               0.48
# split3_test_f1                                                           0.514286
# split4_test_f1                                                           0.363636
# mean_test_f1                                                             0.506833
# std_test_f1                                                              0.085578
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.679365
# split1_test_roc_auc                                                      0.781377
# split2_test_roc_auc                                                      0.865385
# split3_test_roc_auc                                                      0.724359
# split4_test_roc_auc                                                      0.728098
# mean_test_roc_auc                                                        0.755717
# std_test_roc_auc                                                         0.063657
# rank_test_roc_auc                                                              19
# split0_test_recall_weighted                                              0.910569
# split1_test_recall_weighted                                              0.869919
# split2_test_recall_weighted                                              0.894309
# split3_test_recall_weighted                                              0.860656
# split4_test_recall_weighted                                              0.885246
# mean_test_recall_weighted                                                 0.88414
# std_test_recall_weighted                                                 0.017646
# rank_test_recall_weighted                                                       2
#
#                                                                               291  \
# mean_fit_time                                                            0.042151
# std_fit_time                                                             0.003848
# mean_score_time                                                          0.030858
# std_score_time                                                           0.002522
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.526316
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.277778
# mean_test_recall                                                         0.477193
# std_test_recall                                                          0.101246
# rank_test_recall                                                              137
# split0_test_precision                                                    0.526316
# split1_test_precision                                                    0.454545
# split2_test_precision                                                    0.909091
# split3_test_precision                                                        0.45
# split4_test_precision                                                    0.454545
# mean_test_precision                                                        0.5589
# std_test_precision                                                       0.177389
# rank_test_precision                                                            37
# split0_test_f1                                                           0.540541
# split1_test_f1                                                           0.487805
# split2_test_f1                                                           0.666667
# split3_test_f1                                                           0.473684
# split4_test_f1                                                           0.344828
# mean_test_f1                                                             0.502705
# std_test_f1                                                              0.104216
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.678307
# split1_test_roc_auc                                                      0.783907
# split2_test_roc_auc                                                      0.898279
# split3_test_roc_auc                                                      0.723825
# split4_test_roc_auc                                                      0.686432
# mean_test_roc_auc                                                         0.75415
# std_test_roc_auc                                                         0.081137
# rank_test_roc_auc                                                              23
# split0_test_recall_weighted                                              0.861789
# split1_test_recall_weighted                                              0.829268
# split2_test_recall_weighted                                              0.918699
# split3_test_recall_weighted                                              0.836066
# split4_test_recall_weighted                                              0.844262
# mean_test_recall_weighted                                                0.858017
# std_test_recall_weighted                                                 0.032231
# rank_test_recall_weighted                                                      30
#
#                                                                               278  \
# mean_fit_time                                                            0.042558
# std_fit_time                                                             0.003643
# mean_score_time                                                          0.036687
# std_score_time                                                            0.00314
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.473684
# split3_test_recall                                                       0.611111
# split4_test_recall                                                       0.333333
# mean_test_recall                                                              0.5
# std_test_recall                                                           0.09444
# rank_test_recall                                                               96
# split0_test_precision                                                     0.47619
# split1_test_precision                                                     0.37037
# split2_test_precision                                                    0.818182
# split3_test_precision                                                         0.5
# split4_test_precision                                                         0.5
# mean_test_precision                                                      0.532949
# std_test_precision                                                       0.150454
# rank_test_precision                                                            41
# split0_test_f1                                                           0.512821
# split1_test_f1                                                           0.434783
# split2_test_f1                                                                0.6
# split3_test_f1                                                               0.55
# split4_test_f1                                                                0.4
# mean_test_f1                                                             0.499521
# std_test_f1                                                              0.073371
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.637566
# split1_test_roc_auc                                                      0.746964
# split2_test_roc_auc                                                      0.835526
# split3_test_roc_auc                                                      0.810363
# split4_test_roc_auc                                                      0.689103
# mean_test_roc_auc                                                        0.743904
# std_test_roc_auc                                                         0.073664
# rank_test_roc_auc                                                              35
# split0_test_recall_weighted                                              0.845528
# split1_test_recall_weighted                                              0.788618
# split2_test_recall_weighted                                              0.902439
# split3_test_recall_weighted                                              0.852459
# split4_test_recall_weighted                                              0.852459
# mean_test_recall_weighted                                                0.848301
# std_test_recall_weighted                                                 0.036153
# rank_test_recall_weighted                                                      62
#
#                                                                               276  \
# mean_fit_time                                                            0.056175
# std_fit_time                                                             0.002402
# mean_score_time                                                           0.03581
# std_score_time                                                           0.001787
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.526316
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.277778
# mean_test_recall                                                          0.49883
# std_test_recall                                                           0.11178
# rank_test_recall                                                              102
# split0_test_precision                                                    0.454545
# split1_test_precision                                                    0.407407
# split2_test_precision                                                    0.833333
# split3_test_precision                                                    0.454545
# split4_test_precision                                                    0.454545
# mean_test_precision                                                      0.520875
# std_test_precision                                                       0.157292
# rank_test_precision                                                            46
# split0_test_f1                                                                0.5
# split1_test_f1                                                           0.478261
# split2_test_f1                                                           0.645161
# split3_test_f1                                                                0.5
# split4_test_f1                                                           0.344828
# mean_test_f1                                                              0.49365
# std_test_f1                                                              0.095311
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.638095
# split1_test_roc_auc                                                      0.765182
# split2_test_roc_auc                                                      0.876518
# split3_test_roc_auc                                                      0.731303
# split4_test_roc_auc                                                      0.739316
# mean_test_roc_auc                                                        0.750083
# std_test_roc_auc                                                         0.076451
# rank_test_roc_auc                                                              26
# split0_test_recall_weighted                                              0.837398
# split1_test_recall_weighted                                              0.804878
# split2_test_recall_weighted                                              0.910569
# split3_test_recall_weighted                                              0.836066
# split4_test_recall_weighted                                              0.844262
# mean_test_recall_weighted                                                0.846635
# std_test_recall_weighted                                                 0.034739
# rank_test_recall_weighted                                                      65
#
#                                                                               321  \
# mean_fit_time                                                            0.039387
# std_fit_time                                                             0.007241
# mean_score_time                                                          0.024381
# std_score_time                                                           0.005929
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                       0.333333
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.263158
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.222222
# mean_test_recall                                                         0.369006
# std_test_recall                                                           0.12323
# rank_test_recall                                                              181
# split0_test_precision                                                    0.666667
# split1_test_precision                                                    0.833333
# split2_test_precision                                                         1.0
# split3_test_precision                                                    0.642857
# split4_test_precision                                                         1.0
# mean_test_precision                                                      0.828571
# std_test_precision                                                       0.154597
# rank_test_precision                                                             3
# split0_test_f1                                                           0.444444
# split1_test_f1                                                           0.645161
# split2_test_f1                                                           0.416667
# split3_test_f1                                                             0.5625
# split4_test_f1                                                           0.363636
# mean_test_f1                                                             0.486482
# std_test_f1                                                              0.102655
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.674603
# split1_test_roc_auc                                                      0.788968
# split2_test_roc_auc                                                      0.868927
# split3_test_roc_auc                                                      0.832799
# split4_test_roc_auc                                                      0.716346
# mean_test_roc_auc                                                        0.776329
# std_test_roc_auc                                                         0.071929
# rank_test_roc_auc                                                               1
# split0_test_recall_weighted                                              0.878049
# split1_test_recall_weighted                                              0.910569
# split2_test_recall_weighted                                              0.886179
# split3_test_recall_weighted                                              0.885246
# split4_test_recall_weighted                                              0.885246
# mean_test_recall_weighted                                                0.889058
# std_test_recall_weighted                                                 0.011147
# rank_test_recall_weighted                                                       1
#
#                                                                               301  \
# mean_fit_time                                                            0.037574
# std_fit_time                                                             0.004171
# mean_score_time                                                           0.03215
# std_score_time                                                           0.007365
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                       0.388889
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.368421
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.222222
# mean_test_recall                                                         0.390058
# std_test_recall                                                          0.100162
# rank_test_recall                                                              174
# split0_test_precision                                                    0.538462
# split1_test_precision                                                    0.714286
# split2_test_precision                                                         1.0
# split3_test_precision                                                    0.533333
# split4_test_precision                                                         0.8
# mean_test_precision                                                      0.717216
# std_test_precision                                                       0.174697
# rank_test_precision                                                            16
# split0_test_f1                                                           0.451613
# split1_test_f1                                                           0.606061
# split2_test_f1                                                           0.538462
# split3_test_f1                                                           0.484848
# split4_test_f1                                                           0.347826
# mean_test_f1                                                             0.485762
# std_test_f1                                                              0.086536
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                       0.67672
# split1_test_roc_auc                                                      0.765182
# split2_test_roc_auc                                                      0.910425
# split3_test_roc_auc                                                      0.759081
# split4_test_roc_auc                                                      0.731838
# mean_test_roc_auc                                                        0.768649
# std_test_roc_auc                                                         0.077473
# rank_test_roc_auc                                                               3
# split0_test_recall_weighted                                              0.861789
# split1_test_recall_weighted                                              0.894309
# split2_test_recall_weighted                                              0.902439
# split3_test_recall_weighted                                              0.860656
# split4_test_recall_weighted                                              0.877049
# mean_test_recall_weighted                                                0.879248
# std_test_recall_weighted                                                 0.016852
# rank_test_recall_weighted                                                       7
#
#                                                                               313  \
# mean_fit_time                                                            0.043193
# std_fit_time                                                             0.004975
# mean_score_time                                                          0.034159
# std_score_time                                                             0.0029
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.263158
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.222222
# mean_test_recall                                                         0.391228
# std_test_recall                                                          0.124801
# rank_test_recall                                                              171
# split0_test_precision                                                    0.615385
# split1_test_precision                                                    0.769231
# split2_test_precision                                                         1.0
# split3_test_precision                                                      0.5625
# split4_test_precision                                                    0.571429
# mean_test_precision                                                      0.703709
# std_test_precision                                                       0.165723
# rank_test_precision                                                            19
# split0_test_f1                                                           0.516129
# split1_test_f1                                                              0.625
# split2_test_f1                                                           0.416667
# split3_test_f1                                                           0.529412
# split4_test_f1                                                               0.32
# mean_test_f1                                                             0.481441
# std_test_f1                                                              0.104281
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.675661
# split1_test_roc_auc                                                      0.781377
# split2_test_roc_auc                                                      0.765688
# split3_test_roc_auc                                                       0.72062
# split4_test_roc_auc                                                      0.746261
# mean_test_roc_auc                                                        0.737921
# std_test_roc_auc                                                         0.037161
# rank_test_roc_auc                                                              45
# split0_test_recall_weighted                                              0.878049
# split1_test_recall_weighted                                              0.902439
# split2_test_recall_weighted                                              0.886179
# split3_test_recall_weighted                                              0.868852
# split4_test_recall_weighted                                              0.860656
# mean_test_recall_weighted                                                0.879235
# std_test_recall_weighted                                                 0.014429
# rank_test_recall_weighted                                                       8
#
#                                                                               296  \
# mean_fit_time                                                            0.043066
# std_fit_time                                                             0.003842
# mean_score_time                                                          0.033703
# std_score_time                                                           0.002547
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.631579
# split2_test_recall                                                       0.526316
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.333333
# mean_test_recall                                                         0.520468
# std_test_recall                                                          0.099861
# rank_test_recall                                                               57
# split0_test_precision                                                    0.526316
# split1_test_precision                                                       0.375
# split2_test_precision                                                       0.625
# split3_test_precision                                                    0.434783
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.458886
# std_test_precision                                                       0.105377
# rank_test_precision                                                            63
# split0_test_f1                                                           0.540541
# split1_test_f1                                                           0.470588
# split2_test_f1                                                           0.571429
# split3_test_f1                                                           0.487805
# split4_test_f1                                                           0.333333
# mean_test_f1                                                             0.480739
# std_test_f1                                                              0.082076
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.651852
# split1_test_roc_auc                                                      0.754555
# split2_test_roc_auc                                                      0.783907
# split3_test_roc_auc                                                      0.764957
# split4_test_roc_auc                                                      0.690705
# mean_test_roc_auc                                                        0.729195
# std_test_roc_auc                                                         0.049757
# rank_test_roc_auc                                                              51
# split0_test_recall_weighted                                              0.861789
# split1_test_recall_weighted                                              0.780488
# split2_test_recall_weighted                                              0.878049
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.803279
# mean_test_recall_weighted                                                0.830295
# std_test_recall_weighted                                                 0.036024
# rank_test_recall_weighted                                                      96
#
#                                                                               294  \
# mean_fit_time                                                            0.052742
# std_fit_time                                                             0.003431
# mean_score_time                                                          0.038315
# std_score_time                                                           0.002911
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.473684
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.277778
# mean_test_recall                                                         0.488304
# std_test_recall                                                          0.111173
# rank_test_recall                                                              119
# split0_test_precision                                                    0.526316
# split1_test_precision                                                     0.37931
# split2_test_precision                                                         0.9
# split3_test_precision                                                    0.434783
# split4_test_precision                                                      0.3125
# mean_test_precision                                                      0.510582
# std_test_precision                                                       0.206934
# rank_test_precision                                                            51
# split0_test_f1                                                           0.540541
# split1_test_f1                                                           0.458333
# split2_test_f1                                                            0.62069
# split3_test_f1                                                           0.487805
# split4_test_f1                                                           0.294118
# mean_test_f1                                                             0.480297
# std_test_f1                                                              0.108204
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.662963
# split1_test_roc_auc                                                      0.762652
# split2_test_roc_auc                                                       0.83502
# split3_test_roc_auc                                                      0.762821
# split4_test_roc_auc                                                      0.683761
# mean_test_roc_auc                                                        0.741443
# std_test_roc_auc                                                         0.061887
# rank_test_roc_auc                                                              38
# split0_test_recall_weighted                                              0.861789
# split1_test_recall_weighted                                              0.788618
# split2_test_recall_weighted                                              0.910569
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.803279
# mean_test_recall_weighted                                                0.838425
# std_test_recall_weighted                                                 0.043768
# rank_test_recall_weighted                                                      77
#
#                                                                               323  \
# mean_fit_time                                                            0.026775
# std_fit_time                                                             0.012789
# mean_score_time                                                          0.016921
# std_score_time                                                           0.003545
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.368421
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.222222
# mean_test_recall                                                         0.423392
# std_test_recall                                                          0.119996
# rank_test_recall                                                              163
# split0_test_precision                                                    0.533333
# split1_test_precision                                                         0.5
# split2_test_precision                                                         1.0
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.666667
# mean_test_precision                                                          0.64
# std_test_precision                                                       0.190205
# rank_test_precision                                                            26
# split0_test_f1                                                           0.484848
# split1_test_f1                                                           0.512821
# split2_test_f1                                                           0.538462
# split3_test_f1                                                           0.526316
# split4_test_f1                                                           0.333333
# mean_test_f1                                                             0.479156
# std_test_f1                                                              0.075062
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                       0.65291
# split1_test_roc_auc                                                      0.766194
# split2_test_roc_auc                                                      0.885628
# split3_test_roc_auc                                                      0.732906
# split4_test_roc_auc                                                       0.73985
# mean_test_roc_auc                                                        0.755498
# std_test_roc_auc                                                          0.07527
# rank_test_roc_auc                                                              20
# split0_test_recall_weighted                                              0.861789
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.902439
# split3_test_recall_weighted                                              0.852459
# split4_test_recall_weighted                                              0.868852
# mean_test_recall_weighted                                                0.866214
# std_test_recall_weighted                                                 0.019778
# rank_test_recall_weighted                                                      22
#
#                                                                               287  \
# ...
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              297
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# split3_test_precision                                                         0.0
# split4_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           297
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# split3_test_f1                                                                0.0
# split4_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  297
# split0_test_roc_auc                                                      0.621693
# split1_test_roc_auc                                                      0.619939
# split2_test_roc_auc                                                      0.803644
# split3_test_roc_auc                                                      0.731838
# split4_test_roc_auc                                                      0.639423
# mean_test_roc_auc                                                        0.683307
# std_test_roc_auc                                                         0.072902
# rank_test_roc_auc                                                             110
# split0_test_recall_weighted                                              0.853659
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.845528
# split3_test_recall_weighted                                              0.852459
# split4_test_recall_weighted                                              0.852459
# mean_test_recall_weighted                                                0.849927
# std_test_recall_weighted                                                 0.003618
# rank_test_recall_weighted                                                      37
#
#                                                                               36   \
# mean_fit_time                                                            0.034982
# std_fit_time                                                             0.007938
# mean_score_time                                                          0.031618
# std_score_time                                                            0.00316
# param_clf__C                                                                  0.1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 0.1, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# split3_test_recall                                                            0.0
# split4_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              297
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# split3_test_precision                                                         0.0
# split4_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           297
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# split3_test_f1                                                                0.0
# split4_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  297
# split0_test_roc_auc                                                           0.7
# split1_test_roc_auc                                                      0.575911
# split2_test_roc_auc                                                      0.805668
# split3_test_roc_auc                                                      0.709402
# split4_test_roc_auc                                                      0.626603
# mean_test_roc_auc                                                        0.683517
# std_test_roc_auc                                                         0.078334
# rank_test_roc_auc                                                             109
# split0_test_recall_weighted                                              0.853659
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.845528
# split3_test_recall_weighted                                              0.852459
# split4_test_recall_weighted                                              0.852459
# mean_test_recall_weighted                                                0.849927
# std_test_recall_weighted                                                 0.003618
# rank_test_recall_weighted                                                      37
#
#                                                                               52   \
# mean_fit_time                                                            0.041098
# std_fit_time                                                             0.003534
# mean_score_time                                                          0.035432
# std_score_time                                                           0.001565
# param_clf__C                                                                  0.1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 0.1, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# split3_test_recall                                                            0.0
# split4_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              297
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# split3_test_precision                                                         0.0
# split4_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           297
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# split3_test_f1                                                                0.0
# split4_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  297
# split0_test_roc_auc                                                      0.715344
# split1_test_roc_auc                                                      0.630061
# split2_test_roc_auc                                                      0.625506
# split3_test_roc_auc                                                      0.729701
# split4_test_roc_auc                                                      0.588675
# mean_test_roc_auc                                                        0.657857
# std_test_roc_auc                                                         0.054903
# rank_test_roc_auc                                                             166
# split0_test_recall_weighted                                              0.853659
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.845528
# split3_test_recall_weighted                                              0.852459
# split4_test_recall_weighted                                              0.852459
# mean_test_recall_weighted                                                0.849927
# std_test_recall_weighted                                                 0.003618
# rank_test_recall_weighted                                                      37
#
#                                                                               93
# mean_fit_time                                                            0.067609
# std_fit_time                                                             0.008776
# mean_score_time                                                          0.052728
# std_score_time                                                           0.005583
# param_clf__C                                                                  0.5
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 0.5, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# split3_test_recall                                                            0.0
# split4_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              297
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# split3_test_precision                                                         0.0
# split4_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           297
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# split3_test_f1                                                                0.0
# split4_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  297
# split0_test_roc_auc                                                      0.635979
# split1_test_roc_auc                                                       0.76417
# split2_test_roc_auc                                                      0.818826
# split3_test_roc_auc                                                      0.726496
# split4_test_roc_auc                                                      0.649573
# mean_test_roc_auc                                                        0.719009
# std_test_roc_auc                                                         0.068956
# rank_test_roc_auc                                                              61
# split0_test_recall_weighted                                              0.853659
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.845528
# split3_test_recall_weighted                                              0.852459
# split4_test_recall_weighted                                              0.852459
# mean_test_recall_weighted                                                0.849927
# std_test_recall_weighted                                                 0.003618
# rank_test_recall_weighted                                                      37
#
# [50 rows x 324 columns]

# %%
# Evaluation on test data
svm_clf = gscv_svm.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# svm_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation on test data
from sklearn.metrics import classification_report
y_pred = svm_clf.predict(X_eval)
SVM_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
SVM_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.91      0.90      0.91       224
#          poz       0.48      0.50      0.49        40
#
#     accuracy                           0.84       264
#    macro avg       0.69      0.70      0.70       264
# weighted avg       0.84      0.84      0.84       264

# %% [markdown]
# ## Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE(random_state=rand_num)), 
    ('under', RandomUnderSampler(random_state=rand_num)), 
    ('clf', DecisionTreeClassifier(random_state=rand_num))
])

parameters = {
            # 'clf__max_depth': [2,3,4],
            # 'clf__min_samples_split': [5, 10, 15, 20],
            'clf__min_samples_leaf': [75], #35, 40, 45, 30, 50,  75,, 150, 200
            'clf__criterion': ['gini', 'entropy', 'log_loss'],
            # 'clf__max_leaf_nodes': [5, 7, 10],
            # 'clf__ccp_alpha': [0.2, 0.3, 0.4],
               'clf__class_weight': ['balanced', None],
               'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
               'under__sampling_strategy': [0.5, 0.6, 0.7],
               'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv_dt = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True, random_state=rand_num),
                    return_train_score=False, 
                    verbose=1, 
                    refit="f1",
                    n_jobs=-1)
resultsGSCV = gscv_dt.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_dt, classifier_name, notebook_name)

# Save best parameters 
DT_best_params = gscv_dt.best_params_
df = pd.DataFrame([DT_best_params])
df.to_csv(f"{dir_path}/DT_best_params-{notebook_name}-{timestamp}.csv", index=False)
# Save with pickle
with open(f"{dir_path}/DT_best_params-{notebook_name}-{timestamp}.pkl", 'wb') as f:
    pickle.dump(DT_best_params, f)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# Best estimator saved as: models/02062023_1415/DecisionTreeClassifier-HAB_modelling_6_8-retrained-DT-02062023_1415.pkl
#                                                                               113  \
# mean_fit_time                                                            0.024664
# std_fit_time                                                             0.001586
# mean_score_time                                                          0.018547
# std_score_time                                                            0.00298
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.277778
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.526316
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.476608
# std_test_recall                                                          0.109311
# rank_test_recall                                                              114
# split0_test_precision                                                    0.238095
# split1_test_precision                                                    0.392857
# split2_test_precision                                                    0.357143
# split3_test_precision                                                    0.434783
# split4_test_precision                                                    0.421053
# mean_test_precision                                                      0.368786
# std_test_precision                                                       0.070544
# rank_test_precision                                                            13
# split0_test_f1                                                            0.25641
# split1_test_f1                                                           0.468085
# split2_test_f1                                                           0.425532
# split3_test_f1                                                           0.487805
# split4_test_f1                                                           0.432432
# mean_test_f1                                                             0.414053
# std_test_f1                                                              0.082073
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.596296
# split1_test_roc_auc                                                      0.695091
# split2_test_roc_auc                                                      0.684211
# split3_test_roc_auc                                                      0.706197
# split4_test_roc_auc                                                      0.692842
# mean_test_roc_auc                                                        0.674927
# std_test_roc_auc                                                         0.039936
# rank_test_roc_auc                                                              63
# split0_test_recall_weighted                                              0.764228
# split1_test_recall_weighted                                              0.796748
# split2_test_recall_weighted                                              0.780488
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.827869
# mean_test_recall_weighted                                                 0.79944
# std_test_recall_weighted                                                 0.025388
# rank_test_recall_weighted                                                      14
#
#                                                                               112  \
# mean_fit_time                                                            0.022161
# std_fit_time                                                             0.002037
# mean_score_time                                                          0.013819
# std_score_time                                                            0.00068
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.277778
# split1_test_recall                                                       0.684211
# split2_test_recall                                                       0.526316
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.497661
# std_test_recall                                                          0.134279
# rank_test_recall                                                              106
# split0_test_precision                                                    0.227273
# split1_test_precision                                                    0.270833
# split2_test_precision                                                    0.357143
# split3_test_precision                                                    0.434783
# split4_test_precision                                                    0.615385
# mean_test_precision                                                      0.381083
# std_test_precision                                                       0.137235
# rank_test_precision                                                             9
# split0_test_f1                                                               0.25
# split1_test_f1                                                            0.38806
# split2_test_f1                                                           0.425532
# split3_test_f1                                                           0.487805
# split4_test_f1                                                           0.516129
# mean_test_f1                                                             0.413505
# std_test_f1                                                              0.093358
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.585979
# split1_test_roc_auc                                                      0.702682
# split2_test_roc_auc                                                      0.736589
# split3_test_roc_auc                                                      0.701923
# split4_test_roc_auc                                                      0.715278
# mean_test_roc_auc                                                         0.68849
# std_test_roc_auc                                                         0.052766
# rank_test_roc_auc                                                              28
# split0_test_recall_weighted                                              0.756098
# split1_test_recall_weighted                                              0.666667
# split2_test_recall_weighted                                              0.780488
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.877049
# mean_test_recall_weighted                                                0.781634
# std_test_recall_weighted                                                  0.07087
# rank_test_recall_weighted                                                      34
#
#                                                                               102  \
# mean_fit_time                                                            0.026031
# std_fit_time                                                             0.002262
# mean_score_time                                                          0.017652
# std_score_time                                                           0.002645
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.277778
# split1_test_recall                                                       0.473684
# split2_test_recall                                                       0.368421
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.423977
# std_test_recall                                                          0.094513
# rank_test_recall                                                              132
# split0_test_precision                                                      0.3125
# split1_test_precision                                                         0.5
# split2_test_precision                                                        0.35
# split3_test_precision                                                    0.434783
# split4_test_precision                                                    0.421053
# mean_test_precision                                                      0.403667
# std_test_precision                                                       0.065942
# rank_test_precision                                                             4
# split0_test_f1                                                           0.294118
# split1_test_f1                                                           0.486486
# split2_test_f1                                                           0.358974
# split3_test_f1                                                           0.487805
# split4_test_f1                                                           0.432432
# mean_test_f1                                                             0.411963
# std_test_f1                                                              0.075392
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.613757
# split1_test_roc_auc                                                      0.723937
# split2_test_roc_auc                                                      0.625506
# split3_test_roc_auc                                                      0.685897
# split4_test_roc_auc                                                      0.692842
# mean_test_roc_auc                                                        0.668388
# std_test_roc_auc                                                         0.041985
# rank_test_roc_auc                                                              87
# split0_test_recall_weighted                                              0.804878
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.796748
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.827869
# mean_test_recall_weighted                                                0.820578
# std_test_recall_weighted                                                 0.017568
# rank_test_recall_weighted                                                       3
#
#                                                                               139  \
# mean_fit_time                                                              0.0277
# std_fit_time                                                             0.003352
# mean_score_time                                                          0.018272
# std_score_time                                                           0.003123
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.277778
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.526316
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.454386
# std_test_recall                                                          0.102056
# rank_test_recall                                                              127
# split0_test_precision                                                    0.277778
# split1_test_precision                                                    0.392857
# split2_test_precision                                                    0.357143
# split3_test_precision                                                    0.444444
# split4_test_precision                                                    0.421053
# mean_test_precision                                                      0.378655
# std_test_precision                                                       0.058252
# rank_test_precision                                                            11
# split0_test_f1                                                           0.277778
# split1_test_f1                                                           0.468085
# split2_test_f1                                                           0.425532
# split3_test_f1                                                           0.444444
# split4_test_f1                                                           0.432432
# mean_test_f1                                                             0.409654
# std_test_f1                                                              0.067508
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.610053
# split1_test_roc_auc                                                      0.732794
# split2_test_roc_auc                                                        0.6875
# split3_test_roc_auc                                                      0.630609
# split4_test_roc_auc                                                      0.692842
# mean_test_roc_auc                                                        0.670759
# std_test_roc_auc                                                         0.044527
# rank_test_roc_auc                                                              78
# split0_test_recall_weighted                                              0.788618
# split1_test_recall_weighted                                              0.796748
# split2_test_recall_weighted                                              0.780488
# split3_test_recall_weighted                                              0.836066
# split4_test_recall_weighted                                              0.827869
# mean_test_recall_weighted                                                0.805958
# std_test_recall_weighted                                                 0.022004
# rank_test_recall_weighted                                                       7
#
#                                                                               141  \
# mean_fit_time                                                            0.028904
# std_fit_time                                                             0.003193
# mean_score_time                                                          0.015305
# std_score_time                                                           0.001578
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.277778
# split1_test_recall                                                       0.421053
# split2_test_recall                                                       0.473684
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.388889
# mean_test_recall                                                         0.423392
# std_test_recall                                                          0.092083
# rank_test_recall                                                              134
# split0_test_precision                                                    0.227273
# split1_test_precision                                                        0.32
# split2_test_precision                                                       0.375
# split3_test_precision                                                    0.434783
# split4_test_precision                                                    0.777778
# mean_test_precision                                                      0.426967
# std_test_precision                                                       0.188228
# rank_test_precision                                                             1
# split0_test_f1                                                               0.25
# split1_test_f1                                                           0.363636
# split2_test_f1                                                           0.418605
# split3_test_f1                                                           0.487805
# split4_test_f1                                                           0.518519
# mean_test_f1                                                             0.407713
# std_test_f1                                                              0.095527
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.592328
# split1_test_roc_auc                                                      0.625506
# split2_test_roc_auc                                                      0.682945
# split3_test_roc_auc                                                      0.732906
# split4_test_roc_auc                                                       0.70219
# mean_test_roc_auc                                                        0.667175
# std_test_roc_auc                                                         0.051252
# rank_test_roc_auc                                                              88
# split0_test_recall_weighted                                              0.756098
# split1_test_recall_weighted                                              0.772358
# split2_test_recall_weighted                                              0.796748
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.893443
# mean_test_recall_weighted                                                0.809303
# std_test_recall_weighted                                                 0.048534
# rank_test_recall_weighted                                                       4
#
#                                                                               45   \
# mean_fit_time                                                            0.025468
# std_fit_time                                                             0.004558
# mean_score_time                                                          0.014162
# std_score_time                                                           0.001444
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.631579
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.555556
# mean_test_recall                                                         0.553216
# std_test_recall                                                          0.061066
# rank_test_recall                                                               76
# split0_test_precision                                                    0.228571
# split1_test_precision                                                    0.478261
# split2_test_precision                                                     0.27907
# split3_test_precision                                                    0.277778
# split4_test_precision                                                     0.37037
# mean_test_precision                                                       0.32681
# std_test_precision                                                       0.088509
# rank_test_precision                                                            43
# split0_test_f1                                                           0.301887
# split1_test_f1                                                            0.52381
# split2_test_f1                                                           0.387097
# split3_test_f1                                                            0.37037
# split4_test_f1                                                           0.444444
# mean_test_f1                                                             0.405522
# std_test_f1                                                              0.074595
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.622222
# split1_test_roc_auc                                                       0.73583
# split2_test_roc_auc                                                      0.728745
# split3_test_roc_auc                                                      0.652778
# split4_test_roc_auc                                                      0.701389
# mean_test_roc_auc                                                        0.688193
# std_test_roc_auc                                                         0.044032
# rank_test_roc_auc                                                              29
# split0_test_recall_weighted                                              0.699187
# split1_test_recall_weighted                                              0.837398
# split2_test_recall_weighted                                              0.691057
# split3_test_recall_weighted                                              0.721311
# split4_test_recall_weighted                                              0.795082
# mean_test_recall_weighted                                                0.748807
# std_test_recall_weighted                                                  0.05752
# rank_test_recall_weighted                                                      58
#
#                                                                               87   \
# mean_fit_time                                                            0.023864
# std_fit_time                                                             0.003483
# mean_score_time                                                          0.016564
# std_score_time                                                            0.00497
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.277778
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.421053
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.433333
# std_test_recall                                                          0.095707
# rank_test_recall                                                              130
# split0_test_precision                                                    0.227273
# split1_test_precision                                                    0.392857
# split2_test_precision                                                    0.347826
# split3_test_precision                                                    0.533333
# split4_test_precision                                                    0.421053
# mean_test_precision                                                      0.384468
# std_test_precision                                                       0.099622
# rank_test_precision                                                             6
# split0_test_f1                                                               0.25
# split1_test_f1                                                           0.468085
# split2_test_f1                                                           0.380952
# split3_test_f1                                                           0.484848
# split4_test_f1                                                           0.432432
# mean_test_f1                                                             0.403264
# std_test_f1                                                              0.084494
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.556878
# split1_test_roc_auc                                                      0.665992
# split2_test_roc_auc                                                      0.742662
# split3_test_roc_auc                                                      0.657585
# split4_test_roc_auc                                                      0.655983
# mean_test_roc_auc                                                         0.65582
# std_test_roc_auc                                                         0.059055
# rank_test_roc_auc                                                             117
# split0_test_recall_weighted                                              0.756098
# split1_test_recall_weighted                                              0.796748
# split2_test_recall_weighted                                              0.788618
# split3_test_recall_weighted                                              0.860656
# split4_test_recall_weighted                                              0.827869
# mean_test_recall_weighted                                                0.805998
# std_test_recall_weighted                                                 0.035619
# rank_test_recall_weighted                                                       6
#
#                                                                               122  \
# mean_fit_time                                                            0.024385
# std_fit_time                                                              0.00156
# mean_score_time                                                          0.013778
# std_score_time                                                           0.000703
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.473684
# split2_test_recall                                                       0.526316
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.544444
# std_test_recall                                                          0.066892
# rank_test_recall                                                               80
# split0_test_precision                                                    0.257143
# split1_test_precision                                                        0.45
# split2_test_precision                                                    0.357143
# split3_test_precision                                                    0.277778
# split4_test_precision                                                         0.3
# mean_test_precision                                                      0.328413
# std_test_precision                                                       0.069368
# rank_test_precision                                                            42
# split0_test_f1                                                           0.339623
# split1_test_f1                                                           0.461538
# split2_test_f1                                                           0.425532
# split3_test_f1                                                            0.37037
# split4_test_f1                                                           0.413793
# mean_test_f1                                                             0.402171
# std_test_f1                                                              0.042729
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.659259
# split1_test_roc_auc                                                      0.737348
# split2_test_roc_auc                                                      0.741144
# split3_test_roc_auc                                                      0.702991
# split4_test_roc_auc                                                       0.69391
# mean_test_roc_auc                                                        0.706931
# std_test_roc_auc                                                         0.030177
# rank_test_roc_auc                                                               4
# split0_test_recall_weighted                                              0.715447
# split1_test_recall_weighted                                              0.829268
# split2_test_recall_weighted                                              0.780488
# split3_test_recall_weighted                                              0.721311
# split4_test_recall_weighted                                              0.721311
# mean_test_recall_weighted                                                0.753565
# std_test_recall_weighted                                                 0.044698
# rank_test_recall_weighted                                                      53
#
#                                                                               5    \
# mean_fit_time                                                            0.028152
# std_fit_time                                                             0.005326
# mean_score_time                                                          0.022372
# std_score_time                                                           0.005581
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.277778
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.526316
# split3_test_recall                                                       0.555556
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.466082
# std_test_recall                                                          0.101181
# rank_test_recall                                                              121
# split0_test_precision                                                    0.227273
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.357143
# split3_test_precision                                                    0.434783
# split4_test_precision                                                    0.421053
# mean_test_precision                                                      0.354717
# std_test_precision                                                       0.074184
# rank_test_precision                                                            24
# split0_test_f1                                                               0.25
# split1_test_f1                                                           0.408163
# split2_test_f1                                                           0.425532
# split3_test_f1                                                           0.487805
# split4_test_f1                                                           0.432432
# mean_test_f1                                                             0.400786
# std_test_f1                                                              0.079971
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.585979
# split1_test_roc_auc                                                      0.707996
# split2_test_roc_auc                                                       0.71837
# split3_test_roc_auc                                                       0.70406
# split4_test_roc_auc                                                      0.692842
# mean_test_roc_auc                                                        0.681849
# std_test_roc_auc                                                         0.048627
# rank_test_roc_auc                                                              46
# split0_test_recall_weighted                                              0.756098
# split1_test_recall_weighted                                              0.764228
# split2_test_recall_weighted                                              0.780488
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.827869
# mean_test_recall_weighted                                                 0.79131
# std_test_recall_weighted                                                 0.030866
# rank_test_recall_weighted                                                      23
#
#                                                                               57   \
# mean_fit_time                                                            0.024806
# std_fit_time                                                             0.002621
# mean_score_time                                                           0.01585
# std_score_time                                                           0.001789
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.842105
# split2_test_recall                                                       0.736842
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.593567
# std_test_recall                                                          0.164638
# rank_test_recall                                                               48
# split0_test_precision                                                    0.205128
# split1_test_precision                                                    0.372093
# split2_test_precision                                                        0.28
# split3_test_precision                                                    0.290323
# split4_test_precision                                                    0.421053
# mean_test_precision                                                      0.313719
# std_test_precision                                                       0.075372
# rank_test_precision                                                            53
# split0_test_f1                                                           0.280702
# split1_test_f1                                                           0.516129
# split2_test_f1                                                           0.405797
# split3_test_f1                                                           0.367347
# split4_test_f1                                                           0.432432
# mean_test_f1                                                             0.400481
# std_test_f1                                                               0.07729
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.642593
# split1_test_roc_auc                                                      0.792004
# split2_test_roc_auc                                                      0.767966
# split3_test_roc_auc                                                      0.611378
# split4_test_roc_auc                                                      0.692842
# mean_test_roc_auc                                                        0.701356
# std_test_roc_auc                                                         0.069679
# rank_test_roc_auc                                                               7
# split0_test_recall_weighted                                              0.666667
# split1_test_recall_weighted                                              0.756098
# split2_test_recall_weighted                                              0.666667
# split3_test_recall_weighted                                              0.745902
# split4_test_recall_weighted                                              0.827869
# mean_test_recall_weighted                                                 0.73264
# std_test_recall_weighted                                                 0.060827
# rank_test_recall_weighted                                                      67
#
#                                                                               9    \
# mean_fit_time                                                             0.02324
# std_fit_time                                                             0.002788
# mean_score_time                                                          0.017674
# std_score_time                                                           0.004261
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.722222
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.631579
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.611111
# mean_test_recall                                                         0.598246
# std_test_recall                                                          0.079338
# rank_test_recall                                                               35
# split0_test_precision                                                    0.188406
# split1_test_precision                                                    0.333333
# split2_test_precision                                                     0.27907
# split3_test_precision                                                    0.290323
# split4_test_precision                                                    0.478261
# mean_test_precision                                                      0.313878
# std_test_precision                                                       0.094773
# rank_test_precision                                                            52
# split0_test_f1                                                           0.298851
# split1_test_f1                                                           0.408163
# split2_test_f1                                                           0.387097
# split3_test_f1                                                           0.367347
# split4_test_f1                                                           0.536585
# mean_test_f1                                                             0.399609
# std_test_f1                                                              0.077699
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.637302
# split1_test_roc_auc                                                      0.686741
# split2_test_roc_auc                                                       0.67333
# split3_test_roc_auc                                                      0.711004
# split4_test_roc_auc                                                      0.735577
# mean_test_roc_auc                                                        0.688791
# ...
# split0_test_precision                                                    0.228571
# split1_test_precision                                                         0.0
# split2_test_precision                                                     0.27907
# split3_test_precision                                                    0.277778
# split4_test_precision                                                    0.194444
# mean_test_precision                                                      0.195973
# std_test_precision                                                       0.103022
# rank_test_precision                                                           159
# split0_test_f1                                                           0.301887
# split1_test_f1                                                                0.0
# split2_test_f1                                                           0.387097
# split3_test_f1                                                            0.37037
# split4_test_f1                                                           0.311111
# mean_test_f1                                                             0.274093
# std_test_f1                                                              0.140932
# rank_test_f1                                                                  159
# split0_test_roc_auc                                                      0.593651
# split1_test_roc_auc                                                      0.625506
# split2_test_roc_auc                                                      0.666751
# split3_test_roc_auc                                                      0.652778
# split4_test_roc_auc                                                      0.610043
# mean_test_roc_auc                                                        0.629746
# std_test_roc_auc                                                         0.026866
# rank_test_roc_auc                                                             156
# split0_test_recall_weighted                                              0.699187
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.691057
# split3_test_recall_weighted                                              0.721311
# split4_test_recall_weighted                                              0.491803
# mean_test_recall_weighted                                                0.689777
# std_test_recall_weighted                                                  0.11361
# rank_test_recall_weighted                                                     111
#
#                                                                               154  \
# mean_fit_time                                                            0.029463
# std_fit_time                                                             0.004502
# mean_score_time                                                          0.023891
# std_score_time                                                           0.004598
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.789474
# split2_test_recall                                                       0.631579
# split3_test_recall                                                            0.5
# split4_test_recall                                                            0.0
# mean_test_recall                                                         0.484211
# std_test_recall                                                          0.264523
# rank_test_recall                                                              111
# split0_test_precision                                                    0.257143
# split1_test_precision                                                    0.211268
# split2_test_precision                                                     0.27907
# split3_test_precision                                                    0.214286
# split4_test_precision                                                         0.0
# mean_test_precision                                                      0.192353
# std_test_precision                                                       0.099555
# rank_test_precision                                                           160
# split0_test_f1                                                           0.339623
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.387097
# split3_test_f1                                                                0.3
# split4_test_f1                                                                0.0
# mean_test_f1                                                             0.272011
# std_test_f1                                                              0.138816
# rank_test_f1                                                                  160
# split0_test_roc_auc                                                       0.62619
# split1_test_roc_auc                                                      0.625506
# split2_test_roc_auc                                                      0.666751
# split3_test_roc_auc                                                      0.591346
# split4_test_roc_auc                                                      0.610043
# mean_test_roc_auc                                                        0.623967
# std_test_roc_auc                                                         0.024883
# rank_test_roc_auc                                                             159
# split0_test_recall_weighted                                              0.715447
# split1_test_recall_weighted                                              0.512195
# split2_test_recall_weighted                                              0.691057
# split3_test_recall_weighted                                              0.655738
# split4_test_recall_weighted                                              0.852459
# mean_test_recall_weighted                                                0.685379
# std_test_recall_weighted                                                 0.109292
# rank_test_recall_weighted                                                     117
#
#                                                                               81   \
# mean_fit_time                                                            0.026592
# std_fit_time                                                             0.002282
# mean_score_time                                                          0.018193
# std_score_time                                                           0.001338
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.684211
# split2_test_recall                                                            0.0
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.444444
# mean_test_recall                                                          0.41462
# std_test_recall                                                          0.225237
# rank_test_recall                                                              142
# split0_test_precision                                                    0.228571
# split1_test_precision                                                    0.270833
# split2_test_precision                                                         0.0
# split3_test_precision                                                    0.214286
# split4_test_precision                                                    0.222222
# mean_test_precision                                                      0.187183
# std_test_precision                                                       0.095614
# rank_test_precision                                                           161
# split0_test_f1                                                           0.301887
# split1_test_f1                                                            0.38806
# split2_test_f1                                                                0.0
# split3_test_f1                                                                0.3
# split4_test_f1                                                           0.296296
# mean_test_f1                                                             0.257249
# std_test_f1                                                              0.133142
# rank_test_f1                                                                  161
# split0_test_roc_auc                                                      0.616931
# split1_test_roc_auc                                                      0.728492
# split2_test_roc_auc                                                      0.642206
# split3_test_roc_auc                                                      0.583066
# split4_test_roc_auc                                                      0.629274
# mean_test_roc_auc                                                        0.639994
# std_test_roc_auc                                                         0.048424
# rank_test_roc_auc                                                             146
# split0_test_recall_weighted                                              0.699187
# split1_test_recall_weighted                                              0.666667
# split2_test_recall_weighted                                              0.845528
# split3_test_recall_weighted                                              0.655738
# split4_test_recall_weighted                                              0.688525
# mean_test_recall_weighted                                                0.711129
# std_test_recall_weighted                                                 0.068937
# rank_test_recall_weighted                                                      88
#
#                                                                               108
# mean_fit_time                                                            0.023748
# std_fit_time                                                             0.001193
# mean_score_time                                                          0.015387
# std_score_time                                                           0.000519
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                            0.0
# split2_test_recall                                                       0.736842
# split3_test_recall                                                            0.0
# split4_test_recall                                                       0.555556
# mean_test_recall                                                         0.347368
# std_test_recall                                                          0.298592
# rank_test_recall                                                              161
# split0_test_precision                                                    0.228571
# split1_test_precision                                                         0.0
# split2_test_precision                                                        0.35
# split3_test_precision                                                         0.0
# split4_test_precision                                                    0.357143
# mean_test_precision                                                      0.187143
# std_test_precision                                                       0.159489
# rank_test_precision                                                           162
# split0_test_f1                                                           0.301887
# split1_test_f1                                                                0.0
# split2_test_f1                                                           0.474576
# split3_test_f1                                                                0.0
# split4_test_f1                                                           0.434783
# mean_test_f1                                                             0.242249
# std_test_f1                                                              0.205899
# rank_test_f1                                                                  162
# split0_test_roc_auc                                                      0.616931
# split1_test_roc_auc                                                      0.628036
# split2_test_roc_auc                                                      0.740638
# split3_test_roc_auc                                                       0.67735
# split4_test_roc_auc                                                      0.709936
# mean_test_roc_auc                                                        0.674578
# std_test_roc_auc                                                          0.04714
# rank_test_roc_auc                                                              66
# split0_test_recall_weighted                                              0.699187
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.747967
# split3_test_recall_weighted                                              0.852459
# split4_test_recall_weighted                                              0.786885
# mean_test_recall_weighted                                                0.786405
# std_test_recall_weighted                                                 0.058212
# rank_test_recall_weighted                                                      26
#
# [51 rows x 162 columns]

# %%
# Evaluation on test data
dt_clf = gscv_dt.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/12042023_1718/DecisionTreeClassifier-HAB_modelling_5_8-12042023_1718.pkl"
# dt_clf = load_best_estimator(pickle_file_name).steps[2][1]

y_pred = dt_clf.predict(X_eval)
DT_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
DT_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.90      0.89      0.89       224
#          poz       0.40      0.42      0.41        40
#
#     accuracy                           0.82       264
#    macro avg       0.65      0.66      0.65       264
# weighted avg       0.82      0.82      0.82       264

# %%
viz_model = dtreeviz.model(dt_clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"]
             #   scale=1.5
              )

# Save the visualization as a PNG file
viz_file_name = f"{dir_path}/DT_visualisation.svg"
# viz_model.save(viz_file_name)
v = viz_model.view(fancy=False)    
v.save(viz_file_name) 
print(f"Visualization saved as: {viz_file_name}")

# Display the visualization
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 viz = dtreeviz.model(dt_clf, X, y,
#       2                 target_name="target",
#       3                 feature_names=X.columns,
#       4                 class_names=["neg", "poz"],
#       5              # fancy=False,
#       6              #   scale=1.5
#       7               )
#       9 # Save the visualization as a PNG file
#      10 viz_file_name = f"{dir_path}/DT_visualisation.svg"
#
# NameError: name 'dt_clf' is not defined

# %%
from sklearn import tree
fig = plt.figure(figsize=(15,10))
_ = tree.plot_tree(dt_clf, 
                   feature_names=X.columns,  
                   class_names=["neg", "poz"],
                   filled=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 3>()
#       1 from sklearn import tree
#       2 fig = plt.figure(figsize=(15,10))
# ----> 3 _ = tree.plot_tree(dt_clf, X, y,
#       4                    feature_names=X.columns,
#       5                    class_names=["neg", "poz"],
#       6                    filled=True)
#
# TypeError: plot_tree() takes 1 positional argument but 3 positional arguments (and 3 keyword-only arguments) were given
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(dt_clf, out_file=None, 
                                feature_names=X.columns,  
                                class_names=["neg", "poz"],
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data, format="png") 
graph

# %% [markdown]
# #### Retrain DT with best parameters from gridsearch on a all data

# %%
# Retrain DT with best parameters from gridsearch on a all data
best_params = gscv_dt.best_params_

# # Load the data with pickle
# with open('DT_best_params.pkl', 'rb') as f:
#     DT_best_params = pickle.load(f)

print(best_params)

# Create a pipeline with the best parameters
best_pipeline = IMBLpipeline([
    ('smt', SMOTE(sampling_strategy=best_params['smt__sampling_strategy'], k_neighbors=best_params['smt__k_neighbors'], random_state=rand_num)), 
    ('under', RandomUnderSampler(sampling_strategy=best_params['under__sampling_strategy'], random_state=rand_num)), 
    ('clf', DecisionTreeClassifier(max_depth=best_params['clf__min_samples_leaf'], criterion=best_params['clf__criterion'], class_weight=best_params['clf__class_weight'], random_state=rand_num))
])

# Train the model on the entire dataset
best_pipeline.fit(X_all, y_all)

# Extract the decision tree classifier from the pipeline
best_dt_clf = best_pipeline.named_steps['clf']

# Save the best decision tree classifier with pickle
with open(f"{dir_path}/best_DT_clf_all_data.pkl-{notebook_name}-{timestamp}.pkl", 'wb') as f:
    pickle.dump(best_dt_clf, f)

#Visualise DT
from dtreeviz.trees import dtreeviz

viz = dtreeviz(best_dt_clf, X_all, y_all,
                target_name="target",
                feature_names=X_all.columns,
                class_names=["neg", "poz"],
                fancy=False,
                scale=1.5)

# Save the visualization as a PNG file
viz_file_name = f"{dir_path}/best_DT_visualisation_all-data.svg"
viz.save(viz_file_name)
print(f"Visualization saved as: {viz_file_name}")

# Display the visualization
viz
# Out:
# {'clf__class_weight': None, 'clf__criterion': 'log_loss', 'clf__min_samples_leaf': 75, 'smt__k_neighbors': 5, 'smt__sampling_strategy': 0.4, 'under__sampling_strategy': 0.5}
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Visualization saved as: models/02062023_1334/best_DT_visualisation_all-data.svg

# %%
from sklearn import tree
tree.plot_tree(best_dt_clf, fontsize=12)
# Out:
# [Text(0.5753424657534246, 0.9642857142857143, 'X[3] <= 0.002\nlog_loss = 0.918\nsamples = 894\nvalue = [596, 298]'),
#  Text(0.3176369863013699, 0.8928571428571429, 'X[11] <= 36.88\nlog_loss = 0.632\nsamples = 515\nvalue = [433, 82]'),
#  Text(0.1421232876712329, 0.8214285714285714, 'X[12] <= 9.831\nlog_loss = 0.802\nsamples = 258\nvalue = [195, 63]'),
#  Text(0.1284246575342466, 0.75, 'log_loss = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.1558219178082192, 0.75, 'X[13] <= 2109.899\nlog_loss = 0.736\nsamples = 246\nvalue = [195, 51]'),
#  Text(0.1421232876712329, 0.6785714285714286, 'log_loss = 0.0\nsamples = 71\nvalue = [71, 0]'),
#  Text(0.1695205479452055, 0.6785714285714286, 'X[2] <= 3.014\nlog_loss = 0.871\nsamples = 175\nvalue = [124, 51]'),
#  Text(0.08561643835616438, 0.6071428571428571, 'X[9] <= 2.331\nlog_loss = 0.567\nsamples = 120\nvalue = [104, 16]'),
#  Text(0.0410958904109589, 0.5357142857142857, 'X[8] <= 17.112\nlog_loss = 1.0\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.0273972602739726, 0.4642857142857143, 'X[4] <= 5.0\nlog_loss = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.0136986301369863, 0.39285714285714285, 'log_loss = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0410958904109589, 0.39285714285714285, 'log_loss = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.0547945205479452, 0.4642857142857143, 'log_loss = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.13013698630136986, 0.5357142857142857, 'X[13] <= 5347.777\nlog_loss = 0.419\nsamples = 106\nvalue = [97, 9]'),
#  Text(0.11643835616438356, 0.4642857142857143, 'X[13] <= 3559.968\nlog_loss = 0.564\nsamples = 68\nvalue = [59, 9]'),
#  Text(0.0684931506849315, 0.39285714285714285, 'X[10] <= 76.6\nlog_loss = 0.151\nsamples = 46\nvalue = [45, 1]'),
#  Text(0.0547945205479452, 0.32142857142857145, 'log_loss = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.0821917808219178, 0.32142857142857145, 'X[8] <= 20.431\nlog_loss = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.0684931506849315, 0.25, 'log_loss = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.0958904109589041, 0.25, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1643835616438356, 0.39285714285714285, 'X[1] <= 45.0\nlog_loss = 0.946\nsamples = 22\nvalue = [14, 8]'),
#  Text(0.136986301369863, 0.32142857142857145, 'X[11] <= 36.865\nlog_loss = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.1232876712328767, 0.25, 'log_loss = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.1506849315068493, 0.25, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1917808219178082, 0.32142857142857145, 'X[13] <= 4032.66\nlog_loss = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.1780821917808219, 0.25, 'log_loss = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.2054794520547945, 0.25, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14383561643835616, 0.4642857142857143, 'log_loss = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(0.2534246575342466, 0.6071428571428571, 'X[8] <= 13.595\nlog_loss = 0.946\nsamples = 55\nvalue = [20, 35]'),
#  Text(0.23972602739726026, 0.5357142857142857, 'log_loss = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2671232876712329, 0.5357142857142857, 'X[2] <= 29.5\nlog_loss = 0.881\nsamples = 50\nvalue = [15, 35]'),
#  Text(0.2191780821917808, 0.4642857142857143, 'X[10] <= 20.132\nlog_loss = 0.999\nsamples = 23\nvalue = [11, 12]'),
#  Text(0.2054794520547945, 0.39285714285714285, 'log_loss = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.2328767123287671, 0.39285714285714285, 'X[10] <= 54.4\nlog_loss = 0.964\nsamples = 18\nvalue = [11, 7]'),
#  Text(0.2191780821917808, 0.32142857142857145, 'log_loss = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.2465753424657534, 0.32142857142857145, 'X[11] <= 34.065\nlog_loss = 0.946\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.2328767123287671, 0.25, 'log_loss = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2602739726027397, 0.25, 'X[6] <= 5.0\nlog_loss = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.2465753424657534, 0.17857142857142858, 'X[13] <= 5681.062\nlog_loss = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.2328767123287671, 0.10714285714285714, 'log_loss = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.2602739726027397, 0.10714285714285714, 'X[9] <= 2.7\nlog_loss = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2465753424657534, 0.03571428571428571, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.273972602739726, 0.03571428571428571, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.273972602739726, 0.17857142857142858, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3150684931506849, 0.4642857142857143, 'X[12] <= 22.296\nlog_loss = 0.605\nsamples = 27\nvalue = [4, 23]'),
#  Text(0.2876712328767123, 0.39285714285714285, 'X[13] <= 5552.701\nlog_loss = 0.297\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.273972602739726, 0.32142857142857145, 'log_loss = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.3013698630136986, 0.32142857142857145, 'X[7] <= 176.4\nlog_loss = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2876712328767123, 0.25, 'log_loss = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3150684931506849, 0.25, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3424657534246575, 0.39285714285714285, 'X[4] <= 9.05\nlog_loss = 0.954\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.3287671232876712, 0.32142857142857145, 'log_loss = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3561643835616438, 0.32142857142857145, 'log_loss = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4931506849315068, 0.8214285714285714, 'X[9] <= 3.16\nlog_loss = 0.38\nsamples = 257\nvalue = [238, 19]'),
#  Text(0.4794520547945205, 0.75, 'X[9] <= 3.091\nlog_loss = 0.513\nsamples = 166\nvalue = [147, 19]'),
#  Text(0.4520547945205479, 0.6785714285714286, 'X[11] <= 37.605\nlog_loss = 0.391\nsamples = 143\nvalue = [132, 11]'),
#  Text(0.4383561643835616, 0.6071428571428571, 'X[12] <= 13.66\nlog_loss = 0.514\nsamples = 96\nvalue = [85, 11]'),
#  Text(0.3972602739726027, 0.5357142857142857, 'X[9] <= 2.88\nlog_loss = 0.971\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.3835616438356164, 0.4642857142857143, 'X[13] <= 2753.19\nlog_loss = 0.918\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.3698630136986301, 0.39285714285714285, 'log_loss = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3972602739726027, 0.39285714285714285, 'X[10] <= 12.6\nlog_loss = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3835616438356164, 0.32142857142857145, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.410958904109589, 0.32142857142857145, 'log_loss = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.410958904109589, 0.4642857142857143, 'log_loss = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4794520547945205, 0.5357142857142857, 'X[9] <= 2.512\nlog_loss = 0.334\nsamples = 81\nvalue = [76, 5]'),
#  Text(0.4383561643835616, 0.4642857142857143, 'X[9] <= 2.464\nlog_loss = 0.811\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.4246575342465753, 0.39285714285714285, 'log_loss = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.4520547945205479, 0.39285714285714285, 'X[10] <= 80.85\nlog_loss = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.4383561643835616, 0.32142857142857145, 'log_loss = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4657534246575342, 0.32142857142857145, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5205479452054794, 0.4642857142857143, 'X[13] <= 1506.887\nlog_loss = 0.189\nsamples = 69\nvalue = [67, 2]'),
#  Text(0.5068493150684932, 0.39285714285714285, 'X[12] <= 23.64\nlog_loss = 0.469\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.4931506849315068, 0.32142857142857145, 'X[7] <= 220.65\nlog_loss = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.4794520547945205, 0.25, 'log_loss = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5068493150684932, 0.25, 'log_loss = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5205479452054794, 0.32142857142857145, 'log_loss = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.5342465753424658, 0.39285714285714285, 'log_loss = 0.0\nsamples = 49\nvalue = [49, 0]'),
#  Text(0.4657534246575342, 0.6071428571428571, 'log_loss = 0.0\nsamples = 47\nvalue = [47, 0]'),
#  Text(0.5068493150684932, 0.6785714285714286, 'X[9] <= 3.105\nlog_loss = 0.932\nsamples = 23\nvalue = [15, 8]'),
#  Text(0.4931506849315068, 0.6071428571428571, 'log_loss = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5205479452054794, 0.6071428571428571, 'X[8] <= 24.181\nlog_loss = 0.65\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.5068493150684932, 0.5357142857142857, 'log_loss = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.5342465753424658, 0.5357142857142857, 'log_loss = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5068493150684932, 0.75, 'log_loss = 0.0\nsamples = 91\nvalue = [91, 0]'),
#  Text(0.8330479452054794, 0.8928571428571429, 'X[11] <= 37.104\nlog_loss = 0.986\nsamples = 379\nvalue = [163, 216]'),
#  Text(0.7277397260273972, 0.8214285714285714, 'X[13] <= 4061.272\nlog_loss = 0.906\nsamples = 274\nvalue = [88, 186]'),
#  Text(0.6198630136986302, 0.75, 'X[3] <= 9.988\nlog_loss = 0.992\nsamples = 174\nvalue = [78, 96]'),
#  Text(0.6061643835616438, 0.6785714285714286, 'log_loss = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.6335616438356164, 0.6785714285714286, 'X[3] <= 11.31\nlog_loss = 0.995\nsamples = 144\nvalue = [78, 66]'),
#  Text(0.5753424657534246, 0.6071428571428571, 'X[12] <= 22.605\nlog_loss = 0.567\nsamples = 45\nvalue = [39, 6]'),
#  Text(0.5616438356164384, 0.5357142857142857, 'log_loss = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.589041095890411, 0.5357142857142857, 'X[8] <= 23.248\nlog_loss = 0.709\nsamples = 31\nvalue = [25, 6]'),
#  Text(0.5753424657534246, 0.4642857142857143, 'X[4] <= 48.0\nlog_loss = 0.9\nsamples = 19\nvalue = [13, 6]'),
#  Text(0.5616438356164384, 0.39285714285714285, 'X[10] <= 27.4\nlog_loss = 0.787\nsamples = 17\nvalue = [13, 4]'),
#  Text(0.547945205479452, 0.32142857142857145, 'log_loss = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5753424657534246, 0.32142857142857145, 'X[13] <= 2765.983\nlog_loss = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.5616438356164384, 0.25, 'X[12] <= 23.15\nlog_loss = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.547945205479452, 0.17857142857142858, 'X[1] <= 32.0\nlog_loss = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5342465753424658, 0.10714285714285714, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5616438356164384, 0.10714285714285714, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5753424657534246, 0.17857142857142858, 'log_loss = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.589041095890411, 0.25, 'log_loss = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.589041095890411, 0.39285714285714285, 'log_loss = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6027397260273972, 0.4642857142857143, 'log_loss = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.6917808219178082, 0.6071428571428571, 'X[8] <= 23.037\nlog_loss = 0.967\nsamples = 99\nvalue = [39, 60]'),
#  Text(0.6575342465753424, 0.5357142857142857, 'X[9] <= 2.807\nlog_loss = 0.902\nsamples = 85\nvalue = [27, 58]'),
#  Text(0.6301369863013698, 0.4642857142857143, 'X[3] <= 33.445\nlog_loss = 0.949\nsamples = 19\nvalue = [12, 7]'),
#  Text(0.6164383561643836, 0.39285714285714285, 'log_loss = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.6438356164383562, 0.39285714285714285, 'X[1] <= 355.0\nlog_loss = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.6301369863013698, 0.32142857142857145, 'log_loss = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6575342465753424, 0.32142857142857145, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.684931506849315, 0.4642857142857143, 'X[11] <= 35.194\nlog_loss = 0.773\nsamples = 66\nvalue = [15, 51]'),
#  Text(0.6712328767123288, 0.39285714285714285, 'log_loss = 0.0\nsamples = 23\nvalue = [0, 23]'),
#  Text(0.6986301369863014, 0.39285714285714285, 'X[8] <= 21.082\nlog_loss = 0.933\nsamples = 43\nvalue = [15, 28]'),
#  Text(0.684931506849315, 0.32142857142857145, 'X[13] <= 1738.865\nlog_loss = 0.764\nsamples = 36\nvalue = [8, 28]'),
#  Text(0.6712328767123288, 0.25, 'log_loss = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.6986301369863014, 0.25, 'X[10] <= 66.15\nlog_loss = 0.998\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.6712328767123288, 0.17857142857142858, 'X[3] <= 16.481\nlog_loss = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.6575342465753424, 0.10714285714285714, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.684931506849315, 0.10714285714285714, 'log_loss = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.726027397260274, 0.17857142857142858, 'X[1] <= 925.0\nlog_loss = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.7123287671232876, 0.10714285714285714, 'log_loss = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.7397260273972602, 0.10714285714285714, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7123287671232876, 0.32142857142857145, 'log_loss = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.726027397260274, 0.5357142857142857, 'X[4] <= 88.5\nlog_loss = 0.592\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.7123287671232876, 0.4642857142857143, 'log_loss = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.7397260273972602, 0.4642857142857143, 'log_loss = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8356164383561644, 0.75, 'X[13] <= 11570.663\nlog_loss = 0.469\nsamples = 100\nvalue = [10, 90]'),
#  Text(0.821917808219178, 0.6785714285714286, 'X[6] <= 0.091\nlog_loss = 0.337\nsamples = 96\nvalue = [6, 90]'),
#  Text(0.8082191780821918, 0.6071428571428571, 'X[4] <= 17.0\nlog_loss = 0.65\nsamples = 36\nvalue = [6, 30]'),
#  Text(0.7808219178082192, 0.5357142857142857, 'X[8] <= 13.112\nlog_loss = 0.362\nsamples = 29\nvalue = [2, 27]'),
#  Text(0.7671232876712328, 0.4642857142857143, 'X[11] <= 33.177\nlog_loss = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7534246575342466, 0.39285714285714285, 'log_loss = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7808219178082192, 0.39285714285714285, 'log_loss = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7945205479452054, 0.4642857142857143, 'log_loss = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.8356164383561644, 0.5357142857142857, 'X[7] <= 97.0\nlog_loss = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.821917808219178, 0.4642857142857143, 'log_loss = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8493150684931506, 0.4642857142857143, 'log_loss = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8356164383561644, 0.6071428571428571, 'log_loss = 0.0\nsamples = 60\nvalue = [0, 60]'),
#  Text(0.8493150684931506, 0.6785714285714286, 'log_loss = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9383561643835616, 0.8214285714285714, 'X[2] <= 31.262\nlog_loss = 0.863\nsamples = 105\nvalue = [75, 30]'),
#  Text(0.9041095890410958, 0.75, 'X[12] <= 25.78\nlog_loss = 0.699\nsamples = 90\nvalue = [73, 17]'),
#  Text(0.8767123287671232, 0.6785714285714286, 'X[10] <= 47.05\nlog_loss = 0.469\nsamples = 80\nvalue = [72, 8]'),
#  Text(0.863013698630137, 0.6071428571428571, 'log_loss = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.8904109589041096, 0.6071428571428571, 'X[10] <= 49.585\nlog_loss = 0.753\nsamples = 37\nvalue = [29, 8]'),
#  Text(0.8767123287671232, 0.5357142857142857, 'log_loss = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9041095890410958, 0.5357142857142857, 'X[3] <= 173.5\nlog_loss = 0.533\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.8904109589041096, 0.4642857142857143, 'X[3] <= 9.5\nlog_loss = 0.345\nsamples = 31\nvalue = [29, 2]'),
#  Text(0.8767123287671232, 0.39285714285714285, 'X[1] <= 47.606\nlog_loss = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.863013698630137, 0.32142857142857145, 'log_loss = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8904109589041096, 0.32142857142857145, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9041095890410958, 0.39285714285714285, 'log_loss = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.9178082191780822, 0.4642857142857143, 'log_loss = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9315068493150684, 0.6785714285714286, 'X[9] <= 3.169\nlog_loss = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.9178082191780822, 0.6071428571428571, 'log_loss = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9452054794520548, 0.6071428571428571, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9726027397260274, 0.75, 'X[2] <= 152.5\nlog_loss = 0.567\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.958904109589041, 0.6785714285714286, 'log_loss = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.9863013698630136, 0.6785714285714286, 'log_loss = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %% [markdown]
# ## Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE(random_state=rand_num)), 
   ('under', RandomUnderSampler(random_state=rand_num)), 
    ('clf', RandomForestClassifier(random_state=rand_num))
])

parameters = {
              'clf__n_estimators': [100,300,500],
              'clf__criterion': ['gini', 'entropy', 'log_loss'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
              'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
              'under__sampling_strategy': [0.5, 0.6, 0.7],
              'smt__k_neighbors': [3, 5]
             }

nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
refit_score = 'f1'
gscv_rf = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True, random_state=rand_num),
                    return_train_score=False, 
                    verbose=1, 
                    refit=refit_score,
                    n_jobs=-1)
resultsGSCV = gscv_rf.fit(X, y)

# Save the resultsGSCV with pickle
with open('RF_resultsGSCV.pkl', 'wb') as f:
    pickle.dump(resultsGSCV, f)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_rf, classifier_name, notebook_name)

# Save best parameters 
RF_best_params = gscv_rf.best_params_
df = pd.DataFrame([RF_best_params])
df.to_csv(f"{dir_path}/RF_best_params-{notebook_name}-{timestamp}.csv", index=False)
# Save with pickle
with open(f"{dir_path}/RF_best_params-{notebook_name}-{timestamp}.pkl", 'wb') as f:
    pickle.dump(RF_best_params, f)
    
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
pd.set_option("display.max_rows", None)

# %%
# Evaluation on test data
rf_clf = gscv_rf.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# rf_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation RF on test set
y_pred = rf_clf.predict(X_eval)
RF_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
RF_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))

# %% [markdown]
# Plot the mean ROC curve of the algorithm with best performing parameter selection. We will perform CV once again and plot the ROC curve for each fold and compute and plot the mean.

# %%
# Plot the ROC curve for RF
from sklearn.metrics import RocCurveDisplay
# # Load the data with pickle
# with open('RF_resultsGSCV.pkl', 'rb') as f:
#     resultsGSCV = pickle.load(f)
clf = resultsGSCV.best_estimator_

y_pred = clf.predict_proba(X_eval)[:, 1]
RocCurveDisplay.from_predictions(y_eval, y_pred)
plt.savefig(f"{dir_path}/RF_ROC_curve_noCV-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Plot the ROC curve for RF

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=rand_num)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval, y_eval)):
    classifier.fit(X_eval.iloc[train], y_eval[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X_eval.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
# plt.savefig(f"{dir_path}/RF_ROC_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# Plot the mean precision-recall curve. The approach is the same as for the mean ROC curve.

# %%
# Plot the mean precision-recall curve. 
from sklearn.metrics import PrecisionRecallDisplay
# # Load the data with pickle
# with open('RF_resultsGSCV.pkl', 'rb') as f:
#     resultsGSCV = pickle.load(f)
clf = resultsGSCV.best_estimator_

y_pred = clf.predict_proba(X_eval)[:, 1]
PrecisionRecallDisplay.from_predictions(y_eval, y_pred)
plt.savefig(f"{dir_path}/RF_precision-recall_curve_noCV-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Plot the mean precision-recall curve. 

from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=rand_num)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval, y_eval)):
    classifier.fit(X_eval.iloc[train], y_eval[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X_eval.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
# plt.savefig(f"{dir_path}/RF_precision-recall_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf_clf, X_eval, y_eval, random_state=rand_num)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X_eval.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
plt.savefig(f"{dir_path}/permutation_importance_RF-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300, bbox_inches='tight')

# %% [markdown]
# ### SHAP

# %%
# # Get feature importance with SHAP
# explainer = shap.TreeExplainer(rf)
# shap_values = explainer.shap_values(X)
# RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %%
# SHAP summary plot
explainer = shap.TreeExplainer(rf_clf)
shap_values = explainer.shap_values(X_eval)
classid = 1

# Save shap.summary_plot()
fig = shap.summary_plot(shap_values[classid], X_eval, max_display=len(X_eval.columns), class_names=le.classes_, show=False)
plt.savefig(f"{dir_path}/shap_summary_plot-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')

# %%
# Try dependence contribution plot
explainer = shap.TreeExplainer(rf_clf)
shap_values = explainer.shap_values(X_eval)
for i in X_eval.columns:
    shap.dependence_plot(i, shap_values[1], X_eval) #interaction_index="salinity"

# %% [markdown]
# ### Exaplain individual prediction with SHAP

# %%
# explain positive example prediction 
correct_indices = np.where((y_eval == 1) & (rf_clf.predict(X_eval) == y_eval))[0]

instanceID = correct_indices[12]
# instanceID = 120

instance = X_eval.iloc[[instanceID]]
display_instance = X_eval.iloc[[instanceID]]

prediction = rf_clf.predict(instance)[0]
prediction_probs = rf_clf.predict_proba(instance)[0]
print(f'real value: {y_eval[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.TreeExplainer(rf_clf)
shap_values = explainer.shap_values(instance)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)

# %%
# explain negative example prediction 
correct_indices = np.where((y_eval == 0) & (rf_clf.predict(X_eval) == y_eval))[0]

instanceID = correct_indices[1]
# instanceID = 135

instance = X_eval.iloc[[instanceID]]
display_instance = X_eval.iloc[[instanceID]]

prediction = rf_clf.predict(instance)[0]
prediction_probs = rf_clf.predict_proba(instance)[0]
print(f'real value: {y_eval[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.TreeExplainer(rf_clf)
shap_values = explainer.shap_values(instance)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

#Remove months from X
Xnn = X.drop(X.columns[0], axis=1)

X_display = Xnn.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xnn)
Xsc = pd.DataFrame(scaled_array, columns=Xnn.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE(random_state=rand_num)),
    ('under', RandomUnderSampler(random_state=rand_num)),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000, random_state=rand_num))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.5, 0.6, 0.8], # probaj poveča ovresampling do 0.9
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
              'clf__solver': ['lbfgs', 'sgd', 'adam']
             }
nfolds = 5
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv_NN = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True, random_state=rand_num),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "f1")
resultsGSCV = gscv_NN.fit(Xsc, y)

# Save the resultsGSCV with pickle
with open('MLP_resultsGSCV.pkl', 'wb') as f:
    pickle.dump(resultsGSCV, f)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_NN, classifier_name, notebook_name)

# Save best parameters 
MLP_best_params = gscv_NN.best_params_
df = pd.DataFrame([MLP_best_params])
df.to_csv(f"{dir_path}/MLP_best_params-{notebook_name}-{timestamp}.csv", index=False)
# Save with pickle
with open(f"{dir_path}/MLP_best_params-{notebook_name}-{timestamp}.pkl", 'wb') as f:
    pickle.dump(MLP_best_params, f)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())

# %%
# Evaluation on test data
nn_clf = gscv_NN.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# nn_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation of NN on test set
X_eval_nn = X_eval.drop(X_eval.columns[0], axis=1)
X_eval_display = X_eval_nn.copy()

scaler = StandardScaler().fit(Xnn)
X_eval_sc = scaler.transform(X_eval_nn)
X_eval_sc = pd.DataFrame(X_eval_sc, columns=Xnn.columns)
y_pred = nn_clf.predict(X_eval_sc)
NN_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
NN_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))

# %%
# Plot the ROC curve for MLP (Check code as moved form RF!). 

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval_sc, y_eval)):
    classifier.fit(X_eval_sc.iloc[train], y_eval[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X_eval_sc.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
plt.savefig(f"{dir_path}/MLP_ROC_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Plot the mean precision-recall curve for MLP (Check code as moved form RF!). 

from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval_sc, y_eval)):
    classifier.fit(X_eval_sc.iloc[train], y_eval[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X_eval_sc.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
plt.savefig(f"{dir_path}/MLP_precision-recall_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# #### Feature Importance (MLP)

# %%
# Feature importance of model (best MLP from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(nn_clf, X_eval_sc, y_eval, random_state=rand_num)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X_eval_sc.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance MLP")
plt.savefig(f"{dir_path}/permutation_importance_MLP-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300, bbox_inches='tight')

# %% [markdown]
# #### Feature importance with SHAP

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# # explain the model's predictions using SHAP
# import shap
# import warnings
# warnings.filterwarnings("ignore")
# shap.initjs()

# explainer = shap.KernelExplainer(NN_model.predict_proba, shap.sample(X_eval_sc,20))
# shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
# shap.summary_plot(shap_values, X_eval_sc, max_display=len(X.columns), class_names=le.classes_)

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
warnings.filterwarnings("ignore")
shap.initjs()

explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(X_eval_sc, 50))
shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
classid = 1

# Save shap.summary_plot()
fig = shap.summary_plot(shap_values[classid], X_eval_display, max_display=len(X_eval_display.columns), class_names=le.classes_, show=False)
plt.savefig(f"{dir_path}/shap_summary_plot-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')

# %%
# Try dependence contribution plot
explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(X_eval_sc, 50))
shap_values = explainer.shap_values(X_eval_sc, nsamples=50)

for i in X_eval_display.columns:
    shap.dependence_plot(i, shap_values[1], X_eval_display,) #interaction_index="salinity"

# %% [markdown]
# Example intepretation: The fact this slopes upward says the higher the soca flow, the higher the model's prediction is for poz/neg. The spread suggests that other features must interact with Soca flow.
# In general, high Soca flow increases the chance of poz/neg. But if the sea temp is moderate or low, that trend reverses and even high soca flow does not increase preditions of poz/neg as the sea temp is too low.
# https://www.kaggle.com/code/dansbecker/advanced-uses-of-shap-values
# ----
# To interpret the dependence contribution plot, look for trends or patterns in the relationship between the 'salinity' feature values and their SHAP values. For example:
#
# If the points show a clear positive trend, it means that as the 'salinity' value increases, its positive contribution to the model's prediction also increases.
# If the points show a clear negative trend, it means that as the 'salinity' value increases, its negative contribution to the model's prediction increases (i.e., higher 'salinity' values decrease the probability of class 1).
# If there is no clear trend or the points are scattered randomly, it means that there is no strong relationship between the 'salinity' feature values and their SHAP values.
# Additionally, observe the colors of the points in the plot. If there is a clear pattern in the colors, it may indicate that the interaction between 'salinity' and the interaction feature has a significant impact on the model's predictions. This can help you identify interactions between features that the model is capturing.

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
# explain positive example prediction 
correct_indices = np.where((y_eval == 1) & (nn_clf.predict(X_eval_sc) == y_eval))[0]

instanceID = correct_indices[0]
instance = X_eval_sc.iloc[[instanceID]]
display_instance = X_eval_display.iloc[[instanceID]]

prediction = nn_clf.predict(instance)[0]
prediction_probs = nn_clf.predict_proba(instance)[0]
print(f'real value: {y_eval[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(Xsc, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)

# %%
# explain negative example prediction 
correct_indices = np.where((y_eval == 0) & (nn_clf.predict(X_eval_sc) == y_eval))[0]

instanceID = correct_indices[0]
instance = X_eval_sc.iloc[[instanceID]]
display_instance = X_eval_display.iloc[[instanceID]]

prediction = nn_clf.predict(instance)[0]
prediction_probs = nn_clf.predict_proba(instance)[0]
print(f'real value: {y_eval[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(Xsc, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)

# %% [markdown]
# Interpretation:
#
# Observe the base value (Expected value) and the prediction line. This gives you an idea of the overall prediction for the instance compared to the average prediction.
#
# Look at the colored arrows and identify the most important features, which are the ones with the longest arrows. These features have the greatest impact on the prediction.
#
# Analyze the direction and color of the arrows to understand whether each feature increases or decreases the probability of the positive class (class 1) and whether the feature values are high or low.
#
# Consider the interactions between the features and their combined impact on the prediction.
#
# By analyzing the force plot, you can gain insights into the contributions of each feature to the model's prediction for a specific instance, helping you understand the model's decision-making process.

# %% [markdown]
# ### LIME

# %%
import lime
from lime import lime_tabular

# Create a LIME explainer object
lime_explainer = lime_tabular.LimeTabularExplainer(
    training_data=np.array(Xsc),
    feature_names=Xsc.columns,
    class_names=le.classes_,
    mode='classification'
)

# Exaplain an instance
instanceID = 100
lime_exp = lime_explainer.explain_instance(
    data_row=Xsc.iloc[instanceID], 
    predict_fn=nn_clf.predict_proba
)

lime_exp.show_in_notebook(show_table=True)

# Save the LIME explanation as an image file
# fig = lime_exp.as_pyplot_figure(label=1)
# plt.savefig(f"{dir_path}/lime_explanation-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')

# %% [markdown]
# ### Conclusion

# %%
# Define a function to extract the metrics from the classification report dictionary
def extract_metrics(report_dict):
    metrics = {}
    for class_label in report_dict:
        if class_label in ('accuracy', 'macro avg', 'weighted avg'):
            continue
        metrics[class_label] = {
            'precision': report_dict[class_label]['precision'],
            'recall': report_dict[class_label]['recall'],
            'f1-score': report_dict[class_label]['f1-score'],
            'support': report_dict[class_label]['support']
        }
    return metrics

# Extract the metrics for each classifier
SVM_metrics = extract_metrics(SVM_report_dict)
DT_metrics = extract_metrics(DT_report_dict)
RF_metrics = extract_metrics(RF_report_dict)
NN_metrics = extract_metrics(NN_report_dict)

# Create a dictionary to store the metrics for each classifier
classifier_metrics = {
    'Support Vector Machines': SVM_metrics,
    'Decision Tree': DT_metrics,
    'Random Forest': RF_metrics,
    'Neural Network': NN_metrics
}

# Convert the dictionary to a pandas DataFrame
summary_df = pd.concat({k: pd.DataFrame(v).transpose() for k, v in classifier_metrics.items()}, axis=0)
summary_df.reset_index(inplace=True)
summary_df.columns = ['Classifier', 'Class', 'Precision', 'Recall', 'F1-score', 'Support']

# Map the original class labels to the new names
class_name_mapping = {
    '0': 'neg',
    '1': 'poz'
}
summary_df['Class'] = summary_df['Class'].map(class_name_mapping)

# Filter the summary DataFrame to display only the 'poz' class
poz_summary_df = summary_df.query("Class == 'poz'")

# Display the filtered summary DataFrame
poz_summary_df

# %%
# Format table

poz_summary_df = poz_summary_df.round(2)
# poz_summary_df = poz_summary_df.set_index('Classifier')
poz_summary_df = poz_summary_df.drop(['Support', "Class"], axis=1)
# poz_summary_df = poz_summary_df.style.highlight_max(subset=['Precision', 'Recall', 'F1-score'], color='green')
poz_summary_df.to_csv(f"{dir_path}/results_summary_df.csv")
poz_summary_df["Timestamp"] = timestamp
poz_summary_df

# %%
# # Add results to results to results df
# df_results = pd.read_pickle("data/results/df_results_3_0")
# df_results

# %%
# df_results = df_results.append(poz_summary_df)
# df_results.to_pickle("data/results/df_results_3_0")
# df_results
