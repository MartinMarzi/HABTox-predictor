# %%
from datetime import datetime
import pandas as pd
import numpy as np
import os
import pickle
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.svm import SVC 
from sklearn.tree import export_text
import dtreeviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold
import umap

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import warnings

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

import ipynbname
notebook_name = ipynbname.name()

import seaborn as sns

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 35)
# Out:
# 2023-06-05 15:15:46.030151: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Define directory path name and timestamp

# Get the current date and time as a string
timestamp = datetime.datetime.now().strftime('%d%m%Y_%H%M')

# Construct the directory path with the models folder and timestamp
dir_path = f"models/{timestamp}"
    
# Create the directory if it doesn't exist
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

# %%
# Saving models

# Function to save best estimator
def save_best_estimator(grid_search_cv, classifier_name, notebook_name):
    # Get the best estimator from the GridSearchCV object
    best_estimator = grid_search_cv.best_estimator_

    # Construct the file name with the classifier name and notebook name
    pickle_file_name = f"{dir_path}/{classifier_name}-{notebook_name}-{timestamp}.pkl"
    
    # Save the best estimator to the file
    with open(pickle_file_name, 'wb') as f:
        pickle.dump(best_estimator, f)

    print(f"Best estimator saved as: {pickle_file_name}")

# %%
# Function for loading saved models

def load_best_estimator(pickle_file_name):
    with open(pickle_file_name, 'rb') as f:
        best_estimator = pickle.load(f)
    return best_estimator

# %%
# import data
X = pd.read_csv("data/data splits/X_train.csv")
y = np.genfromtxt("data/data splits/y_train.csv", delimiter=',', skip_header=1, dtype=int)
X_all = pd.read_csv("data/data splits/X_all.csv")
y_all = np.genfromtxt("data/data splits/y_all.csv", delimiter=',', skip_header=1, dtype=int)
X_eval = pd.read_csv("data/data splits/X_test.csv")
y_eval = np.genfromtxt("data/data splits/y_test.csv", delimiter=',', skip_header=1, dtype=int)

# %% [markdown]
# --------

# %%
len(X_eval)
# Out:
# 264

# %%
len(X)
# Out:
# 613

# %%
# Count number of zeros
num_zeros = np.count_nonzero(y == 0)

# Count number of ones
num_ones = np.count_nonzero(y == 1)

print(f"Number of 0's: {num_zeros}")
print(f"Number of 1's: {num_ones}")
# Out:
# Number of 0's: 521
# Number of 1's: 92

# %%
# ratio poz : neg after upsampling
(92* 1.6989130434782607) / 521 = 0.3
# Out:
# 0.3

# %%
0.3*521/92
# Out:
# 1.6989130434782607

# %%
# y poz upsampled
92 * 1.6989130434782607
# Out:
# 156.29999999999998

# %%
# ratio poz : neg after donwlsapling
(156.3) / (521*0.4285714285714286) = 0.7
# Out:
# 0.7

# %%
521*0.4285714285714286
# Out:
# 223.2857142857143

# %%
223.3+156.3
# Out:
# 379.6

# %% [markdown]
# ------------

# %% [markdown]
# # Modelling

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE()), 
    ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
            # 'clf__max_depth': [2,3,4],
            # 'clf__min_samples_split': [5, 10, 15, 20],
            'clf__min_samples_leaf': [50, 75, 100], #35, 40, 45, 30, 50,  75,, 150, 200
            'clf__criterion': ['gini', 'entropy', 'log_loss'],
            # 'clf__max_leaf_nodes': [5, 7, 10],
            # 'clf__ccp_alpha': [0.2, 0.3, 0.4],
               'clf__class_weight': ['balanced', None],
               'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
               'under__sampling_strategy': [0.5, 0.6, 0.7],
               'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv_dt = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="f1",
                    n_jobs=-1)
resultsGSCV = gscv_dt.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_dt, classifier_name, notebook_name)

# Save best parameters 
DT_best_params = gscv_dt.best_params_
df = pd.DataFrame([DT_best_params])
df.to_csv(f"{dir_path}/DT_best_params-{notebook_name}-{timestamp}.csv", index=False)
# Save with pickle
with open(f"{dir_path}/DT_best_params-{notebook_name}-{timestamp}.pkl", 'wb') as f:
    pickle.dump(DT_best_params, f)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Best estimator saved as: models/05062023_1515/DecisionTreeClassifier-HAB_modelling_6_8-DT-visualisation_1-05062023_1515.pkl
#                                                                               419  \
# mean_fit_time                                                            0.021776
# std_fit_time                                                             0.001971
# mean_score_time                                                          0.015394
# std_score_time                                                            0.00293
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.421053
# split2_test_recall                                                       0.421053
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.611111
# mean_test_recall                                                         0.479532
# std_test_recall                                                          0.071837
# rank_test_recall                                                              407
# split0_test_precision                                                    0.692308
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.615385
# split3_test_precision                                                    0.444444
# split4_test_precision                                                    0.354839
# mean_test_precision                                                      0.521395
# std_test_precision                                                       0.120138
# rank_test_precision                                                             4
# split0_test_f1                                                           0.580645
# split1_test_f1                                                           0.457143
# split2_test_f1                                                                0.5
# split3_test_f1                                                           0.444444
# split4_test_f1                                                            0.44898
# mean_test_f1                                                             0.486242
# std_test_f1                                                              0.051154
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.750794
# split1_test_roc_auc                                                      0.677885
# split2_test_roc_auc                                                      0.693573
# split3_test_roc_auc                                                      0.739049
# split4_test_roc_auc                                                      0.764957
# mean_test_roc_auc                                                        0.725252
# std_test_roc_auc                                                         0.033664
# rank_test_roc_auc                                                              65
# split0_test_recall_weighted                                              0.894309
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.869919
# split3_test_recall_weighted                                              0.836066
# split4_test_recall_weighted                                              0.778689
# mean_test_recall_weighted                                                0.844902
# std_test_recall_weighted                                                 0.038806
# rank_test_recall_weighted                                                       2
#
#                                                                               256  \
# mean_fit_time                                                            0.019346
# std_fit_time                                                              0.00064
# mean_score_time                                                          0.011907
# std_score_time                                                           0.001378
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.421053
# split3_test_recall                                                       0.388889
# split4_test_recall                                                       0.777778
# mean_test_recall                                                         0.511696
# std_test_recall                                                          0.140594
# rank_test_recall                                                              369
# split0_test_precision                                                    0.888889
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.615385
# split3_test_precision                                                    0.538462
# split4_test_precision                                                    0.333333
# mean_test_precision                                                       0.54188
# std_test_precision                                                       0.206307
# rank_test_precision                                                             2
# split0_test_f1                                                           0.592593
# split1_test_f1                                                           0.408163
# split2_test_f1                                                                0.5
# split3_test_f1                                                           0.451613
# split4_test_f1                                                           0.466667
# mean_test_f1                                                             0.483807
# std_test_f1                                                              0.061885
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.804762
# split1_test_roc_auc                                                      0.722419
# split2_test_roc_auc                                                      0.760881
# split3_test_roc_auc                                                      0.741186
# split4_test_roc_auc                                                      0.795139
# mean_test_roc_auc                                                        0.764877
# std_test_roc_auc                                                         0.031262
# rank_test_roc_auc                                                               1
# split0_test_recall_weighted                                              0.910569
# split1_test_recall_weighted                                              0.764228
# split2_test_recall_weighted                                              0.869919
# split3_test_recall_weighted                                              0.860656
# split4_test_recall_weighted                                              0.737705
# mean_test_recall_weighted                                                0.828615
# std_test_recall_weighted                                                  0.06612
# rank_test_recall_weighted                                                       8
#
#                                                                               366  \
# mean_fit_time                                                            0.024273
# std_fit_time                                                              0.00361
# mean_score_time                                                           0.01472
# std_score_time                                                           0.002637
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.631579
# split2_test_recall                                                       0.368421
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.477778
# std_test_recall                                                          0.087555
# rank_test_recall                                                              412
# split0_test_precision                                                    0.692308
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.636364
# split3_test_precision                                                    0.470588
# split4_test_precision                                                        0.32
# mean_test_precision                                                      0.498852
# std_test_precision                                                       0.144541
# rank_test_precision                                                             8
# split0_test_f1                                                           0.580645
# split1_test_f1                                                           0.470588
# split2_test_f1                                                           0.466667
# split3_test_f1                                                           0.457143
# split4_test_f1                                                           0.372093
# mean_test_f1                                                             0.469427
# std_test_f1                                                              0.066337
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.761376
# split1_test_roc_auc                                                      0.770749
# split2_test_roc_auc                                                      0.712045
# split3_test_roc_auc                                                        0.7289
# split4_test_roc_auc                                                      0.753739
# mean_test_roc_auc                                                        0.745362
# std_test_roc_auc                                                          0.02169
# rank_test_roc_auc                                                              19
# split0_test_recall_weighted                                              0.894309
# split1_test_recall_weighted                                              0.780488
# split2_test_recall_weighted                                              0.869919
# split3_test_recall_weighted                                              0.844262
# split4_test_recall_weighted                                              0.778689
# mean_test_recall_weighted                                                0.833533
# std_test_recall_weighted                                                 0.046807
# rank_test_recall_weighted                                                       6
#
#                                                                               426  \
# mean_fit_time                                                            0.023475
# std_fit_time                                                             0.001848
# mean_score_time                                                          0.014753
# std_score_time                                                           0.002107
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.421053
# split2_test_recall                                                       0.368421
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.424561
# std_test_recall                                                          0.029496
# rank_test_recall                                                              465
# split0_test_precision                                                    0.888889
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.636364
# split3_test_precision                                                    0.444444
# split4_test_precision                                                        0.32
# mean_test_precision                                                      0.557939
# std_test_precision                                                       0.194181
# rank_test_precision                                                             1
# split0_test_f1                                                           0.592593
# split1_test_f1                                                           0.457143
# split2_test_f1                                                           0.466667
# split3_test_f1                                                           0.444444
# split4_test_f1                                                           0.372093
# mean_test_f1                                                             0.466588
# std_test_f1                                                              0.071254
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.772751
# split1_test_roc_auc                                                      0.694079
# split2_test_roc_auc                                                      0.682692
# split3_test_roc_auc                                                      0.695246
# split4_test_roc_auc                                                      0.771368
# mean_test_roc_auc                                                        0.723227
# std_test_roc_auc                                                         0.040114
# rank_test_roc_auc                                                              76
# split0_test_recall_weighted                                              0.910569
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.869919
# split3_test_recall_weighted                                              0.836066
# split4_test_recall_weighted                                              0.778689
# mean_test_recall_weighted                                                0.848154
# std_test_recall_weighted                                                 0.043238
# rank_test_recall_weighted                                                       1
#
#                                                                               420  \
# mean_fit_time                                                            0.025036
# std_fit_time                                                             0.003839
# mean_score_time                                                          0.012804
# std_score_time                                                           0.001502
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.473684
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.666667
# mean_test_recall                                                              0.6
# std_test_recall                                                          0.083329
# rank_test_recall                                                              229
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.322581
# split2_test_precision                                                    0.391304
# split3_test_precision                                                    0.352941
# split4_test_precision                                                    0.342857
# mean_test_precision                                                      0.381937
# std_test_precision                                                       0.063115
# rank_test_precision                                                            60
# split0_test_f1                                                           0.571429
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.428571
# split3_test_f1                                                           0.461538
# split4_test_f1                                                            0.45283
# mean_test_f1                                                             0.462874
# std_test_f1                                                              0.058338
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.815079
# split1_test_roc_auc                                                      0.729504
# split2_test_roc_auc                                                      0.685476
# split3_test_roc_auc                                                      0.750267
# split4_test_roc_auc                                                      0.776175
# mean_test_roc_auc                                                          0.7513
# std_test_roc_auc                                                         0.043579
# rank_test_roc_auc                                                              10
# split0_test_recall_weighted                                              0.853659
# split1_test_recall_weighted                                              0.756098
# split2_test_recall_weighted                                              0.804878
# split3_test_recall_weighted                                              0.770492
# split4_test_recall_weighted                                              0.762295
# mean_test_recall_weighted                                                0.789484
# std_test_recall_weighted                                                 0.036249
# rank_test_recall_weighted                                                      53
#
#                                                                               363  \
# mean_fit_time                                                            0.023549
# std_fit_time                                                             0.003293
# mean_score_time                                                          0.014305
# std_score_time                                                           0.002652
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__min_samples_leaf                                                    75
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.421053
# split2_test_recall                                                       0.421053
# split3_test_recall                                                       0.444444
# split4_test_recall                                                            0.5
# mean_test_recall                                                          0.45731
# std_test_recall                                                          0.035888
# rank_test_recall                                                              437
# split0_test_precision                                                         0.6
# split1_test_precision                                                    0.571429
# split2_test_precision                                                    0.470588
# split3_test_precision                                                    0.421053
# split4_test_precision                                                         0.3
# mean_test_precision                                                      0.472614
# std_test_precision                                                        0.10812
# rank_test_precision                                                            11
# split0_test_f1                                                           0.545455
# split1_test_f1                                                           0.484848
# split2_test_f1                                                           0.444444
# split3_test_f1                                                           0.432432
# split4_test_f1                                                              0.375
# mean_test_f1                                                             0.456436
# std_test_f1                                                              0.056716
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.748413
# split1_test_roc_auc                                                      0.700911
# split2_test_roc_auc                                                      0.632844
# split3_test_roc_auc                                                      0.744658
# split4_test_roc_auc                                                      0.742788
# mean_test_roc_auc                                                        0.713923
# std_test_roc_auc                                                         0.044069
# rank_test_roc_auc                                                             140
# split0_test_recall_weighted                                              0.878049
# split1_test_recall_weighted                                              0.861789
# split2_test_recall_weighted                                              0.837398
# split3_test_recall_weighted                                              0.827869
# split4_test_recall_weighted                                              0.754098
# mean_test_recall_weighted                                                0.831841
# std_test_recall_weighted                                                 0.042714
# rank_test_recall_weighted                                                       7
#
#                                                                               329  \
# mean_fit_time                                                            0.021362
# std_fit_time                                                             0.002043
# mean_score_time                                                          0.013667
# std_score_time                                                           0.001359
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.631579
# split2_test_recall                                                       0.684211
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.722222
# mean_test_recall                                                         0.629825
# std_test_recall                                                          0.097182
# rank_test_recall                                                              173
# split0_test_precision                                                    0.888889
# split1_test_precision                                                    0.324324
# split2_test_precision                                                        0.26
# split3_test_precision                                                    0.307692
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.422848
# std_test_precision                                                        0.23439
# rank_test_precision                                                            35
# split0_test_f1                                                           0.592593
# split1_test_f1                                                           0.428571
# split2_test_f1                                                           0.376812
# split3_test_f1                                                           0.421053
# split4_test_f1                                                            0.45614
# mean_test_f1                                                             0.455034
# std_test_f1                                                              0.073345
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.773016
# split1_test_roc_auc                                                      0.753289
# split2_test_roc_auc                                                      0.656123
# split3_test_roc_auc                                                      0.765224
# split4_test_roc_auc                                                      0.736378
# mean_test_roc_auc                                                        0.736806
# std_test_roc_auc                                                         0.042191
# rank_test_roc_auc                                                              32
# split0_test_recall_weighted                                              0.910569
# split1_test_recall_weighted                                              0.739837
# split2_test_recall_weighted                                              0.650407
# split3_test_recall_weighted                                              0.729508
# split4_test_recall_weighted                                              0.745902
# mean_test_recall_weighted                                                0.755245
# std_test_recall_weighted                                                 0.084975
# rank_test_recall_weighted                                                     128
#
#                                                                               409  \
# mean_fit_time                                                            0.023276
# std_fit_time                                                             0.002294
# mean_score_time                                                          0.013253
# std_score_time                                                           0.001207
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.684211
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.508772
# std_test_recall                                                          0.093274
# rank_test_recall                                                              376
# split0_test_precision                                                    0.888889
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.317073
# split3_test_precision                                                    0.470588
# split4_test_precision                                                        0.32
# mean_test_precision                                                      0.465977
# std_test_precision                                                       0.219067
# rank_test_precision                                                            13
# split0_test_f1                                                           0.592593
# split1_test_f1                                                           0.408163
# split2_test_f1                                                           0.433333
# split3_test_f1                                                           0.457143
# split4_test_f1                                                           0.372093
# mean_test_f1                                                             0.452665
# std_test_f1                                                              0.075426
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.733862
# split1_test_roc_auc                                                      0.725202
# split2_test_roc_auc                                                        0.7333
# split3_test_roc_auc                                                      0.719017
# split4_test_roc_auc                                                      0.694979
# mean_test_roc_auc                                                        0.721272
# std_test_roc_auc                                                         0.014248
# rank_test_roc_auc                                                              95
# split0_test_recall_weighted                                              0.910569
# split1_test_recall_weighted                                              0.764228
# split2_test_recall_weighted                                              0.723577
# split3_test_recall_weighted                                              0.844262
# split4_test_recall_weighted                                              0.778689
# mean_test_recall_weighted                                                0.804265
# std_test_recall_weighted                                                  0.06583
# rank_test_recall_weighted                                                      25
#
#                                                                               251  \
# mean_fit_time                                                            0.022585
# std_fit_time                                                             0.007315
# mean_score_time                                                          0.012456
# std_score_time                                                           0.001427
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.684211
# split2_test_recall                                                       0.368421
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.722222
# mean_test_recall                                                         0.554971
# std_test_recall                                                           0.13542
# rank_test_recall                                                              317
# split0_test_precision                                                    0.357143
# split1_test_precision                                                    0.276596
# split2_test_precision                                                    0.636364
# split3_test_precision                                                    0.444444
# split4_test_precision                                                     0.40625
# mean_test_precision                                                      0.424159
# std_test_precision                                                       0.120024
# rank_test_precision                                                            33
# split0_test_f1                                                           0.434783
# split1_test_f1                                                           0.393939
# split2_test_f1                                                           0.466667
# split3_test_f1                                                           0.444444
# split4_test_f1                                                               0.52
# mean_test_f1                                                             0.451967
# std_test_f1                                                              0.041385
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.720106
# split1_test_roc_auc                                                      0.742156
# split2_test_roc_auc                                                      0.724696
# split3_test_roc_auc                                                      0.695246
# split4_test_roc_auc                                                      0.809295
# mean_test_roc_auc                                                          0.7383
# std_test_roc_auc                                                         0.038535
# rank_test_roc_auc                                                              30
# split0_test_recall_weighted                                              0.788618
# split1_test_recall_weighted                                              0.674797
# split2_test_recall_weighted                                              0.869919
# split3_test_recall_weighted                                              0.836066
# split4_test_recall_weighted                                              0.803279
# mean_test_recall_weighted                                                0.794536
# std_test_recall_weighted                                                 0.066115
# rank_test_recall_weighted                                                      44
#
#                                                                               421  \
# mean_fit_time                                                            0.023313
# std_fit_time                                                             0.001604
# mean_score_time                                                          0.013087
# std_score_time                                                           0.000931
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.631579
# split2_test_recall                                                       0.368421
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.722222
# mean_test_recall                                                         0.566667
# std_test_recall                                                          0.136125
# rank_test_recall                                                              298
# split0_test_precision                                                    0.470588
# split1_test_precision                                                    0.352941
# split2_test_precision                                                    0.636364
# split3_test_precision                                                    0.352941
# split4_test_precision                                                    0.276596
# mean_test_precision                                                      0.417886
# std_test_precision                                                       0.125625
# rank_test_precision                                                            39
# split0_test_f1                                                           0.457143
# split1_test_f1                                                            0.45283
# split2_test_f1                                                           0.466667
# split3_test_f1                                                           0.461538
# split4_test_f1                                                                0.4
# mean_test_f1                                                             0.447636
# std_test_f1                                                              0.024257
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.689153
# split1_test_roc_auc                                                      0.717358
# split2_test_roc_auc                                                      0.661437
# split3_test_roc_auc                                                      0.740652
# split4_test_roc_auc                                                      0.750267
# mean_test_roc_auc                                                        0.711774
# std_test_roc_auc                                                          0.03284
# rank_test_roc_auc                                                             162
# split0_test_recall_weighted                                              0.845528
# split1_test_recall_weighted                                              0.764228
# split2_test_recall_weighted                                              0.869919
# split3_test_recall_weighted                                              0.770492
# split4_test_recall_weighted                                              0.680328
# mean_test_recall_weighted                                                0.786099
# std_test_recall_weighted                                                 0.067033
# rank_test_recall_weighted                                                      64
#
#                                                                               267  \
# mean_fit_time                                                            0.026445
# std_fit_time                                                             0.003484
# mean_score_time                                                          0.013555
# std_score_time                                                           0.000663
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                    50
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.444444
# split1_test_recall                                                       0.473684
# split2_test_recall                                                       0.263158
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.777778
# mean_test_recall                                                         0.480702
# std_test_recall                                                          0.166288
# rank_test_recall                                                              406
# split0_test_precision                                                    0.888889
# split1_test_precision                                                    0.321429
# split2_test_precision                                                    0.333333
# split3_test_precision                                                    0.444444
# split4_test_precision                                                    0.368421
# mean_test_precision                                                      0.471303
# std_test_precision                                                       0.213158
# rank_test_precision                                                            12
# split0_test_f1                                                           0.592593
# split1_test_f1                                                           0.382979
# split2_test_f1                                                           0.294118
# split3_test_f1                                                           0.444444
# split4_test_f1                                                                0.5
# mean_test_f1                                                             0.442827
# std_test_f1                                                              0.101388
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.772222
# split1_test_roc_auc                                                      0.685982
# split2_test_roc_auc                                                      0.690536
# split3_test_roc_auc                                                      0.776709
# split4_test_roc_auc                                                      0.839476
# mean_test_roc_auc                                                        0.752985
# ...
# split0_test_precision                                                    0.297872
# split1_test_precision                                                    0.235294
# split2_test_precision                                                    0.234043
# split3_test_precision                                                    0.254902
# split4_test_precision                                                         0.0
# mean_test_precision                                                      0.204422
# std_test_precision                                                       0.104786
# rank_test_precision                                                           482
# split0_test_f1                                                           0.430769
# split1_test_f1                                                           0.342857
# split2_test_f1                                                           0.333333
# split3_test_f1                                                           0.376812
# split4_test_f1                                                                0.0
# mean_test_f1                                                             0.296754
# std_test_f1                                                              0.152247
# rank_test_f1                                                                  483
# split0_test_roc_auc                                                      0.731746
# split1_test_roc_auc                                                      0.628289
# split2_test_roc_auc                                                      0.616397
# split3_test_roc_auc                                                      0.678419
# split4_test_roc_auc                                                      0.610043
# mean_test_roc_auc                                                        0.652979
# std_test_roc_auc                                                         0.046136
# rank_test_roc_auc                                                             449
# split0_test_recall_weighted                                              0.699187
# split1_test_recall_weighted                                              0.626016
# split2_test_recall_weighted                                              0.642276
# split3_test_recall_weighted                                              0.647541
# split4_test_recall_weighted                                              0.852459
# mean_test_recall_weighted                                                0.693496
# std_test_recall_weighted                                                 0.083175
# rank_test_recall_weighted                                                     308
#
#                                                                               470  \
# mean_fit_time                                                            0.021307
# std_fit_time                                                             0.002011
# mean_score_time                                                          0.015815
# std_score_time                                                            0.00489
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                   100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                            0.0
# split2_test_recall                                                       0.578947
# split3_test_recall                                                       0.722222
# split4_test_recall                                                       0.888889
# mean_test_recall                                                         0.571345
# std_test_recall                                                          0.303044
# rank_test_recall                                                              291
# split0_test_precision                                                    0.222222
# split1_test_precision                                                         0.0
# split2_test_precision                                                    0.186441
# split3_test_precision                                                    0.224138
# split4_test_precision                                                    0.313725
# mean_test_precision                                                      0.189305
# std_test_precision                                                       0.103559
# rank_test_precision                                                           484
# split0_test_f1                                                           0.333333
# split1_test_f1                                                                0.0
# split2_test_f1                                                           0.282051
# split3_test_f1                                                           0.342105
# split4_test_f1                                                           0.463768
# mean_test_f1                                                             0.284252
# std_test_f1                                                              0.154134
# rank_test_f1                                                                  484
# split0_test_roc_auc                                                      0.633333
# split1_test_roc_auc                                                      0.590081
# split2_test_roc_auc                                                      0.558704
# split3_test_roc_auc                                                      0.644765
# split4_test_roc_auc                                                      0.776175
# mean_test_roc_auc                                                        0.640612
# std_test_roc_auc                                                         0.074444
# rank_test_roc_auc                                                             468
# split0_test_recall_weighted                                              0.609756
# split1_test_recall_weighted                                              0.845528
# split2_test_recall_weighted                                              0.544715
# split3_test_recall_weighted                                              0.590164
# split4_test_recall_weighted                                              0.696721
# mean_test_recall_weighted                                                0.657377
# std_test_recall_weighted                                                 0.106233
# rank_test_recall_weighted                                                     401
#
#                                                                               477  \
# mean_fit_time                                                            0.025454
# std_fit_time                                                             0.002023
# mean_score_time                                                          0.016986
# std_score_time                                                           0.003241
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__min_samples_leaf                                                   100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.0
# split1_test_recall                                                       0.631579
# split2_test_recall                                                       0.631579
# split3_test_recall                                                            0.0
# split4_test_recall                                                       0.833333
# mean_test_recall                                                         0.419298
# std_test_recall                                                          0.350192
# rank_test_recall                                                              468
# split0_test_precision                                                         0.0
# split1_test_precision                                                    0.235294
# split2_test_precision                                                    0.235294
# split3_test_precision                                                         0.0
# split4_test_precision                                                    0.326087
# mean_test_precision                                                      0.159335
# std_test_precision                                                       0.134254
# rank_test_precision                                                           485
# split0_test_f1                                                                0.0
# split1_test_f1                                                           0.342857
# split2_test_f1                                                           0.342857
# split3_test_f1                                                                0.0
# split4_test_f1                                                            0.46875
# mean_test_f1                                                             0.230893
# std_test_f1                                                              0.194047
# rank_test_f1                                                                  485
# split0_test_roc_auc                                                      0.731746
# split1_test_roc_auc                                                      0.628289
# split2_test_roc_auc                                                      0.628289
# split3_test_roc_auc                                                      0.644765
# split4_test_roc_auc                                                      0.767628
# mean_test_roc_auc                                                        0.680144
# std_test_roc_auc                                                         0.058216
# rank_test_roc_auc                                                             374
# split0_test_recall_weighted                                              0.853659
# split1_test_recall_weighted                                              0.626016
# split2_test_recall_weighted                                              0.626016
# split3_test_recall_weighted                                              0.852459
# split4_test_recall_weighted                                              0.721311
# mean_test_recall_weighted                                                0.735892
# std_test_recall_weighted                                                 0.101799
# rank_test_recall_weighted                                                     179
#
#                                                                               315
# mean_fit_time                                                            0.024131
# std_fit_time                                                              0.00302
# mean_score_time                                                          0.016086
# std_score_time                                                           0.002719
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__min_samples_leaf                                                   100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.0
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.578947
# split3_test_recall                                                       0.722222
# split4_test_recall                                                            0.0
# mean_test_recall                                                         0.376023
# std_test_recall                                                          0.311447
# rank_test_recall                                                              484
# split0_test_precision                                                         0.0
# split1_test_precision                                                    0.282051
# split2_test_precision                                                    0.234043
# split3_test_precision                                                    0.224138
# split4_test_precision                                                         0.0
# mean_test_precision                                                      0.148046
# std_test_precision                                                       0.122457
# rank_test_precision                                                           486
# split0_test_f1                                                                0.0
# split1_test_f1                                                            0.37931
# split2_test_f1                                                           0.333333
# split3_test_f1                                                           0.342105
# split4_test_f1                                                                0.0
# mean_test_f1                                                              0.21095
# std_test_f1                                                               0.17293
# rank_test_f1                                                                  486
# split0_test_roc_auc                                                      0.719048
# split1_test_roc_auc                                                      0.654858
# split2_test_roc_auc                                                      0.616397
# split3_test_roc_auc                                                      0.644765
# split4_test_roc_auc                                                      0.599893
# mean_test_roc_auc                                                        0.646992
# std_test_roc_auc                                                          0.04102
# rank_test_roc_auc                                                             458
# split0_test_recall_weighted                                              0.853659
# split1_test_recall_weighted                                              0.707317
# split2_test_recall_weighted                                              0.642276
# split3_test_recall_weighted                                              0.590164
# split4_test_recall_weighted                                              0.852459
# mean_test_recall_weighted                                                0.729175
# std_test_recall_weighted                                                 0.107748
# rank_test_recall_weighted                                                     202
#
# [51 rows x 486 columns]

# %%
# Evaluation on test data
dt_clf = gscv_dt.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/12042023_1718/DecisionTreeClassifier-HAB_modelling_5_8-12042023_1718.pkl"
# dt_clf = load_best_estimator(pickle_file_name).steps[2][1]

y_pred = dt_clf.predict(X_eval)
DT_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
DT_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.90      0.88      0.89       224
#          poz       0.39      0.45      0.42        40
#
#     accuracy                           0.81       264
#    macro avg       0.65      0.66      0.65       264
# weighted avg       0.82      0.81      0.82       264

# %%
viz_model = dtreeviz.model(dt_clf, X_eval, y_eval,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"]
             #   scale=1.5
              )

# Save the visualization as a PNG file
viz_file_name = f"{dir_path}/DT_visualisation.svg"
# viz_model.save(viz_file_name)
v = viz_model.view(fancy=False, colors = {'neg': '#3eb489', 'poz': '#ff5349'})    
v.save(viz_file_name) 
print(f"Visualization saved as: {viz_file_name}")

# Display the visualization
v
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Visualization saved as: models/05062023_1515/DT_visualisation.svg

# %%
# viz_model.ctree_leaf_distributions(figsize=(3.5,2))

# %%
from sklearn import tree
fig = plt.figure(figsize=(15,10))
_ = tree.plot_tree(dt_clf, 
                   feature_names=X.columns,  
                   class_names=["neg", "poz"],
                   filled=True)

# %%
# import graphviz
# # DOT data
# dot_data = tree.export_graphviz(dt_clf, out_file=None, 
#                                 feature_names=X.columns,  
#                                 class_names=["neg", "poz"],
#                                 filled=True)

# # Draw graph
# graph = graphviz.Source(dot_data, format="png") 
# graph

# %% [markdown]
# # Retrain DT with best parameters from gridsearch on a all data

# %%
# # Retrain DT with best parameters from gridsearch on a all data
# best_params = gscv_dt.best_params_

# # # Load the data with pickle
# # with open('DT_best_params.pkl', 'rb') as f:
# #     DT_best_params = pickle.load(f)

# print(best_params)

# # Create a pipeline with the best parameters
# best_pipeline = IMBLpipeline([
#     ('smt', SMOTE(sampling_strategy=best_params['smt__sampling_strategy'], k_neighbors=best_params['smt__k_neighbors'], random_state=rand_num)), 
#     ('under', RandomUnderSampler(sampling_strategy=best_params['under__sampling_strategy'], random_state=rand_num)), 
#     ('clf', DecisionTreeClassifier(max_depth=best_params['clf__min_samples_leaf'], criterion=best_params['clf__criterion'], class_weight=best_params['clf__class_weight'], random_state=rand_num))
# ])

# # Train the model on the entire dataset
# best_pipeline.fit(X_all, y_all)

# # Extract the decision tree classifier from the pipeline
# best_dt_clf = best_pipeline.named_steps['clf']

# # Save the best decision tree classifier with pickle
# with open(f"{dir_path}/best_DT_clf_all_data.pkl-{notebook_name}-{timestamp}.pkl", 'wb') as f:
#     pickle.dump(best_dt_clf, f)

# #Visualise DT
# from dtreeviz.trees import dtreeviz

# viz = dtreeviz(best_dt_clf, X_all, y_all,
#                 target_name="target",
#                 feature_names=X_all.columns,
#                 class_names=["neg", "poz"],
#                 fancy=False,
#                 scale=1.5)

# # Save the visualization as a PNG file
# viz_file_name = f"{dir_path}/best_DT_visualisation_all-data.svg"
# viz.save(viz_file_name)
# print(f"Visualization saved as: {viz_file_name}")

# # Display the visualization
# viz
