# %%
from datetime import datetime
import pandas as pd
import numpy as np
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from dtreeviz.trees import dtreeviz 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 30)

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")
data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
# data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    661
# salinity                 191
# T                        244
# SECCHI                   696
# DIN                      542
# PO4-P                    534
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
data.drop(columns=["Chl-a","PO4-P","DIN","SECCHI"], inplace=True)
# data.drop(columns=["SECCHI",  ], inplace=True)#,"Chl-a", "PO4-P", "DIN",
data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# salinity                 191
# T                        244
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Modelling and Preliminary Results

# %% [markdown]
# ![Screenshot 2022-07-26 at 12.15.26.png](attachment:500d2dd5-b27f-4f67-a0a0-94d4c6fc8714.png)

# %% [markdown]
# # Scikit-learn Analysis

# %% [markdown]
# ### Preprocessing

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    839
# poz    114
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# ## Model Training and Evaluation

# %% [markdown]
# ### Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
              'clf__max_depth': [2,3,4],
                'clf__criterion': ['gini', 'entropy'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
               'smt__sampling_strategy': [ 0.1, 0.2],
               'under__sampling_strategy': [0.7, 0.8],
                'smt__k_neighbors': [3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="recall",
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# 480 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 268, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 226, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 394, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 534, in check_sampling_strategy
#     _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 373, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 272, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 969, in fit
#     super().fit(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 227, in fit
#     expanded_class_weight = compute_sample_weight(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/utils/class_weight.py", line 127, in compute_sample_weight
#     raise ValueError(
# ValueError: The only valid preset for class_weight is "balanced". Given "balanced_subsample".
#
# One or more of the test scores are non-finite: [       nan        nan 0.61304348 0.52608696        nan        nan
#  0.61383399 0.5               nan        nan 0.53517787 0.58695652
#         nan        nan 0.6743083  0.63043478        nan        nan
#  0.72687747 0.63992095        nan        nan 0.62252964 0.65810277
#         nan        nan 0.55256917 0.52450593        nan        nan
#  0.6055336  0.57944664        nan        nan 0.52529644 0.56956522
#         nan        nan 0.70316206 0.60355731        nan        nan
#  0.59604743 0.6312253         nan        nan 0.65810277 0.56166008
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.53557312 0.47312253        nan        nan
#  0.4284585  0.49802372        nan        nan 0.51541502 0.44545455
#         nan        nan 0.5256917  0.58577075        nan        nan
#  0.55968379 0.53517787        nan        nan 0.59486166 0.45375494
#         nan        nan 0.55968379 0.46324111        nan        nan
#  0.54387352 0.46442688        nan        nan 0.52648221 0.52490119
#         nan        nan 0.57035573 0.46363636        nan        nan
#  0.58616601 0.58735178        nan        nan 0.53320158 0.61462451]
# One or more of the test scores are non-finite: [       nan        nan 0.23052239 0.22328336        nan        nan
#  0.20434604 0.27079816        nan        nan 0.27475983 0.25197719
#         nan        nan 0.21871784 0.19824237        nan        nan
#  0.24370047 0.21982852        nan        nan 0.24291586 0.26858224
#         nan        nan 0.25065712 0.21434399        nan        nan
#  0.2227456  0.23236331        nan        nan 0.24771345 0.23444444
#         nan        nan 0.20502326 0.20735161        nan        nan
#  0.25580381 0.31228449        nan        nan 0.23068237 0.2297909
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.23092296 0.26579122        nan        nan
#  0.26435978 0.22329982        nan        nan 0.28398278 0.25959866
#         nan        nan 0.31484578 0.2429817         nan        nan
#  0.30790577 0.2311578         nan        nan 0.29787128 0.26730579
#         nan        nan 0.24774299 0.27158537        nan        nan
#  0.25609489 0.26079918        nan        nan 0.24768662 0.2568522
#         nan        nan 0.25611401 0.24409432        nan        nan
#  0.27108605 0.2886108         nan        nan 0.33646826 0.20844747]
# One or more of the test scores are non-finite: [       nan        nan 0.32127866 0.31051994        nan        nan
#  0.30371511 0.34679912        nan        nan 0.34563321 0.34918953
#         nan        nan 0.31773241 0.29847434        nan        nan
#  0.36469719 0.32551606        nan        nan 0.3487917  0.37441243
#         nan        nan 0.34128578 0.29684539        nan        nan
#  0.31696929 0.31996742        nan        nan 0.32798531 0.31870221
#         nan        nan 0.30747904 0.30518413        nan        nan
#  0.35321761 0.40819562        nan        nan 0.33699782 0.31481626
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.31404236 0.33601464        nan        nan
#  0.32525162 0.29212634        nan        nan 0.35583778 0.31895713
#         nan        nan 0.39026326 0.33895118        nan        nan
#  0.3915677  0.32074854        nan        nan 0.3937167  0.33349379
#         nan        nan 0.33515177 0.33637292        nan        nan
#  0.31817382 0.32375561        nan        nan 0.31122655 0.33633871
#         nan        nan 0.34649874 0.31399421        nan        nan
#  0.36623674 0.36005096        nan        nan 0.37899057 0.30993985]
# One or more of the test scores are non-finite: [       nan        nan 0.68565574 0.67044932        nan        nan
#  0.65180842 0.68151401        nan        nan 0.68814505 0.70379723
#         nan        nan 0.71810378 0.70033511        nan        nan
#  0.74003164 0.72452891        nan        nan 0.68909366 0.73289028
#         nan        nan 0.69065779 0.66471283        nan        nan
#  0.66802076 0.6788768         nan        nan 0.69429076 0.70429497
#         nan        nan 0.72870967 0.69364868        nan        nan
#  0.73691197 0.72677849        nan        nan 0.74212778 0.74120274
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.67886935 0.65359794        nan        nan
#  0.6839702  0.67282178        nan        nan 0.7225319  0.71601434
#         nan        nan 0.70325942 0.68489829        nan        nan
#  0.74329133 0.68848146        nan        nan 0.73516633 0.67674714
#         nan        nan 0.66911478 0.69209507        nan        nan
#  0.67701468 0.67888382        nan        nan 0.70582488 0.70711435
#         nan        nan 0.73195828 0.67760709        nan        nan
#  0.72712053 0.71012756        nan        nan 0.74079891 0.7041824 ]
#                                                                               18   \
# mean_fit_time                                                            0.019428
# std_fit_time                                                             0.001754
# mean_score_time                                                          0.009631
# std_score_time                                                           0.000661
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.826087
# split2_test_recall                                                       0.869565
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.590909
# mean_test_recall                                                         0.726877
# std_test_recall                                                          0.105115
# rank_test_recall                                                                1
# split0_test_precision                                                    0.222222
# split1_test_precision                                                        0.25
# split2_test_precision                                                    0.298507
# split3_test_precision                                                    0.238095
# split4_test_precision                                                    0.209677
# mean_test_precision                                                        0.2437
# std_test_precision                                                       0.030639
# rank_test_precision                                                            28
# split0_test_f1                                                           0.336842
# split1_test_f1                                                           0.383838
# split2_test_f1                                                           0.444444
# split3_test_f1                                                           0.348837
# split4_test_f1                                                           0.309524
# mean_test_f1                                                             0.364697
# std_test_f1                                                              0.046471
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.721661
# split1_test_roc_auc                                                       0.76074
# split2_test_roc_auc                                                      0.826087
# split3_test_roc_auc                                                      0.709581
# split4_test_roc_auc                                                      0.682089
# mean_test_roc_auc                                                        0.740032
# std_test_roc_auc                                                         0.049913
# rank_test_roc_auc                                                               5
#
#                                                                               38   \
# mean_fit_time                                                            0.019841
# std_fit_time                                                             0.001516
# mean_score_time                                                          0.009955
# std_score_time                                                           0.000236
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                       0.521739
# split2_test_recall                                                       0.869565
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.863636
# mean_test_recall                                                         0.703162
# std_test_recall                                                          0.169262
# rank_test_recall                                                                2
# split0_test_precision                                                    0.255814
# split1_test_precision                                                    0.235294
# split2_test_precision                                                    0.165289
# split3_test_precision                                                    0.189474
# split4_test_precision                                                    0.179245
# mean_test_precision                                                      0.205023
# std_test_precision                                                       0.034586
# rank_test_precision                                                            46
# split0_test_f1                                                           0.333333
# split1_test_f1                                                           0.324324
# split2_test_f1                                                           0.277778
# split3_test_f1                                                           0.305085
# split4_test_f1                                                           0.296875
# mean_test_f1                                                             0.307479
# std_test_f1                                                              0.019761
# rank_test_f1                                                                   43
# split0_test_roc_auc                                                      0.728131
# split1_test_roc_auc                                                      0.711439
# split2_test_roc_auc                                                      0.736801
# split3_test_roc_auc                                                      0.729758
# split4_test_roc_auc                                                      0.737419
# mean_test_roc_auc                                                         0.72871
# std_test_roc_auc                                                         0.009392
# rank_test_roc_auc                                                              10
#
#                                                                               14   \
# mean_fit_time                                                            0.016948
# std_fit_time                                                             0.002304
# mean_score_time                                                          0.009164
# std_score_time                                                           0.001122
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.826087
# split2_test_recall                                                       0.869565
# split3_test_recall                                                       0.695652
# split4_test_recall                                                       0.545455
# mean_test_recall                                                         0.674308
# std_test_recall                                                          0.164678
# rank_test_recall                                                                3
# split0_test_precision                                                      0.3125
# split1_test_precision                                                    0.175926
# split2_test_precision                                                    0.194175
# split3_test_precision                                                    0.231884
# split4_test_precision                                                    0.179104
# mean_test_precision                                                      0.218718
# std_test_precision                                                       0.050934
# rank_test_precision                                                            42
# split0_test_f1                                                           0.363636
# split1_test_f1                                                           0.290076
# split2_test_f1                                                            0.31746
# split3_test_f1                                                           0.347826
# split4_test_f1                                                           0.269663
# mean_test_f1                                                             0.317732
# std_test_f1                                                              0.034895
# rank_test_f1                                                                   35
# split0_test_roc_auc                                                      0.679218
# split1_test_roc_auc                                                       0.64881
# split2_test_roc_auc                                                      0.781315
# split3_test_roc_auc                                                       0.78326
# split4_test_roc_auc                                                      0.697917
# mean_test_roc_auc                                                        0.718104
# std_test_roc_auc                                                         0.054703
# rank_test_roc_auc                                                              15
#
#                                                                               46   \
# mean_fit_time                                                             0.02233
# std_fit_time                                                             0.004403
# mean_score_time                                                          0.011949
# std_score_time                                                           0.001837
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.681818
# mean_test_recall                                                         0.658103
# std_test_recall                                                          0.073713
# rank_test_recall                                                                4
# split0_test_precision                                                    0.270833
# split1_test_precision                                                    0.147368
# split2_test_precision                                                    0.346154
# split3_test_precision                                                    0.208333
# split4_test_precision                                                    0.180723
# mean_test_precision                                                      0.230682
# std_test_precision                                                       0.070544
# rank_test_precision                                                            35
# split0_test_f1                                                           0.366197
# split1_test_f1                                                           0.237288
# split2_test_f1                                                               0.48
# split3_test_f1                                                           0.315789
# split4_test_f1                                                           0.285714
# mean_test_f1                                                             0.336998
# std_test_f1                                                              0.082854
# rank_test_f1                                                                   19
# split0_test_roc_auc                                                      0.751165
# split1_test_roc_auc                                                      0.641304
# split2_test_roc_auc                                                      0.847438
# split3_test_roc_auc                                                       0.74603
# split4_test_roc_auc                                                      0.724702
# mean_test_roc_auc                                                        0.742128
# std_test_roc_auc                                                         0.065812
# rank_test_roc_auc                                                               2
#
#                                                                               23   \
# mean_fit_time                                                            0.017145
# std_fit_time                                                             0.002431
# mean_score_time                                                          0.009842
# std_score_time                                                           0.001174
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.782609
# split1_test_recall                                                       0.434783
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.681818
# mean_test_recall                                                         0.658103
# std_test_recall                                                          0.129521
# rank_test_recall                                                                4
# split0_test_precision                                                    0.285714
# split1_test_precision                                                    0.322581
# split2_test_precision                                                    0.197183
# split3_test_precision                                                    0.264706
# split4_test_precision                                                    0.272727
# mean_test_precision                                                      0.268582
# std_test_precision                                                        0.04084
# rank_test_precision                                                            12
# split0_test_f1                                                           0.418605
# split1_test_f1                                                            0.37037
# split2_test_f1                                                           0.297872
# split3_test_f1                                                           0.395604
# split4_test_f1                                                            0.38961
# mean_test_f1                                                             0.374412
# std_test_f1                                                               0.04125
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.832816
# split1_test_roc_auc                                                      0.734213
# split2_test_roc_auc                                                      0.633411
# split3_test_roc_auc                                                      0.741474
# split4_test_roc_auc                                                      0.722538
# mean_test_roc_auc                                                         0.73289
# std_test_roc_auc                                                         0.063346
# rank_test_roc_auc                                                               8
#
#                                                                               19   \
# mean_fit_time                                                            0.018974
# std_fit_time                                                             0.003045
# mean_score_time                                                          0.009331
# std_score_time                                                           0.000917
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.565217
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.695652
# split4_test_recall                                                       0.590909
# mean_test_recall                                                         0.639921
# std_test_recall                                                          0.053563
# rank_test_recall                                                                6
# split0_test_precision                                                    0.205128
# split1_test_precision                                                    0.203125
# split2_test_precision                                                    0.294118
# split3_test_precision                                                    0.216216
# split4_test_precision                                                    0.180556
# mean_test_precision                                                      0.219829
# std_test_precision                                                       0.038909
# rank_test_precision                                                            41
# split0_test_f1                                                           0.316832
# split1_test_f1                                                           0.298851
# split2_test_f1                                                           0.405405
# split3_test_f1                                                           0.329897
# split4_test_f1                                                           0.276596
# mean_test_f1                                                             0.325516
# std_test_f1                                                              0.043775
# rank_test_f1                                                                   26
# split0_test_roc_auc                                                      0.707169
# split1_test_roc_auc                                                       0.70471
# split2_test_roc_auc                                                      0.777045
# split3_test_roc_auc                                                      0.744598
# split4_test_roc_auc                                                      0.689123
# mean_test_roc_auc                                                        0.724529
# std_test_roc_auc                                                         0.031964
# rank_test_roc_auc                                                              13
#
#                                                                               43   \
# mean_fit_time                                                            0.022466
# std_fit_time                                                             0.003665
# mean_score_time                                                          0.012691
# std_score_time                                                           0.002635
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.565217
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.590909
# mean_test_recall                                                         0.631225
# std_test_recall                                                          0.060947
# rank_test_recall                                                                7
# split0_test_precision                                                    0.202381
# split1_test_precision                                                    0.270833
# split2_test_precision                                                    0.466667
# split3_test_precision                                                    0.326087
# split4_test_precision                                                    0.295455
# mean_test_precision                                                      0.312284
# std_test_precision                                                       0.087298
# rank_test_precision                                                             3
# split0_test_f1                                                           0.317757
# split1_test_f1                                                           0.366197
# split2_test_f1                                                           0.528302
# split3_test_f1                                                           0.434783
# split4_test_f1                                                           0.393939
# mean_test_f1                                                             0.408196
# std_test_f1                                                              0.071104
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.679607
# split1_test_roc_auc                                                      0.694488
# split2_test_roc_auc                                                      0.780021
# split3_test_roc_auc                                                      0.777532
# split4_test_roc_auc                                                      0.702246
# mean_test_roc_auc                                                        0.726778
# std_test_roc_auc                                                         0.043082
# rank_test_roc_auc                                                              12
#
#                                                                               15   \
# mean_fit_time                                                            0.018428
# std_fit_time                                                             0.000796
# mean_score_time                                                          0.009275
# std_score_time                                                           0.001028
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.826087
# split3_test_recall                                                       0.652174
# split4_test_recall                                                            0.5
# mean_test_recall                                                         0.630435
# std_test_recall                                                          0.109992
# rank_test_recall                                                                8
# split0_test_precision                                                    0.236364
# split1_test_precision                                                    0.241379
# split2_test_precision                                                        0.19
# split3_test_precision                                                    0.168539
# split4_test_precision                                                     0.15493
# mean_test_precision                                                      0.198242
# std_test_precision                                                       0.035043
# rank_test_precision                                                            48
# split0_test_f1                                                           0.333333
# split1_test_f1                                                           0.345679
# split2_test_f1                                                           0.308943
# split3_test_f1                                                           0.267857
# split4_test_f1                                                           0.236559
# mean_test_f1                                                             0.298474
# std_test_f1                                                              0.040802
# rank_test_f1                                                                   46
# split0_test_roc_auc                                                      0.711568
# split1_test_roc_auc                                                      0.677277
# split2_test_roc_auc                                                      0.762681
# split3_test_roc_auc                                                      0.695522
# split4_test_roc_auc                                                      0.654627
# mean_test_roc_auc                                                        0.700335
# std_test_roc_auc                                                         0.036489
# rank_test_roc_auc                                                              24
#
#                                                                               22   \
# mean_fit_time                                                            0.018204
# std_fit_time                                                              0.00263
# mean_score_time                                                          0.009122
# std_score_time                                                           0.000361
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.478261
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.590909
# mean_test_recall                                                          0.62253
# std_test_recall                                                          0.081714
# rank_test_recall                                                                9
# split0_test_precision                                                    0.235294
# split1_test_precision                                                    0.180328
# split2_test_precision                                                    0.280702
# split3_test_precision                                                    0.294118
# split4_test_precision                                                    0.224138
# mean_test_precision                                                      0.242916
# std_test_precision                                                       0.040933
# rank_test_precision                                                            30
# split0_test_f1                                                           0.351648
# split1_test_f1                                                           0.261905
# split2_test_f1                                                                0.4
# split3_test_f1                                                           0.405405
# split4_test_f1                                                              0.325
# mean_test_f1                                                             0.348792
# std_test_f1                                                              0.052822
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.713121
# split1_test_roc_auc                                                      0.611801
# split2_test_roc_auc                                                      0.728131
# split3_test_roc_auc                                                       0.73887
# split4_test_roc_auc                                                      0.653544
# mean_test_roc_auc                                                        0.689094
# std_test_roc_auc                                                         0.048614
# rank_test_roc_auc                                                              29
#
#                                                                               143  \
# mean_fit_time                                                            0.017013
# std_fit_time                                                             0.001482
# mean_score_time                                                          0.005992
# std_score_time                                                           0.000309
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                       0.521739
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.521739
# split4_test_recall                                                       0.681818
# mean_test_recall                                                         0.614625
# std_test_recall                                                          0.077131
# rank_test_recall                                                               10
# split0_test_precision                                                    0.182927
# split1_test_precision                                                    0.230769
# split2_test_precision                                                    0.222222
# split3_test_precision                                                    0.164384
# split4_test_precision                                                    0.241935
# mean_test_precision                                                      0.208447
# std_test_precision                                                       0.029673
# rank_test_precision                                                            44
# split0_test_f1                                                           0.285714
# split1_test_f1                                                               0.32
# split2_test_f1                                                           0.336842
# split3_test_f1                                                               0.25
# split4_test_f1                                                           0.357143
# mean_test_f1                                                              0.30994
# std_test_f1                                                              0.038033
# rank_test_f1                                                                   42
# split0_test_roc_auc                                                      0.668996
# split1_test_roc_auc                                                      0.696299
# split2_test_roc_auc                                                      0.713898
# split3_test_roc_auc                                                      0.654517
# split4_test_roc_auc                                                      0.787202
# mean_test_roc_auc                                                        0.704182
# std_test_roc_auc                                                         0.046376
# rank_test_roc_auc                                                              21
#
#                                                                               6    \
# mean_fit_time                                                            0.022028
# std_fit_time                                                             0.003932
# mean_score_time                                                          0.012366
# std_score_time                                                            0.00063
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# ...
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  140
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             140
#
#                                                                               56   \
# mean_fit_time                                                            0.005794
# std_fit_time                                                             0.002686
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              141
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           141
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  141
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             141
#
#                                                                               55   \
# mean_fit_time                                                            0.023829
# std_fit_time                                                              0.00256
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              142
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           142
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  142
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             142
#
#                                                                               67   \
# mean_fit_time                                                            0.026653
# std_fit_time                                                             0.004143
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              143
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           143
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  143
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             143
#
#                                                                               71
# mean_fit_time                                                            0.021393
# std_fit_time                                                             0.002806
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              144
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           144
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  144
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             144
#
# [43 rows x 144 columns]

# %%
clf = gscv.best_estimator_.steps[2][1]
viz = dtreeviz(clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"],
             fancy=False,
               scale=1.5
              )

viz
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
# Calculate the feature importance
dt_importances = clf.feature_importances_
dt_importances_df = pd.DataFrame(data = dt_importances, index = X.columns, columns=["importance"])  
dt_importances_df = dt_importances_df.sort_values(by="importance", ascending=False)
dt_importances_df[0:10]
# Out:
#                        importance
# Dinophysis fortii        0.271930
# wind strength            0.229401
# salinity                 0.182300
# T                        0.170050
# precipitation            0.082756
# air temp                 0.048703
# sun [h]                  0.014859
# DSP                      0.000000
# Dinophysis caudata       0.000000
# Phalacroma rotundatum    0.000000

# %% [markdown]
# ### Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', RandomForestClassifier())
])

parameters = {
              'clf__n_estimators': [300,500,800],
              'clf__criterion': ['gini', 'entropy'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
               'smt__sampling_strategy': [ 0.1, 0.2],
               'under__sampling_strategy': [0.7, 0.8],
                'smt__k_neighbors': [3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="recall",
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
pd.set_option("display.max_rows", None)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# 360 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 268, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 226, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 394, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 534, in check_sampling_strategy
#     _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 373, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
# One or more of the test scores are non-finite: [       nan        nan 0.65652174 0.66600791        nan        nan
#  0.6486166  0.69288538        nan        nan 0.63913043 0.68339921
#         nan        nan 0.65731225 0.70118577        nan        nan
#  0.66640316 0.65770751        nan        nan 0.64031621 0.63952569
#         nan        nan 0.6229249  0.66600791        nan        nan
#  0.68379447 0.70039526        nan        nan 0.65770751 0.67509881
#         nan        nan 0.61462451 0.68379447        nan        nan
#  0.68379447 0.67509881        nan        nan 0.67470356 0.66600791
#         nan        nan 0.70079051 0.66600791        nan        nan
#  0.63992095 0.70118577        nan        nan 0.63992095 0.64822134
#         nan        nan 0.68379447 0.69249012        nan        nan
#  0.64782609 0.72687747        nan        nan 0.67470356 0.66600791
#         nan        nan 0.68458498 0.67509881        nan        nan
#  0.64901186 0.69209486        nan        nan 0.6312253  0.67470356
#         nan        nan 0.66600791 0.70988142        nan        nan
#  0.64782609 0.67509881        nan        nan 0.63043478 0.70988142
#         nan        nan 0.65731225 0.6486166         nan        nan
#  0.63992095 0.68379447        nan        nan 0.68339921 0.69249012
#         nan        nan 0.65770751 0.70158103        nan        nan
#  0.67549407 0.70118577        nan        nan 0.63992095 0.68300395
#         nan        nan 0.63083004 0.67509881        nan        nan
#  0.69209486 0.69209486        nan        nan 0.67470356 0.7173913
#         nan        nan 0.63083004 0.68339921        nan        nan
#  0.66640316 0.71897233        nan        nan 0.66600791 0.73636364]
# One or more of the test scores are non-finite: [       nan        nan 0.49623656 0.4553684         nan        nan
#  0.45676272 0.45410394        nan        nan 0.49329776 0.46695271
#         nan        nan 0.46973658 0.46121745        nan        nan
#  0.4916192  0.40338425        nan        nan 0.48965839 0.44142857
#         nan        nan 0.47463651 0.43248139        nan        nan
#  0.49683393 0.42020615        nan        nan 0.46434607 0.4496513
#         nan        nan 0.43449074 0.46595684        nan        nan
#  0.52065131 0.44074799        nan        nan 0.45695186 0.40642857
#         nan        nan 0.50319219 0.42444361        nan        nan
#  0.50432692 0.40701134        nan        nan 0.4712963  0.43680619
#         nan        nan 0.48586016 0.46147455        nan        nan
#  0.46920707 0.4465163         nan        nan 0.5101737  0.42324577
#         nan        nan 0.46037294 0.48832913        nan        nan
#  0.48408419 0.42758946        nan        nan 0.49727027 0.47403272
#         nan        nan 0.44798656 0.45310409        nan        nan
#  0.49356643 0.43610858        nan        nan 0.48761538 0.41406657
#         nan        nan 0.4739508  0.41075415        nan        nan
#  0.46297651 0.39314574        nan        nan 0.50845434 0.42564365
#         nan        nan 0.46239424 0.44207516        nan        nan
#  0.48864097 0.45793067        nan        nan 0.45920635 0.44202714
#         nan        nan 0.47708374 0.46976354        nan        nan
#  0.49227326 0.39917967        nan        nan 0.4674033  0.45730868
#         nan        nan 0.47696257 0.43077983        nan        nan
#  0.45009854 0.42879908        nan        nan 0.49465351 0.49134924]
# One or more of the test scores are non-finite: [       nan        nan 0.562503   0.53715069        nan        nan
#  0.53286765 0.54526012        nan        nan 0.55283092 0.54772796
#         nan        nan 0.54202521 0.54747163        nan        nan
#  0.56440204 0.49970978        nan        nan 0.55369321 0.51904185
#         nan        nan 0.53829912 0.52313975        nan        nan
#  0.57358443 0.52016173        nan        nan 0.54290966 0.53620587
#         nan        nan 0.50432888 0.55126584        nan        nan
#  0.58575858 0.52948252        nan        nan 0.53842126 0.50361278
#         nan        nan 0.58031873 0.51573075        nan        nan
#  0.56213316 0.51298213        nan        nan 0.53989793 0.51754971
#         nan        nan 0.5649134  0.5507628         nan        nan
#  0.54286443 0.55230152        nan        nan 0.57795658 0.51530037
#         nan        nan 0.5480543  0.56200965        nan        nan
#  0.54650893 0.52533606        nan        nan 0.54981146 0.549678
#         nan        nan 0.53290063 0.54912827        nan        nan
#  0.55509348 0.52592263        nan        nan 0.54533189 0.51659742
#         nan        nan 0.54999331 0.49915902        nan        nan
#  0.53349656 0.49680106        nan        nan 0.57342797 0.52645589
#         nan        nan 0.54094702 0.53907656        nan        nan
#  0.56671318 0.54912578        nan        nan 0.5291837  0.53212197
#         nan        nan 0.54210212 0.54735464        nan        nan
#  0.57004391 0.50316036        nan        nan 0.54934871 0.55671108
#         nan        nan 0.540139   0.52746823        nan        nan
#  0.53596551 0.53337355        nan        nan 0.56053741 0.58680737]
# One or more of the test scores are non-finite: [       nan        nan 0.87321685 0.87215122        nan        nan
#  0.87605071 0.86641837        nan        nan 0.86049995 0.86556366
#         nan        nan 0.8591937  0.8782835         nan        nan
#  0.88363445 0.84746633        nan        nan 0.85982797 0.86449709
#         nan        nan 0.8506879  0.85615389        nan        nan
#  0.87448514 0.86263329        nan        nan 0.86431984 0.87359668
#         nan        nan 0.85956538 0.85576161        nan        nan
#  0.85961425 0.85416052        nan        nan 0.8718173  0.86442426
#         nan        nan 0.86705967 0.86727828        nan        nan
#  0.86990349 0.86169538        nan        nan 0.86611891 0.84758992
#         nan        nan 0.86724965 0.85273812        nan        nan
#  0.85905734 0.87352747        nan        nan 0.87365887 0.85405534
#         nan        nan 0.86455974 0.86760048        nan        nan
#  0.86873006 0.86372544        nan        nan 0.8805184  0.8759047
#         nan        nan 0.85549058 0.86520652        nan        nan
#  0.85996442 0.85891297        nan        nan 0.86749722 0.8710485
#         nan        nan 0.85911073 0.85961055        nan        nan
#  0.86000496 0.86431398        nan        nan 0.87041685 0.84355562
#         nan        nan 0.86768163 0.86733112        nan        nan
#  0.86989821 0.85761751        nan        nan 0.86956253 0.86443244
#         nan        nan 0.87704502 0.85227637        nan        nan
#  0.86774983 0.84942057        nan        nan 0.86997048 0.87271464
#         nan        nan 0.87586748 0.85809967        nan        nan
#  0.87190484 0.86916646        nan        nan 0.87084076 0.87240306]
#                                                                               143  \
# mean_fit_time                                                            1.995318
# std_fit_time                                                             0.124769
# mean_score_time                                                          0.236079
# std_score_time                                                           0.026888
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       800
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.695652
# split2_test_recall                                                        0.73913
# split3_test_recall                                                       0.869565
# split4_test_recall                                                       0.681818
# mean_test_recall                                                         0.736364
# std_test_recall                                                           0.06934
# rank_test_recall                                                                1
# split0_test_precision                                                    0.592593
# split1_test_precision                                                    0.432432
# split2_test_precision                                                         0.5
# split3_test_precision                                                    0.526316
# split4_test_precision                                                    0.405405
# mean_test_precision                                                      0.491349
# std_test_precision                                                       0.066941
# rank_test_precision                                                            14
# split0_test_f1                                                               0.64
# split1_test_f1                                                           0.533333
# split2_test_f1                                                           0.596491
# split3_test_f1                                                           0.655738
# split4_test_f1                                                           0.508475
# mean_test_f1                                                             0.586807
# std_test_f1                                                              0.057741
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.853131
# split1_test_roc_auc                                                      0.860119
# split2_test_roc_auc                                                      0.879658
# split3_test_roc_auc                                                      0.930227
# split4_test_roc_auc                                                       0.83888
# mean_test_roc_auc                                                        0.872403
# std_test_roc_auc                                                         0.031756
# rank_test_roc_auc                                                              14
#
#                                                                               67   \
# mean_fit_time                                                            2.572456
# std_fit_time                                                              0.01545
# mean_score_time                                                          0.355554
# std_score_time                                                           0.003191
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       800
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.590909
# mean_test_recall                                                         0.726877
# std_test_recall                                                          0.080698
# rank_test_recall                                                                2
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.444444
# split2_test_precision                                                    0.418605
# split3_test_precision                                                    0.487179
# split4_test_precision                                                    0.382353
# mean_test_precision                                                      0.446516
# std_test_precision                                                       0.043392
# rank_test_precision                                                            50
# split0_test_f1                                                           0.596491
# split1_test_f1                                                           0.542373
# split2_test_f1                                                           0.545455
# split3_test_f1                                                           0.612903
# split4_test_f1                                                           0.464286
# mean_test_f1                                                             0.552302
# std_test_f1                                                              0.051995
# rank_test_f1                                                                   19
# split0_test_roc_auc                                                      0.866977
# split1_test_roc_auc                                                      0.857402
# split2_test_roc_auc                                                      0.901915
# split3_test_roc_auc                                                       0.91031
# split4_test_roc_auc                                                      0.831034
# mean_test_roc_auc                                                        0.873527
# std_test_roc_auc                                                         0.029215
# rank_test_roc_auc                                                              11
#
#                                                                               139  \
# mean_fit_time                                                            2.657745
# std_fit_time                                                             0.082195
# mean_score_time                                                           0.38018
# std_score_time                                                           0.009807
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       800
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.869565
# split4_test_recall                                                       0.681818
# mean_test_recall                                                         0.718972
# std_test_recall                                                          0.076952
# rank_test_recall                                                                3
# split0_test_precision                                                    0.470588
# split1_test_precision                                                    0.390244
# split2_test_precision                                                         0.5
# split3_test_precision                                                    0.408163
# split4_test_precision                                                       0.375
# mean_test_precision                                                      0.428799
# std_test_precision                                                       0.048213
# rank_test_precision                                                            60
# split0_test_f1                                                           0.561404
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.566038
# split3_test_f1                                                           0.555556
# split4_test_f1                                                           0.483871
# mean_test_f1                                                             0.533374
# std_test_f1                                                              0.034377
# rank_test_f1                                                                   49
# split0_test_roc_auc                                                      0.874224
# split1_test_roc_auc                                                      0.854684
# split2_test_roc_auc                                                      0.873447
# split3_test_roc_auc                                                      0.911091
# split4_test_roc_auc                                                      0.832386
# mean_test_roc_auc                                                        0.869166
# std_test_roc_auc                                                         0.025939
# rank_test_roc_auc                                                              25
#
#                                                                               131  \
# mean_fit_time                                                            1.503713
# std_fit_time                                                             0.006997
# mean_score_time                                                          0.236797
# std_score_time                                                            0.00132
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.782609
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.913043
# split4_test_recall                                                            0.5
# mean_test_recall                                                         0.717391
# std_test_recall                                                          0.134712
# rank_test_recall                                                                4
# split0_test_precision                                                      0.5625
# split1_test_precision                                                    0.432432
# split2_test_precision                                                    0.470588
# split3_test_precision                                                    0.477273
# split4_test_precision                                                     0.34375
# mean_test_precision                                                      0.457309
# std_test_precision                                                       0.070929
# rank_test_precision                                                            41
# split0_test_f1                                                           0.654545
# split1_test_f1                                                           0.533333
# split2_test_f1                                                           0.561404
# split3_test_f1                                                           0.626866
# split4_test_f1                                                           0.407407
# mean_test_f1                                                             0.556711
# std_test_f1                                                              0.086433
# rank_test_f1                                                                   15
# split0_test_roc_auc                                                      0.848602
# split1_test_roc_auc                                                      0.863095
# split2_test_roc_auc                                                      0.887422
# split3_test_roc_auc                                                      0.935043
# split4_test_roc_auc                                                       0.82941
# mean_test_roc_auc                                                        0.872715
# std_test_roc_auc                                                          0.03647
# rank_test_roc_auc                                                              13
#
#                                                                               87   \
# mean_fit_time                                                            1.783684
# std_fit_time                                                             0.016213
# mean_score_time                                                          0.238706
# std_score_time                                                           0.002972
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.636364
# mean_test_recall                                                         0.709881
# std_test_recall                                                           0.07359
# rank_test_recall                                                                5
# split0_test_precision                                                    0.447368
# split1_test_precision                                                    0.358974
# split2_test_precision                                                    0.529412
# split3_test_precision                                                    0.391304
# split4_test_precision                                                    0.538462
# mean_test_precision                                                      0.453104
# std_test_precision                                                       0.071863
# rank_test_precision                                                            46
# split0_test_f1                                                           0.557377
# split1_test_f1                                                           0.451613
# split2_test_f1                                                           0.631579
# split3_test_f1                                                           0.521739
# split4_test_f1                                                           0.583333
# mean_test_f1                                                             0.549128
# std_test_f1                                                              0.060491
# rank_test_f1                                                                   26
# split0_test_roc_auc                                                      0.821429
# split1_test_roc_auc                                                      0.839933
# split2_test_roc_auc                                                      0.916408
# split3_test_roc_auc                                                      0.889091
# split4_test_roc_auc                                                      0.859172
# mean_test_roc_auc                                                        0.865207
# std_test_roc_auc                                                         0.034011
# rank_test_roc_auc                                                              38
#
#                                                                               95   \
# mean_fit_time                                                            2.896027
# std_fit_time                                                             0.040163
# mean_score_time                                                          0.368994
# std_score_time                                                           0.004635
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       800
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.913043
# split4_test_recall                                                       0.636364
# mean_test_recall                                                         0.709881
# std_test_recall                                                          0.107073
# rank_test_recall                                                                5
# split0_test_precision                                                    0.516129
# split1_test_precision                                                    0.388889
# split2_test_precision                                                    0.421053
# split3_test_precision                                                    0.344262
# split4_test_precision                                                         0.4
# mean_test_precision                                                      0.414067
# std_test_precision                                                       0.056868
# rank_test_precision                                                            66
# split0_test_f1                                                           0.592593
# split1_test_f1                                                           0.474576
# split2_test_f1                                                            0.52459
# split3_test_f1                                                                0.5
# split4_test_f1                                                           0.491228
# mean_test_f1                                                             0.516597
# std_test_f1                                                              0.041289
# rank_test_f1                                                                   63
# split0_test_roc_auc                                                      0.898033
# split1_test_roc_auc                                                       0.85352
# split2_test_roc_auc                                                      0.873059
# split3_test_roc_auc                                                      0.904061
# split4_test_roc_auc                                                      0.826569
# mean_test_roc_auc                                                        0.871049
# std_test_roc_auc                                                         0.028663
# rank_test_roc_auc                                                              18
#
#                                                                               111  \
# mean_fit_time                                                            1.392211
# std_fit_time                                                             0.004525
# mean_score_time                                                          0.264643
# std_score_time                                                            0.00569
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                       0.565217
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.913043
# split4_test_recall                                                       0.681818
# mean_test_recall                                                         0.701581
# std_test_recall                                                          0.115046
# rank_test_recall                                                                7
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.361111
# split2_test_precision                                                    0.470588
# split3_test_precision                                                      0.4375
# split4_test_precision                                                    0.441176
# mean_test_precision                                                      0.442075
# std_test_precision                                                       0.046358
# rank_test_precision                                                            51
# split0_test_f1                                                           0.566038
# split1_test_f1                                                           0.440678
# split2_test_f1                                                           0.561404
# split3_test_f1                                                           0.591549
# split4_test_f1                                                           0.535714
# mean_test_f1                                                             0.539077
# std_test_f1                                                              0.052292
# rank_test_f1                                                                   42
# split0_test_roc_auc                                                       0.85986
# split1_test_roc_auc                                                      0.845367
# split2_test_roc_auc                                                      0.869953
# split3_test_roc_auc                                                      0.931658
# split4_test_roc_auc                                                      0.829816
# mean_test_roc_auc                                                        0.867331
# std_test_roc_auc                                                         0.034901
# rank_test_roc_auc                                                              31
#
#                                                                               55   \
# mean_fit_time                                                            0.968741
# std_fit_time                                                             0.010063
# mean_score_time                                                          0.142196
# std_score_time                                                            0.00229
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                       0.608696
# split2_test_recall                                                        0.73913
# split3_test_recall                                                       0.869565
# split4_test_recall                                                       0.636364
# mean_test_recall                                                         0.701186
# std_test_recall                                                          0.094816
# rank_test_recall                                                                8
# split0_test_precision                                                     0.46875
# split1_test_precision                                                    0.297872
# split2_test_precision                                                       0.425
# split3_test_precision                                                    0.454545
# split4_test_precision                                                    0.388889
# mean_test_precision                                                      0.407011
# std_test_precision                                                       0.061048
# rank_test_precision                                                            68
# split0_test_f1                                                           0.545455
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.539683
# split3_test_f1                                                           0.597015
# split4_test_f1                                                           0.482759
# mean_test_f1                                                             0.512982
# std_test_f1                                                              0.067093
# rank_test_f1                                                                   66
# split0_test_roc_auc                                                       0.83631
# split1_test_roc_auc                                                       0.83191
# split2_test_roc_auc                                                      0.880952
# split3_test_roc_auc                                                       0.91799
# split4_test_roc_auc                                                      0.841315
# mean_test_roc_auc                                                        0.861695
# std_test_roc_auc                                                         0.033127
# rank_test_roc_auc                                                              47
#
#                                                                               15   \
# mean_fit_time                                                            1.248677
# std_fit_time                                                             0.037096
# mean_score_time                                                          0.213235
# std_score_time                                                           0.007423
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                       0.565217
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.869565
# split4_test_recall                                                       0.636364
# mean_test_recall                                                         0.701186
# std_test_recall                                                          0.109611
# rank_test_recall                                                                8
# split0_test_precision                                                    0.555556
# split1_test_precision                                                    0.393939
# split2_test_precision                                                         0.6
# split3_test_precision                                                    0.344828
# split4_test_precision                                                    0.411765
# mean_test_precision                                                      0.461217
# std_test_precision                                                        0.09867
# rank_test_precision                                                            37
# split0_test_f1                                                                0.6
# split1_test_f1                                                           0.464286
# split2_test_f1                                                           0.679245
# split3_test_f1                                                           0.493827
# split4_test_f1                                                                0.5
# mean_test_f1                                                             0.547472
# std_test_f1                                                              0.080218
# rank_test_f1                                                                   30
# split0_test_roc_auc                                                      0.897386
# split1_test_roc_auc                                                      0.852743
# split2_test_roc_auc                                                      0.904503
# split3_test_roc_auc                                                      0.888571
# split4_test_roc_auc                                                      0.848214
# mean_test_roc_auc                                                        0.878283
# std_test_roc_auc                                                         0.023301
# rank_test_roc_auc                                                               3
#
#                                                                               115  \
# mean_fit_time                                                             2.38443
# std_fit_time                                                             0.035989
# mean_score_time                                                          0.402493
# std_score_time                                                              0.022
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       800
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.913043
# split4_test_recall                                                       0.636364
# mean_test_recall                                                         0.701186
# std_test_recall                                                          0.116305
# rank_test_recall                                                                8
# split0_test_precision                                                     0.53125
# split1_test_precision                                                    0.341463
# split2_test_precision                                                    0.451613
# split3_test_precision                                                    0.446809
# split4_test_precision                                                    0.518519
# mean_test_precision                                                      0.457931
# std_test_precision                                                       0.067491
# rank_test_precision                                                            40
# split0_test_f1                                                           0.618182
# split1_test_f1                                                             0.4375
# split2_test_f1                                                           0.518519
# split3_test_f1                                                                0.6
# split4_test_f1                                                           0.571429
# mean_test_f1                                                             0.549126
# std_test_f1                                                              0.065194
# rank_test_f1                                                                   27
# split0_test_roc_auc                                                      0.833722
# split1_test_roc_auc                                                      0.839803
# split2_test_roc_auc                                                      0.848473
# split3_test_roc_auc                                                       0.91057
# split4_test_roc_auc                                                      0.855519
# mean_test_roc_auc                                                        0.857618
# std_test_roc_auc                                                         0.027497
# rank_test_roc_auc                                                              60
#
#                                                                               50   \
# mean_fit_time                                                            1.034407
# std_fit_time                                                             0.027236
# mean_score_time                                                          0.138005
# std_score_time                                                           0.003949
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.608696
# split2_test_recall                                                        0.73913
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.590909
# mean_test_recall                                                         0.700791
# std_test_recall                                                          0.088538
# rank_test_recall                                                               11
# split0_test_precision                                                     0.62963
# ...
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  114
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             114
#
#                                                                               28   \
# mean_fit_time                                                             0.00317
# std_fit_time                                                             0.000212
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              141
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                            76
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                   83
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             107
#
#                                                                               29   \
# mean_fit_time                                                            0.004062
# std_fit_time                                                              0.00175
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              142
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                            92
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  106
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             127
#
#                                                                               101  \
# mean_fit_time                                                            0.004208
# std_fit_time                                                             0.000748
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              143
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           129
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  130
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             128
#
#                                                                               0
# mean_fit_time                                                            0.001849
# std_fit_time                                                             0.000081
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              144
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           144
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  144
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             144
#
# [43 rows x 144 columns]

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Calculate the feature importance
clf = gscv.best_estimator_.steps[2][1]
rf_importances = clf.feature_importances_
rf_importances_df = pd.DataFrame(data = rf_importances, index = X.columns, columns=["importance"])  
rf_importances_df = rf_importances_df.sort_values(by="importance", ascending=False)
rf_importances_df
# Out:
#                        importance
# salinity                 0.109281
# Dinophysis fortii        0.105877
# DSP                      0.105229
# precipitation            0.095144
# Soca                     0.089780
# air temp                 0.081508
# wind strength            0.077183
# T                        0.074700
# sun [h]                  0.072458
# month                    0.047875
# Dinophysis caudata       0.042722
# Phalacroma rotundatum    0.036669
# Dinophysis tripos        0.031337
# Dinophysis sacculus      0.030237

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

rf = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf, X, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
# Out:
# Text(0.5, 1.0, 'Permutation Importance Random Forest')

# %%
# Get feature importance with SHAP
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)
RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

# one-hot encoding of month feature
Xohe = pd.get_dummies(X, columns=["month"])

X_display = Xohe.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xohe)
Xsc = pd.DataFrame(scaled_array, columns=Xohe.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE()),
    ('under', RandomUnderSampler()),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.4, 0.5, 0.6],
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
             }
nfolds = 3
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "recall")
resultsGSCV = gscv.fit(Xsc, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
#                                                                               5    \
# mean_fit_time                                                            0.272227
# std_fit_time                                                              0.05122
# mean_score_time                                                          0.010961
# std_score_time                                                           0.000239
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.657895
# split1_test_recall                                                       0.710526
# split2_test_recall                                                       0.815789
# mean_test_recall                                                          0.72807
# std_test_recall                                                          0.065643
# rank_test_recall                                                                1
# split0_test_precision                                                    0.204918
# split1_test_precision                                                    0.191489
# split2_test_precision                                                    0.213793
# mean_test_precision                                                        0.2034
# std_test_precision                                                       0.009169
# rank_test_precision                                                           180
# split0_test_f1                                                             0.3125
# split1_test_f1                                                           0.301676
# split2_test_f1                                                           0.338798
# mean_test_f1                                                             0.317658
# std_test_f1                                                              0.015588
# rank_test_f1                                                                  105
# split0_test_roc_auc                                                      0.688769
# split1_test_roc_auc                                                       0.69234
# split2_test_roc_auc                                                      0.756838
# mean_test_roc_auc                                                        0.712649
# std_test_roc_auc                                                          0.03128
# rank_test_roc_auc                                                              37
#
#                                                                               194  \
# mean_fit_time                                                            0.592832
# std_fit_time                                                             0.403011
# mean_score_time                                                          0.012459
# std_score_time                                                           0.000749
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.552632
# split1_test_recall                                                       0.657895
# split2_test_recall                                                       0.815789
# mean_test_recall                                                         0.675439
# std_test_recall                                                          0.108148
# rank_test_recall                                                                2
# split0_test_precision                                                        0.21
# split1_test_precision                                                    0.181159
# split2_test_precision                                                     0.22963
# mean_test_precision                                                       0.20693
# std_test_precision                                                       0.019907
# rank_test_precision                                                           179
# split0_test_f1                                                           0.304348
# split1_test_f1                                                           0.284091
# split2_test_f1                                                           0.358382
# mean_test_f1                                                             0.315607
# std_test_f1                                                              0.031357
# rank_test_f1                                                                  110
# split0_test_roc_auc                                                      0.713111
# split1_test_roc_auc                                                      0.623402
# split2_test_roc_auc                                                      0.781409
# mean_test_roc_auc                                                        0.705974
# std_test_roc_auc                                                         0.064703
# rank_test_roc_auc                                                              46
#
#                                                                               76   \
# mean_fit_time                                                            0.371376
# std_fit_time                                                             0.075185
# mean_score_time                                                          0.011988
# std_score_time                                                           0.000723
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.578947
# split1_test_recall                                                       0.473684
# split2_test_recall                                                       0.921053
# mean_test_recall                                                         0.657895
# std_test_recall                                                          0.190978
# rank_test_recall                                                                3
# split0_test_precision                                                    0.205607
# split1_test_precision                                                         0.2
# split2_test_precision                                                    0.198864
# mean_test_precision                                                       0.20149
# std_test_precision                                                       0.002948
# rank_test_precision                                                           183
# split0_test_f1                                                           0.303448
# split1_test_f1                                                            0.28125
# split2_test_f1                                                           0.327103
# mean_test_f1                                                             0.303934
# std_test_f1                                                              0.018722
# rank_test_f1                                                                  133
# split0_test_roc_auc                                                      0.657613
# split1_test_roc_auc                                                      0.607331
# split2_test_roc_auc                                                      0.714394
# mean_test_roc_auc                                                        0.659779
# std_test_roc_auc                                                         0.043735
# rank_test_roc_auc                                                             157
#
#                                                                               176  \
# mean_fit_time                                                            1.623389
# std_fit_time                                                             1.139726
# mean_score_time                                                          0.015012
# std_score_time                                                           0.003927
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.710526
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.684211
# mean_test_recall                                                         0.640351
# std_test_recall                                                          0.081348
# rank_test_recall                                                                4
# split0_test_precision                                                    0.221311
# split1_test_precision                                                     0.25974
# split2_test_precision                                                        0.26
# mean_test_precision                                                      0.247017
# std_test_precision                                                       0.018177
# rank_test_precision                                                           106
# split0_test_f1                                                             0.3375
# split1_test_f1                                                           0.347826
# split2_test_f1                                                           0.376812
# mean_test_f1                                                             0.354046
# std_test_f1                                                              0.016641
# rank_test_f1                                                                   27
# split0_test_roc_auc                                                      0.659586
# split1_test_roc_auc                                                      0.630075
# split2_test_roc_auc                                                      0.787304
# mean_test_roc_auc                                                        0.692322
# std_test_roc_auc                                                         0.068235
# rank_test_roc_auc                                                              74
#
#                                                                               38   \
# mean_fit_time                                                            0.360524
# std_fit_time                                                             0.056196
# mean_score_time                                                          0.011054
# std_score_time                                                           0.000173
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.684211
# split1_test_recall                                                       0.473684
# split2_test_recall                                                       0.763158
# mean_test_recall                                                         0.640351
# std_test_recall                                                          0.122179
# rank_test_recall                                                                4
# split0_test_precision                                                    0.220339
# split1_test_precision                                                    0.272727
# split2_test_precision                                                    0.179012
# mean_test_precision                                                      0.224026
# std_test_precision                                                       0.038348
# rank_test_precision                                                           158
# split0_test_f1                                                           0.333333
# split1_test_f1                                                           0.346154
# split2_test_f1                                                               0.29
# mean_test_f1                                                             0.323162
# std_test_f1                                                              0.024026
# rank_test_f1                                                                   87
# split0_test_roc_auc                                                      0.655216
# split1_test_roc_auc                                                      0.694925
# split2_test_roc_auc                                                      0.662186
# mean_test_roc_auc                                                        0.670776
# std_test_roc_auc                                                         0.017311
# rank_test_roc_auc                                                             129
#
#                                                                               134  \
# mean_fit_time                                                            0.405942
# std_fit_time                                                             0.245351
# mean_score_time                                                          0.015724
# std_score_time                                                           0.001951
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.657895
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.736842
# mean_test_recall                                                         0.640351
# std_test_recall                                                          0.086838
# rank_test_recall                                                                4
# split0_test_precision                                                         0.2
# split1_test_precision                                                    0.196078
# split2_test_precision                                                    0.459016
# mean_test_precision                                                      0.285032
# std_test_precision                                                       0.123036
# rank_test_precision                                                            42
# split0_test_f1                                                           0.306748
# split1_test_f1                                                           0.285714
# split2_test_f1                                                           0.565657
# mean_test_f1                                                              0.38604
# std_test_f1                                                              0.127298
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.681579
# split1_test_roc_auc                                                      0.679511
# split2_test_roc_auc                                                      0.875731
# mean_test_roc_auc                                                        0.745607
# std_test_roc_auc                                                         0.092015
# rank_test_roc_auc                                                               5
#
#                                                                               23   \
# mean_fit_time                                                            0.368228
# std_fit_time                                                             0.178246
# mean_score_time                                                          0.012109
# std_score_time                                                           0.000654
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.631579
# split2_test_recall                                                       0.763158
# mean_test_recall                                                         0.631579
# std_test_recall                                                          0.107434
# rank_test_recall                                                                7
# split0_test_precision                                                    0.175926
# split1_test_precision                                                    0.172662
# split2_test_precision                                                    0.214815
# mean_test_precision                                                      0.187801
# std_test_precision                                                       0.019148
# rank_test_precision                                                           194
# split0_test_f1                                                           0.260274
# split1_test_f1                                                           0.271186
# split2_test_f1                                                            0.33526
# mean_test_f1                                                             0.288907
# std_test_f1                                                              0.033078
# rank_test_f1                                                                  157
# split0_test_roc_auc                                                      0.647556
# split1_test_roc_auc                                                      0.654793
# split2_test_roc_auc                                                      0.712932
# mean_test_roc_auc                                                         0.67176
# std_test_roc_auc                                                         0.029262
# rank_test_roc_auc                                                             126
#
#                                                                               110  \
# mean_fit_time                                                             0.38216
# std_fit_time                                                             0.157801
# mean_score_time                                                          0.011991
# std_score_time                                                           0.000242
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.526316
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.789474
# mean_test_recall                                                         0.631579
# std_test_recall                                                          0.113697
# rank_test_recall                                                                8
# split0_test_precision                                                    0.208333
# split1_test_precision                                                    0.244444
# split2_test_precision                                                    0.352941
# mean_test_precision                                                      0.268573
# std_test_precision                                                       0.061452
# rank_test_precision                                                            65
# split0_test_f1                                                           0.298507
# split1_test_f1                                                            0.34375
# split2_test_f1                                                           0.487805
# mean_test_f1                                                             0.376687
# std_test_f1                                                              0.080714
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.692481
# split1_test_roc_auc                                                      0.700141
# split2_test_roc_auc                                                      0.846255
# mean_test_roc_auc                                                        0.746293
# std_test_roc_auc                                                         0.070754
# rank_test_roc_auc                                                               4
#
#                                                                               214  \
# mean_fit_time                                                            0.567737
# std_fit_time                                                             0.253374
# mean_score_time                                                          0.009969
# std_score_time                                                            0.00188
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.578947
# split1_test_recall                                                       0.473684
# split2_test_recall                                                       0.815789
# mean_test_recall                                                         0.622807
# std_test_recall                                                          0.143066
# rank_test_recall                                                                9
# split0_test_precision                                                    0.261905
# split1_test_precision                                                    0.230769
# split2_test_precision                                                    0.267241
# mean_test_precision                                                      0.253305
# std_test_precision                                                       0.016084
# rank_test_precision                                                            94
# split0_test_f1                                                           0.360656
# split1_test_f1                                                           0.310345
# split2_test_f1                                                           0.402597
# mean_test_f1                                                             0.357866
# std_test_f1                                                              0.037714
# rank_test_f1                                                                   23
# split0_test_roc_auc                                                      0.690414
# split1_test_roc_auc                                                      0.683459
# split2_test_roc_auc                                                      0.791502
# mean_test_roc_auc                                                        0.721791
# std_test_roc_auc                                                         0.049374
# rank_test_roc_auc                                                              26
#
#                                                                               157  \
# mean_fit_time                                                            0.351601
# std_fit_time                                                             0.190478
# mean_score_time                                                          0.013218
# std_score_time                                                            0.00142
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.578947
# split1_test_recall                                                       0.605263
# split2_test_recall                                                       0.684211
# mean_test_recall                                                         0.622807
# std_test_recall                                                          0.044728
# rank_test_recall                                                                9
# split0_test_precision                                                    0.181818
# split1_test_precision                                                    0.315068
# split2_test_precision                                                    0.440678
# mean_test_precision                                                      0.312522
# std_test_precision                                                       0.105694
# rank_test_precision                                                            13
# split0_test_f1                                                            0.27673
# split1_test_f1                                                           0.414414
# split2_test_f1                                                           0.536082
# mean_test_f1                                                             0.409075
# std_test_f1                                                              0.105948
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.667951
# split1_test_roc_auc                                                      0.738534
# split2_test_roc_auc                                                      0.861064
# mean_test_roc_auc                                                         0.75585
# std_test_roc_auc                                                         0.079783
# rank_test_roc_auc                                                               2
#
#                                                                               129  \
# mean_fit_time                                                            0.905339
# std_fit_time                                                             0.305024
# mean_score_time                                                          0.015148
# std_score_time                                                           0.001623
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.605263
# split2_test_recall                                                       0.763158
# mean_test_recall                                                         0.622807
# std_test_recall                                                          0.108148
# rank_test_recall                                                                9
# split0_test_precision                                                    0.246753
# split1_test_precision                                                    0.223301
# split2_test_precision                                                        0.29
# mean_test_precision                                                      0.253351
# std_test_precision                                                       0.027627
# rank_test_precision                                                            93
# split0_test_f1                                                           0.330435
# split1_test_f1                                                           0.326241
# split2_test_f1                                                            0.42029
# mean_test_f1                                                             0.358989
# std_test_f1                                                               0.04338
# rank_test_f1                                                                   20
# split0_test_roc_auc                                                      0.660808
# split1_test_roc_auc                                                      0.710056
# split2_test_roc_auc                                                      0.797868
# mean_test_roc_auc                                                        0.722911
# std_test_roc_auc                                                         0.056688
# rank_test_roc_auc                                                              23
#
#                                                                               137  \
# mean_fit_time                                                            0.702675
# std_fit_time                                                              0.14222
# mean_score_time                                                          0.016752
# std_score_time                                                           0.002934
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.631579
# split2_test_recall                                                       0.710526
# mean_test_recall                                                         0.614035
# std_test_recall                                                          0.086838
# rank_test_recall                                                               12
# split0_test_precision                                                    0.253333
# split1_test_precision                                                    0.210526
# split2_test_precision                                                    0.186207
# mean_test_precision                                                      0.216689
# std_test_precision                                                       0.027749
# rank_test_precision                                                           169
# split0_test_f1                                                           0.336283
# split1_test_f1                                                           0.315789
# split2_test_f1                                                           0.295082
# mean_test_f1                                                             0.315718
# std_test_f1                                                               0.01682
# rank_test_f1                                                                  108
# split0_test_roc_auc                                                      0.708459
# split1_test_roc_auc                                                      0.729981
# split2_test_roc_auc                                                      0.721656
# mean_test_roc_auc                                                        0.720032
# std_test_roc_auc                                                         0.008861
# rank_test_roc_auc                                                              29
#
#                                                                               104  \
# mean_fit_time                                                            0.434113
# std_fit_time                                                             0.076229
# mean_score_time                                                          0.012305
# std_score_time                                                           0.000297
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.578947
# split2_test_recall                                                       0.736842
# mean_test_recall                                                         0.605263
# std_test_recall                                                          0.098465
# rank_test_recall                                                               13
# split0_test_precision                                                    0.171171
# split1_test_precision                                                    0.170543
# split2_test_precision                                                    0.212121
# mean_test_precision                                                      0.184612
# std_test_precision                                                       0.019454
# rank_test_precision                                                           195
# split0_test_f1                                                           0.255034
# split1_test_f1                                                           0.263473
# split2_test_f1                                                           0.329412
# mean_test_f1                                                             0.282639
# std_test_f1                                                              0.033252
# rank_test_f1                                                                  170
# split0_test_roc_auc                                                      0.609492
# split1_test_roc_auc                                                      0.615414
# split2_test_roc_auc                                                      0.678551
# mean_test_roc_auc                                                        0.634486
# std_test_roc_auc                                                         0.031253
# rank_test_roc_auc                                                             186
#
#                                                                               11   \
# mean_fit_time                                                            0.153703
# std_fit_time                                                             0.025365
# mean_score_time                                                          0.010903
# std_score_time                                                           0.000207
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.736842
# split1_test_recall                                                       0.526316
# split2_test_recall                                                       0.552632
# mean_test_recall                                                         0.605263
# std_test_recall                                                          0.093659
# rank_test_recall                                                               13
# split0_test_precision                                                       0.224
# split1_test_precision                                                    0.240964
# split2_test_precision                                                    0.333333
# mean_test_precision                                                      0.266099
# std_test_precision                                                       0.048044
# rank_test_precision                                                            72
# split0_test_f1                                                           0.343558
# split1_test_f1                                                           0.330579
# split2_test_f1                                                           0.415842
# mean_test_f1                                                             0.363326
# std_test_f1                                                               0.03751
# rank_test_f1                                                                   15
# split0_test_roc_auc                                                      0.700752
# split1_test_roc_auc                                                      0.677773
# split2_test_roc_auc                                                      0.765988
# mean_test_roc_auc                                                        0.714837
# std_test_roc_auc                                                         0.037366
# rank_test_roc_auc                                                              34
#
#                                                                               182  \
# mean_fit_time                                                            0.637363
# std_fit_time                                                             0.334877
# mean_score_time                                                          0.015188
# std_score_time                                                           0.004174
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.552632
# split1_test_recall                                                       0.473684
# split2_test_recall                                                       0.789474
# mean_test_recall                                                         0.605263
# std_test_recall                                                          0.134185
# rank_test_recall                                                               13
# split0_test_precision                                                    0.165354
# split1_test_precision                                                        0.18
# split2_test_precision                                                    0.169492
# mean_test_precision                                                      0.171615
# std_test_precision                                                       0.006165
# rank_test_precision                                                           205
# split0_test_f1                                                           0.254545
# split1_test_f1                                                            0.26087
# split2_test_f1                                                            0.27907
# mean_test_f1                                                             0.264828
# std_test_f1                                                              0.010396
# rank_test_f1                                                                  183
# split0_test_roc_auc                                                      0.599671
# split1_test_roc_auc                                                      0.678055
# split2_test_roc_auc                                                      0.692134
# mean_test_roc_auc                                                         0.65662
# std_test_roc_auc                                                         0.040677
# rank_test_roc_auc                                                             159
#
#                                 ...  \
# mean_fit_time                   ...
# std_fit_time                    ...
# mean_score_time                 ...
# std_score_time                  ...
# param_clf__hidden_layer_sizes   ...
# param_over__k_neighbors         ...
# param_over__sampling_strategy   ...
# param_under__sampling_strategy  ...
# params                          ...
# split0_test_recall              ...
# split1_test_recall              ...
# split2_test_recall              ...
# mean_test_recall                ...
# std_test_recall                 ...
# rank_test_recall                ...
# split0_test_precision           ...
# split1_test_precision           ...
# split2_test_precision           ...
# mean_test_precision             ...
# std_test_precision              ...
# rank_test_precision             ...
# split0_test_f1                  ...
# split1_test_f1                  ...
# split2_test_f1                  ...
# mean_test_f1                    ...
# std_test_f1                     ...
# rank_test_f1                    ...
# split0_test_roc_auc             ...
# split1_test_roc_auc             ...
# split2_test_roc_auc             ...
# mean_test_roc_auc               ...
# std_test_roc_auc                ...
# rank_test_roc_auc               ...
#
#                                                                               199  \
# mean_fit_time                                                            0.992338
# std_fit_time                                                             0.478371
# mean_score_time                                                           0.01258
# std_score_time                                                           0.000517
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.078947
# split1_test_recall                                                       0.447368
# split2_test_recall                                                       0.473684
# mean_test_recall                                                         0.333333
# std_test_recall                                                          0.180199
# rank_test_recall                                                              202
# split0_test_precision                                                    0.111111
# split1_test_precision                                                    0.209877
# split2_test_precision                                                    0.305085
# mean_test_precision                                                      0.208691
# std_test_precision                                                       0.079194
# rank_test_precision                                                           177
# split0_test_f1                                                           0.092308
# split1_test_f1                                                           0.285714
# split2_test_f1                                                           0.371134
# mean_test_f1                                                             0.249719
# std_test_f1                                                              0.116641
# rank_test_f1                                                                  197
# split0_test_roc_auc                                                      0.527538
# split1_test_roc_auc                                                      0.662641
# split2_test_roc_auc                                                      0.717883
# mean_test_roc_auc                                                        0.636021
# std_test_roc_auc                                                         0.079956
# rank_test_roc_auc                                                             185
#
#                                                                               186  \
# mean_fit_time                                                            0.538226
# std_fit_time                                                             0.594475
# mean_score_time                                                          0.014077
# ...
# split0_test_precision                                                    0.216667
# split1_test_precision                                                    0.240741
# split2_test_precision                                                         0.0
# mean_test_precision                                                      0.152469
# std_test_precision                                                       0.108259
# rank_test_precision                                                           208
# split0_test_f1                                                           0.265306
# split1_test_f1                                                           0.282609
# split2_test_f1                                                                0.0
# mean_test_f1                                                             0.182638
# std_test_f1                                                              0.129338
# rank_test_f1                                                                  210
# split0_test_roc_auc                                                      0.656391
# split1_test_roc_auc                                                       0.66391
# split2_test_roc_auc                                                           0.5
# mean_test_roc_auc                                                        0.606767
# std_test_roc_auc                                                         0.075558
# rank_test_roc_auc                                                             203
#
#                                                                               42   \
# mean_fit_time                                                            0.844819
# std_fit_time                                                             0.162679
# mean_score_time                                                          0.012593
# std_score_time                                                           0.001312
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.157895
# split1_test_recall                                                       0.157895
# split2_test_recall                                                       0.368421
# mean_test_recall                                                          0.22807
# std_test_recall                                                          0.099243
# rank_test_recall                                                              212
# split0_test_precision                                                    0.214286
# split1_test_precision                                                    0.315789
# split2_test_precision                                                    0.333333
# mean_test_precision                                                      0.287803
# std_test_precision                                                       0.052476
# rank_test_precision                                                            37
# split0_test_f1                                                           0.181818
# split1_test_f1                                                           0.210526
# split2_test_f1                                                               0.35
# mean_test_f1                                                             0.247448
# std_test_f1                                                              0.073456
# rank_test_f1                                                                  199
# split0_test_roc_auc                                                      0.628055
# split1_test_roc_auc                                                       0.61485
# split2_test_roc_auc                                                      0.768204
# mean_test_roc_auc                                                        0.670369
# std_test_roc_auc                                                         0.069389
# rank_test_roc_auc                                                             130
#
#                                                                               95   \
# mean_fit_time                                                            0.192014
# std_fit_time                                                             0.113257
# mean_score_time                                                          0.011363
# std_score_time                                                           0.000397
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.157895
# split1_test_recall                                                            0.0
# split2_test_recall                                                       0.394737
# mean_test_recall                                                         0.184211
# std_test_recall                                                          0.162221
# rank_test_recall                                                              213
# split0_test_precision                                                        0.25
# split1_test_precision                                                         0.0
# split2_test_precision                                                    0.348837
# mean_test_precision                                                      0.199612
# std_test_precision                                                       0.146802
# rank_test_precision                                                           185
# split0_test_f1                                                           0.193548
# split1_test_f1                                                                0.0
# split2_test_f1                                                            0.37037
# mean_test_f1                                                             0.187973
# std_test_f1                                                              0.151254
# rank_test_f1                                                                  209
# split0_test_roc_auc                                                      0.590508
# split1_test_roc_auc                                                           0.5
# split2_test_roc_auc                                                      0.621722
# mean_test_roc_auc                                                        0.570743
# std_test_roc_auc                                                         0.051621
# rank_test_roc_auc                                                             213
#
#                                                                               94   \
# mean_fit_time                                                            0.390525
# std_fit_time                                                             0.269438
# mean_score_time                                                          0.011815
# std_score_time                                                           0.000759
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.236842
# split1_test_recall                                                       0.236842
# split2_test_recall                                                            0.0
# mean_test_recall                                                         0.157895
# std_test_recall                                                          0.111648
# rank_test_recall                                                              214
# split0_test_precision                                                    0.321429
# split1_test_precision                                                    0.132353
# split2_test_precision                                                         0.0
# mean_test_precision                                                      0.151261
# std_test_precision                                                       0.131902
# rank_test_precision                                                           209
# split0_test_f1                                                           0.272727
# split1_test_f1                                                           0.169811
# split2_test_f1                                                                0.0
# mean_test_f1                                                             0.147513
# std_test_f1                                                              0.112451
# rank_test_f1                                                                  213
# split0_test_roc_auc                                                      0.584445
# split1_test_roc_auc                                                      0.556955
# split2_test_roc_auc                                                           0.5
# mean_test_roc_auc                                                        0.547133
# std_test_roc_auc                                                         0.035167
# rank_test_roc_auc                                                             216
#
#                                                                               61   \
# mean_fit_time                                                            0.399162
# std_fit_time                                                             0.261326
# mean_score_time                                                          0.012499
# std_score_time                                                           0.001752
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.131579
# split1_test_recall                                                       0.289474
# split2_test_recall                                                            0.0
# mean_test_recall                                                         0.140351
# std_test_recall                                                           0.11834
# rank_test_recall                                                              215
# split0_test_precision                                                    0.119048
# split1_test_precision                                                    0.120879
# split2_test_precision                                                         0.0
# mean_test_precision                                                      0.079976
# std_test_precision                                                       0.056556
# rank_test_precision                                                           216
# split0_test_f1                                                              0.125
# split1_test_f1                                                           0.170543
# split2_test_f1                                                                0.0
# mean_test_f1                                                             0.098514
# std_test_f1                                                              0.072099
# rank_test_f1                                                                  216
# split0_test_roc_auc                                                      0.630827
# split1_test_roc_auc                                                      0.600235
# split2_test_roc_auc                                                           0.5
# mean_test_roc_auc                                                        0.577021
# std_test_roc_auc                                                         0.055876
# rank_test_roc_auc                                                             210
#
#                                                                               85
# mean_fit_time                                                            0.176709
# std_fit_time                                                             0.208761
# mean_score_time                                                             0.015
# std_score_time                                                           0.003273
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                       0.394737
# mean_test_recall                                                         0.131579
# std_test_recall                                                          0.186081
# rank_test_recall                                                              216
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                    0.384615
# mean_test_precision                                                      0.128205
# std_test_precision                                                       0.181309
# rank_test_precision                                                           211
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                            0.38961
# mean_test_f1                                                              0.12987
# std_test_f1                                                              0.183664
# rank_test_f1                                                                  214
# split0_test_roc_auc                                                           0.5
# split1_test_roc_auc                                                           0.5
# split2_test_roc_auc                                                       0.76561
# mean_test_roc_auc                                                        0.588537
# std_test_roc_auc                                                          0.12521
# rank_test_roc_auc                                                             206
#
# [33 rows x 216 columns]

# %% [markdown]
# #### Feature Importance (MLP)

# %%
# Feature importance of model (MLP)  (no cross-validation!)

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=3)

MLP = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(MLP, Xsc, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = Xsc.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance MLP")
# Out:
# Text(0.5, 1.0, 'Permutation Importance MLP')

# %% [markdown]
# #### Feature importance with SHAP

# %%
X = Xsc.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.25)

nn = MLPClassifier(hidden_layer_sizes=(3,3), solver='lbfgs', max_iter=5000)
model = nn.fit(X_train.to_numpy(), y_train)

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# explain the model's predictions using SHAP
import shap
import warnings
warnings.filterwarnings("ignore")
shap.initjs()

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,20))
shap_values = explainer.shap_values(X_test, nsamples=50)
shap.summary_plot(shap_values, X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
#   0%|          | 0/239 [00:00<?, ?it/s]

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,50))
shap_values = explainer.shap_values(X_test, nsamples=50)
for classid in [0,1]:
    shap.summary_plot(shap_values[classid], X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
#   0%|          | 0/239 [00:00<?, ?it/s]

# %%
# Try dependence contribution plot
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,50))
shap_values = explainer.shap_values(X_test, nsamples=50)
shap.dependence_plot('salinity', shap_values[1], X_test,) #interaction_index="salinity"
# Out:
#   0%|          | 0/239 [00:00<?, ?it/s]

# %% [markdown]
# Example intepretation: The fact this slopes upward says the higher the soca flow, the higher the model's prediction is for poz/neg. The spread suggests that other features must interact with Soca flow.
# In general, high Soca flow increases the chance of poz/neg. But if the sea temp is moderate or low, that trend reverses and even high soca flow does not increase preditions of poz/neg as the sea temp is too low.
# https://www.kaggle.com/code/dansbecker/advanced-uses-of-shap-values

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
instanceID = 10
instance = X.iloc[[instanceID]]
display_instance = X_display.iloc[[instanceID]]

prediction = model.predict(instance)[0]
prediction_probs = model.predict_proba(instance)[0]
print(f'real value: {y[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)
# Out:
# real value: 1,
# predicted: 0,
# predicted probs: [0.57066093 0.42933907]
# Explanation for prediction: class=0, p=0.5706609336947952
#   0%|          | 0/1 [00:00<?, ?it/s]
# <div id='iU4CZQ9PU6J2VN5LNLM6U'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.9186157310587268, "outValue": 0.5706609336947952, "link": "identity", "featureNames": ["DSP", "Dinophysis caudata", "Dinophysis fortii", "Phalacroma rotundatum", "Dinophysis sacculus", "Dinophysis tripos", "sun [h]", "air temp", "wind strength", "precipitation", "salinity", "T", "Soca", "month_1", "month_2", "month_3", "month_4", "month_5", "month_6", "month_7", "month_8", "month_9", "month_10", "month_11", "month_12"], "features": {"0": {"effect": -0.017522748819441353, "value": 216.0}, "1": {"effect": -0.0656020175803001, "value": 92.0}, "2": {"effect": -0.018830374652593046, "value": 111.0}, "3": {"effect": 0.007198010918829656, "value": 13.0}, "4": {"effect": -0.0053940890594434965, "value": 0.0}, "5": {"effect": 0.009173216349999097, "value": 0.0}, "6": {"effect": -0.044288047900615246, "value": 103.40000000000002}, "7": {"effect": -0.0692428456914216, "value": 14.77142857142857}, "8": {"effect": 0.010550850370343368, "value": 2.704761904761905}, "9": {"effect": -0.016554851511557556, "value": 219.9}, "10": {"effect": 0.04962828384899637, "value": 37.39}, "11": {"effect": 0.03207385824139222, "value": 21.73}, "12": {"effect": -0.03466710111157931, "value": 1852.896}, "14": {"effect": 0.0042135406318753454, "value": 0.0}, "15": {"effect": -0.0037019694319856966, "value": 0.0}, "16": {"effect": -0.03863021380279116, "value": 0.0}, "17": {"effect": 0.005777903617527391, "value": 0.0}, "18": {"effect": -0.015319649952273806, "value": 0.0}, "19": {"effect": 0.007550371537178108, "value": 0.0}, "21": {"effect": -0.14631199774790565, "value": 1.0}, "23": {"effect": 0.0019450743818348326, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iU4CZQ9PU6J2VN5LNLM6U')
#   );
# </script>

# %% [markdown]
# Show the mean values of features as it may help understanding this particular instance data in the plot above.

# %%
data = pd.get_dummies(data, columns=["month"])


pd.DataFrame([data[data['lipophylic_toxins']=='neg'].mean(), data[data['lipophylic_toxins']=='poz'].mean()], index=['neg','pos']).T
# Out:
#                                neg          pos
# DSP                     102.700503   195.860294
# Dinophysis caudata       25.537688    40.543382
# Dinophysis fortii        23.725829    72.827941
# Phalacroma rotundatum    16.438492    13.510294
# Dinophysis sacculus      24.474070    52.823529
# Dinophysis tripos         4.902513     8.235294
# sun [h]                 165.661647   152.191912
# air temp                 17.422122    16.944328
# wind strength             2.997017     2.921674
# precipitation            56.557731    75.321324
# salinity                 37.572301    35.645847
# T                        20.169225    20.321842
# Soca                   3208.868147  3703.893351
# month_1                   0.015060     0.022059
# month_2                   0.021084     0.022059
# month_3                   0.028112     0.014706
# month_4                   0.066265     0.014706
# month_5                   0.089357     0.102941
# month_6                   0.115462     0.088235
# month_7                   0.125502     0.132353
# month_8                   0.126506     0.080882
# month_9                   0.143574     0.227941
# month_10                  0.138554     0.176471
# month_11                  0.091365     0.095588
# month_12                  0.039157     0.022059

# %% [markdown]
# ### Conclusion

# %%
# Summary table of prediction results
RF_recall = round(RF_recall_best_k[1], 2)
RF_auc = round(RF_auc_best_k[1], 2)
MLP_recall = round(MLP_recall_best_k[1], 2)
MLP_auc = round(MLP_auc_best_k[1], 2)

summary = pd.DataFrame(
    [
        (
            "RF",
            RF_recall_score,
            RF_auc_score,
        ),
        (
            "MLP",
            MLP_recall_score,
            MLP_auc_score,
        ),
        (
            "RF (smote)",
            RF_recall,
            RF_auc,
        ),
        (
            "MLP (smote)",
            MLP_recall,
            MLP_auc,
        ),
        (
            "Decision tree (J48)*",
            0.56,
            0.18,
        ),
    ],
    columns=("Model", "Recall", "ROC AUC"),
).set_index("Model")

print("Table summarising the prediction results of the used classifiers, both with and without SMOTE resampling:\n")
summary.round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 # Summary table of prediction results
# ----> 2 RF_recall = round(RF_recall_best_k[1], 2)
#       3 RF_auc = round(RF_auc_best_k[1], 2)
#       4 MLP_recall = round(MLP_recall_best_k[1], 2)
#
# NameError: name 'RF_recall_best_k' is not defined

# %% [markdown]
# As can be seen resampling with SMOTE helped to improve the results substantially, especially when calculating recall. The highest recall and ROC AUC was achieved with Random Forest with the re-sampled data. Both recall and ROC AUC suggest Random Forest as beeing the better classifier for this particular problem. Recall is a crucial metric as it gives indication of what fraction of true positive instances have been predicted. Since the models predict toxins in seashells (food) it is crucial that as few positives as possible are missed.
#
# Due to the use of SMOTE resampling (upsampling and downsampling) in combinaiton with cross-validation it was curcial to do the resampling within each fold to avoid data lekeage and validate on original (unsampled) data. In addition, I have optimised the model with regard to the k-values of SMOTE, all of which brought along some complexity. So for the parameter tuning of Random Forest and MLP various parameter settings have been tried  and the model with best performing settings has been chosen.
#
# The decision tree J48 algorithm was run within Weka on a slightly different dataset (missing values were not removed to use as many instances as possible, cross validation was 10-fold as opposed to 3-fold due to a higher dataset etc.) thus this results are not directly comparable but were provided as a reference to give an indication of the performance of this algorithm.
#
# As can be seen in the feature importance bar plots above, similar features were on the top despite using two different classification algorithms and two different feature ranking methods. If we consider just the three highest-ranking features of each of the feature ranking methods for both algortihms (RF and MLP) the features that overlap are DSP, DSP_like, ASP, Dinophysis fortii and Dinophysis caudata. These can be shown to the domain experts for validation and interpretation.
