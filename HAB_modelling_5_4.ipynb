# %%
from datetime import datetime
import pandas as pd
import numpy as np
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from dtreeviz.trees import dtreeviz 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 30)

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")
data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
# data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    661
# salinity                 191
# T                        244
# SECCHI                   696
# DIN                      542
# PO4-P                    534
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
data.drop(columns=["Chl-a","PO4-P","DIN","SECCHI"], inplace=True)
# data.drop(columns=["SECCHI",  ], inplace=True)#,"Chl-a", "PO4-P", "DIN",
data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# salinity                 191
# T                        244
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Modelling and Preliminary Results

# %% [markdown]
# ![Screenshot 2022-07-26 at 12.15.26.png](attachment:500d2dd5-b27f-4f67-a0a0-94d4c6fc8714.png)

# %% [markdown]
# # Scikit-learn Analysis

# %% [markdown]
# ### Preprocessing

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    839
# poz    114
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# ## Model Training and Evaluation

# %% [markdown]
# ### Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
              'clf__max_depth': [2,3,4],
                'clf__criterion': ['gini', 'entropy'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
               'smt__sampling_strategy': [ 0.1, 0.2],
               'under__sampling_strategy': [0.7, 0.8],
                'smt__k_neighbors': [3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="recall",
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# 480 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 268, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 226, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 394, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 534, in check_sampling_strategy
#     _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 373, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 272, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 969, in fit
#     super().fit(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 227, in fit
#     expanded_class_weight = compute_sample_weight(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/utils/class_weight.py", line 127, in compute_sample_weight
#     raise ValueError(
# ValueError: The only valid preset for class_weight is "balanced". Given "balanced_subsample".
#
# One or more of the test scores are non-finite: [       nan        nan 0.56993464 0.57777778        nan        nan
#  0.55686275 0.64771242        nan        nan 0.6248366  0.60130719
#         nan        nan 0.65882353 0.64901961        nan        nan
#  0.61176471 0.58823529        nan        nan 0.57843137 0.55490196
#         nan        nan 0.58104575 0.55555556        nan        nan
#  0.62418301 0.45490196        nan        nan 0.66928105 0.61568627
#         nan        nan 0.54705882 0.54705882        nan        nan
#  0.64705882 0.6379085         nan        nan 0.56535948 0.62418301
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.52222222 0.55555556        nan        nan
#  0.44313725 0.53464052        nan        nan 0.47581699 0.63464052
#         nan        nan 0.46535948 0.51176471        nan        nan
#  0.50065359 0.51176471        nan        nan 0.45359477 0.49869281
#         nan        nan 0.51111111 0.5875817         nan        nan
#  0.5        0.59019608        nan        nan 0.50980392 0.51045752
#         nan        nan 0.49803922 0.5               nan        nan
#  0.54575163 0.55555556        nan        nan 0.47712418 0.60326797]
# One or more of the test scores are non-finite: [       nan        nan 0.21522556 0.21392857        nan        nan
#  0.19105701 0.20593748        nan        nan 0.19889795 0.21060813
#         nan        nan 0.19475155 0.20536635        nan        nan
#  0.20950161 0.20366106        nan        nan 0.19842243 0.21509485
#         nan        nan 0.19187095 0.20421446        nan        nan
#  0.21765004 0.22697626        nan        nan 0.16901543 0.22391415
#         nan        nan 0.21334895 0.16760703        nan        nan
#  0.16003794 0.21039072        nan        nan 0.23115617 0.2170959
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.21610823 0.21700143        nan        nan
#  0.25153796 0.20241566        nan        nan 0.2027252  0.2031393
#         nan        nan 0.25134615 0.22614625        nan        nan
#  0.2094603  0.19426299        nan        nan 0.21129117 0.24187893
#         nan        nan 0.20067102 0.21363847        nan        nan
#  0.2196675  0.22464111        nan        nan 0.22313286 0.26913383
#         nan        nan 0.24371751 0.22836323        nan        nan
#  0.21405194 0.21350593        nan        nan 0.28034222 0.20096566]
# One or more of the test scores are non-finite: [       nan        nan 0.3088952  0.3096077         nan        nan
#  0.27949702 0.31204702        nan        nan 0.29935094 0.30084643
#         nan        nan 0.29858893 0.31041339        nan        nan
#  0.31096678 0.29994555        nan        nan 0.29048768 0.30891896
#         nan        nan 0.28010502 0.28025426        nan        nan
#  0.31887801 0.29864307        nan        nan 0.26904108 0.32195549
#         nan        nan 0.29558577 0.2550826         nan        nan
#  0.2552961  0.31130993        nan        nan 0.32724154 0.31985844
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.3036496  0.30587978        nan        nan
#  0.30967708 0.28672335        nan        nan 0.28313017 0.30410708
#         nan        nan 0.32487358 0.30430334        nan        nan
#  0.29303442 0.2790387         nan        nan 0.28373959 0.32289452
#         nan        nan 0.28384615 0.3093649         nan        nan
#  0.30120101 0.32475278        nan        nan 0.30649646 0.34770879
#         nan        nan 0.32427885 0.31180813        nan        nan
#  0.30340775 0.30072384        nan        nan 0.34635475 0.29387412]
# One or more of the test scores are non-finite: [       nan        nan 0.67881014 0.6685008         nan        nan
#  0.63897561 0.67957016        nan        nan 0.6728443  0.64404741
#         nan        nan 0.65830407 0.69754502        nan        nan
#  0.64826797 0.64817138        nan        nan 0.65231091 0.64320752
#         nan        nan 0.66047913 0.66128931        nan        nan
#  0.66411749 0.64877723        nan        nan 0.6711863  0.66692571
#         nan        nan 0.67177419 0.63065343        nan        nan
#  0.64286487 0.67151126        nan        nan 0.69051835 0.68507331
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.63969706 0.63172922        nan        nan
#  0.67353585 0.68389574        nan        nan 0.62311935 0.69488635
#         nan        nan 0.66535505 0.64906527        nan        nan
#  0.66837113 0.62952762        nan        nan 0.64200893 0.66905264
#         nan        nan 0.64968301 0.66662663        nan        nan
#  0.66870049 0.66719902        nan        nan 0.68173483 0.68107805
#         nan        nan 0.65685509 0.67202143        nan        nan
#  0.70286716 0.69891758        nan        nan 0.70466989 0.66843505]
#                                                                               34   \
# mean_fit_time                                                            0.024729
# std_fit_time                                                             0.002023
# mean_score_time                                                          0.014068
# std_score_time                                                           0.002704
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.611111
# split1_test_recall                                                       0.833333
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.588235
# split4_test_recall                                                       0.647059
# mean_test_recall                                                         0.669281
# std_test_recall                                                          0.086448
# rank_test_recall                                                                1
# split0_test_precision                                                    0.161765
# split1_test_precision                                                    0.217391
# split2_test_precision                                                     0.20339
# split3_test_precision                                                    0.131579
# split4_test_precision                                                    0.130952
# mean_test_precision                                                      0.169015
# std_test_precision                                                       0.035846
# rank_test_precision                                                            46
# split0_test_f1                                                           0.255814
# split1_test_f1                                                           0.344828
# split2_test_f1                                                           0.311688
# split3_test_f1                                                           0.215054
# split4_test_f1                                                           0.217822
# mean_test_f1                                                             0.269041
# std_test_f1                                                              0.051527
# rank_test_f1                                                                   46
# split0_test_roc_auc                                                      0.671717
# split1_test_roc_auc                                                      0.787668
# split2_test_roc_auc                                                      0.694865
# split3_test_roc_auc                                                      0.582043
# split4_test_roc_auc                                                      0.619637
# mean_test_roc_auc                                                        0.671186
# std_test_roc_auc                                                         0.070332
# rank_test_roc_auc                                                              18
#
#                                                                               14   \
# mean_fit_time                                                            0.016312
# std_fit_time                                                             0.001541
# mean_score_time                                                          0.008837
# std_score_time                                                           0.001043
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                       0.611111
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.705882
# split4_test_recall                                                       0.588235
# mean_test_recall                                                         0.658824
# std_test_recall                                                          0.052067
# rank_test_recall                                                                2
# split0_test_precision                                                    0.230769
# split1_test_precision                                                    0.189655
# split2_test_precision                                                        0.26
# split3_test_precision                                                        0.16
# split4_test_precision                                                    0.133333
# mean_test_precision                                                      0.194752
# std_test_precision                                                       0.045958
# rank_test_precision                                                            42
# split0_test_f1                                                           0.342857
# split1_test_f1                                                           0.289474
# split2_test_f1                                                           0.382353
# split3_test_f1                                                            0.26087
# split4_test_f1                                                           0.217391
# mean_test_f1                                                             0.298589
# std_test_f1                                                              0.058438
# rank_test_f1                                                                   33
# split0_test_roc_auc                                                      0.697391
# split1_test_roc_auc                                                      0.630682
# split2_test_roc_auc                                                      0.718645
# split3_test_roc_auc                                                      0.632021
# split4_test_roc_auc                                                      0.612782
# mean_test_roc_auc                                                        0.658304
# std_test_roc_auc                                                         0.041701
# rank_test_roc_auc                                                              31
#
#                                                                               15   \
# mean_fit_time                                                             0.01594
# std_fit_time                                                             0.002183
# mean_score_time                                                          0.008624
# std_score_time                                                           0.001056
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.705882
# split4_test_recall                                                       0.705882
# mean_test_recall                                                          0.64902
# std_test_recall                                                          0.076546
# rank_test_recall                                                                3
# split0_test_precision                                                    0.160714
# split1_test_precision                                                    0.272727
# split2_test_precision                                                    0.214286
# split3_test_precision                                                    0.179104
# split4_test_precision                                                         0.2
# mean_test_precision                                                      0.205366
# std_test_precision                                                       0.038287
# rank_test_precision                                                            32
# split0_test_f1                                                           0.243243
# split1_test_f1                                                           0.387097
# split2_test_f1                                                           0.324324
# split3_test_f1                                                           0.285714
# split4_test_f1                                                           0.311688
# mean_test_f1                                                             0.310413
# std_test_f1                                                              0.047323
# rank_test_f1                                                                   15
# split0_test_roc_auc                                                      0.618897
# split1_test_roc_auc                                                      0.767045
# split2_test_roc_auc                                                      0.724958
# split3_test_roc_auc                                                      0.641751
# split4_test_roc_auc                                                      0.735073
# mean_test_roc_auc                                                        0.697545
# std_test_roc_auc                                                         0.057076
# rank_test_roc_auc                                                               4
#
#                                                                               7    \
# mean_fit_time                                                            0.021347
# std_fit_time                                                             0.000675
# mean_score_time                                                          0.010045
# std_score_time                                                           0.001252
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.470588
# split4_test_recall                                                       0.823529
# mean_test_recall                                                         0.647712
# std_test_recall                                                          0.123845
# rank_test_recall                                                                4
# split0_test_precision                                                    0.188679
# split1_test_precision                                                    0.196721
# split2_test_precision                                                    0.240741
# split3_test_precision                                                    0.170213
# split4_test_precision                                                    0.233333
# mean_test_precision                                                      0.205937
# std_test_precision                                                        0.02691
# rank_test_precision                                                            31
# split0_test_f1                                                            0.28169
# split1_test_f1                                                           0.303797
# split2_test_f1                                                           0.361111
# split3_test_f1                                                               0.25
# split4_test_f1                                                           0.363636
# mean_test_f1                                                             0.312047
# std_test_f1                                                              0.044516
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                       0.65404
# split1_test_roc_auc                                                      0.652778
# split2_test_roc_auc                                                      0.684133
# split3_test_roc_auc                                                      0.630473
# split4_test_roc_auc                                                      0.776426
# mean_test_roc_auc                                                         0.67957
# std_test_roc_auc                                                         0.051346
# rank_test_roc_auc                                                              11
#
#                                                                               42   \
# mean_fit_time                                                            0.029539
# std_fit_time                                                             0.001098
# mean_score_time                                                          0.011802
# std_score_time                                                           0.001646
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                       0.611111
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.588235
# split4_test_recall                                                       0.647059
# mean_test_recall                                                         0.647059
# std_test_recall                                                          0.046447
# rank_test_recall                                                                5
# split0_test_precision                                                    0.142857
# split1_test_precision                                                    0.186441
# split2_test_precision                                                    0.213115
# split3_test_precision                                                     0.12987
# split4_test_precision                                                    0.127907
# mean_test_precision                                                      0.160038
# std_test_precision                                                       0.033917
# rank_test_precision                                                            48
# split0_test_f1                                                           0.235294
# split1_test_f1                                                           0.285714
# split2_test_f1                                                           0.329114
# split3_test_f1                                                           0.212766
# split4_test_f1                                                           0.213592
# mean_test_f1                                                             0.255296
# std_test_f1                                                              0.045437
# rank_test_f1                                                                   47
# split0_test_roc_auc                                                      0.625631
# split1_test_roc_auc                                                      0.680556
# split2_test_roc_auc                                                      0.736532
# split3_test_roc_auc                                                      0.545555
# split4_test_roc_auc                                                       0.62605
# mean_test_roc_auc                                                        0.642865
# std_test_roc_auc                                                         0.063629
# rank_test_roc_auc                                                              41
#
#                                                                               43   \
# mean_fit_time                                                            0.025819
# std_fit_time                                                              0.00553
# mean_score_time                                                          0.010981
# std_score_time                                                           0.001363
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.555556
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.764706
# split4_test_recall                                                       0.647059
# mean_test_recall                                                         0.637908
# std_test_recall                                                          0.078169
# rank_test_recall                                                                6
# split0_test_precision                                                    0.263158
# split1_test_precision                                                    0.192308
# split2_test_precision                                                    0.272727
# split3_test_precision                                                    0.168831
# split4_test_precision                                                     0.15493
# mean_test_precision                                                      0.210391
# std_test_precision                                                       0.048581
# rank_test_precision                                                            28
# split0_test_f1                                                           0.357143
# split1_test_f1                                                           0.285714
# split2_test_f1                                                           0.387097
# split3_test_f1                                                           0.276596
# split4_test_f1                                                               0.25
# mean_test_f1                                                              0.31131
# std_test_f1                                                              0.051891
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.673401
# split1_test_roc_auc                                                      0.624369
# split2_test_roc_auc                                                      0.724537
# split3_test_roc_auc                                                      0.681336
# split4_test_roc_auc                                                      0.653914
# mean_test_roc_auc                                                        0.671511
# std_test_roc_auc                                                         0.032997
# rank_test_roc_auc                                                              17
#
#                                                                               107  \
# mean_fit_time                                                            0.024023
# std_fit_time                                                             0.001395
# mean_score_time                                                          0.011812
# std_score_time                                                           0.000832
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.944444
# split1_test_recall                                                       0.722222
# split2_test_recall                                                       0.388889
# split3_test_recall                                                       0.647059
# split4_test_recall                                                       0.470588
# mean_test_recall                                                         0.634641
# std_test_recall                                                          0.195505
# rank_test_recall                                                                7
# split0_test_precision                                                    0.242857
# split1_test_precision                                                    0.180556
# split2_test_precision                                                    0.152174
# split3_test_precision                                                    0.211538
# split4_test_precision                                                    0.228571
# mean_test_precision                                                      0.203139
# std_test_precision                                                        0.03287
# rank_test_precision                                                            35
# split0_test_f1                                                           0.386364
# split1_test_f1                                                           0.288889
# split2_test_f1                                                            0.21875
# split3_test_f1                                                           0.318841
# split4_test_f1                                                           0.307692
# mean_test_f1                                                             0.304107
# std_test_f1                                                              0.053877
# rank_test_f1                                                                   24
# split0_test_roc_auc                                                      0.760943
# split1_test_roc_auc                                                      0.700758
# split2_test_roc_auc                                                      0.640993
# split3_test_roc_auc                                                      0.650376
# split4_test_roc_auc                                                      0.721362
# mean_test_roc_auc                                                        0.694886
# std_test_roc_auc                                                         0.044687
# rank_test_roc_auc                                                               5
#
#                                                                               10   \
# mean_fit_time                                                            0.023466
# std_fit_time                                                             0.000329
# mean_score_time                                                          0.011183
# std_score_time                                                           0.000442
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.722222
# split1_test_recall                                                            0.5
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.647059
# split4_test_recall                                                       0.588235
# mean_test_recall                                                         0.624837
# std_test_recall                                                          0.075699
# rank_test_recall                                                                8
# split0_test_precision                                                        0.25
# split1_test_precision                                                    0.140625
# split2_test_precision                                                    0.285714
# split3_test_precision                                                     0.15942
# split4_test_precision                                                     0.15873
# mean_test_precision                                                      0.198898
# std_test_precision                                                       0.057821
# rank_test_precision                                                            40
# split0_test_f1                                                           0.371429
# split1_test_f1                                                           0.219512
# split2_test_f1                                                                0.4
# split3_test_f1                                                           0.255814
# split4_test_f1                                                               0.25
# mean_test_f1                                                             0.299351
# std_test_f1                                                              0.072153
# rank_test_f1                                                                   31
# split0_test_roc_auc                                                      0.743897
# split1_test_roc_auc                                                      0.591751
# split2_test_roc_auc                                                       0.76431
# split3_test_roc_auc                                                      0.629368
# split4_test_roc_auc                                                      0.634896
# mean_test_roc_auc                                                        0.672844
# std_test_roc_auc                                                         0.068295
# rank_test_roc_auc                                                              14
#
#                                                                               30   \
# mean_fit_time                                                            0.022335
# std_fit_time                                                              0.00159
# mean_score_time                                                            0.0115
# std_score_time                                                            0.00098
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.470588
# split4_test_recall                                                       0.705882
# mean_test_recall                                                         0.624183
# std_test_recall                                                          0.096325
# rank_test_recall                                                                9
# split0_test_precision                                                    0.188679
# split1_test_precision                                                    0.235294
# split2_test_precision                                                    0.164557
# split3_test_precision                                                    0.156863
# split4_test_precision                                                    0.342857
# mean_test_precision                                                       0.21765
# std_test_precision                                                       0.068325
# rank_test_precision                                                            15
# split0_test_f1                                                            0.28169
# split1_test_f1                                                           0.347826
# split2_test_f1                                                           0.268041
# split3_test_f1                                                           0.235294
# split4_test_f1                                                           0.461538
# mean_test_f1                                                             0.318878
# std_test_f1                                                              0.080179
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.667298
# split1_test_roc_auc                                                      0.686237
# split2_test_roc_auc                                                      0.599958
# split3_test_roc_auc                                                      0.592658
# split4_test_roc_auc                                                      0.774436
# mean_test_roc_auc                                                        0.664117
# std_test_roc_auc                                                          0.06617
# rank_test_roc_auc                                                              28
#
#                                                                               47   \
# mean_fit_time                                                            0.019653
# std_fit_time                                                             0.004029
# mean_score_time                                                           0.00901
# std_score_time                                                           0.001644
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.611111
# split1_test_recall                                                       0.722222
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.705882
# split4_test_recall                                                       0.470588
# mean_test_recall                                                         0.624183
# std_test_recall                                                          0.089688
# rank_test_recall                                                                9
# split0_test_precision                                                    0.282051
# split1_test_precision                                                    0.232143
# split2_test_precision                                                    0.177419
# split3_test_precision                                                     0.20339
# split4_test_precision                                                    0.190476
# mean_test_precision                                                      0.217096
# std_test_precision                                                       0.037192
# rank_test_precision                                                            16
# split0_test_f1                                                           0.385965
# split1_test_f1                                                           0.351351
# split2_test_f1                                                              0.275
# split3_test_f1                                                           0.315789
# split4_test_f1                                                           0.271186
# mean_test_f1                                                             0.319858
# std_test_f1                                                              0.044181
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.700968
# split1_test_roc_auc                                                      0.724537
# split2_test_roc_auc                                                      0.707071
# split3_test_roc_auc                                                      0.659885
# split4_test_roc_auc                                                      0.632906
# mean_test_roc_auc                                                        0.685073
# std_test_roc_auc                                                         0.033615
# rank_test_roc_auc                                                               7
#
#                                                                               35   \
# mean_fit_time                                                            0.025713
# std_fit_time                                                             0.001775
# mean_score_time                                                          0.012474
# std_score_time                                                           0.001252
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# ...
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  140
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             140
#
#                                                                               56   \
# mean_fit_time                                                            0.003403
# std_fit_time                                                             0.000293
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              141
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           141
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  141
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             141
#
#                                                                               55   \
# mean_fit_time                                                             0.01775
# std_fit_time                                                             0.001616
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              142
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           142
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  142
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             142
#
#                                                                               67   \
# mean_fit_time                                                            0.017359
# std_fit_time                                                             0.003374
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              143
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           143
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  143
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             143
#
#                                                                               71
# mean_fit_time                                                            0.017745
# std_fit_time                                                             0.003137
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              144
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           144
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  144
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             144
#
# [43 rows x 144 columns]

# %%
clf = gscv.best_estimator_.steps[2][1]
viz = dtreeviz(clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"],
             fancy=False,
               scale=1.5
              )

viz
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
# Calculate the feature importance
dt_importances = clf.feature_importances_
dt_importances_df = pd.DataFrame(data = dt_importances, index = X.columns, columns=["importance"])  
dt_importances_df = dt_importances_df.sort_values(by="importance", ascending=False)
dt_importances_df[0:10]
# Out:
#                    importance
# Dinophysis fortii    0.354063
# salinity             0.193546
# Chl-a                0.182089
# T                    0.118938
# precipitation        0.095046
# sun [h]              0.056318
# DSP                  0.000000
# Soca                 0.000000
# PO4-P                0.000000
# DIN                  0.000000

# %% [markdown]
# ### Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', RandomForestClassifier())
])

parameters = {
              'clf__n_estimators': [300,500,800],
              'clf__criterion': ['gini', 'entropy'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
               'smt__sampling_strategy': [ 0.1, 0.2],
               'under__sampling_strategy': [0.7, 0.8],
                'smt__k_neighbors': [3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="recall",
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
pd.set_option("display.max_rows", None)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# 360 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 268, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 226, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 394, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 534, in check_sampling_strategy
#     _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 373, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
# One or more of the test scores are non-finite: [       nan        nan 0.58169935 0.59215686        nan        nan
#  0.51176471 0.54771242        nan        nan 0.52352941 0.61633987
#         nan        nan 0.55816993 0.57058824        nan        nan
#  0.57124183 0.59281046        nan        nan 0.56928105 0.59281046
#         nan        nan 0.54640523 0.60457516        nan        nan
#  0.52352941 0.61437908        nan        nan 0.5248366  0.55751634
#         nan        nan 0.53464052 0.60392157        nan        nan
#  0.54705882 0.55882353        nan        nan 0.54575163 0.56928105
#         nan        nan 0.5124183  0.61503268        nan        nan
#  0.47843137 0.60457516        nan        nan 0.54640523 0.60392157
#         nan        nan 0.55751634 0.55686275        nan        nan
#  0.54640523 0.56993464        nan        nan 0.5124183  0.57058824
#         nan        nan 0.55882353 0.60392157        nan        nan
#  0.50065359 0.54705882        nan        nan 0.53464052 0.56993464
#         nan        nan 0.56993464 0.60588235        nan        nan
#  0.51176471 0.53594771        nan        nan 0.54771242 0.57058824
#         nan        nan 0.55947712 0.5372549         nan        nan
#  0.58104575 0.57058824        nan        nan 0.52418301 0.54640523
#         nan        nan 0.53660131 0.58235294        nan        nan
#  0.52287582 0.53398693        nan        nan 0.54705882 0.55816993
#         nan        nan 0.54901961 0.58104575        nan        nan
#  0.55686275 0.59346405        nan        nan 0.53660131 0.59215686
#         nan        nan 0.54640523 0.55816993        nan        nan
#  0.56993464 0.59281046        nan        nan 0.58169935 0.60457516]
# One or more of the test scores are non-finite: [       nan        nan 0.42942125 0.33998484        nan        nan
#  0.34495473 0.33322173        nan        nan 0.44068008 0.3667972
#         nan        nan 0.44584659 0.31763129        nan        nan
#  0.40731092 0.39510898        nan        nan 0.40039303 0.3203964
#         nan        nan 0.3742109  0.34976803        nan        nan
#  0.37217057 0.35364161        nan        nan 0.35647975 0.36184788
#         nan        nan 0.41272282 0.33756737        nan        nan
#  0.413276   0.33103628        nan        nan 0.41176788 0.30349584
#         nan        nan 0.37452697 0.37333075        nan        nan
#  0.36295837 0.39304187        nan        nan 0.39565902 0.39604227
#         nan        nan 0.39878002 0.41971714        nan        nan
#  0.45038321 0.35854978        nan        nan 0.37766128 0.36785621
#         nan        nan 0.43174873 0.33566837        nan        nan
#  0.38961538 0.3503585         nan        nan 0.38114719 0.36878122
#         nan        nan 0.38115588 0.37064815        nan        nan
#  0.35115152 0.30264498        nan        nan 0.42141005 0.36619872
#         nan        nan 0.41203822 0.36143318        nan        nan
#  0.40138006 0.36397328        nan        nan 0.38634772 0.37568067
#         nan        nan 0.40671654 0.32825833        nan        nan
#  0.3934103  0.35038095        nan        nan 0.39316979 0.33894661
#         nan        nan 0.37450589 0.3710578         nan        nan
#  0.36682925 0.33739364        nan        nan 0.36698413 0.33337817
#         nan        nan 0.36153846 0.36382756        nan        nan
#  0.39514012 0.36309921        nan        nan 0.39448129 0.34703108]
# One or more of the test scores are non-finite: [       nan        nan 0.47954712 0.42795242        nan        nan
#  0.40648114 0.40785116        nan        nan 0.46580617 0.45378785
#         nan        nan 0.49295248 0.40522782        nan        nan
#  0.46775319 0.46467847        nan        nan 0.46372195 0.4125254
#         nan        nan 0.43462279 0.43490272        nan        nan
#  0.4310106  0.44584249        nan        nan 0.41640153 0.43594182
#         nan        nan 0.45384615 0.43193058        nan        nan
#  0.45674506 0.40896541        nan        nan 0.46007139 0.39202418
#         nan        nan 0.42821194 0.45763144        nan        nan
#  0.40204798 0.46383403        nan        nan 0.45164367 0.46744601
#         nan        nan 0.45661616 0.46362954        nan        nan
#  0.48502626 0.43498603        nan        nan 0.42529224 0.4447974
#         nan        nan 0.47554935 0.4295519         nan        nan
#  0.43236098 0.42368433        nan        nan 0.43984962 0.44014827
#         nan        nan 0.44962653 0.45088636        nan        nan
#  0.41295087 0.38303708        nan        nan 0.46999263 0.43990307
#         nan        nan 0.46285376 0.41927503        nan        nan
#  0.46896552 0.43458353        nan        nan 0.43760863 0.43219663
#         nan        nan 0.44803485 0.41344156        nan        nan
#  0.44464571 0.4193604         nan        nan 0.45406922 0.41848148
#         nan        nan 0.43739316 0.44841536        nan        nan
#  0.44044254 0.42818549        nan        nan 0.43080657 0.42464011
#         nan        nan 0.43213385 0.43073864        nan        nan
#  0.45851468 0.4441771         nan        nan 0.46197562 0.43646511]
# One or more of the test scores are non-finite: [       nan        nan 0.82142881 0.81785042        nan        nan
#  0.83711397 0.81326303        nan        nan 0.84688318 0.80354807
#         nan        nan 0.83227031 0.81825302        nan        nan
#  0.83525428 0.81895563        nan        nan 0.83552604 0.82869933
#         nan        nan 0.82763273 0.83508299        nan        nan
#  0.83635643 0.8201233         nan        nan 0.81506916 0.8395778
#         nan        nan 0.82818836 0.8324957         nan        nan
#  0.81772358 0.82877846        nan        nan 0.81753949 0.83123521
#         nan        nan 0.81911962 0.81898189        nan        nan
#  0.81342851 0.83244577        nan        nan 0.82110194 0.83611236
#         nan        nan 0.83543471 0.83738569        nan        nan
#  0.83784873 0.8429362         nan        nan 0.81328153 0.83861635
#         nan        nan 0.85512305 0.82034956        nan        nan
#  0.84192548 0.82666334        nan        nan 0.83334173 0.81529397
#         nan        nan 0.82658635 0.8197939         nan        nan
#  0.82182179 0.8250212         nan        nan 0.85367586 0.82938325
#         nan        nan 0.84947135 0.81662724        nan        nan
#  0.81865815 0.82381496        nan        nan 0.84400574 0.8260719
#         nan        nan 0.8187515  0.82129617        nan        nan
#  0.83849854 0.83371543        nan        nan 0.81546958 0.82417089
#         nan        nan 0.84329453 0.83586996        nan        nan
#  0.84220725 0.82645577        nan        nan 0.84247407 0.8338162
#         nan        nan 0.83159985 0.83050684        nan        nan
#  0.84143328 0.83681148        nan        nan 0.81846415 0.8313073 ]
#                                                                               11   \
# mean_fit_time                                                            1.365331
# std_fit_time                                                             0.017421
# mean_score_time                                                          0.223324
# std_score_time                                                           0.008975
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.611111
# split1_test_recall                                                       0.444444
# split2_test_recall                                                       0.555556
# split3_test_recall                                                       0.823529
# split4_test_recall                                                       0.647059
# mean_test_recall                                                          0.61634
# std_test_recall                                                          0.124211
# rank_test_recall                                                                1
# split0_test_precision                                                    0.423077
# split1_test_precision                                                        0.32
# split2_test_precision                                                    0.416667
# split3_test_precision                                                    0.424242
# split4_test_precision                                                        0.25
# mean_test_precision                                                      0.366797
# std_test_precision                                                       0.070407
# rank_test_precision                                                            42
# split0_test_f1                                                                0.5
# split1_test_f1                                                           0.372093
# split2_test_f1                                                            0.47619
# split3_test_f1                                                               0.56
# split4_test_f1                                                           0.360656
# mean_test_f1                                                             0.453788
# std_test_f1                                                              0.076506
# rank_test_f1                                                                   23
# split0_test_roc_auc                                                      0.793981
# split1_test_roc_auc                                                      0.753157
# split2_test_roc_auc                                                      0.764941
# split3_test_roc_auc                                                      0.879478
# split4_test_roc_auc                                                      0.826183
# mean_test_roc_auc                                                        0.803548
# std_test_roc_auc                                                         0.045605
# rank_test_roc_auc                                                              72
#
#                                                                               51   \
# mean_fit_time                                                            1.081876
# std_fit_time                                                             0.047418
# mean_score_time                                                          0.160416
# std_score_time                                                            0.02571
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.611111
# split1_test_recall                                                       0.555556
# split2_test_recall                                                       0.555556
# split3_test_recall                                                       0.764706
# split4_test_recall                                                       0.588235
# mean_test_recall                                                         0.615033
# std_test_recall                                                          0.077731
# rank_test_recall                                                                2
# split0_test_precision                                                     0.52381
# split1_test_precision                                                     0.37037
# split2_test_precision                                                    0.357143
# split3_test_precision                                                    0.371429
# split4_test_precision                                                    0.243902
# mean_test_precision                                                      0.373331
# std_test_precision                                                       0.089073
# rank_test_precision                                                            34
# split0_test_f1                                                           0.564103
# split1_test_f1                                                           0.444444
# split2_test_f1                                                           0.434783
# split3_test_f1                                                                0.5
# split4_test_f1                                                           0.344828
# mean_test_f1                                                             0.457631
# std_test_f1                                                              0.072872
# rank_test_f1                                                                   18
# split0_test_roc_auc                                                      0.861111
# split1_test_roc_auc                                                      0.772938
# split2_test_roc_auc                                                       0.81734
# split3_test_roc_auc                                                      0.884564
# split4_test_roc_auc                                                      0.758956
# mean_test_roc_auc                                                        0.818982
# std_test_roc_auc                                                         0.048583
# rank_test_roc_auc                                                              56
#
#                                                                               31   \
# mean_fit_time                                                            0.979387
# std_fit_time                                                             0.045819
# mean_score_time                                                            0.1464
# std_score_time                                                           0.005472
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                       0.444444
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.764706
# split4_test_recall                                                       0.529412
# mean_test_recall                                                         0.614379
# std_test_recall                                                          0.113281
# rank_test_recall                                                                3
# split0_test_precision                                                    0.461538
# split1_test_precision                                                        0.32
# split2_test_precision                                                    0.307692
# split3_test_precision                                                     0.40625
# split4_test_precision                                                    0.272727
# mean_test_precision                                                      0.353642
# std_test_precision                                                        0.06957
# rank_test_precision                                                            53
# split0_test_f1                                                           0.545455
# split1_test_f1                                                           0.372093
# split2_test_f1                                                           0.421053
# split3_test_f1                                                           0.530612
# split4_test_f1                                                               0.36
# mean_test_f1                                                             0.445842
# std_test_f1                                                              0.078142
# rank_test_f1                                                                   29
# split0_test_roc_auc                                                      0.842382
# split1_test_roc_auc                                                      0.755471
# split2_test_roc_auc                                                       0.84133
# split3_test_roc_auc                                                      0.883016
# split4_test_roc_auc                                                      0.778417
# mean_test_roc_auc                                                        0.820123
# std_test_roc_auc                                                         0.046519
# rank_test_roc_auc                                                              53
#
#                                                                               87   \
# mean_fit_time                                                            1.930897
# std_fit_time                                                             0.012019
# mean_score_time                                                          0.248198
# std_score_time                                                           0.003756
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.388889
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.823529
# split4_test_recall                                                       0.705882
# mean_test_recall                                                         0.605882
# std_test_recall                                                          0.152115
# rank_test_recall                                                                4
# split0_test_precision                                                        0.45
# split1_test_precision                                                    0.291667
# split2_test_precision                                                    0.407407
# split3_test_precision                                                      0.4375
# split4_test_precision                                                    0.266667
# mean_test_precision                                                      0.370648
# std_test_precision                                                       0.076377
# rank_test_precision                                                            37
# split0_test_f1                                                           0.473684
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.488889
# split3_test_f1                                                           0.571429
# split4_test_f1                                                           0.387097
# mean_test_f1                                                             0.450886
# std_test_f1                                                              0.082924
# rank_test_f1                                                                   25
# split0_test_roc_auc                                                       0.78388
# split1_test_roc_auc                                                      0.752525
# split2_test_roc_auc                                                      0.843855
# split3_test_roc_auc                                                      0.891641
# split4_test_roc_auc                                                      0.827068
# mean_test_roc_auc                                                        0.819794
# std_test_roc_auc                                                         0.048184
# rank_test_roc_auc                                                              54
#
#                                                                               55   \
# mean_fit_time                                                            1.136281
# std_fit_time                                                             0.036394
# mean_score_time                                                          0.147652
# std_score_time                                                           0.006284
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            0.5
# split1_test_recall                                                            0.5
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.705882
# split4_test_recall                                                       0.705882
# mean_test_recall                                                         0.604575
# std_test_recall                                                          0.092131
# rank_test_recall                                                                5
# split0_test_precision                                                      0.5625
# split1_test_precision                                                    0.310345
# split2_test_precision                                                    0.392857
# split3_test_precision                                                    0.413793
# split4_test_precision                                                    0.285714
# mean_test_precision                                                      0.393042
# std_test_precision                                                       0.097473
# rank_test_precision                                                            24
# split0_test_f1                                                           0.529412
# split1_test_f1                                                           0.382979
# split2_test_f1                                                           0.478261
# split3_test_f1                                                           0.521739
# split4_test_f1                                                            0.40678
# mean_test_f1                                                             0.463834
# std_test_f1                                                              0.059421
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.809975
# split1_test_roc_auc                                                      0.796507
# split2_test_roc_auc                                                       0.86048
# split3_test_roc_auc                                                       0.85847
# split4_test_roc_auc                                                      0.836798
# mean_test_roc_auc                                                        0.832446
# std_test_roc_auc                                                         0.025607
# rank_test_roc_auc                                                              30
#
#                                                                               27   \
# mean_fit_time                                                            0.940867
# std_fit_time                                                             0.077797
# mean_score_time                                                          0.142115
# std_score_time                                                           0.009276
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.555556
# split1_test_recall                                                       0.388889
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.705882
# split4_test_recall                                                       0.705882
# mean_test_recall                                                         0.604575
# std_test_recall                                                          0.121083
# rank_test_recall                                                                5
# split0_test_precision                                                    0.434783
# split1_test_precision                                                    0.291667
# split2_test_precision                                                    0.387097
# split3_test_precision                                                         0.4
# split4_test_precision                                                    0.235294
# mean_test_precision                                                      0.349768
# std_test_precision                                                       0.074329
# rank_test_precision                                                            57
# split0_test_f1                                                           0.487805
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.489796
# split3_test_f1                                                           0.510638
# split4_test_f1                                                           0.352941
# mean_test_f1                                                             0.434903
# std_test_f1                                                              0.075607
# rank_test_f1                                                                   42
# split0_test_roc_auc                                                      0.856061
# split1_test_roc_auc                                                      0.775884
# split2_test_roc_auc                                                      0.858375
# split3_test_roc_auc                                                      0.860239
# split4_test_roc_auc                                                      0.824856
# mean_test_roc_auc                                                        0.835083
# std_test_roc_auc                                                         0.032325
# rank_test_roc_auc                                                              25
#
#                                                                               143  \
# mean_fit_time                                                            2.036363
# std_fit_time                                                             0.144343
# mean_score_time                                                          0.216526
# std_score_time                                                           0.013575
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       800
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.611111
# split1_test_recall                                                       0.388889
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.823529
# split4_test_recall                                                       0.588235
# mean_test_recall                                                         0.604575
# std_test_recall                                                          0.137705
# rank_test_recall                                                                5
# split0_test_precision                                                    0.458333
# split1_test_precision                                                        0.28
# split2_test_precision                                                    0.282051
# split3_test_precision                                                    0.451613
# split4_test_precision                                                    0.263158
# mean_test_precision                                                      0.347031
# std_test_precision                                                       0.088403
# rank_test_precision                                                            58
# split0_test_f1                                                            0.52381
# split1_test_f1                                                           0.325581
# split2_test_f1                                                           0.385965
# split3_test_f1                                                           0.583333
# split4_test_f1                                                           0.363636
# mean_test_f1                                                             0.436465
# std_test_f1                                                              0.099347
# rank_test_f1                                                                   39
# split0_test_roc_auc                                                      0.848485
# split1_test_roc_auc                                                        0.7742
# split2_test_roc_auc                                                      0.825758
# split3_test_roc_auc                                                      0.896948
# split4_test_roc_auc                                                      0.811146
# mean_test_roc_auc                                                        0.831307
# std_test_roc_auc                                                         0.040749
# rank_test_roc_auc                                                              33
#
#                                                                               59   \
# mean_fit_time                                                              1.7688
# std_fit_time                                                             0.022822
# mean_score_time                                                          0.256626
# std_score_time                                                           0.010193
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.611111
# split1_test_recall                                                            0.5
# split2_test_recall                                                       0.555556
# split3_test_recall                                                       0.647059
# split4_test_recall                                                       0.705882
# mean_test_recall                                                         0.603922
# std_test_recall                                                          0.071341
# rank_test_recall                                                                8
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.473684
# split2_test_precision                                                    0.322581
# split3_test_precision                                                    0.423077
# split4_test_precision                                                     0.26087
# mean_test_precision                                                      0.396042
# std_test_precision                                                       0.090813
# rank_test_precision                                                            17
# split0_test_f1                                                               0.55
# split1_test_f1                                                           0.486486
# split2_test_f1                                                           0.408163
# split3_test_f1                                                           0.511628
# split4_test_f1                                                           0.380952
# mean_test_f1                                                             0.467446
# std_test_f1                                                              0.063443
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.868056
# split1_test_roc_auc                                                      0.784301
# split2_test_roc_auc                                                       0.84112
# split3_test_roc_auc                                                      0.867758
# split4_test_roc_auc                                                      0.819328
# mean_test_roc_auc                                                        0.836112
# std_test_roc_auc                                                         0.031664
# rank_test_roc_auc                                                              20
#
#                                                                               39   \
# mean_fit_time                                                            1.524981
# std_fit_time                                                             0.024549
# mean_score_time                                                          0.237757
# std_score_time                                                           0.025959
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                       0.444444
# split2_test_recall                                                       0.555556
# split3_test_recall                                                       0.705882
# split4_test_recall                                                       0.647059
# mean_test_recall                                                         0.603922
# std_test_recall                                                          0.093772
# rank_test_recall                                                                9
# split0_test_precision                                                    0.428571
# split1_test_precision                                                    0.275862
# split2_test_precision                                                    0.294118
# split3_test_precision                                                       0.375
# split4_test_precision                                                    0.314286
# mean_test_precision                                                      0.337567
# std_test_precision                                                       0.056428
# rank_test_precision                                                            62
# split0_test_f1                                                           0.521739
# split1_test_f1                                                           0.340426
# split2_test_f1                                                           0.384615
# split3_test_f1                                                           0.489796
# split4_test_f1                                                           0.423077
# mean_test_f1                                                             0.431931
# std_test_f1                                                              0.066489
# rank_test_f1                                                                   48
# split0_test_roc_auc                                                      0.848485
# split1_test_roc_auc                                                       0.77399
# split2_test_roc_auc                                                      0.848274
# split3_test_roc_auc                                                       0.88567
# split4_test_roc_auc                                                      0.806059
# mean_test_roc_auc                                                        0.832496
# std_test_roc_auc                                                         0.038611
# rank_test_roc_auc                                                              29
#
#                                                                               75   \
# mean_fit_time                                                            1.328741
# std_fit_time                                                             0.010471
# mean_score_time                                                           0.16947
# std_score_time                                                           0.007936
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                       0.388889
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.705882
# split4_test_recall                                                       0.647059
# mean_test_recall                                                         0.603922
# std_test_recall                                                           0.11179
# rank_test_recall                                                                9
# split0_test_precision                                                    0.413793
# split1_test_precision                                                    0.233333
# split2_test_precision                                                    0.297297
# split3_test_precision                                                    0.444444
# split4_test_precision                                                    0.289474
# mean_test_precision                                                      0.335668
# std_test_precision                                                       0.080018
# rank_test_precision                                                            64
# split0_test_f1                                                           0.510638
# split1_test_f1                                                           0.291667
# split2_test_f1                                                                0.4
# split3_test_f1                                                           0.545455
# split4_test_f1                                                                0.4
# mean_test_f1                                                             0.429552
# std_test_f1                                                              0.090297
# rank_test_f1                                                                   52
# split0_test_roc_auc                                                       0.81713
# split1_test_roc_auc                                                      0.762416
# split2_test_roc_auc                                                      0.815657
# split3_test_roc_auc                                                      0.888103
# split4_test_roc_auc                                                      0.818443
# mean_test_roc_auc                                                         0.82035
# std_test_roc_auc                                                         0.039957
# rank_test_roc_auc                                                              52
#
#                                                                               127  \
# mean_fit_time                                                            0.958771
# std_fit_time                                                             0.007241
# mean_score_time                                                          0.153671
# std_score_time                                                           0.001771
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.388889
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.823529
# split4_test_recall                                                       0.588235
# mean_test_recall                                                         0.593464
# std_test_recall                                                          0.147582
# rank_test_recall                                                               11
# split0_test_precision                                                    0.310345
# ...
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  121
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             142
#
#                                                                               65   \
# mean_fit_time                                                            0.004582
# std_fit_time                                                             0.000622
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       800
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              141
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           115
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  118
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             123
#
#                                                                               64   \
# mean_fit_time                                                             0.00398
# std_fit_time                                                             0.000279
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       800
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              142
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           116
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  124
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             122
#
#                                                                               77   \
# mean_fit_time                                                            0.005399
# std_fit_time                                                             0.001413
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              143
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           106
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  119
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             136
#
#                                                                               0
# mean_fit_time                                                            0.002426
# std_fit_time                                                             0.000213
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              144
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           144
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  144
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             144
#
# [43 rows x 144 columns]

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Calculate the feature importance
clf = gscv.best_estimator_.steps[2][1]
rf_importances = clf.feature_importances_
rf_importances_df = pd.DataFrame(data = rf_importances, index = X.columns, columns=["importance"])  
rf_importances_df = rf_importances_df.sort_values(by="importance", ascending=False)
rf_importances_df
# Out:
#                        importance
# Dinophysis fortii        0.122744
# salinity                 0.089424
# air temp                 0.082691
# DSP                      0.075600
# DIN                      0.071066
# precipitation            0.070016
# Chl-a                    0.067553
# wind strength            0.064845
# sun [h]                  0.064668
# Soca                     0.061823
# T                        0.051313
# PO4-P                    0.049698
# Phalacroma rotundatum    0.040923
# month                    0.033751
# Dinophysis caudata       0.020314
# Dinophysis sacculus      0.019230
# Dinophysis tripos        0.014342

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

rf = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf, X, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
# Out:
# Text(0.5, 1.0, 'Permutation Importance Random Forest')

# %%
# Get feature importance with SHAP
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)
RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

# one-hot encoding of month feature
Xohe = pd.get_dummies(X, columns=["month"])

X_display = Xohe.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xohe)
Xsc = pd.DataFrame(scaled_array, columns=Xohe.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE()),
    ('under', RandomUnderSampler()),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.4, 0.5, 0.6],
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
             }
nfolds = 3
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "recall")
resultsGSCV = gscv.fit(Xsc, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
#                                                                               74   \
# mean_fit_time                                                            0.201671
# std_fit_time                                                             0.105322
# mean_score_time                                                          0.012542
# std_score_time                                                           0.000185
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                       0.689655
# split2_test_recall                                                       0.758621
# mean_test_recall                                                         0.704981
# std_test_recall                                                          0.039073
# rank_test_recall                                                                1
# split0_test_precision                                                    0.181818
# split1_test_precision                                                    0.148148
# split2_test_precision                                                    0.196429
# mean_test_precision                                                      0.175465
# std_test_precision                                                       0.020216
# rank_test_precision                                                           193
# split0_test_f1                                                           0.285714
# split1_test_f1                                                           0.243902
# split2_test_f1                                                           0.312057
# mean_test_f1                                                             0.280558
# std_test_f1                                                              0.028062
# rank_test_f1                                                                  125
# split0_test_roc_auc                                                       0.62947
# split1_test_roc_auc                                                      0.592682
# split2_test_roc_auc                                                      0.753706
# mean_test_roc_auc                                                        0.658619
# std_test_roc_auc                                                         0.068893
# rank_test_roc_auc                                                              75
#
#                                                                               88   \
# mean_fit_time                                                            0.224862
# std_fit_time                                                             0.037575
# mean_score_time                                                          0.011847
# std_score_time                                                           0.000633
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.633333
# split1_test_recall                                                       0.793103
# split2_test_recall                                                       0.448276
# mean_test_recall                                                         0.624904
# std_test_recall                                                          0.140901
# rank_test_recall                                                                2
# split0_test_precision                                                    0.195876
# split1_test_precision                                                    0.193277
# split2_test_precision                                                     0.19697
# mean_test_precision                                                      0.195374
# std_test_precision                                                       0.001549
# rank_test_precision                                                           170
# split0_test_f1                                                           0.299213
# split1_test_f1                                                           0.310811
# split2_test_f1                                                           0.273684
# mean_test_f1                                                             0.294569
# std_test_f1                                                              0.015508
# rank_test_f1                                                                   95
# split0_test_roc_auc                                                      0.631667
# split1_test_roc_auc                                                      0.700343
# split2_test_roc_auc                                                      0.542596
# mean_test_roc_auc                                                        0.624869
# std_test_roc_auc                                                         0.064579
# rank_test_roc_auc                                                             161
#
#                                                                               92   \
# mean_fit_time                                                            0.264262
# std_fit_time                                                             0.109904
# mean_score_time                                                           0.01357
# std_score_time                                                           0.001285
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.633333
# split1_test_recall                                                       0.586207
# split2_test_recall                                                        0.62069
# mean_test_recall                                                          0.61341
# std_test_recall                                                          0.019916
# rank_test_recall                                                                3
# split0_test_precision                                                    0.153226
# split1_test_precision                                                    0.265625
# split2_test_precision                                                    0.268657
# mean_test_precision                                                      0.229169
# std_test_precision                                                       0.053714
# rank_test_precision                                                           103
# split0_test_f1                                                           0.246753
# split1_test_f1                                                           0.365591
# split2_test_f1                                                              0.375
# mean_test_f1                                                             0.329115
# std_test_f1                                                              0.058365
# rank_test_f1                                                                   25
# split0_test_roc_auc                                                      0.588106
# split1_test_roc_auc                                                      0.738571
# split2_test_roc_auc                                                      0.772351
# mean_test_roc_auc                                                        0.699676
# std_test_roc_auc                                                         0.080088
# rank_test_roc_auc                                                               9
#
#                                                                               39   \
# mean_fit_time                                                            0.420704
# std_fit_time                                                             0.053358
# mean_score_time                                                          0.012885
# std_score_time                                                           0.001404
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.766667
# split1_test_recall                                                       0.655172
# split2_test_recall                                                        0.37931
# mean_test_recall                                                         0.600383
# std_test_recall                                                          0.162814
# rank_test_recall                                                                4
# split0_test_precision                                                    0.194915
# split1_test_precision                                                     0.24359
# split2_test_precision                                                    0.189655
# mean_test_precision                                                      0.209387
# std_test_precision                                                        0.02428
# rank_test_precision                                                           143
# split0_test_f1                                                           0.310811
# split1_test_f1                                                            0.35514
# split2_test_f1                                                           0.252874
# mean_test_f1                                                             0.306275
# std_test_f1                                                              0.041873
# rank_test_f1                                                                   69
# split0_test_roc_auc                                                      0.694091
# split1_test_roc_auc                                                      0.726478
# split2_test_roc_auc                                                      0.728741
# mean_test_roc_auc                                                        0.716437
# std_test_roc_auc                                                         0.015828
# rank_test_roc_auc                                                               3
#
#                                                                               83   \
# mean_fit_time                                                             0.33523
# std_fit_time                                                             0.051811
# mean_score_time                                                          0.012052
# std_score_time                                                           0.000203
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.633333
# split1_test_recall                                                       0.586207
# split2_test_recall                                                       0.551724
# mean_test_recall                                                         0.590421
# std_test_recall                                                           0.03345
# rank_test_recall                                                                5
# split0_test_precision                                                    0.133803
# split1_test_precision                                                    0.202381
# split2_test_precision                                                    0.164948
# mean_test_precision                                                      0.167044
# std_test_precision                                                       0.028036
# rank_test_precision                                                           201
# split0_test_f1                                                            0.22093
# split1_test_f1                                                           0.300885
# split2_test_f1                                                           0.253968
# mean_test_f1                                                             0.258594
# std_test_f1                                                              0.032805
# rank_test_f1                                                                  167
# split0_test_roc_auc                                                      0.541515
# split1_test_roc_auc                                                      0.716336
# split2_test_roc_auc                                                       0.67257
# mean_test_roc_auc                                                        0.643474
# std_test_roc_auc                                                         0.074277
# rank_test_roc_auc                                                             123
#
#                                                                               195  \
# mean_fit_time                                                            0.629265
# std_fit_time                                                             0.478876
# mean_score_time                                                          0.012385
# std_score_time                                                           0.000239
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                            0.7
# split1_test_recall                                                        0.62069
# split2_test_recall                                                       0.448276
# mean_test_recall                                                         0.589655
# std_test_recall                                                          0.105083
# rank_test_recall                                                                6
# split0_test_precision                                                         0.3
# split1_test_precision                                                        0.25
# split2_test_precision                                                    0.236364
# mean_test_precision                                                      0.262121
# std_test_precision                                                       0.027357
# rank_test_precision                                                            28
# split0_test_f1                                                               0.42
# split1_test_f1                                                           0.356436
# split2_test_f1                                                           0.309524
# mean_test_f1                                                             0.361986
# std_test_f1                                                              0.045272
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.780909
# split1_test_roc_auc                                                      0.695272
# split2_test_roc_auc                                                      0.718131
# mean_test_roc_auc                                                        0.731437
# std_test_roc_auc                                                         0.036205
# rank_test_roc_auc                                                               1
#
#                                                                               28   \
# mean_fit_time                                                            0.280449
# std_fit_time                                                             0.084825
# mean_score_time                                                          0.012861
# std_score_time                                                           0.001765
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.633333
# split1_test_recall                                                       0.655172
# split2_test_recall                                                       0.448276
# mean_test_recall                                                         0.578927
# std_test_recall                                                          0.092814
# rank_test_recall                                                                7
# split0_test_precision                                                    0.204301
# split1_test_precision                                                    0.218391
# split2_test_precision                                                    0.175676
# mean_test_precision                                                      0.199456
# std_test_precision                                                       0.017772
# rank_test_precision                                                           160
# split0_test_f1                                                           0.308943
# split1_test_f1                                                           0.327586
# split2_test_f1                                                           0.252427
# mean_test_f1                                                             0.296319
# std_test_f1                                                              0.031956
# rank_test_f1                                                                   89
# split0_test_roc_auc                                                      0.653333
# split1_test_roc_auc                                                      0.684584
# split2_test_roc_auc                                                      0.617335
# mean_test_roc_auc                                                        0.651751
# std_test_roc_auc                                                         0.027477
# rank_test_roc_auc                                                              96
#
#                                                                               204  \
# mean_fit_time                                                            0.502488
# std_fit_time                                                             0.274425
# mean_score_time                                                           0.01317
# std_score_time                                                           0.000486
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.833333
# split1_test_recall                                                       0.448276
# split2_test_recall                                                       0.448276
# mean_test_recall                                                         0.576628
# std_test_recall                                                          0.181518
# rank_test_recall                                                                8
# split0_test_precision                                                    0.185185
# split1_test_precision                                                    0.393939
# split2_test_precision                                                    0.156627
# mean_test_precision                                                       0.24525
# std_test_precision                                                       0.105783
# rank_test_precision                                                            62
# split0_test_f1                                                            0.30303
# split1_test_f1                                                           0.419355
# split2_test_f1                                                           0.232143
# mean_test_f1                                                             0.318176
# std_test_f1                                                              0.077176
# rank_test_f1                                                                   43
# split0_test_roc_auc                                                       0.67303
# split1_test_roc_auc                                                       0.78655
# split2_test_roc_auc                                                      0.556561
# mean_test_roc_auc                                                        0.672047
# std_test_roc_auc                                                         0.093895
# rank_test_roc_auc                                                              42
#
#                                                                               177  \
# mean_fit_time                                                            0.509814
# std_fit_time                                                             0.196654
# mean_score_time                                                          0.014026
# std_score_time                                                           0.000102
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.566667
# split1_test_recall                                                       0.482759
# split2_test_recall                                                       0.655172
# mean_test_recall                                                         0.568199
# std_test_recall                                                          0.070396
# rank_test_recall                                                                9
# split0_test_precision                                                    0.236111
# split1_test_precision                                                    0.225806
# split2_test_precision                                                    0.240506
# mean_test_precision                                                      0.234141
# std_test_precision                                                       0.006161
# rank_test_precision                                                            85
# split0_test_f1                                                           0.333333
# split1_test_f1                                                           0.307692
# split2_test_f1                                                           0.351852
# mean_test_f1                                                             0.330959
# std_test_f1                                                              0.018106
# rank_test_f1                                                                   20
# split0_test_roc_auc                                                      0.700833
# split1_test_roc_auc                                                      0.669761
# split2_test_roc_auc                                                      0.734826
# mean_test_roc_auc                                                        0.701807
# std_test_roc_auc                                                         0.026571
# rank_test_roc_auc                                                               7
#
#                                                                               149  \
# mean_fit_time                                                            0.310729
# std_fit_time                                                             0.220794
# mean_score_time                                                          0.013163
# std_score_time                                                           0.000077
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.666667
# split1_test_recall                                                       0.448276
# split2_test_recall                                                       0.586207
# mean_test_recall                                                          0.56705
# std_test_recall                                                          0.090181
# rank_test_recall                                                               10
# split0_test_precision                                                      0.3125
# split1_test_precision                                                    0.254902
# split2_test_precision                                                    0.242857
# mean_test_precision                                                      0.270086
# std_test_precision                                                       0.030391
# rank_test_precision                                                            22
# split0_test_f1                                                           0.425532
# split1_test_f1                                                              0.325
# split2_test_f1                                                           0.343434
# mean_test_f1                                                             0.364655
# std_test_f1                                                              0.043699
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                       0.79197
# split1_test_roc_auc                                                      0.635513
# split2_test_roc_auc                                                      0.710797
# mean_test_roc_auc                                                         0.71276
# std_test_roc_auc                                                         0.063888
# rank_test_roc_auc                                                               4
#
#                                                                               45   \
# mean_fit_time                                                            0.637517
# std_fit_time                                                             0.149807
# mean_score_time                                                          0.012125
# std_score_time                                                           0.000663
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.766667
# split1_test_recall                                                       0.344828
# split2_test_recall                                                       0.586207
# mean_test_recall                                                           0.5659
# std_test_recall                                                          0.172813
# rank_test_recall                                                               11
# split0_test_precision                                                    0.181102
# split1_test_precision                                                    0.208333
# split2_test_precision                                                    0.204819
# mean_test_precision                                                      0.198085
# std_test_precision                                                       0.012094
# rank_test_precision                                                           164
# split0_test_f1                                                           0.292994
# split1_test_f1                                                            0.25974
# split2_test_f1                                                           0.303571
# mean_test_f1                                                             0.285435
# std_test_f1                                                              0.018675
# rank_test_f1                                                                  108
# split0_test_roc_auc                                                      0.655909
# split1_test_roc_auc                                                      0.634576
# split2_test_roc_auc                                                      0.660321
# mean_test_roc_auc                                                        0.650269
# std_test_roc_auc                                                         0.011242
# rank_test_roc_auc                                                             102
#
#                                                                               95   \
# mean_fit_time                                                            0.555849
# std_fit_time                                                             0.221319
# mean_score_time                                                          0.014378
# std_score_time                                                           0.002635
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.333333
# split1_test_recall                                                       0.655172
# split2_test_recall                                                       0.689655
# mean_test_recall                                                         0.559387
# std_test_recall                                                          0.160463
# rank_test_recall                                                               12
# split0_test_precision                                                    0.222222
# split1_test_precision                                                    0.148438
# split2_test_precision                                                     0.15748
# mean_test_precision                                                      0.176047
# std_test_precision                                                       0.032859
# rank_test_precision                                                           192
# split0_test_f1                                                           0.266667
# split1_test_f1                                                           0.242038
# split2_test_f1                                                            0.25641
# mean_test_f1                                                             0.255038
# std_test_f1                                                              0.010101
# rank_test_f1                                                                  170
# split0_test_roc_auc                                                      0.610606
# split1_test_roc_auc                                                      0.594086
# split2_test_roc_auc                                                      0.609533
# mean_test_roc_auc                                                        0.604742
# std_test_roc_auc                                                         0.007547
# rank_test_roc_auc                                                             190
#
#                                                                               20   \
# mean_fit_time                                                            0.286573
# std_fit_time                                                             0.169732
# mean_score_time                                                          0.012444
# std_score_time                                                           0.001098
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.533333
# split1_test_recall                                                       0.551724
# split2_test_recall                                                       0.586207
# mean_test_recall                                                         0.557088
# std_test_recall                                                          0.021916
# rank_test_recall                                                               13
# split0_test_precision                                                    0.202532
# split1_test_precision                                                    0.296296
# split2_test_precision                                                    0.220779
# mean_test_precision                                                      0.239869
# std_test_precision                                                        0.04059
# rank_test_precision                                                            76
# split0_test_f1                                                           0.293578
# split1_test_f1                                                           0.385542
# split2_test_f1                                                           0.320755
# mean_test_f1                                                             0.333292
# std_test_f1                                                              0.038577
# rank_test_f1                                                                   18
# split0_test_roc_auc                                                      0.647045
# split1_test_roc_auc                                                      0.701045
# split2_test_roc_auc                                                      0.721485
# mean_test_roc_auc                                                        0.689859
# std_test_roc_auc                                                         0.031403
# rank_test_roc_auc                                                              20
#
#                                                                               17   \
# mean_fit_time                                                             0.31408
# std_fit_time                                                             0.204567
# mean_score_time                                                          0.012149
# std_score_time                                                           0.000794
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                            0.4
# split1_test_recall                                                       0.586207
# split2_test_recall                                                       0.655172
# mean_test_recall                                                         0.547126
# std_test_recall                                                          0.107777
# rank_test_recall                                                               14
# split0_test_precision                                                    0.292683
# split1_test_precision                                                    0.314815
# split2_test_precision                                                    0.228916
# mean_test_precision                                                      0.278804
# std_test_precision                                                       0.036415
# rank_test_precision                                                            13
# split0_test_f1                                                           0.338028
# split1_test_f1                                                           0.409639
# split2_test_f1                                                           0.339286
# mean_test_f1                                                             0.362317
# std_test_f1                                                              0.033465
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.695909
# split1_test_roc_auc                                                      0.675144
# split2_test_roc_auc                                                      0.728039
# mean_test_roc_auc                                                        0.699697
# std_test_roc_auc                                                          0.02176
# rank_test_roc_auc                                                               8
#
#                                                                               119  \
# mean_fit_time                                                            0.192747
# std_fit_time                                                             0.043088
# mean_score_time                                                          0.014564
# std_score_time                                                           0.001484
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.466667
# split1_test_recall                                                        0.62069
# split2_test_recall                                                       0.551724
# mean_test_recall                                                          0.54636
# std_test_recall                                                          0.062994
# rank_test_recall                                                               15
# split0_test_precision                                                    0.142857
# split1_test_precision                                                    0.189474
# split2_test_precision                                                    0.242424
# mean_test_precision                                                      0.191585
# std_test_precision                                                       0.040676
# rank_test_precision                                                           177
# split0_test_f1                                                            0.21875
# split1_test_f1                                                           0.290323
# split2_test_f1                                                           0.336842
# mean_test_f1                                                             0.281972
# std_test_f1                                                              0.048571
# rank_test_f1                                                                  120
# split0_test_roc_auc                                                      0.584697
# split1_test_roc_auc                                                      0.660946
# split2_test_roc_auc                                                       0.64113
# mean_test_roc_auc                                                        0.628924
# std_test_roc_auc                                                         0.032303
# rank_test_roc_auc                                                             148
#
#                                 ...  \
# mean_fit_time                   ...
# std_fit_time                    ...
# mean_score_time                 ...
# std_score_time                  ...
# param_clf__hidden_layer_sizes   ...
# param_over__k_neighbors         ...
# param_over__sampling_strategy   ...
# param_under__sampling_strategy  ...
# params                          ...
# split0_test_recall              ...
# split1_test_recall              ...
# split2_test_recall              ...
# mean_test_recall                ...
# std_test_recall                 ...
# rank_test_recall                ...
# split0_test_precision           ...
# split1_test_precision           ...
# split2_test_precision           ...
# mean_test_precision             ...
# std_test_precision              ...
# rank_test_precision             ...
# split0_test_f1                  ...
# split1_test_f1                  ...
# split2_test_f1                  ...
# mean_test_f1                    ...
# std_test_f1                     ...
# rank_test_f1                    ...
# split0_test_roc_auc             ...
# split1_test_roc_auc             ...
# split2_test_roc_auc             ...
# mean_test_roc_auc               ...
# std_test_roc_auc                ...
# rank_test_roc_auc               ...
#
#                                                                               184  \
# mean_fit_time                                                             0.38865
# std_fit_time                                                             0.114299
# mean_score_time                                                          0.013271
# std_score_time                                                           0.001744
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.266667
# split1_test_recall                                                        0.37931
# split2_test_recall                                                       0.310345
# mean_test_recall                                                         0.318774
# std_test_recall                                                          0.046371
# rank_test_recall                                                              202
# split0_test_precision                                                    0.186047
# split1_test_precision                                                       0.275
# split2_test_precision                                                    0.169811
# mean_test_precision                                                      0.210286
# std_test_precision                                                       0.046237
# rank_test_precision                                                           139
# split0_test_f1                                                           0.219178
# split1_test_f1                                                           0.318841
# split2_test_f1                                                           0.219512
# mean_test_f1                                                              0.25251
# std_test_f1                                                              0.046903
# rank_test_f1                                                                  175
# split0_test_roc_auc                                                      0.593258
# split1_test_roc_auc                                                      0.673662
# split2_test_roc_auc                                                      0.565533
# mean_test_roc_auc                                                        0.610817
# std_test_roc_auc                                                         0.045857
# rank_test_roc_auc                                                             181
#
#                                                                               22   \
# mean_fit_time                                                            0.260834
# std_fit_time                                                             0.080395
# mean_score_time                                                          0.011256
# ...
# split0_test_precision                                                     0.27027
# split1_test_precision                                                    0.346154
# split2_test_precision                                                        0.12
# mean_test_precision                                                      0.245475
# std_test_precision                                                       0.093977
# rank_test_precision                                                            61
# split0_test_f1                                                           0.298507
# split1_test_f1                                                           0.327273
# split2_test_f1                                                           0.151899
# mean_test_f1                                                             0.259226
# std_test_f1                                                              0.076795
# rank_test_f1                                                                  165
# split0_test_roc_auc                                                      0.681136
# split1_test_roc_auc                                                      0.631144
# split2_test_roc_auc                                                      0.491964
# mean_test_roc_auc                                                        0.601415
# std_test_roc_auc                                                         0.080039
# rank_test_roc_auc                                                             196
#
#                                                                               86   \
# mean_fit_time                                                            0.377537
# std_fit_time                                                             0.074338
# mean_score_time                                                          0.014914
# std_score_time                                                           0.003753
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                            0.1
# split1_test_recall                                                       0.310345
# split2_test_recall                                                        0.37931
# mean_test_recall                                                         0.263218
# std_test_recall                                                          0.118797
# rank_test_recall                                                              212
# split0_test_precision                                                    0.115385
# split1_test_precision                                                    0.236842
# split2_test_precision                                                    0.423077
# mean_test_precision                                                      0.258435
# std_test_precision                                                       0.126539
# rank_test_precision                                                            32
# split0_test_f1                                                           0.107143
# split1_test_f1                                                           0.268657
# split2_test_f1                                                                0.4
# mean_test_f1                                                               0.2586
# std_test_f1                                                               0.11977
# rank_test_f1                                                                  166
# split0_test_roc_auc                                                      0.635985
# split1_test_roc_auc                                                      0.655016
# split2_test_roc_auc                                                      0.743954
# mean_test_roc_auc                                                        0.678318
# std_test_roc_auc                                                         0.047057
# rank_test_roc_auc                                                              32
#
#                                                                               112  \
# mean_fit_time                                                            0.827041
# std_fit_time                                                             0.356551
# mean_score_time                                                          0.013059
# std_score_time                                                           0.002268
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.103448
# split2_test_recall                                                       0.137931
# mean_test_recall                                                         0.247126
# std_test_recall                                                          0.179362
# rank_test_recall                                                              213
# split0_test_precision                                                      0.3125
# split1_test_precision                                                    0.111111
# split2_test_precision                                                    0.102564
# mean_test_precision                                                      0.175392
# std_test_precision                                                       0.097013
# rank_test_precision                                                           194
# split0_test_f1                                                           0.384615
# split1_test_f1                                                           0.107143
# split2_test_f1                                                           0.117647
# mean_test_f1                                                             0.203135
# std_test_f1                                                              0.128398
# rank_test_f1                                                                  205
# split0_test_roc_auc                                                      0.733485
# split1_test_roc_auc                                                      0.589171
# split2_test_roc_auc                                                       0.61125
# mean_test_roc_auc                                                        0.644635
# std_test_roc_auc                                                         0.063469
# rank_test_roc_auc                                                             120
#
#                                                                               90   \
# mean_fit_time                                                            0.221483
# std_fit_time                                                             0.156726
# mean_score_time                                                            0.0124
# std_score_time                                                           0.000974
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                            0.0
# split1_test_recall                                                       0.344828
# split2_test_recall                                                        0.37931
# mean_test_recall                                                         0.241379
# std_test_recall                                                          0.171261
# rank_test_recall                                                              214
# split0_test_precision                                                         0.0
# split1_test_precision                                                    0.172414
# split2_test_precision                                                     0.23913
# mean_test_precision                                                      0.137181
# std_test_precision                                                       0.100753
# rank_test_precision                                                           210
# split0_test_f1                                                                0.0
# split1_test_f1                                                           0.229885
# split2_test_f1                                                           0.293333
# mean_test_f1                                                             0.174406
# std_test_f1                                                              0.126015
# rank_test_f1                                                                  214
# split0_test_roc_auc                                                           0.5
# split1_test_roc_auc                                                      0.584491
# split2_test_roc_auc                                                      0.691372
# mean_test_roc_auc                                                        0.591954
# std_test_roc_auc                                                         0.078305
# rank_test_roc_auc                                                             206
#
#                                                                               5    \
# mean_fit_time                                                            0.530679
# std_fit_time                                                             0.308864
# mean_score_time                                                          0.011512
# std_score_time                                                           0.000379
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                            0.1
# split1_test_recall                                                       0.275862
# split2_test_recall                                                       0.275862
# mean_test_recall                                                         0.217241
# std_test_recall                                                          0.082902
# rank_test_recall                                                              215
# split0_test_precision                                                    0.111111
# split1_test_precision                                                    0.285714
# split2_test_precision                                                    0.242424
# mean_test_precision                                                      0.213083
# std_test_precision                                                       0.074239
# rank_test_precision                                                           127
# split0_test_f1                                                           0.105263
# split1_test_f1                                                           0.280702
# split2_test_f1                                                           0.258065
# mean_test_f1                                                             0.214676
# std_test_f1                                                              0.077917
# rank_test_f1                                                                  200
# split0_test_roc_auc                                                      0.601288
# split1_test_roc_auc                                                      0.665158
# split2_test_roc_auc                                                      0.677017
# mean_test_roc_auc                                                        0.647821
# std_test_roc_auc                                                         0.033258
# rank_test_roc_auc                                                             113
#
#                                                                               162
# mean_fit_time                                                            0.346946
# std_fit_time                                                             0.220094
# mean_score_time                                                          0.013122
# std_score_time                                                           0.000598
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                            0.0
# split1_test_recall                                                       0.413793
# split2_test_recall                                                       0.137931
# mean_test_recall                                                         0.183908
# std_test_recall                                                           0.17203
# rank_test_recall                                                              216
# split0_test_precision                                                         0.0
# split1_test_precision                                                    0.324324
# split2_test_precision                                                    0.190476
# mean_test_precision                                                        0.1716
# std_test_precision                                                       0.133076
# rank_test_precision                                                           199
# split0_test_f1                                                                0.0
# split1_test_f1                                                           0.363636
# split2_test_f1                                                               0.16
# mean_test_f1                                                             0.174545
# std_test_f1                                                               0.14881
# rank_test_f1                                                                  213
# split0_test_roc_auc                                                           0.5
# split1_test_roc_auc                                                      0.616321
# split2_test_roc_auc                                                      0.588859
# mean_test_roc_auc                                                        0.568393
# std_test_roc_auc                                                         0.049644
# rank_test_roc_auc                                                             215
#
# [33 rows x 216 columns]

# %% [markdown]
# #### Feature Importance (MLP)

# %%
# Feature importance of model (MLP)  (no cross-validation!)

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=3)

MLP = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(MLP, Xsc, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = Xsc.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance MLP")
# Out:
# Text(0.5, 1.0, 'Permutation Importance MLP')

# %% [markdown]
# #### Feature importance with SHAP

# %%
X = Xsc.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.25)

nn = MLPClassifier(hidden_layer_sizes=(3,3), solver='lbfgs', max_iter=5000)
model = nn.fit(X_train.to_numpy(), y_train)

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# explain the model's predictions using SHAP
import shap
import warnings
warnings.filterwarnings("ignore")
shap.initjs()

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,20))
shap_values = explainer.shap_values(X_test, nsamples=50)
shap.summary_plot(shap_values, X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
#   0%|          | 0/188 [00:00<?, ?it/s]

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,50))
shap_values = explainer.shap_values(X_test, nsamples=50)
for classid in [0,1]:
    shap.summary_plot(shap_values[classid], X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
#   0%|          | 0/188 [00:00<?, ?it/s]

# %%
# Try dependence contribution plot
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,50))
shap_values = explainer.shap_values(X_test, nsamples=50)
shap.dependence_plot('salinity', shap_values[1], X_test,) #interaction_index="salinity"
# Out:
#   0%|          | 0/188 [00:00<?, ?it/s]

# %% [markdown]
# Example intepretation: The fact this slopes upward says the higher the soca flow, the higher the model's prediction is for poz/neg. The spread suggests that other features must interact with Soca flow.
# In general, high Soca flow increases the chance of poz/neg. But if the sea temp is moderate or low, that trend reverses and even high soca flow does not increase preditions of poz/neg as the sea temp is too low.
# https://www.kaggle.com/code/dansbecker/advanced-uses-of-shap-values

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
instanceID = 10
instance = X.iloc[[instanceID]]
display_instance = X_display.iloc[[instanceID]]

prediction = model.predict(instance)[0]
prediction_probs = model.predict_proba(instance)[0]
print(f'real value: {y[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)
# Out:
# real value: 1,
# predicted: 1,
# predicted probs: [0.32465362 0.67534638]
# Explanation for prediction: class=1, p=0.6753463780420859
#   0%|          | 0/1 [00:00<?, ?it/s]
# <div id='iD2TJLYDNH0AGOJ7GSXL7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.15501669117158756, "outValue": 0.6753463780420859, "link": "identity", "featureNames": ["DSP", "Dinophysis caudata", "Dinophysis fortii", "Phalacroma rotundatum", "Dinophysis sacculus", "Dinophysis tripos", "sun [h]", "air temp", "wind strength", "precipitation", "Chl-a", "salinity", "T", "DIN", "PO4-P", "Soca", "month_1", "month_2", "month_3", "month_4", "month_5", "month_6", "month_7", "month_8", "month_9", "month_10", "month_11", "month_12"], "features": {"0": {"effect": 0.012869451438460522, "value": 228.0}, "1": {"effect": 0.013892293626515784, "value": 0.0}, "2": {"effect": 0.061465728590638424, "value": 222.0}, "3": {"effect": 0.04202741781416852, "value": 6.0}, "4": {"effect": -0.004124843359749053, "value": 0.0}, "5": {"effect": 0.0001622565008411181, "value": 0.0}, "6": {"effect": -0.047091316180778886, "value": 103.40000000000002}, "7": {"effect": -0.03496898950310201, "value": 14.77142857142857}, "8": {"effect": -0.04637333249895531, "value": 2.704761904761905}, "9": {"effect": 0.2218513110843935, "value": 219.9}, "10": {"effect": 0.03446285682035366, "value": 1.87}, "11": {"effect": -0.04294980701710549, "value": 37.53}, "12": {"effect": -0.01446912834345343, "value": 21.68}, "13": {"effect": 0.04078038463055926, "value": 4.469999894499782}, "14": {"effect": 0.11323466550741978, "value": 0.170000001788139}, "15": {"effect": -0.029123845658679204, "value": 1852.896}, "16": {"effect": -0.010692809034621276, "value": 0.0}, "19": {"effect": 0.01703195221509482, "value": 0.0}, "20": {"effect": 0.011369443910761612, "value": 0.0}, "21": {"effect": 0.024183322443649236, "value": 0.0}, "22": {"effect": -0.006941772632485577, "value": 0.0}, "23": {"effect": -0.037610847752033494, "value": 0.0}, "24": {"effect": 0.17041971905214276, "value": 1.0}, "26": {"effect": 0.022945537842442132, "value": 0.0}, "27": {"effect": 0.007980037374020865, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iD2TJLYDNH0AGOJ7GSXL7')
#   );
# </script>

# %% [markdown]
# Show the mean values of features as it may help understanding this particular instance data in the plot above.

# %%
data = pd.get_dummies(data, columns=["month"])


pd.DataFrame([data[data['lipophylic_toxins']=='neg'].mean(), data[data['lipophylic_toxins']=='poz'].mean()], index=['neg','pos']).T
# Out:
#                                neg          pos
# DSP                     102.700503   195.860294
# Dinophysis caudata       25.537688    40.543382
# Dinophysis fortii        23.725829    72.827941
# Phalacroma rotundatum    16.438492    13.510294
# Dinophysis sacculus      24.474070    52.823529
# Dinophysis tripos         4.902513     8.235294
# sun [h]                 165.661647   152.191912
# air temp                 17.422122    16.944328
# wind strength             2.997017     2.921674
# precipitation            56.557731    75.321324
# Chl-a                     0.791451     0.965165
# salinity                 37.476320    35.692370
# T                        20.112537    20.241136
# DIN                       2.921092     3.868770
# PO4-P                     0.058539     0.076768
# Soca                   3208.868147  3703.893351
# month_1                   0.015060     0.022059
# month_2                   0.021084     0.022059
# month_3                   0.028112     0.014706
# month_4                   0.066265     0.014706
# month_5                   0.089357     0.102941
# month_6                   0.115462     0.088235
# month_7                   0.125502     0.132353
# month_8                   0.126506     0.080882
# month_9                   0.143574     0.227941
# month_10                  0.138554     0.176471
# month_11                  0.091365     0.095588
# month_12                  0.039157     0.022059

# %% [markdown]
# ### Conclusion

# %%
# Summary table of prediction results
RF_recall = round(RF_recall_best_k[1], 2)
RF_auc = round(RF_auc_best_k[1], 2)
MLP_recall = round(MLP_recall_best_k[1], 2)
MLP_auc = round(MLP_auc_best_k[1], 2)

summary = pd.DataFrame(
    [
        (
            "RF",
            RF_recall_score,
            RF_auc_score,
        ),
        (
            "MLP",
            MLP_recall_score,
            MLP_auc_score,
        ),
        (
            "RF (smote)",
            RF_recall,
            RF_auc,
        ),
        (
            "MLP (smote)",
            MLP_recall,
            MLP_auc,
        ),
        (
            "Decision tree (J48)*",
            0.56,
            0.18,
        ),
    ],
    columns=("Model", "Recall", "ROC AUC"),
).set_index("Model")

print("Table summarising the prediction results of the used classifiers, both with and without SMOTE resampling:\n")
summary.round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 # Summary table of prediction results
# ----> 2 RF_recall = round(RF_recall_best_k[1], 2)
#       3 RF_auc = round(RF_auc_best_k[1], 2)
#       4 MLP_recall = round(MLP_recall_best_k[1], 2)
#
# NameError: name 'RF_recall_best_k' is not defined

# %% [markdown]
# As can be seen resampling with SMOTE helped to improve the results substantially, especially when calculating recall. The highest recall and ROC AUC was achieved with Random Forest with the re-sampled data. Both recall and ROC AUC suggest Random Forest as beeing the better classifier for this particular problem. Recall is a crucial metric as it gives indication of what fraction of true positive instances have been predicted. Since the models predict toxins in seashells (food) it is crucial that as few positives as possible are missed.
#
# Due to the use of SMOTE resampling (upsampling and downsampling) in combinaiton with cross-validation it was curcial to do the resampling within each fold to avoid data lekeage and validate on original (unsampled) data. In addition, I have optimised the model with regard to the k-values of SMOTE, all of which brought along some complexity. So for the parameter tuning of Random Forest and MLP various parameter settings have been tried  and the model with best performing settings has been chosen.
#
# The decision tree J48 algorithm was run within Weka on a slightly different dataset (missing values were not removed to use as many instances as possible, cross validation was 10-fold as opposed to 3-fold due to a higher dataset etc.) thus this results are not directly comparable but were provided as a reference to give an indication of the performance of this algorithm.
#
# As can be seen in the feature importance bar plots above, similar features were on the top despite using two different classification algorithms and two different feature ranking methods. If we consider just the three highest-ranking features of each of the feature ranking methods for both algortihms (RF and MLP) the features that overlap are DSP, DSP_like, ASP, Dinophysis fortii and Dinophysis caudata. These can be shown to the domain experts for validation and interpretation.
