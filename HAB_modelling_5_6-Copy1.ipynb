# %%
from datetime import datetime
import pandas as pd
import numpy as np
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from dtreeviz.trees import dtreeviz 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 30)

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")

# data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# SECCHI                   450
# DIN                      352
# PO4-P                    349
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
# data.drop(columns=["Chl-a","PO4-P","DIN","SECCHI"], inplace=True)
data.drop(columns=["SECCHI",  ], inplace=True)#,"Chl-a", "PO4-P", "DIN",
data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# DIN                      352
# PO4-P                    349
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Modelling and Preliminary Results

# %% [markdown]
# ![Screenshot 2022-07-26 at 12.15.26.png](attachment:500d2dd5-b27f-4f67-a0a0-94d4c6fc8714.png)

# %% [markdown]
# # Scikit-learn Analysis

# %% [markdown]
# ### Preprocessing

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    662
# poz     88
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# Clean the dataset by removing samples close to the decision boundary. Because the dataset is heavily imbalanced in favor of clas 0 (neg) we will remove instances from this class whenever finding samples which do not agree “enough” with their neighboorhood. The EditedNearestNeighbours will be used. One other option is to use Tomek links but it is more conservative and was found to perform slightly worse.

# %%
from collections import Counter
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours

print(f'Original dataset shape: {Counter(y)}')
usmp = EditedNearestNeighbours()
lastMajorityCount = Counter(y)[0]
for i in range(10):
    X_res, y_res = usmp.fit_resample(X, y)
    if Counter(y_res)[0] == lastMajorityCount:
        print('Cannot remove any more samples')
        break
    else:
        print(f'Resampled dataset shape {Counter(y_res)}')
        lastMajorityCount = Counter(y_res)[0]
    X = X_res
    y = y_res
# Out:
# Original dataset shape: Counter({0: 662, 1: 88})
# Resampled dataset shape Counter({0: 540, 1: 88})
# Resampled dataset shape Counter({0: 501, 1: 88})
# Resampled dataset shape Counter({0: 490, 1: 88})
# Resampled dataset shape Counter({0: 488, 1: 88})
# Resampled dataset shape Counter({0: 487, 1: 88})
# Cannot remove any more samples

# %%
# train test split
X, X_eval, y, y_eval = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.30)

# %% [markdown]
# ## Model Training and Evaluation

# %% [markdown]
# ### Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE()), 
    ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
            'clf__max_depth': [2,3,4],
            'clf__criterion': ['gini', 'entropy', 'log_loss'],
               'clf__class_weight': ['balanced', None],
               'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
               'under__sampling_strategy': [0.5, 0.6, 0.7],
               'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv_dt = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="f1",
                    n_jobs=-1)
resultsGSCV = gscv_dt.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
#                                                                               200  \
# mean_fit_time                                                            0.055232
# std_fit_time                                                             0.002699
# mean_score_time                                                          0.024669
# std_score_time                                                           0.001255
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.538462
# split1_test_recall                                                       0.923077
# split2_test_recall                                                            0.5
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.916667
# mean_test_recall                                                         0.742308
# std_test_recall                                                          0.185273
# rank_test_recall                                                                1
# split0_test_precision                                                    0.269231
# split1_test_precision                                                    0.230769
# split2_test_precision                                                     0.26087
# split3_test_precision                                                    0.204082
# split4_test_precision                                                    0.196429
# mean_test_precision                                                      0.232276
# std_test_precision                                                       0.029208
# rank_test_precision                                                           451
# split0_test_f1                                                           0.358974
# split1_test_f1                                                           0.369231
# split2_test_f1                                                           0.342857
# split3_test_f1                                                           0.327869
# split4_test_f1                                                           0.323529
# mean_test_f1                                                             0.344492
# std_test_f1                                                              0.017551
# rank_test_f1                                                                  304
# split0_test_roc_auc                                                      0.691742
# split1_test_roc_auc                                                      0.742647
# split2_test_roc_auc                                                      0.604779
# split3_test_roc_auc                                                       0.71201
# split4_test_roc_auc                                                      0.671569
# mean_test_roc_auc                                                        0.684549
# std_test_roc_auc                                                         0.046288
# rank_test_roc_auc                                                             146
# split0_test_recall_weighted                                              0.691358
# split1_test_recall_weighted                                              0.493827
# split2_test_recall_weighted                                                0.7125
# split3_test_recall_weighted                                                0.4875
# split4_test_recall_weighted                                                 0.425
# mean_test_recall_weighted                                                0.562037
# std_test_recall_weighted                                                 0.116919
# rank_test_recall_weighted                                                     482
#
#                                                                               198  \
# mean_fit_time                                                            0.049546
# std_fit_time                                                             0.004929
# mean_score_time                                                          0.023974
# std_score_time                                                           0.001322
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.538462
# split1_test_recall                                                       0.923077
# split2_test_recall                                                       0.666667
# split3_test_recall                                                           0.75
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.725641
# std_test_recall                                                          0.125445
# rank_test_recall                                                                2
# split0_test_precision                                                    0.304348
# split1_test_precision                                                    0.226415
# split2_test_precision                                                        0.25
# split3_test_precision                                                    0.243243
# split4_test_precision                                                    0.321429
# mean_test_precision                                                      0.269087
# std_test_precision                                                       0.036976
# rank_test_precision                                                           344
# split0_test_f1                                                           0.388889
# split1_test_f1                                                           0.363636
# split2_test_f1                                                           0.363636
# split3_test_f1                                                           0.367347
# split4_test_f1                                                               0.45
# mean_test_f1                                                             0.386702
# std_test_f1                                                              0.033015
# rank_test_f1                                                                   87
# split0_test_roc_auc                                                      0.753394
# split1_test_roc_auc                                                      0.745475
# split2_test_roc_auc                                                      0.621324
# split3_test_roc_auc                                                      0.754289
# split4_test_roc_auc                                                      0.713235
# mean_test_roc_auc                                                        0.717543
# std_test_roc_auc                                                         0.050384
# rank_test_roc_auc                                                              14
# split0_test_recall_weighted                                              0.728395
# split1_test_recall_weighted                                              0.481481
# split2_test_recall_weighted                                                  0.65
# split3_test_recall_weighted                                                0.6125
# split4_test_recall_weighted                                                 0.725
# mean_test_recall_weighted                                                0.639475
# std_test_recall_weighted                                                 0.090578
# rank_test_recall_weighted                                                     444
#
#                                                                               217  \
# mean_fit_time                                                            0.051973
# std_fit_time                                                             0.005251
# mean_score_time                                                          0.024769
# std_score_time                                                           0.003195
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.615385
# split1_test_recall                                                       0.769231
# split2_test_recall                                                       0.583333
# split3_test_recall                                                       0.833333
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.710256
# std_test_recall                                                            0.0952
# rank_test_recall                                                                3
# split0_test_precision                                                    0.190476
# split1_test_precision                                                    0.227273
# split2_test_precision                                                    0.159091
# split3_test_precision                                                    0.185185
# split4_test_precision                                                    0.391304
# mean_test_precision                                                      0.230666
# std_test_precision                                                       0.083214
# rank_test_precision                                                           454
# split0_test_f1                                                           0.290909
# split1_test_f1                                                           0.350877
# split2_test_f1                                                               0.25
# split3_test_f1                                                            0.30303
# split4_test_f1                                                           0.514286
# mean_test_f1                                                              0.34182
# std_test_f1                                                              0.092037
# rank_test_f1                                                                  318
# split0_test_roc_auc                                                      0.575792
# split1_test_roc_auc                                                      0.707579
# split2_test_roc_auc                                                      0.539828
# split3_test_roc_auc                                                      0.709559
# split4_test_roc_auc                                                      0.808211
# mean_test_roc_auc                                                        0.668194
# std_test_roc_auc                                                          0.09786
# rank_test_roc_auc                                                             260
# split0_test_recall_weighted                                              0.518519
# split1_test_recall_weighted                                               0.54321
# split2_test_recall_weighted                                                 0.475
# split3_test_recall_weighted                                                 0.425
# split4_test_recall_weighted                                                0.7875
# mean_test_recall_weighted                                                0.549846
# std_test_recall_weighted                                                 0.125454
# rank_test_recall_weighted                                                     484
#
#                                                                               130  \
# mean_fit_time                                                            0.051311
# std_fit_time                                                             0.005671
# mean_score_time                                                          0.020911
# std_score_time                                                           0.004254
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.615385
# split1_test_recall                                                       0.769231
# split2_test_recall                                                       0.666667
# split3_test_recall                                                           0.75
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.710256
# std_test_recall                                                          0.059225
# rank_test_recall                                                                4
# split0_test_precision                                                    0.266667
# split1_test_precision                                                    0.434783
# split2_test_precision                                                    0.170213
# split3_test_precision                                                    0.346154
# split4_test_precision                                                    0.264706
# mean_test_precision                                                      0.296504
# std_test_precision                                                       0.088811
# rank_test_precision                                                           219
# split0_test_f1                                                           0.372093
# split1_test_f1                                                           0.555556
# split2_test_f1                                                           0.271186
# split3_test_f1                                                           0.473684
# split4_test_f1                                                           0.391304
# mean_test_f1                                                             0.412765
# std_test_f1                                                              0.096187
# rank_test_f1                                                                   29
# split0_test_roc_auc                                                      0.739253
# split1_test_roc_auc                                                      0.748869
# split2_test_roc_auc                                                      0.575368
# split3_test_roc_auc                                                      0.716912
# split4_test_roc_auc                                                      0.680147
# mean_test_roc_auc                                                         0.69211
# std_test_roc_auc                                                         0.062978
# rank_test_roc_auc                                                              88
# split0_test_recall_weighted                                              0.666667
# split1_test_recall_weighted                                              0.802469
# split2_test_recall_weighted                                                0.4625
# split3_test_recall_weighted                                                  0.75
# split4_test_recall_weighted                                                  0.65
# mean_test_recall_weighted                                                0.666327
# std_test_recall_weighted                                                 0.116059
# rank_test_recall_weighted                                                     410
#
#                                                                               109  \
# mean_fit_time                                                              0.0564
# std_fit_time                                                             0.009733
# mean_score_time                                                          0.025806
# std_score_time                                                           0.004063
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.769231
# split1_test_recall                                                       0.923077
# split2_test_recall                                                           0.25
# split3_test_recall                                                       0.583333
# split4_test_recall                                                            1.0
# mean_test_recall                                                         0.705128
# std_test_recall                                                          0.268528
# rank_test_recall                                                                5
# split0_test_precision                                                    0.222222
# split1_test_precision                                                        0.25
# split2_test_precision                                                    0.157895
# split3_test_precision                                                    0.233333
# split4_test_precision                                                    0.230769
# mean_test_precision                                                      0.218844
# std_test_precision                                                       0.031778
# rank_test_precision                                                           473
# split0_test_f1                                                           0.344828
# split1_test_f1                                                           0.393443
# split2_test_f1                                                           0.193548
# split3_test_f1                                                           0.333333
# split4_test_f1                                                              0.375
# mean_test_f1                                                              0.32803
# std_test_f1                                                              0.070542
# rank_test_f1                                                                  365
# split0_test_roc_auc                                                      0.692308
# split1_test_roc_auc                                                      0.794683
# split2_test_roc_auc                                                      0.465686
# split3_test_roc_auc                                                      0.550245
# split4_test_roc_auc                                                      0.805147
# mean_test_roc_auc                                                        0.661614
# std_test_roc_auc                                                         0.134195
# rank_test_roc_auc                                                             300
# split0_test_recall_weighted                                              0.530864
# split1_test_recall_weighted                                               0.54321
# split2_test_recall_weighted                                                0.6875
# split3_test_recall_weighted                                                  0.65
# split4_test_recall_weighted                                                   0.5
# mean_test_recall_weighted                                                0.582315
# std_test_recall_weighted                                                 0.072935
# rank_test_recall_weighted                                                     479
#
#                                                                               191  \
# mean_fit_time                                                            0.049402
# std_fit_time                                                             0.006653
# mean_score_time                                                          0.023766
# std_score_time                                                           0.001126
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.615385
# split1_test_recall                                                       0.769231
# split2_test_recall                                                            0.5
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.916667
# mean_test_recall                                                          0.69359
# std_test_recall                                                          0.141282
# rank_test_recall                                                                6
# split0_test_precision                                                    0.275862
# split1_test_precision                                                    0.322581
# split2_test_precision                                                    0.230769
# split3_test_precision                                                    0.205128
# split4_test_precision                                                    0.211538
# mean_test_precision                                                      0.249176
# std_test_precision                                                       0.044263
# rank_test_precision                                                           423
# split0_test_f1                                                           0.380952
# split1_test_f1                                                           0.454545
# split2_test_f1                                                           0.315789
# split3_test_f1                                                           0.313725
# split4_test_f1                                                            0.34375
# mean_test_f1                                                             0.361753
# std_test_f1                                                              0.052388
# rank_test_f1                                                                  216
# split0_test_roc_auc                                                      0.714367
# split1_test_roc_auc                                                      0.721154
# split2_test_roc_auc                                                      0.643995
# split3_test_roc_auc                                                      0.640319
# split4_test_roc_auc                                                       0.76348
# mean_test_roc_auc                                                        0.696663
# std_test_roc_auc                                                         0.047595
# rank_test_roc_auc                                                              65
# split0_test_recall_weighted                                              0.679012
# split1_test_recall_weighted                                              0.703704
# split2_test_recall_weighted                                                 0.675
# split3_test_recall_weighted                                                0.5625
# split4_test_recall_weighted                                                 0.475
# mean_test_recall_weighted                                                0.619043
# std_test_recall_weighted                                                 0.086995
# rank_test_recall_weighted                                                     463
#
#                                                                               343  \
# mean_fit_time                                                            0.044742
# std_fit_time                                                             0.003244
# mean_score_time                                                           0.03021
# std_score_time                                                           0.006458
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.615385
# split1_test_recall                                                       0.846154
# split2_test_recall                                                       0.583333
# split3_test_recall                                                       0.583333
# split4_test_recall                                                       0.833333
# mean_test_recall                                                         0.692308
# std_test_recall                                                          0.121016
# rank_test_recall                                                                7
# split0_test_precision                                                    0.266667
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.225806
# split3_test_precision                                                       0.175
# split4_test_precision                                                     0.25641
# mean_test_precision                                                      0.251443
# std_test_precision                                                       0.051891
# rank_test_precision                                                           420
# split0_test_f1                                                           0.372093
# split1_test_f1                                                           0.478261
# split2_test_f1                                                           0.325581
# split3_test_f1                                                           0.269231
# split4_test_f1                                                           0.392157
# mean_test_f1                                                             0.367465
# std_test_f1                                                               0.06973
# rank_test_f1                                                                  185
# split0_test_roc_auc                                                      0.696267
# split1_test_roc_auc                                                      0.789027
# split2_test_roc_auc                                                      0.607843
# split3_test_roc_auc                                                      0.578431
# split4_test_roc_auc                                                      0.742034
# mean_test_roc_auc                                                        0.682721
# std_test_roc_auc                                                         0.079354
# rank_test_roc_auc                                                             161
# split0_test_recall_weighted                                              0.666667
# split1_test_recall_weighted                                              0.703704
# split2_test_recall_weighted                                                0.6375
# split3_test_recall_weighted                                                 0.525
# split4_test_recall_weighted                                                0.6125
# mean_test_recall_weighted                                                0.629074
# std_test_recall_weighted                                                 0.060266
# rank_test_recall_weighted                                                     458
#
#                                                                               105  \
# mean_fit_time                                                            0.063799
# std_fit_time                                                             0.011695
# mean_score_time                                                          0.029639
# std_score_time                                                           0.007862
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.615385
# split1_test_recall                                                       0.846154
# split2_test_recall                                                            0.5
# split3_test_recall                                                           0.75
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.692308
# std_test_recall                                                          0.121016
# rank_test_recall                                                                8
# split0_test_precision                                                    0.266667
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.230769
# split3_test_precision                                                    0.346154
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.302051
# std_test_precision                                                       0.045245
# rank_test_precision                                                           189
# split0_test_f1                                                           0.372093
# split1_test_f1                                                           0.478261
# split2_test_f1                                                           0.315789
# split3_test_f1                                                           0.473684
# split4_test_f1                                                           0.461538
# mean_test_f1                                                             0.420273
# std_test_f1                                                              0.065048
# rank_test_f1                                                                   14
# split0_test_roc_auc                                                      0.652149
# split1_test_roc_auc                                                      0.770362
# split2_test_roc_auc                                                      0.577206
# split3_test_roc_auc                                                      0.727328
# split4_test_roc_auc                                                      0.762255
# mean_test_roc_auc                                                         0.69786
# std_test_roc_auc                                                         0.073374
# rank_test_roc_auc                                                              61
# split0_test_recall_weighted                                              0.666667
# split1_test_recall_weighted                                              0.703704
# split2_test_recall_weighted                                                 0.675
# split3_test_recall_weighted                                                  0.75
# split4_test_recall_weighted                                                0.7375
# mean_test_recall_weighted                                                0.706574
# std_test_recall_weighted                                                 0.032985
# rank_test_recall_weighted                                                     302
#
#                                                                               153  \
# mean_fit_time                                                            0.053991
# std_fit_time                                                             0.006734
# mean_score_time                                                           0.02345
# std_score_time                                                           0.001916
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.461538
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.833333
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.680769
# std_test_recall                                                          0.123663
# rank_test_recall                                                                9
# split0_test_precision                                                    0.290323
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.210526
# split3_test_precision                                                    0.196078
# split4_test_precision                                                     0.28125
# mean_test_precision                                                      0.270635
# std_test_precision                                                       0.064131
# rank_test_precision                                                           334
# split0_test_f1                                                           0.409091
# split1_test_f1                                                           0.413793
# split2_test_f1                                                               0.32
# split3_test_f1                                                            0.31746
# split4_test_f1                                                           0.409091
# mean_test_f1                                                             0.373887
# std_test_f1                                                              0.045075
# rank_test_f1                                                                  155
# split0_test_roc_auc                                                       0.70871
# split1_test_roc_auc                                                      0.718891
# split2_test_roc_auc                                                      0.579044
# split3_test_roc_auc                                                      0.663603
# split4_test_roc_auc                                                      0.716299
# mean_test_roc_auc                                                         0.67731
# std_test_roc_auc                                                         0.053065
# rank_test_roc_auc                                                             194
# split0_test_recall_weighted                                              0.679012
# split1_test_recall_weighted                                              0.790123
# split2_test_recall_weighted                                                 0.575
# split3_test_recall_weighted                                                0.4625
# split4_test_recall_weighted                                                 0.675
# mean_test_recall_weighted                                                0.636327
# std_test_recall_weighted                                                 0.110406
# rank_test_recall_weighted                                                     452
#
#                                                                               85   \
# mean_fit_time                                                            0.051634
# std_fit_time                                                             0.003077
# mean_score_time                                                          0.022493
# std_score_time                                                           0.004879
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.615385
# split1_test_recall                                                       0.692308
# split2_test_recall                                                            0.5
# split3_test_recall                                                           0.75
# split4_test_recall                                                       0.833333
# mean_test_recall                                                         0.678205
# std_test_recall                                                          0.114124
# rank_test_recall                                                               10
# split0_test_precision                                                    0.266667
# split1_test_precision                                                    0.176471
# split2_test_precision                                                    0.230769
# split3_test_precision                                                    0.346154
# split4_test_precision                                                        0.25
# mean_test_precision                                                      0.254012
# std_test_precision                                                       0.055171
# rank_test_precision                                                           407
# split0_test_f1                                                           0.372093
# split1_test_f1                                                            0.28125
# split2_test_f1                                                           0.315789
# split3_test_f1                                                           0.473684
# split4_test_f1                                                           0.384615
# mean_test_f1                                                             0.365486
# std_test_f1                                                              0.065851
# rank_test_f1                                                                  195
# split0_test_roc_auc                                                      0.699661
# split1_test_roc_auc                                                      0.670814
# split2_test_roc_auc                                                      0.573529
# split3_test_roc_auc                                                      0.712623
# split4_test_roc_auc                                                      0.751225
# mean_test_roc_auc                                                        0.681571
# std_test_roc_auc                                                         0.059886
# rank_test_roc_auc                                                             173
# split0_test_recall_weighted                                              0.666667
# split1_test_recall_weighted                                              0.432099
# split2_test_recall_weighted                                                 0.675
# split3_test_recall_weighted                                                  0.75
# split4_test_recall_weighted                                                   0.6
# mean_test_recall_weighted                                                0.624753
# std_test_recall_weighted                                                 0.107421
# rank_test_recall_weighted                                                     460
#
#                                                                               410  \
# mean_fit_time                                                            0.042406
# std_fit_time                                                             0.001853
# mean_score_time                                                          0.029979
# std_score_time                                                           0.006322
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.615385
# split1_test_recall                                                       0.846154
# split2_test_recall                                                            0.5
# split3_test_recall                                                       0.666667
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.675641
# std_test_recall                                                          0.117614
# rank_test_recall                                                               11
# split0_test_precision                                                    0.266667
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.230769
# split3_test_precision                                                    0.347826
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.302386
# std_test_precision                                                       0.045574
# rank_test_precision                                                           186
# split0_test_f1                                                           0.372093
# split1_test_f1                                                           0.478261
# split2_test_f1                                                           0.315789
# split3_test_f1                                                           0.457143
# split4_test_f1                                                           0.461538
# mean_test_f1                                                             0.416965
# std_test_f1                                                              0.062623
# rank_test_f1                                                                   21
# split0_test_roc_auc                                                      0.696267
# split1_test_roc_auc                                                      0.789027
# split2_test_roc_auc                                                      0.606618
# split3_test_roc_auc                                                      0.704657
# split4_test_roc_auc                                                      0.802083
# mean_test_roc_auc                                                         0.71973
# std_test_roc_auc                                                         0.070931
# ...
# split0_test_precision                                                        0.25
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.133333
# split3_test_precision                                                         0.5
# split4_test_precision                                                         0.5
# mean_test_precision                                                      0.376667
# std_test_precision                                                       0.155492
# rank_test_precision                                                            32
# split0_test_f1                                                           0.341463
# split1_test_f1                                                           0.235294
# split2_test_f1                                                           0.148148
# split3_test_f1                                                           0.142857
# split4_test_f1                                                           0.142857
# mean_test_f1                                                             0.202124
# std_test_f1                                                              0.078044
# rank_test_f1                                                                  486
# split0_test_roc_auc                                                      0.609163
# split1_test_roc_auc                                                      0.770362
# split2_test_roc_auc                                                      0.539216
# split3_test_roc_auc                                                      0.732843
# split4_test_roc_auc                                                      0.771446
# mean_test_roc_auc                                                        0.684606
# std_test_roc_auc                                                         0.093864
# rank_test_roc_auc                                                             145
# split0_test_recall_weighted                                              0.666667
# split1_test_recall_weighted                                              0.839506
# split2_test_recall_weighted                                                0.7125
# split3_test_recall_weighted                                                  0.85
# split4_test_recall_weighted                                                  0.85
# mean_test_recall_weighted                                                0.783735
# std_test_recall_weighted                                                 0.078322
# rank_test_recall_weighted                                                      47
#
#                                                                               342  \
# mean_fit_time                                                            0.040062
# std_fit_time                                                             0.004395
# mean_score_time                                                             0.029
# std_score_time                                                           0.006634
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.230769
# split1_test_recall                                                       0.384615
# split2_test_recall                                                            0.0
# split3_test_recall                                                           0.25
# split4_test_recall                                                       0.083333
# mean_test_recall                                                         0.189744
# std_test_recall                                                          0.134621
# rank_test_recall                                                              484
# split0_test_precision                                                    0.272727
# split1_test_precision                                                       0.625
# split2_test_precision                                                         0.0
# split3_test_precision                                                         0.5
# split4_test_precision                                                         1.0
# mean_test_precision                                                      0.479545
# std_test_precision                                                        0.33621
# rank_test_precision                                                             1
# split0_test_f1                                                               0.25
# split1_test_f1                                                            0.47619
# split2_test_f1                                                                0.0
# split3_test_f1                                                           0.333333
# split4_test_f1                                                           0.153846
# mean_test_f1                                                             0.242674
# std_test_f1                                                              0.160987
# rank_test_f1                                                                  479
# split0_test_roc_auc                                                      0.669683
# split1_test_roc_auc                                                      0.665158
# split2_test_roc_auc                                                      0.556373
# split3_test_roc_auc                                                      0.597426
# split4_test_roc_auc                                                      0.784926
# mean_test_roc_auc                                                        0.654713
# std_test_roc_auc                                                         0.077771
# rank_test_roc_auc                                                             339
# split0_test_recall_weighted                                              0.777778
# split1_test_recall_weighted                                              0.864198
# split2_test_recall_weighted                                                 0.775
# split3_test_recall_weighted                                                  0.85
# split4_test_recall_weighted                                                0.8625
# mean_test_recall_weighted                                                0.825895
# std_test_recall_weighted                                                 0.040727
# rank_test_recall_weighted                                                       4
#
#                                                                               414  \
# mean_fit_time                                                            0.040513
# std_fit_time                                                              0.00236
# mean_score_time                                                          0.029622
# std_score_time                                                           0.007047
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.076923
# split1_test_recall                                                       0.384615
# split2_test_recall                                                       0.333333
# split3_test_recall                                                       0.083333
# split4_test_recall                                                            0.0
# mean_test_recall                                                         0.175641
# std_test_recall                                                          0.153397
# rank_test_recall                                                              485
# split0_test_precision                                                         0.5
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.333333
# split3_test_precision                                                         0.5
# split4_test_precision                                                         0.0
# mean_test_precision                                                      0.366667
# std_test_precision                                                       0.194365
# rank_test_precision                                                            43
# split0_test_f1                                                           0.133333
# split1_test_f1                                                           0.434783
# split2_test_f1                                                           0.333333
# split3_test_f1                                                           0.142857
# split4_test_f1                                                                0.0
# mean_test_f1                                                             0.208861
# std_test_f1                                                               0.15506
# rank_test_f1                                                                  484
# split0_test_roc_auc                                                      0.676471
# split1_test_roc_auc                                                      0.789027
# split2_test_roc_auc                                                      0.634804
# split3_test_roc_auc                                                      0.578431
# split4_test_roc_auc                                                      0.762868
# mean_test_roc_auc                                                         0.68832
# std_test_roc_auc                                                         0.078459
# rank_test_roc_auc                                                             116
# split0_test_recall_weighted                                              0.839506
# split1_test_recall_weighted                                              0.839506
# split2_test_recall_weighted                                                   0.8
# split3_test_recall_weighted                                                  0.85
# split4_test_recall_weighted                                                 0.825
# mean_test_recall_weighted                                                0.830802
# std_test_recall_weighted                                                 0.017335
# rank_test_recall_weighted                                                       1
#
#                                                                               411
# mean_fit_time                                                             0.04195
# std_fit_time                                                              0.00483
# mean_score_time                                                          0.029616
# std_score_time                                                           0.004854
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.153846
# split1_test_recall                                                       0.153846
# split2_test_recall                                                           0.25
# split3_test_recall                                                           0.25
# split4_test_recall                                                            0.0
# mean_test_recall                                                         0.161538
# std_test_recall                                                          0.091503
# rank_test_recall                                                              486
# split0_test_precision                                                         0.4
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.333333
# split3_test_precision                                                       0.375
# split4_test_precision                                                         0.0
# mean_test_precision                                                      0.321667
# std_test_precision                                                       0.169935
# rank_test_precision                                                           130
# split0_test_f1                                                           0.222222
# split1_test_f1                                                           0.235294
# split2_test_f1                                                           0.285714
# split3_test_f1                                                                0.3
# split4_test_f1                                                                0.0
# mean_test_f1                                                             0.208646
# std_test_f1                                                              0.108363
# rank_test_f1                                                                  485
# split0_test_roc_auc                                                      0.645928
# split1_test_roc_auc                                                      0.770362
# split2_test_roc_auc                                                      0.642157
# split3_test_roc_auc                                                       0.58027
# split4_test_roc_auc                                                      0.752451
# mean_test_roc_auc                                                        0.678233
# std_test_roc_auc                                                         0.072025
# rank_test_roc_auc                                                             190
# split0_test_recall_weighted                                               0.82716
# split1_test_recall_weighted                                              0.839506
# split2_test_recall_weighted                                                0.8125
# split3_test_recall_weighted                                                 0.825
# split4_test_recall_weighted                                                 0.825
# mean_test_recall_weighted                                                0.825833
# std_test_recall_weighted                                                 0.008578
# rank_test_recall_weighted                                                       5
#
# [51 rows x 486 columns]

# %%
# Evaluation
from sklearn.metrics import classification_report
y_pred = gscv_dt.best_estimator_.steps[2][1].predict(X_eval)
print(classification_report(y_eval, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85       147
#            1       0.35      0.69      0.47        26
#
#     accuracy                           0.76       173
#    macro avg       0.64      0.73      0.66       173
# weighted avg       0.85      0.76      0.79       173

# %%
clf = gscv_dt.best_estimator_.steps[2][1]
viz = dtreeviz(clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"],
             fancy=False,
               scale=1.5
              )

viz
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %% [markdown]
# ### Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', RandomForestClassifier())
])

parameters = {
              'clf__n_estimators': [100,300,500],
              'clf__criterion': ['gini', 'entropy', 'log_loss'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
              'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
              'under__sampling_strategy': [0.5, 0.6, 0.7],
              'smt__k_neighbors': [3, 5]
             }

nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
refit_score = 'f1'
gscv_rf = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit=refit_score,
                    n_jobs=-1)
resultsGSCV = gscv_rf.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
pd.set_option("display.max_rows", None)
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
#                                                                               218  \
# mean_fit_time                                                            0.677655
# std_fit_time                                                             0.008136
# mean_score_time                                                          0.102464
# std_score_time                                                            0.00187
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.538462
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.583333
# mean_test_recall                                                         0.629487
# std_test_recall                                                          0.058527
# rank_test_recall                                                                1
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.388889
# split2_test_precision                                                    0.380952
# split3_test_precision                                                    0.470588
# split4_test_precision                                                    0.388889
# mean_test_precision                                                      0.425864
# std_test_precision                                                       0.049493
# rank_test_precision                                                           434
# split0_test_f1                                                           0.580645
# split1_test_f1                                                           0.451613
# split2_test_f1                                                           0.484848
# split3_test_f1                                                           0.551724
# split4_test_f1                                                           0.466667
# mean_test_f1                                                             0.507099
# std_test_f1                                                              0.050218
# rank_test_f1                                                                   39
# split0_test_roc_auc                                                      0.893665
# split1_test_roc_auc                                                      0.755656
# split2_test_roc_auc                                                      0.775123
# split3_test_roc_auc                                                      0.819853
# split4_test_roc_auc                                                      0.787377
# mean_test_roc_auc                                                        0.806335
# std_test_roc_auc                                                         0.048397
# rank_test_roc_auc                                                             418
#
#                                                                               209  \
# mean_fit_time                                                            3.324684
# std_fit_time                                                             0.021571
# mean_score_time                                                          0.464887
# std_score_time                                                           0.022829
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.769231
# split1_test_recall                                                       0.461538
# split2_test_recall                                                       0.666667
# split3_test_recall                                                           0.75
# split4_test_recall                                                            0.5
# mean_test_recall                                                         0.629487
# std_test_recall                                                          0.126813
# rank_test_recall                                                                1
# split0_test_precision                                                    0.588235
# split1_test_precision                                                    0.461538
# split2_test_precision                                                    0.363636
# split3_test_precision                                                      0.5625
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.461849
# std_test_precision                                                       0.102241
# rank_test_precision                                                           376
# split0_test_f1                                                           0.666667
# split1_test_f1                                                           0.461538
# split2_test_f1                                                           0.470588
# split3_test_f1                                                           0.642857
# split4_test_f1                                                                0.4
# mean_test_f1                                                              0.52833
# std_test_f1                                                              0.106318
# rank_test_f1                                                                   15
# split0_test_roc_auc                                                      0.885181
# split1_test_roc_auc                                                      0.763009
# split2_test_roc_auc                                                      0.773284
# split3_test_roc_auc                                                      0.869485
# split4_test_roc_auc                                                      0.773897
# mean_test_roc_auc                                                        0.812971
# std_test_roc_auc                                                         0.052927
# rank_test_roc_auc                                                             362
#
#                                                                               182  \
# mean_fit_time                                                            1.967318
# std_fit_time                                                             0.018263
# mean_score_time                                                          0.283926
# std_score_time                                                           0.001177
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.846154
# split1_test_recall                                                       0.461538
# split2_test_recall                                                       0.583333
# split3_test_recall                                                            0.5
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.628205
# std_test_recall                                                          0.147352
# rank_test_recall                                                                3
# split0_test_precision                                                        0.44
# split1_test_precision                                                    0.333333
# split2_test_precision                                                        0.35
# split3_test_precision                                                    0.428571
# split4_test_precision                                                    0.409091
# mean_test_precision                                                      0.392199
# std_test_precision                                                       0.042753
# rank_test_precision                                                           472
# split0_test_f1                                                           0.578947
# split1_test_f1                                                           0.387097
# split2_test_f1                                                             0.4375
# split3_test_f1                                                           0.461538
# split4_test_f1                                                           0.529412
# mean_test_f1                                                             0.478899
# std_test_f1                                                              0.067829
# rank_test_f1                                                                  144
# split0_test_roc_auc                                                        0.8931
# split1_test_roc_auc                                                      0.734163
# split2_test_roc_auc                                                      0.759191
# split3_test_roc_auc                                                      0.799632
# split4_test_roc_auc                                                      0.803922
# mean_test_roc_auc                                                        0.798002
# std_test_roc_auc                                                         0.054153
# rank_test_roc_auc                                                             463
#
#                                                                               263  \
# mean_fit_time                                                            3.234729
# std_fit_time                                                             0.012705
# mean_score_time                                                          0.457877
# std_score_time                                                            0.00764
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.384615
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.615385
# std_test_recall                                                          0.115811
# rank_test_recall                                                                4
# split0_test_precision                                                    0.642857
# split1_test_precision                                                    0.357143
# split2_test_precision                                                    0.363636
# split3_test_precision                                                    0.421053
# split4_test_precision                                                    0.533333
# mean_test_precision                                                      0.463604
# std_test_precision                                                       0.109665
# rank_test_precision                                                           373
# split0_test_f1                                                           0.666667
# split1_test_f1                                                            0.37037
# split2_test_f1                                                           0.470588
# split3_test_f1                                                           0.516129
# split4_test_f1                                                           0.592593
# mean_test_f1                                                             0.523269
# std_test_f1                                                              0.101561
# rank_test_f1                                                                   19
# split0_test_roc_auc                                                       0.88914
# split1_test_roc_auc                                                      0.793552
# split2_test_roc_auc                                                      0.764093
# split3_test_roc_auc                                                      0.835172
# split4_test_roc_auc                                                      0.813725
# mean_test_roc_auc                                                        0.819137
# std_test_roc_auc                                                         0.042122
# rank_test_roc_auc                                                             281
#
#                                                                               29   \
# mean_fit_time                                                            1.721366
# std_fit_time                                                             0.014266
# mean_score_time                                                          0.301333
# std_score_time                                                           0.004366
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.461538
# split2_test_recall                                                       0.583333
# split3_test_recall                                                       0.583333
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.614103
# std_test_recall                                                          0.099753
# rank_test_recall                                                                5
# split0_test_precision                                                    0.473684
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.291667
# split3_test_precision                                                    0.466667
# split4_test_precision                                                    0.473684
# mean_test_precision                                                       0.41614
# std_test_precision                                                       0.072611
# rank_test_precision                                                           452
# split0_test_f1                                                             0.5625
# split1_test_f1                                                           0.413793
# split2_test_f1                                                           0.388889
# split3_test_f1                                                           0.518519
# split4_test_f1                                                           0.580645
# mean_test_f1                                                             0.492869
# std_test_f1                                                              0.077815
# rank_test_f1                                                                   77
# split0_test_roc_auc                                                      0.892534
# split1_test_roc_auc                                                      0.795249
# split2_test_roc_auc                                                      0.752451
# split3_test_roc_auc                                                      0.827206
# split4_test_roc_auc                                                      0.844363
# mean_test_roc_auc                                                         0.82236
# std_test_roc_auc                                                          0.04702
# rank_test_roc_auc                                                             248
#
#                                                                               2    \
# mean_fit_time                                                            0.479442
# std_fit_time                                                             0.091472
# mean_score_time                                                          0.113841
# std_score_time                                                           0.007343
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.307692
# split2_test_recall                                                       0.583333
# split3_test_recall                                                           0.75
# split4_test_recall                                                       0.666667
# mean_test_recall                                                              0.6
# std_test_recall                                                          0.155683
# rank_test_recall                                                                6
# split0_test_precision                                                        0.45
# split1_test_precision                                                    0.444444
# split2_test_precision                                                        0.35
# split3_test_precision                                                      0.5625
# split4_test_precision                                                    0.470588
# mean_test_precision                                                      0.455507
# std_test_precision                                                       0.067763
# rank_test_precision                                                           388
# split0_test_f1                                                           0.545455
# split1_test_f1                                                           0.363636
# split2_test_f1                                                             0.4375
# split3_test_f1                                                           0.642857
# split4_test_f1                                                           0.551724
# mean_test_f1                                                             0.508234
# std_test_f1                                                              0.097275
# rank_test_f1                                                                   37
# split0_test_roc_auc                                                       0.83371
# split1_test_roc_auc                                                      0.682692
# split2_test_roc_auc                                                      0.765319
# split3_test_roc_auc                                                      0.853554
# split4_test_roc_auc                                                      0.837623
# mean_test_roc_auc                                                         0.79458
# std_test_roc_auc                                                         0.063619
# rank_test_roc_auc                                                             471
#
#                                                                               257  \
# mean_fit_time                                                            3.564753
# std_fit_time                                                             0.024781
# mean_score_time                                                          0.476554
# std_score_time                                                           0.026247
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.538462
# split1_test_recall                                                       0.461538
# split2_test_recall                                                       0.583333
# split3_test_recall                                                       0.666667
# split4_test_recall                                                           0.75
# mean_test_recall                                                              0.6
# std_test_recall                                                          0.100181
# rank_test_recall                                                                6
# split0_test_precision                                                    0.583333
# split1_test_precision                                                    0.666667
# split2_test_precision                                                    0.368421
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.473684
# mean_test_precision                                                      0.518421
# std_test_precision                                                       0.101026
# rank_test_precision                                                           225
# split0_test_f1                                                               0.56
# split1_test_f1                                                           0.545455
# split2_test_f1                                                           0.451613
# split3_test_f1                                                           0.571429
# split4_test_f1                                                           0.580645
# mean_test_f1                                                             0.541828
# std_test_f1                                                              0.046616
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.880656
# split1_test_roc_auc                                                      0.878394
# split2_test_roc_auc                                                      0.766544
# split3_test_roc_auc                                                      0.838235
# split4_test_roc_auc                                                      0.813725
# mean_test_roc_auc                                                        0.835511
# std_test_roc_auc                                                         0.042698
# rank_test_roc_auc                                                              68
#
#                                                                               146  \
# mean_fit_time                                                            2.743179
# std_fit_time                                                              0.05083
# mean_score_time                                                          0.443944
# std_score_time                                                           0.008766
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.384615
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.583333
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.598718
# std_test_recall                                                          0.113199
# rank_test_recall                                                                8
# split0_test_precision                                                        0.45
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.380952
# split3_test_precision                                                    0.538462
# split4_test_precision                                                    0.380952
# mean_test_precision                                                      0.450073
# std_test_precision                                                       0.063025
# rank_test_precision                                                           398
# split0_test_f1                                                           0.545455
# split1_test_f1                                                           0.434783
# split2_test_f1                                                           0.484848
# split3_test_f1                                                               0.56
# split4_test_f1                                                           0.484848
# mean_test_f1                                                             0.501987
# std_test_f1                                                              0.045517
# rank_test_f1                                                                   52
# split0_test_roc_auc                                                      0.891403
# split1_test_roc_auc                                                      0.808824
# split2_test_roc_auc                                                      0.769608
# split3_test_roc_auc                                                       0.85723
# split4_test_roc_auc                                                      0.799632
# mean_test_roc_auc                                                        0.825339
# std_test_roc_auc                                                         0.043407
# rank_test_roc_auc                                                             196
#
#                                                                               335  \
# mean_fit_time                                                            0.305807
# std_fit_time                                                             0.002525
# mean_score_time                                                          0.060145
# std_score_time                                                           0.003555
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.384615
# split2_test_recall                                                            0.5
# split3_test_recall                                                       0.666667
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.598718
# std_test_recall                                                          0.135534
# rank_test_recall                                                                8
# split0_test_precision                                                      0.5625
# split1_test_precision                                                    0.384615
# split2_test_precision                                                    0.333333
# split3_test_precision                                                    0.444444
# split4_test_precision                                                         0.5
# mean_test_precision                                                      0.444979
# std_test_precision                                                       0.081175
# rank_test_precision                                                           407
# split0_test_f1                                                            0.62069
# split1_test_f1                                                           0.384615
# split2_test_f1                                                                0.4
# split3_test_f1                                                           0.533333
# split4_test_f1                                                                0.6
# mean_test_f1                                                             0.507728
# std_test_f1                                                              0.098683
# rank_test_f1                                                                   38
# split0_test_roc_auc                                                       0.81957
# split1_test_roc_auc                                                      0.776584
# split2_test_roc_auc                                                      0.745711
# split3_test_roc_auc                                                      0.857843
# split4_test_roc_auc                                                      0.820466
# mean_test_roc_auc                                                        0.804035
# std_test_roc_auc                                                         0.038889
# rank_test_roc_auc                                                             435
#
#                                                                               398  \
# mean_fit_time                                                             0.89596
# std_fit_time                                                             0.025588
# mean_score_time                                                          0.155143
# std_score_time                                                           0.004599
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.384615
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.583333
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.598718
# std_test_recall                                                          0.113199
# rank_test_recall                                                                8
# split0_test_precision                                                        0.45
# split1_test_precision                                                    0.357143
# split2_test_precision                                                    0.285714
# split3_test_precision                                                    0.318182
# split4_test_precision                                                    0.444444
# mean_test_precision                                                      0.371097
# std_test_precision                                                       0.066167
# rank_test_precision                                                           483
# split0_test_f1                                                           0.545455
# split1_test_f1                                                            0.37037
# split2_test_f1                                                                0.4
# split3_test_f1                                                           0.411765
# split4_test_f1                                                           0.533333
# mean_test_f1                                                             0.452185
# std_test_f1                                                              0.072574
# rank_test_f1                                                                  290
# split0_test_roc_auc                                                      0.879525
# split1_test_roc_auc                                                      0.824661
# split2_test_roc_auc                                                      0.680147
# split3_test_roc_auc                                                      0.806985
# split4_test_roc_auc                                                      0.802083
# mean_test_roc_auc                                                         0.79868
# std_test_roc_auc                                                         0.065332
# rank_test_roc_auc                                                             458
#
#                                                                               38   \
# mean_fit_time                                                            2.732436
# std_fit_time                                                             0.044881
# mean_score_time                                                           0.48138
# std_score_time                                                            0.01247
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.769231
# split1_test_recall                                                       0.461538
# split2_test_recall                                                       0.583333
# split3_test_recall                                                       0.666667
# split4_test_recall                                                            0.5
# mean_test_recall                                                         0.596154
# std_test_recall                                                          0.111767
# rank_test_recall                                                               11
# split0_test_precision                                                    0.526316
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.304348
# split3_test_precision                                                    0.470588
# split4_test_precision                                                    0.428571
# mean_test_precision                                                      0.420965
# std_test_precision                                                       0.076592
# rank_test_precision                                                           446
# split0_test_f1                                                              0.625
# split1_test_f1                                                           0.413793
# split2_test_f1                                                                0.4
# split3_test_f1                                                           0.551724
# split4_test_f1                                                           0.461538
# mean_test_f1                                                             0.490411
# std_test_f1                                                              0.085734
# rank_test_f1                                                                   88
# split0_test_roc_auc                                                      0.848982
# split1_test_roc_auc                                                      0.772059
# split2_test_roc_auc                                                      0.708333
# split3_test_roc_auc                                                      0.840686
# split4_test_roc_auc                                                      0.821078
# mean_test_roc_auc                                                        0.798228
# std_test_roc_auc                                                         0.052281
# rank_test_roc_auc                                                             460
#
#                                                                               302  \
# mean_fit_time                                                            1.190227
# std_fit_time                                                             0.009535
# mean_score_time                                                          0.160122
# std_score_time                                                            0.00621
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.307692
# split2_test_recall                                                       0.583333
# split3_test_recall                                                       0.583333
# split4_test_recall                                                           0.75
# mean_test_recall                                                         0.583333
# std_test_recall                                                          0.152073
# rank_test_recall                                                               12
# split0_test_precision                                                         0.6
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.368421
# split3_test_precision                                                    0.466667
# split4_test_precision                                                      0.5625
# mean_test_precision                                                      0.499518
# std_test_precision                                                        0.08041
# rank_test_precision                                                           277
# split0_test_f1                                                           0.642857
# split1_test_f1                                                           0.380952
# split2_test_f1                                                           0.451613
# split3_test_f1                                                           0.518519
# split4_test_f1                                                           0.642857
# mean_test_f1                                                              0.52736
# std_test_f1                                                              0.103856
# rank_test_f1                                                                   16
# split0_test_roc_auc                                                      0.906109
# split1_test_roc_auc                                                      0.803167
# split2_test_roc_auc                                                      0.792279
# split3_test_roc_auc                                                      0.847426
# split4_test_roc_auc                                                      0.834559
# mean_test_roc_auc                                                        0.836708
# std_test_roc_auc                                                         0.040087
# rank_test_roc_auc                                                              57
#
#                                                                               344  \
# mean_fit_time                                                            0.866633
# std_fit_time                                                             0.008752
# mean_score_time                                                          0.166652
# std_score_time                                                           0.013106
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.307692
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.583333
# mean_test_recall                                                         0.583333
# std_test_recall                                                          0.142648
# rank_test_recall                                                               13
# split0_test_precision                                                      0.5625
# split1_test_precision                                                         0.4
# split2_test_precision                                                    0.363636
# split3_test_precision                                                    0.421053
# split4_test_precision                                                         0.5
# mean_test_precision                                                      0.449438
# std_test_precision                                                       0.072043
# rank_test_precision                                                           399
# split0_test_f1                                                            0.62069
# split1_test_f1                                                           0.347826
# split2_test_f1                                                           0.470588
# split3_test_f1                                                           0.516129
# split4_test_f1                                                           0.538462
# mean_test_f1                                                             0.498739
# std_test_f1                                                              0.089799
# ...
# split4_test_f1                                                           0.266667
# mean_test_f1                                                              0.38372
# std_test_f1                                                              0.068728
# rank_test_f1                                                                  478
# split0_test_roc_auc                                                      0.849548
# split1_test_roc_auc                                                      0.861991
# split2_test_roc_auc                                                       0.78799
# split3_test_roc_auc                                                      0.856005
# split4_test_roc_auc                                                      0.826593
# mean_test_roc_auc                                                        0.836425
# std_test_roc_auc                                                         0.027025
# rank_test_roc_auc                                                              61
#
#                                                                               384  \
# mean_fit_time                                                            0.357339
# std_fit_time                                                             0.002061
# mean_score_time                                                          0.059522
# std_score_time                                                           0.003657
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.538462
# split1_test_recall                                                       0.153846
# split2_test_recall                                                       0.166667
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.083333
# mean_test_recall                                                         0.288462
# std_test_recall                                                          0.190935
# rank_test_recall                                                              483
# split0_test_precision                                                    0.636364
# split1_test_precision                                                    0.666667
# split2_test_precision                                                    0.285714
# split3_test_precision                                                    0.666667
# split4_test_precision                                                         0.5
# mean_test_precision                                                      0.551082
# std_test_precision                                                       0.146302
# rank_test_precision                                                           149
# split0_test_f1                                                           0.583333
# split1_test_f1                                                               0.25
# split2_test_f1                                                           0.210526
# split3_test_f1                                                           0.571429
# split4_test_f1                                                           0.142857
# mean_test_f1                                                             0.351629
# std_test_f1                                                              0.187522
# rank_test_f1                                                                  484
# split0_test_roc_auc                                                      0.892534
# split1_test_roc_auc                                                      0.767534
# split2_test_roc_auc                                                       0.79473
# split3_test_roc_auc                                                      0.841912
# split4_test_roc_auc                                                       0.82598
# mean_test_roc_auc                                                        0.824538
# std_test_roc_auc                                                          0.04258
# rank_test_roc_auc                                                             210
#
#                                                                               465  \
# mean_fit_time                                                            1.081716
# std_fit_time                                                             0.005525
# mean_score_time                                                          0.154172
# std_score_time                                                           0.002914
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.461538
# split1_test_recall                                                       0.230769
# split2_test_recall                                                       0.416667
# split3_test_recall                                                       0.333333
# split4_test_recall                                                            0.0
# mean_test_recall                                                         0.288462
# std_test_recall                                                          0.164283
# rank_test_recall                                                              483
# split0_test_precision                                                         0.6
# split1_test_precision                                                         0.6
# split2_test_precision                                                       0.625
# split3_test_precision                                                         0.8
# split4_test_precision                                                         0.0
# mean_test_precision                                                         0.525
# std_test_precision                                                       0.272947
# rank_test_precision                                                           206
# split0_test_f1                                                           0.521739
# split1_test_f1                                                           0.333333
# split2_test_f1                                                                0.5
# split3_test_f1                                                           0.470588
# split4_test_f1                                                                0.0
# mean_test_f1                                                             0.365132
# std_test_f1                                                              0.193994
# rank_test_f1                                                                  483
# split0_test_roc_auc                                                      0.875566
# split1_test_roc_auc                                                      0.834842
# split2_test_roc_auc                                                      0.792892
# split3_test_roc_auc                                                      0.862745
# split4_test_roc_auc                                                      0.824142
# mean_test_roc_auc                                                        0.838037
# std_test_roc_auc                                                          0.02919
# rank_test_roc_auc                                                              47
#
#                                                                               438  \
# mean_fit_time                                                            0.372347
# std_fit_time                                                             0.006628
# mean_score_time                                                          0.058998
# std_score_time                                                           0.002443
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.461538
# split1_test_recall                                                       0.230769
# split2_test_recall                                                       0.416667
# split3_test_recall                                                       0.333333
# split4_test_recall                                                            0.0
# mean_test_recall                                                         0.288462
# std_test_recall                                                          0.164283
# rank_test_recall                                                              483
# split0_test_precision                                                         0.6
# split1_test_precision                                                        0.75
# split2_test_precision                                                    0.384615
# split3_test_precision                                                    0.571429
# split4_test_precision                                                         0.0
# mean_test_precision                                                      0.461209
# std_test_precision                                                       0.258222
# rank_test_precision                                                           377
# split0_test_f1                                                           0.521739
# split1_test_f1                                                           0.352941
# split2_test_f1                                                                0.4
# split3_test_f1                                                           0.421053
# split4_test_f1                                                                0.0
# mean_test_f1                                                             0.339147
# std_test_f1                                                              0.178304
# rank_test_f1                                                                  486
# split0_test_roc_auc                                                       0.88405
# split1_test_roc_auc                                                       0.83371
# split2_test_roc_auc                                                      0.795343
# split3_test_roc_auc                                                       0.83027
# split4_test_roc_auc                                                      0.824142
# mean_test_roc_auc                                                        0.833503
# std_test_roc_auc                                                         0.028668
# rank_test_roc_auc                                                              95
#
#                                                                               6
# mean_fit_time                                                            0.645184
# std_fit_time                                                             0.004002
# mean_score_time                                                          0.113571
# std_score_time                                                           0.005424
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.384615
# split1_test_recall                                                       0.153846
# split2_test_recall                                                       0.416667
# split3_test_recall                                                       0.333333
# split4_test_recall                                                       0.083333
# mean_test_recall                                                         0.274359
# std_test_recall                                                          0.131833
# rank_test_recall                                                              486
# split0_test_precision                                                    0.555556
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.555556
# split3_test_precision                                                    0.666667
# split4_test_precision                                                        0.25
# mean_test_precision                                                      0.505556
# std_test_precision                                                       0.138778
# rank_test_precision                                                           258
# split0_test_f1                                                           0.454545
# split1_test_f1                                                           0.235294
# split2_test_f1                                                            0.47619
# split3_test_f1                                                           0.444444
# split4_test_f1                                                              0.125
# mean_test_f1                                                             0.347095
# std_test_f1                                                              0.141077
# rank_test_f1                                                                  485
# split0_test_roc_auc                                                      0.841063
# split1_test_roc_auc                                                       0.79129
# split2_test_roc_auc                                                      0.783701
# split3_test_roc_auc                                                      0.828431
# split4_test_roc_auc                                                      0.777574
# mean_test_roc_auc                                                        0.804412
# std_test_roc_auc                                                         0.025463
# rank_test_roc_auc                                                             429
#
# [43 rows x 486 columns]

# %%
# Evaluation RF
from sklearn.metrics import classification_report
y_pred = gscv_rf.best_estimator_.steps[2][1].predict(X_eval)
print(classification_report(y_eval, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94       147
#            1       0.63      0.65      0.64        26
#
#     accuracy                           0.89       173
#    macro avg       0.78      0.79      0.79       173
# weighted avg       0.89      0.89      0.89       173

# %% [markdown]
# Plot the mean ROC curve of the algorithm with best performing parameter selection. We will perform CV once again and plot the ROC curve for each fold and compute and plot the mean.

# %%
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval, y_eval)):
    classifier.fit(X_eval.iloc[train], y_eval[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X_eval.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the mean precision-recall curve. The approach is the same as for the mean ROC curve.

# %%
from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval, y_eval)):
    classifier.fit(X.iloc[train], y[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X_eval.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

rf = gscv_rf.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf, X, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
# Out:
# Text(0.5, 1.0, 'Permutation Importance Random Forest')

# %%
# probaj enako z X_eval in primerjaj

# %%
# Get feature importance with SHAP
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)
RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %%
# probaj enako z X_eval in primerjaj

# %%
# SHAP summary plot
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)
classid = 1
shap.summary_plot(shap_values[classid], X, max_display=len(X.columns), class_names=le.classes_)

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

# one-hot encoding of month feature
Xohe = pd.get_dummies(X, columns=["month"])

X_display = Xohe.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xohe)
Xsc = pd.DataFrame(scaled_array, columns=Xohe.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE()),
    ('under', RandomUnderSampler()),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.5, 0.6, 0.8], # probaj poveča ovresampling do 0.9
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
             }
nfolds = 5
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv_NN = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "recall")
resultsGSCV = gscv_NN.fit(Xsc, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# 240 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 268, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 226, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 394, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 534, in check_sampling_strategy
#     _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 393, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to generate new sample in the majority class while trying to remove samples. Please increase the ratio.
#
# One or more of the test scores are non-finite: [0.32692308 0.43589744 0.58205128 0.46025641 0.54487179 0.54487179
#         nan        nan 0.51538462 0.45128205 0.59358974 0.58461538
#  0.41666667 0.52948718 0.42179487        nan        nan 0.49487179
#  0.43717949 0.48076923 0.56538462 0.46666667 0.34358974 0.48205128
#         nan        nan 0.52820513 0.48205128 0.43846154 0.50128205
#  0.37435897 0.61153846 0.53076923        nan        nan 0.59615385
#  0.40512821 0.53461538 0.53205128 0.45       0.43461538 0.66153846
#         nan        nan 0.48333333 0.41538462 0.57051282 0.60769231
#  0.51538462 0.58205128 0.51538462        nan        nan 0.46794872
#  0.32179487 0.61410256 0.40897436 0.41666667 0.49871795 0.29102564
#         nan        nan 0.36282051 0.18846154 0.56794872 0.44487179
#  0.4525641  0.57948718 0.59358974        nan        nan 0.51025641
#  0.4025641  0.56794872 0.55       0.44615385 0.40512821 0.47564103
#         nan        nan 0.51538462 0.59871795 0.40512821 0.53461538
#  0.51538462 0.48076923 0.47307692        nan        nan 0.53333333
#  0.59358974 0.33717949 0.54871795 0.43717949 0.58076923 0.62820513
#         nan        nan 0.53205128 0.48461538 0.51923077 0.34487179
#  0.51923077 0.38205128 0.42051282        nan        nan 0.60897436
#  0.4        0.49871795 0.46666667 0.46666667 0.37051282 0.56410256
#         nan        nan 0.51794872 0.45       0.53333333 0.50128205
#  0.43461538 0.56666667 0.37051282        nan        nan 0.37179487
#  0.38589744 0.48589744 0.40641026 0.48589744 0.48205128 0.60128205
#         nan        nan 0.4974359  0.43461538 0.42179487 0.51410256
#  0.55       0.46666667 0.40128205        nan        nan 0.64358974
#  0.50128205 0.61282051 0.42179487 0.53076923 0.45384615 0.46666667
#         nan        nan 0.48205128 0.51923077 0.48589744 0.48205128
#  0.48333333 0.48589744 0.48333333        nan        nan 0.53846154
#  0.33461538 0.52948718 0.62820513 0.53076923 0.39102564 0.41923077
#         nan        nan 0.41923077 0.48333333 0.46794872 0.49871795
#  0.46538462 0.48333333 0.46410256        nan        nan 0.46410256
#  0.61538462 0.43461538 0.54358974 0.53461538 0.41923077 0.53461538
#         nan        nan 0.56666667 0.49871795 0.6        0.47948718
#  0.38974359 0.37051282 0.53205128        nan        nan 0.35769231
#  0.47307692 0.43846154 0.45384615 0.48205128 0.61153846 0.4025641
#         nan        nan 0.46666667 0.45128205 0.48333333 0.53205128
#  0.43589744 0.54871795 0.48717949        nan        nan 0.53333333]
# One or more of the test scores are non-finite: [0.35641026 0.30570376 0.37392157 0.34550038 0.30347886 0.33301932
#         nan        nan 0.24217537 0.32946154 0.31318681 0.2927399
#  0.51428571 0.29435939 0.35840875        nan        nan 0.31649113
#  0.41057692 0.30525084 0.33186943 0.31967248 0.35154062 0.41695264
#         nan        nan 0.33476618 0.34301665 0.27102654 0.31052216
#  0.40419935 0.37908533 0.32113208        nan        nan 0.39376623
#  0.33118022 0.27191866 0.40850991 0.37692308 0.32297768 0.33342447
#         nan        nan 0.39713904 0.32432877 0.31519568 0.32770455
#  0.37094667 0.41475126 0.37296919        nan        nan 0.45828739
#  0.40882784 0.32783605 0.21839465 0.32862915 0.32877894 0.35899123
#         nan        nan 0.18473595 0.14196078 0.34586368 0.22170455
#  0.37695187 0.33617719 0.31174159        nan        nan 0.20980622
#  0.36629371 0.2562997  0.30086031 0.31993124 0.31815115 0.27076264
#         nan        nan 0.27990741 0.30837359 0.232047   0.33395455
#  0.35807692 0.38241533 0.30959922        nan        nan 0.39228568
#  0.26635132 0.26119552 0.24963045 0.42324324 0.21989348 0.30655502
#         nan        nan 0.29767437 0.32482605 0.30984979 0.31406926
#  0.31926888 0.25812698 0.24965133        nan        nan 0.31351396
#  0.31501401 0.35435039 0.28076366 0.3775     0.2930539  0.29291728
#         nan        nan 0.42947118 0.32988589 0.40873523 0.27554156
#  0.39428571 0.32412904 0.31969697        nan        nan 0.33417798
#  0.30742857 0.37777778 0.29236553 0.41364734 0.40571895 0.4172434
#         nan        nan 0.37455877 0.35027274 0.32269841 0.32523701
#  0.34977703 0.30887016 0.34890332        nan        nan 0.4069335
#  0.33155616 0.37759684 0.30189967 0.32860137 0.29656315 0.31508097
#         nan        nan 0.29855072 0.30881768 0.41602564 0.2861039
#  0.35613851 0.35775058 0.35420365        nan        nan 0.37586401
#  0.31392605 0.27368467 0.26132759 0.37144648 0.27575092 0.29447619
#         nan        nan 0.27675113 0.41252288 0.32619048 0.27492507
#  0.33909681 0.25680761 0.2739228         nan        nan 0.34807812
#  0.31931624 0.33993464 0.25600251 0.41556061 0.39002258 0.33064182
#         nan        nan 0.32637987 0.30044826 0.29946397 0.29340909
#  0.32570473 0.34579783 0.31036268        nan        nan 0.28596491
#  0.35288897 0.27805556 0.28063584 0.35263158 0.29700343 0.25722604
#         nan        nan 0.30485068 0.2913956  0.33702298 0.29692994
#  0.41666667 0.35146958 0.35512679        nan        nan 0.31614954]
# One or more of the test scores are non-finite: [0.33492578 0.35157964 0.41764414 0.36948501 0.37040029 0.3962032
#         nan        nan 0.30328502 0.36914689 0.40269112 0.38360153
#  0.44216078 0.36657143 0.37279037        nan        nan 0.35974705
#  0.41563104 0.35516057 0.38804609 0.36023    0.33573105 0.42970816
#         nan        nan 0.38977169 0.37539827 0.33187987 0.37248507
#  0.37778968 0.44941054 0.39718778        nan        nan 0.45229294
#  0.33651961 0.34356127 0.45547914 0.39212932 0.35433172 0.43428774
#         nan        nan 0.43267652 0.35844296 0.36279302 0.41919371
#  0.42550648 0.4786251  0.41336563        nan        nan 0.43188783
#  0.35056954 0.39954784 0.27125243 0.36159033 0.39068028 0.28527376
#         nan        nan 0.2368223  0.15008802 0.41349613 0.27445887
#  0.39571574 0.41569748 0.38738573        nan        nan 0.28492867
#  0.37668013 0.34246558 0.38135747 0.34994493 0.35325269 0.32728407
#         nan        nan 0.35771924 0.39011579 0.28856584 0.37898352
#  0.41372672 0.39783042 0.35337204        nan        nan 0.4398436
#  0.35751272 0.29311576 0.32327324 0.39644444 0.31031739 0.40531629
#         nan        nan 0.37477124 0.3701001  0.37664642 0.29813209
#  0.37488792 0.29000713 0.30688307        nan        nan 0.38700347
#  0.34985755 0.4092881  0.34514694 0.4127519  0.32480239 0.37469988
#         nan        nan 0.46674481 0.37265849 0.43971161 0.35149848
#  0.40545973 0.40192807 0.33713951        nan        nan 0.34671937
#  0.33128362 0.42296932 0.33469342 0.43220945 0.41988579 0.47599507
#         nan        nan 0.42203581 0.3855675  0.35438312 0.38471802
#  0.42100122 0.36401108 0.36751608        nan        nan 0.47365147
#  0.39717595 0.45119375 0.3321775  0.40124332 0.3487679  0.36908302
#         nan        nan 0.36421356 0.38138484 0.43651678 0.35276145
#  0.38977929 0.40059157 0.40564516        nan        nan 0.42061083
#  0.31421245 0.34957347 0.36072644 0.42418571 0.31629675 0.34333813
#         nan        nan 0.3143973  0.43076909 0.36662751 0.34857725
#  0.38066951 0.33149251 0.33685372        nan        nan 0.38117103
#  0.41835795 0.36893369 0.34586247 0.45606434 0.39043493 0.40555954
#         nan        nan 0.40567558 0.35796493 0.3862362  0.35285997
#  0.33644755 0.35244755 0.39017513        nan        nan 0.30853175
#  0.36045179 0.33142126 0.34173298 0.40068457 0.39108012 0.3125256
#         nan        nan 0.36036939 0.34748348 0.38560317 0.378338
#  0.42385928 0.42766094 0.40921937        nan        nan 0.39583203]
# One or more of the test scores are non-finite: [0.66514894 0.64910445 0.72249246 0.65907805 0.6911859  0.70866327
#         nan        nan 0.66660068 0.67451923 0.71808069 0.69374057
#  0.75535445 0.68910256 0.66459276        nan        nan 0.62988311
#  0.72667798 0.68641591 0.70208333 0.68455882 0.66799585 0.72457579
#         nan        nan 0.72017345 0.70645739 0.67663084 0.70224359
#  0.69410822 0.72564103 0.71039781        nan        nan 0.71638386
#  0.64165724 0.66840121 0.71907994 0.73207014 0.69891591 0.72565045
#         nan        nan 0.69119532 0.67504713 0.70113122 0.7032994
#  0.7378865  0.7228224  0.6980675         nan        nan 0.69351433
#  0.6688914  0.68776395 0.58916855 0.68179676 0.68577489 0.66484729
#         nan        nan 0.60065045 0.56504525 0.68825415 0.64058258
#  0.67498115 0.68183446 0.68440799        nan        nan 0.65409125
#  0.66236802 0.68364442 0.67423643 0.66144419 0.6585313  0.64351433
#         nan        nan 0.66668552 0.70056561 0.62267157 0.6644325
#  0.6730675  0.67019231 0.64024321        nan        nan 0.7328997
#  0.63979072 0.625773   0.59835973 0.71117081 0.65921003 0.69920814
#         nan        nan 0.64651207 0.67079563 0.66558258 0.62890271
#  0.68313537 0.63982843 0.59191176        nan        nan 0.70138575
#  0.65123492 0.74282617 0.65281863 0.68830128 0.66017157 0.70934201
#         nan        nan 0.69442873 0.65490196 0.68663273 0.67794118
#  0.70512821 0.74950038 0.62720588        nan        nan 0.61707202
#  0.62947775 0.72847851 0.6783371  0.67905354 0.69812406 0.74343891
#         nan        nan 0.69919872 0.67889329 0.66336727 0.69449472
#  0.69918929 0.6747549  0.66576169        nan        nan 0.72990196
#  0.67665913 0.76104827 0.68656674 0.68260747 0.67627262 0.67364253
#         nan        nan 0.67458522 0.71824095 0.72862934 0.69439103
#  0.69105392 0.68421003 0.70742836        nan        nan 0.72087104
#  0.65438348 0.65374246 0.6927319  0.72121041 0.68996983 0.68757541
#         nan        nan 0.66731712 0.71217949 0.68618967 0.6682221
#  0.68985671 0.64826546 0.66363122        nan        nan 0.69052602
#  0.73388952 0.68142911 0.65609917 0.71893854 0.71816554 0.67851621
#         nan        nan 0.68979072 0.64930241 0.67620664 0.6520362
#  0.65362934 0.68770739 0.68661388        nan        nan 0.6299491
#  0.64543741 0.68180618 0.62337858 0.69574849 0.69205317 0.63252262
#         nan        nan 0.67860106 0.68423831 0.71786388 0.68022247
#  0.71218891 0.6724736  0.67716817        nan        nan 0.69902903]
#                                                                               41   \
# mean_fit_time                                                            0.199166
# std_fit_time                                                             0.106614
# mean_score_time                                                          0.010992
# std_score_time                                                           0.000098
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.923077
# split1_test_recall                                                       0.384615
# split2_test_recall                                                       0.583333
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.583333
# mean_test_recall                                                         0.661538
# std_test_recall                                                          0.193305
# rank_test_recall                                                                1
# split0_test_precision                                                    0.571429
# split1_test_precision                                                    0.166667
# split2_test_precision                                                    0.368421
# split3_test_precision                                                    0.227273
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.333424
# std_test_precision                                                       0.139246
# rank_test_precision                                                            67
# split0_test_f1                                                           0.705882
# split1_test_f1                                                           0.232558
# split2_test_f1                                                           0.451613
# split3_test_f1                                                           0.357143
# split4_test_f1                                                           0.424242
# mean_test_f1                                                             0.434288
# std_test_f1                                                              0.155442
# rank_test_f1                                                                   14
# split0_test_roc_auc                                                      0.867647
# split1_test_roc_auc                                                      0.534502
# split2_test_roc_auc                                                      0.748162
# split3_test_roc_auc                                                      0.773284
# split4_test_roc_auc                                                      0.704657
# mean_test_roc_auc                                                         0.72565
# std_test_roc_auc                                                         0.109469
# rank_test_roc_auc                                                              14
#
#                                                                               143  \
# mean_fit_time                                                            0.673987
# std_fit_time                                                             0.323522
# mean_score_time                                                          0.014075
# std_score_time                                                           0.001158
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.846154
# split1_test_recall                                                       0.538462
# split2_test_recall                                                            1.0
# split3_test_recall                                                       0.416667
# split4_test_recall                                                       0.416667
# mean_test_recall                                                          0.64359
# std_test_recall                                                          0.237529
# rank_test_recall                                                                2
# split0_test_precision                                                     0.37931
# split1_test_precision                                                    0.583333
# split2_test_precision                                                    0.342857
# split3_test_precision                                                    0.416667
# split4_test_precision                                                      0.3125
# mean_test_precision                                                      0.406933
# std_test_precision                                                       0.094866
# rank_test_precision                                                            17
# split0_test_f1                                                            0.52381
# split1_test_f1                                                               0.56
# split2_test_f1                                                           0.510638
# split3_test_f1                                                           0.416667
# split4_test_f1                                                           0.357143
# mean_test_f1                                                             0.473651
# std_test_f1                                                              0.075049
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                       0.79638
# split1_test_roc_auc                                                      0.688914
# split2_test_roc_auc                                                      0.890931
# split3_test_roc_auc                                                      0.672181
# split4_test_roc_auc                                                      0.601103
# mean_test_roc_auc                                                        0.729902
# std_test_roc_auc                                                         0.101932
# rank_test_roc_auc                                                              10
#
#                                                                               95   \
# mean_fit_time                                                            0.645798
# std_fit_time                                                             0.345513
# mean_score_time                                                          0.015672
# std_score_time                                                            0.00184
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.615385
# split2_test_recall                                                       0.583333
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.583333
# mean_test_recall                                                         0.628205
# std_test_recall                                                          0.044226
# rank_test_recall                                                                3
# split0_test_precision                                                    0.290323
# split1_test_precision                                                    0.190476
# split2_test_precision                                                    0.411765
# split3_test_precision                                                    0.380952
# split4_test_precision                                                    0.259259
# mean_test_precision                                                      0.306555
# std_test_precision                                                        0.08072
# rank_test_precision                                                           114
# split0_test_f1                                                           0.409091
# split1_test_f1                                                           0.290909
# split2_test_f1                                                           0.482759
# split3_test_f1                                                           0.484848
# split4_test_f1                                                           0.358974
# mean_test_f1                                                             0.405316
# std_test_f1                                                              0.074261
# rank_test_f1                                                                   44
# split0_test_roc_auc                                                      0.699661
# split1_test_roc_auc                                                      0.634615
# split2_test_roc_auc                                                       0.72549
# split3_test_roc_auc                                                      0.727941
# split4_test_roc_auc                                                      0.708333
# mean_test_roc_auc                                                        0.699208
# std_test_roc_auc                                                         0.033977
# rank_test_roc_auc                                                              44
#
#                                                                               164  \
# mean_fit_time                                                            0.364786
# std_fit_time                                                             0.387813
# mean_score_time                                                          0.012293
# std_score_time                                                           0.001273
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.846154
# split1_test_recall                                                       0.461538
# split2_test_recall                                                       0.916667
# split3_test_recall                                                           0.25
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.628205
# std_test_recall                                                          0.246174
# rank_test_recall                                                                3
# split0_test_precision                                                    0.314286
# split1_test_precision                                                    0.214286
# split2_test_precision                                                    0.297297
# split3_test_precision                                                    0.230769
# split4_test_precision                                                        0.25
# mean_test_precision                                                      0.261328
# std_test_precision                                                       0.038402
# rank_test_precision                                                           152
# split0_test_f1                                                           0.458333
# split1_test_f1                                                           0.292683
# split2_test_f1                                                            0.44898
# split3_test_f1                                                               0.24
# split4_test_f1                                                           0.363636
# mean_test_f1                                                             0.360726
# std_test_f1                                                              0.085474
# rank_test_f1                                                                  103
# split0_test_roc_auc                                                      0.734163
# split1_test_roc_auc                                                      0.606335
# split2_test_roc_auc                                                      0.819853
# split3_test_roc_auc                                                       0.69424
# split4_test_roc_auc                                                      0.609069
# mean_test_roc_auc                                                        0.692732
# std_test_roc_auc                                                         0.080427
# rank_test_roc_auc                                                              58
#
#                                                                               180  \
# mean_fit_time                                                            0.407036
# std_fit_time                                                             0.115434
# mean_score_time                                                          0.012841
# std_score_time                                                           0.000871
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.769231
# split1_test_recall                                                       0.307692
# split2_test_recall                                                       0.666667
# split3_test_recall                                                           0.75
# split4_test_recall                                                       0.583333
# mean_test_recall                                                         0.615385
# std_test_recall                                                          0.167405
# rank_test_recall                                                                5
# split0_test_precision                                                         0.4
# split1_test_precision                                                    0.166667
# split2_test_precision                                                    0.307692
# split3_test_precision                                                    0.333333
# split4_test_precision                                                    0.388889
# mean_test_precision                                                      0.319316
# std_test_precision                                                       0.083647
# rank_test_precision                                                            93
# split0_test_f1                                                           0.526316
# split1_test_f1                                                           0.216216
# split2_test_f1                                                           0.421053
# split3_test_f1                                                           0.461538
# split4_test_f1                                                           0.466667
# mean_test_f1                                                             0.418358
# std_test_f1                                                               0.10651
# rank_test_f1                                                                   30
# split0_test_roc_auc                                                      0.785633
# split1_test_roc_auc                                                      0.533937
# split2_test_roc_auc                                                       0.78799
# split3_test_roc_auc                                                      0.789216
# split4_test_roc_auc                                                      0.772672
# mean_test_roc_auc                                                         0.73389
# std_test_roc_auc                                                          0.10015
# rank_test_roc_auc                                                               7
#
#                                                                               55   \
# mean_fit_time                                                            0.208166
# std_fit_time                                                             0.152507
# mean_score_time                                                          0.011471
# std_score_time                                                           0.000461
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.769231
# split1_test_recall                                                       0.384615
# split2_test_recall                                                       0.583333
# split3_test_recall                                                           0.75
# split4_test_recall                                                       0.583333
# mean_test_recall                                                         0.614103
# std_test_recall                                                          0.139349
# rank_test_recall                                                                6
# split0_test_precision                                                    0.208333
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.269231
# split3_test_precision                                                    0.272727
# split4_test_precision                                                    0.388889
# mean_test_precision                                                      0.327836
# std_test_precision                                                       0.104039
# rank_test_precision                                                            78
# split0_test_f1                                                           0.327869
# split1_test_f1                                                           0.434783
# split2_test_f1                                                           0.368421
# split3_test_f1                                                                0.4
# split4_test_f1                                                           0.466667
# mean_test_f1                                                             0.399548
# std_test_f1                                                               0.04869
# rank_test_f1                                                                   50
# split0_test_roc_auc                                                      0.618778
# split1_test_roc_auc                                                      0.659502
# split2_test_roc_auc                                                      0.731005
# split3_test_roc_auc                                                      0.704044
# split4_test_roc_auc                                                       0.72549
# mean_test_roc_auc                                                        0.687764
# std_test_roc_auc                                                         0.042699
# rank_test_roc_auc                                                              70
#
#                                                                               145  \
# mean_fit_time                                                            0.237897
# std_fit_time                                                             0.127415
# mean_score_time                                                          0.014117
# std_score_time                                                           0.001379
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.692308
# split1_test_recall                                                       0.538462
# split2_test_recall                                                            0.5
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.612821
# std_test_recall                                                          0.077942
# rank_test_recall                                                                7
# split0_test_precision                                                         0.3
# split1_test_precision                                                    0.304348
# split2_test_precision                                                         0.6
# split3_test_precision                                                    0.363636
# split4_test_precision                                                        0.32
# mean_test_precision                                                      0.377597
# std_test_precision                                                       0.113457
# rank_test_precision                                                            28
# split0_test_f1                                                           0.418605
# split1_test_f1                                                           0.388889
# split2_test_f1                                                           0.545455
# split3_test_f1                                                           0.470588
# split4_test_f1                                                           0.432432
# mean_test_f1                                                             0.451194
# std_test_f1                                                              0.053958
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.754525
# split1_test_roc_auc                                                      0.700226
# split2_test_roc_auc                                                      0.778186
# split3_test_roc_auc                                                      0.805147
# split4_test_roc_auc                                                      0.767157
# mean_test_roc_auc                                                        0.761048
# std_test_roc_auc                                                         0.034692
# rank_test_roc_auc                                                               1
#
#                                                                               202  \
# mean_fit_time                                                            0.288006
# std_fit_time                                                             0.128511
# mean_score_time                                                          0.012626
# std_score_time                                                           0.000347
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.923077
# split1_test_recall                                                       0.384615
# split2_test_recall                                                           0.75
# split3_test_recall                                                       0.583333
# split4_test_recall                                                       0.416667
# mean_test_recall                                                         0.611538
# std_test_recall                                                           0.20322
# rank_test_recall                                                                8
# split0_test_precision                                                    0.387097
# split1_test_precision                                                    0.357143
# split2_test_precision                                                    0.346154
# split3_test_precision                                                    0.233333
# split4_test_precision                                                     0.16129
# mean_test_precision                                                      0.297003
# std_test_precision                                                       0.085582
# rank_test_precision                                                           125
# split0_test_f1                                                           0.545455
# split1_test_f1                                                            0.37037
# split2_test_f1                                                           0.473684
# split3_test_f1                                                           0.333333
# split4_test_f1                                                           0.232558
# mean_test_f1                                                              0.39108
# std_test_f1                                                              0.109131
# rank_test_f1                                                                   59
# split0_test_roc_auc                                                      0.821267
# split1_test_roc_auc                                                      0.655543
# split2_test_roc_auc                                                       0.82598
# split3_test_roc_auc                                                      0.646446
# split4_test_roc_auc                                                      0.511029
# mean_test_roc_auc                                                        0.692053
# std_test_roc_auc                                                         0.119009
# rank_test_roc_auc                                                              59
#
#                                                                               31   \
# mean_fit_time                                                             0.22743
# std_fit_time                                                             0.104642
# mean_score_time                                                          0.011856
# std_score_time                                                           0.001398
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.846154
# split1_test_recall                                                       0.461538
# split2_test_recall                                                           0.75
# split3_test_recall                                                            0.5
# split4_test_recall                                                            0.5
# mean_test_recall                                                         0.611538
# std_test_recall                                                          0.155947
# rank_test_recall                                                                8
# split0_test_precision                                                    0.458333
# split1_test_precision                                                     0.26087
# split2_test_precision                                                    0.230769
# split3_test_precision                                                         0.4
# split4_test_precision                                                    0.545455
# mean_test_precision                                                      0.379085
# std_test_precision                                                       0.118633
# rank_test_precision                                                            26
# split0_test_f1                                                           0.594595
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.352941
# split3_test_f1                                                           0.444444
# split4_test_f1                                                           0.521739
# mean_test_f1                                                             0.449411
# std_test_f1                                                              0.099111
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.878394
# split1_test_roc_auc                                                      0.605204
# split2_test_roc_auc                                                      0.651348
# split3_test_roc_auc                                                      0.702819
# split4_test_roc_auc                                                      0.790441
# mean_test_roc_auc                                                        0.725641
# std_test_roc_auc                                                         0.098059
# rank_test_roc_auc                                                              15
#
#                                                                               107  \
# mean_fit_time                                                            0.415844
# std_fit_time                                                             0.177555
# mean_score_time                                                          0.015836
# std_score_time                                                           0.001422
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.923077
# split1_test_recall                                                       0.538462
# split2_test_recall                                                            0.5
# split3_test_recall                                                       0.833333
# split4_test_recall                                                           0.25
# mean_test_recall                                                         0.608974
# std_test_recall                                                          0.242779
# rank_test_recall                                                               10
# split0_test_precision                                                    0.333333
# split1_test_precision                                                    0.241379
# split2_test_precision                                                         0.6
# split3_test_precision                                                        0.25
# split4_test_precision                                                    0.142857
# mean_test_precision                                                      0.313514
# std_test_precision                                                       0.155453
# rank_test_precision                                                           103
# split0_test_f1                                                           0.489796
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.545455
# split3_test_f1                                                           0.384615
# split4_test_f1                                                           0.181818
# mean_test_f1                                                             0.387003
# std_test_f1                                                              0.127012
# rank_test_f1                                                                   68
# split0_test_roc_auc                                                      0.789593
# split1_test_roc_auc                                                      0.649321
# split2_test_roc_auc                                                      0.770221
# split3_test_roc_auc                                                      0.720588
# split4_test_roc_auc                                                      0.577206
# mean_test_roc_auc                                                        0.701386
# std_test_roc_auc                                                         0.078764
# rank_test_roc_auc                                                              41
#
#                                                                               47   \
# mean_fit_time                                                            0.167438
# std_fit_time                                                              0.08042
# mean_score_time                                                          0.012144
# ...
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           211
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  199
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             199
#
#                                                                               186  \
# mean_fit_time                                                            0.016861
# std_fit_time                                                             0.000752
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              213
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           173
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  211
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             213
#
#                                                                               187  \
# mean_fit_time                                                            0.020618
# std_fit_time                                                             0.002378
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              214
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           175
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  212
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             214
#
#                                                                               133  \
# mean_fit_time                                                            0.021953
# std_fit_time                                                             0.001284
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              215
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           196
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  207
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             215
#
#                                                                               177
# mean_fit_time                                                            0.018347
# std_fit_time                                                             0.000861
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              216
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           183
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  202
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             205
#
# [41 rows x 216 columns]

# %%
# Evaluation 
from sklearn.metrics import classification_report
X_eval_ohe = pd.get_dummies(X_eval, columns=["month"])
scaler = StandardScaler().fit(Xohe)
X_eval_sc = scaler.transform(X_eval_ohe)
X_eval_sc = pd.DataFrame(X_eval_sc, columns=Xohe.columns)
y_pred = gscv_NN.best_estimator_.steps[2][1].predict(X_eval_sc)
print(classification_report(y_eval, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88       147
#            1       0.41      0.58      0.48        26
#
#     accuracy                           0.81       173
#    macro avg       0.66      0.71      0.68       173
# weighted avg       0.84      0.81      0.82       173

# %% [markdown]
# #### Feature Importance (MLP)

# %%
# Feature importance of model (MLP)  (no cross-validation!)

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=3)

MLP = gscv_NN.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(MLP, Xsc, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = Xsc.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance MLP")
# Out:
# Text(0.5, 1.0, 'Permutation Importance MLP')

# %% [markdown]
# #### Feature importance with SHAP

# %%
X = Xsc.copy()
# X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.25)

nn = MLPClassifier(hidden_layer_sizes=(3,3), solver='lbfgs', max_iter=5000)
model = nn.fit(X.to_numpy(), y)

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# # explain the model's predictions using SHAP
# import shap
# import warnings
# warnings.filterwarnings("ignore")
# shap.initjs()

# explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_eval_sc,20))
# shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
# shap.summary_plot(shap_values, X_eval_sc, max_display=len(X.columns), class_names=le.classes_)

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(Xsc,50)) #morda treba zmanjšat število, ali brez sample in samo X_eval
shap_values = explainer.shap_values(Xsc, nsamples=50)
classid = 1
shap.summary_plot(shap_values[classid], Xsc, max_display=len(X.columns), class_names=le.classes_)
# Out:
#   0%|          | 0/402 [00:00<?, ?it/s]
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.651e-04, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=1.723e-04, with an active set of 18 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 23 iterations, alpha=1.604e-04, previous alpha=1.514e-04, with an active set of 18 regressors.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.651e-04, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=1.723e-04, with an active set of 18 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 23 iterations, alpha=1.604e-04, previous alpha=1.514e-04, with an active set of 18 regressors.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=9.700e-07, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=9.028e-07, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.497e-07, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.190e-07, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.179e-07, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.958e-07, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# ...
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).

# %%
# Try dependence contribution plot
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_eval_sc,50))
shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
shap.dependence_plot('salinity', shap_values[1], X_eval_sc,) #interaction_index="salinity"
# Out:
#   0%|          | 0/173 [00:00<?, ?it/s]
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.505e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.504e-04, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=7.519e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 24 iterations, i.e. alpha=6.619e-05, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 25 iterations, alpha=1.002e-04, previous alpha=5.880e-05, with an active set of 22 regressors.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.042e-04, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.380e-04, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 30 iterations, alpha=3.074e-05, previous alpha=3.063e-05, with an active set of 23 regressors.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=6.629e-05, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=1.291e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=8.317e-06, with an active set of 24 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 29 iterations, alpha=1.291e-05, previous alpha=3.666e-06, with an active set of 24 regressors.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=6.629e-05, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=1.291e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=8.317e-06, with an active set of 24 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 29 iterations, alpha=1.291e-05, previous alpha=3.666e-06, with an active set of 24 regressors.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.615e-04, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=3.462e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=3.438e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=1.481e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=1.382e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=1.535e-06, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=1.113e-06, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.615e-04, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=3.462e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=3.438e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=1.481e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=1.382e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=1.535e-06, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=1.113e-06, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=8.247e-04, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=4.570e-05, with an active set of 19 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 33 iterations, alpha=2.526e-05, previous alpha=2.430e-05, with an active set of 22 regressors.
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# ...
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 # Try dependence contribution plot
#       2 explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_eval_sc,50))
# ----> 3 shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
#       4 shap.dependence_plot('salinity', shap_values[1], X_eval_sc,)
#
# File ~/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/shap/explainers/_kernel.py:190, in Kernel.shap_values(self, X, **kwargs)
#     188 if self.keep_index:
#     189     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 190 explanations.append(self.explain(data, **kwargs))
#     191 if kwargs.get("gc_collect", False):
#     192     gc.collect()
#
# File ~/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/shap/explainers/_kernel.py:217, in Kernel.explain(self, incoming_instance, **kwargs)
#     213 match_instance_to_data(instance, self.data)
#     215 # find the feature groups we will test. If a feature does not change from its
#     216 # current value then we know it doesn't impact the model
# --> 217 self.varyingInds = self.varying_groups(instance.x)
#     218 if self.data.groups is None:
#     219     self.varyingFeatureGroups = np.array([i for i in self.varyingInds])
#
# File ~/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/shap/explainers/_kernel.py:417, in Kernel.varying_groups(self, x)
#     415             continue
#     416         x_group = x_group.todense()
# --> 417     num_mismatches = np.sum(np.frompyfunc(self.not_equal, 2, 1)(x_group, self.data.data[:, inds]))
#     418     varying[i] = num_mismatches > 0
#     419 varying_indices = np.nonzero(varying)[0]
#
# File ~/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/shap/explainers/_kernel.py:402, in Kernel.not_equal(i, j)
#     400 number_types = (int, float, np.number)
#     401 if isinstance(i, number_types) and isinstance(j, number_types):
# --> 402     return 0 if np.isclose(i, j, equal_nan=True) else 1
#     403 else:
#     404     return 0 if i == j else 1
#
# File <__array_function__ internals>:180, in isclose(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/numpy/core/numeric.py:2361, in isclose(a, b, rtol, atol, equal_nan)
#    2359 yfin = isfinite(y)
#    2360 if all(xfin) and all(yfin):
# -> 2361     return within_tol(x, y, atol, rtol)
#    2362 else:
#    2363     finite = xfin & yfin
#
# File ~/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/numpy/core/numeric.py:2341, in isclose.<locals>.within_tol(x, y, atol, rtol)
#    2340 def within_tol(x, y, atol, rtol):
# -> 2341     with errstate(invalid='ignore'):
#    2342         return less_equal(abs(x-y), atol + rtol * abs(y))
#
# File ~/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:425, in errstate.__init__(self, call, **kwargs)
#     366 @set_module('numpy')
#     367 class errstate(contextlib.ContextDecorator):
#     368     """
#     369     errstate(**kwargs)
#     370
#    (...)
#     422
#     423     """
# --> 425     def __init__(self, *, call=_Unspecified, **kwargs):
#     426         self.call = call
#     427         self.kwargs = kwargs
#
# KeyboardInterrupt:

# %% [markdown]
# Example intepretation: The fact this slopes upward says the higher the soca flow, the higher the model's prediction is for poz/neg. The spread suggests that other features must interact with Soca flow.
# In general, high Soca flow increases the chance of poz/neg. But if the sea temp is moderate or low, that trend reverses and even high soca flow does not increase preditions of poz/neg as the sea temp is too low.
# https://www.kaggle.com/code/dansbecker/advanced-uses-of-shap-values

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
instanceID = 10
instance = X.iloc[[instanceID]]
display_instance = X_display.iloc[[instanceID]]

prediction = model.predict(instance)[0]
prediction_probs = model.predict_proba(instance)[0]
print(f'real value: {y[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)

# %% [markdown]
# Show the mean values of features as it may help understanding this particular instance data in the plot above.

# %%
data = pd.get_dummies(data, columns=["month"])


pd.DataFrame([data[data['lipophylic_toxins']=='neg'].mean(), data[data['lipophylic_toxins']=='poz'].mean()], index=['neg','pos']).T

# %% [markdown]
# ### Conclusion

# %%
# Summary table of prediction results
RF_recall = round(RF_recall_best_k[1], 2)
RF_auc = round(RF_auc_best_k[1], 2)
MLP_recall = round(MLP_recall_best_k[1], 2)
MLP_auc = round(MLP_auc_best_k[1], 2)

summary = pd.DataFrame(
    [
        (
            "RF",
            RF_recall_score,
            RF_auc_score,
        ),
        (
            "MLP",
            MLP_recall_score,
            MLP_auc_score,
        ),
        (
            "RF (smote)",
            RF_recall,
            RF_auc,
        ),
        (
            "MLP (smote)",
            MLP_recall,
            MLP_auc,
        ),
        (
            "Decision tree (J48)*",
            0.56,
            0.18,
        ),
    ],
    columns=("Model", "Recall", "ROC AUC"),
).set_index("Model")

print("Table summarising the prediction results of the used classifiers, both with and without SMOTE resampling:\n")
summary.round(2)

# %% [markdown]
# As can be seen resampling with SMOTE helped to improve the results substantially, especially when calculating recall. The highest recall and ROC AUC was achieved with Random Forest with the re-sampled data. Both recall and ROC AUC suggest Random Forest as beeing the better classifier for this particular problem. Recall is a crucial metric as it gives indication of what fraction of true positive instances have been predicted. Since the models predict toxins in seashells (food) it is crucial that as few positives as possible are missed.
#
# Due to the use of SMOTE resampling (upsampling and downsampling) in combinaiton with cross-validation it was curcial to do the resampling within each fold to avoid data lekeage and validate on original (unsampled) data. In addition, I have optimised the model with regard to the k-values of SMOTE, all of which brought along some complexity. So for the parameter tuning of Random Forest and MLP various parameter settings have been tried  and the model with best performing settings has been chosen.
#
# The decision tree J48 algorithm was run within Weka on a slightly different dataset (missing values were not removed to use as many instances as possible, cross validation was 10-fold as opposed to 3-fold due to a higher dataset etc.) thus this results are not directly comparable but were provided as a reference to give an indication of the performance of this algorithm.
#
# As can be seen in the feature importance bar plots above, similar features were on the top despite using two different classification algorithms and two different feature ranking methods. If we consider just the three highest-ranking features of each of the feature ranking methods for both algortihms (RF and MLP) the features that overlap are DSP, DSP_like, ASP, Dinophysis fortii and Dinophysis caudata. These can be shown to the domain experts for validation and interpretation.
