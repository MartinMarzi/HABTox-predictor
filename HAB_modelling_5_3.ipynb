# %%
from datetime import datetime
import pandas as pd
import numpy as np
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from dtreeviz.trees import dtreeviz 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 30)

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")
data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
# data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    661
# salinity                 191
# T                        244
# SECCHI                   696
# DIN                      542
# PO4-P                    534
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
data.drop(columns=["Chl-a", "SECCHI", "DIN", "PO4-P"], inplace=True)#
data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# salinity                 191
# T                        244
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Modelling and Preliminary Results

# %% [markdown]
# ![Screenshot 2022-07-26 at 12.15.26.png](attachment:500d2dd5-b27f-4f67-a0a0-94d4c6fc8714.png)

# %% [markdown]
# # Scikit-learn Analysis

# %% [markdown]
# ### Preprocessing

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    839
# poz    114
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# ## Model Training and Evaluation

# %% [markdown]
# ### Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
              'clf__max_depth': [2,3,4],
                'clf__criterion': ['gini', 'entropy'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
               'smt__sampling_strategy': [ 0.1, 0.2],
               'under__sampling_strategy': [0.7, 0.8],
                'smt__k_neighbors': [3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="recall",
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# 480 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 268, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 226, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 394, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 534, in check_sampling_strategy
#     _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 373, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 272, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 969, in fit
#     super().fit(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 227, in fit
#     expanded_class_weight = compute_sample_weight(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/utils/class_weight.py", line 127, in compute_sample_weight
#     raise ValueError(
# ValueError: The only valid preset for class_weight is "balanced". Given "balanced_subsample".
#
# One or more of the test scores are non-finite: [       nan        nan 0.56837945 0.56956522        nan        nan
#  0.59604743 0.47272727        nan        nan 0.63913043 0.53596838
#         nan        nan 0.5944664  0.62213439        nan        nan
#  0.50711462 0.53399209        nan        nan 0.69249012 0.58616601
#         nan        nan 0.46442688 0.55098814        nan        nan
#  0.57786561 0.47272727        nan        nan 0.53478261 0.56047431
#         nan        nan 0.55296443 0.53517787        nan        nan
#  0.63280632 0.67509881        nan        nan 0.62134387 0.60316206
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.44703557 0.45612648        nan        nan
#  0.48181818 0.50750988        nan        nan 0.53399209 0.57114625
#         nan        nan 0.43794466 0.44031621        nan        nan
#  0.50158103 0.56916996        nan        nan 0.63873518 0.54347826
#         nan        nan 0.44703557 0.53596838        nan        nan
#  0.50750988 0.52490119        nan        nan 0.41185771 0.53320158
#         nan        nan 0.47391304 0.58774704        nan        nan
#  0.55177866 0.45533597        nan        nan 0.61343874 0.54268775]
# One or more of the test scores are non-finite: [       nan        nan 0.24030234 0.2172218         nan        nan
#  0.22052958 0.22863478        nan        nan 0.22655792 0.25637866
#         nan        nan 0.2407068  0.24017251        nan        nan
#  0.18352137 0.24532012        nan        nan 0.25039199 0.21186723
#         nan        nan 0.25939806 0.22123618        nan        nan
#  0.23497317 0.27728179        nan        nan 0.22595238 0.28073593
#         nan        nan 0.24182034 0.22473864        nan        nan
#  0.23643967 0.2401202         nan        nan 0.22027981 0.21218508
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.26477579 0.27968234        nan        nan
#  0.27211709 0.26167328        nan        nan 0.24809144 0.25083012
#         nan        nan 0.26048883 0.22076224        nan        nan
#  0.23945429 0.28721954        nan        nan 0.2958973  0.26313068
#         nan        nan 0.25557587 0.25209484        nan        nan
#  0.24026969 0.30188199        nan        nan 0.26518485 0.27087146
#         nan        nan 0.25227004 0.24285165        nan        nan
#  0.24899399 0.27417387        nan        nan 0.25470395 0.23557918]
# One or more of the test scores are non-finite: [       nan        nan 0.3274894  0.31211541        nan        nan
#  0.31900227 0.30762008        nan        nan 0.32898158 0.33509726
#         nan        nan 0.33747398 0.34281894        nan        nan
#  0.26869817 0.33178645        nan        nan 0.3656018  0.30715343
#         nan        nan 0.32570196 0.31151344        nan        nan
#  0.32957293 0.32779059        nan        nan 0.30753808 0.356183
#         nan        nan 0.33397603 0.31303364        nan        nan
#  0.33890704 0.33873078        nan        nan 0.32360203 0.30807088
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.32469342 0.32554235        nan        nan
#  0.33791114 0.34311314        nan        nan 0.33619165 0.34370707
#         nan        nan 0.31974047 0.27661637        nan        nan
#  0.31681288 0.37861909        nan        nan 0.39991155 0.34768512
#         nan        nan 0.32148201 0.33506433        nan        nan
#  0.3116776  0.3817627         nan        nan 0.31885122 0.3304406
#         nan        nan 0.32229431 0.34065603        nan        nan
#  0.33966898 0.32409934        nan        nan 0.35525549 0.32493401]
# One or more of the test scores are non-finite: [       nan        nan 0.68544799 0.66108849        nan        nan
#  0.68740478 0.67002121        nan        nan 0.69636545 0.70283659
#         nan        nan 0.72239243 0.68543423        nan        nan
#  0.63908587 0.68067625        nan        nan 0.75602031 0.68363742
#         nan        nan 0.69115926 0.66214699        nan        nan
#  0.67458872 0.70300549        nan        nan 0.70526092 0.71366947
#         nan        nan 0.7107899  0.68015539        nan        nan
#  0.70552155 0.72792726        nan        nan 0.69855203 0.68015224
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.67270738 0.67414364        nan        nan
#  0.68651307 0.68423147        nan        nan 0.68160502 0.71307663
#         nan        nan 0.66463284 0.68978922        nan        nan
#  0.67636544 0.72496042        nan        nan 0.7489992  0.70383699
#         nan        nan 0.67488548 0.70231816        nan        nan
#  0.67541771 0.67806306        nan        nan 0.69961475 0.69180926
#         nan        nan 0.68406925 0.70949174        nan        nan
#  0.71591554 0.68061529        nan        nan 0.72029224 0.70335316]
#                                                                               22   \
# mean_fit_time                                                             0.01859
# std_fit_time                                                             0.000454
# mean_score_time                                                          0.009561
# std_score_time                                                           0.000378
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.695652
# split3_test_recall                                                        0.73913
# split4_test_recall                                                       0.636364
# mean_test_recall                                                          0.69249
# std_test_recall                                                          0.042746
# rank_test_recall                                                                1
# split0_test_precision                                                    0.193182
# split1_test_precision                                                    0.238095
# split2_test_precision                                                    0.307692
# split3_test_precision                                                    0.253731
# split4_test_precision                                                    0.259259
# mean_test_precision                                                      0.250392
# std_test_precision                                                       0.036871
# rank_test_precision                                                            22
# split0_test_f1                                                           0.306306
# split1_test_f1                                                           0.348837
# split2_test_f1                                                           0.426667
# split3_test_f1                                                           0.377778
# split4_test_f1                                                           0.368421
# mean_test_f1                                                             0.365602
# std_test_f1                                                              0.039197
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.705875
# split1_test_roc_auc                                                       0.72839
# split2_test_roc_auc                                                      0.815864
# split3_test_roc_auc                                                      0.770502
# split4_test_roc_auc                                                       0.75947
# mean_test_roc_auc                                                         0.75602
# std_test_roc_auc                                                         0.037632
# rank_test_roc_auc                                                               1
#
#                                                                               43   \
# mean_fit_time                                                            0.020473
# std_fit_time                                                              0.00065
# mean_score_time                                                          0.011907
# std_score_time                                                           0.002205
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                        0.73913
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.869565
# split4_test_recall                                                       0.636364
# mean_test_recall                                                         0.675099
# std_test_recall                                                          0.119454
# rank_test_recall                                                                2
# split0_test_precision                                                         0.4
# split1_test_precision                                                    0.178947
# split2_test_precision                                                    0.222222
# split3_test_precision                                                    0.190476
# split4_test_precision                                                    0.208955
# mean_test_precision                                                       0.24012
# std_test_precision                                                       0.081314
# rank_test_precision                                                            32
# split0_test_f1                                                            0.45283
# split1_test_f1                                                           0.288136
# split2_test_f1                                                           0.325581
# split3_test_f1                                                             0.3125
# split4_test_f1                                                           0.314607
# mean_test_f1                                                             0.338731
# std_test_f1                                                              0.058346
# rank_test_f1                                                                   14
# split0_test_roc_auc                                                       0.76294
# split1_test_roc_auc                                                      0.721273
# split2_test_roc_auc                                                      0.739519
# split3_test_roc_auc                                                      0.771153
# split4_test_roc_auc                                                      0.644751
# mean_test_roc_auc                                                        0.727927
# std_test_roc_auc                                                         0.045147
# rank_test_roc_auc                                                               3
#
#                                                                               10   \
# mean_fit_time                                                            0.016974
# std_fit_time                                                             0.002141
# mean_score_time                                                          0.010132
# std_score_time                                                           0.001639
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.782609
# split2_test_recall                                                       0.565217
# split3_test_recall                                                       0.782609
# split4_test_recall                                                            0.5
# mean_test_recall                                                          0.63913
# std_test_recall                                                          0.119545
# rank_test_recall                                                                3
# split0_test_precision                                                    0.224138
# split1_test_precision                                                    0.168224
# split2_test_precision                                                    0.288889
# split3_test_precision                                                        0.24
# split4_test_precision                                                    0.211538
# mean_test_precision                                                      0.226558
# std_test_precision                                                       0.039243
# rank_test_precision                                                            38
# split0_test_f1                                                           0.320988
# split1_test_f1                                                           0.276923
# split2_test_f1                                                           0.382353
# split3_test_f1                                                           0.367347
# split4_test_f1                                                           0.297297
# mean_test_f1                                                             0.328982
# std_test_f1                                                              0.040245
# rank_test_f1                                                                   24
# split0_test_roc_auc                                                      0.649715
# split1_test_roc_auc                                                       0.68543
# split2_test_roc_auc                                                      0.750776
# split3_test_roc_auc                                                      0.760219
# split4_test_roc_auc                                                      0.635687
# mean_test_roc_auc                                                        0.696365
# std_test_roc_auc                                                         0.051021
# rank_test_roc_auc                                                              21
#
#                                                                               118  \
# mean_fit_time                                                            0.020765
# std_fit_time                                                             0.001593
# mean_score_time                                                          0.011432
# std_score_time                                                           0.001215
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.454545
# mean_test_recall                                                         0.638735
# std_test_recall                                                          0.121713
# rank_test_recall                                                                4
# split0_test_precision                                                    0.285714
# split1_test_precision                                                    0.341463
# split2_test_precision                                                    0.355556
# split3_test_precision                                                    0.246753
# split4_test_precision                                                        0.25
# mean_test_precision                                                      0.295897
# std_test_precision                                                       0.045301
# rank_test_precision                                                             2
# split0_test_f1                                                           0.388889
# split1_test_f1                                                             0.4375
# split2_test_f1                                                           0.470588
# split3_test_f1                                                               0.38
# split4_test_f1                                                           0.322581
# mean_test_f1                                                             0.399912
# std_test_f1                                                              0.050806
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                       0.72192
# split1_test_roc_auc                                                       0.75207
# split2_test_roc_auc                                                      0.808747
# split3_test_roc_auc                                                      0.741343
# split4_test_roc_auc                                                      0.720915
# mean_test_roc_auc                                                        0.748999
# std_test_roc_auc                                                         0.032124
# rank_test_roc_auc                                                               2
#
#                                                                               42   \
# mean_fit_time                                                            0.021142
# std_fit_time                                                             0.003348
# mean_score_time                                                          0.010401
# std_score_time                                                           0.000628
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.434783
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.632806
# std_test_recall                                                          0.109468
# rank_test_recall                                                                5
# split0_test_precision                                                      0.3125
# split1_test_precision                                                    0.223881
# split2_test_precision                                                    0.192308
# split3_test_precision                                                    0.288462
# split4_test_precision                                                    0.165049
# mean_test_precision                                                       0.23644
# std_test_precision                                                       0.056024
# rank_test_precision                                                            34
# split0_test_f1                                                           0.422535
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.266667
# split3_test_f1                                                                0.4
# split4_test_f1                                                              0.272
# mean_test_f1                                                             0.338907
# std_test_f1                                                              0.063957
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.751294
# split1_test_roc_auc                                                      0.744306
# split2_test_roc_auc                                                      0.672619
# split3_test_roc_auc                                                      0.715178
# split4_test_roc_auc                                                       0.64421
# mean_test_roc_auc                                                        0.705522
# std_test_roc_auc                                                         0.041314
# rank_test_roc_auc                                                              12
#
#                                                                               15   \
# mean_fit_time                                                            0.019557
# std_fit_time                                                             0.001365
# mean_score_time                                                          0.009376
# std_score_time                                                           0.000545
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.565217
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.545455
# mean_test_recall                                                         0.622134
# std_test_recall                                                          0.083943
# rank_test_recall                                                                6
# split0_test_precision                                                    0.197183
# split1_test_precision                                                    0.325581
# split2_test_precision                                                    0.236364
# split3_test_precision                                                    0.219512
# split4_test_precision                                                    0.222222
# mean_test_precision                                                      0.240173
# std_test_precision                                                       0.044511
# rank_test_precision                                                            31
# split0_test_f1                                                           0.297872
# split1_test_f1                                                           0.424242
# split2_test_f1                                                           0.333333
# split3_test_f1                                                           0.342857
# split4_test_f1                                                           0.315789
# mean_test_f1                                                             0.342819
# std_test_f1                                                              0.043521
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.621118
# split1_test_roc_auc                                                      0.733049
# split2_test_roc_auc                                                       0.69824
# split3_test_roc_auc                                                      0.723249
# split4_test_roc_auc                                                      0.651515
# mean_test_roc_auc                                                        0.685434
# std_test_roc_auc                                                         0.042774
# rank_test_roc_auc                                                              28
#
#                                                                               46   \
# mean_fit_time                                                            0.019773
# std_fit_time                                                              0.00017
# mean_score_time                                                          0.010305
# std_score_time                                                           0.000703
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.454545
# mean_test_recall                                                         0.621344
# std_test_recall                                                          0.108517
# rank_test_recall                                                                7
# split0_test_precision                                                    0.164557
# split1_test_precision                                                    0.272727
# split2_test_precision                                                    0.236842
# split3_test_precision                                                    0.227273
# split4_test_precision                                                         0.2
# mean_test_precision                                                       0.22028
# std_test_precision                                                       0.036305
# rank_test_precision                                                            44
# split0_test_f1                                                           0.254902
# split1_test_f1                                                           0.384615
# split2_test_f1                                                           0.363636
# split3_test_f1                                                           0.337079
# split4_test_f1                                                           0.277778
# mean_test_f1                                                             0.323602
# std_test_f1                                                              0.049652
# rank_test_f1                                                                   32
# split0_test_roc_auc                                                      0.682453
# split1_test_roc_auc                                                      0.748059
# split2_test_roc_auc                                                      0.724379
# split3_test_roc_auc                                                      0.680942
# split4_test_roc_auc                                                      0.656926
# mean_test_roc_auc                                                        0.698552
# std_test_roc_auc                                                         0.032924
# rank_test_roc_auc                                                              20
#
#                                                                               142  \
# mean_fit_time                                                            0.020859
# std_fit_time                                                             0.002834
# mean_score_time                                                          0.010342
# std_score_time                                                           0.000652
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.826087
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.521739
# split4_test_recall                                                       0.545455
# mean_test_recall                                                         0.613439
# std_test_recall                                                          0.110089
# rank_test_recall                                                                8
# split0_test_precision                                                    0.245283
# split1_test_precision                                                    0.263889
# split2_test_precision                                                    0.304348
# split3_test_precision                                                         0.3
# split4_test_precision                                                        0.16
# mean_test_precision                                                      0.254704
# std_test_precision                                                       0.052265
# rank_test_precision                                                            18
# split0_test_f1                                                           0.342105
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.405797
# split3_test_f1                                                           0.380952
# split4_test_f1                                                           0.247423
# mean_test_f1                                                             0.355255
# std_test_f1                                                               0.05834
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.660714
# split1_test_roc_auc                                                      0.788173
# split2_test_roc_auc                                                      0.815088
# split3_test_roc_auc                                                      0.676907
# split4_test_roc_auc                                                      0.660579
# mean_test_roc_auc                                                        0.720292
# std_test_roc_auc                                                         0.067218
# rank_test_roc_auc                                                               6
#
#                                                                               47   \
# mean_fit_time                                                            0.019031
# std_fit_time                                                             0.001292
# mean_score_time                                                          0.009445
# std_score_time                                                           0.001663
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.363636
# mean_test_recall                                                         0.603162
# std_test_recall                                                          0.132858
# rank_test_recall                                                                9
# split0_test_precision                                                    0.177083
# split1_test_precision                                                    0.228571
# split2_test_precision                                                    0.192308
# split3_test_precision                                                    0.240741
# split4_test_precision                                                    0.222222
# mean_test_precision                                                      0.212185
# std_test_precision                                                       0.023715
# rank_test_precision                                                            46
# split0_test_f1                                                           0.285714
# split1_test_f1                                                           0.344086
# split2_test_f1                                                            0.29703
# split3_test_f1                                                           0.337662
# split4_test_f1                                                           0.275862
# mean_test_f1                                                             0.308071
# std_test_f1                                                              0.027683
# rank_test_f1                                                                   43
# split0_test_roc_auc                                                      0.701605
# split1_test_roc_auc                                                      0.696817
# split2_test_roc_auc                                                       0.65735
# split3_test_roc_auc                                                      0.699427
# split4_test_roc_auc                                                      0.645563
# mean_test_roc_auc                                                        0.680152
# std_test_roc_auc                                                         0.023773
# rank_test_roc_auc                                                              36
#
#                                                                               6    \
# mean_fit_time                                                            0.026015
# std_fit_time                                                             0.001274
# mean_score_time                                                          0.011663
# std_score_time                                                           0.000338
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.521739
# split3_test_recall                                                       0.695652
# split4_test_recall                                                       0.545455
# mean_test_recall                                                         0.596047
# std_test_recall                                                          0.081787
# rank_test_recall                                                               10
# split0_test_precision                                                    0.218182
# split1_test_precision                                                    0.202532
# split2_test_precision                                                    0.272727
# split3_test_precision                                                    0.235294
# split4_test_precision                                                    0.173913
# mean_test_precision                                                       0.22053
# std_test_precision                                                          0.033
# rank_test_precision                                                            43
# split0_test_f1                                                           0.307692
# split1_test_f1                                                           0.313725
# split2_test_f1                                                           0.358209
# split3_test_f1                                                           0.351648
# split4_test_f1                                                           0.263736
# mean_test_f1                                                             0.319002
# std_test_f1                                                              0.034097
# rank_test_f1                                                                   36
# split0_test_roc_auc                                                      0.663302
# split1_test_roc_auc                                                      0.742365
# split2_test_roc_auc                                                      0.693064
# split3_test_roc_auc                                                      0.718433
# split4_test_roc_auc                                                      0.619859
# mean_test_roc_auc                                                        0.687405
# std_test_roc_auc                                                         0.042799
# rank_test_roc_auc                                                              25
#
#                                                                               14   \
# mean_fit_time                                                            0.017935
# std_fit_time                                                             0.001027
# mean_score_time                                                          0.008962
# std_score_time                                                           0.001043
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# ...
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  140
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             140
#
#                                                                               56   \
# mean_fit_time                                                            0.003212
# std_fit_time                                                             0.000099
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              141
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           141
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  141
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             141
#
#                                                                               55   \
# mean_fit_time                                                            0.017109
# std_fit_time                                                             0.001978
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              142
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           142
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  142
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             142
#
#                                                                               67   \
# mean_fit_time                                                            0.015708
# std_fit_time                                                             0.003631
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              143
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           143
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  143
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             143
#
#                                                                               71
# mean_fit_time                                                             0.01583
# std_fit_time                                                             0.004809
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              144
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           144
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  144
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             144
#
# [43 rows x 144 columns]

# %%
clf = gscv.best_estimator_.steps[2][1]
viz = dtreeviz(clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"],
             fancy=False,
               scale=1.5
              )

viz
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
from sklearn import tree
plt.figure(figsize=(50, 10))
tree.plot_tree(clf, feature_names=X.columns, class_names=[str(_) for _ in [0,1]], filled=True, fontsize=15)
# Out:
# [Text(0.5, 0.9, 'Dinophysis fortii <= 0.707\ngini = 0.5\nsamples = 405\nvalue = [202.5, 202.5]\nclass = 0'),
#  Text(0.25, 0.7, 'month <= 7.5\ngini = 0.433\nsamples = 216\nvalue = [138.687, 64.266]\nclass = 0'),
#  Text(0.125, 0.5, 'salinity <= 37.57\ngini = 0.486\nsamples = 141\nvalue = [79.979, 56.991]\nclass = 0'),
#  Text(0.0625, 0.3, 'T <= 21.615\ngini = 0.499\nsamples = 118\nvalue = [61.261, 55.778]\nclass = 0'),
#  Text(0.03125, 0.1, 'gini = 0.492\nsamples = 84\nvalue = [37.437, 48.503]\nclass = 1'),
#  Text(0.09375, 0.1, 'gini = 0.358\nsamples = 34\nvalue = [23.824, 7.275]\nclass = 0'),
#  Text(0.1875, 0.3, 'wind strength <= 2.49\ngini = 0.114\nsamples = 23\nvalue = [18.718, 1.213]\nclass = 0'),
#  Text(0.15625, 0.1, 'gini = 0.486\nsamples = 3\nvalue = [1.702, 1.213]\nclass = 0'),
#  Text(0.21875, 0.1, 'gini = 0.0\nsamples = 20\nvalue = [17.017, 0.0]\nclass = 0'),
#  Text(0.375, 0.5, 'Soca <= 8754.138\ngini = 0.196\nsamples = 75\nvalue = [58.708, 7.275]\nclass = 0'),
#  Text(0.3125, 0.3, 'Dinophysis sacculus <= 15.0\ngini = 0.111\nsamples = 71\nvalue = [57.857, 3.638]\nclass = 0'),
#  Text(0.28125, 0.1, 'gini = 0.043\nsamples = 64\nvalue = [53.603, 1.213]\nclass = 0'),
#  Text(0.34375, 0.1, 'gini = 0.463\nsamples = 7\nvalue = [4.254, 2.425]\nclass = 0'),
#  Text(0.4375, 0.3, 'precipitation <= 124.55\ngini = 0.307\nsamples = 4\nvalue = [0.851, 3.638]\nclass = 1'),
#  Text(0.40625, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0.851, 0.0]\nclass = 0'),
#  Text(0.46875, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 3.638]\nclass = 1'),
#  Text(0.75, 0.7, 'salinity <= 37.105\ngini = 0.432\nsamples = 189\nvalue = [63.813, 138.234]\nclass = 1'),
#  Text(0.625, 0.5, 'Dinophysis tripos <= 0.357\ngini = 0.346\nsamples = 138\nvalue = [34.034, 118.832]\nclass = 1'),
#  Text(0.5625, 0.3, 'Dinophysis fortii <= 9.676\ngini = 0.42\nsamples = 103\nvalue = [33.183, 77.605]\nclass = 1'),
#  Text(0.53125, 0.1, 'gini = 0.0\nsamples = 13\nvalue = [0.0, 15.763]\nclass = 1'),
#  Text(0.59375, 0.1, 'gini = 0.455\nsamples = 90\nvalue = [33.183, 61.841]\nclass = 1'),
#  Text(0.6875, 0.3, 'air temp <= 20.183\ngini = 0.04\nsamples = 35\nvalue = [0.851, 41.228]\nclass = 1'),
#  Text(0.65625, 0.1, 'gini = 0.0\nsamples = 34\nvalue = [0.0, 41.228]\nclass = 1'),
#  Text(0.71875, 0.1, 'gini = -0.0\nsamples = 1\nvalue = [0.851, 0.0]\nclass = 0'),
#  Text(0.875, 0.5, 'DSP <= 112.0\ngini = 0.478\nsamples = 51\nvalue = [29.779, 19.401]\nclass = 0'),
#  Text(0.8125, 0.3, 'salinity <= 37.525\ngini = 0.295\nsamples = 30\nvalue = [22.122, 4.85]\nclass = 0'),
#  Text(0.78125, 0.1, 'gini = 0.0\nsamples = 19\nvalue = [16.166, 0.0]\nclass = 0'),
#  Text(0.84375, 0.1, 'gini = 0.495\nsamples = 11\nvalue = [5.956, 4.85]\nclass = 0'),
#  Text(0.9375, 0.3, 'Soca <= 1879.728\ngini = 0.452\nsamples = 21\nvalue = [7.658, 14.551]\nclass = 1'),
#  Text(0.90625, 0.1, 'gini = 0.216\nsamples = 12\nvalue = [1.702, 12.126]\nclass = 1'),
#  Text(0.96875, 0.1, 'gini = 0.411\nsamples = 9\nvalue = [5.956, 2.425]\nclass = 0')]

# %% [markdown]
# ### Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', RandomForestClassifier())
])

parameters = {
              'clf__n_estimators': [300,500],
              'clf__criterion': ['gini', 'entropy'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
               'smt__sampling_strategy': [ 0.1, 0.2],
               'under__sampling_strategy': [0.7, 0.8],
                'smt__k_neighbors': [3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="recall",
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
pd.set_option("display.max_rows", None)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# 240 fits failed out of a total of 480.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 268, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 226, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 394, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 534, in check_sampling_strategy
#     _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 373, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to remove samples from the minority class while trying to generate new samples. Please increase the ratio.
#
# One or more of the test scores are non-finite: [       nan        nan 0.60513834 0.69367589        nan        nan
#  0.64940711 0.71106719        nan        nan 0.67588933 0.68498024
#         nan        nan 0.63162055 0.64901186        nan        nan
#  0.66758893 0.64150198        nan        nan 0.64980237 0.69367589
#         nan        nan 0.66719368 0.67628458        nan        nan
#  0.62411067 0.7201581         nan        nan 0.67588933 0.70237154
#         nan        nan 0.66719368 0.67667984        nan        nan
#  0.63201581 0.67628458        nan        nan 0.63201581 0.68498024
#         nan        nan 0.66798419 0.64940711        nan        nan
#  0.64110672 0.7027668         nan        nan 0.64940711 0.70197628
#         nan        nan 0.66719368 0.68498024        nan        nan
#  0.65889328 0.64150198        nan        nan 0.65059289 0.68498024
#         nan        nan 0.65810277 0.71146245        nan        nan
#  0.64150198 0.64980237        nan        nan 0.67667984 0.63241107
#         nan        nan 0.63201581 0.68498024        nan        nan
#  0.64980237 0.69367589        nan        nan 0.67588933 0.66719368]
# One or more of the test scores are non-finite: [       nan        nan 0.47357044 0.43747408        nan        nan
#  0.50015059 0.43130157        nan        nan 0.52839192 0.45980787
#         nan        nan 0.4445515  0.47129857        nan        nan
#  0.47416086 0.43351927        nan        nan 0.47562321 0.43200237
#         nan        nan 0.49627267 0.43509642        nan        nan
#  0.47211279 0.42778279        nan        nan 0.5225463  0.43307455
#         nan        nan 0.48357975 0.42858692        nan        nan
#  0.50006733 0.41761594        nan        nan 0.50023529 0.43515131
#         nan        nan 0.50649823 0.44105963        nan        nan
#  0.47030303 0.458006          nan        nan 0.47388553 0.4312012
#         nan        nan 0.46508961 0.44150436        nan        nan
#  0.50047619 0.42932101        nan        nan 0.49271173 0.47530195
#         nan        nan 0.49158922 0.46435791        nan        nan
#  0.47629228 0.45117485        nan        nan 0.45695612 0.41635233
#         nan        nan 0.43586982 0.41419419        nan        nan
#  0.48305992 0.42930801        nan        nan 0.44743216 0.44196429]
# One or more of the test scores are non-finite: [       nan        nan 0.52859165 0.53133005        nan        nan
#  0.56198182 0.53232765        nan        nan 0.58929299 0.54942913
#         nan        nan 0.52042228 0.54364207        nan        nan
#  0.55143245 0.51396593        nan        nan 0.54788198 0.53000767
#         nan        nan 0.5672494  0.52930226        nan        nan
#  0.52859038 0.53410999        nan        nan 0.58826809 0.53511841
#         nan        nan 0.5558038  0.52043312        nan        nan
#  0.55587366 0.51090226        nan        nan 0.55617316 0.53124828
#         nan        nan 0.57293157 0.52339384        nan        nan
#  0.54148575 0.54825672        nan        nan 0.54581622 0.53384728
#         nan        nan 0.54443923 0.53307874        nan        nan
#  0.56808449 0.51067343        nan        nan 0.55493126 0.55769802
#         nan        nan 0.56134926 0.56169389        nan        nan
#  0.54212262 0.52909793        nan        nan 0.54386572 0.50104896
#         nan        nan 0.51515573 0.51380636        nan        nan
#  0.55197919 0.527388          nan        nan 0.53757737 0.5303238 ]
# One or more of the test scores are non-finite: [       nan        nan 0.86730849 0.87669952        nan        nan
#  0.8835111  0.87697581        nan        nan 0.8855675  0.87962614
#         nan        nan 0.87660613 0.86586274        nan        nan
#  0.88385551 0.86815368        nan        nan 0.88494404 0.87517748
#         nan        nan 0.89120932 0.88537893        nan        nan
#  0.87066201 0.87401473        nan        nan 0.88383389 0.88498017
#         nan        nan 0.87241733 0.87810963        nan        nan
#  0.88220663 0.87702753        nan        nan 0.87778044 0.86237666
#         nan        nan 0.87696499 0.87005405        nan        nan
#  0.87858226 0.88159741        nan        nan 0.88446965 0.88231806
#         nan        nan 0.87140073 0.87857425        nan        nan
#  0.87442161 0.87145806        nan        nan 0.88538251 0.88920664
#         nan        nan 0.8933558  0.87402916        nan        nan
#  0.86720535 0.88624155        nan        nan 0.87448907 0.88084571
#         nan        nan 0.88292502 0.88429595        nan        nan
#  0.87431154 0.87890785        nan        nan 0.87410411 0.87731376]
#                                                                                31  \
# mean_fit_time                                                            1.232484
# std_fit_time                                                             0.037189
# mean_score_time                                                          0.205276
# std_score_time                                                           0.013909
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.565217
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.818182
# mean_test_recall                                                         0.720158
# std_test_recall                                                          0.099818
# rank_test_recall                                                                1
# split0_test_precision                                                    0.472222
# split1_test_precision                                                    0.405405
# split2_test_precision                                                    0.393939
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.367347
# mean_test_precision                                                      0.427783
# std_test_precision                                                       0.049978
# rank_test_precision                                                            45
# split0_test_f1                                                           0.576271
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.464286
# split3_test_f1                                                           0.622951
# split4_test_f1                                                           0.507042
# mean_test_f1                                                              0.53411
# std_test_f1                                                              0.057344
# rank_test_f1                                                                   27
# split0_test_roc_auc                                                      0.924819
# split1_test_roc_auc                                                      0.800466
# split2_test_roc_auc                                                      0.839156
# split3_test_roc_auc                                                      0.909529
# split4_test_roc_auc                                                      0.896104
# mean_test_roc_auc                                                        0.874015
# std_test_roc_auc                                                         0.046808
# rank_test_roc_auc                                                              38
#
#                                                                                75  \
# mean_fit_time                                                            1.408382
# std_fit_time                                                             0.029423
# mean_score_time                                                          0.231231
# std_score_time                                                           0.007817
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.818182
# mean_test_recall                                                         0.711462
# std_test_recall                                                          0.091781
# rank_test_recall                                                                2
# split0_test_precision                                                    0.428571
# split1_test_precision                                                    0.441176
# split2_test_precision                                                    0.424242
# split3_test_precision                                                    0.513514
# split4_test_precision                                                    0.514286
# mean_test_precision                                                      0.464358
# std_test_precision                                                       0.040832
# rank_test_precision                                                            23
# split0_test_f1                                                           0.517241
# split1_test_f1                                                           0.526316
# split2_test_f1                                                                0.5
# split3_test_f1                                                           0.633333
# split4_test_f1                                                           0.631579
# mean_test_f1                                                             0.561694
# std_test_f1                                                              0.058395
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.895057
# split1_test_roc_auc                                                       0.82751
# split2_test_roc_auc                                                      0.846014
# split3_test_roc_auc                                                      0.909789
# split4_test_roc_auc                                                      0.891775
# mean_test_roc_auc                                                        0.874029
# std_test_roc_auc                                                         0.031574
# rank_test_roc_auc                                                              37
#
#                                                                                7   \
# mean_fit_time                                                            0.666811
# std_fit_time                                                             0.009498
# mean_score_time                                                          0.117366
# std_score_time                                                            0.00324
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.711067
# std_test_recall                                                          0.056736
# rank_test_recall                                                                3
# split0_test_precision                                                    0.517241
# split1_test_precision                                                    0.390244
# split2_test_precision                                                    0.394737
# split3_test_precision                                                    0.514286
# split4_test_precision                                                        0.34
# mean_test_precision                                                      0.431302
# std_test_precision                                                       0.071597
# rank_test_precision                                                            40
# split0_test_f1                                                           0.576923
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.491803
# split3_test_f1                                                            0.62069
# split4_test_f1                                                           0.472222
# mean_test_f1                                                             0.532328
# std_test_f1                                                              0.056739
# rank_test_f1                                                                   30
# split0_test_roc_auc                                                      0.903986
# split1_test_roc_auc                                                      0.838251
# split2_test_roc_auc                                                      0.861542
# split3_test_roc_auc                                                      0.924499
# split4_test_roc_auc                                                      0.856602
# mean_test_roc_auc                                                        0.876976
# std_test_roc_auc                                                         0.032065
# rank_test_roc_auc                                                              28
#
#                                                                                55  \
# mean_fit_time                                                            1.090955
# std_fit_time                                                             0.037822
# mean_score_time                                                          0.143445
# std_score_time                                                           0.014283
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.695652
# split4_test_recall                                                       0.818182
# mean_test_recall                                                         0.702767
# std_test_recall                                                          0.060895
# rank_test_recall                                                                4
# split0_test_precision                                                    0.615385
# split1_test_precision                                                    0.416667
# split2_test_precision                                                       0.375
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.382979
# mean_test_precision                                                      0.458006
# std_test_precision                                                       0.090288
# rank_test_precision                                                            25
# split0_test_f1                                                           0.653061
# split1_test_f1                                                           0.508475
# split2_test_f1                                                            0.47619
# split3_test_f1                                                           0.581818
# split4_test_f1                                                           0.521739
# mean_test_f1                                                             0.548257
# std_test_f1                                                              0.062593
# rank_test_f1                                                                   17
# split0_test_roc_auc                                                      0.935947
# split1_test_roc_auc                                                      0.804607
# split2_test_roc_auc                                                      0.871247
# split3_test_roc_auc                                                      0.919292
# split4_test_roc_auc                                                      0.876894
# mean_test_roc_auc                                                        0.881597
# std_test_roc_auc                                                         0.045676
# rank_test_roc_auc                                                              18
#
#                                                                                35  \
# mean_fit_time                                                            0.875272
# std_fit_time                                                             0.043872
# mean_score_time                                                           0.12949
# std_score_time                                                           0.011541
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.565217
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.702372
# std_test_recall                                                          0.082547
# rank_test_recall                                                                5
# split0_test_precision                                                    0.472222
# split1_test_precision                                                    0.405405
# split2_test_precision                                                    0.333333
# split3_test_precision                                                    0.529412
# split4_test_precision                                                       0.425
# mean_test_precision                                                      0.433075
# std_test_precision                                                       0.065715
# rank_test_precision                                                            38
# split0_test_f1                                                           0.576271
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.419355
# split3_test_f1                                                           0.631579
# split4_test_f1                                                           0.548387
# mean_test_f1                                                             0.535118
# std_test_f1                                                              0.071845
# rank_test_f1                                                                   26
# split0_test_roc_auc                                                      0.915631
# split1_test_roc_auc                                                      0.849767
# split2_test_roc_auc                                                      0.846661
# split3_test_roc_auc                                                      0.912002
# split4_test_roc_auc                                                      0.900839
# mean_test_roc_auc                                                         0.88498
# std_test_roc_auc                                                         0.030428
# rank_test_roc_auc                                                               8
#
#                                                                                59  \
# mean_fit_time                                                            1.605585
# std_fit_time                                                              0.03436
# mean_score_time                                                          0.205271
# std_score_time                                                           0.002246
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.727273
# mean_test_recall                                                         0.701976
# std_test_recall                                                          0.062775
# rank_test_recall                                                                6
# split0_test_precision                                                    0.472222
# split1_test_precision                                                    0.405405
# split2_test_precision                                                    0.378378
# split3_test_precision                                                         0.5
# split4_test_precision                                                         0.4
# mean_test_precision                                                      0.431201
# std_test_precision                                                       0.046573
# rank_test_precision                                                            41
# split0_test_f1                                                           0.576271
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.466667
# split3_test_f1                                                           0.610169
# split4_test_f1                                                           0.516129
# mean_test_f1                                                             0.533847
# std_test_f1                                                              0.052149
# rank_test_f1                                                                   28
# split0_test_roc_auc                                                      0.916278
# split1_test_roc_auc                                                       0.84705
# split2_test_roc_auc                                                      0.851579
# split3_test_roc_auc                                                      0.923848
# split4_test_roc_auc                                                      0.872835
# mean_test_roc_auc                                                        0.882318
# std_test_roc_auc                                                         0.032115
# rank_test_roc_auc                                                              16
#
#                                                                                91  \
# mean_fit_time                                                            1.922875
# std_fit_time                                                             0.027519
# mean_score_time                                                          0.250891
# std_score_time                                                           0.018011
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.565217
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.693676
# std_test_recall                                                          0.080481
# rank_test_recall                                                                7
# split0_test_precision                                                    0.355556
# split1_test_precision                                                    0.483871
# split2_test_precision                                                    0.382353
# split3_test_precision                                                    0.529412
# split4_test_precision                                                    0.395349
# mean_test_precision                                                      0.429308
# std_test_precision                                                       0.066023
# rank_test_precision                                                            43
# split0_test_f1                                                           0.470588
# split1_test_f1                                                           0.555556
# split2_test_f1                                                            0.45614
# split3_test_f1                                                           0.631579
# split4_test_f1                                                           0.523077
# mean_test_f1                                                             0.527388
# std_test_f1                                                              0.063198
# rank_test_f1                                                                   39
# split0_test_roc_auc                                                      0.899715
# split1_test_roc_auc                                                      0.851708
# split2_test_roc_auc                                                      0.832945
# split3_test_roc_auc                                                      0.924889
# split4_test_roc_auc                                                      0.885281
# mean_test_roc_auc                                                        0.878908
# std_test_roc_auc                                                         0.032986
# rank_test_roc_auc                                                              21
#
#                                                                                23  \
# mean_fit_time                                                            0.720045
# std_fit_time                                                             0.005885
# mean_score_time                                                          0.117706
# std_score_time                                                           0.002091
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.521739
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.693676
# std_test_recall                                                          0.111921
# rank_test_recall                                                                7
# split0_test_precision                                                    0.435897
# split1_test_precision                                                    0.482759
# split2_test_precision                                                    0.352941
# split3_test_precision                                                    0.463415
# split4_test_precision                                                       0.425
# mean_test_precision                                                      0.432002
# std_test_precision                                                       0.044447
# rank_test_precision                                                            39
# split0_test_f1                                                           0.548387
# split1_test_f1                                                           0.538462
# split2_test_f1                                                           0.421053
# split3_test_f1                                                            0.59375
# split4_test_f1                                                           0.548387
# mean_test_f1                                                             0.530008
# std_test_f1                                                               0.05776
# rank_test_f1                                                                   34
# split0_test_roc_auc                                                      0.896092
# split1_test_roc_auc                                                      0.812241
# split2_test_roc_auc                                                      0.837474
# split3_test_roc_auc                                                      0.934652
# split4_test_roc_auc                                                      0.895427
# mean_test_roc_auc                                                        0.875177
# std_test_roc_auc                                                         0.044198
# rank_test_roc_auc                                                              32
#
#                                                                                3   \
# mean_fit_time                                                            0.666376
# std_fit_time                                                             0.004173
# mean_score_time                                                          0.112206
# std_score_time                                                           0.002171
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.782609
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.521739
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.693676
# std_test_recall                                                          0.108491
# rank_test_recall                                                                7
# split0_test_precision                                                        0.45
# split1_test_precision                                                    0.538462
# split2_test_precision                                                    0.342857
# split3_test_precision                                                    0.486486
# split4_test_precision                                                    0.369565
# mean_test_precision                                                      0.437474
# std_test_precision                                                       0.072556
# rank_test_precision                                                            33
# split0_test_f1                                                           0.571429
# split1_test_f1                                                           0.571429
# split2_test_f1                                                           0.413793
# split3_test_f1                                                                0.6
# split4_test_f1                                                                0.5
# mean_test_f1                                                              0.53133
# std_test_f1                                                              0.067421
# rank_test_f1                                                                   31
# split0_test_roc_auc                                                      0.889622
# split1_test_roc_auc                                                      0.817288
# split2_test_roc_auc                                                      0.861672
# split3_test_roc_auc                                                      0.924629
# split4_test_roc_auc                                                      0.890287
# mean_test_roc_auc                                                          0.8767
# std_test_roc_auc                                                         0.035789
# rank_test_roc_auc                                                              30
#
#                                                                                11  \
# mean_fit_time                                                            1.136692
# std_fit_time                                                             0.023962
# mean_score_time                                                          0.185927
# std_score_time                                                            0.00297
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.608696
# split3_test_recall                                                        0.73913
# split4_test_recall                                                       0.772727
# mean_test_recall                                                          0.68498
# std_test_recall                                                          0.060998
# rank_test_recall                                                               10
# split0_test_precision                                                    0.441176
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.451613
# split3_test_precision                                                         0.5
# split4_test_precision                                                     0.53125
# mean_test_precision                                                      0.459808
# std_test_precision                                                       0.053528
# rank_test_precision                                                            24
# split0_test_f1                                                           0.526316
# split1_test_f1                                                            0.47619
# split2_test_f1                                                           0.518519
# split3_test_f1                                                           0.596491
# split4_test_f1                                                            0.62963
# mean_test_f1                                                             0.549429
# std_test_f1                                                              0.055679
# rank_test_f1                                                                   16
# split0_test_roc_auc                                                      0.901915
# split1_test_roc_auc                                                       0.83631
# split2_test_roc_auc                                                      0.851708
# split3_test_roc_auc                                                       0.90276
# split4_test_roc_auc                                                      0.905438
# mean_test_roc_auc                                                        0.879626
# std_test_roc_auc                                                         0.029509
# rank_test_roc_auc                                                              20
#
#                                                                                47  \
# mean_fit_time                                                            1.563756
# std_fit_time                                                             0.018123
# mean_score_time                                                          0.208207
# std_score_time                                                           0.001117
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.521739
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.772727
# mean_test_recall                                                          0.68498
# std_test_recall                                                          0.094941
# rank_test_recall                                                               10
# split0_test_precision                                                    0.432432
# split1_test_precision                                                    0.384615
# split2_test_precision                                                         0.4
# split3_test_precision                                                    0.486486
# split4_test_precision                                                    0.472222
# mean_test_precision                                                      0.435151
# std_test_precision                                                       0.039513
# rank_test_precision                                                            35
# split0_test_f1                                                           0.533333
# split1_test_f1                                                           0.483871
# split2_test_f1                                                            0.45283
# split3_test_f1                                                                0.6
# split4_test_f1                                                           0.586207
# mean_test_f1                                                             0.531248
# std_test_f1                                                              0.056825
# rank_test_f1                                                                   32
# split0_test_roc_auc                                                      0.888458
# split1_test_roc_auc                                                      0.805901
# split2_test_roc_auc                                                      0.824793
# split3_test_roc_auc                                                      0.928014
# split4_test_roc_auc                                                      0.864719
# mean_test_roc_auc                                                        0.862377
# std_test_roc_auc                                                         0.043809
# rank_test_roc_auc                                                              48
#
#                                                                                63  \
# mean_fit_time                                                            1.625582
# std_fit_time                                                             0.046024
# ...
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                   79
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                              92
#
#                                                                                9   \
# mean_fit_time                                                            0.002549
# std_fit_time                                                              0.00059
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                               93
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                            56
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                   51
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                              60
#
#                                                                                8   \
# mean_fit_time                                                            0.002876
# std_fit_time                                                             0.000225
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                               94
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                            68
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                   55
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                              62
#
#                                                                                45  \
# mean_fit_time                                                            0.003235
# std_fit_time                                                             0.000025
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.8
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                               95
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                            78
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                   78
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                              95
#
#                                                                                0
# mean_fit_time                                                            0.003367
# std_fit_time                                                             0.000879
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.1
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# split3_test_recall                                                            NaN
# split4_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                               96
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# split3_test_precision                                                         NaN
# split4_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                            96
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# split3_test_f1                                                                NaN
# split4_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                   96
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# split3_test_roc_auc                                                           NaN
# split4_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                              96
#
# [43 rows x 96 columns]

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

rf = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf, X, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
# Out:
# Text(0.5, 1.0, 'Permutation Importance Random Forest')

# %%
# Get feature importance with SHAP
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)
RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

# one-hot encoding of month feature
Xohe = pd.get_dummies(X, columns=["month"])

X_display = Xohe.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xohe)
Xsc = pd.DataFrame(scaled_array, columns=Xohe.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE()),
    ('under', RandomUnderSampler()),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.4, 0.5, 0.6],
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
             }
nfolds = 5
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "recall")
resultsGSCV = gscv.fit(Xsc, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#                                                                               11   \
# mean_fit_time                                                            0.338831
# std_fit_time                                                             0.186256
# mean_score_time                                                          0.011273
# std_score_time                                                           0.000848
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.818182
# mean_test_recall                                                         0.702767
# std_test_recall                                                          0.072253
# rank_test_recall                                                                1
# split0_test_precision                                                    0.242857
# split1_test_precision                                                    0.253968
# split2_test_precision                                                    0.208955
# split3_test_precision                                                    0.483871
# split4_test_precision                                                     0.26087
# mean_test_precision                                                      0.290104
# std_test_precision                                                       0.098512
# rank_test_precision                                                            58
# split0_test_f1                                                           0.365591
# split1_test_f1                                                           0.372093
# split2_test_f1                                                           0.311111
# split3_test_f1                                                           0.555556
# split4_test_f1                                                           0.395604
# mean_test_f1                                                             0.399991
# std_test_f1                                                               0.08256
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.700311
# split1_test_roc_auc                                                      0.788561
# split2_test_roc_auc                                                      0.690864
# split3_test_roc_auc                                                      0.759438
# split4_test_roc_auc                                                      0.803571
# mean_test_roc_auc                                                        0.748549
# std_test_roc_auc                                                          0.04561
# rank_test_roc_auc                                                              14
#
#                                                                               176  \
# mean_fit_time                                                            0.635115
# std_fit_time                                                             0.289213
# mean_score_time                                                          0.016027
# std_score_time                                                           0.001821
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                        0.73913
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.727273
# mean_test_recall                                                         0.667194
# std_test_recall                                                          0.110655
# rank_test_recall                                                                2
# split0_test_precision                                                    0.244444
# split1_test_precision                                                    0.217949
# split2_test_precision                                                    0.194444
# split3_test_precision                                                    0.216867
# split4_test_precision                                                    0.253968
# mean_test_precision                                                      0.225535
# std_test_precision                                                       0.021285
# rank_test_precision                                                           182
# split0_test_f1                                                           0.323529
# split1_test_f1                                                           0.336634
# split2_test_f1                                                           0.294737
# split3_test_f1                                                           0.339623
# split4_test_f1                                                           0.376471
# mean_test_f1                                                             0.334199
# std_test_f1                                                              0.026432
# rank_test_f1                                                                  113
# split0_test_roc_auc                                                       0.72619
# split1_test_roc_auc                                                      0.711827
# split2_test_roc_auc                                                      0.640528
# split3_test_roc_auc                                                      0.722598
# split4_test_roc_auc                                                      0.772863
# mean_test_roc_auc                                                        0.714801
# std_test_roc_auc                                                         0.042631
# rank_test_roc_auc                                                              62
#
#                                                                               140  \
# mean_fit_time                                                            0.566947
# std_fit_time                                                             0.185876
# mean_score_time                                                          0.012195
# std_score_time                                                           0.000362
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.521739
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.658893
# std_test_recall                                                          0.119179
# rank_test_recall                                                                3
# split0_test_precision                                                    0.282609
# split1_test_precision                                                    0.297872
# split2_test_precision                                                     0.20339
# split3_test_precision                                                    0.263889
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.276219
# std_test_precision                                                        0.04296
# rank_test_precision                                                            91
# split0_test_f1                                                           0.376812
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.292683
# split3_test_f1                                                                0.4
# split4_test_f1                                                           0.465753
# mean_test_f1                                                              0.38705
# std_test_f1                                                              0.055749
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.697723
# split1_test_roc_auc                                                      0.762034
# split2_test_roc_auc                                                      0.716097
# split3_test_roc_auc                                                      0.824525
# split4_test_roc_auc                                                      0.855249
# mean_test_roc_auc                                                        0.771126
# std_test_roc_auc                                                         0.060707
# rank_test_roc_auc                                                               2
#
#                                                                               169  \
# mean_fit_time                                                            0.905704
# std_fit_time                                                             0.440312
# mean_score_time                                                          0.015444
# std_score_time                                                           0.003267
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.869565
# split2_test_recall                                                       0.478261
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.636364
# mean_test_recall                                                         0.649012
# std_test_recall                                                          0.132028
# rank_test_recall                                                                4
# split0_test_precision                                                    0.231884
# split1_test_precision                                                    0.273973
# split2_test_precision                                                       0.275
# split3_test_precision                                                    0.288889
# split4_test_precision                                                    0.194444
# mean_test_precision                                                      0.252838
# std_test_precision                                                       0.034889
# rank_test_precision                                                           136
# split0_test_f1                                                           0.347826
# split1_test_f1                                                           0.416667
# split2_test_f1                                                           0.349206
# split3_test_f1                                                           0.382353
# split4_test_f1                                                           0.297872
# mean_test_f1                                                             0.358785
# std_test_f1                                                              0.039568
# rank_test_f1                                                                   49
# split0_test_roc_auc                                                      0.704451
# split1_test_roc_auc                                                       0.79529
# split2_test_roc_auc                                                      0.634576
# split3_test_roc_auc                                                      0.667274
# split4_test_roc_auc                                                      0.731466
# mean_test_roc_auc                                                        0.706611
# std_test_roc_auc                                                         0.055178
# rank_test_roc_auc                                                              93
#
#                                                                               56   \
# mean_fit_time                                                            0.326287
# std_fit_time                                                             0.142526
# mean_score_time                                                          0.011822
# std_score_time                                                           0.002299
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.347826
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.641502
# std_test_recall                                                          0.157229
# rank_test_recall                                                                5
# split0_test_precision                                                        0.32
# split1_test_precision                                                    0.234375
# split2_test_precision                                                    0.135338
# split3_test_precision                                                    0.306122
# split4_test_precision                                                    0.242857
# mean_test_precision                                                      0.247739
# std_test_precision                                                       0.065523
# rank_test_precision                                                           148
# split0_test_f1                                                           0.333333
# split1_test_f1                                                           0.344828
# split2_test_f1                                                           0.230769
# split3_test_f1                                                           0.416667
# split4_test_f1                                                           0.369565
# mean_test_f1                                                             0.339032
# std_test_f1                                                              0.061231
# rank_test_f1                                                                  100
# split0_test_roc_auc                                                      0.648292
# split1_test_roc_auc                                                      0.737578
# split2_test_roc_auc                                                      0.557324
# split3_test_roc_auc                                                      0.723249
# split4_test_roc_auc                                                      0.789502
# mean_test_roc_auc                                                        0.691189
# std_test_roc_auc                                                         0.080753
# rank_test_roc_auc                                                             130
#
#                                                                               68   \
# mean_fit_time                                                            0.557746
# std_fit_time                                                              0.30272
# mean_score_time                                                          0.011145
# std_score_time                                                           0.000835
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.521739
# split2_test_recall                                                       0.391304
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.909091
# mean_test_recall                                                         0.633992
# std_test_recall                                                          0.178253
# rank_test_recall                                                                6
# split0_test_precision                                                    0.283333
# split1_test_precision                                                    0.196721
# split2_test_precision                                                     0.28125
# split3_test_precision                                                    0.205882
# split4_test_precision                                                    0.178571
# mean_test_precision                                                      0.229152
# std_test_precision                                                       0.044275
# rank_test_precision                                                           176
# split0_test_f1                                                           0.409639
# split1_test_f1                                                           0.285714
# split2_test_f1                                                           0.327273
# split3_test_f1                                                           0.307692
# split4_test_f1                                                           0.298507
# mean_test_f1                                                             0.325765
# std_test_f1                                                               0.04407
# rank_test_f1                                                                  138
# split0_test_roc_auc                                                      0.736672
# split1_test_roc_auc                                                        0.6897
# split2_test_roc_auc                                                      0.609472
# split3_test_roc_auc                                                      0.755793
# split4_test_roc_auc                                                      0.682089
# mean_test_roc_auc                                                        0.694745
# std_test_roc_auc                                                         0.050876
# rank_test_roc_auc                                                             123
#
#                                                                               155  \
# mean_fit_time                                                            0.619021
# std_fit_time                                                             0.303946
# mean_score_time                                                          0.010797
# std_score_time                                                           0.000181
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.521739
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.632806
# std_test_recall                                                          0.098564
# rank_test_recall                                                                7
# split0_test_precision                                                    0.171429
# split1_test_precision                                                    0.207792
# split2_test_precision                                                    0.170455
# split3_test_precision                                                    0.210526
# split4_test_precision                                                    0.377778
# mean_test_precision                                                      0.227596
# std_test_precision                                                       0.077017
# rank_test_precision                                                           178
# split0_test_f1                                                           0.258065
# split1_test_f1                                                               0.32
# split2_test_f1                                                            0.27027
# split3_test_f1                                                                0.3
# split4_test_f1                                                           0.507463
# mean_test_f1                                                             0.331159
# std_test_f1                                                              0.090806
# rank_test_f1                                                                  121
# split0_test_roc_auc                                                       0.64868
# split1_test_roc_auc                                                      0.721144
# split2_test_roc_auc                                                       0.66382
# split3_test_roc_auc                                                      0.650612
# split4_test_roc_auc                                                      0.803301
# mean_test_roc_auc                                                        0.697511
# std_test_roc_auc                                                         0.059109
# rank_test_roc_auc                                                             120
#
#                                                                               172  \
# mean_fit_time                                                             0.80413
# std_fit_time                                                             0.500972
# mean_score_time                                                          0.011441
# std_score_time                                                           0.000332
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.565217
# split3_test_recall                                                            1.0
# split4_test_recall                                                       0.545455
# mean_test_recall                                                          0.63083
# std_test_recall                                                           0.19329
# rank_test_recall                                                                8
# split0_test_precision                                                    0.294118
# split1_test_precision                                                    0.212121
# split2_test_precision                                                    0.142857
# split3_test_precision                                                    0.255556
# split4_test_precision                                                    0.285714
# mean_test_precision                                                      0.238073
# std_test_precision                                                       0.055598
# rank_test_precision                                                           163
# split0_test_f1                                                           0.350877
# split1_test_f1                                                           0.314607
# split2_test_f1                                                            0.22807
# split3_test_f1                                                            0.40708
# split4_test_f1                                                              0.375
# mean_test_f1                                                             0.335127
# std_test_f1                                                              0.061477
# rank_test_f1                                                                  110
# split0_test_roc_auc                                                      0.670549
# split1_test_roc_auc                                                      0.671325
# split2_test_roc_auc                                                      0.622024
# split3_test_roc_auc                                                      0.842489
# split4_test_roc_auc                                                      0.757711
# mean_test_roc_auc                                                        0.712819
# std_test_roc_auc                                                         0.078207
# rank_test_roc_auc                                                              71
#
#                                                                               201  \
# mean_fit_time                                                            0.722012
# std_fit_time                                                             0.278137
# mean_score_time                                                          0.011903
# std_score_time                                                           0.000566
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.521739
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.434783
# split4_test_recall                                                       0.863636
# mean_test_recall                                                         0.616206
# std_test_recall                                                          0.144506
# rank_test_recall                                                                9
# split0_test_precision                                                     0.27451
# split1_test_precision                                                    0.342857
# split2_test_precision                                                        0.25
# split3_test_precision                                                    0.357143
# split4_test_precision                                                    0.271429
# mean_test_precision                                                      0.299188
# std_test_precision                                                       0.042579
# rank_test_precision                                                            38
# split0_test_f1                                                           0.378378
# split1_test_f1                                                           0.413793
# split2_test_f1                                                           0.361446
# split3_test_f1                                                           0.392157
# split4_test_f1                                                           0.413043
# mean_test_f1                                                             0.391764
# std_test_f1                                                              0.020182
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                        0.6897
# split1_test_roc_auc                                                      0.732919
# split2_test_roc_auc                                                       0.71131
# split3_test_roc_auc                                                      0.691356
# split4_test_roc_auc                                                      0.831034
# mean_test_roc_auc                                                        0.731264
# std_test_roc_auc                                                         0.052297
# rank_test_roc_auc                                                              23
#
#                                                                               206  \
# mean_fit_time                                                            1.011142
# std_fit_time                                                             0.552178
# mean_score_time                                                          0.012748
# std_score_time                                                           0.003434
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                        0.73913
# split2_test_recall                                                       0.391304
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.727273
# mean_test_recall                                                          0.61502
# std_test_recall                                                          0.127995
# rank_test_recall                                                               10
# split0_test_precision                                                    0.319149
# split1_test_precision                                                    0.232877
# split2_test_precision                                                    0.155172
# split3_test_precision                                                        0.26
# split4_test_precision                                                    0.242424
# mean_test_precision                                                      0.241924
# std_test_precision                                                       0.052723
# rank_test_precision                                                           154
# split0_test_f1                                                           0.428571
# split1_test_f1                                                           0.354167
# split2_test_f1                                                           0.222222
# split3_test_f1                                                           0.356164
# split4_test_f1                                                           0.363636
# mean_test_f1                                                             0.344952
# std_test_f1                                                              0.067253
# rank_test_f1                                                                   89
# split0_test_roc_auc                                                      0.754658
# split1_test_roc_auc                                                      0.778468
# split2_test_roc_auc                                                      0.620342
# split3_test_roc_auc                                                      0.672351
# split4_test_roc_auc                                                      0.744859
# mean_test_roc_auc                                                        0.714136
# std_test_roc_auc                                                         0.058767
# rank_test_roc_auc                                                              64
#
#                                                                               31   \
# mean_fit_time                                                            0.367437
# std_fit_time                                                             0.204256
# mean_score_time                                                          0.011686
# std_score_time                                                           0.001068
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.454545
# mean_test_recall                                                         0.612648
# std_test_recall                                                          0.088099
# rank_test_recall                                                               11
# split0_test_precision                                                    0.262295
# split1_test_precision                                                    0.271186
# split2_test_precision                                                    0.133333
# split3_test_precision                                                    0.378378
# split4_test_precision                                                    0.384615
# mean_test_precision                                                      0.285962
# std_test_precision                                                        0.09203
# rank_test_precision                                                            69
# split0_test_f1                                                           0.380952
# split1_test_f1                                                           0.390244
# split2_test_f1                                                            0.21875
# split3_test_f1                                                           0.466667
# split4_test_f1                                                           0.416667
# mean_test_f1                                                             0.374656
# std_test_f1                                                              0.083451
# rank_test_f1                                                                   24
# split0_test_roc_auc                                                       0.73499
# split1_test_roc_auc                                                      0.749224
# split2_test_roc_auc                                                      0.558359
# split3_test_roc_auc                                                      0.817235
# split4_test_roc_auc                                                      0.787338
# mean_test_roc_auc                                                        0.729429
# std_test_roc_auc                                                         0.090278
# rank_test_roc_auc                                                              32
#
#                                                                               85   \
# mean_fit_time                                                            0.349852
# std_fit_time                                                             0.124553
# mean_score_time                                                          0.012104
# std_score_time                                                           0.002245
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.590909
# mean_test_recall                                                         0.596443
# std_test_recall                                                          0.088615
# rank_test_recall                                                               12
# split0_test_precision                                                     0.47619
# split1_test_precision                                                    0.313725
# split2_test_precision                                                    0.164706
# split3_test_precision                                                    0.223881
# split4_test_precision                                                    0.282609
# mean_test_precision                                                      0.292222
# std_test_precision                                                       0.105195
# rank_test_precision                                                            51
# split0_test_f1                                                           0.454545
# split1_test_f1                                                           0.432432
# split2_test_f1                                                           0.259259
# split3_test_f1                                                           0.333333
# split4_test_f1                                                           0.382353
# mean_test_f1                                                             0.372385
# std_test_f1                                                              0.070396
# rank_test_f1                                                                   29
# split0_test_roc_auc                                                      0.691511
# split1_test_roc_auc                                                      0.787008
# split2_test_roc_auc                                                      0.612836
# split3_test_roc_auc                                                      0.698516
# split4_test_roc_auc                                                      0.727002
# mean_test_roc_auc                                                        0.703375
# std_test_roc_auc                                                         0.056417
# rank_test_roc_auc                                                             103
#
#                                                                               48   \
# mean_fit_time                                                            0.422261
# std_fit_time                                                             0.223223
# mean_score_time                                                          0.010691
# std_score_time                                                            0.00041
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.347826
# split2_test_recall                                                       0.434783
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.909091
# mean_test_recall                                                         0.590514
# std_test_recall                                                          0.229951
# rank_test_recall                                                               13
# split0_test_precision                                                         0.4
# split1_test_precision                                                    0.242424
# split2_test_precision                                                    0.185185
# split3_test_precision                                                    0.296875
# split4_test_precision                                                    0.217391
# mean_test_precision                                                      0.268375
# std_test_precision                                                       0.075274
# rank_test_precision                                                           111
# split0_test_f1                                                           0.416667
# split1_test_f1                                                           0.285714
# split2_test_f1                                                            0.25974
# split3_test_f1                                                           0.436782
# split4_test_f1                                                           0.350877
# mean_test_f1                                                             0.349956
# std_test_f1                                                               0.06965
# rank_test_f1                                                                   74
# split0_test_roc_auc                                                      0.703546
# split1_test_roc_auc                                                      0.652174
# split2_test_roc_auc                                                      0.598732
# split3_test_roc_auc                                                       0.83611
# split4_test_roc_auc                                                      0.741883
# mean_test_roc_auc                                                        0.706489
# std_test_roc_auc                                                         0.080777
# rank_test_roc_auc                                                              94
#
#                                                                               55   \
# mean_fit_time                                                            0.492791
# std_fit_time                                                             0.154395
# mean_score_time                                                          0.010591
# std_score_time                                                           0.000117
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.434783
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.478261
# split4_test_recall                                                       0.818182
# mean_test_recall                                                         0.589723
# std_test_recall                                                          0.133674
# ...
# split4_test_precision                                                       0.275
# mean_test_precision                                                      0.166544
# std_test_precision                                                       0.096885
# rank_test_precision                                                           210
# split0_test_f1                                                           0.311688
# split1_test_f1                                                                0.0
# split2_test_f1                                                           0.179775
# split3_test_f1                                                           0.235294
# split4_test_f1                                                           0.354839
# mean_test_f1                                                             0.216319
# std_test_f1                                                              0.123913
# rank_test_f1                                                                  212
# split0_test_roc_auc                                                       0.71558
# split1_test_roc_auc                                                      0.521739
# split2_test_roc_auc                                                      0.493271
# split3_test_roc_auc                                                      0.636553
# split4_test_roc_auc                                                        0.7546
# mean_test_roc_auc                                                        0.624349
# std_test_roc_auc                                                         0.103099
# rank_test_roc_auc                                                             209
#
#                                                                               91   \
# mean_fit_time                                                            0.325165
# std_fit_time                                                             0.180116
# mean_score_time                                                          0.012013
# std_score_time                                                           0.001825
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                        0.26087
# split2_test_recall                                                       0.304348
# split3_test_recall                                                            0.0
# split4_test_recall                                                       0.545455
# mean_test_recall                                                         0.317787
# std_test_recall                                                          0.190784
# rank_test_recall                                                              213
# split0_test_precision                                                        0.25
# split1_test_precision                                                    0.222222
# split2_test_precision                                                    0.225806
# split3_test_precision                                                         0.0
# split4_test_precision                                                    0.266667
# mean_test_precision                                                      0.192939
# std_test_precision                                                       0.097831
# rank_test_precision                                                           207
# split0_test_f1                                                           0.328358
# split1_test_f1                                                               0.24
# split2_test_f1                                                           0.259259
# split3_test_f1                                                                0.0
# split4_test_f1                                                           0.358209
# mean_test_f1                                                             0.237165
# std_test_f1                                                              0.126263
# rank_test_f1                                                                  210
# split0_test_roc_auc                                                      0.677536
# split1_test_roc_auc                                                      0.615683
# split2_test_roc_auc                                                      0.568582
# split3_test_roc_auc                                                           0.5
# split4_test_roc_auc                                                      0.686418
# mean_test_roc_auc                                                        0.609644
# std_test_roc_auc                                                         0.069639
# rank_test_roc_auc                                                             213
#
#                                                                               93   \
# mean_fit_time                                                            0.248037
# std_fit_time                                                             0.165112
# mean_score_time                                                          0.011576
# std_score_time                                                           0.002199
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.363636
# mean_test_recall                                                         0.298814
# std_test_recall                                                          0.260709
# rank_test_recall                                                              214
# split0_test_precision                                                    0.164179
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# split3_test_precision                                                    0.151515
# split4_test_precision                                                    0.296296
# mean_test_precision                                                      0.122398
# std_test_precision                                                       0.112068
# rank_test_precision                                                           215
# split0_test_f1                                                           0.244444
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# split3_test_f1                                                           0.245902
# split4_test_f1                                                           0.326531
# mean_test_f1                                                             0.163375
# std_test_f1                                                              0.136664
# rank_test_f1                                                                  215
# split0_test_roc_auc                                                       0.65722
# split1_test_roc_auc                                                           0.5
# split2_test_roc_auc                                                      0.497024
# split3_test_roc_auc                                                      0.651783
# split4_test_roc_auc                                                      0.760011
# mean_test_roc_auc                                                        0.613208
# std_test_roc_auc                                                         0.101283
# rank_test_roc_auc                                                             212
#
#                                                                               106  \
# mean_fit_time                                                            0.450552
# std_fit_time                                                             0.270485
# mean_score_time                                                          0.012053
# std_score_time                                                           0.001782
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                            0.0
# split1_test_recall                                                       0.347826
# split2_test_recall                                                       0.217391
# split3_test_recall                                                       0.043478
# split4_test_recall                                                       0.727273
# mean_test_recall                                                         0.267194
# std_test_recall                                                          0.261571
# rank_test_recall                                                              215
# split0_test_precision                                                         0.0
# split1_test_precision                                                        0.32
# split2_test_precision                                                         0.2
# split3_test_precision                                                    0.041667
# split4_test_precision                                                    0.149533
# mean_test_precision                                                       0.14224
# std_test_precision                                                       0.114311
# rank_test_precision                                                           214
# split0_test_f1                                                                0.0
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.208333
# split3_test_f1                                                           0.042553
# split4_test_f1                                                           0.248062
# mean_test_f1                                                             0.166456
# std_test_f1                                                              0.125953
# rank_test_f1                                                                  214
# split0_test_roc_auc                                                           0.5
# split1_test_roc_auc                                                      0.625388
# split2_test_roc_auc                                                      0.554089
# split3_test_roc_auc                                                      0.576412
# split4_test_roc_auc                                                      0.636905
# mean_test_roc_auc                                                        0.578559
# std_test_roc_auc                                                         0.049744
# rank_test_roc_auc                                                             216
#
#                                                                               82
# mean_fit_time                                                            0.459867
# std_fit_time                                                             0.513262
# mean_score_time                                                           0.01319
# std_score_time                                                           0.001081
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.391304
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# split3_test_recall                                                            0.0
# split4_test_recall                                                       0.863636
# mean_test_recall                                                         0.250988
# std_test_recall                                                          0.341764
# rank_test_recall                                                              216
# split0_test_precision                                                     0.28125
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# split3_test_precision                                                         0.0
# split4_test_precision                                                    0.202128
# mean_test_precision                                                      0.096676
# std_test_precision                                                       0.121018
# rank_test_precision                                                           216
# split0_test_f1                                                           0.327273
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# split3_test_f1                                                                0.0
# split4_test_f1                                                           0.327586
# mean_test_f1                                                             0.130972
# std_test_f1                                                              0.160407
# rank_test_f1                                                                  216
# split0_test_roc_auc                                                      0.638199
# split1_test_roc_auc                                                      0.494048
# split2_test_roc_auc                                                      0.633023
# split3_test_roc_auc                                                           0.5
# split4_test_roc_auc                                                      0.780574
# mean_test_roc_auc                                                        0.609169
# std_test_roc_auc                                                         0.105794
# rank_test_roc_auc                                                             214
#
# [41 rows x 216 columns]

# %% [markdown]
# #### Feature Importance (MLP)

# %%
# Feature importance of model (MLP)  (no cross-validation!)

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=3)

MLP = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(MLP, Xsc, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = Xsc.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance MLP")
# Out:
# Text(0.5, 1.0, 'Permutation Importance MLP')

# %% [markdown]
# #### Feature importance with SHAP

# %%
X = Xsc.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.25)

nn = MLPClassifier(hidden_layer_sizes=(3,3), solver='lbfgs', max_iter=5000)
model = nn.fit(X_train.to_numpy(), y_train)

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# explain the model's predictions using SHAP
import shap
import warnings
warnings.filterwarnings("ignore")
shap.initjs()

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,20))
shap_values = explainer.shap_values(X_test, nsamples=50)
shap.summary_plot(shap_values, X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
#   0%|          | 0/239 [00:00<?, ?it/s]

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,50))
shap_values = explainer.shap_values(X_test, nsamples=50)
for classid in [0,1]:
    shap.summary_plot(shap_values[classid], X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
#   0%|          | 0/239 [00:00<?, ?it/s]

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
instanceID = 10
instance = X.iloc[[instanceID]]
display_instance = X_display.iloc[[instanceID]]

prediction = model.predict(instance)[0]
prediction_probs = model.predict_proba(instance)[0]
print(f'real value: {y[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)
# Out:
# real value: 1,
# predicted: 0,
# predicted probs: [0.95424595 0.04575405]
# Explanation for prediction: class=0, p=0.9542459536480314
#   0%|          | 0/1 [00:00<?, ?it/s]
# <div id='i0KMNGDU3GST6I6W2HNU0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.9240527114070525, "outValue": 0.9542459536480314, "link": "identity", "featureNames": ["DSP", "Dinophysis caudata", "Dinophysis fortii", "Phalacroma rotundatum", "Dinophysis sacculus", "Dinophysis tripos", "sun [h]", "air temp", "wind strength", "precipitation", "salinity", "T", "Soca", "month_1", "month_2", "month_3", "month_4", "month_5", "month_6", "month_7", "month_8", "month_9", "month_10", "month_11", "month_12"], "features": {"0": {"effect": -0.04972470620550876, "value": 216.0}, "1": {"effect": -0.07063837796440565, "value": 92.0}, "2": {"effect": -0.0451061594752663, "value": 111.0}, "3": {"effect": 0.020336063714273843, "value": 13.0}, "6": {"effect": -0.06085312046314814, "value": 103.40000000000002}, "8": {"effect": 0.054463460345376184, "value": 2.704761904761905}, "9": {"effect": 0.046951718853104646, "value": 219.9}, "10": {"effect": 0.09003012983406525, "value": 37.39}, "11": {"effect": 0.08089277755286356, "value": 21.73}, "12": {"effect": 0.012715924760225338, "value": 1852.896}, "15": {"effect": 0.006262075421995153, "value": 0.0}, "16": {"effect": -0.024700500056539114, "value": 0.0}, "17": {"effect": -0.021904773212085286, "value": 0.0}, "18": {"effect": -0.012366428904895404, "value": 0.0}, "19": {"effect": 0.021556480193429164, "value": 0.0}, "21": {"effect": -0.025613061197695734, "value": 1.0}, "23": {"effect": 0.007891739045190228, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i0KMNGDU3GST6I6W2HNU0')
#   );
# </script>

# %% [markdown]
# Show the mean values of features as it may help understanding this particular instance data in the plot above.

# %%
data = pd.get_dummies(df_cons_SL_l, columns=["month"])


pd.DataFrame([data[data['lipophylic_toxins']=='neg'].mean(), data[data['lipophylic_toxins']=='poz'].mean()], index=['neg','pos']).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 data = pd.get_dummies(df_cons_SL_l, columns=["month"])
#       4 pd.DataFrame([data[data['lipophylic_toxins']=='neg'].mean(), data[data['lipophylic_toxins']=='poz'].mean()], index=['neg','pos']).T
#
# NameError: name 'df_cons_SL_l' is not defined

# %% [markdown]
# ### Conclusion

# %%
# Summary table of prediction results
RF_recall = round(RF_recall_best_k[1], 2)
RF_auc = round(RF_auc_best_k[1], 2)
MLP_recall = round(MLP_recall_best_k[1], 2)
MLP_auc = round(MLP_auc_best_k[1], 2)

summary = pd.DataFrame(
    [
        (
            "RF",
            RF_recall_score,
            RF_auc_score,
        ),
        (
            "MLP",
            MLP_recall_score,
            MLP_auc_score,
        ),
        (
            "RF (smote)",
            RF_recall,
            RF_auc,
        ),
        (
            "MLP (smote)",
            MLP_recall,
            MLP_auc,
        ),
        (
            "Decision tree (J48)*",
            0.56,
            0.18,
        ),
    ],
    columns=("Model", "Recall", "ROC AUC"),
).set_index("Model")

print("Table summarising the prediction results of the used classifiers, both with and without SMOTE resampling:\n")
summary.round(2)
# Out:
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# As can be seen resampling with SMOTE helped to improve the results substantially, especially when calculating recall. The highest recall and ROC AUC was achieved with Random Forest with the re-sampled data. Both recall and ROC AUC suggest Random Forest as beeing the better classifier for this particular problem. Recall is a crucial metric as it gives indication of what fraction of true positive instances have been predicted. Since the models predict toxins in seashells (food) it is crucial that as few positives as possible are missed.
#
# Due to the use of SMOTE resampling (upsampling and downsampling) in combinaiton with cross-validation it was curcial to do the resampling within each fold to avoid data lekeage and validate on original (unsampled) data. In addition, I have optimised the model with regard to the k-values of SMOTE, all of which brought along some complexity. So for the parameter tuning of Random Forest and MLP various parameter settings have been tried  and the model with best performing settings has been chosen.
#
# The decision tree J48 algorithm was run within Weka on a slightly different dataset (missing values were not removed to use as many instances as possible, cross validation was 10-fold as opposed to 3-fold due to a higher dataset etc.) thus this results are not directly comparable but were provided as a reference to give an indication of the performance of this algorithm.
#
# As can be seen in the feature importance bar plots above, similar features were on the top despite using two different classification algorithms and two different feature ranking methods. If we consider just the three highest-ranking features of each of the feature ranking methods for both algortihms (RF and MLP) the features that overlap are DSP, DSP_like, ASP, Dinophysis fortii and Dinophysis caudata. These can be shown to the domain experts for validation and interpretation.
