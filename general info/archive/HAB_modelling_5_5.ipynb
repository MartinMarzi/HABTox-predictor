# %%
from datetime import datetime
import pandas as pd
import numpy as np
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from dtreeviz.trees import dtreeviz 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 30)

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")
# data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# SECCHI                   450
# DIN                      352
# PO4-P                    349
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
# data.drop(columns=["Chl-a","PO4-P","DIN","SECCHI"], inplace=True)
data.drop(columns=["SECCHI",  ], inplace=True)#,"Chl-a", "PO4-P", "DIN",
data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# DIN                      352
# PO4-P                    349
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Modelling and Preliminary Results

# %% [markdown]
# ![Screenshot 2022-07-26 at 12.15.26.png](attachment:500d2dd5-b27f-4f67-a0a0-94d4c6fc8714.png)

# %% [markdown]
# # Scikit-learn Analysis

# %% [markdown]
# ### Preprocessing

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    662
# poz     88
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# Clean the dataset by removing samples close to the decision boundary. Because the dataset is heavily imbalanced in favor of clas 0 (neg) we will remove instances from this class whenever finding samples which do not agree “enough” with their neighboorhood. The EditedNearestNeighbours will be used. One other option is to use Tomek links but it is more conservative and was found to perform slightly worse.

# %%
from collections import Counter
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours

print(f'Original dataset shape: {Counter(y)}')
usmp = EditedNearestNeighbours()
lastMajorityCount = Counter(y)[0]
for i in range(10):
    X_res, y_res = usmp.fit_resample(X, y)
    if Counter(y_res)[0] == lastMajorityCount:
        print('Cannot remove any more samples')
        break
    else:
        print(f'Resampled dataset shape {Counter(y_res)}')
        lastMajorityCount = Counter(y_res)[0]
    X = X_res
    y = y_res
# Out:
# Original dataset shape: Counter({0: 662, 1: 88})
# Resampled dataset shape Counter({0: 540, 1: 88})
# Resampled dataset shape Counter({0: 501, 1: 88})
# Resampled dataset shape Counter({0: 490, 1: 88})
# Resampled dataset shape Counter({0: 488, 1: 88})
# Resampled dataset shape Counter({0: 487, 1: 88})
# Cannot remove any more samples

# %% [markdown]
# ## Model Training and Evaluation

# %% [markdown]
# ### Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE()), 
    ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
            'clf__max_depth': [2,3,4],
            'clf__criterion': ['gini', 'entropy', 'log_loss'],
               'clf__class_weight': ['balanced', None],
               'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
               'under__sampling_strategy': [0.5, 0.6, 0.7],
               'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="recall",
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
#                                                                               19   \
# mean_fit_time                                                            0.020395
# std_fit_time                                                             0.002047
# mean_score_time                                                          0.009514
# std_score_time                                                           0.001335
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.588235
# split1_test_recall                                                       0.882353
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.888889
# split4_test_recall                                                       0.833333
# mean_test_recall                                                         0.794118
# std_test_recall                                                          0.110417
# rank_test_recall                                                                1
# split0_test_precision                                                    0.208333
# split1_test_precision                                                    0.220588
# split2_test_precision                                                    0.424242
# split3_test_precision                                                    0.258065
# split4_test_precision                                                    0.227273
# mean_test_precision                                                        0.2677
# std_test_precision                                                       0.079971
# rank_test_precision                                                           452
# split0_test_f1                                                           0.307692
# split1_test_f1                                                           0.352941
# split2_test_f1                                                            0.54902
# split3_test_f1                                                                0.4
# split4_test_f1                                                           0.357143
# mean_test_f1                                                             0.393359
# std_test_f1                                                              0.083136
# rank_test_f1                                                                  165
# split0_test_roc_auc                                                       0.59904
# split1_test_roc_auc                                                      0.757803
# split2_test_roc_auc                                                      0.790378
# split3_test_roc_auc                                                      0.755441
# split4_test_roc_auc                                                      0.690722
# mean_test_roc_auc                                                        0.718677
# std_test_roc_auc                                                         0.067997
# rank_test_roc_auc                                                             123
#
#                                                                               122  \
# mean_fit_time                                                              0.0217
# std_fit_time                                                             0.001509
# mean_score_time                                                          0.009245
# std_score_time                                                           0.000542
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.647059
# split1_test_recall                                                       0.647059
# split2_test_recall                                                       0.833333
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.888889
# mean_test_recall                                                         0.769935
# std_test_recall                                                          0.102358
# rank_test_recall                                                                2
# split0_test_precision                                                    0.166667
# split1_test_precision                                                     0.34375
# split2_test_precision                                                    0.288462
# split3_test_precision                                                    0.263158
# split4_test_precision                                                    0.253968
# mean_test_precision                                                      0.263201
# std_test_precision                                                       0.057498
# rank_test_precision                                                           458
# split0_test_f1                                                            0.26506
# split1_test_f1                                                            0.44898
# split2_test_f1                                                           0.428571
# split3_test_f1                                                                0.4
# split4_test_f1                                                           0.395062
# mean_test_f1                                                             0.387535
# std_test_f1                                                              0.064299
# rank_test_f1                                                                  199
# split0_test_roc_auc                                                      0.596038
# split1_test_roc_auc                                                      0.789616
# split2_test_roc_auc                                                      0.793242
# split3_test_roc_auc                                                      0.783505
# split4_test_roc_auc                                                      0.746564
# mean_test_roc_auc                                                        0.741793
# std_test_roc_auc                                                         0.074754
# rank_test_roc_auc                                                              18
#
#                                                                               119  \
# mean_fit_time                                                            0.020607
# std_fit_time                                                             0.001456
# mean_score_time                                                          0.009679
# std_score_time                                                           0.000349
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.588235
# split1_test_recall                                                       0.882353
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.722222
# mean_test_recall                                                         0.760784
# std_test_recall                                                          0.101579
# rank_test_recall                                                                3
# split0_test_precision                                                    0.322581
# split1_test_precision                                                    0.208333
# split2_test_precision                                                    0.254545
# split3_test_precision                                                    0.258621
# split4_test_precision                                                    0.270833
# mean_test_precision                                                      0.262983
# std_test_precision                                                        0.03658
# rank_test_precision                                                           459
# split0_test_f1                                                           0.416667
# split1_test_f1                                                           0.337079
# split2_test_f1                                                           0.383562
# split3_test_f1                                                           0.394737
# split4_test_f1                                                           0.393939
# mean_test_f1                                                             0.385197
# std_test_f1                                                              0.026366
# rank_test_f1                                                                  220
# split0_test_roc_auc                                                      0.698679
# split1_test_roc_auc                                                      0.744898
# split2_test_roc_auc                                                      0.754868
# split3_test_roc_auc                                                      0.735682
# split4_test_roc_auc                                                      0.691867
# mean_test_roc_auc                                                        0.725199
# std_test_roc_auc                                                         0.025269
# rank_test_roc_auc                                                              74
#
#                                                                               189  \
# mean_fit_time                                                            0.019288
# std_fit_time                                                             0.001272
# mean_score_time                                                          0.010545
# std_score_time                                                           0.001773
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.588235
# split1_test_recall                                                            1.0
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.555556
# mean_test_recall                                                         0.739869
# std_test_recall                                                          0.163511
# rank_test_recall                                                                4
# split0_test_precision                                                    0.196078
# split1_test_precision                                                    0.236111
# split2_test_precision                                                    0.240741
# split3_test_precision                                                    0.254237
# split4_test_precision                                                     0.37037
# mean_test_precision                                                      0.259508
# std_test_precision                                                       0.058722
# rank_test_precision                                                           463
# split0_test_f1                                                           0.294118
# split1_test_f1                                                           0.382022
# split2_test_f1                                                           0.361111
# split3_test_f1                                                            0.38961
# split4_test_f1                                                           0.444444
# mean_test_f1                                                             0.374261
# std_test_f1                                                              0.048616
# rank_test_f1                                                                  286
# split0_test_roc_auc                                                      0.665066
# split1_test_roc_auc                                                      0.807923
# split2_test_roc_auc                                                      0.710195
# split3_test_roc_auc                                                      0.740836
# split4_test_roc_auc                                                      0.717927
# mean_test_roc_auc                                                        0.728389
# std_test_roc_auc                                                         0.046757
# rank_test_roc_auc                                                              59
#
#                                                                               56   \
# mean_fit_time                                                            0.020125
# std_fit_time                                                             0.001174
# mean_score_time                                                          0.009549
# std_score_time                                                           0.000482
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.529412
# split1_test_recall                                                       0.823529
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.722222
# split4_test_recall                                                            1.0
# mean_test_recall                                                         0.737255
# std_test_recall                                                          0.164812
# rank_test_recall                                                                5
# split0_test_precision                                                    0.236842
# split1_test_precision                                                    0.237288
# split2_test_precision                                                        0.44
# split3_test_precision                                                        0.25
# split4_test_precision                                                    0.253521
# mean_test_precision                                                       0.28353
# std_test_precision                                                       0.078518
# rank_test_precision                                                           409
# split0_test_f1                                                           0.327273
# split1_test_f1                                                           0.368421
# split2_test_f1                                                           0.511628
# split3_test_f1                                                           0.371429
# split4_test_f1                                                           0.404494
# mean_test_f1                                                             0.396649
# std_test_f1                                                              0.062494
# rank_test_f1                                                                  149
# split0_test_roc_auc                                                      0.583433
# split1_test_roc_auc                                                      0.696279
# split2_test_roc_auc                                                        0.7626
# split3_test_roc_auc                                                      0.714204
# split4_test_roc_auc                                                      0.794674
# mean_test_roc_auc                                                        0.710238
# std_test_roc_auc                                                         0.072334
# rank_test_roc_auc                                                             182
#
#                                                                               194  \
# mean_fit_time                                                            0.021806
# std_fit_time                                                             0.002405
# mean_score_time                                                          0.010234
# std_score_time                                                           0.001478
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.647059
# split1_test_recall                                                       0.882353
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.888889
# split4_test_recall                                                       0.611111
# mean_test_recall                                                         0.728105
# std_test_recall                                                          0.129296
# rank_test_recall                                                                6
# split0_test_precision                                                    0.215686
# split1_test_precision                                                         0.3
# split2_test_precision                                                       0.275
# split3_test_precision                                                    0.225352
# split4_test_precision                                                    0.268293
# mean_test_precision                                                      0.256866
# std_test_precision                                                       0.031651
# rank_test_precision                                                           468
# split0_test_f1                                                           0.323529
# split1_test_f1                                                           0.447761
# split2_test_f1                                                            0.37931
# split3_test_f1                                                           0.359551
# split4_test_f1                                                           0.372881
# mean_test_f1                                                             0.376607
# std_test_f1                                                              0.040478
# rank_test_f1                                                                  270
# split0_test_roc_auc                                                       0.60024
# split1_test_roc_auc                                                      0.765606
# split2_test_roc_auc                                                      0.726231
# split3_test_roc_auc                                                       0.71134
# split4_test_roc_auc                                                      0.685281
# mean_test_roc_auc                                                         0.69774
# std_test_roc_auc                                                         0.055252
# rank_test_roc_auc                                                             258
#
#                                                                               209  \
# mean_fit_time                                                            0.018885
# std_fit_time                                                             0.000538
# mean_score_time                                                          0.010022
# std_score_time                                                           0.000398
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.529412
# split1_test_recall                                                       0.647059
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.777778
# split4_test_recall                                                       0.888889
# mean_test_recall                                                         0.713072
# std_test_recall                                                          0.121055
# rank_test_recall                                                                7
# split0_test_precision                                                        0.18
# split1_test_precision                                                    0.314286
# split2_test_precision                                                    0.232143
# split3_test_precision                                                    0.241379
# split4_test_precision                                                    0.225352
# mean_test_precision                                                      0.238632
# std_test_precision                                                       0.043329
# rank_test_precision                                                           482
# split0_test_f1                                                           0.268657
# split1_test_f1                                                           0.423077
# split2_test_f1                                                           0.351351
# split3_test_f1                                                           0.368421
# split4_test_f1                                                           0.359551
# mean_test_f1                                                             0.354211
# std_test_f1                                                                0.0496
# rank_test_f1                                                                  388
# split0_test_roc_auc                                                       0.57443
# split1_test_roc_auc                                                      0.785414
# split2_test_roc_auc                                                      0.607388
# split3_test_roc_auc                                                      0.715636
# split4_test_roc_auc                                                      0.708477
# mean_test_roc_auc                                                        0.678269
# std_test_roc_auc                                                         0.076936
# rank_test_roc_auc                                                             388
#
#                                                                               117  \
# mean_fit_time                                                            0.019663
# std_fit_time                                                             0.000602
# mean_score_time                                                          0.009854
# std_score_time                                                           0.000258
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.529412
# split1_test_recall                                                       0.529412
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.888889
# split4_test_recall                                                       0.888889
# mean_test_recall                                                         0.711765
# std_test_recall                                                          0.160848
# rank_test_recall                                                                8
# split0_test_precision                                                    0.219512
# split1_test_precision                                                    0.183673
# split2_test_precision                                                    0.183099
# split3_test_precision                                                    0.235294
# split4_test_precision                                                    0.207792
# mean_test_precision                                                      0.205874
# std_test_precision                                                       0.020331
# rank_test_precision                                                           486
# split0_test_f1                                                           0.310345
# split1_test_f1                                                           0.272727
# split2_test_f1                                                           0.292135
# split3_test_f1                                                           0.372093
# split4_test_f1                                                           0.336842
# mean_test_f1                                                             0.316828
# std_test_f1                                                              0.034789
# rank_test_f1                                                                  470
# split0_test_roc_auc                                                      0.590336
# split1_test_roc_auc                                                      0.669568
# split2_test_roc_auc                                                      0.651489
# split3_test_roc_auc                                                      0.727377
# split4_test_roc_auc                                                      0.681558
# mean_test_roc_auc                                                        0.664066
# std_test_roc_auc                                                         0.044584
# rank_test_roc_auc                                                             450
#
#                                                                               208  \
# mean_fit_time                                                            0.019584
# std_fit_time                                                             0.001088
# mean_score_time                                                          0.011142
# std_score_time                                                           0.002915
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.470588
# split1_test_recall                                                       0.941176
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.611111
# split4_test_recall                                                       0.888889
# mean_test_recall                                                         0.704575
# std_test_recall                                                          0.180096
# rank_test_recall                                                                9
# split0_test_precision                                                    0.275862
# split1_test_precision                                                    0.262295
# split2_test_precision                                                    0.186441
# split3_test_precision                                                    0.297297
# split4_test_precision                                                    0.231884
# mean_test_precision                                                      0.250756
# std_test_precision                                                       0.038528
# rank_test_precision                                                           475
# split0_test_f1                                                           0.347826
# split1_test_f1                                                           0.410256
# split2_test_f1                                                           0.285714
# split3_test_f1                                                                0.4
# split4_test_f1                                                           0.367816
# mean_test_f1                                                             0.362323
# std_test_f1                                                              0.044331
# rank_test_f1                                                                  351
# split0_test_roc_auc                                                      0.667767
# split1_test_roc_auc                                                      0.810324
# split2_test_roc_auc                                                      0.674685
# split3_test_roc_auc                                                      0.711913
# split4_test_roc_auc                                                      0.713631
# mean_test_roc_auc                                                        0.715664
# std_test_roc_auc                                                         0.050896
# rank_test_roc_auc                                                             143
#
#                                                                               210  \
# mean_fit_time                                                            0.019975
# std_fit_time                                                             0.001963
# mean_score_time                                                          0.009463
# std_score_time                                                           0.000482
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.470588
# split1_test_recall                                                       0.823529
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.777778
# split4_test_recall                                                       0.833333
# mean_test_recall                                                         0.703268
# std_test_recall                                                          0.141113
# rank_test_recall                                                               10
# split0_test_precision                                                    0.181818
# split1_test_precision                                                    0.222222
# split2_test_precision                                                    0.366667
# split3_test_precision                                                    0.264151
# split4_test_precision                                                    0.245902
# mean_test_precision                                                      0.256152
# std_test_precision                                                        0.06174
# rank_test_precision                                                           470
# split0_test_f1                                                           0.262295
# split1_test_f1                                                               0.35
# split2_test_f1                                                           0.458333
# split3_test_f1                                                           0.394366
# split4_test_f1                                                           0.379747
# mean_test_f1                                                             0.368948
# std_test_f1                                                               0.06401
# rank_test_f1                                                                  318
# split0_test_roc_auc                                                      0.606543
# split1_test_roc_auc                                                      0.756903
# split2_test_roc_auc                                                      0.687572
# split3_test_roc_auc                                                      0.766323
# split4_test_roc_auc                                                      0.757732
# mean_test_roc_auc                                                        0.715014
# std_test_roc_auc                                                         0.061207
# rank_test_roc_auc                                                             150
#
#                                                                               32   \
# mean_fit_time                                                             0.01969
# std_fit_time                                                             0.001367
# mean_score_time                                                           0.01012
# std_score_time                                                           0.002925
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.470588
# split1_test_recall                                                       0.764706
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.611111
# split4_test_recall                                                       0.888889
# mean_test_recall                                                         0.702614
# std_test_recall                                                          0.145885
# rank_test_recall                                                               11
# split0_test_precision                                                         0.2
# split1_test_precision                                                    0.245283
# split2_test_precision                                                    0.264151
# split3_test_precision                                                     0.34375
# split4_test_precision                                                    0.219178
# mean_test_precision                                                      0.254472
# std_test_precision                                                       0.049722
# rank_test_precision                                                           472
# split0_test_f1                                                           0.280702
# split1_test_f1                                                           0.371429
# split2_test_f1                                                           0.394366
# split3_test_f1                                                               0.44
# split4_test_f1                                                           0.351648
# mean_test_f1                                                             0.367629
# std_test_f1                                                              0.052495
# rank_test_f1                                                                  322
# split0_test_roc_auc                                                      0.567527
# split1_test_roc_auc                                                      0.726291
# split2_test_roc_auc                                                      0.717354
# split3_test_roc_auc                                                      0.723368
# split4_test_roc_auc                                                      0.678981
# mean_test_roc_auc                                                        0.682704
# std_test_roc_auc                                                         0.060056
# rank_test_roc_auc                                                             368
#
#                                                                               152  \
# mean_fit_time                                                            0.021892
# std_fit_time                                                             0.000796
# mean_score_time                                                          0.010257
# std_score_time                                                           0.001035
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.411765
# split1_test_recall                                                       0.705882
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.722222
# split4_test_recall                                                       0.944444
# mean_test_recall                                                         0.701307
# std_test_recall                                                          0.169615
# rank_test_recall                                                               12
# split0_test_precision                                                    0.166667
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.254902
# split3_test_precision                                                    0.282609
# split4_test_precision                                                    0.298246
# mean_test_precision                                                      0.275485
# std_test_precision                                                       0.067435
# rank_test_precision                                                           426
# split0_test_f1                                                           0.237288
# split1_test_f1                                                           0.489796
# split2_test_f1                                                           0.376812
# split3_test_f1                                                            0.40625
# split4_test_f1                                                           0.453333
# mean_test_f1                                                             0.392696
# std_test_f1                                                              0.086825
# rank_test_f1                                                                  168
# split0_test_roc_auc                                                      0.506303
# split1_test_roc_auc                                                      0.811825
# split2_test_roc_auc                                                        0.7437
# split3_test_roc_auc                                                      0.729668
# split4_test_roc_auc                                                      0.847365
# mean_test_roc_auc                                                        0.727772
# std_test_roc_auc                                                         0.118889
# rank_test_roc_auc                                                              63
#
#                                                                               191  \
# mean_fit_time                                                            0.021484
# std_fit_time                                                             0.002605
# mean_score_time                                                          0.009641
# std_score_time                                                           0.000229
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.352941
# split1_test_recall                                                       0.647059
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.888889
# mean_test_recall                                                              0.7
# std_test_recall                                                          0.191185
# rank_test_recall                                                               13
# split0_test_precision                                                    0.428571
# split1_test_precision                                                    0.297297
# split2_test_precision                                                    0.208955
# split3_test_precision                                                    0.245902
# split4_test_precision                                                    0.238806
# mean_test_precision                                                      0.283906
# std_test_precision                                                       0.077722
# rank_test_precision                                                           407
# split0_test_f1                                                           0.387097
# split1_test_f1                                                           0.407407
# split2_test_f1                                                           0.329412
# split3_test_f1                                                           0.379747
# split4_test_f1                                                           0.376471
# mean_test_f1                                                             0.376027
# std_test_f1                                                              0.025668
# ...
# split4_test_f1                                                           0.307692
# mean_test_f1                                                             0.285278
# std_test_f1                                                               0.07067
# rank_test_f1                                                                  483
# split0_test_roc_auc                                                      0.551621
# split1_test_roc_auc                                                      0.767707
# split2_test_roc_auc                                                      0.781214
# split3_test_roc_auc                                                      0.704754
# split4_test_roc_auc                                                      0.646048
# mean_test_roc_auc                                                        0.690269
# std_test_roc_auc                                                         0.084447
# rank_test_roc_auc                                                             317
#
#                                                                               433  \
# mean_fit_time                                                            0.018769
# std_fit_time                                                             0.000308
# mean_score_time                                                          0.009271
# std_score_time                                                           0.000366
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.117647
# split1_test_recall                                                       0.176471
# split2_test_recall                                                       0.277778
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.333333
# mean_test_recall                                                         0.269935
# std_test_recall                                                          0.115292
# rank_test_recall                                                              483
# split0_test_precision                                                    0.105263
# split1_test_precision                                                         0.6
# split2_test_precision                                                         0.5
# split3_test_precision                                                    0.470588
# split4_test_precision                                                    0.428571
# mean_test_precision                                                      0.420885
# std_test_precision                                                       0.167623
# rank_test_precision                                                            56
# split0_test_f1                                                           0.111111
# split1_test_f1                                                           0.272727
# split2_test_f1                                                           0.357143
# split3_test_f1                                                           0.457143
# split4_test_f1                                                              0.375
# mean_test_f1                                                             0.314625
# std_test_f1                                                               0.11742
# rank_test_f1                                                                  471
# split0_test_roc_auc                                                      0.602041
# split1_test_roc_auc                                                       0.79952
# split2_test_roc_auc                                                      0.625143
# split3_test_roc_auc                                                      0.708763
# split4_test_roc_auc                                                       0.68614
# mean_test_roc_auc                                                        0.684321
# std_test_roc_auc                                                         0.069489
# rank_test_roc_auc                                                             359
#
#                                                                               360  \
# mean_fit_time                                                            0.020165
# std_fit_time                                                             0.002765
# mean_score_time                                                          0.010298
# std_score_time                                                           0.003254
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.411765
# split1_test_recall                                                       0.117647
# split2_test_recall                                                       0.222222
# split3_test_recall                                                       0.388889
# split4_test_recall                                                       0.111111
# mean_test_recall                                                         0.250327
# std_test_recall                                                          0.128869
# rank_test_recall                                                              484
# split0_test_precision                                                    0.184211
# split1_test_precision                                                         0.4
# split2_test_precision                                                    0.363636
# split3_test_precision                                                    0.466667
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.349569
# std_test_precision                                                       0.093872
# rank_test_precision                                                           187
# split0_test_f1                                                           0.254545
# split1_test_f1                                                           0.181818
# split2_test_f1                                                           0.275862
# split3_test_f1                                                           0.424242
# split4_test_f1                                                           0.166667
# mean_test_f1                                                             0.260627
# std_test_f1                                                              0.091737
# rank_test_f1                                                                  485
# split0_test_roc_auc                                                      0.548019
# split1_test_roc_auc                                                      0.740996
# split2_test_roc_auc                                                      0.692726
# split3_test_roc_auc                                                        0.7374
# split4_test_roc_auc                                                      0.626002
# mean_test_roc_auc                                                        0.669029
# std_test_roc_auc                                                         0.073362
# rank_test_roc_auc                                                             427
#
#                                                                               414  \
# mean_fit_time                                                            0.018843
# std_fit_time                                                             0.000481
# mean_score_time                                                          0.009461
# std_score_time                                                           0.000171
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.176471
# split1_test_recall                                                       0.117647
# split2_test_recall                                                       0.277778
# split3_test_recall                                                       0.388889
# split4_test_recall                                                       0.222222
# mean_test_recall                                                         0.236601
# std_test_recall                                                          0.092585
# rank_test_recall                                                              485
# split0_test_precision                                                         0.6
# split1_test_precision                                                         0.4
# split2_test_precision                                                    0.555556
# split3_test_precision                                                    0.466667
# split4_test_precision                                                    0.444444
# mean_test_precision                                                      0.493333
# std_test_precision                                                       0.073569
# rank_test_precision                                                             6
# split0_test_f1                                                           0.272727
# split1_test_f1                                                           0.181818
# split2_test_f1                                                            0.37037
# split3_test_f1                                                           0.424242
# split4_test_f1                                                           0.296296
# mean_test_f1                                                             0.309091
# std_test_f1                                                              0.083306
# rank_test_f1                                                                  477
# split0_test_roc_auc                                                      0.627851
# split1_test_roc_auc                                                      0.741297
# split2_test_roc_auc                                                      0.622566
# split3_test_roc_auc                                                      0.715636
# split4_test_roc_auc                                                      0.626002
# mean_test_roc_auc                                                         0.66667
# std_test_roc_auc                                                         0.051133
# rank_test_roc_auc                                                             441
#
#                                                                               417
# mean_fit_time                                                             0.02026
# std_fit_time                                                               0.0008
# mean_score_time                                                          0.009645
# std_score_time                                                           0.000214
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.235294
# split1_test_recall                                                       0.117647
# split2_test_recall                                                       0.166667
# split3_test_recall                                                       0.222222
# split4_test_recall                                                       0.222222
# mean_test_recall                                                          0.19281
# std_test_recall                                                          0.044425
# rank_test_recall                                                              486
# split0_test_precision                                                    0.181818
# split1_test_precision                                                         0.4
# split2_test_precision                                                       0.375
# split3_test_precision                                                    0.222222
# split4_test_precision                                                         0.5
# mean_test_precision                                                      0.335808
# std_test_precision                                                       0.117669
# rank_test_precision                                                           233
# split0_test_f1                                                           0.205128
# split1_test_f1                                                           0.181818
# split2_test_f1                                                           0.230769
# split3_test_f1                                                           0.222222
# split4_test_f1                                                           0.307692
# mean_test_f1                                                             0.229526
# std_test_f1                                                              0.042512
# rank_test_f1                                                                  486
# split0_test_roc_auc                                                      0.602941
# split1_test_roc_auc                                                      0.755402
# split2_test_roc_auc                                                      0.765178
# split3_test_roc_auc                                                      0.662658
# split4_test_roc_auc                                                      0.634021
# mean_test_roc_auc                                                         0.68404
# std_test_roc_auc                                                         0.065134
# rank_test_roc_auc                                                             362
#
# [43 rows x 486 columns]

# %%
clf = gscv.best_estimator_.steps[2][1]
viz = dtreeviz(clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"],
             fancy=False,
               scale=1.5
              )

viz
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %% [markdown]
# ### Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', RandomForestClassifier())
])

parameters = {
              'clf__n_estimators': [100,300,500],
              'clf__criterion': ['gini', 'entropy', 'log_loss'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
              'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
              'under__sampling_strategy': [0.5, 0.6, 0.7],
              'smt__k_neighbors': [3, 5]
             }

nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
refit_score = 'f1'
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit=refit_score,
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
pd.set_option("display.max_rows", None)
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
#                                                                               479  \
# mean_fit_time                                                            1.406045
# std_fit_time                                                             0.020526
# mean_score_time                                                          0.217757
# std_score_time                                                           0.004889
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.764706
# split1_test_recall                                                       0.882353
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.722222
# split4_test_recall                                                       0.333333
# mean_test_recall                                                         0.696078
# std_test_recall                                                          0.188865
# rank_test_recall                                                                1
# split0_test_precision                                                    0.464286
# split1_test_precision                                                         0.5
# split2_test_precision                                                         0.5
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.272727
# mean_test_precision                                                      0.447403
# std_test_precision                                                       0.088426
# rank_test_precision                                                           457
# split0_test_f1                                                           0.577778
# split1_test_f1                                                           0.638298
# split2_test_f1                                                           0.608696
# split3_test_f1                                                           0.590909
# split4_test_f1                                                                0.3
# mean_test_f1                                                             0.543136
# std_test_f1                                                              0.123249
# rank_test_f1                                                                  310
# split0_test_roc_auc                                                      0.854742
# split1_test_roc_auc                                                      0.937275
# split2_test_roc_auc                                                      0.897194
# split3_test_roc_auc                                                      0.863116
# split4_test_roc_auc                                                      0.726231
# mean_test_roc_auc                                                        0.855711
# std_test_roc_auc                                                         0.070985
# rank_test_roc_auc                                                             414
#
#                                                                               389  \
# mean_fit_time                                                            0.289884
# std_fit_time                                                             0.002739
# mean_score_time                                                          0.052796
# std_score_time                                                           0.001679
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.705882
# split1_test_recall                                                       0.764706
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.683007
# std_test_recall                                                           0.13189
# rank_test_recall                                                                2
# split0_test_precision                                                       0.375
# split1_test_precision                                                    0.464286
# split2_test_precision                                                    0.444444
# split3_test_precision                                                    0.535714
# split4_test_precision                                                    0.275862
# mean_test_precision                                                      0.419061
# std_test_precision                                                       0.088028
# rank_test_precision                                                           482
# split0_test_f1                                                           0.489796
# split1_test_f1                                                           0.577778
# split2_test_f1                                                           0.533333
# split3_test_f1                                                           0.652174
# split4_test_f1                                                           0.340426
# mean_test_f1                                                             0.518701
# std_test_f1                                                              0.104055
# rank_test_f1                                                                  433
# split0_test_roc_auc                                                      0.860444
# split1_test_roc_auc                                                      0.907863
# split2_test_roc_auc                                                       0.87142
# split3_test_roc_auc                                                      0.876575
# split4_test_roc_auc                                                      0.719645
# mean_test_roc_auc                                                         0.84719
# std_test_roc_auc                                                         0.065689
# rank_test_roc_auc                                                             464
#
#                                                                               371  \
# mean_fit_time                                                            1.371338
# std_fit_time                                                             0.033996
# mean_score_time                                                          0.228998
# std_score_time                                                            0.00253
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.764706
# split1_test_recall                                                       0.882353
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.673856
# std_test_recall                                                          0.147203
# rank_test_recall                                                                3
# split0_test_precision                                                    0.464286
# split1_test_precision                                                     0.46875
# split2_test_precision                                                    0.478261
# split3_test_precision                                                    0.631579
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.475242
# std_test_precision                                                       0.094605
# rank_test_precision                                                           428
# split0_test_f1                                                           0.577778
# split1_test_f1                                                           0.612245
# split2_test_f1                                                           0.536585
# split3_test_f1                                                           0.648649
# split4_test_f1                                                           0.380952
# mean_test_f1                                                             0.551242
# std_test_f1                                                              0.092873
# rank_test_f1                                                                  258
# split0_test_roc_auc                                                      0.873049
# split1_test_roc_auc                                                      0.932473
# split2_test_roc_auc                                                      0.872852
# split3_test_roc_auc                                                      0.906644
# split4_test_roc_auc                                                       0.73425
# mean_test_roc_auc                                                        0.863854
# std_test_roc_auc                                                          0.06856
# rank_test_roc_auc                                                             326
#
#                                                                               140  \
# mean_fit_time                                                            0.947765
# std_fit_time                                                             0.013556
# mean_score_time                                                          0.145459
# std_score_time                                                             0.0102
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.705882
# split1_test_recall                                                       0.823529
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.722222
# split4_test_recall                                                       0.388889
# mean_test_recall                                                         0.672549
# std_test_recall                                                          0.147854
# rank_test_recall                                                                4
# split0_test_precision                                                    0.545455
# split1_test_precision                                                    0.608696
# split2_test_precision                                                        0.65
# split3_test_precision                                                    0.764706
# split4_test_precision                                                      0.4375
# mean_test_precision                                                      0.601271
# std_test_precision                                                       0.108699
# rank_test_precision                                                           186
# split0_test_f1                                                           0.615385
# split1_test_f1                                                                0.7
# split2_test_f1                                                           0.684211
# split3_test_f1                                                           0.742857
# split4_test_f1                                                           0.411765
# mean_test_f1                                                             0.630843
# std_test_f1                                                              0.116972
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.872749
# split1_test_roc_auc                                                      0.920768
# split2_test_roc_auc                                                      0.925258
# split3_test_roc_auc                                                      0.918099
# split4_test_roc_auc                                                      0.774341
# mean_test_roc_auc                                                        0.882243
# std_test_roc_auc                                                         0.057189
# rank_test_roc_auc                                                              58
#
#                                                                               335  \
# mean_fit_time                                                            0.294524
# std_fit_time                                                             0.009113
# mean_score_time                                                          0.054564
# std_score_time                                                           0.002839
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.705882
# split1_test_recall                                                       0.764706
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.722222
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.671895
# std_test_recall                                                          0.115385
# rank_test_recall                                                                5
# split0_test_precision                                                    0.413793
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.565217
# split3_test_precision                                                        0.52
# split4_test_precision                                                         0.4
# mean_test_precision                                                      0.479802
# std_test_precision                                                       0.063317
# rank_test_precision                                                           421
# split0_test_f1                                                           0.521739
# split1_test_f1                                                           0.604651
# split2_test_f1                                                           0.634146
# split3_test_f1                                                           0.604651
# split4_test_f1                                                           0.421053
# mean_test_f1                                                             0.557248
# std_test_f1                                                               0.07774
# rank_test_f1                                                                  209
# split0_test_roc_auc                                                      0.866146
# split1_test_roc_auc                                                      0.885354
# split2_test_roc_auc                                                      0.890034
# split3_test_roc_auc                                                      0.866552
# split4_test_roc_auc                                                      0.737686
# mean_test_roc_auc                                                        0.849155
# std_test_roc_auc                                                         0.056565
# rank_test_roc_auc                                                             455
#
#                                                                               344  \
# mean_fit_time                                                            0.820654
# std_fit_time                                                             0.009442
# mean_score_time                                                          0.138915
# std_score_time                                                           0.001972
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.705882
# split1_test_recall                                                       0.823529
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.666667
# split4_test_recall                                                            0.5
# mean_test_recall                                                         0.661438
# std_test_recall                                                           0.10665
# rank_test_recall                                                                6
# split0_test_precision                                                    0.363636
# split1_test_precision                                                      0.4375
# split2_test_precision                                                         0.5
# split3_test_precision                                                    0.545455
# split4_test_precision                                                       0.375
# mean_test_precision                                                      0.444318
# std_test_precision                                                       0.070271
# rank_test_precision                                                           462
# split0_test_f1                                                               0.48
# split1_test_f1                                                           0.571429
# split2_test_f1                                                               0.55
# split3_test_f1                                                                0.6
# split4_test_f1                                                           0.428571
# mean_test_f1                                                                0.526
# std_test_f1                                                              0.062808
# rank_test_f1                                                                  405
# split0_test_roc_auc                                                      0.840336
# split1_test_roc_auc                                                      0.881453
# split2_test_roc_auc                                                      0.861397
# split3_test_roc_auc                                                      0.904639
# split4_test_roc_auc                                                      0.777491
# mean_test_roc_auc                                                        0.853063
# std_test_roc_auc                                                         0.043379
# rank_test_roc_auc                                                             438
#
#                                                                               191  \
# mean_fit_time                                                            1.029259
# std_fit_time                                                              0.01447
# mean_score_time                                                          0.148998
# std_score_time                                                           0.006352
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.705882
# split1_test_recall                                                       0.764706
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.388889
# mean_test_recall                                                         0.660784
# std_test_recall                                                          0.141762
# rank_test_recall                                                                7
# split0_test_precision                                                         0.5
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.583333
# split3_test_precision                                                    0.631579
# split4_test_precision                                                        0.28
# mean_test_precision                                                      0.498982
# std_test_precision                                                       0.120542
# rank_test_precision                                                           391
# split0_test_f1                                                           0.585366
# split1_test_f1                                                           0.604651
# split2_test_f1                                                           0.666667
# split3_test_f1                                                           0.648649
# split4_test_f1                                                           0.325581
# mean_test_f1                                                             0.566183
# std_test_f1                                                              0.123802
# rank_test_f1                                                                  161
# split0_test_roc_auc                                                      0.866447
# split1_test_roc_auc                                                      0.929472
# split2_test_roc_auc                                                      0.880298
# split3_test_roc_auc                                                      0.887457
# split4_test_roc_auc                                                      0.703895
# mean_test_roc_auc                                                        0.853514
# std_test_roc_auc                                                         0.077708
# rank_test_roc_auc                                                             431
#
#                                                                               101  \
# mean_fit_time                                                            1.462493
# std_fit_time                                                             0.032562
# mean_score_time                                                          0.243501
# std_score_time                                                           0.018727
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.764706
# split1_test_recall                                                       0.705882
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.611111
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.660784
# std_test_recall                                                          0.123119
# rank_test_recall                                                                7
# split0_test_precision                                                    0.419355
# split1_test_precision                                                        0.48
# split2_test_precision                                                    0.583333
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.307692
# mean_test_precision                                                      0.458076
# std_test_precision                                                       0.091698
# rank_test_precision                                                           450
# split0_test_f1                                                           0.541667
# split1_test_f1                                                           0.571429
# split2_test_f1                                                           0.666667
# split3_test_f1                                                               0.55
# split4_test_f1                                                           0.363636
# mean_test_f1                                                              0.53868
# std_test_f1                                                              0.098214
# rank_test_f1                                                                  340
# split0_test_roc_auc                                                      0.855042
# split1_test_roc_auc                                                      0.869148
# split2_test_roc_auc                                                      0.905212
# split3_test_roc_auc                                                      0.888316
# split4_test_roc_auc                                                       0.76575
# mean_test_roc_auc                                                        0.856694
# std_test_roc_auc                                                         0.048544
# rank_test_roc_auc                                                             406
#
#                                                                               137  \
# mean_fit_time                                                            0.869626
# std_fit_time                                                             0.010225
# mean_score_time                                                          0.144714
# std_score_time                                                           0.001211
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.647059
# split1_test_recall                                                       0.764706
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.777778
# split4_test_recall                                                       0.333333
# mean_test_recall                                                         0.660131
# std_test_recall                                                          0.170637
# rank_test_recall                                                                9
# split0_test_precision                                                     0.37931
# split1_test_precision                                                        0.52
# split2_test_precision                                                    0.608696
# split3_test_precision                                                    0.636364
# split4_test_precision                                                         0.3
# mean_test_precision                                                      0.488874
# std_test_precision                                                       0.130197
# rank_test_precision                                                           408
# split0_test_f1                                                           0.478261
# split1_test_f1                                                           0.619048
# split2_test_f1                                                           0.682927
# split3_test_f1                                                                0.7
# split4_test_f1                                                           0.315789
# mean_test_f1                                                             0.559205
# std_test_f1                                                              0.144578
# rank_test_f1                                                                  199
# split0_test_roc_auc                                                      0.819028
# split1_test_roc_auc                                                      0.906663
# split2_test_roc_auc                                                      0.924399
# split3_test_roc_auc                                                       0.89748
# split4_test_roc_auc                                                      0.759737
# mean_test_roc_auc                                                        0.861461
# std_test_roc_auc                                                          0.06237
# rank_test_roc_auc                                                             366
#
#                                                                               146  \
# mean_fit_time                                                            1.422397
# std_fit_time                                                             0.012693
# mean_score_time                                                          0.226055
# std_score_time                                                           0.003865
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.705882
# split1_test_recall                                                       0.941176
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.611111
# split4_test_recall                                                       0.388889
# mean_test_recall                                                         0.651634
# std_test_recall                                                           0.17838
# rank_test_recall                                                               10
# split0_test_precision                                                    0.413793
# split1_test_precision                                                    0.484848
# split2_test_precision                                                        0.44
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.304348
# mean_test_precision                                                      0.428598
# std_test_precision                                                       0.069354
# rank_test_precision                                                           476
# split0_test_f1                                                           0.521739
# split1_test_f1                                                               0.64
# split2_test_f1                                                           0.511628
# split3_test_f1                                                               0.55
# split4_test_f1                                                           0.341463
# mean_test_f1                                                             0.512966
# std_test_f1                                                              0.096955
# rank_test_f1                                                                  449
# split0_test_roc_auc                                                      0.877551
# split1_test_roc_auc                                                      0.914466
# split2_test_roc_auc                                                      0.848797
# split3_test_roc_auc                                                      0.883162
# split4_test_roc_auc                                                      0.750859
# mean_test_roc_auc                                                        0.854967
# std_test_roc_auc                                                         0.056074
# rank_test_roc_auc                                                             421
#
#                                                                               415  \
# mean_fit_time                                                            1.454762
# std_fit_time                                                             0.019319
# mean_score_time                                                           0.24816
# std_score_time                                                            0.02854
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.764706
# split1_test_recall                                                       0.823529
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.722222
# split4_test_recall                                                       0.333333
# mean_test_recall                                                          0.65098
# std_test_recall                                                          0.173362
# rank_test_recall                                                               11
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.583333
# split2_test_precision                                                    0.578947
# split3_test_precision                                                    0.684211
# split4_test_precision                                                         0.3
# mean_test_precision                                                      0.529298
# std_test_precision                                                         0.1287
# rank_test_precision                                                           339
# split0_test_f1                                                           0.604651
# split1_test_f1                                                           0.682927
# split2_test_f1                                                           0.594595
# split3_test_f1                                                           0.702703
# split4_test_f1                                                           0.315789
# mean_test_f1                                                             0.580133
# std_test_f1                                                              0.138764
# rank_test_f1                                                                   81
# split0_test_roc_auc                                                      0.865546
# split1_test_roc_auc                                                      0.936375
# split2_test_roc_auc                                                      0.913803
# split3_test_roc_auc                                                      0.922108
# split4_test_roc_auc                                                      0.739977
# mean_test_roc_auc                                                        0.875562
# std_test_roc_auc                                                         0.071848
# rank_test_roc_auc                                                             143
#
#                                                                               419  \
# mean_fit_time                                                            1.757425
# std_fit_time                                                             0.021834
# mean_score_time                                                          0.248231
# std_score_time                                                           0.016414
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.764706
# split1_test_recall                                                       0.823529
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.611111
# split4_test_recall                                                       0.444444
# mean_test_recall                                                          0.65098
# std_test_recall                                                          0.133074
# rank_test_recall                                                               12
# split0_test_precision                                                    0.541667
# split1_test_precision                                                    0.736842
# split2_test_precision                                                         0.5
# split3_test_precision                                                        0.55
# split4_test_precision                                                    0.533333
# mean_test_precision                                                      0.572368
# std_test_precision                                                       0.083971
# rank_test_precision                                                           247
# split0_test_f1                                                           0.634146
# split1_test_f1                                                           0.777778
# split2_test_f1                                                               0.55
# split3_test_f1                                                           0.578947
# split4_test_f1                                                           0.484848
# mean_test_f1                                                             0.605144
# std_test_f1                                                              0.098835
# rank_test_f1                                                                   16
# split0_test_roc_auc                                                      0.872749
# split1_test_roc_auc                                                      0.912965
# split2_test_roc_auc                                                       0.86197
# split3_test_roc_auc                                                      0.899485
# split4_test_roc_auc                                                       0.78551
# mean_test_roc_auc                                                        0.866536
# std_test_roc_auc                                                         0.044421
# rank_test_roc_auc                                                             292
#
#                                                                               263  \
# mean_fit_time                                                            1.721905
# std_fit_time                                                             0.014986
# mean_score_time                                                          0.225068
# std_score_time                                                           0.013763
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.764706
# split1_test_recall                                                       0.764706
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.333333
# mean_test_recall                                                         0.650327
# std_test_recall                                                          0.162534
# rank_test_recall                                                               13
# split0_test_precision                                                    0.419355
# split1_test_precision                                                        0.65
# split2_test_precision                                                         0.5
# split3_test_precision                                                         0.6
# split4_test_precision                                                         0.3
# mean_test_precision                                                      0.493871
# std_test_precision                                                       0.125551
# rank_test_precision                                                           397
# split0_test_f1                                                           0.541667
# split1_test_f1                                                           0.702703
# split2_test_f1                                                           0.590909
# split3_test_f1                                                           0.631579
# split4_test_f1                                                           0.315789
# mean_test_f1                                                             0.556529
# std_test_f1                                                              0.131421
# ...
# split4_test_f1                                                           0.461538
# mean_test_f1                                                             0.541325
# std_test_f1                                                              0.066362
# rank_test_f1                                                                  328
# split0_test_roc_auc                                                      0.909064
# split1_test_roc_auc                                                      0.876651
# split2_test_roc_auc                                                      0.890321
# split3_test_roc_auc                                                      0.931271
# split4_test_roc_auc                                                      0.812142
# mean_test_roc_auc                                                         0.88389
# std_test_roc_auc                                                         0.040299
# rank_test_roc_auc                                                              32
#
#                                                                               168  \
# mean_fit_time                                                            0.436323
# std_fit_time                                                             0.004453
# mean_score_time                                                          0.058539
# std_score_time                                                           0.001751
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.470588
# split1_test_recall                                                       0.470588
# split2_test_recall                                                       0.555556
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.333333
# mean_test_recall                                                         0.454902
# std_test_recall                                                           0.07143
# rank_test_recall                                                              482
# split0_test_precision                                                    0.666667
# split1_test_precision                                                    0.615385
# split2_test_precision                                                    0.909091
# split3_test_precision                                                    0.727273
# split4_test_precision                                                    0.666667
# mean_test_precision                                                      0.717016
# std_test_precision                                                       0.102369
# rank_test_precision                                                            25
# split0_test_f1                                                           0.551724
# split1_test_f1                                                           0.533333
# split2_test_f1                                                           0.689655
# split3_test_f1                                                           0.551724
# split4_test_f1                                                           0.444444
# mean_test_f1                                                             0.554176
# std_test_f1                                                              0.078539
# rank_test_f1                                                                  236
# split0_test_roc_auc                                                      0.876651
# split1_test_roc_auc                                                      0.894358
# split2_test_roc_auc                                                      0.908362
# split3_test_roc_auc                                                      0.926403
# split4_test_roc_auc                                                      0.796105
# mean_test_roc_auc                                                        0.880376
# std_test_roc_auc                                                         0.045194
# rank_test_roc_auc                                                              77
#
#                                                                               12   \
# mean_fit_time                                                            0.292571
# std_fit_time                                                             0.004025
# mean_score_time                                                          0.054166
# std_score_time                                                           0.002267
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.588235
# split1_test_recall                                                       0.352941
# split2_test_recall                                                       0.555556
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.277778
# mean_test_recall                                                         0.454902
# std_test_recall                                                           0.11976
# rank_test_recall                                                              482
# split0_test_precision                                                       0.625
# split1_test_precision                                                    0.545455
# split2_test_precision                                                    0.833333
# split3_test_precision                                                    0.692308
# split4_test_precision                                                    0.714286
# mean_test_precision                                                      0.682076
# std_test_precision                                                       0.095858
# rank_test_precision                                                            59
# split0_test_f1                                                           0.606061
# split1_test_f1                                                           0.428571
# split2_test_f1                                                           0.666667
# split3_test_f1                                                           0.580645
# split4_test_f1                                                                0.4
# mean_test_f1                                                             0.536389
# std_test_f1                                                              0.103934
# rank_test_f1                                                                  349
# split0_test_roc_auc                                                      0.852341
# split1_test_roc_auc                                                      0.876351
# split2_test_roc_auc                                                      0.902921
# split3_test_roc_auc                                                      0.898339
# split4_test_roc_auc                                                      0.786942
# mean_test_roc_auc                                                        0.863379
# std_test_roc_auc                                                         0.042234
# rank_test_roc_auc                                                             336
#
#                                                                               186  \
# mean_fit_time                                                            1.216978
# std_fit_time                                                             0.013923
# mean_score_time                                                          0.147352
# std_score_time                                                           0.002749
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                       0.470588
# split1_test_recall                                                       0.529412
# split2_test_recall                                                       0.555556
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.222222
# mean_test_recall                                                         0.444444
# std_test_recall                                                           0.11801
# rank_test_recall                                                              485
# split0_test_precision                                                    0.666667
# split1_test_precision                                                      0.5625
# split2_test_precision                                                    0.833333
# split3_test_precision                                                    0.727273
# split4_test_precision                                                    0.571429
# mean_test_precision                                                       0.67224
# std_test_precision                                                       0.101209
# rank_test_precision                                                            75
# split0_test_f1                                                           0.551724
# split1_test_f1                                                           0.545455
# split2_test_f1                                                           0.666667
# split3_test_f1                                                           0.551724
# split4_test_f1                                                               0.32
# mean_test_f1                                                             0.527114
# std_test_f1                                                              0.113065
# rank_test_f1                                                                  401
# split0_test_roc_auc                                                      0.860144
# split1_test_roc_auc                                                      0.896759
# split2_test_roc_auc                                                      0.912944
# split3_test_roc_auc                                                      0.924971
# split4_test_roc_auc                                                      0.769759
# mean_test_roc_auc                                                        0.872915
# std_test_roc_auc                                                         0.056009
# rank_test_roc_auc                                                             191
#
#                                                                               33
# mean_fit_time                                                            0.957486
# std_fit_time                                                             0.011928
# mean_score_time                                                          0.137262
# std_score_time                                                           0.005958
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.529412
# split1_test_recall                                                       0.470588
# split2_test_recall                                                            0.5
# split3_test_recall                                                       0.444444
# split4_test_recall                                                       0.277778
# mean_test_recall                                                         0.444444
# std_test_recall                                                          0.088054
# rank_test_recall                                                              485
# split0_test_precision                                                    0.642857
# split1_test_precision                                                    0.888889
# split2_test_precision                                                    0.692308
# split3_test_precision                                                    0.727273
# split4_test_precision                                                       0.625
# mean_test_precision                                                      0.715265
# std_test_precision                                                       0.094029
# rank_test_precision                                                            27
# split0_test_f1                                                           0.580645
# split1_test_f1                                                           0.615385
# split2_test_f1                                                           0.580645
# split3_test_f1                                                           0.551724
# split4_test_f1                                                           0.384615
# mean_test_f1                                                             0.542603
# std_test_f1                                                              0.081529
# rank_test_f1                                                                  317
# split0_test_roc_auc                                                      0.896459
# split1_test_roc_auc                                                      0.897359
# split2_test_roc_auc                                                      0.897766
# split3_test_roc_auc                                                      0.928408
# split4_test_roc_auc                                                      0.775773
# mean_test_roc_auc                                                        0.879153
# std_test_roc_auc                                                         0.053086
# rank_test_roc_auc                                                              89
#
# [43 rows x 486 columns]

# %% [markdown]
# Plot the mean ROC curve of the algorithm with best performing parameter selection. We will perform CV once again and plot the ROC curve for each fold and compute and plot the mean.

# %%
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=nfolds, shuffle=True)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X, y)):
    classifier.fit(X.iloc[train], y[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X.iloc[test],
        y[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the mean precision-recall curve. The approach is the same as for the mean ROC curve.

# %%
from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=nfolds, shuffle=True)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X, y)):
    classifier.fit(X.iloc[train], y[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X.iloc[test],
        y[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

rf = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf, X, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
# Out:
# Text(0.5, 1.0, 'Permutation Importance Random Forest')

# %%
# Get feature importance with SHAP
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)
RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %%
# SHAP summary plot
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)
classid = 1
shap.summary_plot(shap_values[classid], X, max_display=len(X.columns), class_names=le.classes_)

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

# one-hot encoding of month feature
Xohe = pd.get_dummies(X, columns=["month"])

X_display = Xohe.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xohe)
Xsc = pd.DataFrame(scaled_array, columns=Xohe.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE()),
    ('under', RandomUnderSampler()),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.4, 0.5, 0.6],
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
             }
nfolds = 5
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "recall")
resultsGSCV = gscv.fit(Xsc, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#                                                                               92   \
# mean_fit_time                                                            0.486924
# std_fit_time                                                              0.31522
# mean_score_time                                                          0.012635
# std_score_time                                                           0.000484
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.588235
# split1_test_recall                                                       0.823529
# split2_test_recall                                                       0.611111
# split3_test_recall                                                       0.888889
# split4_test_recall                                                       0.777778
# mean_test_recall                                                         0.737908
# std_test_recall                                                          0.118486
# rank_test_recall                                                                1
# split0_test_precision                                                    0.263158
# split1_test_precision                                                        0.28
# split2_test_precision                                                    0.392857
# split3_test_precision                                                    0.271186
# split4_test_precision                                                    0.222222
# mean_test_precision                                                      0.285885
# std_test_precision                                                       0.057032
# rank_test_precision                                                           199
# split0_test_f1                                                           0.363636
# split1_test_f1                                                            0.41791
# split2_test_f1                                                           0.478261
# split3_test_f1                                                           0.415584
# split4_test_f1                                                           0.345679
# mean_test_f1                                                             0.404214
# std_test_f1                                                              0.046632
# rank_test_f1                                                                  133
# split0_test_roc_auc                                                        0.7503
# split1_test_roc_auc                                                      0.688475
# split2_test_roc_auc                                                      0.758018
# split3_test_roc_auc                                                      0.733104
# split4_test_roc_auc                                                      0.670676
# mean_test_roc_auc                                                        0.720115
# std_test_roc_auc                                                         0.034531
# rank_test_roc_auc                                                             105
#
#                                                                               84   \
# mean_fit_time                                                            0.391317
# std_fit_time                                                             0.135934
# mean_score_time                                                           0.01383
# std_score_time                                                           0.001094
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.705882
# split1_test_recall                                                       0.647059
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.611111
# split4_test_recall                                                       0.833333
# mean_test_recall                                                         0.715033
# std_test_recall                                                          0.081775
# rank_test_recall                                                                2
# split0_test_precision                                                     0.26087
# split1_test_precision                                                    0.183333
# split2_test_precision                                                    0.368421
# split3_test_precision                                                        0.25
# split4_test_precision                                                    0.340909
# mean_test_precision                                                      0.280707
# std_test_precision                                                       0.066537
# rank_test_precision                                                           201
# split0_test_f1                                                           0.380952
# split1_test_f1                                                           0.285714
# split2_test_f1                                                                0.5
# split3_test_f1                                                           0.354839
# split4_test_f1                                                           0.483871
# mean_test_f1                                                             0.401075
# std_test_f1                                                              0.080613
# rank_test_f1                                                                  141
# split0_test_roc_auc                                                       0.67407
# split1_test_roc_auc                                                      0.602041
# split2_test_roc_auc                                                      0.757159
# split3_test_roc_auc                                                      0.610252
# split4_test_roc_auc                                                      0.780069
# mean_test_roc_auc                                                        0.684718
# std_test_roc_auc                                                         0.073258
# rank_test_roc_auc                                                             184
#
#                                                                               106  \
# mean_fit_time                                                            0.368836
# std_fit_time                                                             0.135333
# mean_score_time                                                          0.012193
# std_score_time                                                           0.000422
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.529412
# split1_test_recall                                                       0.588235
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.888889
# split4_test_recall                                                       0.777778
# mean_test_recall                                                         0.701307
# std_test_recall                                                          0.129465
# rank_test_recall                                                                3
# split0_test_precision                                                       0.375
# split1_test_precision                                                      0.3125
# split2_test_precision                                                    0.382353
# split3_test_precision                                                    0.313725
# split4_test_precision                                                        0.35
# mean_test_precision                                                      0.346716
# std_test_precision                                                       0.029461
# rank_test_precision                                                           119
# split0_test_f1                                                           0.439024
# split1_test_f1                                                           0.408163
# split2_test_f1                                                                0.5
# split3_test_f1                                                           0.463768
# split4_test_f1                                                           0.482759
# mean_test_f1                                                             0.458743
# std_test_f1                                                              0.032408
# rank_test_f1                                                                   22
# split0_test_roc_auc                                                      0.704682
# split1_test_roc_auc                                                      0.766807
# split2_test_roc_auc                                                       0.75945
# split3_test_roc_auc                                                      0.808133
# split4_test_roc_auc                                                      0.795533
# mean_test_roc_auc                                                        0.766921
# std_test_roc_auc                                                         0.035907
# rank_test_roc_auc                                                              10
#
#                                                                               136  \
# mean_fit_time                                                            0.235095
# std_fit_time                                                             0.130634
# mean_score_time                                                          0.011461
# std_score_time                                                           0.000281
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.705882
# split1_test_recall                                                       0.529412
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.944444
# split4_test_recall                                                       0.611111
# mean_test_recall                                                         0.691503
# std_test_recall                                                          0.139671
# rank_test_recall                                                                4
# split0_test_precision                                                         0.4
# split1_test_precision                                                    0.236842
# split2_test_precision                                                    0.266667
# split3_test_precision                                                    0.435897
# split4_test_precision                                                    0.314286
# mean_test_precision                                                      0.330738
# std_test_precision                                                       0.076221
# rank_test_precision                                                           141
# split0_test_f1                                                           0.510638
# split1_test_f1                                                           0.327273
# split2_test_f1                                                           0.380952
# split3_test_f1                                                           0.596491
# split4_test_f1                                                           0.415094
# mean_test_f1                                                              0.44609
# std_test_f1                                                              0.096029
# rank_test_f1                                                                   46
# split0_test_roc_auc                                                      0.816927
# split1_test_roc_auc                                                      0.682173
# split2_test_roc_auc                                                      0.704754
# split3_test_roc_auc                                                      0.884307
# split4_test_roc_auc                                                      0.773482
# mean_test_roc_auc                                                        0.772329
# std_test_roc_auc                                                         0.073789
# rank_test_roc_auc                                                               6
#
#                                                                               11   \
# mean_fit_time                                                            0.280381
# std_fit_time                                                             0.106057
# mean_score_time                                                            0.0104
# std_score_time                                                           0.000445
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.470588
# split1_test_recall                                                       0.588235
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.833333
# mean_test_recall                                                         0.689542
# std_test_recall                                                          0.141862
# rank_test_recall                                                                5
# split0_test_precision                                                    0.470588
# split1_test_precision                                                    0.238095
# split2_test_precision                                                     0.40625
# split3_test_precision                                                    0.288462
# split4_test_precision                                                    0.214286
# mean_test_precision                                                      0.323536
# std_test_precision                                                       0.098926
# rank_test_precision                                                           162
# split0_test_f1                                                           0.470588
# split1_test_f1                                                           0.338983
# split2_test_f1                                                               0.52
# split3_test_f1                                                           0.428571
# split4_test_f1                                                           0.340909
# mean_test_f1                                                              0.41981
# std_test_f1                                                              0.071346
# rank_test_f1                                                                  103
# split0_test_roc_auc                                                      0.723289
# split1_test_roc_auc                                                       0.62485
# split2_test_roc_auc                                                      0.797251
# split3_test_roc_auc                                                      0.764605
# split4_test_roc_auc                                                      0.731672
# mean_test_roc_auc                                                        0.728333
# std_test_roc_auc                                                         0.057984
# rank_test_roc_auc                                                              74
#
#                                                                               47   \
# mean_fit_time                                                            0.286248
# std_fit_time                                                                0.094
# mean_score_time                                                          0.013143
# std_score_time                                                           0.003948
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.647059
# split1_test_recall                                                       0.647059
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.666667
# split4_test_recall                                                       0.722222
# mean_test_recall                                                         0.681046
# std_test_recall                                                          0.034374
# rank_test_recall                                                                6
# split0_test_precision                                                     0.34375
# split1_test_precision                                                     0.34375
# split2_test_precision                                                    0.342105
# split3_test_precision                                                    0.363636
# split4_test_precision                                                    0.240741
# mean_test_precision                                                      0.326796
# std_test_precision                                                       0.043754
# rank_test_precision                                                           154
# split0_test_f1                                                            0.44898
# split1_test_f1                                                            0.44898
# split2_test_f1                                                           0.464286
# split3_test_f1                                                           0.470588
# split4_test_f1                                                           0.361111
# mean_test_f1                                                             0.438789
# std_test_f1                                                              0.039756
# rank_test_f1                                                                   59
# split0_test_roc_auc                                                      0.719688
# split1_test_roc_auc                                                      0.789916
# split2_test_roc_auc                                                      0.735968
# split3_test_roc_auc                                                      0.738259
# split4_test_roc_auc                                                      0.734822
# mean_test_roc_auc                                                        0.743731
# std_test_roc_auc                                                         0.024003
# rank_test_roc_auc                                                              30
#
#                                                                               128  \
# mean_fit_time                                                            0.289294
# std_fit_time                                                             0.117651
# mean_score_time                                                          0.010865
# std_score_time                                                           0.001732
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.588235
# split1_test_recall                                                       0.647059
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.611111
# mean_test_recall                                                         0.680392
# std_test_recall                                                          0.088932
# rank_test_recall                                                                7
# split0_test_precision                                                      0.3125
# split1_test_precision                                                    0.261905
# split2_test_precision                                                    0.288889
# split3_test_precision                                                    0.405405
# split4_test_precision                                                     0.37931
# mean_test_precision                                                      0.329602
# std_test_precision                                                       0.054314
# rank_test_precision                                                           145
# split0_test_f1                                                           0.408163
# split1_test_f1                                                           0.372881
# split2_test_f1                                                           0.412698
# split3_test_f1                                                           0.545455
# split4_test_f1                                                           0.468085
# mean_test_f1                                                             0.441457
# std_test_f1                                                              0.060271
# rank_test_f1                                                                   52
# split0_test_roc_auc                                                      0.696579
# split1_test_roc_auc                                                      0.685774
# split2_test_roc_auc                                                      0.699885
# split3_test_roc_auc                                                      0.820733
# split4_test_roc_auc                                                      0.710767
# mean_test_roc_auc                                                        0.722748
# std_test_roc_auc                                                         0.049637
# rank_test_roc_auc                                                              95
#
#                                                                               154  \
# mean_fit_time                                                            0.348677
# std_fit_time                                                             0.120908
# mean_score_time                                                          0.012188
# std_score_time                                                           0.001227
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.647059
# split1_test_recall                                                       0.529412
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.777778
# split4_test_recall                                                       0.722222
# mean_test_recall                                                         0.679739
# std_test_recall                                                          0.085892
# rank_test_recall                                                                8
# split0_test_precision                                                    0.366667
# split1_test_precision                                                    0.272727
# split2_test_precision                                                    0.393939
# split3_test_precision                                                    0.451613
# split4_test_precision                                                    0.361111
# mean_test_precision                                                      0.369211
# std_test_precision                                                       0.057936
# rank_test_precision                                                            75
# split0_test_f1                                                           0.468085
# split1_test_f1                                                               0.36
# split2_test_f1                                                           0.509804
# split3_test_f1                                                           0.571429
# split4_test_f1                                                           0.481481
# mean_test_f1                                                              0.47816
# std_test_f1                                                              0.068956
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.702881
# split1_test_roc_auc                                                      0.747599
# split2_test_roc_auc                                                      0.810137
# split3_test_roc_auc                                                      0.850515
# split4_test_roc_auc                                                      0.761741
# mean_test_roc_auc                                                        0.774575
# std_test_roc_auc                                                         0.051116
# rank_test_roc_auc                                                               5
#
#                                                                               165  \
# mean_fit_time                                                            0.341616
# std_fit_time                                                             0.156117
# mean_score_time                                                          0.011301
# std_score_time                                                           0.000218
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.588235
# split1_test_recall                                                       0.352941
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.833333
# split4_test_recall                                                       0.888889
# mean_test_recall                                                         0.677124
# std_test_recall                                                          0.191977
# rank_test_recall                                                                9
# split0_test_precision                                                     0.37037
# split1_test_precision                                                    0.214286
# split2_test_precision                                                        0.52
# split3_test_precision                                                    0.340909
# split4_test_precision                                                        0.25
# mean_test_precision                                                      0.339113
# std_test_precision                                                        0.10698
# rank_test_precision                                                           127
# split0_test_f1                                                           0.454545
# split1_test_f1                                                           0.266667
# split2_test_f1                                                           0.604651
# split3_test_f1                                                           0.483871
# split4_test_f1                                                           0.390244
# mean_test_f1                                                             0.439996
# std_test_f1                                                              0.111145
# rank_test_f1                                                                   54
# split0_test_roc_auc                                                      0.695078
# split1_test_roc_auc                                                       0.62605
# split2_test_roc_auc                                                       0.82646
# split3_test_roc_auc                                                       0.83362
# split4_test_roc_auc                                                      0.708477
# mean_test_roc_auc                                                        0.737937
# std_test_roc_auc                                                         0.080268
# rank_test_roc_auc                                                              43
#
#                                                                               75   \
# mean_fit_time                                                            0.591188
# std_fit_time                                                             0.333911
# mean_score_time                                                          0.015071
# std_score_time                                                            0.00323
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.647059
# split1_test_recall                                                       0.764706
# split2_test_recall                                                       0.722222
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.722222
# mean_test_recall                                                         0.671242
# std_test_recall                                                           0.09364
# rank_test_recall                                                               10
# split0_test_precision                                                    0.423077
# split1_test_precision                                                     0.19697
# split2_test_precision                                                    0.342105
# split3_test_precision                                                    0.473684
# split4_test_precision                                                    0.309524
# mean_test_precision                                                      0.349072
# std_test_precision                                                       0.095658
# rank_test_precision                                                           114
# split0_test_f1                                                           0.511628
# split1_test_f1                                                           0.313253
# split2_test_f1                                                           0.464286
# split3_test_f1                                                           0.486486
# split4_test_f1                                                           0.433333
# mean_test_f1                                                             0.441797
# std_test_f1                                                              0.069245
# rank_test_f1                                                                   51
# split0_test_roc_auc                                                      0.716086
# split1_test_roc_auc                                                      0.620948
# split2_test_roc_auc                                                       0.78551
# split3_test_roc_auc                                                      0.779496
# split4_test_roc_auc                                                      0.767755
# mean_test_roc_auc                                                        0.733959
# std_test_roc_auc                                                         0.061586
# rank_test_roc_auc                                                              50
#
#                                                                               110  \
# mean_fit_time                                                              0.2621
# std_fit_time                                                             0.136038
# mean_score_time                                                           0.01183
# std_score_time                                                           0.002098
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.588235
# split1_test_recall                                                       0.411765
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.944444
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.666667
# std_test_recall                                                          0.173996
# rank_test_recall                                                               11
# split0_test_precision                                                         0.5
# split1_test_precision                                                         0.2
# split2_test_precision                                                     0.40625
# split3_test_precision                                                    0.386364
# split4_test_precision                                                    0.352941
# mean_test_precision                                                      0.369111
# std_test_precision                                                       0.097641
# rank_test_precision                                                            76
# split0_test_f1                                                           0.540541
# split1_test_f1                                                           0.269231
# split2_test_f1                                                               0.52
# split3_test_f1                                                           0.548387
# split4_test_f1                                                           0.461538
# mean_test_f1                                                             0.467939
# std_test_f1                                                              0.103903
# rank_test_f1                                                                   14
# split0_test_roc_auc                                                      0.738595
# split1_test_roc_auc                                                      0.713685
# split2_test_roc_auc                                                      0.762027
# split3_test_roc_auc                                                      0.863975
# split4_test_roc_auc                                                      0.732532
# mean_test_roc_auc                                                        0.762163
# std_test_roc_auc                                                         0.053196
# rank_test_roc_auc                                                              11
#
#                                                                               137  \
# mean_fit_time                                                            0.149912
# std_fit_time                                                             0.038719
# mean_score_time                                                          0.011935
# std_score_time                                                           0.001096
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.647059
# split1_test_recall                                                       0.352941
# split2_test_recall                                                       0.666667
# split3_test_recall                                                            1.0
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.666667
# std_test_recall                                                            0.2049
# rank_test_recall                                                               12
# split0_test_precision                                                    0.282051
# split1_test_precision                                                        0.24
# split2_test_precision                                                        0.25
# split3_test_precision                                                    0.367347
# split4_test_precision                                                    0.342857
# mean_test_precision                                                      0.296451
# std_test_precision                                                       0.050461
# rank_test_precision                                                           194
# split0_test_f1                                                           0.392857
# split1_test_f1                                                           0.285714
# split2_test_f1                                                           0.363636
# split3_test_f1                                                           0.537313
# split4_test_f1                                                            0.45283
# mean_test_f1                                                              0.40647
# std_test_f1                                                              0.084701
# rank_test_f1                                                                  128
# split0_test_roc_auc                                                      0.755402
# split1_test_roc_auc                                                      0.671369
# split2_test_roc_auc                                                      0.660367
# split3_test_roc_auc                                                      0.792383
# split4_test_roc_auc                                                      0.778923
# mean_test_roc_auc                                                        0.731689
# std_test_roc_auc                                                         0.055141
# rank_test_roc_auc                                                              61
#
#                                                                               68   \
# mean_fit_time                                                             0.40316
# std_fit_time                                                             0.130538
# mean_score_time                                                          0.014413
# std_score_time                                                           0.001311
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.470588
# split1_test_recall                                                       0.588235
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.777778
# split4_test_recall                                                       0.722222
# mean_test_recall                                                         0.656209
# std_test_recall                                                          0.111866
# rank_test_recall                                                               13
# split0_test_precision                                                    0.363636
# split1_test_precision                                                    0.263158
# split2_test_precision                                                    0.302326
# split3_test_precision                                                    0.333333
# split4_test_precision                                                    0.419355
# mean_test_precision                                                      0.336362
# std_test_precision                                                       0.053213
# rank_test_precision                                                           132
# split0_test_f1                                                           0.410256
# split1_test_f1                                                           0.363636
# split2_test_f1                                                            0.42623
# split3_test_f1                                                           0.466667
# split4_test_f1                                                           0.530612
# mean_test_f1                                                              0.43948
# std_test_f1                                                               0.05626
# rank_test_f1                                                                   56
# split0_test_roc_auc                                                      0.737695
# split1_test_roc_auc                                                      0.612245
# split2_test_roc_auc                                                      0.685567
# split3_test_roc_auc                                                      0.792096
# split4_test_roc_auc                                                      0.745132
# mean_test_roc_auc                                                        0.714547
# std_test_roc_auc                                                         0.061304
# rank_test_roc_auc                                                             116
#
#                                                                               155  \
# mean_fit_time                                                            0.317424
# std_fit_time                                                             0.171321
# mean_score_time                                                          0.011704
# std_score_time                                                            0.00052
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.529412
# split1_test_recall                                                       0.352941
# split2_test_recall                                                       0.777778
# split3_test_recall                                                       0.888889
# split4_test_recall                                                       0.666667
# mean_test_recall                                                         0.643137
# std_test_recall                                                          0.187735
# ...
# split4_test_precision                                                         0.0
# mean_test_precision                                                      0.277317
# std_test_precision                                                       0.186852
# rank_test_precision                                                           203
# split0_test_f1                                                            0.26087
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.369231
# split3_test_f1                                                           0.461538
# split4_test_f1                                                                0.0
# mean_test_f1                                                             0.284994
# std_test_f1                                                              0.156463
# rank_test_f1                                                                  211
# split0_test_roc_auc                                                      0.627251
# split1_test_roc_auc                                                      0.620048
# split2_test_roc_auc                                                      0.719359
# split3_test_roc_auc                                                      0.761741
# split4_test_roc_auc                                                           0.5
# mean_test_roc_auc                                                         0.64568
# std_test_roc_auc                                                         0.090684
# rank_test_roc_auc                                                             206
#
#                                                                               73   \
# mean_fit_time                                                            0.273641
# std_fit_time                                                             0.122066
# mean_score_time                                                          0.013845
# std_score_time                                                           0.000952
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.470588
# split1_test_recall                                                            0.0
# split2_test_recall                                                       0.722222
# split3_test_recall                                                       0.277778
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.383007
# std_test_recall                                                          0.238445
# rank_test_recall                                                              213
# split0_test_precision                                                    0.285714
# split1_test_precision                                                         0.0
# split2_test_precision                                                    0.382353
# split3_test_precision                                                    0.277778
# split4_test_precision                                                    0.363636
# mean_test_precision                                                      0.261896
# std_test_precision                                                        0.13731
# rank_test_precision                                                           208
# split0_test_f1                                                           0.355556
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.5
# split3_test_f1                                                           0.277778
# split4_test_f1                                                                0.4
# mean_test_f1                                                             0.306667
# std_test_f1                                                              0.169327
# rank_test_f1                                                                  206
# split0_test_roc_auc                                                       0.67437
# split1_test_roc_auc                                                      0.489796
# split2_test_roc_auc                                                      0.719072
# split3_test_roc_auc                                                       0.65693
# split4_test_roc_auc                                                      0.720504
# mean_test_roc_auc                                                        0.652134
# std_test_roc_auc                                                         0.084884
# rank_test_roc_auc                                                             204
#
#                                                                               69   \
# mean_fit_time                                                            0.733869
# std_fit_time                                                             0.604083
# mean_score_time                                                          0.018144
# std_score_time                                                           0.005672
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.411765
# split1_test_recall                                                            0.0
# split2_test_recall                                                       0.666667
# split3_test_recall                                                       0.222222
# split4_test_recall                                                       0.611111
# mean_test_recall                                                         0.382353
# std_test_recall                                                          0.247332
# rank_test_recall                                                              214
# split0_test_precision                                                         0.5
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.4
# split3_test_precision                                                    0.666667
# split4_test_precision                                                    0.423077
# mean_test_precision                                                      0.397949
# std_test_precision                                                       0.219828
# rank_test_precision                                                            32
# split0_test_f1                                                           0.451613
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.5
# split3_test_f1                                                           0.333333
# split4_test_f1                                                                0.5
# mean_test_f1                                                             0.356989
# std_test_f1                                                              0.188605
# rank_test_f1                                                                  191
# split0_test_roc_auc                                                      0.637455
# split1_test_roc_auc                                                           0.5
# split2_test_roc_auc                                                      0.719359
# split3_test_roc_auc                                                      0.601088
# split4_test_roc_auc                                                       0.85252
# mean_test_roc_auc                                                        0.662084
# std_test_roc_auc                                                         0.118444
# rank_test_roc_auc                                                             198
#
#                                                                               14   \
# mean_fit_time                                                            0.419105
# std_fit_time                                                             0.239508
# mean_score_time                                                           0.01094
# std_score_time                                                           0.000353
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.411765
# split1_test_recall                                                       0.176471
# split2_test_recall                                                       0.388889
# split3_test_recall                                                            0.5
# split4_test_recall                                                       0.388889
# mean_test_recall                                                         0.373203
# std_test_recall                                                          0.106546
# rank_test_recall                                                              215
# split0_test_precision                                                         0.5
# split1_test_precision                                                        0.25
# split2_test_precision                                                    0.583333
# split3_test_precision                                                    0.409091
# split4_test_precision                                                    0.538462
# mean_test_precision                                                      0.456177
# std_test_precision                                                       0.117971
# rank_test_precision                                                             4
# split0_test_f1                                                           0.451613
# split1_test_f1                                                           0.206897
# split2_test_f1                                                           0.466667
# split3_test_f1                                                               0.45
# split4_test_f1                                                           0.451613
# mean_test_f1                                                             0.405358
# std_test_f1                                                              0.099416
# rank_test_f1                                                                  130
# split0_test_roc_auc                                                      0.696879
# split1_test_roc_auc                                                      0.667167
# split2_test_roc_auc                                                      0.742268
# split3_test_roc_auc                                                      0.760309
# split4_test_roc_auc                                                      0.735109
# mean_test_roc_auc                                                        0.720346
# std_test_roc_auc                                                         0.033688
# rank_test_roc_auc                                                             103
#
#                                                                               61
# mean_fit_time                                                            0.245455
# std_fit_time                                                             0.124413
# mean_score_time                                                          0.014103
# std_score_time                                                           0.001262
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.647059
# split1_test_recall                                                       0.176471
# split2_test_recall                                                            0.5
# split3_test_recall                                                            0.0
# split4_test_recall                                                       0.444444
# mean_test_recall                                                         0.353595
# std_test_recall                                                          0.233329
# rank_test_recall                                                              216
# split0_test_precision                                                    0.141026
# split1_test_precision                                                         0.3
# split2_test_precision                                                    0.409091
# split3_test_precision                                                         0.0
# split4_test_precision                                                    0.533333
# mean_test_precision                                                       0.27669
# std_test_precision                                                       0.189157
# rank_test_precision                                                           204
# split0_test_f1                                                           0.231579
# split1_test_f1                                                           0.222222
# split2_test_f1                                                               0.45
# split3_test_f1                                                                0.0
# split4_test_f1                                                           0.484848
# mean_test_f1                                                              0.27773
# std_test_f1                                                              0.176023
# rank_test_f1                                                                  214
# split0_test_roc_auc                                                      0.479892
# split1_test_roc_auc                                                       0.64886
# split2_test_roc_auc                                                      0.702463
# split3_test_roc_auc                                                           0.5
# split4_test_roc_auc                                                      0.790664
# mean_test_roc_auc                                                        0.624376
# std_test_roc_auc                                                         0.118907
# rank_test_roc_auc                                                             213
#
# [41 rows x 216 columns]

# %% [markdown]
# #### Feature Importance (MLP)

# %%
# Feature importance of model (MLP)  (no cross-validation!)

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=3)

MLP = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(MLP, Xsc, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = Xsc.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance MLP")
# Out:
# Text(0.5, 1.0, 'Permutation Importance MLP')

# %% [markdown]
# #### Feature importance with SHAP

# %%
X = Xsc.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.25)

nn = MLPClassifier(hidden_layer_sizes=(3,3), solver='lbfgs', max_iter=5000)
model = nn.fit(X_train.to_numpy(), y_train)

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# explain the model's predictions using SHAP
import shap
import warnings
warnings.filterwarnings("ignore")
shap.initjs()

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,20))
shap_values = explainer.shap_values(X_test, nsamples=50)
shap.summary_plot(shap_values, X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
#   0%|          | 0/144 [00:00<?, ?it/s]

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,50))
shap_values = explainer.shap_values(X_test, nsamples=50)
classid = 1
shap.summary_plot(shap_values[classid], X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
#   0%|          | 0/144 [00:00<?, ?it/s]

# %%
# Try dependence contribution plot
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,50))
shap_values = explainer.shap_values(X_test, nsamples=50)
shap.dependence_plot('salinity', shap_values[1], X_test,) #interaction_index="salinity"
# Out:
#   0%|          | 0/144 [00:00<?, ?it/s]

# %% [markdown]
# Example intepretation: The fact this slopes upward says the higher the soca flow, the higher the model's prediction is for poz/neg. The spread suggests that other features must interact with Soca flow.
# In general, high Soca flow increases the chance of poz/neg. But if the sea temp is moderate or low, that trend reverses and even high soca flow does not increase preditions of poz/neg as the sea temp is too low.
# https://www.kaggle.com/code/dansbecker/advanced-uses-of-shap-values

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
instanceID = 10
instance = X.iloc[[instanceID]]
display_instance = X_display.iloc[[instanceID]]

prediction = model.predict(instance)[0]
prediction_probs = model.predict_proba(instance)[0]
print(f'real value: {y[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)
# Out:
# real value: 0,
# predicted: 0,
# predicted probs: [1.00000000e+00 2.43465291e-11]
# Explanation for prediction: class=0, p=0.9999999999756535
#   0%|          | 0/1 [00:00<?, ?it/s]
# <div id='iGELPC9DBEVODSIGW5HC3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.8042416932606296, "outValue": 0.9999999999756535, "link": "identity", "featureNames": ["DSP", "Dinophysis caudata", "Dinophysis fortii", "Phalacroma rotundatum", "Dinophysis sacculus", "Dinophysis tripos", "sun [h]", "air temp", "wind strength", "precipitation", "Chl-a", "salinity", "T", "DIN", "PO4-P", "Soca", "month_1", "month_2", "month_3", "month_4", "month_5", "month_6", "month_7", "month_8", "month_9", "month_10", "month_11", "month_12"], "features": {"0": {"effect": -0.009566283124125361, "value": 77.0}, "1": {"effect": -0.0631293299676315, "value": 36.0}, "2": {"effect": -0.0234572115945561, "value": 27.0}, "3": {"effect": -0.009245829586642895, "value": 9.0}, "4": {"effect": -0.008534610055669526, "value": 0.0}, "5": {"effect": 0.01869285809586154, "value": 0.0}, "6": {"effect": 0.16769392068269073, "value": 185.20000000000002}, "7": {"effect": 0.03432737629484787, "value": 16.17142857142857}, "8": {"effect": 0.11225776453711223, "value": 3.142857142857143}, "9": {"effect": -0.033842532720784815, "value": 0.0}, "10": {"effect": 0.011089177672678883, "value": 0.55}, "11": {"effect": -0.09149960065587813, "value": 35.3}, "12": {"effect": -0.048847608822853654, "value": 21.9}, "13": {"effect": 0.047050459385146993, "value": 1.5099999886006166}, "14": {"effect": 0.04029749012935749, "value": 0.0500000007450581}, "15": {"effect": -0.066288691289122, "value": 1905.1640000000002}, "17": {"effect": -0.01183531502814917, "value": 0.0}, "18": {"effect": -0.03435134572040564, "value": 0.0}, "20": {"effect": 0.010787813176256933, "value": 0.0}, "21": {"effect": -0.01397869061804732, "value": 0.0}, "22": {"effect": 0.028543033128940087, "value": 0.0}, "23": {"effect": 0.028399882508203175, "value": 0.0}, "24": {"effect": -0.008974378007845578, "value": 0.0}, "25": {"effect": 0.17042343761168655, "value": 1.0}, "26": {"effect": -0.021702631157619556, "value": 0.0}, "27": {"effect": -0.028550848158427317, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iGELPC9DBEVODSIGW5HC3')
#   );
# </script>

# %% [markdown]
# Show the mean values of features as it may help understanding this particular instance data in the plot above.

# %%
data = pd.get_dummies(data, columns=["month"])


pd.DataFrame([data[data['lipophylic_toxins']=='neg'].mean(), data[data['lipophylic_toxins']=='poz'].mean()], index=['neg','pos']).T
# Out:
#                                neg          pos
# DSP                     102.700503   195.860294
# Dinophysis caudata       25.537688    40.543382
# Dinophysis fortii        23.725829    72.827941
# Phalacroma rotundatum    16.438492    13.510294
# Dinophysis sacculus      24.474070    52.823529
# Dinophysis tripos         4.902513     8.235294
# sun [h]                 165.661647   152.191912
# air temp                 17.422122    16.944328
# wind strength             2.997017     2.921674
# precipitation            56.557731    75.321324
# Chl-a                     0.791451     0.965165
# salinity                 37.476320    35.692370
# T                        20.112537    20.241136
# DIN                       2.921092     3.868770
# PO4-P                     0.058539     0.076768
# Soca                   3208.868147  3703.893351
# month_1                   0.015060     0.022059
# month_2                   0.021084     0.022059
# month_3                   0.028112     0.014706
# month_4                   0.066265     0.014706
# month_5                   0.089357     0.102941
# month_6                   0.115462     0.088235
# month_7                   0.125502     0.132353
# month_8                   0.126506     0.080882
# month_9                   0.143574     0.227941
# month_10                  0.138554     0.176471
# month_11                  0.091365     0.095588
# month_12                  0.039157     0.022059

# %% [markdown]
# ### Conclusion

# %%
# Summary table of prediction results
RF_recall = round(RF_recall_best_k[1], 2)
RF_auc = round(RF_auc_best_k[1], 2)
MLP_recall = round(MLP_recall_best_k[1], 2)
MLP_auc = round(MLP_auc_best_k[1], 2)

summary = pd.DataFrame(
    [
        (
            "RF",
            RF_recall_score,
            RF_auc_score,
        ),
        (
            "MLP",
            MLP_recall_score,
            MLP_auc_score,
        ),
        (
            "RF (smote)",
            RF_recall,
            RF_auc,
        ),
        (
            "MLP (smote)",
            MLP_recall,
            MLP_auc,
        ),
        (
            "Decision tree (J48)*",
            0.56,
            0.18,
        ),
    ],
    columns=("Model", "Recall", "ROC AUC"),
).set_index("Model")

print("Table summarising the prediction results of the used classifiers, both with and without SMOTE resampling:\n")
summary.round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 # Summary table of prediction results
# ----> 2 RF_recall = round(RF_recall_best_k[1], 2)
#       3 RF_auc = round(RF_auc_best_k[1], 2)
#       4 MLP_recall = round(MLP_recall_best_k[1], 2)
#
# NameError: name 'RF_recall_best_k' is not defined

# %% [markdown]
# As can be seen resampling with SMOTE helped to improve the results substantially, especially when calculating recall. The highest recall and ROC AUC was achieved with Random Forest with the re-sampled data. Both recall and ROC AUC suggest Random Forest as beeing the better classifier for this particular problem. Recall is a crucial metric as it gives indication of what fraction of true positive instances have been predicted. Since the models predict toxins in seashells (food) it is crucial that as few positives as possible are missed.
#
# Due to the use of SMOTE resampling (upsampling and downsampling) in combinaiton with cross-validation it was curcial to do the resampling within each fold to avoid data lekeage and validate on original (unsampled) data. In addition, I have optimised the model with regard to the k-values of SMOTE, all of which brought along some complexity. So for the parameter tuning of Random Forest and MLP various parameter settings have been tried  and the model with best performing settings has been chosen.
#
# The decision tree J48 algorithm was run within Weka on a slightly different dataset (missing values were not removed to use as many instances as possible, cross validation was 10-fold as opposed to 3-fold due to a higher dataset etc.) thus this results are not directly comparable but were provided as a reference to give an indication of the performance of this algorithm.
#
# As can be seen in the feature importance bar plots above, similar features were on the top despite using two different classification algorithms and two different feature ranking methods. If we consider just the three highest-ranking features of each of the feature ranking methods for both algortihms (RF and MLP) the features that overlap are DSP, DSP_like, ASP, Dinophysis fortii and Dinophysis caudata. These can be shown to the domain experts for validation and interpretation.
