# %%
from datetime import datetime
import pandas as pd
import numpy as np
import os
import pickle
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC 
from sklearn.tree import export_text
from dtreeviz.trees import dtreeviz 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

import ipynbname
notebook_name = ipynbname.name()

import seaborn as sns

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 35)

# %%
# Define directory path name and timestamp

# Get the current date and time as a string
timestamp = datetime.datetime.now().strftime('%d%m%Y_%H%M')

# Construct the directory path with the models folder and timestamp
dir_path = f"models/{timestamp}"
    
# Create the directory if it doesn't exist
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")
# data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# SECCHI                   450
# DIN                      352
# PO4-P                    349
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
# move month to first place
cols = data.columns.tolist()  # Get a list of column names
cols = [cols[-2]] + cols[:-2] + [cols[-1]]  # Move the one before the last column to the first position
data = data[cols]

# %%
# data.drop(columns=["Chl-a","PO4-P","DIN","SECCHI"], inplace=True)
data.drop(columns=["SECCHI",  ], inplace=True)#,"Chl-a", "PO4-P", "DIN",
data.isnull().sum()
# Out:
# month                      0
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# DIN                      352
# PO4-P                    349
# Soca                       0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Descriptive analysis

# %%
# describe
description = data.describe(include='all').round(0)

# Calculate the number of missing values for each column
missing_values = data.isna().sum()
missing_values.name = 'missing_values'

# Append the missing_values row to the description DataFrame
description_with_missing = description.append(missing_values)
description_with_missing = description_with_missing.drop(['unique', 'top', 'freq'])

description_with_missing

# # Descriptive statistics without decimals.
# # Generate summary statistics for the dataset and format all numbers as integers
# description = data.describe(include='all').apply(lambda x: x.apply(lambda y: "{:.0f}".format(y) if isinstance(y, (int, float)) else y))

# # Calculate the number of missing values for each column
# missing_values = data.isna().sum()
# missing_values.name = 'missing_values'

# # Append the missing_values row to the description DataFrame
# description_with_missing = description.append(missing_values)
# description_with_missing = description_with_missing.drop(['unique', 'top', 'freq'])

# # Output the modified DataFrame
# description_with_missing
# Out:
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                  month     DSP  Dinophysis caudata  Dinophysis fortii  \
# count           1452.0  1451.0              1451.0             1451.0
# mean               7.0   106.0                25.0               26.0
# std                3.0   340.0                88.0              160.0
# min                1.0     0.0                 0.0                0.0
# 25%                5.0    10.0                 0.0                0.0
# 50%                8.0    37.0                 0.0                0.0
# 75%               10.0    90.0                13.0               10.0
# max               12.0  7630.0              1309.0             4624.0
# missing_values     0.0     1.0                 1.0                1.0
#
#                 Phalacroma rotundatum  Dinophysis sacculus  Dinophysis tripos  \
# count                          1451.0               1451.0             1451.0
# mean                             14.0                 29.0                5.0
# std                              30.0                178.0               41.0
# min                               0.0                  0.0                0.0
# 25%                               0.0                  0.0                0.0
# 50%                              10.0                  0.0                0.0
# 75%                              20.0                 10.0                0.0
# max                             393.0               4639.0             1139.0
# missing_values                    1.0                  1.0                1.0
#
#                 sun [h]  air temp  wind strength  precipitation   Chl-a  \
# count            1452.0    1452.0         1452.0         1452.0  1030.0
# mean              159.0      17.0            3.0           58.0     1.0
# std                61.0       6.0            0.0           51.0     1.0
# min                23.0      -1.0            1.0            0.0     0.0
# 25%               113.0      12.0            3.0           20.0     0.0
# 50%               161.0      17.0            3.0           45.0     1.0
# 75%               207.0      22.0            3.0           79.0     1.0
# max               278.0      27.0            5.0          268.0     9.0
# missing_values      0.0       0.0            0.0            0.0   422.0
#
#                 salinity       T     DIN   PO4-P     Soca lipophylic_toxins
# count             1431.0  1393.0  1100.0  1103.0   1452.0              1132
# mean                37.0    19.0     3.0     0.0   3295.0               NaN
# std                 26.0     5.0     4.0     0.0   2330.0               NaN
# min                 24.0     6.0     0.0     0.0    594.0               NaN
# 25%                 36.0    16.0     1.0     0.0   1636.0               NaN
# 50%                 37.0    20.0     2.0     0.0   2581.0               NaN
# 75%                 37.0    24.0     4.0     0.0   4237.0               NaN
# max                999.0    28.0    35.0     4.0  16040.0               NaN
# missing_values      21.0    59.0   352.0   349.0      0.0               320

# %%
# # Visualize the distribution of each variable with histograms
# num_columns = len(data.columns)
# fig, axes = plt.subplots(num_columns, 1, figsize=(10, num_columns*5))

# for i, column in enumerate(data.columns):
#     if data[column].dtype == 'float64' or data[column].dtype == 'int64':
#         sns.histplot(data=data, x=column, kde=True, ax=axes[i])
#     elif data[column].dtype == 'object':
#         sns.countplot(data=data, x=column, ax=axes[i])

#     axes[i].set_title(f'Distribution of {column}')

# plt.tight_layout()
# plt.show()

# %%
# Create a figure with a more narrow width
fig, ax = plt.subplots(figsize=(4, 5))

# Create a count plot
sns.countplot(data=data, x="lipophylic_toxins", ax=ax)
ax.set_title('Distribution of lipophylic toxins test counts')

# Add numbers on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height() + 0.5,
            p.get_height(), ha='center', fontsize=10)

# Show the plot
plt.savefig(f"{dir_path}/lipophylic_toxins_test_counts-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# # Visualize the distribution of each variable using vertical violin plots
# num_columns = len(data.columns)
# fig, axes = plt.subplots(num_columns, 1, figsize=(6, num_columns*4))

# for i, column in enumerate(data.columns):
#     if data[column].dtype == 'float64' or data[column].dtype == 'int64':
#         sns.violinplot(data=data, y=column, ax=axes[i])
#         axes[i].set_title(f'Violin plot of {column}')
#     else:
#         # Skip categorical columns for violin plots
#         axes[i].set_visible(False)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Descriptive analysis by month

# %%
# table of mean values for each feature by month 
import calendar

grouped_means = data.groupby('month').mean()

# Count binary values for the categorical feature grouped by month
binary_counts = data.groupby('month')['lipophylic_toxins'].value_counts().unstack()

# Calculate the ratio of positive values for each month
sum_positive = binary_counts["poz"].sum()
positive_ratios = [i for i in (binary_counts["poz"] / sum_positive)] 
positive_ratios = [round(v * 100, 1) for v in positive_ratios]

# Change month names
month_names = {i: calendar.month_name[i] for i in range(1, 13)}

# Update the index using the month_names dictionary
grouped_means.index = grouped_means.index.map(month_names)
binary_counts.index = binary_counts.index.map(month_names)

# Concatenate the grouped_means and binary_counts DataFrames
result = pd.concat([grouped_means, binary_counts], axis=1).round(2)

# Add the positive_ratios Series as a new column to the result DataFrame
result["poz %"] = positive_ratios

result
# Out:
#               DSP  Dinophysis caudata  Dinophysis fortii  \
# month
# January      9.00                1.16               2.96
# February    12.86                1.02               4.08
# March       12.38                0.21               0.68
# April       15.49                0.97               0.48
# May         59.00                6.00               0.97
# June       146.89               29.23               1.49
# July       237.04               67.07              44.50
# August     129.67               55.46              24.23
# September  116.79               28.04              58.58
# October     97.76               13.21              35.56
# November    80.54               13.81              29.33
# December    81.96                2.33              51.95
#
#            Phalacroma rotundatum  Dinophysis sacculus  Dinophysis tripos  \
# month
# January                     3.66                 0.09               0.20
# February                    3.38                 0.20               0.69
# March                       3.79                 0.43               0.64
# April                       5.24                 4.51               0.00
# May                         9.67                34.25               0.15
# June                       12.87                93.28               0.09
# July                       19.57                97.25               0.04
# August                     19.01                22.96               0.08
# September                  12.81                 3.57               6.04
# October                    19.39                 2.17              19.76
# November                   19.09                 1.11               8.90
# December                   16.06                 1.18               4.77
#
#            sun [h]  air temp  wind strength  precipitation  Chl-a  salinity  \
# month
# January      72.62      4.95           2.71          46.53   0.76     36.95
# February     80.19      5.52           3.06          60.66   0.77     37.02
# March       118.56      7.55           3.30          30.01   0.77     37.17
# April       144.63     11.69           3.17          54.90   0.68     36.93
# May         171.96     16.22           2.89          48.55   0.96     36.57
# June        202.85     20.51           2.83          45.16   1.09     35.60
# July        227.47     23.31           2.88          38.27   0.75     35.40
# August      220.46     23.46           3.03          54.38   0.63     41.92
# September   174.65     20.06           3.11          69.73   0.64     36.59
# October     127.60     15.56           3.08          72.07   0.80     36.91
# November     82.48     11.35           3.01          74.21   1.20     36.72
# December     65.97      7.51           2.83          81.32   1.20     36.81
#
#                T   DIN  PO4-P     Soca  neg  poz  poz %
# month
# January    11.07  6.79   0.07  4652.16   15    3    2.2
# February   10.22  6.66   0.08  4378.79   21    3    2.2
# March       9.49  4.37   0.05  3257.07   28    2    1.5
# April      11.68  4.68   0.06  3826.10   66    2    1.5
# May        14.87  3.92   0.07  3864.97   89   14   10.3
# June       20.28  3.58   0.13  3436.93  115   12    8.8
# July       23.48  3.38   0.05  2473.18  125   18   13.2
# August     24.93  2.03   0.05  1637.28  126   11    8.1
# September  24.38  2.06   0.05  2102.01  143   31   22.8
# October    21.70  1.95   0.05  2988.28  138   24   17.6
# November   17.61  3.09   0.06  5263.97   91   13    9.6
# December   15.56  4.09   0.06  5868.74   39    3    2.2

# %%
# # Visualise numeric data distribution by month

# # Get the numerical columns
# numerical_columns = data.iloc[:, 1:-1].columns

# # Plot the distribution of each numerical variable by month
# num_numerical = len(numerical_columns)
# fig, axes = plt.subplots(num_numerical, 1, figsize=(10, num_numerical * 4))

# for i, column in enumerate(numerical_columns):
#     sns.lineplot(data=data, x='month', y=column, ax=axes[i], ci=None)
#     axes[i].set_title(f'Distribution of {column} by month')

# plt.tight_layout()
# plt.show()

# %%
# Plot phytoplantkon distribution by month
# Get the phytoplankton columns
phytoplankton = data.iloc[:, 1:7].columns

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the distribution of each of the first 6 numerical variables by month on the same plot
for column in phytoplankton:
    sns.lineplot(data=data, x='month', y=column, ax=ax, label=column)

# Customize the plot
ax.set_title('Distribution of phytoplankton by Month')
ax.set_ylabel('Abundance')  # Set the y-axis label to "Abundance"
ax.legend()

# Customize the x-axis ticks and labels to show only month names
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(range(1, 13), month_names)

# Save and show the plot
plt.tight_layout()
plt.savefig(f"{dir_path}/phytoplankton_abundance_distribution_by_month-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Visualise target variable distribution by month
# Create a displot with hue
sns.displot(data=data, x="month", hue="lipophylic_toxins", kde=True, height=6)

# Customize the x-axis ticks and labels
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                         'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Customize the plot if desired
sns.set_style("whitegrid")
sns.set_palette("Set2")
plt.title('Distribution of Lipophilic Toxins test results by Month')
plt.xlabel('Month')
plt.ylabel('Count')

# Show the plot
plt.savefig(f"{dir_path}/target_distribution_month-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Data preprocessing for modelling

# %% [markdown]
# ## Removing instances with unlabeled target, label encoding

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    662
# poz     88
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# ## Clean instances close to the decision boundary

# %% [markdown]
# Clean the dataset by removing samples close to the decision boundary. Because the dataset is heavily imbalanced in favor of clas 0 (neg) we will remove instances from this class whenever finding samples which do not agree “enough” with their neighboorhood. The EditedNearestNeighbours will be used. One other option is to use Tomek links but it is more conservative and was found to perform slightly worse.

# %%
from collections import Counter
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours

print(f'Original dataset shape: {Counter(y)}')
usmp = EditedNearestNeighbours()
lastMajorityCount = Counter(y)[0]
for i in range(10):
    X_res, y_res = usmp.fit_resample(X, y)
    if Counter(y_res)[0] == lastMajorityCount:
        print('Cannot remove any more samples')
        break
    else:
        print(f'Resampled dataset shape {Counter(y_res)}')
        lastMajorityCount = Counter(y_res)[0]
    X = X_res
    y = y_res
# Out:
# Original dataset shape: Counter({0: 662, 1: 88})
# Resampled dataset shape Counter({0: 540, 1: 88})
# Resampled dataset shape Counter({0: 501, 1: 88})
# Resampled dataset shape Counter({0: 490, 1: 88})
# Resampled dataset shape Counter({0: 488, 1: 88})
# Resampled dataset shape Counter({0: 487, 1: 88})
# Cannot remove any more samples

# %% [markdown]
# ## Train-test split

# %%
# All data
import copy

X_all = copy.copy(X)
y_all = copy.copy(y)

# train test split
X, X_eval, y, y_eval = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.30, random_state=42)

# %% [markdown]
# # Correlation analysis on training data

# %%
# Calculate Pearson correlation between numeric features and binary target variable
pearson_correlations = X.corrwith(pd.Series(y), method='pearson')
pearson_correlations.name = 'Pearson'


# Combine the correlation values into a single dataframe
corr_df = pd.concat([pearson_correlations], axis=1)

# Create a new column for absolute Spearman correlation values
corr_df['Pearson_abs'] = corr_df['Pearson'].abs()

# Sort the dataframe by absolute Spearman correlation values
corr_df_sorted = corr_df.sort_values(by=['Pearson_abs'], ascending=False)

# Drop the absolute Spearman correlation column and return the sorted dataframe
corr_df_ranked = corr_df_sorted.drop(columns=['Pearson_abs'])

corr_df_ranked
# Out:
#                         Pearson
# Dinophysis caudata     0.159930
# T                      0.133431
# air temp               0.101362
# Chl-a                 -0.081980
# month                  0.079418
# Dinophysis tripos      0.076581
# salinity              -0.055177
# DSP                    0.050517
# DIN                    0.048785
# sun [h]                0.048582
# PO4-P                 -0.046319
# Soca                  -0.043240
# Dinophysis fortii     -0.035430
# precipitation          0.032200
# Phalacroma rotundatum  0.027626
# Dinophysis sacculus   -0.012564
# wind strength          0.003026

# %% [markdown]
# # Model Training and Evaluation

# %%
# Saving models

# Function to save best estimator
def save_best_estimator(grid_search_cv, classifier_name, notebook_name):
    # Get the best estimator from the GridSearchCV object
    best_estimator = grid_search_cv.best_estimator_

    # Construct the file name with the classifier name and notebook name
    pickle_file_name = f"{dir_path}/{classifier_name}-{notebook_name}-{timestamp}.pkl"
    
    # Save the best estimator to the file
    with open(pickle_file_name, 'wb') as f:
        pickle.dump(best_estimator, f)

    print(f"Best estimator saved as: {pickle_file_name}")

# %%
# Function for loading saved models

def load_best_estimator(pickle_file_name):
    with open(pickle_file_name, 'rb') as f:
        best_estimator = pickle.load(f)
    return best_estimator

# %% [markdown]
# ## SVM

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE()), 
    ('under', RandomUnderSampler()), 
    ('clf', SVC())
])

parameters = {
            'clf__C': [0.1, 0.5, 1, 3, 10, 100],
            # 'clf__gamma': ['scale', 'auto'],
            # 'clf__kernel': ['linear', 'rbf', 'poly'],
            'clf__class_weight': ['balanced', None],
            'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
            'under__sampling_strategy': [0.5, 0.6, 0.7],
            'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 3
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv_svm = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="f1",
                    n_jobs=-1)
resultsGSCV = gscv_svm.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_svm, classifier_name, notebook_name)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 3 folds for each of 324 candidates, totalling 972 fits
# Best estimator saved as: models/30042023_2348/SVC-HAB_modelling_6_0-30042023_2348.pkl
#                                                                               323  \
# mean_fit_time                                                            0.017201
# std_fit_time                                                              0.00246
# mean_score_time                                                          0.011317
# std_score_time                                                           0.001191
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.25
# split1_test_recall                                                        0.47619
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.400794
# std_test_recall                                                          0.106627
# rank_test_recall                                                              119
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.526316
# split2_test_precision                                                    0.666667
# mean_test_precision                                                      0.564327
# std_test_precision                                                       0.073158
# rank_test_precision                                                            24
# split0_test_f1                                                           0.333333
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.555556
# mean_test_f1                                                             0.462963
# std_test_f1                                                              0.094426
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.707018
# split1_test_roc_auc                                                        0.7126
# split2_test_roc_auc                                                      0.765276
# mean_test_roc_auc                                                        0.728298
# std_test_roc_auc                                                         0.026247
# rank_test_roc_auc                                                              17
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.850746
# split2_test_recall_weighted                                              0.880597
# mean_test_recall_weighted                                                0.860697
# std_test_recall_weighted                                                 0.014072
# rank_test_recall_weighted                                                       4
#
#                                                                               304  \
# mean_fit_time                                                            0.023436
# std_fit_time                                                             0.001713
# mean_score_time                                                          0.019057
# std_score_time                                                           0.000544
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.25
# split1_test_recall                                                       0.333333
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.337302
# std_test_recall                                                          0.072955
# rank_test_recall                                                              148
# split0_test_precision                                                    0.416667
# split1_test_precision                                                    0.777778
# split2_test_precision                                                        0.75
# mean_test_precision                                                      0.648148
# std_test_precision                                                       0.164074
# rank_test_precision                                                            15
# split0_test_f1                                                             0.3125
# split1_test_f1                                                           0.466667
# split2_test_f1                                                           0.545455
# mean_test_f1                                                              0.44154
# std_test_f1                                                              0.096749
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.748246
# split1_test_roc_auc                                                      0.718921
# split2_test_roc_auc                                                      0.747998
# mean_test_roc_auc                                                        0.738388
# std_test_roc_auc                                                         0.013766
# rank_test_roc_auc                                                               8
# split0_test_recall_weighted                                              0.835821
# split1_test_recall_weighted                                              0.880597
# split2_test_recall_weighted                                               0.88806
# mean_test_recall_weighted                                                0.868159
# std_test_recall_weighted                                                 0.023069
# rank_test_recall_weighted                                                       1
#
#                                                                               321  \
# mean_fit_time                                                            0.022851
# std_fit_time                                                             0.000305
# mean_score_time                                                           0.01738
# std_score_time                                                           0.000737
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.25
# split1_test_recall                                                        0.47619
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.353175
# std_test_recall                                                          0.093402
# rank_test_recall                                                              142
# split0_test_precision                                                       0.625
# split1_test_precision                                                    0.454545
# split2_test_precision                                                    0.777778
# mean_test_precision                                                      0.619108
# std_test_precision                                                       0.132025
# rank_test_precision                                                            16
# split0_test_f1                                                           0.357143
# split1_test_f1                                                           0.465116
# split2_test_f1                                                           0.466667
# mean_test_f1                                                             0.429642
# std_test_f1                                                              0.051268
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.754386
# split1_test_roc_auc                                                      0.656553
# split2_test_roc_auc                                                      0.774547
# mean_test_roc_auc                                                        0.728495
# std_test_roc_auc                                                         0.051532
# rank_test_roc_auc                                                              16
# split0_test_recall_weighted                                              0.865672
# split1_test_recall_weighted                                              0.828358
# split2_test_recall_weighted                                              0.880597
# mean_test_recall_weighted                                                0.858209
# std_test_recall_weighted                                                  0.02197
# rank_test_recall_weighted                                                       7
#
#                                                                               305  \
# mean_fit_time                                                            0.021465
# std_fit_time                                                             0.000398
# mean_score_time                                                          0.018923
# std_score_time                                                            0.00093
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.25
# split1_test_recall                                                        0.47619
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.369048
# std_test_recall                                                          0.092725
# rank_test_recall                                                              136
# split0_test_precision                                                    0.555556
# split1_test_precision                                                         0.4
# split2_test_precision                                                    0.727273
# mean_test_precision                                                      0.560943
# std_test_precision                                                       0.133663
# rank_test_precision                                                            26
# split0_test_f1                                                           0.344828
# split1_test_f1                                                           0.434783
# split2_test_f1                                                                0.5
# mean_test_f1                                                             0.426537
# std_test_f1                                                              0.063617
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.672807
# split1_test_roc_auc                                                      0.697008
# split2_test_roc_auc                                                      0.785925
# mean_test_roc_auc                                                         0.71858
# std_test_roc_auc                                                         0.048634
# rank_test_roc_auc                                                              30
# split0_test_recall_weighted                                              0.858209
# split1_test_recall_weighted                                               0.80597
# split2_test_recall_weighted                                              0.880597
# mean_test_recall_weighted                                                0.848259
# std_test_recall_weighted                                                 0.031268
# rank_test_recall_weighted                                                      20
#
#                                                                               322  \
# mean_fit_time                                                            0.021406
# std_fit_time                                                             0.000762
# mean_score_time                                                          0.013888
# std_score_time                                                           0.000696
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.2
# split1_test_recall                                                        0.47619
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.352381
# std_test_recall                                                           0.11455
# rank_test_recall                                                              144
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.434783
# split2_test_precision                                                         0.8
# mean_test_precision                                                      0.578261
# std_test_precision                                                       0.159038
# rank_test_precision                                                            21
# split0_test_f1                                                           0.285714
# split1_test_f1                                                           0.454545
# split2_test_f1                                                           0.516129
# mean_test_f1                                                             0.418796
# std_test_f1                                                              0.097404
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.760526
# split1_test_roc_auc                                                      0.701643
# split2_test_roc_auc                                                      0.775811
# mean_test_roc_auc                                                        0.745994
# std_test_roc_auc                                                         0.031975
# rank_test_roc_auc                                                               3
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.820896
# split2_test_recall_weighted                                               0.88806
# mean_test_recall_weighted                                                0.853234
# std_test_recall_weighted                                                 0.027476
# rank_test_recall_weighted                                                      12
#
#                                                                               294  \
# mean_fit_time                                                            0.023899
# std_fit_time                                                             0.001006
# mean_score_time                                                          0.020862
# std_score_time                                                           0.000698
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.45
# split1_test_recall                                                       0.571429
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.530952
# std_test_recall                                                          0.057242
# rank_test_recall                                                                9
# split0_test_precision                                                       0.375
# split1_test_precision                                                    0.292683
# split2_test_precision                                                    0.363636
# mean_test_precision                                                      0.343773
# std_test_precision                                                       0.036423
# rank_test_precision                                                            53
# split0_test_f1                                                           0.409091
# split1_test_f1                                                           0.387097
# split2_test_f1                                                           0.444444
# mean_test_f1                                                             0.413544
# std_test_f1                                                              0.023623
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.746053
# split1_test_roc_auc                                                      0.650653
# split2_test_roc_auc                                                      0.737885
# mean_test_roc_auc                                                         0.71153
# std_test_roc_auc                                                         0.043175
# rank_test_roc_auc                                                              42
# split0_test_recall_weighted                                               0.80597
# split1_test_recall_weighted                                              0.716418
# split2_test_recall_weighted                                              0.776119
# mean_test_recall_weighted                                                0.766169
# std_test_recall_weighted                                                  0.03723
# rank_test_recall_weighted                                                     165
#
#                                                                               296  \
# mean_fit_time                                                            0.022106
# std_fit_time                                                             0.001055
# mean_score_time                                                          0.018312
# std_score_time                                                           0.000395
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.45
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.666667
# mean_test_recall                                                         0.546825
# std_test_recall                                                          0.089939
# rank_test_recall                                                                5
# split0_test_precision                                                    0.321429
# split1_test_precision                                                    0.305556
# split2_test_precision                                                    0.368421
# mean_test_precision                                                      0.331802
# std_test_precision                                                       0.026692
# rank_test_precision                                                            63
# split0_test_f1                                                              0.375
# split1_test_f1                                                           0.385965
# split2_test_f1                                                           0.474576
# mean_test_f1                                                             0.411847
# std_test_f1                                                              0.044582
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.777193
# split1_test_roc_auc                                                      0.635483
# split2_test_roc_auc                                                      0.734935
# mean_test_roc_auc                                                         0.71587
# std_test_roc_auc                                                         0.059403
# rank_test_roc_auc                                                              35
# split0_test_recall_weighted                                              0.776119
# split1_test_recall_weighted                                              0.738806
# split2_test_recall_weighted                                              0.768657
# mean_test_recall_weighted                                                0.761194
# std_test_recall_weighted                                                 0.016121
# rank_test_recall_weighted                                                     169
#
#                                                                               320  \
# mean_fit_time                                                            0.020981
# std_fit_time                                                             0.000937
# mean_score_time                                                          0.016885
# std_score_time                                                            0.00003
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.35
# split1_test_recall                                                       0.333333
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.338889
# std_test_recall                                                          0.007857
# rank_test_recall                                                              147
# split0_test_precision                                                    0.368421
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.777778
# mean_test_precision                                                      0.548733
# std_test_precision                                                       0.170635
# rank_test_precision                                                            29
# split0_test_f1                                                           0.358974
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.466667
# mean_test_f1                                                             0.408547
# std_test_f1                                                              0.044379
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.751316
# split1_test_roc_auc                                                      0.706279
# split2_test_roc_auc                                                      0.766119
# mean_test_roc_auc                                                        0.741238
# std_test_roc_auc                                                         0.025448
# rank_test_roc_auc                                                               5
# split0_test_recall_weighted                                              0.813433
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.880597
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.027476
# rank_test_recall_weighted                                                      23
#
#                                                                               311  \
# mean_fit_time                                                            0.020089
# std_fit_time                                                             0.001179
# mean_score_time                                                          0.016274
# std_score_time                                                           0.000474
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.3
# split1_test_recall                                                        0.47619
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.369841
# std_test_recall                                                          0.076422
# rank_test_recall                                                              135
# split0_test_precision                                                    0.333333
# split1_test_precision                                                     0.37037
# split2_test_precision                                                       0.875
# mean_test_precision                                                      0.526235
# std_test_precision                                                       0.247077
# rank_test_precision                                                            34
# split0_test_f1                                                           0.315789
# split1_test_f1                                                           0.416667
# split2_test_f1                                                           0.482759
# mean_test_f1                                                             0.405072
# std_test_f1                                                              0.068656
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.674123
# split1_test_roc_auc                                                      0.694058
# split2_test_roc_auc                                                      0.744627
# mean_test_roc_auc                                                        0.704269
# std_test_roc_auc                                                         0.029675
# rank_test_roc_auc                                                              58
# split0_test_recall_weighted                                               0.80597
# split1_test_recall_weighted                                              0.791045
# split2_test_recall_weighted                                               0.88806
# mean_test_recall_weighted                                                0.828358
# std_test_recall_weighted                                                 0.042653
# rank_test_recall_weighted                                                     115
#
#                                                                               273  \
# mean_fit_time                                                            0.021417
# std_fit_time                                                             0.000748
# mean_score_time                                                          0.019942
# std_score_time                                                           0.003015
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.35
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.619048
# mean_test_recall                                                         0.497619
# std_test_recall                                                          0.111389
# rank_test_recall                                                               28
# split0_test_precision                                                    0.304348
# split1_test_precision                                                    0.323529
# split2_test_precision                                                    0.382353
# mean_test_precision                                                      0.336743
# std_test_precision                                                       0.033188
# rank_test_precision                                                            57
# split0_test_f1                                                           0.325581
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.472727
# mean_test_f1                                                             0.399436
# std_test_f1                                                              0.060073
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.689035
# split1_test_roc_auc                                                      0.684787
# split2_test_roc_auc                                                      0.768226
# mean_test_roc_auc                                                        0.714016
# std_test_roc_auc                                                         0.038371
# rank_test_roc_auc                                                              39
# split0_test_recall_weighted                                              0.783582
# split1_test_recall_weighted                                              0.753731
# split2_test_recall_weighted                                              0.783582
# mean_test_recall_weighted                                                0.773632
# std_test_recall_weighted                                                 0.014072
# rank_test_recall_weighted                                                     158
#
#                                                                               301  \
# mean_fit_time                                                            0.021406
# std_fit_time                                                             0.002423
# mean_score_time                                                          0.017616
# std_score_time                                                           0.000197
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.15
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.319841
# std_test_recall                                                          0.121659
# rank_test_recall                                                              155
# split0_test_precision                                                         0.6
# split1_test_precision                                                    0.470588
# split2_test_precision                                                    0.692308
# mean_test_precision                                                      0.587632
# std_test_precision                                                       0.090938
# rank_test_precision                                                            19
# split0_test_f1                                                               0.24
# split1_test_f1                                                           0.421053
# split2_test_f1                                                           0.529412
# mean_test_f1                                                             0.396821
# std_test_f1                                                              0.119388
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.739035
# split1_test_roc_auc                                                      0.700801
# split2_test_roc_auc                                                      0.753055
# mean_test_roc_auc                                                        0.730964
# std_test_roc_auc                                                         0.022083
# rank_test_roc_auc                                                              15
# split0_test_recall_weighted                                              0.858209
# split1_test_recall_weighted                                              0.835821
# split2_test_recall_weighted                                              0.880597
# mean_test_recall_weighted                                                0.858209
# std_test_recall_weighted                                                  0.01828
# rank_test_recall_weighted                                                       7
#
#                                                                               313  \
# mean_fit_time                                                            0.022032
# std_fit_time                                                             0.000533
# mean_score_time                                                          0.018897
# std_score_time                                                           0.001182
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.2
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.320635
# std_test_recall                                                          0.093745
# rank_test_recall                                                              154
# split0_test_precision                                                    0.444444
# split1_test_precision                                                        0.45
# split2_test_precision                                                    0.777778
# mean_test_precision                                                      0.557407
# std_test_precision                                                       0.155842
# rank_test_precision                                                            28
# split0_test_f1                                                           0.275862
# split1_test_f1                                                           0.439024
# split2_test_f1                                                           0.466667
# mean_test_f1                                                             0.393851
# std_test_f1                                                              0.084191
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.706579
# split1_test_roc_auc                                                       0.72145
# split2_test_roc_auc                                                      0.738727
# mean_test_roc_auc                                                        0.722252
# std_test_roc_auc                                                         0.013137
# rank_test_roc_auc                                                              25
# split0_test_recall_weighted                                              0.843284
# split1_test_recall_weighted                                              0.828358
# split2_test_recall_weighted                                              0.880597
# mean_test_recall_weighted                                                0.850746
# std_test_recall_weighted                                                  0.02197
# rank_test_recall_weighted                                                      17
#
#                                                                               278  \
# mean_fit_time                                                            0.021689
# std_fit_time                                                             0.000487
# mean_score_time                                                          0.019301
# std_score_time                                                           0.000215
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                            0.3
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.401587
# std_test_recall                                                          0.092528
# rank_test_recall                                                              118
# split0_test_precision                                                    0.333333
# split1_test_precision                                                    0.297297
# split2_test_precision                                                    0.666667
# mean_test_precision                                                      0.432432
# std_test_precision                                                       0.166281
# rank_test_precision                                                            45
# split0_test_f1                                                           0.315789
# split1_test_f1                                                            0.37931
# split2_test_f1                                                           0.484848
# mean_test_f1                                                             0.393316
# std_test_f1                                                              0.069725
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.691228
# split1_test_roc_auc                                                      0.689001
# split2_test_roc_auc                                                      0.773283
# mean_test_roc_auc                                                        0.717837
# std_test_roc_auc                                                         0.039216
# rank_test_roc_auc                                                              31
# split0_test_recall_weighted                                               0.80597
# split1_test_recall_weighted                                              0.731343
# split2_test_recall_weighted                                              0.873134
# mean_test_recall_weighted                                                0.803483
# std_test_recall_weighted                                                 0.057913
# rank_test_recall_weighted                                                     135
#
#                                                                               293  \
# mean_fit_time                                                            0.022086
# std_fit_time                                                              0.00156
# mean_score_time                                                           0.01739
# std_score_time                                                           0.001298
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.45
# split1_test_recall                                                        0.52381
# split2_test_recall                                                        0.52381
# mean_test_recall                                                         0.499206
# std_test_recall                                                          0.034794
# rank_test_recall                                                               25
# split0_test_precision                                                        0.36
# split1_test_precision                                                    0.314286
# split2_test_precision                                                    0.297297
# mean_test_precision                                                      0.323861
# std_test_precision                                                       0.026479
# rank_test_precision                                                            65
# split0_test_f1                                                                0.4
# split1_test_f1                                                           0.392857
# split2_test_f1                                                            0.37931
# mean_test_f1                                                             0.390722
# std_test_f1                                                               0.00858
# rank_test_f1                                                                   14
# ...
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           249
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  249
# split0_test_roc_auc                                                      0.672807
# split1_test_roc_auc                                                       0.67678
# split2_test_roc_auc                                                      0.638432
# mean_test_roc_auc                                                        0.662673
# std_test_roc_auc                                                         0.017217
# rank_test_roc_auc                                                             120
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      25
#
#                                                                               153  \
# mean_fit_time                                                            0.018847
# std_fit_time                                                              0.00096
# mean_score_time                                                          0.015414
# std_score_time                                                           0.000205
# param_clf__C                                                                    1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 1, 'clf__class_weight': None, 'smt_...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              249
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           249
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  249
# split0_test_roc_auc                                                      0.640789
# split1_test_roc_auc                                                      0.725664
# split2_test_roc_auc                                                      0.743784
# mean_test_roc_auc                                                        0.703412
# std_test_roc_auc                                                         0.044895
# rank_test_roc_auc                                                              62
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      25
#
#                                                                               156  \
# mean_fit_time                                                            0.019453
# std_fit_time                                                             0.001193
# mean_score_time                                                          0.017099
# std_score_time                                                           0.000686
# param_clf__C                                                                    1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 1, 'clf__class_weight': None, 'smt_...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              249
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           249
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  249
# split0_test_roc_auc                                                      0.695175
# split1_test_roc_auc                                                      0.778761
# split2_test_roc_auc                                                      0.742941
# mean_test_roc_auc                                                        0.738959
# std_test_roc_auc                                                          0.03424
# rank_test_roc_auc                                                               6
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      25
#
#                                                                               47   \
# mean_fit_time                                                             0.01744
# std_fit_time                                                             0.001304
# mean_score_time                                                          0.016287
# std_score_time                                                           0.000926
# param_clf__C                                                                  0.1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 0.1, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              249
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           249
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  249
# split0_test_roc_auc                                                      0.677632
# split1_test_roc_auc                                                      0.577328
# split2_test_roc_auc                                                      0.543194
# mean_test_roc_auc                                                        0.599385
# std_test_roc_auc                                                         0.057057
# rank_test_roc_auc                                                             231
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      25
#
#                                                                               104
# mean_fit_time                                                            0.033958
# std_fit_time                                                             0.008826
# mean_score_time                                                           0.02309
# std_score_time                                                           0.004132
# param_clf__C                                                                  0.5
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 0.5, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              249
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           249
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  249
# split0_test_roc_auc                                                      0.703947
# split1_test_roc_auc                                                      0.626633
# split2_test_roc_auc                                                      0.550358
# mean_test_roc_auc                                                         0.62698
# std_test_roc_auc                                                         0.062703
# rank_test_roc_auc                                                             188
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      25
#
# [40 rows x 324 columns]

# %%
# Evaluation on test data
svm_clf = gscv_svm.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# svm_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation on test data
from sklearn.metrics import classification_report
y_pred = svm_clf.predict(X_eval)
SVM_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
SVM_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.91      0.86      0.88       147
#          poz       0.40      0.54      0.46        26
#
#     accuracy                           0.81       173
#    macro avg       0.66      0.70      0.67       173
# weighted avg       0.84      0.81      0.82       173

# %% [markdown]
# ## Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE()), 
    ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
            'clf__max_depth': [2,3, 4],
            'clf__criterion': ['gini', 'entropy', 'log_loss'],
               'clf__class_weight': ['balanced', None],
               'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
               'under__sampling_strategy': [0.5, 0.6, 0.7],
               'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 3
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv_dt = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="f1",
                    n_jobs=-1)
resultsGSCV = gscv_dt.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_dt, classifier_name, notebook_name)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 3 folds for each of 486 candidates, totalling 1458 fits
# Best estimator saved as: models/30042023_2348/DecisionTreeClassifier-HAB_modelling_6_0-30042023_2348.pkl
#                                                                               47   \
# mean_fit_time                                                            0.019421
# std_fit_time                                                             0.000895
# mean_score_time                                                          0.011183
# std_score_time                                                           0.000353
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.857143
# split2_test_recall                                                       0.619048
# mean_test_recall                                                         0.675397
# std_test_recall                                                          0.131569
# rank_test_recall                                                               29
# split0_test_precision                                                    0.478261
# split1_test_precision                                                    0.486486
# split2_test_precision                                                    0.382353
# mean_test_precision                                                      0.449033
# std_test_precision                                                        0.04727
# rank_test_precision                                                            46
# split0_test_f1                                                           0.511628
# split1_test_f1                                                            0.62069
# split2_test_f1                                                           0.472727
# mean_test_f1                                                             0.535015
# std_test_f1                                                              0.062628
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.784649
# split1_test_roc_auc                                                      0.869785
# split2_test_roc_auc                                                      0.745681
# mean_test_roc_auc                                                        0.800038
# std_test_roc_auc                                                         0.051821
# rank_test_roc_auc                                                               1
# split0_test_recall_weighted                                              0.843284
# split1_test_recall_weighted                                              0.835821
# split2_test_recall_weighted                                              0.783582
# mean_test_recall_weighted                                                0.820896
# std_test_recall_weighted                                                  0.02656
# rank_test_recall_weighted                                                      48
#
#                                                                               471  \
# mean_fit_time                                                            0.020241
# std_fit_time                                                             0.001135
# mean_score_time                                                          0.011655
# std_score_time                                                           0.000537
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.3
# split1_test_recall                                                        0.47619
# split2_test_recall                                                        0.47619
# mean_test_recall                                                          0.41746
# std_test_recall                                                          0.083057
# rank_test_recall                                                              400
# split0_test_precision                                                    0.545455
# split1_test_precision                                                    0.714286
# split2_test_precision                                                       0.625
# mean_test_precision                                                      0.628247
# std_test_precision                                                       0.068963
# rank_test_precision                                                             2
# split0_test_f1                                                           0.387097
# split1_test_f1                                                           0.571429
# split2_test_f1                                                           0.540541
# mean_test_f1                                                             0.499689
# std_test_f1                                                              0.080607
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.650658
# split1_test_roc_auc                                                      0.692373
# split2_test_roc_auc                                                      0.670038
# mean_test_roc_auc                                                        0.671023
# std_test_roc_auc                                                         0.017044
# rank_test_roc_auc                                                             268
# split0_test_recall_weighted                                              0.858209
# split1_test_recall_weighted                                               0.88806
# split2_test_recall_weighted                                              0.873134
# mean_test_recall_weighted                                                0.873134
# std_test_recall_weighted                                                 0.012187
# rank_test_recall_weighted                                                       1
#
#                                                                               294  \
# mean_fit_time                                                             0.02637
# std_fit_time                                                             0.005086
# mean_score_time                                                          0.012253
# std_score_time                                                           0.000662
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.35
# split1_test_recall                                                       0.571429
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.434127
# std_test_recall                                                          0.097906
# rank_test_recall                                                              384
# split0_test_precision                                                    0.269231
# split1_test_precision                                                    0.923077
# split2_test_precision                                                    0.571429
# mean_test_precision                                                      0.587912
# std_test_precision                                                       0.267186
# rank_test_precision                                                             5
# split0_test_f1                                                           0.304348
# split1_test_f1                                                           0.705882
# split2_test_f1                                                           0.457143
# mean_test_f1                                                             0.489124
# std_test_f1                                                              0.165478
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.618202
# split1_test_roc_auc                                                      0.868521
# split2_test_roc_auc                                                      0.644121
# mean_test_roc_auc                                                        0.710281
# std_test_roc_auc                                                         0.112391
# rank_test_roc_auc                                                              62
# split0_test_recall_weighted                                              0.761194
# split1_test_recall_weighted                                              0.925373
# split2_test_recall_weighted                                              0.858209
# mean_test_recall_weighted                                                0.848259
# std_test_recall_weighted                                                 0.067394
# rank_test_recall_weighted                                                       9
#
#                                                                               46   \
# mean_fit_time                                                            0.021584
# std_fit_time                                                             0.003739
# mean_score_time                                                          0.011615
# std_score_time                                                           0.000573
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.45
# split1_test_recall                                                       0.809524
# split2_test_recall                                                       0.666667
# mean_test_recall                                                         0.642063
# std_test_recall                                                          0.147802
# rank_test_recall                                                               57
# split0_test_precision                                                        0.36
# split1_test_precision                                                    0.414634
# split2_test_precision                                                    0.424242
# mean_test_precision                                                      0.399626
# std_test_precision                                                       0.028293
# rank_test_precision                                                            88
# split0_test_f1                                                                0.4
# split1_test_f1                                                           0.548387
# split2_test_f1                                                           0.518519
# mean_test_f1                                                             0.488969
# std_test_f1                                                              0.064081
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.651316
# split1_test_roc_auc                                                      0.801728
# split2_test_roc_auc                                                      0.714707
# mean_test_roc_auc                                                        0.722584
# std_test_roc_auc                                                         0.061657
# rank_test_roc_auc                                                              35
# split0_test_recall_weighted                                              0.798507
# split1_test_recall_weighted                                              0.791045
# split2_test_recall_weighted                                               0.80597
# mean_test_recall_weighted                                                0.798507
# std_test_recall_weighted                                                 0.006093
# rank_test_recall_weighted                                                      87
#
#                                                                               245  \
# mean_fit_time                                                            0.026077
# std_fit_time                                                             0.002841
# mean_score_time                                                          0.013647
# std_score_time                                                           0.001403
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.857143
# split2_test_recall                                                       0.666667
# mean_test_recall                                                         0.724603
# std_test_recall                                                          0.093966
# rank_test_recall                                                                7
# split0_test_precision                                                    0.317073
# split1_test_precision                                                         0.4
# split2_test_precision                                                    0.388889
# mean_test_precision                                                      0.368654
# std_test_precision                                                       0.036754
# rank_test_precision                                                           130
# split0_test_f1                                                            0.42623
# split1_test_f1                                                           0.545455
# split2_test_f1                                                           0.491228
# mean_test_f1                                                             0.487637
# std_test_f1                                                               0.04874
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.724781
# split1_test_roc_auc                                                      0.842604
# split2_test_roc_auc                                                      0.743784
# mean_test_roc_auc                                                         0.77039
# std_test_roc_auc                                                         0.051649
# rank_test_roc_auc                                                               2
# split0_test_recall_weighted                                              0.738806
# split1_test_recall_weighted                                              0.776119
# split2_test_recall_weighted                                              0.783582
# mean_test_recall_weighted                                                0.766169
# std_test_recall_weighted                                                 0.019587
# rank_test_recall_weighted                                                     140
#
#                                                                               205  \
# mean_fit_time                                                            0.026544
# std_fit_time                                                             0.003928
# mean_score_time                                                          0.015108
# std_score_time                                                           0.001775
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.714286
# mean_test_recall                                                         0.660317
# std_test_recall                                                          0.046872
# rank_test_recall                                                               39
# split0_test_precision                                                     0.26087
# split1_test_precision                                                      0.4375
# split2_test_precision                                                     0.46875
# mean_test_precision                                                       0.38904
# std_test_precision                                                       0.091524
# rank_test_precision                                                           110
# split0_test_f1                                                           0.363636
# split1_test_f1                                                           0.528302
# split2_test_f1                                                           0.566038
# mean_test_f1                                                             0.485992
# std_test_f1                                                              0.087879
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.664474
# split1_test_roc_auc                                                       0.75748
# split2_test_roc_auc                                                      0.757901
# mean_test_roc_auc                                                        0.726618
# std_test_roc_auc                                                         0.043943
# rank_test_roc_auc                                                              26
# split0_test_recall_weighted                                              0.686567
# split1_test_recall_weighted                                              0.813433
# split2_test_recall_weighted                                              0.828358
# mean_test_recall_weighted                                                0.776119
# std_test_recall_weighted                                                 0.063615
# rank_test_recall_weighted                                                     125
#
#                                                                               265  \
# mean_fit_time                                                            0.024347
# std_fit_time                                                             0.003393
# mean_score_time                                                          0.014204
# std_score_time                                                           0.001787
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.35
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.761905
# mean_test_recall                                                         0.545238
# std_test_recall                                                          0.168841
# rank_test_recall                                                              200
# split0_test_precision                                                    0.304348
# split1_test_precision                                                    0.785714
# split2_test_precision                                                    0.363636
# mean_test_precision                                                      0.484566
# std_test_precision                                                       0.214315
# rank_test_precision                                                            24
# split0_test_f1                                                           0.325581
# split1_test_f1                                                           0.628571
# split2_test_f1                                                           0.492308
# mean_test_f1                                                             0.482154
# std_test_f1                                                              0.123903
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.681579
# split1_test_roc_auc                                                      0.786979
# split2_test_roc_auc                                                      0.773493
# mean_test_roc_auc                                                         0.74735
# std_test_roc_auc                                                         0.046832
# rank_test_roc_auc                                                               7
# split0_test_recall_weighted                                              0.783582
# split1_test_recall_weighted                                              0.902985
# split2_test_recall_weighted                                              0.753731
# mean_test_recall_weighted                                                0.813433
# std_test_recall_weighted                                                 0.064485
# rank_test_recall_weighted                                                      61
#
#                                                                               279  \
# mean_fit_time                                                            0.027014
# std_fit_time                                                             0.001149
# mean_score_time                                                          0.014382
# std_score_time                                                           0.000733
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.714286
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.515873
# std_test_recall                                                          0.155928
# rank_test_recall                                                              251
# split0_test_precision                                                    0.384615
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.538462
# mean_test_precision                                                      0.474359
# std_test_precision                                                       0.065372
# rank_test_precision                                                            30
# split0_test_f1                                                           0.434783
# split1_test_f1                                                           0.588235
# split2_test_f1                                                           0.411765
# mean_test_f1                                                             0.478261
# std_test_f1                                                              0.078329
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.684868
# split1_test_roc_auc                                                      0.738306
# split2_test_roc_auc                                                      0.656342
# mean_test_roc_auc                                                        0.693172
# std_test_roc_auc                                                         0.033973
# rank_test_roc_auc                                                             137
# split0_test_recall_weighted                                               0.80597
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.850746
# mean_test_recall_weighted                                                0.833333
# std_test_recall_weighted                                                 0.019587
# rank_test_recall_weighted                                                      21
#
#                                                                               289  \
# mean_fit_time                                                             0.02409
# std_fit_time                                                             0.003597
# mean_score_time                                                           0.01277
# std_score_time                                                           0.001273
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.45
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.714286
# mean_test_recall                                                         0.515079
# std_test_recall                                                          0.143653
# rank_test_recall                                                              261
# split0_test_precision                                                    0.428571
# split1_test_precision                                                    0.470588
# split2_test_precision                                                    0.454545
# mean_test_precision                                                      0.451235
# std_test_precision                                                       0.017312
# rank_test_precision                                                            44
# split0_test_f1                                                           0.439024
# split1_test_f1                                                           0.421053
# split2_test_f1                                                           0.555556
# mean_test_f1                                                             0.471878
# std_test_f1                                                              0.059622
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.732018
# split1_test_roc_auc                                                      0.685419
# split2_test_roc_auc                                                      0.746734
# mean_test_roc_auc                                                         0.72139
# std_test_roc_auc                                                         0.026135
# rank_test_roc_auc                                                              39
# split0_test_recall_weighted                                              0.828358
# split1_test_recall_weighted                                              0.835821
# split2_test_recall_weighted                                              0.820896
# mean_test_recall_weighted                                                0.828358
# std_test_recall_weighted                                                 0.006093
# rank_test_recall_weighted                                                      35
#
#                                                                               190  \
# mean_fit_time                                                             0.02604
# std_fit_time                                                             0.006273
# mean_score_time                                                          0.015563
# std_score_time                                                            0.00306
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.55
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.714286
# mean_test_recall                                                         0.596032
# std_test_recall                                                          0.084299
# rank_test_recall                                                               97
# split0_test_precision                                                     0.37931
# split1_test_precision                                                    0.423077
# split2_test_precision                                                    0.365854
# mean_test_precision                                                      0.389414
# std_test_precision                                                       0.024429
# rank_test_precision                                                           108
# split0_test_f1                                                            0.44898
# split1_test_f1                                                           0.468085
# split2_test_f1                                                           0.483871
# mean_test_f1                                                             0.466979
# std_test_f1                                                              0.014266
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                       0.70614
# split1_test_roc_auc                                                      0.699115
# split2_test_roc_auc                                                       0.78445
# mean_test_roc_auc                                                        0.729902
# std_test_roc_auc                                                         0.038678
# rank_test_roc_auc                                                              19
# split0_test_recall_weighted                                              0.798507
# split1_test_recall_weighted                                              0.813433
# split2_test_recall_weighted                                              0.761194
# mean_test_recall_weighted                                                0.791045
# std_test_recall_weighted                                                  0.02197
# rank_test_recall_weighted                                                     103
#
#                                                                               387  \
# mean_fit_time                                                            0.025074
# std_fit_time                                                             0.004922
# mean_score_time                                                          0.017905
# std_score_time                                                           0.001684
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.619048
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.484127
# std_test_recall                                                          0.117181
# rank_test_recall                                                              307
# split0_test_precision                                                     0.37037
# split1_test_precision                                                    0.590909
# split2_test_precision                                                    0.411765
# mean_test_precision                                                      0.457681
# std_test_precision                                                        0.09571
# rank_test_precision                                                            39
# split0_test_f1                                                           0.425532
# split1_test_f1                                                           0.604651
# split2_test_f1                                                           0.368421
# mean_test_f1                                                             0.466201
# std_test_f1                                                              0.100637
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.705702
# split1_test_roc_auc                                                      0.757901
# split2_test_roc_auc                                                      0.611252
# mean_test_roc_auc                                                        0.691618
# std_test_roc_auc                                                         0.060692
# rank_test_roc_auc                                                             146
# split0_test_recall_weighted                                              0.798507
# split1_test_recall_weighted                                              0.873134
# split2_test_recall_weighted                                              0.820896
# mean_test_recall_weighted                                                0.830846
# std_test_recall_weighted                                                 0.031268
# rank_test_recall_weighted                                                      26
#
#                                                                               75   \
# mean_fit_time                                                            0.021597
# std_fit_time                                                             0.001078
# mean_score_time                                                          0.012372
# std_score_time                                                           0.000671
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.75
# split1_test_recall                                                       0.761905
# split2_test_recall                                                       0.619048
# mean_test_recall                                                         0.710317
# std_test_recall                                                           0.06472
# rank_test_recall                                                               13
# split0_test_precision                                                    0.277778
# split1_test_precision                                                    0.516129
# split2_test_precision                                                    0.270833
# mean_test_precision                                                      0.354913
# std_test_precision                                                       0.114032
# rank_test_precision                                                           147
# split0_test_f1                                                           0.405405
# split1_test_f1                                                           0.615385
# split2_test_f1                                                           0.376812
# mean_test_f1                                                             0.465867
# std_test_f1                                                              0.106367
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.730702
# split1_test_roc_auc                                                      0.800464
# split2_test_roc_auc                                                      0.650653
# mean_test_roc_auc                                                        0.727273
# std_test_roc_auc                                                         0.061208
# rank_test_roc_auc                                                              24
# split0_test_recall_weighted                                              0.671642
# split1_test_recall_weighted                                              0.850746
# split2_test_recall_weighted                                              0.679104
# mean_test_recall_weighted                                                0.733831
# std_test_recall_weighted                                                 0.082728
# rank_test_recall_weighted                                                     210
#
#                                                                               465  \
# mean_fit_time                                                            0.019993
# std_fit_time                                                             0.000544
# mean_score_time                                                          0.011588
# std_score_time                                                           0.000206
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.35
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.619048
# mean_test_recall                                                         0.465873
# std_test_recall                                                          0.112961
# rank_test_recall                                                              339
# split0_test_precision                                                    0.333333
# split1_test_precision                                                    0.692308
# split2_test_precision                                                    0.433333
# mean_test_precision                                                      0.486325
# std_test_precision                                                       0.151265
# rank_test_precision                                                            23
# split0_test_f1                                                           0.341463
# split1_test_f1                                                           0.529412
# split2_test_f1                                                           0.509804
# mean_test_f1                                                             0.460226
# std_test_f1                                                              0.084359
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.662061
# split1_test_roc_auc                                                      0.705647
# split2_test_roc_auc                                                      0.724189
# mean_test_roc_auc                                                        0.697299
# std_test_roc_auc                                                         0.026041
# rank_test_roc_auc                                                             112
# split0_test_recall_weighted                                              0.798507
# split1_test_recall_weighted                                              0.880597
# split2_test_recall_weighted                                              0.813433
# mean_test_recall_weighted                                                0.830846
# std_test_recall_weighted                                                 0.035703
# rank_test_recall_weighted                                                      26
#
#                                                                               368  \
# mean_fit_time                                                            0.019085
# std_fit_time                                                              0.00067
# mean_score_time                                                          0.012429
# std_score_time                                                           0.002115
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.809524
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.547619
# ...
# std_test_precision                                                       0.120814
# rank_test_precision                                                           128
# split0_test_f1                                                           0.090909
# split1_test_f1                                                           0.339286
# split2_test_f1                                                           0.333333
# mean_test_f1                                                             0.254509
# std_test_f1                                                              0.115708
# rank_test_f1                                                                  482
# split0_test_roc_auc                                                      0.705921
# split1_test_roc_auc                                                      0.671934
# split2_test_roc_auc                                                      0.606195
# mean_test_roc_auc                                                         0.66135
# std_test_roc_auc                                                         0.041395
# rank_test_roc_auc                                                             331
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.447761
# split2_test_recall_weighted                                              0.820896
# mean_test_recall_weighted                                                0.706468
# std_test_recall_weighted                                                 0.183339
# rank_test_recall_weighted                                                     278
#
#                                                                               429  \
# mean_fit_time                                                            0.018931
# std_fit_time                                                             0.000334
# mean_score_time                                                          0.011474
# std_score_time                                                           0.000725
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.05
# split1_test_recall                                                       0.857143
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.445238
# std_test_recall                                                          0.329725
# rank_test_recall                                                              372
# split0_test_precision                                                        0.25
# split1_test_precision                                                    0.233766
# split2_test_precision                                                    0.230769
# mean_test_precision                                                      0.238178
# std_test_precision                                                       0.008448
# rank_test_precision                                                           448
# split0_test_f1                                                           0.083333
# split1_test_f1                                                           0.367347
# split2_test_f1                                                                0.3
# mean_test_f1                                                             0.250227
# std_test_f1                                                              0.121172
# rank_test_f1                                                                  483
# split0_test_roc_auc                                                      0.639474
# split1_test_roc_auc                                                       0.69764
# split2_test_roc_auc                                                      0.625369
# mean_test_roc_auc                                                        0.654161
# std_test_roc_auc                                                         0.031279
# rank_test_roc_auc                                                             364
# split0_test_recall_weighted                                              0.835821
# split1_test_recall_weighted                                              0.537313
# split2_test_recall_weighted                                              0.686567
# mean_test_recall_weighted                                                0.686567
# std_test_recall_weighted                                                 0.121865
# rank_test_recall_weighted                                                     331
#
#                                                                               357  \
# mean_fit_time                                                            0.020049
# std_fit_time                                                             0.001049
# mean_score_time                                                          0.011596
# std_score_time                                                             0.0005
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.05
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.333333
# mean_test_recall                                                             0.35
# std_test_recall                                                          0.252029
# rank_test_recall                                                              454
# split0_test_precision                                                        0.25
# split1_test_precision                                                    0.233333
# split2_test_precision                                                    0.233333
# mean_test_precision                                                      0.238889
# std_test_precision                                                       0.007857
# rank_test_precision                                                           446
# split0_test_f1                                                           0.083333
# split1_test_f1                                                           0.345679
# split2_test_f1                                                            0.27451
# mean_test_f1                                                             0.234507
# std_test_f1                                                              0.110774
# rank_test_f1                                                                  484
# split0_test_roc_auc                                                      0.655702
# split1_test_roc_auc                                                      0.678045
# split2_test_roc_auc                                                      0.572903
# mean_test_roc_auc                                                         0.63555
# std_test_roc_auc                                                         0.045227
# rank_test_roc_auc                                                             435
# split0_test_recall_weighted                                              0.835821
# split1_test_recall_weighted                                              0.604478
# split2_test_recall_weighted                                              0.723881
# mean_test_recall_weighted                                                0.721393
# std_test_recall_weighted                                                 0.094462
# rank_test_recall_weighted                                                     250
#
#                                                                               327  \
# mean_fit_time                                                            0.019204
# std_fit_time                                                              0.00038
# mean_score_time                                                          0.012357
# std_score_time                                                           0.000636
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.2
# split1_test_recall                                                            0.0
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.257143
# std_test_recall                                                          0.236758
# rank_test_recall                                                              479
# split0_test_precision                                                    0.666667
# split1_test_precision                                                         0.0
# split2_test_precision                                                    0.255319
# mean_test_precision                                                      0.307329
# std_test_precision                                                       0.274639
# rank_test_precision                                                           253
# split0_test_f1                                                           0.307692
# split1_test_f1                                                                0.0
# split2_test_f1                                                           0.352941
# mean_test_f1                                                             0.220211
# std_test_f1                                                              0.156805
# rank_test_f1                                                                  485
# split0_test_roc_auc                                                      0.632237
# split1_test_roc_auc                                                      0.666877
# split2_test_roc_auc                                                      0.603456
# mean_test_roc_auc                                                         0.63419
# std_test_roc_auc                                                         0.025929
# rank_test_roc_auc                                                             438
# split0_test_recall_weighted                                              0.865672
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.671642
# mean_test_recall_weighted                                                0.793532
# std_test_recall_weighted                                                 0.086673
# rank_test_recall_weighted                                                      98
#
#                                                                               411
# mean_fit_time                                                            0.020049
# std_fit_time                                                             0.001021
# mean_score_time                                                          0.011807
# std_score_time                                                           0.001088
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.05
# split1_test_recall                                                            0.0
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.175397
# std_test_recall                                                           0.21367
# rank_test_recall                                                              486
# split0_test_precision                                                        0.25
# split1_test_precision                                                         0.0
# split2_test_precision                                                    0.344828
# mean_test_precision                                                      0.198276
# std_test_precision                                                       0.145449
# rank_test_precision                                                           486
# split0_test_f1                                                           0.083333
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.4
# mean_test_f1                                                             0.161111
# std_test_f1                                                              0.172312
# rank_test_f1                                                                  486
# split0_test_roc_auc                                                      0.618421
# split1_test_roc_auc                                                      0.659292
# split2_test_roc_auc                                                      0.761062
# mean_test_roc_auc                                                        0.679592
# std_test_roc_auc                                                         0.059976
# rank_test_roc_auc                                                             212
# split0_test_recall_weighted                                              0.835821
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.776119
# mean_test_recall_weighted                                                0.818408
# std_test_recall_weighted                                                 0.030057
# rank_test_recall_weighted                                                      53
#
# [41 rows x 486 columns]

# %%
# Evaluation on test data
dt_clf = gscv_dt.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/12042023_1718/DecisionTreeClassifier-HAB_modelling_5_8-12042023_1718.pkl"
# dt_clf = load_best_estimator(pickle_file_name).steps[2][1]

y_pred = dt_clf.predict(X_eval)
DT_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
DT_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.91      0.61      0.73       147
#          poz       0.23      0.65      0.34        26
#
#     accuracy                           0.62       173
#    macro avg       0.57      0.63      0.54       173
# weighted avg       0.81      0.62      0.67       173

# %%
viz = dtreeviz(dt_clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"],
             fancy=False,
               scale=1.5
              )

# Save the visualization as a PNG file
viz_file_name = f"{dir_path}/DT_visualisation.svg"
viz.save(viz_file_name)
print(f"Visualization saved as: {viz_file_name}")

# Display the visualization
viz
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Visualization saved as: models/30042023_2348/DT_visualisation.svg

# %% [markdown]
# ## Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', RandomForestClassifier())
])

parameters = {
              'clf__n_estimators': [100,300,500],
              'clf__criterion': ['gini', 'entropy', 'log_loss'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
              'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
              'under__sampling_strategy': [0.5, 0.6, 0.7],
              'smt__k_neighbors': [3, 5]
             }

nfolds = 3
scores = ['recall', 'precision', 'f1', 'roc_auc']
refit_score = 'f1'
gscv_rf = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit=refit_score,
                    n_jobs=-1)
resultsGSCV = gscv_rf.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_rf, classifier_name, notebook_name)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
pd.set_option("display.max_rows", None)
# Out:
# Fitting 3 folds for each of 486 candidates, totalling 1458 fits
# Best estimator saved as: models/30042023_2348/RandomForestClassifier-HAB_modelling_6_0-30042023_2348.pkl
#                                                                               122  \
# mean_fit_time                                                            0.276606
# std_fit_time                                                             0.001787
# mean_score_time                                                          0.051834
# std_score_time                                                           0.001276
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.571429
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.549206
# std_test_recall                                                          0.052931
# rank_test_recall                                                                7
# split0_test_precision                                                    0.444444
# split1_test_precision                                                         0.6
# split2_test_precision                                                     0.47619
# mean_test_precision                                                      0.506878
# std_test_precision                                                        0.06711
# rank_test_precision                                                           204
# split0_test_f1                                                           0.510638
# split1_test_f1                                                           0.585366
# split2_test_f1                                                            0.47619
# mean_test_f1                                                             0.524065
# std_test_f1                                                              0.045571
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.798465
# split1_test_roc_auc                                                      0.767383
# split2_test_roc_auc                                                      0.784871
# mean_test_roc_auc                                                        0.783573
# std_test_roc_auc                                                         0.012722
# rank_test_roc_auc                                                             367
#
#                                                                               223  \
# mean_fit_time                                                             0.37863
# std_fit_time                                                             0.002277
# mean_score_time                                                          0.056767
# std_score_time                                                           0.001752
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.469048
# std_test_recall                                                          0.057242
# rank_test_recall                                                               70
# split0_test_precision                                                    0.478261
# split1_test_precision                                                    0.529412
# split2_test_precision                                                        0.75
# mean_test_precision                                                      0.585891
# std_test_precision                                                       0.117907
# rank_test_precision                                                            39
# split0_test_f1                                                           0.511628
# split1_test_f1                                                           0.473684
# split2_test_f1                                                           0.545455
# mean_test_f1                                                             0.510256
# std_test_f1                                                              0.029316
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.810307
# split1_test_roc_auc                                                      0.808049
# split2_test_roc_auc                                                      0.813738
# mean_test_roc_auc                                                        0.810698
# std_test_roc_auc                                                         0.002339
# rank_test_roc_auc                                                              56
#
#                                                                               32   \
# mean_fit_time                                                            0.759732
# std_fit_time                                                             0.017124
# mean_score_time                                                           0.12432
# std_score_time                                                           0.003312
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.485714
# std_test_recall                                                          0.080812
# rank_test_recall                                                               39
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.692308
# split2_test_precision                                                    0.473684
# mean_test_precision                                                      0.555331
# std_test_precision                                                       0.097451
# rank_test_precision                                                            84
# split0_test_f1                                                           0.545455
# split1_test_f1                                                           0.529412
# split2_test_f1                                                               0.45
# mean_test_f1                                                             0.508289
# std_test_f1                                                              0.041734
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.851316
# split1_test_roc_auc                                                      0.815213
# split2_test_roc_auc                                                      0.786557
# mean_test_roc_auc                                                        0.817695
# std_test_roc_auc                                                         0.026496
# rank_test_roc_auc                                                              23
#
#                                                                               397  \
# mean_fit_time                                                            0.996776
# std_fit_time                                                             0.007489
# mean_score_time                                                          0.158013
# std_score_time                                                            0.01321
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.6
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.501587
# std_test_recall                                                          0.090796
# rank_test_recall                                                               25
# split0_test_precision                                                         0.4
# split1_test_precision                                                      0.6875
# split2_test_precision                                                         0.5
# mean_test_precision                                                      0.529167
# std_test_precision                                                        0.11917
# rank_test_precision                                                           147
# split0_test_f1                                                               0.48
# split1_test_f1                                                           0.594595
# split2_test_f1                                                           0.432432
# mean_test_f1                                                             0.502342
# std_test_f1                                                              0.068061
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.844079
# split1_test_roc_auc                                                      0.869785
# split2_test_roc_auc                                                      0.788243
# mean_test_roc_auc                                                        0.834036
# std_test_roc_auc                                                         0.034039
# rank_test_roc_auc                                                               3
#
#                                                                               461  \
# mean_fit_time                                                            0.982464
# std_fit_time                                                             0.017987
# mean_score_time                                                          0.201561
# std_score_time                                                            0.00616
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.7
# split1_test_recall                                                       0.571429
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.566667
# std_test_recall                                                          0.110861
# rank_test_recall                                                                3
# split0_test_precision                                                    0.388889
# split1_test_precision                                                    0.631579
# split2_test_precision                                                        0.36
# mean_test_precision                                                      0.460156
# std_test_precision                                                       0.121787
# rank_test_precision                                                           336
# split0_test_f1                                                                0.5
# split1_test_f1                                                                0.6
# split2_test_f1                                                           0.391304
# mean_test_f1                                                             0.497101
# std_test_f1                                                              0.085224
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.804167
# split1_test_roc_auc                                                      0.840076
# split2_test_roc_auc                                                      0.774758
# mean_test_roc_auc                                                        0.806333
# std_test_roc_auc                                                          0.02671
# rank_test_roc_auc                                                              99
#
#                                                                               71   \
# mean_fit_time                                                            0.285305
# std_fit_time                                                             0.002618
# mean_score_time                                                          0.051721
# std_score_time                                                           0.000645
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.469841
# std_test_recall                                                          0.094067
# rank_test_recall                                                               59
# split0_test_precision                                                        0.48
# split1_test_precision                                                         0.6
# split2_test_precision                                                    0.571429
# mean_test_precision                                                      0.550476
# std_test_precision                                                       0.051181
# rank_test_precision                                                            95
# split0_test_f1                                                           0.533333
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.457143
# mean_test_f1                                                             0.496825
# std_test_f1                                                              0.031186
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.817325
# split1_test_roc_auc                                                      0.812684
# split2_test_roc_auc                                                      0.785925
# mean_test_roc_auc                                                        0.805311
# std_test_roc_auc                                                         0.013838
# rank_test_roc_auc                                                             117
#
#                                                                               230  \
# mean_fit_time                                                              0.3578
# std_fit_time                                                             0.003872
# mean_score_time                                                          0.056255
# std_score_time                                                           0.001008
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                           0.55
# split1_test_recall                                                        0.47619
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.500794
# std_test_recall                                                          0.034794
# rank_test_recall                                                               30
# split0_test_precision                                                    0.423077
# split1_test_precision                                                    0.588235
# split2_test_precision                                                     0.47619
# mean_test_precision                                                      0.495834
# std_test_precision                                                       0.068842
# rank_test_precision                                                           233
# split0_test_f1                                                           0.478261
# split1_test_f1                                                           0.526316
# split2_test_f1                                                            0.47619
# mean_test_f1                                                             0.493589
# std_test_f1                                                              0.023157
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.778728
# split1_test_roc_auc                                                      0.798989
# split2_test_roc_auc                                                      0.776022
# mean_test_roc_auc                                                         0.78458
# std_test_roc_auc                                                         0.010248
# rank_test_roc_auc                                                             358
#
#                                                                               85   \
# mean_fit_time                                                            0.805765
# std_fit_time                                                             0.002405
# mean_score_time                                                          0.135003
# std_score_time                                                           0.002152
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.485714
# std_test_recall                                                          0.080812
# rank_test_recall                                                               39
# split0_test_precision                                                    0.461538
# split1_test_precision                                                         0.6
# split2_test_precision                                                    0.473684
# mean_test_precision                                                      0.511741
# std_test_precision                                                       0.062605
# rank_test_precision                                                           192
# split0_test_f1                                                           0.521739
# split1_test_f1                                                                0.5
# split2_test_f1                                                               0.45
# mean_test_f1                                                              0.49058
# std_test_f1                                                              0.030035
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.790132
# split1_test_roc_auc                                                      0.774758
# split2_test_roc_auc                                                      0.778972
# mean_test_roc_auc                                                        0.781287
# std_test_roc_auc                                                         0.006486
# rank_test_roc_auc                                                             381
#
#                                                                               148  \
# mean_fit_time                                                            1.531421
# std_fit_time                                                             0.025669
# mean_score_time                                                          0.235954
# std_score_time                                                           0.002491
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.469841
# std_test_recall                                                          0.094067
# rank_test_recall                                                               59
# split0_test_precision                                                    0.444444
# split1_test_precision                                                    0.615385
# split2_test_precision                                                      0.5625
# mean_test_precision                                                      0.540776
# std_test_precision                                                       0.071457
# rank_test_precision                                                           114
# split0_test_f1                                                           0.510638
# split1_test_f1                                                           0.470588
# split2_test_f1                                                           0.486486
# mean_test_f1                                                             0.489238
# std_test_f1                                                              0.016466
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.845175
# split1_test_roc_auc                                                      0.797303
# split2_test_roc_auc                                                      0.805099
# mean_test_roc_auc                                                        0.815859
# std_test_roc_auc                                                         0.020973
# rank_test_roc_auc                                                              31
#
#                                                                               160  \
# mean_fit_time                                                            1.442587
# std_fit_time                                                             0.009512
# mean_score_time                                                          0.215587
# std_score_time                                                           0.000551
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.469841
# std_test_recall                                                          0.094067
# rank_test_recall                                                               59
# split0_test_precision                                                         0.6
# split1_test_precision                                                      0.5625
# split2_test_precision                                                    0.380952
# mean_test_precision                                                      0.514484
# std_test_precision                                                       0.095654
# rank_test_precision                                                           186
# split0_test_f1                                                                0.6
# split1_test_f1                                                           0.486486
# split2_test_f1                                                           0.380952
# mean_test_f1                                                             0.489146
# std_test_f1                                                              0.089446
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.848684
# split1_test_roc_auc                                                      0.797514
# split2_test_roc_auc                                                      0.769701
# mean_test_roc_auc                                                          0.8053
# std_test_roc_auc                                                         0.032711
# rank_test_roc_auc                                                             118
#
#                                                                               275  \
# mean_fit_time                                                            0.347882
# std_fit_time                                                             0.007028
# mean_score_time                                                          0.055739
# std_score_time                                                           0.001007
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.500794
# std_test_recall                                                          0.085191
# rank_test_recall                                                               30
# split0_test_precision                                                    0.478261
# split1_test_precision                                                    0.470588
# split2_test_precision                                                         0.5
# mean_test_precision                                                       0.48295
# std_test_precision                                                       0.012457
# rank_test_precision                                                           274
# split0_test_f1                                                           0.511628
# split1_test_f1                                                           0.421053
# split2_test_f1                                                           0.533333
# mean_test_f1                                                             0.488671
# std_test_f1                                                              0.048628
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.864912
# split1_test_roc_auc                                                      0.796882
# split2_test_roc_auc                                                       0.77855
# mean_test_roc_auc                                                        0.813448
# std_test_roc_auc                                                         0.037152
# rank_test_roc_auc                                                              44
#
#                                                                               427  \
# mean_fit_time                                                             1.70429
# std_fit_time                                                             0.012052
# mean_score_time                                                          0.276758
# std_score_time                                                           0.015283
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.437302
# std_test_recall                                                           0.07969
# rank_test_recall                                                              132
# split0_test_precision                                                    0.578947
# split1_test_precision                                                    0.571429
# split2_test_precision                                                    0.533333
# mean_test_precision                                                      0.561236
# std_test_precision                                                       0.019968
# rank_test_precision                                                            74
# split0_test_f1                                                           0.564103
# split1_test_f1                                                           0.457143
# split2_test_f1                                                           0.444444
# mean_test_f1                                                             0.488563
# std_test_f1                                                              0.053665
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.868202
# split1_test_roc_auc                                                      0.789507
# split2_test_roc_auc                                                      0.790139
# mean_test_roc_auc                                                        0.815949
# std_test_roc_auc                                                         0.036949
# rank_test_roc_auc                                                              30
#
#                                                                               302  \
# mean_fit_time                                                            1.037698
# std_fit_time                                                             0.012667
# mean_score_time                                                          0.143746
# std_score_time                                                           0.003036
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.502381
# std_test_recall                                                          0.104382
# rank_test_recall                                                               24
# split0_test_precision                                                     0.40625
# split1_test_precision                                                         0.6
# split2_test_precision                                                         0.5
# mean_test_precision                                                      0.502083
# std_test_precision                                                       0.079112
# rank_test_precision                                                           218
# split0_test_f1                                                                0.5
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.461538
# mean_test_f1                                                             0.487179
# std_test_f1                                                              0.018131
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.816447
# split1_test_roc_auc                                                      0.797935
# split2_test_roc_auc                                                      0.797514
# mean_test_roc_auc                                                        0.803965
# std_test_roc_auc                                                         0.008828
# rank_test_roc_auc                                                             135
#
#                                                                               441  \
# mean_fit_time                                                            0.350731
# std_fit_time                                                             0.002966
# mean_score_time                                                          0.061814
# std_score_time                                                           0.003149
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.333333
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.454762
# std_test_recall                                                          0.139416
# rank_test_recall                                                               76
# split0_test_precision                                                    0.565217
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.533333
# mean_test_precision                                                       0.53285
# std_test_precision                                                       0.026627
# rank_test_precision                                                           140
# split0_test_f1                                                           0.604651
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.444444
# mean_test_f1                                                             0.483032
# std_test_f1                                                              0.087891
# rank_test_f1                                                                   14
# split0_test_roc_auc                                                      0.883553
# split1_test_roc_auc                                                      0.836705
# split2_test_roc_auc                                                       0.76338
# mean_test_roc_auc                                                        0.827879
# std_test_roc_auc                                                         0.049456
# rank_test_roc_auc                                                               6
#
#                                                                               147  \
# mean_fit_time                                                            1.502888
# std_fit_time                                                             0.020258
# mean_score_time                                                          0.259719
# std_score_time                                                           0.001854
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.333333
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.422222
# std_test_recall                                                          0.125708
# rank_test_recall                                                              160
# split0_test_precision                                                    0.545455
# split1_test_precision                                                    0.636364
# split2_test_precision                                                    0.636364
# mean_test_precision                                                      0.606061
# std_test_precision                                                       0.042855
# rank_test_precision                                                            24
# split0_test_f1                                                           0.571429
# split1_test_f1                                                             0.4375
# split2_test_f1                                                             0.4375
# mean_test_f1                                                             0.482143
# std_test_f1                                                              0.063135
# rank_test_f1                                                                   15
# split0_test_roc_auc                                                      0.835746
# split1_test_roc_auc                                                      0.796249
# split2_test_roc_auc                                                      0.768647
# mean_test_roc_auc                                                        0.800214
# std_test_roc_auc                                                         0.027536
# rank_test_roc_auc                                                             173
#
#                                                                               336  \
# mean_fit_time                                                            0.321353
# std_fit_time                                                             0.002485
# mean_score_time                                                          0.060126
# std_score_time                                                           0.002161
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.333333
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.453968
# std_test_recall                                                          0.110337
# rank_test_recall                                                               82
# split0_test_precision                                                        0.48
# split1_test_precision                                                    0.583333
# split2_test_precision                                                      0.5625
# mean_test_precision                                                      0.541944
# ...
# std_test_f1                                                              0.058183
# rank_test_f1                                                                  481
# split0_test_roc_auc                                                      0.728509
# split1_test_roc_auc                                                      0.775601
# split2_test_roc_auc                                                      0.750527
# mean_test_roc_auc                                                        0.751545
# std_test_roc_auc                                                         0.019239
# rank_test_roc_auc                                                             479
#
#                                                                               74   \
# mean_fit_time                                                            0.723003
# std_fit_time                                                             0.003976
# mean_score_time                                                          0.129853
# std_score_time                                                           0.001774
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.438095
# std_test_recall                                                          0.116123
# rank_test_recall                                                              116
# split0_test_precision                                                    0.352941
# split1_test_precision                                                    0.363636
# split2_test_precision                                                    0.269231
# mean_test_precision                                                      0.328603
# std_test_precision                                                       0.042209
# rank_test_precision                                                           485
# split0_test_f1                                                           0.444444
# split1_test_f1                                                           0.372093
# split2_test_f1                                                           0.297872
# mean_test_f1                                                              0.37147
# std_test_f1                                                              0.059839
# rank_test_f1                                                                  482
# split0_test_roc_auc                                                       0.82193
# split1_test_roc_auc                                                      0.739781
# split2_test_roc_auc                                                      0.738517
# mean_test_roc_auc                                                        0.766742
# std_test_roc_auc                                                         0.039027
# rank_test_roc_auc                                                             463
#
#                                                                               220  \
# mean_fit_time                                                            0.382603
# std_fit_time                                                             0.004669
# mean_score_time                                                          0.056701
# std_score_time                                                            0.00148
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                           0.35
# split1_test_recall                                                       0.285714
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.323016
# std_test_recall                                                           0.02724
# rank_test_recall                                                              465
# split0_test_precision                                                    0.388889
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.411765
# mean_test_precision                                                      0.433551
# std_test_precision                                                       0.047906
# rank_test_precision                                                           393
# split0_test_f1                                                           0.368421
# split1_test_f1                                                           0.363636
# split2_test_f1                                                           0.368421
# mean_test_f1                                                             0.366826
# std_test_f1                                                              0.002256
# rank_test_f1                                                                  483
# split0_test_roc_auc                                                      0.798026
# split1_test_roc_auc                                                      0.757691
# split2_test_roc_auc                                                      0.749473
# mean_test_roc_auc                                                        0.768397
# std_test_roc_auc                                                         0.021218
# rank_test_roc_auc                                                             457
#
#                                                                               253  \
# mean_fit_time                                                            1.520082
# std_fit_time                                                              0.00492
# mean_score_time                                                          0.218367
# std_score_time                                                           0.002631
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            0.4
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.403175
# std_test_recall                                                           0.01957
# rank_test_recall                                                              251
# split0_test_precision                                                        0.32
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.333333
# mean_test_precision                                                      0.328889
# std_test_precision                                                       0.006285
# rank_test_precision                                                           484
# split0_test_f1                                                           0.355556
# split1_test_f1                                                           0.355556
# split2_test_f1                                                              0.375
# mean_test_f1                                                             0.362037
# std_test_f1                                                              0.009166
# rank_test_f1                                                                  484
# split0_test_roc_auc                                                      0.775658
# split1_test_roc_auc                                                      0.767594
# split2_test_roc_auc                                                       0.76949
# mean_test_roc_auc                                                        0.770914
# std_test_roc_auc                                                         0.003443
# rank_test_roc_auc                                                             444
#
#                                                                               272  \
# mean_fit_time                                                             0.35268
# std_fit_time                                                             0.004594
# mean_score_time                                                          0.056243
# std_score_time                                                           0.000586
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.238095
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.423016
# std_test_recall                                                           0.17077
# rank_test_recall                                                              156
# split0_test_precision                                                       0.325
# split1_test_precision                                                      0.3125
# split2_test_precision                                                    0.347826
# mean_test_precision                                                      0.328442
# std_test_precision                                                       0.014626
# rank_test_precision                                                           486
# split0_test_f1                                                           0.433333
# split1_test_f1                                                            0.27027
# split2_test_f1                                                           0.363636
# mean_test_f1                                                             0.355747
# std_test_f1                                                              0.066804
# rank_test_f1                                                                  485
# split0_test_roc_auc                                                      0.804605
# split1_test_roc_auc                                                      0.731985
# split2_test_roc_auc                                                      0.714707
# mean_test_roc_auc                                                        0.750432
# std_test_roc_auc                                                          0.03895
# rank_test_roc_auc                                                             480
#
#                                                                               170
# mean_fit_time                                                            0.341934
# std_fit_time                                                             0.002716
# mean_score_time                                                          0.052319
# std_score_time                                                            0.00056
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                           0.45
# split1_test_recall                                                       0.238095
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.340476
# std_test_recall                                                          0.086657
# rank_test_recall                                                              421
# split0_test_precision                                                       0.375
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.304348
# mean_test_precision                                                      0.393116
# std_test_precision                                                       0.080895
# rank_test_precision                                                           454
# split0_test_f1                                                           0.409091
# split1_test_f1                                                           0.322581
# split2_test_f1                                                           0.318182
# mean_test_f1                                                             0.349951
# std_test_f1                                                              0.041857
# rank_test_f1                                                                  486
# split0_test_roc_auc                                                      0.808772
# split1_test_roc_auc                                                      0.835651
# split2_test_roc_auc                                                      0.743995
# mean_test_roc_auc                                                        0.796139
# std_test_roc_auc                                                          0.03847
# rank_test_roc_auc                                                             212
#
# [35 rows x 486 columns]

# %%
# Evaluation on test data
rf_clf = gscv_rf.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# rf_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation RF on test set
y_pred = rf_clf.predict(X_eval)
RF_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
RF_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.92      0.86      0.89       147
#          poz       0.43      0.58      0.49        26
#
#     accuracy                           0.82       173
#    macro avg       0.67      0.72      0.69       173
# weighted avg       0.85      0.82      0.83       173

# %% [markdown]
# Plot the mean ROC curve of the algorithm with best performing parameter selection. We will perform CV once again and plot the ROC curve for each fold and compute and plot the mean.

# %%
# Plot the ROC curve for RF

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval, y_eval)):
    classifier.fit(X_eval.iloc[train], y_eval[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X_eval.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
plt.savefig(f"{dir_path}/RF_ROC_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# Plot the mean precision-recall curve. The approach is the same as for the mean ROC curve.

# %%
# Plot the mean precision-recall curve. 

from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval, y_eval)):
    classifier.fit(X_eval.iloc[train], y_eval[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X_eval.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
plt.savefig(f"{dir_path}/RF_precision-recall_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf_clf, X, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
# Out:
# Text(0.5, 1.0, 'Permutation Importance Random Forest')

# %% [markdown]
# ### SHAP

# %%
# # Get feature importance with SHAP
# explainer = shap.TreeExplainer(rf)
# shap_values = explainer.shap_values(X)
# RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %%
# SHAP summary plot
explainer = shap.TreeExplainer(rf_clf)
shap_values = explainer.shap_values(X_eval)
classid = 1

# Save shap.summary_plot()
fig = shap.summary_plot(shap_values[classid], X_eval, max_display=len(X_eval.columns), class_names=le.classes_, show=False)
plt.savefig(f"{dir_path}/shap_summary_plot-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

#Remove months from X
Xnn = X.drop(X.columns[0], axis=1)

X_display = Xnn.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xnn)
Xsc = pd.DataFrame(scaled_array, columns=Xnn.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE()),
    ('under', RandomUnderSampler()),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.5, 0.6, 0.8], # probaj poveča ovresampling do 0.9
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
              'clf__solver': ['lbfgs', 'sgd', 'adam']
             }
nfolds = 3
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv_NN = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "f1")
resultsGSCV = gscv_NN.fit(Xsc, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_NN, classifier_name, notebook_name)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# 432 fits failed out of a total of 1944.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 432 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 268, in fit
#     Xt, yt = self._fit(X, y, **fit_params_steps)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 226, in _fit
#     X, y, fitted_transformer = fit_resample_one_cached(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/pipeline.py", line 394, in _fit_resample_one
#     X_res, y_res = sampler.fit_resample(X, y, **fit_params)
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/base.py", line 79, in fit_resample
#     self.sampling_strategy_ = check_sampling_strategy(
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 534, in check_sampling_strategy
#     _sampling_strategy_float(sampling_strategy, y, sampling_type).items()
#   File "/Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/imblearn/utils/_validation.py", line 393, in _sampling_strategy_float
#     raise ValueError(
# ValueError: The specified ratio required to generate new sample in the majority class while trying to remove samples. Please increase the ratio.
#
# One or more of the test scores are non-finite: [0.49920635 0.49920635 0.51587302 0.44920635 0.4515873  0.51269841
#         nan        nan 0.51428571 0.49920635 0.46666667 0.49920635
#  0.5968254  0.42063492 0.51349206        nan        nan 0.56269841
#  0.43174603 0.46507937 0.57857143 0.46904762 0.64365079 0.49761905
#         nan        nan 0.56111111 0.43650794 0.61111111 0.58015873
#  0.46825397 0.56349206 0.51190476        nan        nan 0.36984127
#  0.53412698 0.51349206 0.41746032 0.45       0.45079365 0.43412698
#         nan        nan 0.46587302 0.45       0.58412698 0.48174603
#  0.43492063 0.48253968 0.53253968        nan        nan 0.48333333
#  0.43809524 0.29285714 0.35555556 0.09761905 0.22460317 0.48095238
#         nan        nan 0.30238095 0.35634921 0.36904762 0.27539683
#  0.22619048 0.5484127  0.3015873         nan        nan 0.14285714
#  0.19047619 0.35238095 0.60873016 0.22619048 0.32619048 0.52936508
#         nan        nan 0.50079365 0.27777778 0.18095238 0.51746032
#  0.33968254 0.35714286 0.47142857        nan        nan 0.54365079
#  0.11428571 0.         0.41746032 0.14285714 0.49920635 0.30396825
#         nan        nan 0.73573268 0.71383862 0.70251541 0.6685155
#  0.70192738 0.73679322 0.7211005         nan        nan 0.70127929
#  0.63430922 0.68416136 0.66996677 0.68111549 0.66353919 0.68196145
#         nan        nan 0.69878466 0.69024525 0.69791108 0.67328166
#  0.64617591 0.70186408 0.69408699        nan        nan 0.75837566]
# Best estimator saved as: models/30042023_2348/MLPClassifier-HAB_modelling_6_0-30042023_2348.pkl
#                                                                               22   \
# mean_fit_time                                                            0.181939
# std_fit_time                                                             0.021753
# mean_score_time                                                            0.0137
# std_score_time                                                           0.001802
# param_clf__hidden_layer_sizes                                                (2,)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'clf__solver...
# split0_test_recall                                                           0.55
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.857143
# mean_test_recall                                                         0.643651
# std_test_recall                                                           0.15134
# rank_test_recall                                                               15
# split0_test_precision                                                    0.333333
# split1_test_precision                                                    0.392857
# split2_test_precision                                                    0.418605
# mean_test_precision                                                      0.381598
# std_test_precision                                                       0.035711
# rank_test_precision                                                            34
# split0_test_f1                                                           0.415094
# split1_test_f1                                                            0.44898
# split2_test_f1                                                             0.5625
# mean_test_f1                                                             0.475525
# std_test_f1                                                              0.063037
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                       0.68136
# split1_test_roc_auc                                                      0.750948
# split2_test_roc_auc                                                      0.893805
# mean_test_roc_auc                                                        0.775371
# std_test_roc_auc                                                         0.088433
# rank_test_roc_auc                                                               2
#
#                                                                               30   \
# mean_fit_time                                                            0.155937
# std_fit_time                                                             0.042941
# mean_score_time                                                          0.010472
# std_score_time                                                           0.000155
# param_clf__hidden_layer_sizes                                                (2,)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2,), 'clf__solver...
# split0_test_recall                                                            0.5
# split1_test_recall                                                        0.47619
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.468254
# std_test_recall                                                          0.029696
# rank_test_recall                                                              244
# split0_test_precision                                                         0.4
# split1_test_precision                                                    0.555556
# split2_test_precision                                                    0.473684
# mean_test_precision                                                      0.476413
# std_test_precision                                                       0.063535
# rank_test_precision                                                             5
# split0_test_f1                                                           0.444444
# split1_test_f1                                                           0.512821
# split2_test_f1                                                               0.45
# mean_test_f1                                                             0.469088
# std_test_f1                                                              0.031006
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.687939
# split1_test_roc_auc                                                      0.711336
# split2_test_roc_auc                                                      0.713232
# mean_test_roc_auc                                                        0.704169
# std_test_roc_auc                                                         0.011503
# rank_test_roc_auc                                                              98
#
#                                                                               325  \
# mean_fit_time                                                            0.310928
# std_fit_time                                                               0.1616
# mean_score_time                                                          0.011555
# std_score_time                                                           0.000446
# param_clf__hidden_layer_sizes                                                (3,)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3,), 'clf__solver...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.619048
# split2_test_recall                                                       0.666667
# mean_test_recall                                                         0.645238
# std_test_recall                                                           0.01973
# rank_test_recall                                                               13
# split0_test_precision                                                    0.351351
# split1_test_precision                                                    0.333333
# split2_test_precision                                                         0.4
# mean_test_precision                                                      0.361562
# std_test_precision                                                       0.028158
# rank_test_precision                                                            65
# split0_test_f1                                                            0.45614
# split1_test_f1                                                           0.433333
# split2_test_f1                                                                0.5
# mean_test_f1                                                             0.463158
# std_test_f1                                                              0.027665
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.809868
# split1_test_roc_auc                                                      0.707122
# split2_test_roc_auc                                                      0.812052
# mean_test_roc_auc                                                        0.776347
# std_test_roc_auc                                                         0.048958
# rank_test_roc_auc                                                               1
#
#                                                                               442  \
# mean_fit_time                                                            2.066895
# std_fit_time                                                             0.553854
# mean_score_time                                                          0.011613
# std_score_time                                                           0.000193
# param_clf__hidden_layer_sizes                                                (3,)
# param_clf__solver                                                            adam
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3,), 'clf__solver...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.571429
# split2_test_recall                                                       0.619048
# mean_test_recall                                                         0.563492
# std_test_recall                                                          0.048924
# rank_test_recall                                                               69
# split0_test_precision                                                     0.37037
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.433333
# mean_test_precision                                                      0.392901
# std_test_precision                                                       0.028652
# rank_test_precision                                                            26
# split0_test_f1                                                           0.425532
# split1_test_f1                                                            0.45283
# split2_test_f1                                                           0.509804
# mean_test_f1                                                             0.462722
# std_test_f1                                                              0.035108
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.685965
# split1_test_roc_auc                                                      0.741256
# split2_test_roc_auc                                                      0.831858
# mean_test_roc_auc                                                        0.753026
# std_test_roc_auc                                                         0.060139
# rank_test_roc_auc                                                               5
#
#                                                                               495  \
# mean_fit_time                                                            0.224248
# std_fit_time                                                             0.021436
# mean_score_time                                                          0.011519
# std_score_time                                                           0.000157
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'clf__solv...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.571429
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.518254
# std_test_recall                                                          0.134636
# rank_test_recall                                                              139
# split0_test_precision                                                    0.333333
# split1_test_precision                                                    0.444444
# split2_test_precision                                                    0.636364
# mean_test_precision                                                       0.47138
# std_test_precision                                                       0.125169
# rank_test_precision                                                             6
# split0_test_f1                                                           0.440678
# split1_test_f1                                                                0.5
# split2_test_f1                                                             0.4375
# mean_test_f1                                                             0.459393
# std_test_f1                                                              0.028743
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.717325
# split1_test_roc_auc                                                      0.726717
# split2_test_roc_auc                                                      0.806785
# mean_test_roc_auc                                                        0.750275
# std_test_roc_auc                                                         0.040142
# rank_test_roc_auc                                                               7
#
#                                                                               441  \
# mean_fit_time                                                            1.653037
# std_fit_time                                                              0.21367
# mean_score_time                                                          0.011768
# std_score_time                                                           0.000464
# param_clf__hidden_layer_sizes                                                (3,)
# param_clf__solver                                                            adam
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3,), 'clf__solver...
# split0_test_recall                                                           0.45
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.515079
# std_test_recall                                                          0.049956
# rank_test_recall                                                              152
# split0_test_precision                                                    0.310345
# split1_test_precision                                                    0.458333
# split2_test_precision                                                        0.48
# mean_test_precision                                                      0.416226
# std_test_precision                                                        0.07539
# ...
# rank_test_precision                                                           633
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  643
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             621
#
#                                                                               88   \
# mean_fit_time                                                            0.018812
# std_fit_time                                                             0.001601
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                                (2,)
# param_clf__solver                                                             sgd
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'clf__solver...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              577
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           522
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  644
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             520
#
#                                                                               87   \
# mean_fit_time                                                            0.016633
# std_fit_time                                                             0.002084
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                                (2,)
# param_clf__solver                                                             sgd
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2,), 'clf__solver...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              575
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           520
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  645
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             515
#
#                                                                               231  \
# mean_fit_time                                                             0.01469
# std_fit_time                                                             0.003122
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_clf__solver                                                             sgd
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'clf__solv...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              542
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           598
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  646
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             564
#
#                                                                               493  \
# mean_fit_time                                                            0.014127
# std_fit_time                                                             0.000946
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'clf__solv...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              635
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           605
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  647
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             646
#
#                                                                               142
# mean_fit_time                                                            0.015287
# std_fit_time                                                             0.001521
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                                (2,)
# param_clf__solver                                                            adam
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'clf__solver...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              630
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           642
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  648
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             602
#
# [34 rows x 648 columns]

# %%
# Evaluation on test data
nn_clf = gscv_NN.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# nn_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation of NN on test set
X_eval_nn = X_eval.drop(X_eval.columns[0], axis=1)
scaler = StandardScaler().fit(Xnn)
X_eval_sc = scaler.transform(X_eval_nn)
X_eval_sc = pd.DataFrame(X_eval_sc, columns=Xnn.columns)
y_pred = nn_clf.predict(X_eval_sc)
NN_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
NN_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.93      0.85      0.89       147
#          poz       0.42      0.62      0.50        26
#
#     accuracy                           0.82       173
#    macro avg       0.67      0.73      0.69       173
# weighted avg       0.85      0.82      0.83       173

# %%
# Plot the ROC curve for MLP (Check code as moved form RF!). 

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval_sc, y_eval)):
    classifier.fit(X_eval_sc.iloc[train], y_eval[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X_eval_sc.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
plt.savefig(f"{dir_path}/MLP_ROC_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Plot the mean precision-recall curve for MLP (Check code as moved form RF!). 

from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval_sc, y_eval)):
    classifier.fit(X_eval_sc.iloc[train], y_eval[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X_eval_sc.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
plt.savefig(f"{dir_path}/MLP_precision-recall_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# #### Feature Importance (MLP)

# %% [markdown]
# #### Feature importance with SHAP

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# # explain the model's predictions using SHAP
# import shap
# import warnings
# warnings.filterwarnings("ignore")
# shap.initjs()

# explainer = shap.KernelExplainer(NN_model.predict_proba, shap.sample(X_eval_sc,20))
# shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
# shap.summary_plot(shap_values, X_eval_sc, max_display=len(X.columns), class_names=le.classes_)

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
import shap
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
shap.initjs()

explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(X_eval_sc, 50))
shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
classid = 1

# Save shap.summary_plot()
fig = shap.summary_plot(shap_values[classid], X_eval_sc, max_display=len(X_eval_sc.columns), class_names=le.classes_, show=False)
plt.savefig(f"{dir_path}/shap_summary_plot-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
#   0%|          | 0/173 [00:00<?, ?it/s]

# %%
# Try dependence contribution plot
explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(Xsc,50))
shap_values = explainer.shap_values(Xsc, nsamples=50)
for i in Xsc.columns:
    shap.dependence_plot(i, shap_values[1], Xsc,) #interaction_index="salinity"
# Out:
#   0%|          | 0/402 [00:00<?, ?it/s]

# %% [markdown]
# Example intepretation: The fact this slopes upward says the higher the soca flow, the higher the model's prediction is for poz/neg. The spread suggests that other features must interact with Soca flow.
# In general, high Soca flow increases the chance of poz/neg. But if the sea temp is moderate or low, that trend reverses and even high soca flow does not increase preditions of poz/neg as the sea temp is too low.
# https://www.kaggle.com/code/dansbecker/advanced-uses-of-shap-values
# ----
# To interpret the dependence contribution plot, look for trends or patterns in the relationship between the 'salinity' feature values and their SHAP values. For example:
#
# If the points show a clear positive trend, it means that as the 'salinity' value increases, its positive contribution to the model's prediction also increases.
# If the points show a clear negative trend, it means that as the 'salinity' value increases, its negative contribution to the model's prediction increases (i.e., higher 'salinity' values decrease the probability of class 1).
# If there is no clear trend or the points are scattered randomly, it means that there is no strong relationship between the 'salinity' feature values and their SHAP values.
# Additionally, observe the colors of the points in the plot. If there is a clear pattern in the colors, it may indicate that the interaction between 'salinity' and the interaction feature has a significant impact on the model's predictions. This can help you identify interactions between features that the model is capturing.

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
instanceID = 10
instance = Xsc.iloc[[instanceID]]
display_instance = X_display.iloc[[instanceID]]

prediction = nn_clf.predict(instance)[0]
prediction_probs = nn_clf.predict_proba(instance)[0]
print(f'real value: {y[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(Xsc, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)
# Out:
# real value: 1,
# predicted: 1,
# predicted probs: [0.43462752 0.56537248]
# Explanation for prediction: class=1, p=0.5653724831656636
#   0%|          | 0/1 [00:00<?, ?it/s]
# <div id='i10B9WYL0Q4WPS3TIW2QA'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.24091982143497775, "outValue": 0.5653724831656635, "link": "identity", "featureNames": ["DSP", "Dinophysis caudata", "Dinophysis fortii", "Phalacroma rotundatum", "Dinophysis sacculus", "Dinophysis tripos", "sun [h]", "air temp", "wind strength", "precipitation", "Chl-a", "salinity", "T", "DIN", "PO4-P", "Soca"], "features": {"0": {"effect": 0.011468790057441067, "value": 50.0}, "2": {"effect": -0.013920567845676576, "value": 10.0}, "3": {"effect": -0.008357771326390281, "value": 10.0}, "5": {"effect": 0.04081756479642768, "value": 30.0}, "6": {"effect": 0.017991356108647247, "value": 42.99999999999999}, "7": {"effect": -0.03866737292500441, "value": 6.8428571428571425}, "10": {"effect": -0.26655926859382584, "value": 4.24}, "11": {"effect": -0.034694672392732176, "value": 31.89}, "12": {"effect": 0.014634464222555571, "value": 14.55}, "13": {"effect": 0.25143347448147185, "value": 10.379999905824656}, "14": {"effect": 0.009424849641150368, "value": 0.00999999977648258}, "15": {"effect": 0.3408818155066213, "value": 10683.316}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i10B9WYL0Q4WPS3TIW2QA')
#   );
# </script>

# %% [markdown]
# Interpretation:
#
# Observe the base value (Expected value) and the prediction line. This gives you an idea of the overall prediction for the instance compared to the average prediction.
#
# Look at the colored arrows and identify the most important features, which are the ones with the longest arrows. These features have the greatest impact on the prediction.
#
# Analyze the direction and color of the arrows to understand whether each feature increases or decreases the probability of the positive class (class 1) and whether the feature values are high or low.
#
# Consider the interactions between the features and their combined impact on the prediction.
#
# By analyzing the force plot, you can gain insights into the contributions of each feature to the model's prediction for a specific instance, helping you understand the model's decision-making process.

# %% [markdown]
# ### LIME

# %%
import lime
from lime import lime_tabular

# Create a LIME explainer object
lime_explainer = lime_tabular.LimeTabularExplainer(
    training_data=np.array(Xsc),
    feature_names=Xsc.columns,
    class_names=le.classes_,
    mode='classification'
)

# Exaplain an instance
instanceID = 100
lime_exp = lime_explainer.explain_instance(
    data_row=Xsc.iloc[instanceID], 
    predict_fn=nn_clf.predict_proba
)

lime_exp.show_in_notebook(show_table=True)

# Save the LIME explanation as an image file
# fig = lime_exp.as_pyplot_figure(label=1)
# plt.savefig(f"{dir_path}/lime_explanation-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %% [markdown]
# ### Conclusion

# %%
# Define a function to extract the metrics from the classification report dictionary
def extract_metrics(report_dict):
    metrics = {}
    for class_label in report_dict:
        if class_label in ('accuracy', 'macro avg', 'weighted avg'):
            continue
        metrics[class_label] = {
            'precision': report_dict[class_label]['precision'],
            'recall': report_dict[class_label]['recall'],
            'f1-score': report_dict[class_label]['f1-score'],
            'support': report_dict[class_label]['support']
        }
    return metrics

# Extract the metrics for each classifier
SVM_metrics = extract_metrics(SVM_report_dict)
DT_metrics = extract_metrics(DT_report_dict)
RF_metrics = extract_metrics(RF_report_dict)
NN_metrics = extract_metrics(NN_report_dict)

# Create a dictionary to store the metrics for each classifier
classifier_metrics = {
    'Support Vector Mashines': SVM_metrics,
    'Decision Tree': DT_metrics,
    'Random Forest': RF_metrics,
    'Neural Network': NN_metrics
}

# Convert the dictionary to a pandas DataFrame
summary_df = pd.concat({k: pd.DataFrame(v).transpose() for k, v in classifier_metrics.items()}, axis=0)
summary_df.reset_index(inplace=True)
summary_df.columns = ['Classifier', 'Class', 'Precision', 'Recall', 'F1-score', 'Support']

# Map the original class labels to the new names
class_name_mapping = {
    '0': 'neg',
    '1': 'poz'
}
summary_df['Class'] = summary_df['Class'].map(class_name_mapping)

# Filter the summary DataFrame to display only the 'poz' class
poz_summary_df = summary_df.query("Class == 'poz'")

# Display the filtered summary DataFrame
poz_summary_df
# Out:
#                 Classifier Class  Precision    Recall  F1-score  Support
# 1  Support Vector Mashines   poz   0.400000  0.538462  0.459016     26.0
# 3            Decision Tree   poz   0.229730  0.653846  0.340000     26.0
# 5            Random Forest   poz   0.428571  0.576923  0.491803     26.0
# 7           Neural Network   poz   0.421053  0.615385  0.500000     26.0

# %%
# Format table

poz_summary_df = poz_summary_df.round(2)
poz_summary_df = poz_summary_df.set_index('Classifier')
poz_summary_df = poz_summary_df.drop(['Support', "Class"], axis=1)
# poz_summary_df = poz_summary_df.style.highlight_max(subset=['Precision', 'Recall', 'F1-score'], color='green')
poz_summary_df.to_csv(f"{dir_path}/results_summary_df.csv")
poz_summary_df
# Out:
#                          Precision  Recall  F1-score
# Classifier
# Support Vector Mashines       0.40    0.54      0.46
# Decision Tree                 0.23    0.65      0.34
# Random Forest                 0.43    0.58      0.49
# Neural Network                0.42    0.62      0.50
