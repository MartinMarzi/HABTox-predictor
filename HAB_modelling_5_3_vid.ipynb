# %%
from datetime import datetime
import pandas as pd
import numpy as np
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from dtreeviz.trees import dtreeviz 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 30)

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")
data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
# data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    661
# salinity                 191
# T                        244
# SECCHI                   696
# DIN                      542
# PO4-P                    534
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
data.drop(columns=["Chl-a", "SECCHI", "DIN", "PO4-P"], inplace=True)#
data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# salinity                 191
# T                        244
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Modelling and Preliminary Results

# %% [markdown]
# ![Screenshot 2022-07-26 at 12.15.26.png](attachment:500d2dd5-b27f-4f67-a0a0-94d4c6fc8714.png)

# %% [markdown]
# # Scikit-learn Analysis

# %% [markdown]
# ### Preprocessing

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    839
# poz    114
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# Clean the dataset by removing samples close to the decision boundary. Because the dataset is heavily imbalanced in favor of clas 0 (neg) we will remove instances from this class whenever finding samples which do not agree “enough” with their neighboorhood. The _EditedNearestNeighbours_ will be used. One other option is to use Tomek links but it is more conservative and was found to perform slightly worse.

# %%
from collections import Counter
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours

print(f'Original dataset shape: {Counter(y)}')
usmp = EditedNearestNeighbours()
lastMajorityCount = Counter(y)[0]
for i in range(10):
    X_res, y_res = usmp.fit_resample(X, y)
    if Counter(y_res)[0] == lastMajorityCount:
        print('Cannot remove any more samples')
        break
    else:
        print(f'Resampled dataset shape {Counter(y_res)}')
        lastMajorityCount = Counter(y_res)[0]
    X = X_res
    y = y_res
# Out:
# Original dataset shape: Counter({0: 839, 1: 114})
# Resampled dataset shape Counter({0: 721, 1: 114})
# Resampled dataset shape Counter({0: 682, 1: 114})
# Resampled dataset shape Counter({0: 666, 1: 114})
# Resampled dataset shape Counter({0: 662, 1: 114})
# Cannot remove any more samples

# %% [markdown]
# ## Model Training and Evaluation

# %% [markdown]
# ### Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE()), 
    ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
               'clf__criterion': ['gini', 'entropy', 'log_loss'],
               'clf__class_weight': ['balanced', None],
               'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
               'under__sampling_strategy': [0.5, 0.6, 0.7],
               'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="recall",
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
#                                                                               100  \
# mean_fit_time                                                            0.015318
# std_fit_time                                                             0.000431
# mean_score_time                                                          0.007887
# std_score_time                                                           0.000151
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.826087
# split1_test_recall                                                       0.727273
# split2_test_recall                                                       0.869565
# split3_test_recall                                                       0.608696
# split4_test_recall                                                        0.73913
# mean_test_recall                                                          0.75415
# std_test_recall                                                          0.090112
# rank_test_recall                                                                1
# split0_test_precision                                                    0.372549
# split1_test_precision                                                    0.372093
# split2_test_precision                                                     0.31746
# split3_test_precision                                                         0.4
# split4_test_precision                                                    0.369565
# mean_test_precision                                                      0.366334
# std_test_precision                                                       0.026849
# rank_test_precision                                                           131
# split0_test_f1                                                           0.513514
# split1_test_f1                                                           0.492308
# split2_test_f1                                                           0.465116
# split3_test_f1                                                           0.482759
# split4_test_f1                                                           0.492754
# mean_test_f1                                                              0.48929
# std_test_f1                                                              0.015716
# rank_test_f1                                                                   87
# split0_test_roc_auc                                                      0.792743
# split1_test_roc_auc                                                      0.762133
# split2_test_roc_auc                                                      0.771904
# split3_test_roc_auc                                                      0.724802
# split4_test_roc_auc                                                      0.759717
# mean_test_roc_auc                                                         0.76226
# std_test_roc_auc                                                         0.022053
# rank_test_roc_auc                                                              19
#
#                                                                               47   \
# mean_fit_time                                                            0.016551
# std_fit_time                                                             0.001022
# mean_score_time                                                          0.008209
# std_score_time                                                           0.000716
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.782609
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.826087
# mean_test_recall                                                         0.727273
# std_test_recall                                                          0.087422
# rank_test_recall                                                                2
# split0_test_precision                                                    0.333333
# split1_test_precision                                                    0.285714
# split2_test_precision                                                    0.333333
# split3_test_precision                                                    0.311111
# split4_test_precision                                                        0.38
# mean_test_precision                                                      0.328698
# std_test_precision                                                       0.031086
# rank_test_precision                                                           157
# split0_test_f1                                                           0.467532
# split1_test_f1                                                           0.394366
# split2_test_f1                                                           0.467532
# split3_test_f1                                                           0.411765
# split4_test_f1                                                           0.520548
# mean_test_f1                                                             0.452349
# std_test_f1                                                              0.044992
# rank_test_f1                                                                  141
# split0_test_roc_auc                                                      0.755966
# split1_test_roc_auc                                                      0.686603
# split2_test_roc_auc                                                      0.754941
# split3_test_roc_auc                                                      0.686924
# split4_test_roc_auc                                                      0.795619
# mean_test_roc_auc                                                         0.73601
# std_test_roc_auc                                                         0.042803
# rank_test_roc_auc                                                              66
#
#                                                                               46   \
# mean_fit_time                                                            0.015623
# std_fit_time                                                             0.002709
# mean_score_time                                                          0.007648
# std_score_time                                                           0.000961
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.782609
# split1_test_recall                                                       0.590909
# split2_test_recall                                                       0.826087
# split3_test_recall                                                       0.695652
# split4_test_recall                                                        0.73913
# mean_test_recall                                                         0.726877
# std_test_recall                                                          0.080698
# rank_test_recall                                                                3
# split0_test_precision                                                    0.486486
# split1_test_precision                                                    0.361111
# split2_test_precision                                                    0.575758
# split3_test_precision                                                    0.340426
# split4_test_precision                                                    0.369565
# mean_test_precision                                                      0.426669
# std_test_precision                                                       0.090335
# rank_test_precision                                                            74
# split0_test_f1                                                                0.6
# split1_test_f1                                                           0.448276
# split2_test_f1                                                           0.678571
# split3_test_f1                                                           0.457143
# split4_test_f1                                                           0.492754
# mean_test_f1                                                             0.535349
# std_test_f1                                                              0.089671
# rank_test_f1                                                                   30
# split0_test_roc_auc                                                      0.819876
# split1_test_roc_auc                                                      0.708988
# split2_test_roc_auc                                                      0.860013
# split3_test_roc_auc                                                      0.730402
# split4_test_roc_auc                                                      0.759717
# mean_test_roc_auc                                                        0.775799
# std_test_roc_auc                                                         0.056246
# rank_test_roc_auc                                                               6
#
#                                                                               155  \
# mean_fit_time                                                            0.014972
# std_fit_time                                                             0.000224
# mean_score_time                                                           0.00782
# std_score_time                                                           0.000114
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.826087
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.695652
# mean_test_recall                                                         0.718577
# std_test_recall                                                          0.073963
# rank_test_recall                                                                4
# split0_test_precision                                                    0.395833
# split1_test_precision                                                    0.318182
# split2_test_precision                                                    0.272727
# split3_test_precision                                                    0.339623
# split4_test_precision                                                    0.421053
# mean_test_precision                                                      0.349484
# std_test_precision                                                       0.053365
# rank_test_precision                                                           143
# split0_test_f1                                                           0.535211
# split1_test_f1                                                           0.424242
# split2_test_f1                                                           0.384615
# split3_test_f1                                                           0.473684
# split4_test_f1                                                            0.52459
# mean_test_f1                                                             0.468469
# std_test_f1                                                              0.057652
# rank_test_f1                                                                  119
# split0_test_roc_auc                                                      0.804021
# split1_test_roc_auc                                                        0.7054
# split2_test_roc_auc                                                      0.674572
# split3_test_roc_auc                                                      0.758729
# split4_test_roc_auc                                                      0.764493
# mean_test_roc_auc                                                        0.741443
# std_test_roc_auc                                                         0.045863
# rank_test_roc_auc                                                              58
#
#                                                                               146  \
# mean_fit_time                                                            0.016545
# std_fit_time                                                             0.002272
# mean_score_time                                                          0.008466
# std_score_time                                                           0.000894
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.636364
# split2_test_recall                                                        0.73913
# split3_test_recall                                                       0.695652
# split4_test_recall                                                       0.782609
# mean_test_recall                                                         0.718577
# std_test_recall                                                          0.049456
# rank_test_recall                                                                4
# split0_test_precision                                                    0.395349
# split1_test_precision                                                    0.388889
# split2_test_precision                                                    0.333333
# split3_test_precision                                                         0.4
# split4_test_precision                                                    0.367347
# mean_test_precision                                                      0.376984
# std_test_precision                                                       0.024523
# rank_test_precision                                                           120
# split0_test_f1                                                           0.515152
# split1_test_f1                                                           0.482759
# split2_test_f1                                                           0.459459
# split3_test_f1                                                           0.507937
# split4_test_f1                                                                0.5
# mean_test_f1                                                             0.493061
# std_test_f1                                                              0.019963
# rank_test_f1                                                                   79
# split0_test_roc_auc                                                      0.771821
# split1_test_roc_auc                                                      0.735475
# split2_test_roc_auc                                                      0.740777
# split3_test_roc_auc                                                      0.756917
# split4_test_roc_auc                                                       0.77388
# mean_test_roc_auc                                                        0.755774
# std_test_roc_auc                                                         0.015643
# rank_test_roc_auc                                                              28
#
#                                                                               104  \
# mean_fit_time                                                             0.01564
# std_fit_time                                                             0.000501
# mean_score_time                                                          0.007505
# std_score_time                                                           0.000246
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.869565
# split1_test_recall                                                       0.545455
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.695652
# split4_test_recall                                                       0.782609
# mean_test_recall                                                         0.717787
# std_test_recall                                                          0.107626
# rank_test_recall                                                                6
# split0_test_precision                                                    0.416667
# split1_test_precision                                                    0.387097
# split2_test_precision                                                    0.432432
# split3_test_precision                                                    0.444444
# split4_test_precision                                                         0.4
# mean_test_precision                                                      0.416128
# std_test_precision                                                       0.020837
# rank_test_precision                                                            84
# split0_test_f1                                                            0.56338
# split1_test_f1                                                            0.45283
# split2_test_f1                                                           0.533333
# split3_test_f1                                                           0.542373
# split4_test_f1                                                           0.529412
# mean_test_f1                                                             0.524266
# std_test_f1                                                              0.037602
# rank_test_f1                                                                   40
# split0_test_roc_auc                                                      0.829519
# split1_test_roc_auc                                                      0.701299
# split2_test_roc_auc                                                      0.768281
# split3_test_roc_auc                                                      0.772069
# split4_test_roc_auc                                                      0.789032
# mean_test_roc_auc                                                         0.77204
# std_test_roc_auc                                                           0.0415
# rank_test_roc_auc                                                               8
#
#                                                                               137  \
# mean_fit_time                                                            0.014993
# std_fit_time                                                              0.00016
# mean_score_time                                                          0.007131
# std_score_time                                                           0.001198
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.545455
# split2_test_recall                                                       0.956522
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.782609
# mean_test_recall                                                         0.717787
# std_test_recall                                                          0.151412
# rank_test_recall                                                                6
# split0_test_precision                                                    0.361702
# split1_test_precision                                                    0.342857
# split2_test_precision                                                    0.468085
# split3_test_precision                                                    0.317073
# split4_test_precision                                                    0.346154
# mean_test_precision                                                      0.367174
# std_test_precision                                                       0.052452
# rank_test_precision                                                           130
# split0_test_f1                                                           0.485714
# split1_test_f1                                                           0.421053
# split2_test_f1                                                           0.628571
# split3_test_f1                                                            0.40625
# split4_test_f1                                                               0.48
# mean_test_f1                                                             0.484318
# std_test_f1                                                              0.078647
# rank_test_f1                                                                   94
# split0_test_roc_auc                                                      0.756783
# split1_test_roc_auc                                                      0.686261
# split2_test_roc_auc                                                      0.883564
# split3_test_roc_auc                                                      0.676548
# split4_test_roc_auc                                                      0.762516
# mean_test_roc_auc                                                        0.753135
# std_test_roc_auc                                                         0.074095
# rank_test_roc_auc                                                              33
#
#                                                                               101  \
# mean_fit_time                                                            0.016364
# std_fit_time                                                               0.0018
# mean_score_time                                                          0.009363
# std_score_time                                                           0.002076
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.782609
# split1_test_recall                                                       0.681818
# split2_test_recall                                                       0.869565
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.608696
# mean_test_recall                                                         0.710277
# std_test_recall                                                          0.102031
# rank_test_recall                                                                8
# split0_test_precision                                                    0.382979
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.425532
# split3_test_precision                                                    0.368421
# split4_test_precision                                                    0.341463
# mean_test_precision                                                      0.370346
# std_test_precision                                                       0.032903
# rank_test_precision                                                           126
# split0_test_f1                                                           0.514286
# split1_test_f1                                                           0.447761
# split2_test_f1                                                           0.571429
# split3_test_f1                                                           0.459016
# split4_test_f1                                                             0.4375
# mean_test_f1                                                             0.485998
# std_test_f1                                                              0.050281
# rank_test_f1                                                                   91
# split0_test_roc_auc                                                      0.782282
# split1_test_roc_auc                                                      0.728127
# split2_test_roc_auc                                                       0.83251
# split3_test_roc_auc                                                      0.713439
# split4_test_roc_auc                                                      0.702075
# mean_test_roc_auc                                                        0.751687
# std_test_roc_auc                                                         0.048883
# rank_test_roc_auc                                                              37
#
#                                                                               38   \
# mean_fit_time                                                            0.015611
# std_fit_time                                                             0.000346
# mean_score_time                                                            0.0078
# std_score_time                                                           0.000057
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.782609
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.826087
# mean_test_recall                                                         0.709881
# std_test_recall                                                          0.083233
# rank_test_recall                                                                9
# split0_test_precision                                                    0.428571
# split1_test_precision                                                    0.368421
# split2_test_precision                                                    0.340426
# split3_test_precision                                                    0.358974
# split4_test_precision                                                        0.38
# mean_test_precision                                                      0.375278
# std_test_precision                                                       0.029631
# rank_test_precision                                                           123
# split0_test_f1                                                           0.553846
# split1_test_f1                                                           0.466667
# split2_test_f1                                                           0.457143
# split3_test_f1                                                           0.451613
# split4_test_f1                                                           0.520548
# mean_test_f1                                                             0.489963
# std_test_f1                                                              0.040267
# rank_test_f1                                                                   86
# split0_test_roc_auc                                                      0.801079
# split1_test_roc_auc                                                      0.727956
# split2_test_roc_auc                                                      0.730402
# split3_test_roc_auc                                                      0.709651
# split4_test_roc_auc                                                      0.795619
# mean_test_roc_auc                                                        0.752941
# std_test_roc_auc                                                         0.037802
# rank_test_roc_auc                                                              35
#
#                                                                               122  \
# mean_fit_time                                                            0.017015
# std_fit_time                                                             0.000508
# mean_score_time                                                           0.00859
# std_score_time                                                             0.0006
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.913043
# split1_test_recall                                                       0.545455
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.565217
# split4_test_recall                                                        0.73913
# mean_test_recall                                                         0.709091
# std_test_recall                                                          0.138116
# rank_test_recall                                                               10
# split0_test_precision                                                        0.42
# split1_test_precision                                                    0.461538
# split2_test_precision                                                    0.461538
# split3_test_precision                                                    0.433333
# split4_test_precision                                                    0.459459
# mean_test_precision                                                      0.447174
# std_test_precision                                                       0.017284
# rank_test_precision                                                            57
# split0_test_f1                                                           0.575342
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.580645
# split3_test_f1                                                           0.490566
# split4_test_f1                                                           0.566667
# mean_test_f1                                                             0.542644
# std_test_f1                                                              0.039041
# rank_test_f1                                                                   20
# split0_test_roc_auc                                                      0.847499
# split1_test_roc_auc                                                      0.720096
# split2_test_roc_auc                                                      0.811759
# split3_test_roc_auc                                                      0.718215
# split4_test_roc_auc                                                      0.793808
# mean_test_roc_auc                                                        0.778275
# std_test_roc_auc                                                         0.051277
# rank_test_roc_auc                                                               3
#
#                                                                               64   \
# mean_fit_time                                                             0.01608
# std_fit_time                                                             0.000371
# mean_score_time                                                          0.007662
# std_score_time                                                           0.000204
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.826087
# split3_test_recall                                                       0.478261
# split4_test_recall                                                       0.826087
# mean_test_recall                                                         0.701186
# std_test_recall                                                          0.131558
# rank_test_recall                                                               11
# split0_test_precision                                                    0.369565
# split1_test_precision                                                    0.341463
# split2_test_precision                                                    0.372549
# split3_test_precision                                                    0.323529
# split4_test_precision                                                    0.404255
# mean_test_precision                                                      0.362272
# std_test_precision                                                       0.027768
# rank_test_precision                                                           135
# split0_test_f1                                                           0.492754
# split1_test_f1                                                           0.444444
# split2_test_f1                                                           0.513514
# split3_test_f1                                                           0.385965
# split4_test_f1                                                           0.542857
# mean_test_f1                                                             0.475907
# std_test_f1                                                              0.055245
# rank_test_f1                                                                  108
# split0_test_roc_auc                                                      0.760543
# split1_test_roc_auc                                                      0.716678
# split2_test_roc_auc                                                      0.791831
# split3_test_roc_auc                                                      0.652009
# split4_test_roc_auc                                                      0.806983
# mean_test_roc_auc                                                        0.745609
# std_test_roc_auc                                                         0.056079
# rank_test_roc_auc                                                              49
#
#                                                                               11   \
# mean_fit_time                                                            0.016427
# std_fit_time                                                             0.001248
# mean_score_time                                                           0.00794
# std_score_time                                                           0.000261
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.869565
# split1_test_recall                                                       0.545455
# split2_test_recall                                                        0.73913
# split3_test_recall                                                       0.695652
# split4_test_recall                                                       0.652174
# mean_test_recall                                                         0.700395
# std_test_recall                                                          0.106276
# rank_test_recall                                                               12
# split0_test_precision                                                    0.425532
# split1_test_precision                                                    0.324324
# split2_test_precision                                                    0.354167
# split3_test_precision                                                    0.372093
# split4_test_precision                                                    0.340909
# mean_test_precision                                                      0.363405
# std_test_precision                                                       0.034796
# rank_test_precision                                                           134
# split0_test_f1                                                           0.571429
# split1_test_f1                                                            0.40678
# split2_test_f1                                                           0.478873
# split3_test_f1                                                           0.484848
# split4_test_f1                                                           0.447761
# mean_test_f1                                                             0.477938
# std_test_f1                                                              0.054338
# rank_test_f1                                                                  104
# split0_test_roc_auc                                                      0.833279
# split1_test_roc_auc                                                      0.678742
# split2_test_roc_auc                                                      0.752141
# split3_test_roc_auc                                                      0.745553
# split4_test_roc_auc                                                      0.716238
# mean_test_roc_auc                                                        0.745191
# std_test_roc_auc                                                         0.051111
# rank_test_roc_auc                                                              51
#
#                                                                               126  \
# mean_fit_time                                                            0.015432
# std_fit_time                                                             0.000437
# mean_score_time                                                          0.007733
# std_score_time                                                            0.00024
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.782609
# split1_test_recall                                                            0.5
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.826087
# mean_test_recall                                                              0.7
# std_test_recall                                                          0.124806
# rank_test_recall                                                               13
# split0_test_precision                                                    0.409091
# split1_test_precision                                                    0.354839
# split2_test_precision                                                    0.391304
# split3_test_precision                                                    0.538462
# split4_test_precision                                                    0.513514
# mean_test_precision                                                      0.441442
# std_test_precision                                                       0.071649
# rank_test_precision                                                            62
# split0_test_f1                                                           0.537313
# split1_test_f1                                                           0.415094
# split2_test_f1                                                           0.521739
# split3_test_f1                                                           0.571429
# split4_test_f1                                                           0.633333
# mean_test_f1                                                             0.535782
# std_test_f1                                                              0.071487
# rank_test_f1                                                                   29
# split0_test_roc_auc                                                       0.79356
# split1_test_roc_auc                                                      0.674812
# split2_test_roc_auc                                                      0.785244
# split3_test_roc_auc                                                      0.758893
# split4_test_roc_auc                                                      0.844862
# mean_test_roc_auc                                                        0.771474
# std_test_roc_auc                                                         0.055794
# rank_test_roc_auc                                                              10
#
#                                                                               20   \
# mean_fit_time                                                             0.01569
# std_fit_time                                                             0.000151
# mean_score_time                                                          0.007965
# ...
# split0_test_f1                                                           0.529412
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.407407
# split3_test_f1                                                           0.418605
# split4_test_f1                                                               0.55
# mean_test_f1                                                             0.461085
# std_test_f1                                                              0.064795
# rank_test_f1                                                                  134
# split0_test_roc_auc                                                      0.789801
# split1_test_roc_auc                                                      0.651914
# split2_test_roc_auc                                                      0.663373
# split3_test_roc_auc                                                      0.653986
# split4_test_roc_auc                                                      0.716403
# mean_test_roc_auc                                                        0.695095
# std_test_roc_auc                                                         0.052885
# rank_test_roc_auc                                                             153
#
#                                                                               3    \
# mean_fit_time                                                            0.018508
# std_fit_time                                                             0.001736
# mean_score_time                                                          0.008311
# std_score_time                                                           0.000778
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.409091
# split2_test_recall                                                       0.565217
# split3_test_recall                                                       0.347826
# split4_test_recall                                                       0.608696
# mean_test_recall                                                         0.507905
# std_test_recall                                                           0.10862
# rank_test_recall                                                              158
# split0_test_precision                                                    0.636364
# split1_test_precision                                                         0.5
# split2_test_precision                                                    0.433333
# split3_test_precision                                                    0.347826
# split4_test_precision                                                    0.466667
# mean_test_precision                                                      0.476838
# std_test_precision                                                       0.094472
# rank_test_precision                                                            32
# split0_test_f1                                                           0.622222
# split1_test_f1                                                               0.45
# split2_test_f1                                                           0.490566
# split3_test_f1                                                           0.347826
# split4_test_f1                                                           0.528302
# mean_test_f1                                                             0.487783
# std_test_f1                                                              0.090265
# rank_test_f1                                                                   88
# split0_test_roc_auc                                                      0.774273
# split1_test_roc_auc                                                      0.670711
# split2_test_roc_auc                                                      0.718215
# split3_test_roc_auc                                                      0.617095
# split4_test_roc_auc                                                      0.743742
# mean_test_roc_auc                                                        0.704807
# std_test_roc_auc                                                         0.055457
# rank_test_roc_auc                                                             145
#
#                                                                               34   \
# mean_fit_time                                                            0.018401
# std_fit_time                                                             0.000874
# mean_score_time                                                          0.008348
# std_score_time                                                           0.000724
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.826087
# split1_test_recall                                                       0.318182
# split2_test_recall                                                       0.565217
# split3_test_recall                                                       0.434783
# split4_test_recall                                                       0.391304
# mean_test_recall                                                         0.507115
# std_test_recall                                                          0.178583
# rank_test_recall                                                              160
# split0_test_precision                                                    0.678571
# split1_test_precision                                                    0.466667
# split2_test_precision                                                    0.433333
# split3_test_precision                                                    0.416667
# split4_test_precision                                                    0.310345
# mean_test_precision                                                      0.461117
# std_test_precision                                                       0.120663
# rank_test_precision                                                            45
# split0_test_f1                                                           0.745098
# split1_test_f1                                                           0.378378
# split2_test_f1                                                           0.490566
# split3_test_f1                                                           0.425532
# split4_test_f1                                                           0.346154
# mean_test_f1                                                             0.477146
# std_test_f1                                                              0.142518
# rank_test_f1                                                                  107
# split0_test_roc_auc                                                      0.879209
# split1_test_roc_auc                                                      0.629016
# split2_test_roc_auc                                                      0.718215
# split3_test_roc_auc                                                      0.664361
# split4_test_roc_auc                                                      0.619895
# mean_test_roc_auc                                                        0.702139
# std_test_roc_auc                                                         0.095027
# rank_test_roc_auc                                                             148
#
#                                                                               87   \
# mean_fit_time                                                            0.016921
# std_fit_time                                                             0.000117
# mean_score_time                                                           0.00739
# std_score_time                                                           0.000067
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.363636
# split2_test_recall                                                       0.565217
# split3_test_recall                                                       0.478261
# split4_test_recall                                                       0.478261
# mean_test_recall                                                         0.498814
# std_test_recall                                                          0.084382
# rank_test_recall                                                              161
# split0_test_precision                                                    0.608696
# split1_test_precision                                                    0.666667
# split2_test_precision                                                    0.419355
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.458333
# mean_test_precision                                                       0.53061
# std_test_precision                                                       0.092895
# rank_test_precision                                                             8
# split0_test_f1                                                           0.608696
# split1_test_f1                                                           0.470588
# split2_test_f1                                                           0.481481
# split3_test_f1                                                           0.488889
# split4_test_f1                                                           0.468085
# mean_test_f1                                                             0.503548
# std_test_f1                                                              0.053107
# rank_test_f1                                                                   62
# split0_test_roc_auc                                                      0.770513
# split1_test_roc_auc                                                      0.666781
# split2_test_roc_auc                                                      0.714427
# split3_test_roc_auc                                                      0.697464
# split4_test_roc_auc                                                      0.689888
# mean_test_roc_auc                                                        0.707814
# std_test_roc_auc                                                         0.034892
# rank_test_roc_auc                                                             139
#
#                                                                               14
# mean_fit_time                                                            0.017328
# std_fit_time                                                             0.001373
# mean_score_time                                                          0.008695
# std_score_time                                                           0.000982
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.363636
# split2_test_recall                                                       0.434783
# split3_test_recall                                                       0.391304
# split4_test_recall                                                       0.652174
# mean_test_recall                                                         0.490119
# std_test_recall                                                          0.117598
# rank_test_recall                                                              162
# split0_test_precision                                                    0.451613
# split1_test_precision                                                    0.210526
# split2_test_precision                                                    0.238095
# split3_test_precision                                                        0.36
# split4_test_precision                                                    0.357143
# mean_test_precision                                                      0.323475
# std_test_precision                                                       0.088243
# rank_test_precision                                                           161
# split0_test_f1                                                           0.518519
# split1_test_f1                                                           0.266667
# split2_test_f1                                                           0.307692
# split3_test_f1                                                              0.375
# split4_test_f1                                                           0.461538
# mean_test_f1                                                             0.385883
# std_test_f1                                                              0.093553
# rank_test_f1                                                                  162
# split0_test_roc_auc                                                      0.740438
# split1_test_roc_auc                                                      0.569036
# split2_test_roc_auc                                                      0.596179
# split3_test_roc_auc                                                      0.635046
# split4_test_roc_auc                                                      0.723814
# mean_test_roc_auc                                                        0.652903
# std_test_roc_auc                                                         0.068207
# rank_test_roc_auc                                                             162
#
# [42 rows x 162 columns]

# %%
clf = gscv.best_estimator_.steps[2][1]
viz = dtreeviz(clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"],
             fancy=False,
               scale=1.5
              )
viz

# %%
from sklearn import tree
plt.figure(figsize=(60, 30))
_=tree.plot_tree(clf, feature_names=X.columns, class_names=[str(_) for _ in [0,1]], filled=True, fontsize=15)

# %% [markdown]
# ### Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', RandomForestClassifier())
])

parameters = {
              'clf__n_estimators': [100,300,500],
              'clf__criterion': ['gini', 'entropy', 'log_loss'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
              'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
              'under__sampling_strategy': [0.5, 0.6, 0.7],
              'smt__k_neighbors': [3, 5]
             }

nfolds = 5
scores = ['recall', 'precision', 'f1', 'roc_auc']
refit_score = 'f1'
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit=refit_score,
                    n_jobs=-1)
resultsGSCV = gscv.fit(X, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
pd.set_option("display.max_rows", None)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
#                                                                                14  \
# mean_fit_time                                                            0.197924
# std_fit_time                                                             0.008941
# mean_score_time                                                          0.034882
# std_score_time                                                           0.000347
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.681818
# split2_test_recall                                                       0.913043
# split3_test_recall                                                       0.565217
# split4_test_recall                                                        0.73913
# mean_test_recall                                                         0.692885
# std_test_recall                                                          0.129096
# rank_test_recall                                                                1
# split0_test_precision                                                    0.684211
# split1_test_precision                                                    0.576923
# split2_test_precision                                                    0.777778
# split3_test_precision                                                    0.565217
# split4_test_precision                                                    0.515152
# mean_test_precision                                                      0.623856
# std_test_precision                                                       0.094649
# rank_test_precision                                                            17
# split0_test_f1                                                           0.619048
# split1_test_f1                                                              0.625
# split2_test_f1                                                               0.84
# split3_test_f1                                                           0.565217
# split4_test_f1                                                           0.607143
# mean_test_f1                                                             0.651282
# std_test_f1                                                              0.096643
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.867931
# split1_test_roc_auc                                                      0.909262
# split2_test_roc_auc                                                       0.97859
# split3_test_roc_auc                                                      0.871377
# split4_test_roc_auc                                                      0.910903
# mean_test_roc_auc                                                        0.907612
# std_test_roc_auc                                                         0.039847
# rank_test_roc_auc                                                               9
#
#                                                                                11  \
# mean_fit_time                                                            0.184627
# std_fit_time                                                             0.002193
# mean_score_time                                                          0.038659
# std_score_time                                                           0.003938
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.727273
# split2_test_recall                                                       0.826087
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.695652
# mean_test_recall                                                         0.684585
# std_test_recall                                                          0.091625
# rank_test_recall                                                                2
# split0_test_precision                                                        0.65
# split1_test_precision                                                    0.533333
# split2_test_precision                                                     0.59375
# split3_test_precision                                                    0.466667
# split4_test_precision                                                    0.888889
# mean_test_precision                                                      0.626528
# std_test_precision                                                       0.144706
# rank_test_precision                                                            15
# split0_test_f1                                                           0.604651
# split1_test_f1                                                           0.615385
# split2_test_f1                                                           0.690909
# split3_test_f1                                                           0.528302
# split4_test_f1                                                           0.780488
# mean_test_f1                                                             0.643947
# std_test_f1                                                              0.085537
# rank_test_f1                                                                   15
# split0_test_roc_auc                                                      0.831481
# split1_test_roc_auc                                                       0.89337
# split2_test_roc_auc                                                      0.940053
# split3_test_roc_auc                                                      0.809289
# split4_test_roc_auc                                                      0.926054
# mean_test_roc_auc                                                        0.880049
# std_test_roc_auc                                                         0.051498
# rank_test_roc_auc                                                              18
#
#                                                                                2   \
# mean_fit_time                                                            0.187726
# std_fit_time                                                             0.005905
# mean_score_time                                                          0.035833
# std_score_time                                                           0.000533
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.826087
# split3_test_recall                                                       0.608696
# split4_test_recall                                                        0.73913
# mean_test_recall                                                         0.675099
# std_test_recall                                                          0.094743
# rank_test_recall                                                                3
# split0_test_precision                                                    0.684211
# split1_test_precision                                                        0.56
# split2_test_precision                                                    0.527778
# split3_test_precision                                                    0.538462
# split4_test_precision                                                    0.607143
# mean_test_precision                                                      0.583519
# std_test_precision                                                       0.057249
# rank_test_precision                                                            18
# split0_test_f1                                                           0.619048
# split1_test_f1                                                           0.595745
# split2_test_f1                                                           0.644068
# split3_test_f1                                                           0.571429
# split4_test_f1                                                           0.666667
# mean_test_f1                                                             0.619391
# std_test_f1                                                              0.033775
# rank_test_f1                                                                   17
# split0_test_roc_auc                                                      0.889343
# split1_test_roc_auc                                                       0.86244
# split2_test_roc_auc                                                      0.922925
# split3_test_roc_auc                                                      0.858531
# split4_test_roc_auc                                                      0.902833
# mean_test_roc_auc                                                        0.887214
# std_test_roc_auc                                                         0.024332
# rank_test_roc_auc                                                              15
#
#                                                                                0   \
# mean_fit_time                                                            0.206726
# std_fit_time                                                             0.034802
# mean_score_time                                                          0.040449
# std_score_time                                                           0.004577
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                       0.681818
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.695652
# mean_test_recall                                                         0.649407
# std_test_recall                                                          0.101863
# rank_test_recall                                                                4
# split0_test_precision                                                      0.6875
# split1_test_precision                                                       0.625
# split2_test_precision                                                        0.75
# split3_test_precision                                                         0.7
# split4_test_precision                                                        0.64
# mean_test_precision                                                        0.6805
# std_test_precision                                                       0.044677
# rank_test_precision                                                            12
# split0_test_f1                                                           0.564103
# split1_test_f1                                                           0.652174
# split2_test_f1                                                           0.765957
# split3_test_f1                                                           0.651163
# split4_test_f1                                                           0.666667
# mean_test_f1                                                             0.660013
# std_test_f1                                                              0.064198
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                       0.86744
# split1_test_roc_auc                                                      0.882433
# split2_test_roc_auc                                                      0.977108
# split3_test_roc_auc                                                      0.847661
# split4_test_roc_auc                                                      0.939065
# mean_test_roc_auc                                                        0.902742
# std_test_roc_auc                                                         0.048046
# rank_test_roc_auc                                                              13
#
#                                                                                8   \
# mean_fit_time                                                            0.204457
# std_fit_time                                                             0.001861
# mean_score_time                                                          0.035966
# std_score_time                                                           0.000258
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.826087
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.652174
# mean_test_recall                                                         0.649012
# std_test_recall                                                          0.099347
# rank_test_recall                                                                5
# split0_test_precision                                                         0.8
# split1_test_precision                                                    0.736842
# split2_test_precision                                                    0.791667
# split3_test_precision                                                    0.736842
# split4_test_precision                                                    0.652174
# mean_test_precision                                                      0.743505
# std_test_precision                                                       0.052804
# rank_test_precision                                                             8
# split0_test_f1                                                           0.631579
# split1_test_f1                                                           0.682927
# split2_test_f1                                                           0.808511
# split3_test_f1                                                           0.666667
# split4_test_f1                                                           0.652174
# mean_test_f1                                                             0.688371
# std_test_f1                                                              0.062402
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.861066
# split1_test_roc_auc                                                      0.936432
# split2_test_roc_auc                                                      0.980731
# split3_test_roc_auc                                                      0.881258
# split4_test_roc_auc                                                      0.900692
# mean_test_roc_auc                                                        0.912036
# std_test_roc_auc                                                         0.042398
# rank_test_roc_auc                                                               5
#
#                                                                                1   \
# mean_fit_time                                                            0.214906
# std_fit_time                                                             0.023227
# mean_score_time                                                          0.037168
# std_score_time                                                           0.002287
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.652174
# mean_test_recall                                                         0.649012
# std_test_recall                                                          0.082736
# rank_test_recall                                                                5
# split0_test_precision                                                    0.631579
# split1_test_precision                                                    0.538462
# split2_test_precision                                                        0.75
# split3_test_precision                                                    0.535714
# split4_test_precision                                                    0.833333
# mean_test_precision                                                      0.657818
# std_test_precision                                                       0.117598
# rank_test_precision                                                            13
# split0_test_f1                                                           0.571429
# split1_test_f1                                                           0.583333
# split2_test_f1                                                           0.765957
# split3_test_f1                                                           0.588235
# split4_test_f1                                                           0.731707
# mean_test_f1                                                             0.648132
# std_test_f1                                                              0.083111
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.842432
# split1_test_roc_auc                                                       0.88944
# split2_test_roc_auc                                                      0.940711
# split3_test_roc_auc                                                      0.837286
# split4_test_roc_auc                                                      0.918643
# mean_test_roc_auc                                                        0.885702
# std_test_roc_auc                                                         0.040845
# rank_test_roc_auc                                                              17
#
#                                                                                5   \
# mean_fit_time                                                            0.196768
# std_fit_time                                                             0.006088
# mean_score_time                                                          0.035659
# std_score_time                                                           0.000565
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.681818
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.608696
# mean_test_recall                                                         0.640711
# std_test_recall                                                          0.082763
# rank_test_recall                                                                7
# split0_test_precision                                                    0.764706
# split1_test_precision                                                    0.652174
# split2_test_precision                                                    0.857143
# split3_test_precision                                                        0.65
# split4_test_precision                                                    0.933333
# mean_test_precision                                                      0.771471
# std_test_precision                                                       0.111868
# rank_test_precision                                                             4
# split0_test_f1                                                               0.65
# split1_test_f1                                                           0.666667
# split2_test_f1                                                           0.818182
# split3_test_f1                                                           0.604651
# split4_test_f1                                                           0.736842
# mean_test_f1                                                             0.695268
# std_test_f1                                                              0.074719
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.873488
# split1_test_roc_auc                                                      0.915414
# split2_test_roc_auc                                                      0.972003
# split3_test_roc_auc                                                      0.862484
# split4_test_roc_auc                                                      0.917655
# mean_test_roc_auc                                                        0.908209
# std_test_roc_auc                                                         0.038748
# rank_test_roc_auc                                                               7
#
#                                                                                10  \
# mean_fit_time                                                             0.18482
# std_fit_time                                                             0.003197
# mean_score_time                                                          0.035785
# std_score_time                                                           0.001125
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.545455
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.565217
# split4_test_recall                                                        0.73913
# mean_test_recall                                                         0.639526
# std_test_recall                                                          0.100286
# rank_test_recall                                                                8
# split0_test_precision                                                    0.722222
# split1_test_precision                                                         0.6
# split2_test_precision                                                         0.9
# split3_test_precision                                                    0.464286
# split4_test_precision                                                    0.894737
# mean_test_precision                                                      0.716249
# std_test_precision                                                       0.168913
# rank_test_precision                                                            10
# split0_test_f1                                                           0.634146
# split1_test_f1                                                           0.571429
# split2_test_f1                                                           0.837209
# split3_test_f1                                                           0.509804
# split4_test_f1                                                           0.809524
# mean_test_f1                                                             0.672422
# std_test_f1                                                              0.129662
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.868094
# split1_test_roc_auc                                                      0.868421
# split2_test_roc_auc                                                      0.958333
# split3_test_roc_auc                                                      0.830534
# split4_test_roc_auc                                                      0.905797
# mean_test_roc_auc                                                        0.886236
# std_test_roc_auc                                                         0.043197
# rank_test_roc_auc                                                              16
#
#                                                                                13  \
# mean_fit_time                                                            0.217321
# std_fit_time                                                             0.012238
# mean_score_time                                                          0.035675
# std_score_time                                                            0.00051
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.681818
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.608696
# mean_test_recall                                                         0.632016
# std_test_recall                                                          0.049152
# rank_test_recall                                                                9
# split0_test_precision                                                    0.722222
# split1_test_precision                                                    0.555556
# split2_test_precision                                                    0.761905
# split3_test_precision                                                    0.466667
# split4_test_precision                                                    0.736842
# mean_test_precision                                                      0.648638
# std_test_precision                                                       0.116449
# rank_test_precision                                                            14
# split0_test_f1                                                           0.634146
# split1_test_f1                                                           0.612245
# split2_test_f1                                                           0.727273
# split3_test_f1                                                           0.528302
# split4_test_f1                                                           0.666667
# mean_test_f1                                                             0.633727
# std_test_f1                                                               0.06544
# rank_test_f1                                                                   16
# split0_test_roc_auc                                                      0.881007
# split1_test_roc_auc                                                      0.915414
# split2_test_roc_auc                                                      0.974802
# split3_test_roc_auc                                                      0.839756
# split4_test_roc_auc                                                      0.909091
# mean_test_roc_auc                                                        0.904014
# std_test_roc_auc                                                         0.044329
# rank_test_roc_auc                                                              12
#
#                                                                                4   \
# mean_fit_time                                                            0.194153
# std_fit_time                                                             0.001729
# mean_score_time                                                           0.03698
# std_score_time                                                           0.002722
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.681818
# split2_test_recall                                                       0.826087
# split3_test_recall                                                       0.521739
# split4_test_recall                                                       0.565217
# mean_test_recall                                                          0.62332
# std_test_recall                                                          0.117089
# rank_test_recall                                                               10
# split0_test_precision                                                    0.666667
# split1_test_precision                                                        0.75
# split2_test_precision                                                    0.904762
# split3_test_precision                                                        0.48
# split4_test_precision                                                    0.866667
# mean_test_precision                                                      0.733619
# std_test_precision                                                       0.152358
# rank_test_precision                                                             9
# split0_test_f1                                                           0.585366
# split1_test_f1                                                           0.714286
# split2_test_f1                                                           0.863636
# split3_test_f1                                                                0.5
# split4_test_f1                                                           0.684211
# mean_test_f1                                                               0.6695
# std_test_f1                                                              0.123061
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.871527
# split1_test_roc_auc                                                      0.905673
# split2_test_roc_auc                                                      0.978755
# split3_test_roc_auc                                                      0.819993
# split4_test_roc_auc                                                      0.928689
# mean_test_roc_auc                                                        0.900927
# std_test_roc_auc                                                         0.053414
# rank_test_roc_auc                                                              14
#
#                                                                                12  \
# mean_fit_time                                                            0.212575
# std_fit_time                                                             0.005246
# mean_score_time                                                          0.037703
# std_score_time                                                           0.001263
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.826087
# split3_test_recall                                                       0.478261
# split4_test_recall                                                       0.608696
# mean_test_recall                                                         0.614229
# std_test_recall                                                          0.120371
# rank_test_recall                                                               11
# split0_test_precision                                                    0.857143
# split1_test_precision                                                         0.7
# split2_test_precision                                                    0.863636
# split3_test_precision                                                    0.611111
# split4_test_precision                                                    0.823529
# mean_test_precision                                                      0.771084
# std_test_precision                                                       0.099365
# rank_test_precision                                                             5
# split0_test_f1                                                           0.648649
# split1_test_f1                                                           0.666667
# split2_test_f1                                                           0.844444
# split3_test_f1                                                           0.536585
# split4_test_f1                                                                0.7
# mean_test_f1                                                             0.679269
# std_test_f1                                                              0.099164
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.873815
# split1_test_roc_auc                                                       0.90892
# split2_test_roc_auc                                                      0.976779
# split3_test_roc_auc                                                      0.833004
# split4_test_roc_auc                                                      0.943841
# mean_test_roc_auc                                                        0.907272
# std_test_roc_auc                                                         0.050609
# rank_test_roc_auc                                                              10
#
#                                                                                9   \
# mean_fit_time                                                            0.185554
# std_fit_time                                                             0.003683
# mean_score_time                                                          0.036538
# std_score_time                                                           0.000763
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.565217
# mean_test_recall                                                         0.614229
# std_test_recall                                                           0.09187
# rank_test_recall                                                               12
# split0_test_precision                                                    0.521739
# split1_test_precision                                                    0.583333
# split2_test_precision                                                        0.75
# split3_test_precision                                                         0.5
# split4_test_precision                                                    0.764706
# mean_test_precision                                                      0.623956
# std_test_precision                                                       0.112393
# rank_test_precision                                                            16
# split0_test_f1                                                           0.521739
# split1_test_f1                                                           0.608696
# split2_test_f1                                                           0.765957
# split3_test_f1                                                           0.530612
# split4_test_f1                                                               0.65
# mean_test_f1                                                             0.615401
# std_test_f1                                                              0.089298
# rank_test_f1                                                                   18
# split0_test_roc_auc                                                      0.886728
# split1_test_roc_auc                                                      0.892686
# split2_test_roc_auc                                                      0.966238
# split3_test_roc_auc                                                      0.847003
# split4_test_roc_auc                                                      0.932806
# mean_test_roc_auc                                                        0.905092
# std_test_roc_auc                                                         0.040921
# rank_test_roc_auc                                                              11
#
#                                                                                17  \
# mean_fit_time                                                            0.197998
# std_fit_time                                                             0.034025
# mean_score_time                                                          0.026463
# std_score_time                                                           0.005586
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.590909
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.652174
# mean_test_recall                                                         0.605138
# std_test_recall                                                          0.061898
# rank_test_recall                                                               13
# split0_test_precision                                                        0.75
# split1_test_precision                                                    0.619048
# split2_test_precision                                                    0.761905
# split3_test_precision                                                        0.52
# split4_test_precision                                                    0.833333
# mean_test_precision                                                      0.696857
# std_test_precision                                                       0.112262
# rank_test_precision                                                            11
# split0_test_f1                                                           0.615385
# split1_test_f1                                                           0.604651
# split2_test_f1                                                           0.727273
# split3_test_f1                                                           0.541667
# split4_test_f1                                                           0.731707
# mean_test_f1                                                             0.644136
# std_test_f1                                                              0.074116
# rank_test_f1                                                                   14
# split0_test_roc_auc                                                       0.85796
# split1_test_roc_auc                                                      0.927375
# split2_test_roc_auc                                                      0.967227
# split3_test_roc_auc                                                       0.86693
# split4_test_roc_auc                                                      0.920125
# mean_test_roc_auc                                                        0.907923
# std_test_roc_auc                                                         0.040548
# rank_test_roc_auc                                                               8
#
#                                                                                7   \
# mean_fit_time                                                            0.215674
# std_fit_time                                                             0.004705
# mean_score_time                                                          0.035299
# std_score_time                                                           0.000591
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.545455
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.565217
# mean_test_recall                                                         0.604743
# std_test_recall                                                          0.093401
# rank_test_recall                                                               14
# split0_test_precision                                                    0.857143
# split1_test_precision                                                    0.666667
# split2_test_precision                                                    0.782609
# split3_test_precision                                                         0.7
# split4_test_precision                                                    0.722222
# mean_test_precision                                                      0.745728
# std_test_precision                                                       0.067332
# rank_test_precision                                                             7
# split0_test_f1                                                           0.648649
# split1_test_f1                                                                0.6
# split2_test_f1                                                           0.782609
# split3_test_f1                                                           0.651163
# split4_test_f1                                                           0.634146
# mean_test_f1                                                             0.663313
# std_test_f1                                                              0.062375
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.872671
# split1_test_roc_auc                                                      0.922591
# split2_test_roc_auc                                                      0.977273
# split3_test_roc_auc                                                      0.880929
# split4_test_roc_auc                                                      0.948287
# mean_test_roc_auc                                                         0.92035
# std_test_roc_auc                                                         0.039631
# rank_test_roc_auc                                                               3
#
#                                                                                15  \
# mean_fit_time                                                            0.213607
# std_fit_time                                                             0.001878
# mean_score_time                                                          0.035888
# std_score_time                                                           0.000557
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                       0.681818
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.478261
# split4_test_recall                                                       0.652174
# mean_test_recall                                                         0.597233
# std_test_recall                                                          0.098151
# rank_test_recall                                                               15
# split0_test_precision                                                    0.916667
# split1_test_precision                                                    0.833333
# split2_test_precision                                                    0.941176
# split3_test_precision                                                    0.785714
# split4_test_precision                                                         1.0
# mean_test_precision                                                      0.895378
# std_test_precision                                                       0.076645
# rank_test_precision                                                             2
# split0_test_f1                                                           0.628571
# split1_test_f1                                                               0.75
# split2_test_f1                                                                0.8
# split3_test_f1                                                           0.594595
# split4_test_f1                                                           0.789474
# mean_test_f1                                                             0.712528
# std_test_f1                                                              0.084774
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                       0.88117
# split1_test_roc_auc                                                      0.935578
# split2_test_roc_auc                                                      0.983202
# split3_test_roc_auc                                                      0.870553
# split4_test_roc_auc                                                      0.928524
# mean_test_roc_auc                                                        0.919805
# std_test_roc_auc                                                          0.04065
# rank_test_roc_auc                                                               4
#
#                                                                                16  \
# mean_fit_time                                                            0.218747
# std_fit_time                                                             0.013077
# mean_score_time                                                           0.04075
# std_score_time                                                           0.008274
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'smt__k_neighbors': 5, 'smt__sampling_strateg...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.590909
# split2_test_recall                                                        0.73913
# split3_test_recall                                                       0.521739
# split4_test_recall                                                       0.608696
# mean_test_recall                                                         0.596443
# std_test_recall                                                          0.079626
# rank_test_recall                                                               16
# split0_test_precision                                                        0.75
# split1_test_precision                                                        0.65
# split2_test_precision                                                    0.944444
# split3_test_precision                                                        0.75
# split4_test_precision                                                    0.933333
# mean_test_precision                                                      0.805556
# std_test_precision                                                       0.114881
# rank_test_precision                                                             3
# split0_test_f1                                                           0.615385
# split1_test_f1                                                           0.619048
# split2_test_f1                                                           0.829268
# split3_test_f1                                                           0.615385
# split4_test_f1                                                           0.736842
# mean_test_f1                                                             0.683185
# std_test_f1                                                              0.086633
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.899314
# split1_test_roc_auc                                                      0.927546
# split2_test_roc_auc                                                      0.975955
# split3_test_roc_auc                                                      0.884058
# split4_test_roc_auc                                                      0.945158
# mean_test_roc_auc                                                        0.926406
# std_test_roc_auc                                                         0.032666
# rank_test_roc_auc                                                               1
#
#                                                                                6   \
# mean_fit_time                                                            0.221423
# std_fit_time                                                             0.003997
# mean_score_time                                                          0.035447
# std_score_time                                                           0.000674
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.636364
# split2_test_recall                                                       0.695652
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.608696
# mean_test_recall                                                         0.588142
# std_test_recall                                                           0.08758
# rank_test_recall                                                               17
# split0_test_precision                                                         1.0
# split1_test_precision                                                    0.777778
# split2_test_precision                                                         1.0
# split3_test_precision                                                      0.8125
# split4_test_precision                                                    0.933333
# mean_test_precision                                                      0.904722
# std_test_precision                                                       0.093375
# rank_test_precision                                                             1
# split0_test_f1                                                           0.606061
# split1_test_f1                                                                0.7
# split2_test_f1                                                           0.820513
# split3_test_f1                                                           0.666667
# split4_test_f1                                                           0.736842
# mean_test_f1                                                             0.706016
# std_test_f1                                                              0.071604
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.891141
# split1_test_roc_auc                                                      0.937799
# split2_test_roc_auc                                                      0.981555
# split3_test_roc_auc                                                      0.884058
# split4_test_roc_auc                                                      0.930336
# mean_test_roc_auc                                                        0.924978
# std_test_roc_auc                                                         0.035252
# rank_test_roc_auc                                                               2
#
#                                                                                3
# mean_fit_time                                                             0.19965
# std_fit_time                                                              0.00139
# mean_score_time                                                           0.03562
# std_score_time                                                           0.000552
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'smt__k_neighbors': 3, 'smt__sampling_strateg...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.590909
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.478261
# split4_test_recall                                                       0.608696
# mean_test_recall                                                         0.579051
# std_test_recall                                                          0.121183
# rank_test_recall                                                               18
# split0_test_precision                                                    0.714286
# split1_test_precision                                                    0.684211
# split2_test_precision                                                    0.857143
# split3_test_precision                                                    0.647059
# split4_test_precision                                                       0.875
# mean_test_precision                                                       0.75554
# std_test_precision                                                         0.0929
# rank_test_precision                                                             6
# split0_test_f1                                                           0.540541
# split1_test_f1                                                           0.634146
# split2_test_f1                                                           0.818182
# split3_test_f1                                                               0.55
# split4_test_f1                                                           0.717949
# mean_test_f1                                                             0.652163
# std_test_f1                                                              0.104987
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.860412
# split1_test_roc_auc                                                      0.901401
# split2_test_roc_auc                                                      0.986001
# split3_test_roc_auc                                                      0.847003
# split4_test_roc_auc                                                      0.962615
# mean_test_roc_auc                                                        0.911486
# std_test_roc_auc                                                         0.054836
# rank_test_roc_auc                                                               6

# %% [markdown]
# Plot the mean ROC curve of the algorithm with best performing parameter selection. We will perform CV once again and plot the ROC curve for each fold and compute and plot the mean.

# %%
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=nfolds, shuffle=True)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X, y)):
    classifier.fit(X.iloc[train], y[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X.iloc[test],
        y[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the mean precision-recall curve. The approach is the same as for the mean ROC curve.

# %%
from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=nfolds, shuffle=True)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X, y)):
    classifier.fit(X.iloc[train], y[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X.iloc[test],
        y[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

rf = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf, X, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
# Out:
# Text(0.5, 1.0, 'Permutation Importance Random Forest')

# %%
# Get feature importance with SHAP
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)
RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

# one-hot encoding of month feature
Xohe = pd.get_dummies(X, columns=["month"])

X_display = Xohe.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xohe)
Xsc = pd.DataFrame(scaled_array, columns=Xohe.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE()),
    ('under', RandomUnderSampler()),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.4, 0.5, 0.6],
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
             }
nfolds = 5
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "recall")
resultsGSCV = gscv.fit(Xsc, y)
results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_recall']).transpose())
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#                                                                               11   \
# mean_fit_time                                                            0.338831
# std_fit_time                                                             0.186256
# mean_score_time                                                          0.011273
# std_score_time                                                           0.000848
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.818182
# mean_test_recall                                                         0.702767
# std_test_recall                                                          0.072253
# rank_test_recall                                                                1
# split0_test_precision                                                    0.242857
# split1_test_precision                                                    0.253968
# split2_test_precision                                                    0.208955
# split3_test_precision                                                    0.483871
# split4_test_precision                                                     0.26087
# mean_test_precision                                                      0.290104
# std_test_precision                                                       0.098512
# rank_test_precision                                                            58
# split0_test_f1                                                           0.365591
# split1_test_f1                                                           0.372093
# split2_test_f1                                                           0.311111
# split3_test_f1                                                           0.555556
# split4_test_f1                                                           0.395604
# mean_test_f1                                                             0.399991
# std_test_f1                                                               0.08256
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.700311
# split1_test_roc_auc                                                      0.788561
# split2_test_roc_auc                                                      0.690864
# split3_test_roc_auc                                                      0.759438
# split4_test_roc_auc                                                      0.803571
# mean_test_roc_auc                                                        0.748549
# std_test_roc_auc                                                          0.04561
# rank_test_roc_auc                                                              14
#
#                                                                               176  \
# mean_fit_time                                                            0.635115
# std_fit_time                                                             0.289213
# mean_score_time                                                          0.016027
# std_score_time                                                           0.001821
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                        0.73913
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.782609
# split4_test_recall                                                       0.727273
# mean_test_recall                                                         0.667194
# std_test_recall                                                          0.110655
# rank_test_recall                                                                2
# split0_test_precision                                                    0.244444
# split1_test_precision                                                    0.217949
# split2_test_precision                                                    0.194444
# split3_test_precision                                                    0.216867
# split4_test_precision                                                    0.253968
# mean_test_precision                                                      0.225535
# std_test_precision                                                       0.021285
# rank_test_precision                                                           182
# split0_test_f1                                                           0.323529
# split1_test_f1                                                           0.336634
# split2_test_f1                                                           0.294737
# split3_test_f1                                                           0.339623
# split4_test_f1                                                           0.376471
# mean_test_f1                                                             0.334199
# std_test_f1                                                              0.026432
# rank_test_f1                                                                  113
# split0_test_roc_auc                                                       0.72619
# split1_test_roc_auc                                                      0.711827
# split2_test_roc_auc                                                      0.640528
# split3_test_roc_auc                                                      0.722598
# split4_test_roc_auc                                                      0.772863
# mean_test_roc_auc                                                        0.714801
# std_test_roc_auc                                                         0.042631
# rank_test_roc_auc                                                              62
#
#                                                                               140  \
# mean_fit_time                                                            0.566947
# std_fit_time                                                             0.185876
# mean_score_time                                                          0.012195
# std_score_time                                                           0.000362
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.565217
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.521739
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.658893
# std_test_recall                                                          0.119179
# rank_test_recall                                                                3
# split0_test_precision                                                    0.282609
# split1_test_precision                                                    0.297872
# split2_test_precision                                                     0.20339
# split3_test_precision                                                    0.263889
# split4_test_precision                                                    0.333333
# mean_test_precision                                                      0.276219
# std_test_precision                                                        0.04296
# rank_test_precision                                                            91
# split0_test_f1                                                           0.376812
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.292683
# split3_test_f1                                                                0.4
# split4_test_f1                                                           0.465753
# mean_test_f1                                                              0.38705
# std_test_f1                                                              0.055749
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.697723
# split1_test_roc_auc                                                      0.762034
# split2_test_roc_auc                                                      0.716097
# split3_test_roc_auc                                                      0.824525
# split4_test_roc_auc                                                      0.855249
# mean_test_roc_auc                                                        0.771126
# std_test_roc_auc                                                         0.060707
# rank_test_roc_auc                                                               2
#
#                                                                               169  \
# mean_fit_time                                                            0.905704
# std_fit_time                                                             0.440312
# mean_score_time                                                          0.015444
# std_score_time                                                           0.003267
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.869565
# split2_test_recall                                                       0.478261
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.636364
# mean_test_recall                                                         0.649012
# std_test_recall                                                          0.132028
# rank_test_recall                                                                4
# split0_test_precision                                                    0.231884
# split1_test_precision                                                    0.273973
# split2_test_precision                                                       0.275
# split3_test_precision                                                    0.288889
# split4_test_precision                                                    0.194444
# mean_test_precision                                                      0.252838
# std_test_precision                                                       0.034889
# rank_test_precision                                                           136
# split0_test_f1                                                           0.347826
# split1_test_f1                                                           0.416667
# split2_test_f1                                                           0.349206
# split3_test_f1                                                           0.382353
# split4_test_f1                                                           0.297872
# mean_test_f1                                                             0.358785
# std_test_f1                                                              0.039568
# rank_test_f1                                                                   49
# split0_test_roc_auc                                                      0.704451
# split1_test_roc_auc                                                       0.79529
# split2_test_roc_auc                                                      0.634576
# split3_test_roc_auc                                                      0.667274
# split4_test_roc_auc                                                      0.731466
# mean_test_roc_auc                                                        0.706611
# std_test_roc_auc                                                         0.055178
# rank_test_roc_auc                                                              93
#
#                                                                               56   \
# mean_fit_time                                                            0.326287
# std_fit_time                                                             0.142526
# mean_score_time                                                          0.011822
# std_score_time                                                           0.002299
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.347826
# split1_test_recall                                                       0.652174
# split2_test_recall                                                       0.782609
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.641502
# std_test_recall                                                          0.157229
# rank_test_recall                                                                5
# split0_test_precision                                                        0.32
# split1_test_precision                                                    0.234375
# split2_test_precision                                                    0.135338
# split3_test_precision                                                    0.306122
# split4_test_precision                                                    0.242857
# mean_test_precision                                                      0.247739
# std_test_precision                                                       0.065523
# rank_test_precision                                                           148
# split0_test_f1                                                           0.333333
# split1_test_f1                                                           0.344828
# split2_test_f1                                                           0.230769
# split3_test_f1                                                           0.416667
# split4_test_f1                                                           0.369565
# mean_test_f1                                                             0.339032
# std_test_f1                                                              0.061231
# rank_test_f1                                                                  100
# split0_test_roc_auc                                                      0.648292
# split1_test_roc_auc                                                      0.737578
# split2_test_roc_auc                                                      0.557324
# split3_test_roc_auc                                                      0.723249
# split4_test_roc_auc                                                      0.789502
# mean_test_roc_auc                                                        0.691189
# std_test_roc_auc                                                         0.080753
# rank_test_roc_auc                                                             130
#
#                                                                               68   \
# mean_fit_time                                                            0.557746
# std_fit_time                                                              0.30272
# mean_score_time                                                          0.011145
# std_score_time                                                           0.000835
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                        0.73913
# split1_test_recall                                                       0.521739
# split2_test_recall                                                       0.391304
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.909091
# mean_test_recall                                                         0.633992
# std_test_recall                                                          0.178253
# rank_test_recall                                                                6
# split0_test_precision                                                    0.283333
# split1_test_precision                                                    0.196721
# split2_test_precision                                                     0.28125
# split3_test_precision                                                    0.205882
# split4_test_precision                                                    0.178571
# mean_test_precision                                                      0.229152
# std_test_precision                                                       0.044275
# rank_test_precision                                                           176
# split0_test_f1                                                           0.409639
# split1_test_f1                                                           0.285714
# split2_test_f1                                                           0.327273
# split3_test_f1                                                           0.307692
# split4_test_f1                                                           0.298507
# mean_test_f1                                                             0.325765
# std_test_f1                                                               0.04407
# rank_test_f1                                                                  138
# split0_test_roc_auc                                                      0.736672
# split1_test_roc_auc                                                        0.6897
# split2_test_roc_auc                                                      0.609472
# split3_test_roc_auc                                                      0.755793
# split4_test_roc_auc                                                      0.682089
# mean_test_roc_auc                                                        0.694745
# std_test_roc_auc                                                         0.050876
# rank_test_roc_auc                                                             123
#
#                                                                               155  \
# mean_fit_time                                                            0.619021
# std_fit_time                                                             0.303946
# mean_score_time                                                          0.010797
# std_score_time                                                           0.000181
# param_clf__hidden_layer_sizes                                                (3,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'over__k_nei...
# split0_test_recall                                                       0.521739
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.521739
# split4_test_recall                                                       0.772727
# mean_test_recall                                                         0.632806
# std_test_recall                                                          0.098564
# rank_test_recall                                                                7
# split0_test_precision                                                    0.171429
# split1_test_precision                                                    0.207792
# split2_test_precision                                                    0.170455
# split3_test_precision                                                    0.210526
# split4_test_precision                                                    0.377778
# mean_test_precision                                                      0.227596
# std_test_precision                                                       0.077017
# rank_test_precision                                                           178
# split0_test_f1                                                           0.258065
# split1_test_f1                                                               0.32
# split2_test_f1                                                            0.27027
# split3_test_f1                                                                0.3
# split4_test_f1                                                           0.507463
# mean_test_f1                                                             0.331159
# std_test_f1                                                              0.090806
# rank_test_f1                                                                  121
# split0_test_roc_auc                                                       0.64868
# split1_test_roc_auc                                                      0.721144
# split2_test_roc_auc                                                       0.66382
# split3_test_roc_auc                                                      0.650612
# split4_test_roc_auc                                                      0.803301
# mean_test_roc_auc                                                        0.697511
# std_test_roc_auc                                                         0.059109
# rank_test_roc_auc                                                             120
#
#                                                                               172  \
# mean_fit_time                                                             0.80413
# std_fit_time                                                             0.500972
# mean_score_time                                                          0.011441
# std_score_time                                                           0.000332
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.608696
# split2_test_recall                                                       0.565217
# split3_test_recall                                                            1.0
# split4_test_recall                                                       0.545455
# mean_test_recall                                                          0.63083
# std_test_recall                                                           0.19329
# rank_test_recall                                                                8
# split0_test_precision                                                    0.294118
# split1_test_precision                                                    0.212121
# split2_test_precision                                                    0.142857
# split3_test_precision                                                    0.255556
# split4_test_precision                                                    0.285714
# mean_test_precision                                                      0.238073
# std_test_precision                                                       0.055598
# rank_test_precision                                                           163
# split0_test_f1                                                           0.350877
# split1_test_f1                                                           0.314607
# split2_test_f1                                                            0.22807
# split3_test_f1                                                            0.40708
# split4_test_f1                                                              0.375
# mean_test_f1                                                             0.335127
# std_test_f1                                                              0.061477
# rank_test_f1                                                                  110
# split0_test_roc_auc                                                      0.670549
# split1_test_roc_auc                                                      0.671325
# split2_test_roc_auc                                                      0.622024
# split3_test_roc_auc                                                      0.842489
# split4_test_roc_auc                                                      0.757711
# mean_test_roc_auc                                                        0.712819
# std_test_roc_auc                                                         0.078207
# rank_test_roc_auc                                                              71
#
#                                                                               201  \
# mean_fit_time                                                            0.722012
# std_fit_time                                                             0.278137
# mean_score_time                                                          0.011903
# std_score_time                                                           0.000566
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.521739
# split2_test_recall                                                       0.652174
# split3_test_recall                                                       0.434783
# split4_test_recall                                                       0.863636
# mean_test_recall                                                         0.616206
# std_test_recall                                                          0.144506
# rank_test_recall                                                                9
# split0_test_precision                                                     0.27451
# split1_test_precision                                                    0.342857
# split2_test_precision                                                        0.25
# split3_test_precision                                                    0.357143
# split4_test_precision                                                    0.271429
# mean_test_precision                                                      0.299188
# std_test_precision                                                       0.042579
# rank_test_precision                                                            38
# split0_test_f1                                                           0.378378
# split1_test_f1                                                           0.413793
# split2_test_f1                                                           0.361446
# split3_test_f1                                                           0.392157
# split4_test_f1                                                           0.413043
# mean_test_f1                                                             0.391764
# std_test_f1                                                              0.020182
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                        0.6897
# split1_test_roc_auc                                                      0.732919
# split2_test_roc_auc                                                       0.71131
# split3_test_roc_auc                                                      0.691356
# split4_test_roc_auc                                                      0.831034
# mean_test_roc_auc                                                        0.731264
# std_test_roc_auc                                                         0.052297
# rank_test_roc_auc                                                              23
#
#                                                                               206  \
# mean_fit_time                                                            1.011142
# std_fit_time                                                             0.552178
# mean_score_time                                                          0.012748
# std_score_time                                                           0.003434
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3, 3), 'over__k_n...
# split0_test_recall                                                       0.652174
# split1_test_recall                                                        0.73913
# split2_test_recall                                                       0.391304
# split3_test_recall                                                       0.565217
# split4_test_recall                                                       0.727273
# mean_test_recall                                                          0.61502
# std_test_recall                                                          0.127995
# rank_test_recall                                                               10
# split0_test_precision                                                    0.319149
# split1_test_precision                                                    0.232877
# split2_test_precision                                                    0.155172
# split3_test_precision                                                        0.26
# split4_test_precision                                                    0.242424
# mean_test_precision                                                      0.241924
# std_test_precision                                                       0.052723
# rank_test_precision                                                           154
# split0_test_f1                                                           0.428571
# split1_test_f1                                                           0.354167
# split2_test_f1                                                           0.222222
# split3_test_f1                                                           0.356164
# split4_test_f1                                                           0.363636
# mean_test_f1                                                             0.344952
# std_test_f1                                                              0.067253
# rank_test_f1                                                                   89
# split0_test_roc_auc                                                      0.754658
# split1_test_roc_auc                                                      0.778468
# split2_test_roc_auc                                                      0.620342
# split3_test_roc_auc                                                      0.672351
# split4_test_roc_auc                                                      0.744859
# mean_test_roc_auc                                                        0.714136
# std_test_roc_auc                                                         0.058767
# rank_test_roc_auc                                                              64
#
#                                                                               31   \
# mean_fit_time                                                            0.367437
# std_fit_time                                                             0.204256
# mean_score_time                                                          0.011686
# std_score_time                                                           0.001068
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.695652
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.608696
# split4_test_recall                                                       0.454545
# mean_test_recall                                                         0.612648
# std_test_recall                                                          0.088099
# rank_test_recall                                                               11
# split0_test_precision                                                    0.262295
# split1_test_precision                                                    0.271186
# split2_test_precision                                                    0.133333
# split3_test_precision                                                    0.378378
# split4_test_precision                                                    0.384615
# mean_test_precision                                                      0.285962
# std_test_precision                                                        0.09203
# rank_test_precision                                                            69
# split0_test_f1                                                           0.380952
# split1_test_f1                                                           0.390244
# split2_test_f1                                                            0.21875
# split3_test_f1                                                           0.466667
# split4_test_f1                                                           0.416667
# mean_test_f1                                                             0.374656
# std_test_f1                                                              0.083451
# rank_test_f1                                                                   24
# split0_test_roc_auc                                                       0.73499
# split1_test_roc_auc                                                      0.749224
# split2_test_roc_auc                                                      0.558359
# split3_test_roc_auc                                                      0.817235
# split4_test_roc_auc                                                      0.787338
# mean_test_roc_auc                                                        0.729429
# std_test_roc_auc                                                         0.090278
# rank_test_roc_auc                                                              32
#
#                                                                               85   \
# mean_fit_time                                                            0.349852
# std_fit_time                                                             0.124553
# mean_score_time                                                          0.012104
# std_score_time                                                           0.002245
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.695652
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.590909
# mean_test_recall                                                         0.596443
# std_test_recall                                                          0.088615
# rank_test_recall                                                               12
# split0_test_precision                                                     0.47619
# split1_test_precision                                                    0.313725
# split2_test_precision                                                    0.164706
# split3_test_precision                                                    0.223881
# split4_test_precision                                                    0.282609
# mean_test_precision                                                      0.292222
# std_test_precision                                                       0.105195
# rank_test_precision                                                            51
# split0_test_f1                                                           0.454545
# split1_test_f1                                                           0.432432
# split2_test_f1                                                           0.259259
# split3_test_f1                                                           0.333333
# split4_test_f1                                                           0.382353
# mean_test_f1                                                             0.372385
# std_test_f1                                                              0.070396
# rank_test_f1                                                                   29
# split0_test_roc_auc                                                      0.691511
# split1_test_roc_auc                                                      0.787008
# split2_test_roc_auc                                                      0.612836
# split3_test_roc_auc                                                      0.698516
# split4_test_roc_auc                                                      0.727002
# mean_test_roc_auc                                                        0.703375
# std_test_roc_auc                                                         0.056417
# rank_test_roc_auc                                                             103
#
#                                                                               48   \
# mean_fit_time                                                            0.422261
# std_fit_time                                                             0.223223
# mean_score_time                                                          0.010691
# std_score_time                                                            0.00041
# param_clf__hidden_layer_sizes                                                (2,)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2,), 'over__k_nei...
# split0_test_recall                                                       0.434783
# split1_test_recall                                                       0.347826
# split2_test_recall                                                       0.434783
# split3_test_recall                                                       0.826087
# split4_test_recall                                                       0.909091
# mean_test_recall                                                         0.590514
# std_test_recall                                                          0.229951
# rank_test_recall                                                               13
# split0_test_precision                                                         0.4
# split1_test_precision                                                    0.242424
# split2_test_precision                                                    0.185185
# split3_test_precision                                                    0.296875
# split4_test_precision                                                    0.217391
# mean_test_precision                                                      0.268375
# std_test_precision                                                       0.075274
# rank_test_precision                                                           111
# split0_test_f1                                                           0.416667
# split1_test_f1                                                           0.285714
# split2_test_f1                                                            0.25974
# split3_test_f1                                                           0.436782
# split4_test_f1                                                           0.350877
# mean_test_f1                                                             0.349956
# std_test_f1                                                               0.06965
# rank_test_f1                                                                   74
# split0_test_roc_auc                                                      0.703546
# split1_test_roc_auc                                                      0.652174
# split2_test_roc_auc                                                      0.598732
# split3_test_roc_auc                                                       0.83611
# split4_test_roc_auc                                                      0.741883
# mean_test_roc_auc                                                        0.706489
# std_test_roc_auc                                                         0.080777
# rank_test_roc_auc                                                              94
#
#                                                                               55   \
# mean_fit_time                                                            0.492791
# std_fit_time                                                             0.154395
# mean_score_time                                                          0.010591
# std_score_time                                                           0.000117
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.608696
# split1_test_recall                                                       0.434783
# split2_test_recall                                                       0.608696
# split3_test_recall                                                       0.478261
# split4_test_recall                                                       0.818182
# mean_test_recall                                                         0.589723
# std_test_recall                                                          0.133674
# ...
# split4_test_precision                                                       0.275
# mean_test_precision                                                      0.166544
# std_test_precision                                                       0.096885
# rank_test_precision                                                           210
# split0_test_f1                                                           0.311688
# split1_test_f1                                                                0.0
# split2_test_f1                                                           0.179775
# split3_test_f1                                                           0.235294
# split4_test_f1                                                           0.354839
# mean_test_f1                                                             0.216319
# std_test_f1                                                              0.123913
# rank_test_f1                                                                  212
# split0_test_roc_auc                                                       0.71558
# split1_test_roc_auc                                                      0.521739
# split2_test_roc_auc                                                      0.493271
# split3_test_roc_auc                                                      0.636553
# split4_test_roc_auc                                                        0.7546
# mean_test_roc_auc                                                        0.624349
# std_test_roc_auc                                                         0.103099
# rank_test_roc_auc                                                             209
#
#                                                                               91   \
# mean_fit_time                                                            0.325165
# std_fit_time                                                             0.180116
# mean_score_time                                                          0.012013
# std_score_time                                                           0.001825
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                        0.26087
# split2_test_recall                                                       0.304348
# split3_test_recall                                                            0.0
# split4_test_recall                                                       0.545455
# mean_test_recall                                                         0.317787
# std_test_recall                                                          0.190784
# rank_test_recall                                                              213
# split0_test_precision                                                        0.25
# split1_test_precision                                                    0.222222
# split2_test_precision                                                    0.225806
# split3_test_precision                                                         0.0
# split4_test_precision                                                    0.266667
# mean_test_precision                                                      0.192939
# std_test_precision                                                       0.097831
# rank_test_precision                                                           207
# split0_test_f1                                                           0.328358
# split1_test_f1                                                               0.24
# split2_test_f1                                                           0.259259
# split3_test_f1                                                                0.0
# split4_test_f1                                                           0.358209
# mean_test_f1                                                             0.237165
# std_test_f1                                                              0.126263
# rank_test_f1                                                                  210
# split0_test_roc_auc                                                      0.677536
# split1_test_roc_auc                                                      0.615683
# split2_test_roc_auc                                                      0.568582
# split3_test_roc_auc                                                           0.5
# split4_test_roc_auc                                                      0.686418
# mean_test_roc_auc                                                        0.609644
# std_test_roc_auc                                                         0.069639
# rank_test_roc_auc                                                             213
#
#                                                                               93   \
# mean_fit_time                                                            0.248037
# std_fit_time                                                             0.165112
# mean_score_time                                                          0.011576
# std_score_time                                                           0.002199
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.478261
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# split3_test_recall                                                       0.652174
# split4_test_recall                                                       0.363636
# mean_test_recall                                                         0.298814
# std_test_recall                                                          0.260709
# rank_test_recall                                                              214
# split0_test_precision                                                    0.164179
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# split3_test_precision                                                    0.151515
# split4_test_precision                                                    0.296296
# mean_test_precision                                                      0.122398
# std_test_precision                                                       0.112068
# rank_test_precision                                                           215
# split0_test_f1                                                           0.244444
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# split3_test_f1                                                           0.245902
# split4_test_f1                                                           0.326531
# mean_test_f1                                                             0.163375
# std_test_f1                                                              0.136664
# rank_test_f1                                                                  215
# split0_test_roc_auc                                                       0.65722
# split1_test_roc_auc                                                           0.5
# split2_test_roc_auc                                                      0.497024
# split3_test_roc_auc                                                      0.651783
# split4_test_roc_auc                                                      0.760011
# mean_test_roc_auc                                                        0.613208
# std_test_roc_auc                                                         0.101283
# rank_test_roc_auc                                                             212
#
#                                                                               106  \
# mean_fit_time                                                            0.450552
# std_fit_time                                                             0.270485
# mean_score_time                                                          0.012053
# std_score_time                                                           0.001782
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         6
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                            0.0
# split1_test_recall                                                       0.347826
# split2_test_recall                                                       0.217391
# split3_test_recall                                                       0.043478
# split4_test_recall                                                       0.727273
# mean_test_recall                                                         0.267194
# std_test_recall                                                          0.261571
# rank_test_recall                                                              215
# split0_test_precision                                                         0.0
# split1_test_precision                                                        0.32
# split2_test_precision                                                         0.2
# split3_test_precision                                                    0.041667
# split4_test_precision                                                    0.149533
# mean_test_precision                                                       0.14224
# std_test_precision                                                       0.114311
# rank_test_precision                                                           214
# split0_test_f1                                                                0.0
# split1_test_f1                                                           0.333333
# split2_test_f1                                                           0.208333
# split3_test_f1                                                           0.042553
# split4_test_f1                                                           0.248062
# mean_test_f1                                                             0.166456
# std_test_f1                                                              0.125953
# rank_test_f1                                                                  214
# split0_test_roc_auc                                                           0.5
# split1_test_roc_auc                                                      0.625388
# split2_test_roc_auc                                                      0.554089
# split3_test_roc_auc                                                      0.576412
# split4_test_roc_auc                                                      0.636905
# mean_test_roc_auc                                                        0.578559
# std_test_roc_auc                                                         0.049744
# rank_test_roc_auc                                                             216
#
#                                                                               82
# mean_fit_time                                                            0.459867
# std_fit_time                                                             0.513262
# mean_score_time                                                           0.01319
# std_score_time                                                           0.001081
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'over__k_n...
# split0_test_recall                                                       0.391304
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# split3_test_recall                                                            0.0
# split4_test_recall                                                       0.863636
# mean_test_recall                                                         0.250988
# std_test_recall                                                          0.341764
# rank_test_recall                                                              216
# split0_test_precision                                                     0.28125
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# split3_test_precision                                                         0.0
# split4_test_precision                                                    0.202128
# mean_test_precision                                                      0.096676
# std_test_precision                                                       0.121018
# rank_test_precision                                                           216
# split0_test_f1                                                           0.327273
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# split3_test_f1                                                                0.0
# split4_test_f1                                                           0.327586
# mean_test_f1                                                             0.130972
# std_test_f1                                                              0.160407
# rank_test_f1                                                                  216
# split0_test_roc_auc                                                      0.638199
# split1_test_roc_auc                                                      0.494048
# split2_test_roc_auc                                                      0.633023
# split3_test_roc_auc                                                           0.5
# split4_test_roc_auc                                                      0.780574
# mean_test_roc_auc                                                        0.609169
# std_test_roc_auc                                                         0.105794
# rank_test_roc_auc                                                             214
#
# [41 rows x 216 columns]

# %% [markdown]
# #### Feature Importance (MLP)

# %%
# Feature importance of model (MLP)  (no cross-validation!)

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=3)

MLP = gscv.best_estimator_.steps[2][1]

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(MLP, Xsc, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = Xsc.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance MLP")
# Out:
# Text(0.5, 1.0, 'Permutation Importance MLP')

# %% [markdown]
# #### Feature importance with SHAP

# %%
X = Xsc.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.25)

nn = MLPClassifier(hidden_layer_sizes=(3,3), solver='lbfgs', max_iter=5000)
model = nn.fit(X_train.to_numpy(), y_train)

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# explain the model's predictions using SHAP
import shap
import warnings
warnings.filterwarnings("ignore")
shap.initjs()

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,20))
shap_values = explainer.shap_values(X_test, nsamples=50)
shap.summary_plot(shap_values, X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
#   0%|          | 0/239 [00:00<?, ?it/s]

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X_test,50))
shap_values = explainer.shap_values(X_test, nsamples=50)
for classid in [0,1]:
    shap.summary_plot(shap_values[classid], X_test, max_display=len(X.columns), class_names=le.classes_)
# Out:
#   0%|          | 0/239 [00:00<?, ?it/s]

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
instanceID = 10
instance = X.iloc[[instanceID]]
display_instance = X_display.iloc[[instanceID]]

prediction = model.predict(instance)[0]
prediction_probs = model.predict_proba(instance)[0]
print(f'real value: {y[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(model.predict_proba, shap.sample(X, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)
# Out:
# real value: 1,
# predicted: 0,
# predicted probs: [0.95424595 0.04575405]
# Explanation for prediction: class=0, p=0.9542459536480314
#   0%|          | 0/1 [00:00<?, ?it/s]
# <div id='i0KMNGDU3GST6I6W2HNU0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.9240527114070525, "outValue": 0.9542459536480314, "link": "identity", "featureNames": ["DSP", "Dinophysis caudata", "Dinophysis fortii", "Phalacroma rotundatum", "Dinophysis sacculus", "Dinophysis tripos", "sun [h]", "air temp", "wind strength", "precipitation", "salinity", "T", "Soca", "month_1", "month_2", "month_3", "month_4", "month_5", "month_6", "month_7", "month_8", "month_9", "month_10", "month_11", "month_12"], "features": {"0": {"effect": -0.04972470620550876, "value": 216.0}, "1": {"effect": -0.07063837796440565, "value": 92.0}, "2": {"effect": -0.0451061594752663, "value": 111.0}, "3": {"effect": 0.020336063714273843, "value": 13.0}, "6": {"effect": -0.06085312046314814, "value": 103.40000000000002}, "8": {"effect": 0.054463460345376184, "value": 2.704761904761905}, "9": {"effect": 0.046951718853104646, "value": 219.9}, "10": {"effect": 0.09003012983406525, "value": 37.39}, "11": {"effect": 0.08089277755286356, "value": 21.73}, "12": {"effect": 0.012715924760225338, "value": 1852.896}, "15": {"effect": 0.006262075421995153, "value": 0.0}, "16": {"effect": -0.024700500056539114, "value": 0.0}, "17": {"effect": -0.021904773212085286, "value": 0.0}, "18": {"effect": -0.012366428904895404, "value": 0.0}, "19": {"effect": 0.021556480193429164, "value": 0.0}, "21": {"effect": -0.025613061197695734, "value": 1.0}, "23": {"effect": 0.007891739045190228, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i0KMNGDU3GST6I6W2HNU0')
#   );
# </script>

# %% [markdown]
# Show the mean values of features as it may help understanding this particular instance data in the plot above.

# %%
data = pd.get_dummies(df_cons_SL_l, columns=["month"])


pd.DataFrame([data[data['lipophylic_toxins']=='neg'].mean(), data[data['lipophylic_toxins']=='poz'].mean()], index=['neg','pos']).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 data = pd.get_dummies(df_cons_SL_l, columns=["month"])
#       4 pd.DataFrame([data[data['lipophylic_toxins']=='neg'].mean(), data[data['lipophylic_toxins']=='poz'].mean()], index=['neg','pos']).T
#
# NameError: name 'df_cons_SL_l' is not defined

# %% [markdown]
# ### Conclusion

# %%
# Summary table of prediction results
RF_recall = round(RF_recall_best_k[1], 2)
RF_auc = round(RF_auc_best_k[1], 2)
MLP_recall = round(MLP_recall_best_k[1], 2)
MLP_auc = round(MLP_auc_best_k[1], 2)

summary = pd.DataFrame(
    [
        (
            "RF",
            RF_recall_score,
            RF_auc_score,
        ),
        (
            "MLP",
            MLP_recall_score,
            MLP_auc_score,
        ),
        (
            "RF (smote)",
            RF_recall,
            RF_auc,
        ),
        (
            "MLP (smote)",
            MLP_recall,
            MLP_auc,
        ),
        (
            "Decision tree (J48)*",
            0.56,
            0.18,
        ),
    ],
    columns=("Model", "Recall", "ROC AUC"),
).set_index("Model")

print("Table summarising the prediction results of the used classifiers, both with and without SMOTE resampling:\n")
summary.round(2)
# Out:
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/mmarzi/.pyenv/versions/3.8.0/envs/hab/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# As can be seen resampling with SMOTE helped to improve the results substantially, especially when calculating recall. The highest recall and ROC AUC was achieved with Random Forest with the re-sampled data. Both recall and ROC AUC suggest Random Forest as beeing the better classifier for this particular problem. Recall is a crucial metric as it gives indication of what fraction of true positive instances have been predicted. Since the models predict toxins in seashells (food) it is crucial that as few positives as possible are missed.
#
# Due to the use of SMOTE resampling (upsampling and downsampling) in combinaiton with cross-validation it was curcial to do the resampling within each fold to avoid data lekeage and validate on original (unsampled) data. In addition, I have optimised the model with regard to the k-values of SMOTE, all of which brought along some complexity. So for the parameter tuning of Random Forest and MLP various parameter settings have been tried  and the model with best performing settings has been chosen.
#
# The decision tree J48 algorithm was run within Weka on a slightly different dataset (missing values were not removed to use as many instances as possible, cross validation was 10-fold as opposed to 3-fold due to a higher dataset etc.) thus this results are not directly comparable but were provided as a reference to give an indication of the performance of this algorithm.
#
# As can be seen in the feature importance bar plots above, similar features were on the top despite using two different classification algorithms and two different feature ranking methods. If we consider just the three highest-ranking features of each of the feature ranking methods for both algortihms (RF and MLP) the features that overlap are DSP, DSP_like, ASP, Dinophysis fortii and Dinophysis caudata. These can be shown to the domain experts for validation and interpretation.
