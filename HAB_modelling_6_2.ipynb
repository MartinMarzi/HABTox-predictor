# %%
from datetime import datetime
import pandas as pd
import numpy as np
import os
import pickle
from dateutil.parser import parse
import datetime
from dateutil.parser import parse
import math
from numpy import mean

from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV, cross_validate, StratifiedKFold
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline as SKLpipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC 
from sklearn.tree import export_text
from dtreeviz.trees import dtreeviz 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as IMBLpipeline

from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

import ipynbname
notebook_name = ipynbname.name()

import seaborn as sns

pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 35)

# %%
# Define directory path name and timestamp

# Get the current date and time as a string
timestamp = datetime.datetime.now().strftime('%d%m%Y_%H%M')

# Construct the directory path with the models folder and timestamp
dir_path = f"models/{timestamp}"
    
# Create the directory if it doesn't exist
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

# %%
# read df pickle
df_alg = pd.read_pickle("objects/df_alg-HAB_preprocessing_5_1")
# data = pd.read_pickle("data/preprocessed/hab_org-data-HAB_part2-preprocessing-5_2")
data = pd.read_pickle("data/preprocessed/hab_interp_data-HAB_part2-preprocessing-5_2")

data.drop(columns=["sampling station", "date"], inplace=True)
# data.set_index('date', inplace=True)


# slice by station and time
# data = data[data["sampling station"] == "Debeli_rtic"].loc["2008-01-01" : "2021-12-31"]

data.isnull().sum()
# Out:
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# SECCHI                   450
# DIN                      352
# PO4-P                    349
# Soca                       0
# month                      0
# lipophylic_toxins        320
# dtype: int64

# %%
# Class distribution
data["lipophylic_toxins"].value_counts(dropna=False)
# Out:
# neg    996
# NaN    320
# poz    136
# Name: lipophylic_toxins, dtype: int64

# %%
# move month to first place
cols = data.columns.tolist()  # Get a list of column names
cols = [cols[-2]] + cols[:-2] + [cols[-1]]  # Move the one before the last column to the first position
data = data[cols]

# %%
# data.drop(columns=["Chl-a","PO4-P","DIN","SECCHI"], inplace=True)
data.drop(columns=["SECCHI",  ], inplace=True)#,"Chl-a", "PO4-P", "DIN",
data.isnull().sum()
# Out:
# month                      0
# DSP                        1
# Dinophysis caudata         1
# Dinophysis fortii          1
# Phalacroma rotundatum      1
# Dinophysis sacculus        1
# Dinophysis tripos          1
# sun [h]                    0
# air temp                   0
# wind strength              0
# precipitation              0
# Chl-a                    422
# salinity                  21
# T                         59
# DIN                      352
# PO4-P                    349
# Soca                       0
# lipophylic_toxins        320
# dtype: int64

# %% [markdown]
# # Descriptive analysis

# %%
# describe
description = data.describe(include='all').round(0)

# Calculate the number of missing values for each column
missing_values = data.isna().sum()
missing_values.name = 'missing_values'

# Append the missing_values row to the description DataFrame
description_with_missing = description.append(missing_values)
description_with_missing = description_with_missing.drop(['unique', 'top', 'freq'])

description_with_missing

# # Descriptive statistics without decimals.
# # Generate summary statistics for the dataset and format all numbers as integers
# description = data.describe(include='all').apply(lambda x: x.apply(lambda y: "{:.0f}".format(y) if isinstance(y, (int, float)) else y))

# # Calculate the number of missing values for each column
# missing_values = data.isna().sum()
# missing_values.name = 'missing_values'

# # Append the missing_values row to the description DataFrame
# description_with_missing = description.append(missing_values)
# description_with_missing = description_with_missing.drop(['unique', 'top', 'freq'])

# # Output the modified DataFrame
# description_with_missing
# Out:
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                  month     DSP  Dinophysis caudata  Dinophysis fortii  \
# count           1452.0  1451.0              1451.0             1451.0
# mean               7.0   106.0                25.0               26.0
# std                3.0   340.0                88.0              160.0
# min                1.0     0.0                 0.0                0.0
# 25%                5.0    10.0                 0.0                0.0
# 50%                8.0    37.0                 0.0                0.0
# 75%               10.0    90.0                13.0               10.0
# max               12.0  7630.0              1309.0             4624.0
# missing_values     0.0     1.0                 1.0                1.0
#
#                 Phalacroma rotundatum  Dinophysis sacculus  Dinophysis tripos  \
# count                          1451.0               1451.0             1451.0
# mean                             14.0                 29.0                5.0
# std                              30.0                178.0               41.0
# min                               0.0                  0.0                0.0
# 25%                               0.0                  0.0                0.0
# 50%                              10.0                  0.0                0.0
# 75%                              20.0                 10.0                0.0
# max                             393.0               4639.0             1139.0
# missing_values                    1.0                  1.0                1.0
#
#                 sun [h]  air temp  wind strength  precipitation   Chl-a  \
# count            1452.0    1452.0         1452.0         1452.0  1030.0
# mean              159.0      17.0            3.0           58.0     1.0
# std                61.0       6.0            0.0           51.0     1.0
# min                23.0      -1.0            1.0            0.0     0.0
# 25%               113.0      12.0            3.0           20.0     0.0
# 50%               161.0      17.0            3.0           45.0     1.0
# 75%               207.0      22.0            3.0           79.0     1.0
# max               278.0      27.0            5.0          268.0     9.0
# missing_values      0.0       0.0            0.0            0.0   422.0
#
#                 salinity       T     DIN   PO4-P     Soca lipophylic_toxins
# count             1431.0  1393.0  1100.0  1103.0   1452.0              1132
# mean                37.0    19.0     3.0     0.0   3295.0               NaN
# std                 26.0     5.0     4.0     0.0   2330.0               NaN
# min                 24.0     6.0     0.0     0.0    594.0               NaN
# 25%                 36.0    16.0     1.0     0.0   1636.0               NaN
# 50%                 37.0    20.0     2.0     0.0   2581.0               NaN
# 75%                 37.0    24.0     4.0     0.0   4237.0               NaN
# max                999.0    28.0    35.0     4.0  16040.0               NaN
# missing_values      21.0    59.0   352.0   349.0      0.0               320

# %%
# # Visualize the distribution of each variable with histograms
# num_columns = len(data.columns)
# fig, axes = plt.subplots(num_columns, 1, figsize=(10, num_columns*5))

# for i, column in enumerate(data.columns):
#     if data[column].dtype == 'float64' or data[column].dtype == 'int64':
#         sns.histplot(data=data, x=column, kde=True, ax=axes[i])
#     elif data[column].dtype == 'object':
#         sns.countplot(data=data, x=column, ax=axes[i])

#     axes[i].set_title(f'Distribution of {column}')

# plt.tight_layout()
# plt.show()

# %%
# Create a figure with a more narrow width
fig, ax = plt.subplots(figsize=(4, 5))

# Create a count plot
sns.countplot(data=data, x="lipophylic_toxins", ax=ax)
ax.set_title('Distribution of lipophylic toxins test counts')

# Add numbers on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height() + 0.5,
            p.get_height(), ha='center', fontsize=10)

# Show the plot
plt.savefig(f"{dir_path}/lipophylic_toxins_test_counts-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# # Visualize the distribution of each variable using vertical violin plots
# num_columns = len(data.columns)
# fig, axes = plt.subplots(num_columns, 1, figsize=(6, num_columns*4))

# for i, column in enumerate(data.columns):
#     if data[column].dtype == 'float64' or data[column].dtype == 'int64':
#         sns.violinplot(data=data, y=column, ax=axes[i])
#         axes[i].set_title(f'Violin plot of {column}')
#     else:
#         # Skip categorical columns for violin plots
#         axes[i].set_visible(False)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Descriptive analysis by month

# %%
# table of mean values for each feature by month 
import calendar

grouped_means = data.groupby('month').mean()

# Count binary values for the categorical feature grouped by month
binary_counts = data.groupby('month')['lipophylic_toxins'].value_counts().unstack()

# Calculate the ratio of positive values for each month
sum_positive = binary_counts["poz"].sum()
positive_ratios = [i for i in (binary_counts["poz"] / sum_positive)] 
positive_ratios = [round(v * 100, 1) for v in positive_ratios]

# Change month names
month_names = {i: calendar.month_name[i] for i in range(1, 13)}

# Update the index using the month_names dictionary
grouped_means.index = grouped_means.index.map(month_names)
binary_counts.index = binary_counts.index.map(month_names)

# Concatenate the grouped_means and binary_counts DataFrames
result = pd.concat([grouped_means, binary_counts], axis=1).round(2)

# Add the positive_ratios Series as a new column to the result DataFrame
result["poz %"] = positive_ratios

result
# Out:
#               DSP  Dinophysis caudata  Dinophysis fortii  \
# month
# January      9.00                1.16               2.96
# February    12.86                1.02               4.08
# March       12.38                0.21               0.68
# April       15.49                0.97               0.48
# May         59.00                6.00               0.97
# June       146.89               29.23               1.49
# July       237.04               67.07              44.50
# August     129.67               55.46              24.23
# September  116.79               28.04              58.58
# October     97.76               13.21              35.56
# November    80.54               13.81              29.33
# December    81.96                2.33              51.95
#
#            Phalacroma rotundatum  Dinophysis sacculus  Dinophysis tripos  \
# month
# January                     3.66                 0.09               0.20
# February                    3.38                 0.20               0.69
# March                       3.79                 0.43               0.64
# April                       5.24                 4.51               0.00
# May                         9.67                34.25               0.15
# June                       12.87                93.28               0.09
# July                       19.57                97.25               0.04
# August                     19.01                22.96               0.08
# September                  12.81                 3.57               6.04
# October                    19.39                 2.17              19.76
# November                   19.09                 1.11               8.90
# December                   16.06                 1.18               4.77
#
#            sun [h]  air temp  wind strength  precipitation  Chl-a  salinity  \
# month
# January      72.62      4.95           2.71          46.53   0.76     36.95
# February     80.19      5.52           3.06          60.66   0.77     37.02
# March       118.56      7.55           3.30          30.01   0.77     37.17
# April       144.63     11.69           3.17          54.90   0.68     36.93
# May         171.96     16.22           2.89          48.55   0.96     36.57
# June        202.85     20.51           2.83          45.16   1.09     35.60
# July        227.47     23.31           2.88          38.27   0.75     35.40
# August      220.46     23.46           3.03          54.38   0.63     41.92
# September   174.65     20.06           3.11          69.73   0.64     36.59
# October     127.60     15.56           3.08          72.07   0.80     36.91
# November     82.48     11.35           3.01          74.21   1.20     36.72
# December     65.97      7.51           2.83          81.32   1.20     36.81
#
#                T   DIN  PO4-P     Soca  neg  poz  poz %
# month
# January    11.07  6.79   0.07  4652.16   15    3    2.2
# February   10.22  6.66   0.08  4378.79   21    3    2.2
# March       9.49  4.37   0.05  3257.07   28    2    1.5
# April      11.68  4.68   0.06  3826.10   66    2    1.5
# May        14.87  3.92   0.07  3864.97   89   14   10.3
# June       20.28  3.58   0.13  3436.93  115   12    8.8
# July       23.48  3.38   0.05  2473.18  125   18   13.2
# August     24.93  2.03   0.05  1637.28  126   11    8.1
# September  24.38  2.06   0.05  2102.01  143   31   22.8
# October    21.70  1.95   0.05  2988.28  138   24   17.6
# November   17.61  3.09   0.06  5263.97   91   13    9.6
# December   15.56  4.09   0.06  5868.74   39    3    2.2

# %%
# # Visualise numeric data distribution by month

# # Get the numerical columns
# numerical_columns = data.iloc[:, 1:-1].columns

# # Plot the distribution of each numerical variable by month
# num_numerical = len(numerical_columns)
# fig, axes = plt.subplots(num_numerical, 1, figsize=(10, num_numerical * 4))

# for i, column in enumerate(numerical_columns):
#     sns.lineplot(data=data, x='month', y=column, ax=axes[i], ci=None)
#     axes[i].set_title(f'Distribution of {column} by month')

# plt.tight_layout()
# plt.show()

# %%
# Plot phytoplantkon distribution by month
# Get the phytoplankton columns
phytoplankton = data.iloc[:, 1:7].columns

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the distribution of each of the first 6 numerical variables by month on the same plot
for column in phytoplankton:
    sns.lineplot(data=data, x='month', y=column, ax=ax, label=column)

# Customize the plot
ax.set_title('Distribution of phytoplankton by Month')
ax.set_ylabel('Abundance')  # Set the y-axis label to "Abundance"
ax.legend()

# Customize the x-axis ticks and labels to show only month names
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(range(1, 13), month_names)

# Save and show the plot
plt.tight_layout()
plt.savefig(f"{dir_path}/phytoplankton_abundance_distribution_by_month-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Visualise target variable distribution by month
# Create a displot with hue
sns.displot(data=data, x="month", hue="lipophylic_toxins", kde=True, height=6)

# Customize the x-axis ticks and labels
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                         'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Customize the plot if desired
sns.set_style("whitegrid")
sns.set_palette("Set2")
plt.title('Distribution of Lipophilic Toxins test results by Month')
plt.xlabel('Month')
plt.ylabel('Count')

# Show the plot
plt.savefig(f"{dir_path}/target_distribution_month-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Data preprocessing for modelling

# %% [markdown]
# ## Removing instances with unlabeled target, label encoding

# %%
# Prepare for ML in scikit-learn
# labeled and unlabeled part
data_l = data[data['lipophylic_toxins'].notnull()]
data_ul = data[data['lipophylic_toxins'].isnull()]

# Remove missing values
data_l = data_l.dropna(how="any")
print(f"class distribution:")
print(data_l["lipophylic_toxins"].value_counts(dropna=False))

X = data_l.drop("lipophylic_toxins", axis=1)
y = data_l["lipophylic_toxins"]

# sklearn lable encoding
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print(f"class encoding: ['neg','poz'] -> {le.transform(['neg','poz'])}")
# Out:
# class distribution:
# neg    662
# poz     88
# Name: lipophylic_toxins, dtype: int64
# class encoding: ['neg','poz'] -> [0 1]

# %% [markdown]
# ## Clean instances close to the decision boundary

# %% [markdown]
# Clean the dataset by removing samples close to the decision boundary. Because the dataset is heavily imbalanced in favor of clas 0 (neg) we will remove instances from this class whenever finding samples which do not agree “enough” with their neighboorhood. The EditedNearestNeighbours will be used. One other option is to use Tomek links but it is more conservative and was found to perform slightly worse.

# %%
from collections import Counter
from imblearn.under_sampling import TomekLinks, EditedNearestNeighbours

print(f'Original dataset shape: {Counter(y)}')
usmp = EditedNearestNeighbours()
lastMajorityCount = Counter(y)[0]
for i in range(10):
    X_res, y_res = usmp.fit_resample(X, y)
    if Counter(y_res)[0] == lastMajorityCount:
        print('Cannot remove any more samples')
        break
    else:
        print(f'Resampled dataset shape {Counter(y_res)}')
        lastMajorityCount = Counter(y_res)[0]
    X = X_res
    y = y_res
# Out:
# Original dataset shape: Counter({0: 662, 1: 88})
# Resampled dataset shape Counter({0: 540, 1: 88})
# Resampled dataset shape Counter({0: 501, 1: 88})
# Resampled dataset shape Counter({0: 490, 1: 88})
# Resampled dataset shape Counter({0: 488, 1: 88})
# Resampled dataset shape Counter({0: 487, 1: 88})
# Cannot remove any more samples

# %% [markdown]
# ## Train-test split

# %%
# All data
import copy

X_all = copy.copy(X)
y_all = copy.copy(y)

# train test split
X, X_eval, y, y_eval = train_test_split(X, y, shuffle=True, stratify=y, test_size=0.30, random_state=42)

# %% [markdown]
# # Correlation analysis on training data

# %%
# Calculate Pearson correlation between numeric features and binary target variable
pearson_correlations = X.corrwith(pd.Series(y), method='pearson')
pearson_correlations.name = 'Pearson'


# Combine the correlation values into a single dataframe
corr_df = pd.concat([pearson_correlations], axis=1)

# Create a new column for absolute Spearman correlation values
corr_df['Pearson_abs'] = corr_df['Pearson'].abs()

# Sort the dataframe by absolute Spearman correlation values
corr_df_sorted = corr_df.sort_values(by=['Pearson_abs'], ascending=False)

# Drop the absolute Spearman correlation column and return the sorted dataframe
corr_df_ranked = corr_df_sorted.drop(columns=['Pearson_abs'])

corr_df_ranked
# Out:
#                         Pearson
# Dinophysis caudata     0.159930
# T                      0.133431
# air temp               0.101362
# Chl-a                 -0.081980
# month                  0.079418
# Dinophysis tripos      0.076581
# salinity              -0.055177
# DSP                    0.050517
# DIN                    0.048785
# sun [h]                0.048582
# PO4-P                 -0.046319
# Soca                  -0.043240
# Dinophysis fortii     -0.035430
# precipitation          0.032200
# Phalacroma rotundatum  0.027626
# Dinophysis sacculus   -0.012564
# wind strength          0.003026

# %% [markdown]
# # Model Training and Evaluation

# %%
# Saving models

# Function to save best estimator
def save_best_estimator(grid_search_cv, classifier_name, notebook_name):
    # Get the best estimator from the GridSearchCV object
    best_estimator = grid_search_cv.best_estimator_

    # Construct the file name with the classifier name and notebook name
    pickle_file_name = f"{dir_path}/{classifier_name}-{notebook_name}-{timestamp}.pkl"
    
    # Save the best estimator to the file
    with open(pickle_file_name, 'wb') as f:
        pickle.dump(best_estimator, f)

    print(f"Best estimator saved as: {pickle_file_name}")

# %%
# Function for loading saved models

def load_best_estimator(pickle_file_name):
    with open(pickle_file_name, 'rb') as f:
        best_estimator = pickle.load(f)
    return best_estimator

# %% [markdown]
# ## SVM

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE()), 
    ('under', RandomUnderSampler()), 
    ('clf', SVC())
])

parameters = {
            'clf__C': [0.1, 0.5, 1, 3, 10, 100],
            # 'clf__gamma': ['scale', 'auto'],
            # 'clf__kernel': ['linear', 'rbf', 'poly'],
            'clf__class_weight': ['balanced', None],
            'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
            'under__sampling_strategy': [0.5, 0.6, 0.7],
            'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 3
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv_svm = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="f1",
                    n_jobs=-1)
resultsGSCV = gscv_svm.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_svm, classifier_name, notebook_name)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 3 folds for each of 324 candidates, totalling 972 fits
# Best estimator saved as: models/30042023_2331/SVC-HAB_modelling_6_2-30042023_2331.pkl
#                                                                               283  \
# mean_fit_time                                                            0.018994
# std_fit_time                                                              0.00126
# mean_score_time                                                           0.01927
# std_score_time                                                           0.000817
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                            0.8
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.536508
# std_test_recall                                                          0.187328
# rank_test_recall                                                                6
# split0_test_precision                                                         0.4
# split1_test_precision                                                    0.409091
# split2_test_precision                                                    0.275862
# mean_test_precision                                                      0.361651
# std_test_precision                                                       0.060775
# rank_test_precision                                                            45
# split0_test_f1                                                           0.533333
# split1_test_f1                                                           0.418605
# split2_test_f1                                                               0.32
# mean_test_f1                                                             0.423979
# std_test_f1                                                              0.087176
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.804386
# split1_test_roc_auc                                                      0.683944
# split2_test_roc_auc                                                      0.672988
# mean_test_roc_auc                                                        0.720439
# std_test_roc_auc                                                         0.059527
# rank_test_roc_auc                                                              73
# split0_test_recall_weighted                                              0.791045
# split1_test_recall_weighted                                              0.813433
# split2_test_recall_weighted                                              0.746269
# mean_test_recall_weighted                                                0.783582
# std_test_recall_weighted                                                 0.027923
# rank_test_recall_weighted                                                     154
#
#                                                                               294  \
# mean_fit_time                                                              0.0225
# std_fit_time                                                             0.002286
# mean_score_time                                                          0.019806
# std_score_time                                                           0.000903
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                            0.7
# split1_test_recall                                                       0.428571
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.534921
# std_test_recall                                                          0.118337
# rank_test_recall                                                               11
# split0_test_precision                                                    0.358974
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.322581
# mean_test_precision                                                      0.352185
# std_test_precision                                                       0.021932
# rank_test_precision                                                            47
# split0_test_f1                                                           0.474576
# split1_test_f1                                                                0.4
# split2_test_f1                                                           0.384615
# mean_test_f1                                                             0.419731
# std_test_f1                                                              0.039287
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.806579
# split1_test_roc_auc                                                      0.697008
# split2_test_roc_auc                                                      0.721028
# mean_test_roc_auc                                                        0.741538
# std_test_roc_auc                                                         0.047024
# rank_test_roc_auc                                                              30
# split0_test_recall_weighted                                              0.768657
# split1_test_recall_weighted                                              0.798507
# split2_test_recall_weighted                                              0.761194
# mean_test_recall_weighted                                                0.776119
# std_test_recall_weighted                                                 0.016121
# rank_test_recall_weighted                                                     162
#
#                                                                               314  \
# mean_fit_time                                                            0.022165
# std_fit_time                                                             0.000736
# mean_score_time                                                          0.018877
# std_score_time                                                           0.000814
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.238095
# split2_test_recall                                                       0.238095
# mean_test_recall                                                         0.342063
# std_test_recall                                                          0.147033
# rank_test_recall                                                              143
# split0_test_precision                                                    0.647059
# split1_test_precision                                                         0.5
# split2_test_precision                                                         0.5
# mean_test_precision                                                       0.54902
# std_test_precision                                                       0.069324
# rank_test_precision                                                            18
# split0_test_f1                                                           0.594595
# split1_test_f1                                                           0.322581
# split2_test_f1                                                           0.322581
# mean_test_f1                                                             0.413252
# std_test_f1                                                              0.128229
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.825877
# split1_test_roc_auc                                                      0.758534
# split2_test_roc_auc                                                      0.725664
# mean_test_roc_auc                                                        0.770025
# std_test_roc_auc                                                         0.041711
# rank_test_roc_auc                                                               5
# split0_test_recall_weighted                                               0.88806
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.858209
# std_test_recall_weighted                                                 0.021108
# rank_test_recall_weighted                                                       6
#
#                                                                               295  \
# mean_fit_time                                                             0.02186
# std_fit_time                                                             0.001028
# mean_score_time                                                          0.020133
# std_score_time                                                           0.000423
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                            0.7
# split1_test_recall                                                        0.47619
# split2_test_recall                                                       0.238095
# mean_test_recall                                                         0.471429
# std_test_recall                                                          0.188602
# rank_test_recall                                                               52
# split0_test_precision                                                        0.35
# split1_test_precision                                                    0.384615
# split2_test_precision                                                         0.5
# mean_test_precision                                                      0.411538
# std_test_precision                                                       0.064128
# rank_test_precision                                                            36
# split0_test_f1                                                           0.466667
# split1_test_f1                                                           0.425532
# split2_test_f1                                                           0.322581
# mean_test_f1                                                             0.404926
# std_test_f1                                                              0.060601
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.832018
# split1_test_roc_auc                                                      0.708807
# split2_test_roc_auc                                                      0.730299
# mean_test_roc_auc                                                        0.757041
# std_test_roc_auc                                                         0.053737
# rank_test_roc_auc                                                              14
# split0_test_recall_weighted                                              0.761194
# split1_test_recall_weighted                                              0.798507
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.800995
# std_test_recall_weighted                                                 0.033559
# rank_test_recall_weighted                                                     130
#
#                                                                               311  \
# mean_fit_time                                                            0.020368
# std_fit_time                                                              0.00055
# mean_score_time                                                          0.016952
# std_score_time                                                           0.000504
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.333333
# split2_test_recall                                                       0.285714
# mean_test_recall                                                         0.423016
# std_test_recall                                                          0.161675
# rank_test_recall                                                               94
# split0_test_precision                                                    0.464286
# split1_test_precision                                                        0.35
# split2_test_precision                                                       0.375
# mean_test_precision                                                      0.396429
# std_test_precision                                                       0.049056
# rank_test_precision                                                            40
# split0_test_f1                                                           0.541667
# split1_test_f1                                                           0.341463
# split2_test_f1                                                           0.324324
# mean_test_f1                                                             0.402485
# std_test_f1                                                              0.098665
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.844298
# split1_test_roc_auc                                                      0.675095
# split2_test_roc_auc                                                      0.712179
# mean_test_roc_auc                                                        0.743857
# std_test_roc_auc                                                         0.072618
# rank_test_roc_auc                                                              26
# split0_test_recall_weighted                                              0.835821
# split1_test_recall_weighted                                              0.798507
# split2_test_recall_weighted                                              0.813433
# mean_test_recall_weighted                                                 0.81592
# std_test_recall_weighted                                                 0.015334
# rank_test_recall_weighted                                                     120
#
#                                                                               317  \
# mean_fit_time                                                            0.020258
# std_fit_time                                                             0.000629
# mean_score_time                                                          0.015749
# std_score_time                                                           0.000116
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.285714
# split2_test_recall                                                       0.238095
# mean_test_recall                                                          0.34127
# std_test_recall                                                           0.11391
# rank_test_recall                                                              144
# split0_test_precision                                                    0.714286
# split1_test_precision                                                    0.428571
# split2_test_precision                                                      0.3125
# mean_test_precision                                                      0.485119
# std_test_precision                                                       0.168832
# rank_test_precision                                                            23
# split0_test_f1                                                           0.588235
# split1_test_f1                                                           0.342857
# split2_test_f1                                                            0.27027
# mean_test_f1                                                             0.400454
# std_test_f1                                                              0.136048
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.812719
# split1_test_roc_auc                                                      0.719343
# split2_test_roc_auc                                                      0.672145
# mean_test_roc_auc                                                        0.734736
# std_test_roc_auc                                                         0.058412
# rank_test_roc_auc                                                              40
# split0_test_recall_weighted                                              0.895522
# split1_test_recall_weighted                                              0.828358
# split2_test_recall_weighted                                              0.798507
# mean_test_recall_weighted                                                0.840796
# std_test_recall_weighted                                                 0.040571
# rank_test_recall_weighted                                                      89
#
#                                                                               292  \
# mean_fit_time                                                            0.020873
# std_fit_time                                                             0.000552
# mean_score_time                                                          0.017887
# std_score_time                                                           0.000568
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.75
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.503968
# std_test_recall                                                          0.178263
# rank_test_recall                                                               26
# split0_test_precision                                                    0.348837
# split1_test_precision                                                        0.36
# split2_test_precision                                                    0.333333
# mean_test_precision                                                       0.34739
# std_test_precision                                                       0.010935
# rank_test_precision                                                            48
# split0_test_f1                                                            0.47619
# split1_test_f1                                                           0.391304
# split2_test_f1                                                           0.333333
# mean_test_f1                                                             0.400276
# std_test_f1                                                              0.058665
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.782018
# split1_test_roc_auc                                                      0.674252
# split2_test_roc_auc                                                      0.683102
# mean_test_roc_auc                                                        0.713124
# std_test_roc_auc                                                         0.048849
# rank_test_roc_auc                                                              91
# split0_test_recall_weighted                                              0.753731
# split1_test_recall_weighted                                              0.791045
# split2_test_recall_weighted                                              0.791045
# mean_test_recall_weighted                                                0.778607
# std_test_recall_weighted                                                  0.01759
# rank_test_recall_weighted                                                     158
#
#                                                                               270  \
# mean_fit_time                                                            0.020016
# std_fit_time                                                             0.000965
# mean_score_time                                                          0.017263
# std_score_time                                                           0.000623
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.75
# split1_test_recall                                                       0.380952
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.535714
# std_test_recall                                                          0.156432
# rank_test_recall                                                                7
# split0_test_precision                                                    0.333333
# split1_test_precision                                                    0.347826
# split2_test_precision                                                     0.30303
# mean_test_precision                                                      0.328063
# std_test_precision                                                       0.018664
# rank_test_precision                                                            63
# split0_test_f1                                                           0.461538
# split1_test_f1                                                           0.363636
# split2_test_f1                                                            0.37037
# mean_test_f1                                                             0.398515
# std_test_f1                                                              0.044649
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.813158
# split1_test_roc_auc                                                      0.681837
# split2_test_roc_auc                                                      0.702065
# mean_test_roc_auc                                                        0.732353
# std_test_roc_auc                                                         0.057731
# rank_test_roc_auc                                                              44
# split0_test_recall_weighted                                              0.738806
# split1_test_recall_weighted                                              0.791045
# split2_test_recall_weighted                                              0.746269
# mean_test_recall_weighted                                                0.758706
# std_test_recall_weighted                                                 0.023069
# rank_test_recall_weighted                                                     174
#
#                                                                               305  \
# mean_fit_time                                                            0.021236
# std_fit_time                                                              0.00019
# mean_score_time                                                          0.017602
# std_score_time                                                            0.00086
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.75
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.142857
# mean_test_recall                                                         0.424603
# std_test_recall                                                          0.249779
# rank_test_recall                                                               92
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.380952
# split2_test_precision                                                    0.428571
# mean_test_precision                                                      0.436508
# std_test_precision                                                       0.048924
# rank_test_precision                                                            29
# split0_test_f1                                                                0.6
# split1_test_f1                                                           0.380952
# split2_test_f1                                                           0.214286
# mean_test_f1                                                             0.398413
# std_test_f1                                                               0.15795
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.838158
# split1_test_roc_auc                                                      0.692373
# split2_test_roc_auc                                                      0.725664
# mean_test_roc_auc                                                        0.752065
# std_test_roc_auc                                                         0.062376
# rank_test_roc_auc                                                              18
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                               0.80597
# split2_test_recall_weighted                                              0.835821
# mean_test_recall_weighted                                                0.830846
# std_test_recall_weighted                                                 0.018615
# rank_test_recall_weighted                                                     102
#
#                                                                               277  \
# mean_fit_time                                                            0.022839
# std_fit_time                                                             0.001355
# mean_score_time                                                          0.021066
# std_score_time                                                           0.000346
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.75
# split1_test_recall                                                       0.380952
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.535714
# std_test_recall                                                          0.156432
# rank_test_recall                                                                7
# split0_test_precision                                                    0.272727
# split1_test_precision                                                    0.347826
# split2_test_precision                                                    0.384615
# mean_test_precision                                                      0.335056
# std_test_precision                                                       0.046562
# rank_test_precision                                                            51
# split0_test_f1                                                                0.4
# split1_test_f1                                                           0.363636
# split2_test_f1                                                           0.425532
# mean_test_f1                                                             0.396389
# std_test_f1                                                              0.025397
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.807018
# split1_test_roc_auc                                                      0.696165
# split2_test_roc_auc                                                      0.715129
# mean_test_roc_auc                                                        0.739437
# std_test_roc_auc                                                          0.04841
# rank_test_roc_auc                                                              34
# split0_test_recall_weighted                                              0.664179
# split1_test_recall_weighted                                              0.791045
# split2_test_recall_weighted                                              0.798507
# mean_test_recall_weighted                                                0.751244
# std_test_recall_weighted                                                 0.061639
# rank_test_recall_weighted                                                     182
#
#                                                                               288  \
# mean_fit_time                                                             0.02041
# std_fit_time                                                             0.000777
# mean_score_time                                                          0.015625
# std_score_time                                                           0.000524
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                            0.7
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.519048
# std_test_recall                                                          0.127953
# rank_test_recall                                                               16
# split0_test_precision                                                        0.35
# split1_test_precision                                                    0.290323
# split2_test_precision                                                    0.333333
# mean_test_precision                                                      0.324552
# std_test_precision                                                       0.025142
# rank_test_precision                                                            65
# split0_test_f1                                                           0.466667
# split1_test_f1                                                           0.346154
# split2_test_f1                                                              0.375
# mean_test_f1                                                              0.39594
# std_test_f1                                                              0.051379
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.828509
# split1_test_roc_auc                                                      0.667509
# split2_test_roc_auc                                                      0.713443
# mean_test_roc_auc                                                        0.736487
# std_test_roc_auc                                                         0.067717
# rank_test_roc_auc                                                              37
# split0_test_recall_weighted                                              0.761194
# split1_test_recall_weighted                                              0.746269
# split2_test_recall_weighted                                              0.776119
# mean_test_recall_weighted                                                0.761194
# std_test_recall_weighted                                                 0.012187
# rank_test_recall_weighted                                                     172
#
#                                                                               320  \
# mean_fit_time                                                            0.021597
# std_fit_time                                                             0.000948
# mean_score_time                                                          0.018175
# std_score_time                                                           0.001642
# param_clf__C                                                                  100
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 100, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.142857
# mean_test_recall                                                          0.39127
# std_test_recall                                                          0.207169
# rank_test_recall                                                              114
# split0_test_precision                                                    0.448276
# split1_test_precision                                                         0.5
# split2_test_precision                                                         0.5
# mean_test_precision                                                      0.482759
# std_test_precision                                                       0.024383
# rank_test_precision                                                            24
# split0_test_f1                                                           0.530612
# split1_test_f1                                                           0.432432
# split2_test_f1                                                           0.222222
# mean_test_f1                                                             0.395089
# std_test_f1                                                              0.128639
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.790351
# split1_test_roc_auc                                                      0.699536
# split2_test_roc_auc                                                      0.737042
# mean_test_roc_auc                                                         0.74231
# std_test_roc_auc                                                         0.037261
# rank_test_roc_auc                                                              28
# split0_test_recall_weighted                                              0.828358
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.838308
# std_test_recall_weighted                                                 0.007036
# rank_test_recall_weighted                                                      95
#
#                                                                               285  \
# mean_fit_time                                                            0.022463
# std_fit_time                                                             0.000611
# mean_score_time                                                          0.020646
# std_score_time                                                           0.000602
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.85
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.238095
# mean_test_recall                                                         0.505556
# std_test_recall                                                          0.255671
# rank_test_recall                                                               24
# split0_test_precision                                                    0.369565
# split1_test_precision                                                    0.333333
# split2_test_precision                                                    0.384615
# mean_test_precision                                                      0.362505
# std_test_precision                                                       0.021523
# rank_test_precision                                                            44
# split0_test_f1                                                           0.515152
# split1_test_f1                                                              0.375
# split2_test_f1                                                           0.294118
# mean_test_f1                                                             0.394756
# std_test_f1                                                              0.091312
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.792105
# split1_test_roc_auc                                                      0.686051
# split2_test_roc_auc                                                      0.746313
# mean_test_roc_auc                                                         0.74149
# std_test_roc_auc                                                          0.04343
# rank_test_roc_auc                                                              31
# split0_test_recall_weighted                                              0.761194
# split1_test_recall_weighted                                              0.776119
# split2_test_recall_weighted                                              0.820896
# mean_test_recall_weighted                                                 0.78607
# std_test_recall_weighted                                                 0.025368
# rank_test_recall_weighted                                                     152
#
#                                                                               286  \
# mean_fit_time                                                            0.024425
# std_fit_time                                                             0.001951
# mean_score_time                                                          0.020535
# std_score_time                                                           0.002212
# param_clf__C                                                                  100
# param_clf__class_weight                                                  balanced
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 100, 'clf__class_weight': 'balanced...
# split0_test_recall                                                           0.75
# split1_test_recall                                                       0.380952
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.535714
# std_test_recall                                                          0.156432
# rank_test_recall                                                                7
# split0_test_precision                                                    0.283019
# split1_test_precision                                                        0.32
# split2_test_precision                                                     0.37037
# mean_test_precision                                                      0.324463
# std_test_precision                                                         0.0358
# rank_test_precision                                                            66
# split0_test_f1                                                           0.410959
# split1_test_f1                                                           0.347826
# split2_test_f1                                                           0.416667
# mean_test_f1                                                             0.391817
# std_test_f1                                                              0.031194
# rank_test_f1                                                                   14
# ...
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           264
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  264
# split0_test_roc_auc                                                      0.830702
# split1_test_roc_auc                                                      0.674252
# split2_test_roc_auc                                                      0.687316
# mean_test_roc_auc                                                        0.730756
# std_test_roc_auc                                                         0.070873
# rank_test_roc_auc                                                              47
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      27
#
#                                                                               50   \
# mean_fit_time                                                            0.018444
# std_fit_time                                                             0.003365
# mean_score_time                                                          0.017025
# std_score_time                                                           0.001978
# param_clf__C                                                                  0.1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__C': 0.1, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              264
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           264
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  264
# split0_test_roc_auc                                                      0.760088
# split1_test_roc_auc                                                      0.552044
# split2_test_roc_auc                                                      0.583228
# mean_test_roc_auc                                                        0.631787
# std_test_roc_auc                                                         0.091612
# rank_test_roc_auc                                                             192
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      27
#
#                                                                               31   \
# mean_fit_time                                                            0.021483
# std_fit_time                                                             0.001031
# mean_score_time                                                          0.018657
# std_score_time                                                           0.000691
# param_clf__C                                                                  0.1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__C': 0.1, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              264
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           264
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  264
# split0_test_roc_auc                                                      0.816667
# split1_test_roc_auc                                                      0.529288
# split2_test_roc_auc                                                      0.680995
# mean_test_roc_auc                                                         0.67565
# std_test_roc_auc                                                         0.117383
# rank_test_roc_auc                                                             139
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      27
#
#                                                                               45   \
# mean_fit_time                                                            0.019637
# std_fit_time                                                             0.002674
# mean_score_time                                                          0.019512
# std_score_time                                                           0.005019
# param_clf__C                                                                  0.1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 0.1, 'clf__class_weight': None, 'sm...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              264
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           264
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  264
# split0_test_roc_auc                                                      0.808772
# split1_test_roc_auc                                                      0.724821
# split2_test_roc_auc                                                      0.660346
# mean_test_roc_auc                                                        0.731313
# std_test_roc_auc                                                         0.060768
# rank_test_roc_auc                                                              46
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      27
#
#                                                                               156
# mean_fit_time                                                            0.023894
# std_fit_time                                                             0.003194
# mean_score_time                                                          0.024183
# std_score_time                                                           0.004687
# param_clf__C                                                                    1
# param_clf__class_weight                                                      None
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__C': 1, 'clf__class_weight': None, 'smt_...
# split0_test_recall                                                            0.0
# split1_test_recall                                                            0.0
# split2_test_recall                                                            0.0
# mean_test_recall                                                              0.0
# std_test_recall                                                               0.0
# rank_test_recall                                                              264
# split0_test_precision                                                         0.0
# split1_test_precision                                                         0.0
# split2_test_precision                                                         0.0
# mean_test_precision                                                           0.0
# std_test_precision                                                            0.0
# rank_test_precision                                                           264
# split0_test_f1                                                                0.0
# split1_test_f1                                                                0.0
# split2_test_f1                                                                0.0
# mean_test_f1                                                                  0.0
# std_test_f1                                                                   0.0
# rank_test_f1                                                                  264
# split0_test_roc_auc                                                      0.841228
# split1_test_roc_auc                                                      0.667931
# split2_test_roc_auc                                                      0.657396
# mean_test_roc_auc                                                        0.722185
# std_test_roc_auc                                                         0.084286
# rank_test_roc_auc                                                              67
# split0_test_recall_weighted                                              0.850746
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.003518
# rank_test_recall_weighted                                                      27
#
# [40 rows x 324 columns]

# %%
# Evaluation on test data
svm_clf = gscv_svm.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# svm_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation on test data
from sklearn.metrics import classification_report
y_pred = svm_clf.predict(X_eval)
SVM_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
SVM_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.92      0.68      0.78       147
#          poz       0.27      0.65      0.38        26
#
#     accuracy                           0.68       173
#    macro avg       0.59      0.67      0.58       173
# weighted avg       0.82      0.68      0.72       173

# %% [markdown]
# ## Decision Tree Model (sklearn)

# %%
pd.set_option("display.max_rows", None)

pipeline = IMBLpipeline([
    ('smt', SMOTE()), 
    ('under', RandomUnderSampler()), 
    ('clf', DecisionTreeClassifier())
])

parameters = {
            'clf__max_depth': [2,3,4],
            'clf__criterion': ['gini', 'entropy', 'log_loss'],
               'clf__class_weight': ['balanced', None],
               'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
               'under__sampling_strategy': [0.5, 0.6, 0.7],
               'smt__k_neighbors': [1, 3, 5]
             }
nfolds = 3
scores = ['recall', 'precision', 'f1', 'roc_auc', 'recall_weighted']
gscv_dt = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit="f1",
                    n_jobs=-1)
resultsGSCV = gscv_dt.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_dt, classifier_name, notebook_name)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 3 folds for each of 486 candidates, totalling 1458 fits
# Best estimator saved as: models/30042023_2331/DecisionTreeClassifier-HAB_modelling_6_2-30042023_2331.pkl
#                                                                               253  \
# mean_fit_time                                                            0.018707
# std_fit_time                                                             0.000589
# mean_score_time                                                          0.013211
# std_score_time                                                           0.002512
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.579365
# std_test_recall                                                          0.068272
# rank_test_recall                                                               94
# split0_test_precision                                                    0.588235
# split1_test_precision                                                    0.341463
# split2_test_precision                                                    0.387097
# mean_test_precision                                                      0.438932
# std_test_precision                                                       0.107205
# rank_test_precision                                                            26
# split0_test_f1                                                           0.540541
# split1_test_f1                                                           0.451613
# split2_test_f1                                                           0.461538
# mean_test_f1                                                             0.484564
# std_test_f1                                                              0.039788
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.798246
# split1_test_roc_auc                                                      0.710072
# split2_test_roc_auc                                                       0.72145
# mean_test_roc_auc                                                        0.743256
# std_test_roc_auc                                                          0.03916
# rank_test_roc_auc                                                              10
# split0_test_recall_weighted                                              0.873134
# split1_test_recall_weighted                                              0.746269
# split2_test_recall_weighted                                              0.791045
# mean_test_recall_weighted                                                0.803483
# std_test_recall_weighted                                                 0.052534
# rank_test_recall_weighted                                                      75
#
#                                                                               288  \
# mean_fit_time                                                            0.018763
# std_fit_time                                                             0.000487
# mean_score_time                                                          0.011755
# std_score_time                                                           0.000838
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.7
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.380952
# mean_test_recall                                                          0.58254
# std_test_recall                                                          0.143192
# rank_test_recall                                                               86
# split0_test_precision                                                    0.518519
# split1_test_precision                                                    0.388889
# split2_test_precision                                                    0.347826
# mean_test_precision                                                      0.418411
# std_test_precision                                                       0.072745
# rank_test_precision                                                            39
# split0_test_f1                                                           0.595745
# split1_test_f1                                                           0.491228
# split2_test_f1                                                           0.363636
# mean_test_f1                                                             0.483536
# std_test_f1                                                              0.094914
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.765789
# split1_test_roc_auc                                                      0.750105
# split2_test_roc_auc                                                      0.657606
# mean_test_roc_auc                                                          0.7245
# std_test_roc_auc                                                         0.047733
# rank_test_roc_auc                                                              40
# split0_test_recall_weighted                                              0.858209
# split1_test_recall_weighted                                              0.783582
# split2_test_recall_weighted                                              0.791045
# mean_test_recall_weighted                                                0.810945
# std_test_recall_weighted                                                 0.033559
# rank_test_recall_weighted                                                      56
#
#                                                                               189  \
# mean_fit_time                                                             0.02189
# std_fit_time                                                             0.002304
# mean_score_time                                                          0.013924
# std_score_time                                                           0.000654
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.714286
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.645238
# std_test_recall                                                          0.058418
# rank_test_recall                                                               48
# split0_test_precision                                                    0.270833
# split1_test_precision                                                       0.375
# split2_test_precision                                                    0.521739
# mean_test_precision                                                      0.389191
# std_test_precision                                                       0.102922
# rank_test_precision                                                            73
# split0_test_f1                                                           0.382353
# split1_test_f1                                                           0.491803
# split2_test_f1                                                           0.545455
# mean_test_f1                                                             0.473204
# std_test_f1                                                              0.067872
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.720175
# split1_test_roc_auc                                                      0.768226
# split2_test_roc_auc                                                      0.706911
# mean_test_roc_auc                                                        0.731771
# std_test_roc_auc                                                          0.02634
# rank_test_roc_auc                                                              25
# split0_test_recall_weighted                                              0.686567
# split1_test_recall_weighted                                              0.768657
# split2_test_recall_weighted                                              0.850746
# mean_test_recall_weighted                                                0.768657
# std_test_recall_weighted                                                 0.067026
# rank_test_recall_weighted                                                     152
#
#                                                                               225  \
# mean_fit_time                                                            0.019285
# std_fit_time                                                             0.000894
# mean_score_time                                                           0.01125
# std_score_time                                                           0.000238
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.85
# split1_test_recall                                                       0.761905
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.727778
# std_test_recall                                                          0.116258
# rank_test_recall                                                               13
# split0_test_precision                                                    0.485714
# split1_test_precision                                                    0.219178
# split2_test_precision                                                       0.375
# mean_test_precision                                                      0.359964
# std_test_precision                                                       0.109331
# rank_test_precision                                                           130
# split0_test_f1                                                           0.618182
# split1_test_f1                                                           0.340426
# split2_test_f1                                                            0.45283
# mean_test_f1                                                             0.470479
# std_test_f1                                                              0.114078
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.908333
# split1_test_roc_auc                                                      0.621787
# split2_test_roc_auc                                                      0.703751
# mean_test_roc_auc                                                        0.744624
# std_test_roc_auc                                                         0.120499
# rank_test_roc_auc                                                               9
# split0_test_recall_weighted                                              0.843284
# split1_test_recall_weighted                                              0.537313
# split2_test_recall_weighted                                              0.783582
# mean_test_recall_weighted                                                0.721393
# std_test_recall_weighted                                                 0.132426
# rank_test_recall_weighted                                                     261
#
#                                                                               432  \
# mean_fit_time                                                            0.019458
# std_fit_time                                                             0.000518
# mean_score_time                                                          0.012309
# std_score_time                                                           0.000638
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.7
# split1_test_recall                                                       0.285714
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.471429
# std_test_recall                                                          0.171825
# rank_test_recall                                                              210
# split0_test_precision                                                    0.538462
# split1_test_precision                                                         0.5
# split2_test_precision                                                        0.45
# mean_test_precision                                                      0.496154
# std_test_precision                                                       0.036217
# rank_test_precision                                                             8
# split0_test_f1                                                           0.608696
# split1_test_f1                                                           0.363636
# split2_test_f1                                                           0.439024
# mean_test_f1                                                             0.470452
# std_test_f1                                                              0.102483
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.849342
# split1_test_roc_auc                                                      0.669617
# split2_test_roc_auc                                                      0.726085
# mean_test_roc_auc                                                        0.748348
# std_test_roc_auc                                                         0.075042
# rank_test_roc_auc                                                               6
# split0_test_recall_weighted                                              0.865672
# split1_test_recall_weighted                                              0.843284
# split2_test_recall_weighted                                              0.828358
# mean_test_recall_weighted                                                0.845771
# std_test_recall_weighted                                                 0.015334
# rank_test_recall_weighted                                                       5
#
#                                                                               272  \
# mean_fit_time                                                            0.019259
# std_fit_time                                                             0.000162
# mean_score_time                                                          0.011816
# std_score_time                                                            0.00047
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.95
# split1_test_recall                                                       0.714286
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.713492
# std_test_recall                                                          0.193433
# rank_test_recall                                                               18
# split0_test_precision                                                    0.292308
# split1_test_precision                                                    0.365854
# split2_test_precision                                                     0.47619
# mean_test_precision                                                      0.378117
# std_test_precision                                                       0.075569
# rank_test_precision                                                            86
# split0_test_f1                                                           0.447059
# split1_test_f1                                                           0.483871
# split2_test_f1                                                            0.47619
# mean_test_f1                                                              0.46904
# std_test_f1                                                              0.015856
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.908772
# split1_test_roc_auc                                                      0.746734
# split2_test_roc_auc                                                      0.715129
# mean_test_roc_auc                                                        0.790212
# std_test_roc_auc                                                         0.084822
# rank_test_roc_auc                                                               1
# split0_test_recall_weighted                                              0.649254
# split1_test_recall_weighted                                              0.761194
# split2_test_recall_weighted                                              0.835821
# mean_test_recall_weighted                                                0.748756
# std_test_recall_weighted                                                 0.076672
# rank_test_recall_weighted                                                     194
#
#                                                                               423  \
# mean_fit_time                                                            0.018351
# std_fit_time                                                             0.000382
# mean_score_time                                                           0.01132
# std_score_time                                                           0.000217
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.65
# split1_test_recall                                                       0.190476
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.407143
# std_test_recall                                                          0.188512
# rank_test_recall                                                              306
# split0_test_precision                                                    0.764706
# split1_test_precision                                                    0.307692
# split2_test_precision                                                    0.571429
# mean_test_precision                                                      0.547942
# std_test_precision                                                       0.187313
# rank_test_precision                                                             2
# split0_test_f1                                                           0.702703
# split1_test_f1                                                           0.235294
# split2_test_f1                                                           0.457143
# mean_test_f1                                                             0.465047
# std_test_f1                                                              0.190901
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.827193
# split1_test_roc_auc                                                      0.628529
# split2_test_roc_auc                                                       0.73051
# mean_test_roc_auc                                                        0.728744
# std_test_roc_auc                                                         0.081114
# rank_test_roc_auc                                                              30
# split0_test_recall_weighted                                               0.91791
# split1_test_recall_weighted                                               0.80597
# split2_test_recall_weighted                                              0.858209
# mean_test_recall_weighted                                                0.860697
# std_test_recall_weighted                                                 0.045733
# rank_test_recall_weighted                                                       1
#
#                                                                               453  \
# mean_fit_time                                                            0.020381
# std_fit_time                                                             0.000214
# mean_score_time                                                          0.012913
# std_score_time                                                           0.000617
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.45
# split1_test_recall                                                        0.47619
# split2_test_recall                                                        0.47619
# mean_test_recall                                                          0.46746
# std_test_recall                                                          0.012346
# rank_test_recall                                                              225
# split0_test_precision                                                    0.818182
# split1_test_precision                                                    0.285714
# split2_test_precision                                                         0.4
# mean_test_precision                                                      0.501299
# std_test_precision                                                       0.228876
# rank_test_precision                                                             6
# split0_test_f1                                                           0.580645
# split1_test_f1                                                           0.357143
# split2_test_f1                                                           0.434783
# mean_test_f1                                                             0.457524
# std_test_f1                                                              0.092651
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.782018
# split1_test_roc_auc                                                      0.696165
# split2_test_roc_auc                                                      0.731563
# mean_test_roc_auc                                                        0.736582
# std_test_roc_auc                                                         0.035228
# rank_test_roc_auc                                                              19
# split0_test_recall_weighted                                              0.902985
# split1_test_recall_weighted                                              0.731343
# split2_test_recall_weighted                                               0.80597
# mean_test_recall_weighted                                                0.813433
# std_test_recall_weighted                                                 0.070271
# rank_test_recall_weighted                                                      50
#
#                                                                               79   \
# mean_fit_time                                                            0.020598
# std_fit_time                                                             0.001471
# mean_score_time                                                          0.012539
# std_score_time                                                           0.000629
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.75
# split1_test_recall                                                       0.714286
# split2_test_recall                                                       0.619048
# mean_test_recall                                                         0.694444
# std_test_recall                                                          0.055271
# rank_test_recall                                                               25
# split0_test_precision                                                    0.357143
# split1_test_precision                                                    0.384615
# split2_test_precision                                                    0.276596
# mean_test_precision                                                      0.339451
# std_test_precision                                                       0.045839
# rank_test_precision                                                           169
# split0_test_f1                                                           0.483871
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.382353
# mean_test_f1                                                             0.455408
# std_test_f1                                                              0.052076
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.726096
# split1_test_roc_auc                                                      0.750737
# split2_test_roc_auc                                                      0.656553
# mean_test_roc_auc                                                        0.711129
# std_test_roc_auc                                                         0.039881
# rank_test_roc_auc                                                              71
# split0_test_recall_weighted                                              0.761194
# split1_test_recall_weighted                                              0.776119
# split2_test_recall_weighted                                              0.686567
# mean_test_recall_weighted                                                0.741294
# std_test_recall_weighted                                                 0.039174
# rank_test_recall_weighted                                                     218
#
#                                                                               322  \
# mean_fit_time                                                            0.021627
# std_fit_time                                                             0.001242
# mean_score_time                                                          0.013156
# std_score_time                                                           0.000833
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.85
# split1_test_recall                                                        0.52381
# split2_test_recall                                                        0.52381
# mean_test_recall                                                          0.63254
# std_test_recall                                                          0.153768
# rank_test_recall                                                               52
# split0_test_precision                                                    0.298246
# split1_test_precision                                                     0.37931
# split2_test_precision                                                        0.44
# mean_test_precision                                                      0.372519
# std_test_precision                                                        0.05807
# rank_test_precision                                                            99
# split0_test_f1                                                           0.441558
# split1_test_f1                                                               0.44
# split2_test_f1                                                           0.478261
# mean_test_f1                                                             0.453273
# std_test_f1                                                               0.01768
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.722368
# split1_test_roc_auc                                                      0.726928
# split2_test_roc_auc                                                      0.678255
# mean_test_roc_auc                                                        0.709184
# std_test_roc_auc                                                         0.021949
# rank_test_roc_auc                                                              78
# split0_test_recall_weighted                                              0.679104
# split1_test_recall_weighted                                              0.791045
# split2_test_recall_weighted                                              0.820896
# mean_test_recall_weighted                                                0.763682
# std_test_recall_weighted                                                 0.061034
# rank_test_recall_weighted                                                     164
#
#                                                                               357  \
# mean_fit_time                                                            0.020911
# std_fit_time                                                             0.001607
# mean_score_time                                                          0.011587
# std_score_time                                                           0.000744
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.333333
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.468254
# std_test_recall                                                           0.09976
# rank_test_recall                                                              224
# split0_test_precision                                                    0.526316
# split1_test_precision                                                    0.368421
# split2_test_precision                                                    0.428571
# mean_test_precision                                                      0.441103
# std_test_precision                                                       0.065066
# rank_test_precision                                                            25
# split0_test_f1                                                           0.512821
# split1_test_f1                                                               0.35
# split2_test_f1                                                           0.489796
# mean_test_f1                                                             0.450872
# std_test_f1                                                              0.071944
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.744298
# split1_test_roc_auc                                                      0.674884
# split2_test_roc_auc                                                      0.758955
# mean_test_roc_auc                                                        0.726046
# std_test_roc_auc                                                         0.036668
# rank_test_roc_auc                                                              34
# split0_test_recall_weighted                                              0.858209
# split1_test_recall_weighted                                               0.80597
# split2_test_recall_weighted                                              0.813433
# mean_test_recall_weighted                                                0.825871
# std_test_recall_weighted                                                 0.023069
# rank_test_recall_weighted                                                      25
#
#                                                                               309  \
# mean_fit_time                                                            0.020851
# std_fit_time                                                             0.001543
# mean_score_time                                                          0.012579
# std_score_time                                                           0.001177
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.285714
# mean_test_recall                                                         0.484127
# std_test_recall                                                          0.155928
# rank_test_recall                                                              201
# split0_test_precision                                                    0.416667
# split1_test_precision                                                         0.4
# split2_test_precision                                                         0.6
# mean_test_precision                                                      0.472222
# std_test_precision                                                       0.090608
# rank_test_precision                                                            14
# split0_test_f1                                                           0.454545
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.387097
# mean_test_f1                                                             0.447214
# std_test_f1                                                              0.046383
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.745833
# split1_test_roc_auc                                                      0.763801
# split2_test_roc_auc                                                      0.601349
# mean_test_roc_auc                                                        0.703661
# std_test_roc_auc                                                         0.072717
# rank_test_roc_auc                                                              93
# split0_test_recall_weighted                                              0.820896
# split1_test_recall_weighted                                              0.791045
# split2_test_recall_weighted                                              0.858209
# mean_test_recall_weighted                                                0.823383
# std_test_recall_weighted                                                 0.027476
# rank_test_recall_weighted                                                      32
#
#                                                                               477  \
# mean_fit_time                                                            0.023626
# std_fit_time                                                             0.001939
# mean_score_time                                                          0.013455
# std_score_time                                                           0.000126
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.7
# split1_test_recall                                                       0.238095
# split2_test_recall                                                        0.52381
# mean_test_recall                                                         0.487302
# std_test_recall                                                          0.190331
# rank_test_recall                                                              192
# split0_test_precision                                                      0.4375
# split1_test_precision                                                    0.357143
# split2_test_precision                                                         0.5
# mean_test_precision                                                      0.431548
# std_test_precision                                                       0.058473
# rank_test_precision                                                            33
# split0_test_f1                                                           0.538462
# split1_test_f1                                                           0.285714
# split2_test_f1                                                           0.511628
# mean_test_f1                                                             0.445268
# std_test_f1                                                              0.113352
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.784211
# split1_test_roc_auc                                                      0.746102
# split2_test_roc_auc                                                      0.747577
# mean_test_roc_auc                                                        0.759296
# std_test_roc_auc                                                         0.017627
# rank_test_roc_auc                                                               4
# split0_test_recall_weighted                                              0.820896
# split1_test_recall_weighted                                              0.813433
# split2_test_recall_weighted                                              0.843284
# mean_test_recall_weighted                                                0.825871
# std_test_recall_weighted                                                 0.012684
# rank_test_recall_weighted                                                      25
#
#                                                                               399  \
# mean_fit_time                                                             0.02216
# std_fit_time                                                             0.002825
# mean_score_time                                                          0.013306
# std_score_time                                                           0.001506
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            4
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.238095
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.390476
# ...
# std_test_precision                                                         0.0904
# rank_test_precision                                                           486
# split0_test_f1                                                           0.076923
# split1_test_f1                                                            0.27907
# split2_test_f1                                                               0.36
# mean_test_f1                                                             0.238664
# std_test_f1                                                              0.119045
# rank_test_f1                                                                  482
# split0_test_roc_auc                                                      0.439035
# split1_test_roc_auc                                                       0.65276
# split2_test_roc_auc                                                      0.734092
# mean_test_roc_auc                                                        0.608629
# std_test_roc_auc                                                         0.124433
# rank_test_roc_auc                                                             451
# split0_test_recall_weighted                                              0.641791
# split1_test_recall_weighted                                              0.768657
# split2_test_recall_weighted                                              0.522388
# mean_test_recall_weighted                                                0.644279
# std_test_recall_weighted                                                 0.100554
# rank_test_recall_weighted                                                     418
#
#                                                                               412  \
# mean_fit_time                                                            0.019693
# std_fit_time                                                             0.000494
# mean_score_time                                                          0.013086
# std_score_time                                                           0.002618
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          1
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.45
# split1_test_recall                                                       0.190476
# split2_test_recall                                                       0.238095
# mean_test_recall                                                         0.292857
# std_test_recall                                                          0.112805
# rank_test_recall                                                              455
# split0_test_precision                                                    0.147541
# split1_test_precision                                                    0.307692
# split2_test_precision                                                    0.263158
# mean_test_precision                                                      0.239464
# std_test_precision                                                       0.067494
# rank_test_precision                                                           439
# split0_test_f1                                                           0.222222
# split1_test_f1                                                           0.235294
# split2_test_f1                                                               0.25
# mean_test_f1                                                             0.235839
# std_test_f1                                                              0.011347
# rank_test_f1                                                                  483
# split0_test_roc_auc                                                      0.507456
# split1_test_roc_auc                                                      0.613359
# split2_test_roc_auc                                                      0.709018
# mean_test_roc_auc                                                        0.609944
# std_test_roc_auc                                                         0.082323
# rank_test_roc_auc                                                             447
# split0_test_recall_weighted                                              0.529851
# split1_test_recall_weighted                                               0.80597
# split2_test_recall_weighted                                              0.776119
# mean_test_recall_weighted                                                 0.70398
# std_test_recall_weighted                                                  0.12373
# rank_test_recall_weighted                                                     303
#
#                                                                               91   \
# mean_fit_time                                                            0.020042
# std_fit_time                                                               0.0007
# mean_score_time                                                          0.012068
# std_score_time                                                           0.000847
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.4
# split1_test_recall                                                       0.095238
# split2_test_recall                                                       0.857143
# mean_test_recall                                                         0.450794
# std_test_recall                                                          0.313113
# rank_test_recall                                                              247
# split0_test_precision                                                    0.153846
# split1_test_precision                                                    0.285714
# split2_test_precision                                                    0.211765
# mean_test_precision                                                      0.217108
# std_test_precision                                                       0.053967
# rank_test_precision                                                           477
# split0_test_f1                                                           0.222222
# split1_test_f1                                                           0.142857
# split2_test_f1                                                           0.339623
# mean_test_f1                                                             0.234901
# std_test_f1                                                              0.080828
# rank_test_f1                                                                  484
# split0_test_roc_auc                                                      0.508553
# split1_test_roc_auc                                                      0.612094
# split2_test_roc_auc                                                      0.711757
# mean_test_roc_auc                                                        0.610801
# std_test_roc_auc                                                         0.082963
# rank_test_roc_auc                                                             444
# split0_test_recall_weighted                                               0.58209
# split1_test_recall_weighted                                              0.820896
# split2_test_recall_weighted                                              0.477612
# mean_test_recall_weighted                                                0.626866
# std_test_recall_weighted                                                 0.143677
# rank_test_recall_weighted                                                     436
#
#                                                                               201  \
# mean_fit_time                                                            0.020453
# std_fit_time                                                             0.000756
# mean_score_time                                                          0.012236
# std_score_time                                                           0.000642
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__max_depth                                                            3
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.75
# split1_test_recall                                                       0.190476
# split2_test_recall                                                       0.142857
# mean_test_recall                                                         0.361111
# std_test_recall                                                          0.275672
# rank_test_recall                                                              386
# split0_test_precision                                                    0.185185
# split1_test_precision                                                    0.363636
# split2_test_precision                                                        0.15
# mean_test_precision                                                      0.232941
# std_test_precision                                                       0.093526
# rank_test_precision                                                           455
# split0_test_f1                                                            0.29703
# split1_test_f1                                                               0.25
# split2_test_f1                                                           0.146341
# mean_test_f1                                                             0.231124
# std_test_f1                                                               0.06295
# rank_test_f1                                                                  485
# split0_test_roc_auc                                                      0.599342
# split1_test_roc_auc                                                      0.666456
# split2_test_roc_auc                                                      0.623894
# mean_test_roc_auc                                                        0.629897
# std_test_roc_auc                                                         0.027726
# rank_test_roc_auc                                                             395
# split0_test_recall_weighted                                              0.470149
# split1_test_recall_weighted                                              0.820896
# split2_test_recall_weighted                                              0.738806
# mean_test_recall_weighted                                                0.676617
# std_test_recall_weighted                                                 0.149792
# rank_test_recall_weighted                                                     367
#
#                                                                               97
# mean_fit_time                                                            0.019539
# std_fit_time                                                             0.000276
# mean_score_time                                                          0.011745
# std_score_time                                                           0.000265
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__max_depth                                                            2
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.1
# split1_test_recall                                                       0.190476
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.255556
# std_test_recall                                                          0.160325
# rank_test_recall                                                              476
# split0_test_precision                                                    0.060606
# split1_test_precision                                                    0.444444
# split2_test_precision                                                     0.25641
# mean_test_precision                                                       0.25382
# std_test_precision                                                       0.156712
# rank_test_precision                                                           417
# split0_test_f1                                                           0.075472
# split1_test_f1                                                           0.266667
# split2_test_f1                                                           0.333333
# mean_test_f1                                                             0.225157
# std_test_f1                                                              0.109287
# rank_test_f1                                                                  486
# split0_test_roc_auc                                                      0.428509
# split1_test_roc_auc                                                      0.626422
# split2_test_roc_auc                                                       0.64981
# mean_test_roc_auc                                                        0.568247
# std_test_roc_auc                                                          0.09927
# rank_test_roc_auc                                                             484
# split0_test_recall_weighted                                              0.634328
# split1_test_recall_weighted                                              0.835821
# split2_test_recall_weighted                                              0.701493
# mean_test_recall_weighted                                                0.723881
# std_test_recall_weighted                                                 0.083768
# rank_test_recall_weighted                                                     254
#
# [41 rows x 486 columns]

# %%
# Evaluation on test data
dt_clf = gscv_dt.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/12042023_1718/DecisionTreeClassifier-HAB_modelling_5_8-12042023_1718.pkl"
# dt_clf = load_best_estimator(pickle_file_name).steps[2][1]

y_pred = dt_clf.predict(X_eval)
DT_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
DT_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.89      0.92      0.90       147
#          poz       0.43      0.35      0.38        26
#
#     accuracy                           0.83       173
#    macro avg       0.66      0.63      0.64       173
# weighted avg       0.82      0.83      0.82       173

# %%
viz = dtreeviz(dt_clf, X, y,
                target_name="target",
                feature_names=X.columns,
                class_names=["neg", "poz"],
             fancy=False,
               scale=1.5
              )

# Save the visualization as a PNG file
viz_file_name = f"{dir_path}/DT_visualisation.svg"
viz.save(viz_file_name)
print(f"Visualization saved as: {viz_file_name}")

# Display the visualization
viz
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Visualization saved as: models/30042023_2331/DT_visualisation.svg

# %% [markdown]
# ## Random Forest Model

# %% [markdown]
# #### Model evaluation (Random Forest)

# %%
# Random forest with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
   ('smt', SMOTE()), 
   ('under', RandomUnderSampler()), 
    ('clf', RandomForestClassifier())
])

parameters = {
              'clf__n_estimators': [100,300,500],
              'clf__criterion': ['gini', 'entropy', 'log_loss'],
              'clf__class_weight': ['balanced', 'balanced_subsample', None],
              'smt__sampling_strategy': [ 0.2, 0.3, 0.4],
              'under__sampling_strategy': [0.5, 0.6, 0.7],
              'smt__k_neighbors': [3, 5]
             }

nfolds = 3
scores = ['recall', 'precision', 'f1', 'roc_auc']
refit_score = 'f1'
gscv_rf = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    return_train_score=False, 
                    verbose=1, 
                    refit=refit_score,
                    n_jobs=-1)
resultsGSCV = gscv_rf.fit(X, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_rf, classifier_name, notebook_name)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
pd.set_option("display.max_rows", None)
# Out:
# Fitting 3 folds for each of 486 candidates, totalling 1458 fits
# Best estimator saved as: models/30042023_2331/RandomForestClassifier-HAB_modelling_6_2-30042023_2331.pkl
#                                                                               261  \
# mean_fit_time                                                            1.865823
# std_fit_time                                                             0.036304
# mean_score_time                                                          0.249902
# std_score_time                                                           0.009914
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.571429
# split2_test_recall                                                        0.52381
# mean_test_recall                                                         0.531746
# std_test_recall                                                          0.029696
# rank_test_recall                                                               57
# split0_test_precision                                                    0.526316
# split1_test_precision                                                    0.857143
# split2_test_precision                                                     0.52381
# mean_test_precision                                                      0.635756
# std_test_precision                                                       0.156547
# rank_test_precision                                                            23
# split0_test_f1                                                           0.512821
# split1_test_f1                                                           0.685714
# split2_test_f1                                                            0.52381
# mean_test_f1                                                             0.574115
# std_test_f1                                                               0.07904
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.787281
# split1_test_roc_auc                                                      0.879688
# split2_test_roc_auc                                                      0.819638
# mean_test_roc_auc                                                        0.828869
# std_test_roc_auc                                                         0.038286
# rank_test_roc_auc                                                             149
#
#                                                                               473  \
# mean_fit_time                                                            1.437918
# std_fit_time                                                             0.016285
# mean_score_time                                                           0.23088
# std_score_time                                                           0.002132
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.761905
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.579365
# std_test_recall                                                          0.129441
# rank_test_recall                                                               17
# split0_test_precision                                                     0.47619
# split1_test_precision                                                    0.615385
# split2_test_precision                                                         0.5
# mean_test_precision                                                      0.530525
# std_test_precision                                                       0.060787
# rank_test_precision                                                           180
# split0_test_f1                                                           0.487805
# split1_test_f1                                                           0.680851
# split2_test_f1                                                           0.487805
# mean_test_f1                                                             0.552154
# std_test_f1                                                              0.091003
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                       0.78443
# split1_test_roc_auc                                                      0.899494
# split2_test_roc_auc                                                        0.7815
# mean_test_roc_auc                                                        0.821808
# std_test_roc_auc                                                         0.054945
# rank_test_roc_auc                                                             251
#
#                                                                               127  \
# mean_fit_time                                                            0.778052
# std_fit_time                                                             0.014489
# mean_score_time                                                          0.136049
# std_score_time                                                           0.002434
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.619048
# split2_test_recall                                                       0.571429
# mean_test_recall                                                         0.580159
# std_test_recall                                                          0.028857
# rank_test_recall                                                               13
# split0_test_precision                                                    0.611111
# split1_test_precision                                                        0.52
# split2_test_precision                                                    0.461538
# mean_test_precision                                                      0.530883
# std_test_precision                                                       0.061546
# rank_test_precision                                                           178
# split0_test_f1                                                           0.578947
# split1_test_f1                                                           0.565217
# split2_test_f1                                                           0.510638
# mean_test_f1                                                             0.551601
# std_test_f1                                                              0.029502
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.813377
# split1_test_roc_auc                                                      0.865571
# split2_test_roc_auc                                                      0.830805
# mean_test_roc_auc                                                        0.836584
# std_test_roc_auc                                                         0.021696
# rank_test_roc_auc                                                              67
#
#                                                                               112  \
# mean_fit_time                                                            0.283673
# std_fit_time                                                             0.002252
# mean_score_time                                                          0.052984
# std_score_time                                                           0.003238
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.619048
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.549206
# std_test_recall                                                          0.085655
# rank_test_recall                                                               30
# split0_test_precision                                                    0.545455
# split1_test_precision                                                        0.65
# split2_test_precision                                                        0.45
# mean_test_precision                                                      0.548485
# std_test_precision                                                       0.081678
# rank_test_precision                                                           131
# split0_test_f1                                                           0.571429
# split1_test_f1                                                           0.634146
# split2_test_f1                                                           0.439024
# mean_test_f1                                                               0.5482
# std_test_f1                                                              0.081334
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                      0.873026
# split1_test_roc_auc                                                      0.894227
# split2_test_roc_auc                                                      0.812895
# mean_test_roc_auc                                                        0.860049
# std_test_roc_auc                                                         0.034448
# rank_test_roc_auc                                                               1
#
#                                                                               348  \
# mean_fit_time                                                            0.957816
# std_fit_time                                                             0.034221
# mean_score_time                                                          0.156769
# std_score_time                                                           0.002211
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.45
# split1_test_recall                                                        0.47619
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.451587
# std_test_recall                                                          0.019473
# rank_test_recall                                                              268
# split0_test_precision                                                    0.692308
# split1_test_precision                                                    0.833333
# split2_test_precision                                                      0.5625
# mean_test_precision                                                      0.696047
# std_test_precision                                                       0.110599
# rank_test_precision                                                             1
# split0_test_f1                                                           0.545455
# split1_test_f1                                                           0.606061
# split2_test_f1                                                           0.486486
# mean_test_f1                                                             0.546001
# std_test_f1                                                              0.048817
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.819298
# split1_test_roc_auc                                                      0.898441
# split2_test_roc_auc                                                      0.809524
# mean_test_roc_auc                                                        0.842421
# std_test_roc_auc                                                         0.039812
# rank_test_roc_auc                                                              27
#
#                                                                               477  \
# mean_fit_time                                                            1.345102
# std_fit_time                                                             0.008802
# mean_score_time                                                          0.226994
# std_score_time                                                           0.000293
# param_clf__class_weight                                                      None
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.571429
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.515873
# std_test_recall                                                          0.040468
# rank_test_recall                                                               89
# split0_test_precision                                                     0.47619
# split1_test_precision                                                         0.6
# split2_test_precision                                                    0.666667
# mean_test_precision                                                      0.580952
# std_test_precision                                                       0.078919
# rank_test_precision                                                            77
# split0_test_f1                                                           0.487805
# split1_test_f1                                                           0.585366
# split2_test_f1                                                           0.555556
# mean_test_f1                                                             0.542909
# std_test_f1                                                              0.040821
# rank_test_f1                                                                    6
# split0_test_roc_auc                                                      0.798904
# split1_test_roc_auc                                                      0.867678
# split2_test_roc_auc                                                      0.806574
# mean_test_roc_auc                                                        0.824385
# std_test_roc_auc                                                         0.030772
# rank_test_roc_auc                                                             215
#
#                                                                               160  \
# mean_fit_time                                                            1.446485
# std_fit_time                                                             0.007709
# mean_score_time                                                           0.21834
# std_score_time                                                           0.006898
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.5
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.468254
# std_test_recall                                                          0.062492
# rank_test_recall                                                              199
# split0_test_precision                                                    0.526316
# split1_test_precision                                                    0.733333
# split2_test_precision                                                    0.666667
# mean_test_precision                                                      0.642105
# std_test_precision                                                       0.086281
# rank_test_precision                                                            16
# split0_test_f1                                                           0.512821
# split1_test_f1                                                           0.611111
# split2_test_f1                                                           0.484848
# mean_test_f1                                                              0.53626
# std_test_f1                                                              0.054146
# rank_test_f1                                                                    7
# split0_test_roc_auc                                                      0.815351
# split1_test_roc_auc                                                      0.845765
# split2_test_roc_auc                                                      0.782132
# mean_test_roc_auc                                                        0.814416
# std_test_roc_auc                                                         0.025986
# rank_test_roc_auc                                                             335
#
#                                                                               142  \
# mean_fit_time                                                            0.873841
# std_fit_time                                                             0.003845
# mean_score_time                                                           0.14329
# std_score_time                                                           0.001102
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.45
# split1_test_recall                                                       0.619048
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.483333
# std_test_recall                                                          0.100019
# rank_test_recall                                                              180
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.764706
# split2_test_precision                                                    0.533333
# mean_test_precision                                                      0.599346
# std_test_precision                                                       0.117716
# rank_test_precision                                                            49
# split0_test_f1                                                           0.473684
# split1_test_f1                                                           0.684211
# split2_test_f1                                                           0.444444
# mean_test_f1                                                             0.534113
# std_test_f1                                                              0.106804
# rank_test_f1                                                                    8
# split0_test_roc_auc                                                      0.813158
# split1_test_roc_auc                                                      0.881374
# split2_test_roc_auc                                                      0.813738
# mean_test_roc_auc                                                         0.83609
# std_test_roc_auc                                                         0.032021
# rank_test_roc_auc                                                              74
#
#                                                                               246  \
# mean_fit_time                                                            1.143221
# std_fit_time                                                             0.005898
# mean_score_time                                                          0.148018
# std_score_time                                                           0.001259
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                           0.45
# split1_test_recall                                                       0.571429
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.483333
# std_test_recall                                                          0.062904
# rank_test_recall                                                              180
# split0_test_precision                                                    0.529412
# split1_test_precision                                                    0.666667
# split2_test_precision                                                         0.6
# mean_test_precision                                                      0.598693
# std_test_precision                                                       0.056042
# rank_test_precision                                                            50
# split0_test_f1                                                           0.486486
# split1_test_f1                                                           0.615385
# split2_test_f1                                                                0.5
# mean_test_f1                                                             0.533957
# std_test_f1                                                              0.057842
# rank_test_f1                                                                    9
# split0_test_roc_auc                                                      0.839254
# split1_test_roc_auc                                                      0.888327
# split2_test_roc_auc                                                      0.841129
# mean_test_roc_auc                                                        0.856237
# std_test_roc_auc                                                         0.022704
# rank_test_roc_auc                                                               3
#
#                                                                               159  \
# mean_fit_time                                                            1.467708
# std_fit_time                                                             0.006002
# mean_score_time                                                          0.229054
# std_score_time                                                           0.002935
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.4
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.434921
# std_test_recall                                                          0.063333
# rank_test_recall                                                              348
# split0_test_precision                                                    0.727273
# split1_test_precision                                                    0.785714
# split2_test_precision                                                    0.571429
# mean_test_precision                                                      0.694805
# std_test_precision                                                       0.090444
# rank_test_precision                                                             2
# split0_test_f1                                                           0.516129
# split1_test_f1                                                           0.628571
# split2_test_f1                                                           0.457143
# mean_test_f1                                                             0.533948
# std_test_f1                                                              0.071111
# rank_test_f1                                                                   10
# split0_test_roc_auc                                                      0.804605
# split1_test_roc_auc                                                      0.857986
# split2_test_roc_auc                                                      0.819427
# mean_test_roc_auc                                                        0.827339
# std_test_roc_auc                                                         0.022499
# rank_test_roc_auc                                                             167
#
#                                                                               334  \
# mean_fit_time                                                            0.296359
# std_fit_time                                                             0.003656
# mean_score_time                                                          0.060626
# std_score_time                                                           0.002653
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.666667
# split2_test_recall                                                        0.52381
# mean_test_recall                                                         0.580159
# std_test_recall                                                          0.062098
# rank_test_recall                                                               13
# split0_test_precision                                                        0.44
# split1_test_precision                                                    0.666667
# split2_test_precision                                                     0.37931
# mean_test_precision                                                      0.495326
# std_test_precision                                                       0.123664
# rank_test_precision                                                           271
# split0_test_f1                                                           0.488889
# split1_test_f1                                                           0.666667
# split2_test_f1                                                               0.44
# mean_test_f1                                                             0.531852
# std_test_f1                                                              0.097395
# rank_test_f1                                                                   11
# split0_test_roc_auc                                                      0.816009
# split1_test_roc_auc                                                      0.902655
# split2_test_roc_auc                                                      0.772861
# mean_test_roc_auc                                                        0.830508
# std_test_roc_auc                                                         0.053971
# rank_test_roc_auc                                                             125
#
#                                                                               76   \
# mean_fit_time                                                            0.809747
# std_fit_time                                                             0.006651
# mean_score_time                                                          0.133939
# std_score_time                                                           0.002634
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.619048
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.515873
# std_test_recall                                                          0.078567
# rank_test_recall                                                               85
# split0_test_precision                                                    0.555556
# split1_test_precision                                                    0.684211
# split2_test_precision                                                    0.409091
# mean_test_precision                                                      0.549619
# std_test_precision                                                       0.112396
# rank_test_precision                                                           129
# split0_test_f1                                                           0.526316
# split1_test_f1                                                               0.65
# split2_test_f1                                                           0.418605
# mean_test_f1                                                              0.53164
# std_test_f1                                                              0.094542
# rank_test_f1                                                                   12
# split0_test_roc_auc                                                      0.826535
# split1_test_roc_auc                                                      0.859039
# split2_test_roc_auc                                                      0.784661
# mean_test_roc_auc                                                        0.823412
# std_test_roc_auc                                                         0.030445
# rank_test_roc_auc                                                             231
#
#                                                                               427  \
# mean_fit_time                                                            1.476281
# std_fit_time                                                              0.01358
# mean_score_time                                                           0.27327
# std_score_time                                                            0.01628
# param_clf__class_weight                                                      None
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.714286
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.547619
# std_test_recall                                                          0.121405
# rank_test_recall                                                               33
# split0_test_precision                                                         0.5
# split1_test_precision                                                    0.681818
# split2_test_precision                                                        0.36
# mean_test_precision                                                      0.513939
# std_test_precision                                                       0.131751
# rank_test_precision                                                           219
# split0_test_f1                                                                0.5
# split1_test_f1                                                           0.697674
# split2_test_f1                                                           0.391304
# mean_test_f1                                                              0.52966
# std_test_f1                                                              0.126821
# rank_test_f1                                                                   13
# split0_test_roc_auc                                                      0.800658
# split1_test_roc_auc                                                       0.89507
# split2_test_roc_auc                                                      0.785925
# mean_test_roc_auc                                                        0.827217
# std_test_roc_auc                                                         0.048354
# rank_test_roc_auc                                                             171
#
#                                                                               374  \
# mean_fit_time                                                             1.45188
# std_fit_time                                                             0.016294
# mean_score_time                                                          0.241304
# std_score_time                                                           0.010465
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.666667
# split2_test_recall                                                       0.428571
# mean_test_recall                                                         0.531746
# std_test_recall                                                           0.09976
# rank_test_recall                                                               57
# split0_test_precision                                                     0.47619
# split1_test_precision                                                    0.736842
# split2_test_precision                                                       0.375
# mean_test_precision                                                      0.529344
# std_test_precision                                                       0.152428
# rank_test_precision                                                           181
# split0_test_f1                                                           0.487805
# split1_test_f1                                                                0.7
# split2_test_f1                                                                0.4
# mean_test_f1                                                             0.529268
# std_test_f1                                                              0.125935
# rank_test_f1                                                                   14
# split0_test_roc_auc                                                      0.800439
# split1_test_roc_auc                                                      0.893384
# split2_test_roc_auc                                                      0.808049
# mean_test_roc_auc                                                        0.833957
# std_test_roc_auc                                                         0.042136
# rank_test_roc_auc                                                              88
#
#                                                                               93   \
# mean_fit_time                                                            1.307548
# std_fit_time                                                             0.006181
# mean_score_time                                                          0.212977
# std_score_time                                                           0.002686
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       500
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.5
# split1_test_recall                                                        0.52381
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.468254
# std_test_recall                                                          0.062492
# rank_test_recall                                                              199
# split0_test_precision                                                    0.555556
# split1_test_precision                                                    0.733333
# split2_test_precision                                                    0.533333
# mean_test_precision                                                      0.607407
# std_test_precision                                                       0.089504
# rank_test_precision                                                            43
# split0_test_f1                                                           0.526316
# split1_test_f1                                                           0.611111
# split2_test_f1                                                           0.444444
# mean_test_f1                                                              0.52729
# std_test_f1                                                              0.068045
# rank_test_f1                                                                   15
# split0_test_roc_auc                                                      0.805921
# split1_test_roc_auc                                                      0.894437
# split2_test_roc_auc                                                      0.812263
# mean_test_roc_auc                                                         0.83754
# std_test_roc_auc                                                         0.040315
# rank_test_roc_auc                                                              61
#
#                                                                               336  \
# mean_fit_time                                                             0.32026
# std_fit_time                                                             0.001075
# mean_score_time                                                          0.060345
# std_score_time                                                           0.003181
# param_clf__class_weight                                                      None
# param_clf__criterion                                                         gini
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.3
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': None, 'clf__criterion': ...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.571429
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.484921
# std_test_recall                                                          0.107545
# rank_test_recall                                                              153
# split0_test_precision                                                         0.5
# split1_test_precision                                                         0.8
# split2_test_precision                                                    0.466667
# mean_test_precision                                                      0.588889
# ...
# std_test_f1                                                              0.095814
# rank_test_f1                                                                  481
# split0_test_roc_auc                                                      0.748684
# split1_test_roc_auc                                                      0.812263
# split2_test_roc_auc                                                      0.772651
# mean_test_roc_auc                                                        0.777866
# std_test_roc_auc                                                         0.026217
# rank_test_roc_auc                                                             483
#
#                                                                               132  \
# mean_fit_time                                                            0.924038
# std_fit_time                                                             0.012256
# mean_score_time                                                          0.138674
# std_score_time                                                           0.001964
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.5
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                            0.4
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.238095
# mean_test_recall                                                         0.339683
# std_test_recall                                                          0.072253
# rank_test_recall                                                              483
# split0_test_precision                                                    0.470588
# split1_test_precision                                                    0.666667
# split2_test_precision                                                    0.357143
# mean_test_precision                                                      0.498133
# std_test_precision                                                       0.127855
# rank_test_precision                                                           266
# split0_test_f1                                                           0.432432
# split1_test_f1                                                           0.484848
# split2_test_f1                                                           0.285714
# mean_test_f1                                                             0.400998
# std_test_f1                                                               0.08428
# rank_test_f1                                                                  482
# split0_test_roc_auc                                                      0.813377
# split1_test_roc_auc                                                      0.867678
# split2_test_roc_auc                                                      0.781711
# mean_test_roc_auc                                                        0.820922
# std_test_roc_auc                                                         0.035499
# rank_test_roc_auc                                                             260
#
#                                                                               217  \
# mean_fit_time                                                             0.32292
# std_fit_time                                                             0.000414
# mean_score_time                                                          0.052697
# std_score_time                                                           0.000786
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            0.4
# split1_test_recall                                                       0.380952
# split2_test_recall                                                       0.380952
# mean_test_recall                                                         0.387302
# std_test_recall                                                          0.008979
# rank_test_recall                                                              443
# split0_test_precision                                                    0.347826
# split1_test_precision                                                    0.571429
# split2_test_precision                                                    0.347826
# mean_test_precision                                                       0.42236
# std_test_precision                                                       0.105407
# rank_test_precision                                                           430
# split0_test_f1                                                           0.372093
# split1_test_f1                                                           0.457143
# split2_test_f1                                                           0.363636
# mean_test_f1                                                             0.397624
# std_test_f1                                                              0.042227
# rank_test_f1                                                                  483
# split0_test_roc_auc                                                      0.766447
# split1_test_roc_auc                                                      0.814581
# split2_test_roc_auc                                                      0.780447
# mean_test_roc_auc                                                        0.787158
# std_test_roc_auc                                                         0.020215
# rank_test_roc_auc                                                             477
#
#                                                                               235  \
# mean_fit_time                                                            1.007223
# std_fit_time                                                             0.008497
# mean_score_time                                                          0.149474
# std_score_time                                                           0.007711
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       300
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.2
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            0.4
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.387302
# std_test_recall                                                          0.039904
# rank_test_recall                                                              443
# split0_test_precision                                                    0.380952
# split1_test_precision                                                    0.529412
# split2_test_precision                                                    0.304348
# mean_test_precision                                                      0.404904
# std_test_precision                                                        0.09343
# rank_test_precision                                                           461
# split0_test_f1                                                           0.390244
# split1_test_f1                                                           0.473684
# split2_test_f1                                                           0.318182
# mean_test_f1                                                             0.394037
# std_test_f1                                                               0.06354
# rank_test_f1                                                                  484
# split0_test_roc_auc                                                      0.798246
# split1_test_roc_auc                                                      0.799199
# split2_test_roc_auc                                                      0.785504
# mean_test_roc_auc                                                        0.794316
# std_test_roc_auc                                                         0.006244
# rank_test_roc_auc                                                             463
#
#                                                                               233  \
# mean_fit_time                                                            0.382263
# std_fit_time                                                             0.004237
# mean_score_time                                                          0.060042
# std_score_time                                                           0.001242
# param_clf__class_weight                                        balanced_subsample
# param_clf__criterion                                                      entropy
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          5
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.7
# params                          {'clf__class_weight': 'balanced_subsample', 'c...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.428571
# split2_test_recall                                                       0.333333
# mean_test_recall                                                         0.420635
# std_test_recall                                                          0.068272
# rank_test_recall                                                              365
# split0_test_precision                                                    0.333333
# split1_test_precision                                                    0.473684
# split2_test_precision                                                    0.318182
# mean_test_precision                                                      0.375066
# std_test_precision                                                       0.070007
# rank_test_precision                                                           483
# split0_test_f1                                                                0.4
# split1_test_f1                                                               0.45
# split2_test_f1                                                           0.325581
# mean_test_f1                                                              0.39186
# std_test_f1                                                              0.051119
# rank_test_f1                                                                  485
# split0_test_roc_auc                                                      0.784211
# split1_test_roc_auc                                                      0.896123
# split2_test_roc_auc                                                      0.780657
# mean_test_roc_auc                                                         0.82033
# std_test_roc_auc                                                         0.053613
# rank_test_roc_auc                                                             265
#
#                                                                               115
# mean_fit_time                                                            0.293813
# std_fit_time                                                             0.003791
# mean_score_time                                                          0.053573
# std_score_time                                                           0.000537
# param_clf__class_weight                                                  balanced
# param_clf__criterion                                                     log_loss
# param_clf__n_estimators                                                       100
# param_smt__k_neighbors                                                          3
# param_smt__sampling_strategy                                                  0.4
# param_under__sampling_strategy                                                0.6
# params                          {'clf__class_weight': 'balanced', 'clf__criter...
# split0_test_recall                                                           0.45
# split1_test_recall                                                       0.333333
# split2_test_recall                                                       0.238095
# mean_test_recall                                                         0.340476
# std_test_recall                                                          0.086657
# rank_test_recall                                                              482
# split0_test_precision                                                        0.45
# split1_test_precision                                                    0.583333
# split2_test_precision                                                    0.357143
# mean_test_precision                                                      0.463492
# std_test_precision                                                       0.092833
# rank_test_precision                                                           353
# split0_test_f1                                                               0.45
# split1_test_f1                                                           0.424242
# split2_test_f1                                                           0.285714
# mean_test_f1                                                             0.386652
# std_test_f1                                                              0.072144
# rank_test_f1                                                                  486
# split0_test_roc_auc                                                      0.829825
# split1_test_roc_auc                                                       0.86515
# split2_test_roc_auc                                                      0.783397
# mean_test_roc_auc                                                        0.826124
# std_test_roc_auc                                                         0.033478
# rank_test_roc_auc                                                             188
#
# [35 rows x 486 columns]

# %%
# Evaluation on test data
rf_clf = gscv_rf.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# rf_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation RF on test set
y_pred = rf_clf.predict(X_eval)
RF_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
RF_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.92      0.90      0.91       147
#          poz       0.52      0.58      0.55        26
#
#     accuracy                           0.86       173
#    macro avg       0.72      0.74      0.73       173
# weighted avg       0.86      0.86      0.86       173

# %% [markdown]
# Plot the mean ROC curve of the algorithm with best performing parameter selection. We will perform CV once again and plot the ROC curve for each fold and compute and plot the mean.

# %%
# Plot the ROC curve for RF

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval, y_eval)):
    classifier.fit(X_eval.iloc[train], y_eval[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X_eval.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
plt.savefig(f"{dir_path}/RF_ROC_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# Plot the mean precision-recall curve. The approach is the same as for the mean ROC curve.

# %%
# Plot the mean precision-recall curve. 

from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval, y_eval)):
    classifier.fit(X_eval.iloc[train], y_eval[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X_eval.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
plt.savefig(f"{dir_path}/RF_precision-recall_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# #### Feature importance (Random Forest)

# %%
# Feature importance of model (best RandomForest from gridsearch) with three methods!

fig, (ax2) = plt.subplots(1, 1, figsize=(10,9))
plt.subplots_adjust(wspace=1.1)

# Get feature importance with Permutation Based Feature Importance (randomly shuffles each feature and compute the 
# change in the model’s performance. The features which impact the performance the most are the most important one).
perm_importance = permutation_importance(rf_clf, X, y)
perm_sorted_idx = perm_importance.importances_mean.argsort()
x2 = X.columns[perm_sorted_idx]
y2 = perm_importance.importances_mean[perm_sorted_idx]
ax2.barh(x2, y2)
ax2.set_title("Permutation Importance Random Forest")
# Out:
# Text(0.5, 1.0, 'Permutation Importance Random Forest')

# %% [markdown]
# ### SHAP

# %%
# # Get feature importance with SHAP
# explainer = shap.TreeExplainer(rf)
# shap_values = explainer.shap_values(X)
# RF_shap = shap.summary_plot(shap_values, X, plot_type="bar")

# %%
# SHAP summary plot
explainer = shap.TreeExplainer(rf_clf)
shap_values = explainer.shap_values(X_eval)
classid = 1

# Save shap.summary_plot()
fig = shap.summary_plot(shap_values[classid], X_eval, max_display=len(X_eval.columns), class_names=le.classes_, show=False)
plt.savefig(f"{dir_path}/shap_summary_plot-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# #### Model Evaluation (MLP)

# %%
# Preprocessing for NN in scikit_learn

# Model evaluation with the pipeline of SMOTE oversampling and undersampling on the training dataset only (within each cross-validation fold)!

#Remove months from X
Xnn = X.drop(X.columns[0], axis=1)

X_display = Xnn.copy()  # *used for SHAP visualization so we can show unscaled values

# scalling numeric values for NN
scaled_array = StandardScaler().fit_transform(Xnn)
Xsc = pd.DataFrame(scaled_array, columns=Xnn.columns)

# %%
# pd.set_option("display.max_rows", None)

# %%
# MLP with grid search for parameters, testing on 5-fold CV with shuffling

pipeline = IMBLpipeline([
    ('over', SMOTE()),
    ('under', RandomUnderSampler()),
    ('clf', MLPClassifier(solver='lbfgs', max_iter=5000))
])

parameters = {'over__k_neighbors': range(1,7),
              'over__sampling_strategy': [0.5, 0.6, 0.8], # probaj poveča ovresampling do 0.9
              'under__sampling_strategy': [0.6, 0.7, 0.8],
              'clf__hidden_layer_sizes': [(2, ), (2, 2), (3,), (3,3)],
              'clf__solver': ['lbfgs', 'sgd', 'adam']
             }
nfolds = 3
scores = ['recall', "precision", 'f1', 'roc_auc']
gscv_NN = GridSearchCV(pipeline, 
                    parameters, 
                    scoring=scores,
                    cv=StratifiedKFold(n_splits=nfolds, shuffle=True),
                    n_jobs= -1, 
                    return_train_score=False, 
                    verbose=1, 
                    refit= "f1")
resultsGSCV = gscv_NN.fit(Xsc, y)

# Get the classifier name from the pipeline
classifier_name = resultsGSCV.best_estimator_.named_steps['clf'].__class__.__name__
    
# save the best estimator
save_best_estimator(gscv_NN, classifier_name, notebook_name)

results = pd.DataFrame(resultsGSCV.cv_results_)
display(results.sort_values(by=[f'rank_test_f1']).transpose())
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# 432 fits failed out of a total of 1944.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
#
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'clf__solver...
# split0_test_recall                                                            0.7
# split1_test_recall                                                       0.619048
# split2_test_recall                                                       0.619048
# mean_test_recall                                                         0.646032
# std_test_recall                                                          0.038161
# rank_test_recall                                                               10
# split0_test_precision                                                    0.451613
# split1_test_precision                                                     0.40625
# split2_test_precision                                                    0.254902
# mean_test_precision                                                      0.370922
# std_test_precision                                                       0.084103
# rank_test_precision                                                            65
# split0_test_f1                                                            0.54902
# split1_test_f1                                                           0.490566
# split2_test_f1                                                           0.361111
# mean_test_f1                                                             0.466899
# std_test_f1                                                              0.078518
# rank_test_f1                                                                    1
# split0_test_roc_auc                                                      0.735526
# split1_test_roc_auc                                                      0.786346
# split2_test_roc_auc                                                       0.67973
# mean_test_roc_auc                                                        0.733868
# std_test_roc_auc                                                         0.043542
# rank_test_roc_auc                                                              23
#
#                                                                               473  \
# mean_fit_time                                                            1.981234
# std_fit_time                                                             0.146054
# mean_score_time                                                          0.012621
# std_score_time                                                           0.001693
# param_clf__hidden_layer_sizes                                                (3,)
# param_clf__solver                                                            adam
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'clf__solver...
# split0_test_recall                                                           0.55
# split1_test_recall                                                       0.571429
# split2_test_recall                                                        0.47619
# mean_test_recall                                                          0.53254
# std_test_recall                                                          0.040794
# rank_test_recall                                                              138
# split0_test_precision                                                    0.314286
# split1_test_precision                                                    0.631579
# split2_test_precision                                                    0.333333
# mean_test_precision                                                      0.426399
# std_test_precision                                                       0.145292
# rank_test_precision                                                            14
# split0_test_f1                                                                0.4
# split1_test_f1                                                                0.6
# split2_test_f1                                                           0.392157
# mean_test_f1                                                             0.464052
# std_test_f1                                                              0.096183
# rank_test_f1                                                                    2
# split0_test_roc_auc                                                      0.737061
# split1_test_roc_auc                                                       0.77244
# split2_test_roc_auc                                                      0.675516
# mean_test_roc_auc                                                        0.728339
# std_test_roc_auc                                                         0.040047
# rank_test_roc_auc                                                              39
#
#                                                                               495  \
# mean_fit_time                                                            0.285461
# std_fit_time                                                              0.07822
# mean_score_time                                                          0.013537
# std_score_time                                                           0.003811
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         2
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'clf__solv...
# split0_test_recall                                                            0.6
# split1_test_recall                                                       0.761905
# split2_test_recall                                                        0.52381
# mean_test_recall                                                         0.628571
# std_test_recall                                                          0.099279
# rank_test_recall                                                               16
# split0_test_precision                                                     0.27907
# split1_test_precision                                                    0.432432
# split2_test_precision                                                    0.407407
# mean_test_precision                                                       0.37297
# std_test_precision                                                       0.067179
# rank_test_precision                                                            60
# split0_test_f1                                                           0.380952
# split1_test_f1                                                           0.551724
# split2_test_f1                                                           0.458333
# mean_test_f1                                                              0.46367
# std_test_f1                                                              0.069819
# rank_test_f1                                                                    3
# split0_test_roc_auc                                                      0.695175
# split1_test_roc_auc                                                      0.831858
# split2_test_roc_auc                                                      0.671513
# mean_test_roc_auc                                                        0.732849
# std_test_roc_auc                                                         0.070674
# rank_test_roc_auc                                                              26
#
#                                                                               516  \
# mean_fit_time                                                            0.427742
# std_fit_time                                                              0.13499
# mean_score_time                                                          0.010927
# std_score_time                                                           0.000212
# param_clf__hidden_layer_sizes                                              (3, 3)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.6
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (3, 3), 'clf__solv...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.571429
# split2_test_recall                                                        0.47619
# mean_test_recall                                                         0.515873
# std_test_recall                                                          0.040468
# rank_test_recall                                                              177
# split0_test_precision                                                    0.333333
# split1_test_precision                                                         0.6
# split2_test_precision                                                    0.333333
# mean_test_precision                                                      0.422222
# std_test_precision                                                       0.125708
# rank_test_precision                                                            15
# split0_test_f1                                                                0.4
# split1_test_f1                                                           0.585366
# split2_test_f1                                                           0.392157
# mean_test_f1                                                             0.459174
# std_test_f1                                                              0.089288
# rank_test_f1                                                                    4
# split0_test_roc_auc                                                          0.65
# split1_test_roc_auc                                                      0.779815
# split2_test_roc_auc                                                      0.670881
# mean_test_roc_auc                                                        0.700232
# std_test_roc_auc                                                         0.056916
# rank_test_roc_auc                                                             145
#
#                                                                               332  \
# mean_fit_time                                                            0.339966
# std_fit_time                                                              0.15549
# mean_score_time                                                          0.011408
# std_score_time                                                           0.000248
# param_clf__hidden_layer_sizes                                                (3,)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.8
# params                          {'clf__hidden_layer_sizes': (3,), 'clf__solver...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.619048
# split2_test_recall                                                       0.619048
# mean_test_recall                                                         0.579365
# std_test_recall                                                           0.05612
# rank_test_recall                                                               65
# split0_test_precision                                                     0.37037
# split1_test_precision                                                    0.419355
# split2_test_precision                                                    0.351351
# mean_test_precision                                                      0.380359
# std_test_precision                                                       0.028647
# rank_test_precision                                                            52
# split0_test_f1                                                           0.425532
# split1_test_f1                                                                0.5
# split2_test_f1                                                           0.448276
# mean_test_f1                                                             0.457936
# std_test_f1                                                              0.031159
# rank_test_f1                                                                    5
# split0_test_roc_auc                                                      0.723246
# split1_test_roc_auc                                                      0.828487
# split2_test_roc_auc                                                      0.698904
# mean_test_roc_auc                                                        0.750212
# std_test_roc_auc                                                         0.056234
# rank_test_roc_auc                                                               7
#
#                                                                               28   \
# mean_fit_time                                                            0.328324
# std_fit_time                                                             0.156814
# mean_score_time                                                          0.011702
# std_score_time                                                           0.001287
# param_clf__hidden_layer_sizes                                                (2,)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         4
# param_over__sampling_strategy                                                 0.5
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'clf__solver...
# split0_test_recall                                                            0.5
# split1_test_recall                                                       0.714286
# split2_test_recall                                                        0.52381
# mean_test_recall                                                         0.579365
# std_test_recall                                                          0.095897
# rank_test_recall                                                               65
# split0_test_precision                                                    0.416667
# split1_test_precision                                                    0.405405
# split2_test_precision                                                    0.323529
# mean_test_precision                                                      0.381867
# ...
# rank_test_precision                                                           601
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  643
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             531
#
#                                                                               24   \
# mean_fit_time                                                            0.014586
# std_fit_time                                                             0.001347
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                                (2,)
# param_clf__solver                                                           lbfgs
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2,), 'clf__solver...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              516
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           510
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  644
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             533
#
#                                                                               223  \
# mean_fit_time                                                              0.0125
# std_fit_time                                                             0.000682
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_clf__solver                                                             sgd
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2, 2), 'clf__solv...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              589
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           542
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  645
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             628
#
#                                                                               222  \
# mean_fit_time                                                            0.012747
# std_fit_time                                                             0.000983
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_clf__solver                                                             sgd
# param_over__k_neighbors                                                         1
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'clf__solv...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              588
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           547
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  646
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             623
#
#                                                                               240  \
# mean_fit_time                                                            0.016501
# std_fit_time                                                              0.00316
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                              (2, 2)
# param_clf__solver                                                             sgd
# param_over__k_neighbors                                                         3
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.6
# params                          {'clf__hidden_layer_sizes': (2, 2), 'clf__solv...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              564
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           540
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  647
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             513
#
#                                                                               97
# mean_fit_time                                                            0.013527
# std_fit_time                                                             0.000291
# mean_score_time                                                               0.0
# std_score_time                                                                0.0
# param_clf__hidden_layer_sizes                                                (2,)
# param_clf__solver                                                             sgd
# param_over__k_neighbors                                                         5
# param_over__sampling_strategy                                                 0.8
# param_under__sampling_strategy                                                0.7
# params                          {'clf__hidden_layer_sizes': (2,), 'clf__solver...
# split0_test_recall                                                            NaN
# split1_test_recall                                                            NaN
# split2_test_recall                                                            NaN
# mean_test_recall                                                              NaN
# std_test_recall                                                               NaN
# rank_test_recall                                                              556
# split0_test_precision                                                         NaN
# split1_test_precision                                                         NaN
# split2_test_precision                                                         NaN
# mean_test_precision                                                           NaN
# std_test_precision                                                            NaN
# rank_test_precision                                                           543
# split0_test_f1                                                                NaN
# split1_test_f1                                                                NaN
# split2_test_f1                                                                NaN
# mean_test_f1                                                                  NaN
# std_test_f1                                                                   NaN
# rank_test_f1                                                                  648
# split0_test_roc_auc                                                           NaN
# split1_test_roc_auc                                                           NaN
# split2_test_roc_auc                                                           NaN
# mean_test_roc_auc                                                             NaN
# std_test_roc_auc                                                              NaN
# rank_test_roc_auc                                                             594
#
# [34 rows x 648 columns]

# %%
# Evaluation on test data
nn_clf = gscv_NN.best_estimator_.steps[2][1]

# # Load the best estimator from the saved pickle file (replace with acctual file name)
# pickle_file_name = "models/timestamp/classifier_name-notebook_name.pkl"
# nn_clf = load_best_estimator(pickle_file_name).steps[2][1]

# Evaluation of NN on test set
X_eval_nn = X_eval.drop(X_eval.columns[0], axis=1)
scaler = StandardScaler().fit(Xnn)
X_eval_sc = scaler.transform(X_eval_nn)
X_eval_sc = pd.DataFrame(X_eval_sc, columns=Xnn.columns)
y_pred = nn_clf.predict(X_eval_sc)
NN_classification_report = classification_report(y_eval, y_pred)

# Create classification report as dictionary
NN_report_dict = classification_report(y_eval, y_pred, output_dict=True)

print(classification_report(y_eval, y_pred, target_names=["neg", "poz"]))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.90      0.72      0.80       147
#          poz       0.25      0.54      0.35        26
#
#     accuracy                           0.69       173
#    macro avg       0.58      0.63      0.57       173
# weighted avg       0.80      0.69      0.73       173

# %%
# Plot the ROC curve for MLP (Check code as moved form RF!). 

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval_sc, y_eval)):
    classifier.fit(X_eval_sc.iloc[train], y_eval[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X_eval_sc.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Baseline (random prediction)", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (ROC-AUC, {nfolds}-fold CV)',
)
ax.legend(loc="lower right")
plt.tight_layout()
plt.savefig(f"{dir_path}/MLP_ROC_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %%
# Plot the mean precision-recall curve for MLP (Check code as moved form RF!). 

from sklearn.metrics import PrecisionRecallDisplay

cv = StratifiedKFold(n_splits=3, shuffle=True)
classifier = resultsGSCV.best_estimator_

prs = []
aucs = []
mean_r = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(10,8))
for i, (train, test) in enumerate(cv.split(X_eval_sc, y_eval)):
    classifier.fit(X_eval_sc.iloc[train], y_eval[train])
    viz = PrecisionRecallDisplay.from_estimator(
        classifier,
        X_eval_sc.iloc[test],
        y_eval[test],
        name="fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_pr = np.interp(mean_r, viz.recall[::-1], viz.precision[::-1])
    prs.append(interp_pr)

mean_p = np.mean(prs, axis=0)
ax.plot(
    mean_r,
    mean_p,
    color="b",
    label=f"mean",
    lw=2,
    alpha=0.8,
)
ax.legend(loc="lower left")
clfname = [str(step[1].__class__.__name__) for step in classifier.steps if step[0]=='clf'][0]
ax.set(
    # xlim=[-0.05, 1.05],
    # ylim=[-0.05, 1.05],
    title=f'{clfname} evaluation (precision-recall, {nfolds}-fold CV)')
plt.tight_layout()
plt.savefig(f"{dir_path}/MLP_precision-recall_curve-{notebook_name}-{timestamp}.pdf", format="pdf", dpi=300)
plt.show()

# %% [markdown]
# #### Feature Importance (MLP)

# %% [markdown]
# #### Feature importance with SHAP

# %% [markdown]
# First, visualize the impact of all features on both classes in one chart. We are using KernelExplainer but simpler general Explainer should be also tested once the SHAP code fixes all bugs.
#
# **Note: SHAP explanations change between runs because of sampling and probably other random factors!**

# %%
# # explain the model's predictions using SHAP
# import shap
# import warnings
# warnings.filterwarnings("ignore")
# shap.initjs()

# explainer = shap.KernelExplainer(NN_model.predict_proba, shap.sample(X_eval_sc,20))
# shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
# shap.summary_plot(shap_values, X_eval_sc, max_display=len(X.columns), class_names=le.classes_)

# %% [markdown]
# Now for each class separately. We observe the impact of features on the returned model's probability for a given class.

# %%
import shap
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
shap.initjs()

explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(X_eval_sc, 50))
shap_values = explainer.shap_values(X_eval_sc, nsamples=50)
classid = 1

# Save shap.summary_plot()
fig = shap.summary_plot(shap_values[classid], X_eval_sc, max_display=len(X_eval_sc.columns), class_names=le.classes_, show=False)
plt.savefig(f"{dir_path}/shap_summary_plot-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
#   0%|          | 0/173 [00:00<?, ?it/s]

# %%
# Try dependence contribution plot
explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(Xsc,50))
shap_values = explainer.shap_values(Xsc, nsamples=50)
for i in Xsc.columns:
    shap.dependence_plot(i, shap_values[1], Xsc,) #interaction_index="salinity"
# Out:
#   0%|          | 0/402 [00:00<?, ?it/s]

# %% [markdown]
# Example intepretation: The fact this slopes upward says the higher the soca flow, the higher the model's prediction is for poz/neg. The spread suggests that other features must interact with Soca flow.
# In general, high Soca flow increases the chance of poz/neg. But if the sea temp is moderate or low, that trend reverses and even high soca flow does not increase preditions of poz/neg as the sea temp is too low.
# https://www.kaggle.com/code/dansbecker/advanced-uses-of-shap-values
# ----
# To interpret the dependence contribution plot, look for trends or patterns in the relationship between the 'salinity' feature values and their SHAP values. For example:
#
# If the points show a clear positive trend, it means that as the 'salinity' value increases, its positive contribution to the model's prediction also increases.
# If the points show a clear negative trend, it means that as the 'salinity' value increases, its negative contribution to the model's prediction increases (i.e., higher 'salinity' values decrease the probability of class 1).
# If there is no clear trend or the points are scattered randomly, it means that there is no strong relationship between the 'salinity' feature values and their SHAP values.
# Additionally, observe the colors of the points in the plot. If there is a clear pattern in the colors, it may indicate that the interaction between 'salinity' and the interaction feature has a significant impact on the model's predictions. This can help you identify interactions between features that the model is capturing.

# %% [markdown]
# Now let's explain the prediction of a single instance. We will show the explanation of the bigger predicted probability to see why the model decided as it did. But in practice we could be interested only in the explanation of the probability of the positive prediction.

# %%
instanceID = 10
instance = Xsc.iloc[[instanceID]]
display_instance = X_display.iloc[[instanceID]]

prediction = nn_clf.predict(instance)[0]
prediction_probs = nn_clf.predict_proba(instance)[0]
print(f'real value: {y[instanceID]}, \npredicted: {prediction}, \npredicted probs: {prediction_probs}')
max_p_id = prediction_probs.argmax()  # we will show the explanation of the bigger predicted probability
print(f'Explanation for prediction: class={max_p_id}, p={prediction_probs.max()}')

explainer = shap.KernelExplainer(nn_clf.predict_proba, shap.sample(Xsc, 50))
shap_values = explainer.shap_values(instance, nsamples=500)
shap.force_plot(explainer.expected_value[max_p_id], shap_values[max_p_id], features=display_instance)
# Out:
# real value: 1,
# predicted: 0,
# predicted probs: [0.94787677 0.05212323]
# Explanation for prediction: class=0, p=0.9478767656193879
#   0%|          | 0/1 [00:00<?, ?it/s]
# <div id='iV0NPCB121UBZDRYJCP3C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6239506462407821, "outValue": 0.9478767656193879, "link": "identity", "featureNames": ["DSP", "Dinophysis caudata", "Dinophysis fortii", "Phalacroma rotundatum", "Dinophysis sacculus", "Dinophysis tripos", "sun [h]", "air temp", "wind strength", "precipitation", "Chl-a", "salinity", "T", "DIN", "PO4-P", "Soca"], "features": {"1": {"effect": -0.012242632739329753, "value": 0.0}, "2": {"effect": 0.02066137319396641, "value": 10.0}, "3": {"effect": -0.00858856867006002, "value": 10.0}, "4": {"effect": -0.0030435278264944344, "value": 0.0}, "5": {"effect": -0.08868390103461912, "value": 30.0}, "6": {"effect": 0.08765919180111696, "value": 42.99999999999999}, "7": {"effect": 0.09651230548514896, "value": 6.8428571428571425}, "8": {"effect": -0.07125010839546295, "value": 2.2333333333333334}, "9": {"effect": -0.13510575250818999, "value": 158.79999999999998}, "10": {"effect": 0.326248570449765, "value": 4.24}, "11": {"effect": -0.11782049222693841, "value": 31.89}, "12": {"effect": -0.01207325594704322, "value": 14.55}, "13": {"effect": 0.04459405038359439, "value": 10.379999905824656}, "14": {"effect": 0.005822329923254349, "value": 0.00999999977648258}, "15": {"effect": 0.19123653748989763, "value": 10683.316}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iV0NPCB121UBZDRYJCP3C')
#   );
# </script>

# %% [markdown]
# Interpretation:
#
# Observe the base value (Expected value) and the prediction line. This gives you an idea of the overall prediction for the instance compared to the average prediction.
#
# Look at the colored arrows and identify the most important features, which are the ones with the longest arrows. These features have the greatest impact on the prediction.
#
# Analyze the direction and color of the arrows to understand whether each feature increases or decreases the probability of the positive class (class 1) and whether the feature values are high or low.
#
# Consider the interactions between the features and their combined impact on the prediction.
#
# By analyzing the force plot, you can gain insights into the contributions of each feature to the model's prediction for a specific instance, helping you understand the model's decision-making process.

# %% [markdown]
# ### LIME

# %%
import lime
from lime import lime_tabular

# Create a LIME explainer object
lime_explainer = lime_tabular.LimeTabularExplainer(
    training_data=np.array(Xsc),
    feature_names=Xsc.columns,
    class_names=le.classes_,
    mode='classification'
)

# Exaplain an instance
instanceID = 100
lime_exp = lime_explainer.explain_instance(
    data_row=Xsc.iloc[instanceID], 
    predict_fn=nn_clf.predict_proba
)

lime_exp.show_in_notebook(show_table=True)

# Save the LIME explanation as an image file
# fig = lime_exp.as_pyplot_figure(label=1)
# plt.savefig(f"{dir_path}/lime_explanation-{classifier_name}-{notebook_name}-{timestamp}.pdf", format="pdf", bbox_inches='tight')
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %% [markdown]
# ### Conclusion

# %%
# Define a function to extract the metrics from the classification report dictionary
def extract_metrics(report_dict):
    metrics = {}
    for class_label in report_dict:
        if class_label in ('accuracy', 'macro avg', 'weighted avg'):
            continue
        metrics[class_label] = {
            'precision': report_dict[class_label]['precision'],
            'recall': report_dict[class_label]['recall'],
            'f1-score': report_dict[class_label]['f1-score'],
            'support': report_dict[class_label]['support']
        }
    return metrics

# Extract the metrics for each classifier
SVM_metrics = extract_metrics(SVM_report_dict)
DT_metrics = extract_metrics(DT_report_dict)
RF_metrics = extract_metrics(RF_report_dict)
NN_metrics = extract_metrics(NN_report_dict)

# Create a dictionary to store the metrics for each classifier
classifier_metrics = {
    'Support Vector Mashines': SVM_metrics,
    'Decision Tree': DT_metrics,
    'Random Forest': RF_metrics,
    'Neural Network': NN_metrics
}

# Convert the dictionary to a pandas DataFrame
summary_df = pd.concat({k: pd.DataFrame(v).transpose() for k, v in classifier_metrics.items()}, axis=0)
summary_df.reset_index(inplace=True)
summary_df.columns = ['Classifier', 'Class', 'Precision', 'Recall', 'F1-score', 'Support']

# Map the original class labels to the new names
class_name_mapping = {
    '0': 'neg',
    '1': 'poz'
}
summary_df['Class'] = summary_df['Class'].map(class_name_mapping)

# Filter the summary DataFrame to display only the 'poz' class
poz_summary_df = summary_df.query("Class == 'poz'")

# Display the filtered summary DataFrame
poz_summary_df
# Out:
#                 Classifier Class  Precision    Recall  F1-score  Support
# 1  Support Vector Mashines   poz   0.265625  0.653846  0.377778     26.0
# 3            Decision Tree   poz   0.428571  0.346154  0.382979     26.0
# 5            Random Forest   poz   0.517241  0.576923  0.545455     26.0
# 7           Neural Network   poz   0.254545  0.538462  0.345679     26.0

# %%
# Format table

poz_summary_df = poz_summary_df.round(2)
poz_summary_df = poz_summary_df.set_index('Classifier')
poz_summary_df = poz_summary_df.drop(['Support', "Class"], axis=1)
# poz_summary_df = poz_summary_df.style.highlight_max(subset=['Precision', 'Recall', 'F1-score'], color='green')
poz_summary_df.to_csv(f"{dir_path}/results_summary_df.csv")
poz_summary_df
# Out:
#                          Precision  Recall  F1-score
# Classifier
# Support Vector Mashines       0.27    0.65      0.38
# Decision Tree                 0.43    0.35      0.38
# Random Forest                 0.52    0.58      0.55
# Neural Network                0.25    0.54      0.35
